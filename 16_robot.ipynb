# %%
dbase='/Users/romanpodoynitsyn/workbase/work/workbase_16.db'
dbase_city='/Users/romanpodoynitsyn/workbase/work/workbase_city.db'
from pprint import pprint  
import requests  
import sqlite3

# %%
conn = sqlite3.connect(dbase)
print ("Opened database successfully")

conn.execute('''CREATE TABLE USERS
         (
         id_api, first_name, last_name, nickname, city, country, bdate, career, domain, education, interests_all, contacts_all, followers_count, home_town, last_seen, maiden_name, occupation, personal, photo_100, photo_max_orig, relatives, relation, schools, screen_name, sex, universities   TEXT    
         
         );''')
print ("Table created successfully")


conn.close()
# Out:
# Opened database successfully
# Table created successfully

# %%
def write_to (LLL):
    conn = sqlite3.connect(dbase)
    #print ("Opened database successfully")
    cursor = conn.cursor()

    cursor.executemany("INSERT INTO USERS VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)", LLL)

    conn.commit()
    #print ("Records created successfully")
    conn.close()

# %%
columns_bd='id, first_name, last_name, nickname, city, country, bdate, career, domain, education, interests_all, contacts_all, followers_count, home_town, last_seen, maiden_name, occupation, personal, photo_100, photo_max_orig, relatives, relation, schools, screen_name, sex, universities'   

columns_bd_add ='political, langs, religion, inspired_by, people_main, life_main, smoking, alcohol, city_name, country_name, university_name_, faculty_name_, graduation_, platform, last_time, relation_name,  occupation_type, occupation_place, contacts'    

columns_bd_list=columns_bd.split(', ')


interests_list=['about', 'activities', 'books', 'games', 'interests', 'movies', 'tv', 'music', 'quotes', 'status']

contacts_list=['skype', 'facebook', 'twitter', 'livejournal', 'Instagram', 'contacts', 'mobile_phone', 'home_phone','site']



platform_dict={
'1':  'mobile web site',
'2':  'iPhone',
'3':  'iPad',
'4':  'Android',
'5':  'Windows Phone',
'6':  'Windows 10',
'7':  'full web site',
}

relation_dict={ 
'1' : 'не женат/не замужем',
'2' : 'есть друг/есть подруга',
'3' : 'помолвлен/помолвлена',
'4' : 'женат/замужем',
'5' : 'всё сложно',
'6' : 'в активном поиске',
'7' : 'влюблён/влюблена',
'8' : 'в гражданском браке',
'0' : '?'}



personal_ = ['political','langs','religion','inspired_by','people_main','life_main','smoking','alcohol']

political_dict={'0' : '?',
    '1' : 'коммунистические',
'2' : 'социалистические',
'3' : 'умеренные',
'4' : 'либеральные',
'5' : 'консервативные',
'6' : 'монархические',
'7' : 'ультраконсервативные',
'8' : 'индифферентные',
'9' : 'либертарианские'}

people_main_dict={'0' : '?',
                  '1' : 'ум и креативность',
'2' : 'доброта и честность',
'3' : 'красота и здоровье',
'4' : 'власть и богатство',
'5' : 'смелость и упорство',
'6' : 'юмор и жизнелюбие'
}

life_main_dict={'0' : '?',
                '1':'семья и дети',
'2':'карьера и деньги',
'3':'развлечения и отдых',
'4':'наука и исследования',
'5':'совершенствование мира',
'6':'саморазвитие',
'7':'красота и искусство',
'8':'слава и влияние'}

smoking_dict={'0' : '?',
'1' :'резко негативное',
'2' : 'негативное',
'3' : 'компромиссное',
'4' : 'нейтральное',
'5' : 'положительное'}
alcohol_dict={'0' : '?',
'1' :'резко негативное',
'2' : 'негативное',
'3' : 'компромиссное',
'4' : 'нейтральное',
'5' : 'положительное'}

def robot_1(response_):

    LLx=list()
    
    for ii in range(0, len(response_)):      
        #print('ii___',ii)
        user = response_[ii]
        if 'deactivated' in user:
            continue
        if user['first_name']=='DELETED':
            continue
        columns_bd_dict={}
      
        for X in columns_bd_list:
            if X in user:               
                columns_bd_dict[X]=user[X]          
            else:
                columns_bd_dict[X]='?'               
        
        columns_bd_dict['interests_all']=interests_(user)
        columns_bd_dict['contacts_all']=contacts_(user)
        
        LLx.append(replace_(columns_bd_dict))      
    return LLx



def interests_(user):
    dict_1={}
    for X in interests_list:
        if X in user:
            if len(user[X])==0:
                continue
            else:
                dict_1[X]=user[X]
    if len(dict_1)==0:
        return '?'
    else:
        return dict_1
    
    
def contacts_(user):
    dict_1={}
    for X in contacts_list:
        if X in user:
            if len(user[X])==0:
                continue
            else:
                dict_1[X]=user[X]
    if len(dict_1)==0:
        return '?'
    else:
        return dict_1
    

import datetime
from timeit import default_timer as timer


def replace_ (return_robot_1):
    #for ii in range(0, len(return_robot_1)):      
        #user = return_robot_1[ii]
        user=return_robot_1
        
        #start = timer()
        
        if 'city' in user:
            if 'title' in user['city']:
                user['city']=user['city']['title']
        
        #end = timer()
        #print('city___',(end - start)*10000000) 
        #start = timer()
        
        if 'country' in user:
            if 'title' in user['country']:
                user['country']=user['country']['title']      
        
        #end = timer()
        #print('country___',(end - start)*10000000) 
        #start = timer()
        
        if 'last_seen' in user:
            if 'time' in user['last_seen']:
                try:
                    time_seen=datetime.datetime.fromtimestamp(int(user['last_seen']['time']))
                    user['last_seen']['time']=time_seen.strftime('%Y-%m-%d %H:%M:%S')
                except:
                    print(user['id'],'__',user['first_name'],'___',user['last_name'])
            if ('platform' in user['last_seen'] and str(user['last_seen']['platform']) in platform_dict.keys()):
                user['last_seen']['platform']=platform_dict[str(user['last_seen']['platform'])]
        
        #end = timer()
        #print('last_seen___',(end - start)*10000000) 
        #start = timer()
        
        if 'relation' in user:
           # if ('relation' in user['relation'] and str(user['relation']) in relation_dict.keys()):
            if  str(user['relation']) in relation_dict.keys(): 
                user['relation']=relation_dict[str(user['relation'])]
        
        #end = timer()
        #print('relation___',(end - start)*10000000) 
        #start = timer()
        
        if 'career' in user:
            if len(user['career'])>0:
                for iii in range(0,len(user['career'])):
                    if 'city_id' in user['career'][iii]:
                        user['career'][iii]['city_id']=city_id(user['career'][iii]['city_id'])
                    if 'country_id' in user['career'][iii]:
                        user['career'][iii]['country_id']=country_id(user['career'][iii]['country_id'])
        
        #end = timer()
        #print('career___',(end - start)*10000000) 
        #start = timer()
        
        if 'universities' in user:
            if len(user['universities'])>0:
                for iii in range(0,len(user['universities'])):
                    if 'city' in user['universities'][iii]:
                        user['universities'][iii]['city']=city_id(user['universities'][iii]['city'])
                    if 'country' in user['universities'][iii]:
                        user['universities'][iii]['country']=country_id(user['universities'][iii]['country'])
        
        #end = timer()
        #print('universities___',(end - start)*10000000) 
        #start = timer()
        
        if 'schools' in user:
            u=user['schools']
        
            if len(u)>0:
                for iii in range(0,len(u)):
                    if 'city' in u[iii]:
                        u[iii]['city']=city_id(u[iii]['city'])
                    if 'country' in u[iii]:
                        u[iii]['country']=country_id(u[iii]['country'])
        
        
        #end = timer()
        #print('schools___',(end - start)*10000000) 
        #start = timer()
        
        if 'personal' in user:
            #print('check_1')
            for X in personal_:
               # print('check_2')
                if X in user['personal']:
                   # print('check_3')
                    
                    if (X=='political' and str(user['personal'][X]) in political_dict.keys()):
                        user['personal'][X]=political_dict[str(user['personal'][X])]
                        
                        continue
                    if (X=='people_main' and str(user['personal'][X]) in people_main_dict.keys()):
                        user['personal'][X]=people_main_dict[str(user['personal'][X])]
                        
                        continue
                    if (X=='life_main' and str(user['personal'][X]) in life_main_dict.keys()):
                        user['personal'][X]=life_main_dict[str(user['personal'][X])]
                        
                        continue
                    if (X=='smoking' and str(user['personal'][X]) in smoking_dict.keys()):              
                        user['personal'][X]=smoking_dict[str(user['personal'][X])]
                        
                        continue
                    if (X=='alcohol' and str(user['personal'][X]) in alcohol_dict.keys()):
                        user['personal'][X]=alcohol_dict[str(user['personal'][X])]
                        
                        continue
        
        #end = timer()
        #print('personal___',(end - start)*10000000)
        
        return user
        
    


def turn_to_list(return_robot_1):
   
    list_2=list()
    for k in range(0,len(return_robot_1)):
        list_1=list()
        for kk in columns_bd_list:
            list_1.append(str(return_robot_1[k][kk]))
        list_2.append(list_1)
    return list_2

# %%
#old method
city_id_dict_1={2: 'Saint Petersburg', 458: 'Berlin', 16: 'Torino', 314: 'Kyiv', 1713650: 'Heraklion', 14269: 'Dundee', 2057: 'Birmingham', 1719: 'Warrington', 295: 'London', 635: 'Hamburg', 1: 'Moscow', 1937764: 'Paris', 3296: 'Tel Aviv', 147: 'Tyumen', 0: 0, 1029: 'Kronshtadt', 10: 'Volgograd', 20665: 'Antwerpen', 194: 'Tashkent', 2202278: 'Kraków', 1147: 'Pesochny', 73: 'Krasnoyarsk', 1945830: 'Shanghai', 2182: 'Reykjavík', 208: 'San Francisco', 102: 'Norilsk', 72: 'Krasnodar', 4670: 'Khadyzhensk', 186: 'Tikhvin', 2510: 'Alushta', 167: 'Yuzhno-Sakhalinsk', 1941: 'Auckland', 4973578: 'Milwaukee', 5529: 'Milwaukee', 20619: 'Charleston', 1057: 'Lviv', 175: 'Apatity', 139: 'Taganrog', 119: 'Rostov-on-Don', 1707: 'Rossosh', 99: 'Novosibirsk', 1709510: 'Golden', 3238: 'Kamen-Na-Obi', 9632: '?', 1515588: '?', 12: 'Pushkin', 61: 'Kaliningrad', 294: 'Megion', 1030816: 'Bolshoe Isakovo', 402: 'Haifa', 207: 'Wünsdorf', 1743: 'Kirishi', 1711731: 'Köln', 216: 'Bonn', 96: 'Nizhny Tagil', 3722863: 'Taichung', 1714892: 'Cancún', 1926921: 'San Cristóbal de Las Casas', 687: 'Ostrovnoy', 1914764: 'Tokyo', 244: 'Vitebsk', 1713816: 'Daegu', 2001398: 'Bielefeld', 221: 'Turku', 3215024: 'Salo', 74: 'Kurgan', 33: 'Bryansk', 22168: 'Amsterdam', 1956107: 'Oxford', 20691: 'Tosno', 20602: 'Cork', 190: 'Vorkuta', 255: 'Inta', 382: 'Nefteyugansk', 4965: 'Lexington', 378: 'New York City', 55: 'Ivanovo', 83: 'Maykop', 250: 'Iowa City', 177: 'Vyborg', 169: 'Yaroslavl', 1611: 'Tutaev', 1803702: 'Phuket', 144: 'Tomsk', 1965294: 'Tbilisi', 197: 'Vsevolozhsk', 615: 'Porvoo (Borgå)', 242: 'Petergof', 97: 'Novokuznetsk', 62: 'Kaluga', 348: 'Lomonosov', 2634: 'Charlottesville', 269: 'Amherst', 1515864: 'Boston', 1906517: 'Grenoble', 1707102: 'Singapore', 21613: 'Zheleznodorozhny (balashikha)', 420: 'Bergen', 60: 'Kazan', 627: 'Simferopol', 75: 'Kursk', 133: 'Sochi', 45: 'Glazov', 1582: 'Proletarsk', 80: 'Lyubertsy', 42: 'Voronezh', 95: 'Nizhny Novgorod', 121: 'Rybinsk', 123: 'Samara', 87: 'Murmansk', 134: 'Stavropol', 924: 'Ashkhabad', 26: 'Belgorod', 2487: 'Naryan-Mar', 351: '?', 5379: 'Mirgorod', 23: 'Astrakhan', 3193: 'Shymkent', 6360: 'Shakhtinsk', 1700270: '?', 581: 'Talnakh', 66: 'Kirov', 9531: 'Murygino', 2874: '?', 5093158: 'Mountain View', 140: 'Tambov', 1549: 'Tarusa', 1033103: 'Kaluga-2', 354: 'Anapa', 20680: 'Zvezdny Gorodok', 621: 'Dzerzhinsk', 173: 'Baikonur', 321: 'Neryungri', 198: 'Wien', 151: 'Ufa', 1035829: 'Primorsky', 17177: 'Silver Spring', 79: 'Luga', 3425: 'Azov', 1801744: 'Monaco', 1970519: 'Dresden', 1901266: 'Lausanne', 125: 'Saratov', 3878913: 'Sanya', 158: 'Chelyabinsk', 5098: 'Kopeysk', 384: 'Genichesk', 11: 'Severodvinsk', 240: 'Olenegorsk', 161: 'Chita', 1951155: 'The Valley', 1900938: "Sha'alvim", 124: 'Saransk', 4460: 'Konibodom', 14712: 'Kaifeng', 3783848: 'Yueqing', 6296: 'Sosnovo', 1859: 'Sukhodolye', 18173: 'Oktyabrsky', 155: 'Khimki', 1904965: 'Bridgetown', 355: 'Lagan', 1905655: 'Budapest', 10536: 'Gödöllő', 219: 'Frankfurt am Main', 280: 'Kharkiv', 1372: 'Bowling Green', 288: 'Krymsk', 1142: 'Zheleznogorsk', 1908817: 'Marburg', 365: 'Gus-Khrustalny', 4373337: 'Göttingen', 168: 'Yakutsk', 1048255: 'Sosnovy Bor', 22701: 'Olshanskoe', 2201: 'Kropivnitsky / Kirovograd', 22426: 'Belfast', 1713823: 'Las Vegas', 5006883: 'San Antonio', 1896: 'Phoenix', 273: 'Toronto', 10080: 'Santa Monica', 1955477: 'Milano', 178: 'Sertolovo', 373: 'Konakovo', 35: 'Veliky Novgorod', 282: 'Minsk', 1013425: 'Seltso', 104: 'Omsk', 183: 'Almaty', 1973733: 'Forlì', -2: -2, 20775: "Modi'in-Maccabim-Re'ut", 1793: 'Babson Park', 37: 'Vladivostok', 2205240: 'Jiddah', 7739: 'Amvrosievka', 703: 'Zürich', 385: 'Severouralsk', 1661: 'Washington, D.C.', 369: '?', 7529: 'Bolshaya Izhora', 846: 'Kem', 1003234: 'Solovetsky', 1449: 'Budennovsk', 528: 'Sumy', 20995: 'Wrexham', 185: 'Sevastopol', 1960291: 'Vancouver', 3436: 'Exeter', 400: 'Loughborough', 782: 'Krasnoe Selo', 49: 'Yekaterinburg', 1711047: 'Seattle', 1933924: 'Praha', 640: 'Staraya Russa', 109: 'Penza', 12945: 'Chernyakhovsk', 106: 'Orenburg', 115: 'Puschino', 78: 'Lipetsk', 53: 'Zhukovsky', 11981: 'Salzburg', 431: 'Sarov', 18779: 'Usman', 32: 'Bratsk', 110: 'Perm', 1133: 'Berdsk', 64: 'Kemerovo', 857: 'Dolgoprudny', 149: 'Ulyanovsk', 972: 'Samarkand', 93: 'Nizhnevartovsk', 432: 'Namangan', 1033782: 'Radischevo', 1516823: '?', 3485546: 'Sri Jayawardenapura Kotte', 4695954: 'Chaguanas', 3438: 'Maastricht', 145: 'Troitsk', 427: 'Kherson', 1519: 'Gatchina', 1915930: 'Newtown Square', 2999: 'Kotelnich', 13886: 'Uni', 437: 'Delhi', 1518: 'Sanatory Sosnovy Bor', 591: 'Fryazino', 1518651: 'Pavia', 1054308: 'Domodedovo', 2883: 'Gävle', 114: 'Pskov', 6923: 'Vyksa', 21855: 'Michurinsk', 48: 'Dubna', 392: 'Gomel', 1903333: 'Tromsø', 103: 'Obninsk', 88: 'Naberezhnye Chelny', 8162: 'Lobnya', 2001748: 'Reggio Emilia', 138: 'Syktyvkar', 188: 'Sestroretsk', 1704131: 'Cedar Falls', 1904869: 'Helsinki', 3700: 'Volgodonsk', 266: 'Kotlas', 20950: 'Novy Urengoy', 21713: 'Usinsk', 695: 'Kholmsk', 20558: 'Dzerzhinsky', 1951986: 'München', 2201761: 'Ljubljana', 1908252: 'Tampere', 22: 'Arkhangelsk', 1585: 'Primorsk', 11399: 'Artashat', 268: 'Nikel', 1516250: 'Skellefteå', 21856: 'Troitsk', 3462: 'Afipsky', 112: 'Petrozavodsk', 98: 'Novorossiysk', 105: 'Oryol', 1970123: 'Lappeenranta', 122: 'Ryazan', 3521: 'Makeevka', 5543: 'Kola', 1904029: 'Limassol', 487: 'Koltushi', 1016609: 'Yanino', 172: 'Severomorsk', 483: 'Krasnogorsk', 3218: '?', 274: 'Stary Oskol', 1901501: 'Barcelona', 14: 'Nur-Sultan/Astana', 284: 'Karaganda', 11334: 'Lesnoe (p/o Sputnik)', 4433: 'Vilyuchinsk', 3050162: 'Mosul', 3049557: 'Baghdad', 130: 'Smolensk', 12014: 'Langepas', 248: 'Kirovsk', 1046160: 'Murino', 1463: 'Zelenograd', 24: 'Balashikha', 916: 'Kryvyi Rih', 5331: 'Los Angeles', 17288: 'Mukhino', 1712659: 'Ararat (gorod)', 530: 'Chernogolovka', 8590: 'Donetsk', 13279: 'Corvallis', 25: 'Barnaul', 2164: 'Soligorsk', 5259878: 'Greifswald', 2480: 'Göteborg', 538: 'Baranovichi', 270: 'Podolsk', 1908479: 'Antananarivo', 1914789: 'Montréal', 20436: 'Poznań', 81: 'Magadan', 699: 'Sydney', 21050: 'Dublin', 1901824: 'Kiel', 40: 'Volzhsky', 529: '?', 2996: '?', 1517767: 'Aktobe', 1709666: 'Aizkraukle', 1297: 'Schyolkovo', 543: 'Priozersk', 1812: 'Novokubansk', 1581: 'Poltava', 5267861: 'Konstanz', 1042435: 'Sosnovy Bor (poselok)', 146: 'Tula', 71: 'Kostroma', 1928920: 'Doha', 51: 'Elets', 21118: 'Düsseldorf', 1916066: 'Bologna', 3592: 'Nancy', 6123: 'Stroitel', 12020: 'Bellevue', 39: 'Vladimir', 899: 'Berezniki', 21414: 'Daejeon', 5: 'Otradnoe', 1904856: 'Basel', 260: 'Zelenogorsk', 964: 'Novomoskovsk', 2539: 'Donskoy', 637: 'Vidyaevo', 292: 'Odessa', 801: 'Lytkarino', 438: 'Uzhgorod', 2722525: 'Speightstown', 18231: '?', 577: '?', 578: 'Khanlar (gyoygyol)', 585: 'Saint Helens', 584: 'Manchester', 1925340: 'Rīga', 7279: 'Petropavlovsk', 1517238: 'Changchun', 403: 'Noyabrsk', 1710959: 'Chişinău', 113: 'Petropavlovsk-Kamchatsky', 1062: 'Gadzhievo', 117: 'Ramenskoe', 1932468: 'Roma', 1852: 'Cambridge', 522: 'Shlisselburg', 281: 'Brest', 353: 'Borovichi', 2583: 'Jerusalem', 1517157: 'Shoval', 1932227: 'Vilnius', 5266737: 'Bühl', 1997: 'Kolpino', 1712003: 'Seoul', 5264173: 'Eberdingen', 8: 'Cherepovets', 1710581: 'Coon Rapids', 5228211: 'Sartrouville', 19280: 'Cergy-Pontoise', 5792: 'Pangody', 967: 'Roslavl', 1714908: 'Palo Alto', 1903546: 'Menlo Park', 601: 'Morozovsk', 1270: 'Ust-Nera', 1275: 'Petushki', 459: 'Reutov', 4245: 'Fort Madison', 643: 'Richmond', 56: 'Izhevsk', 136: 'Surgut', 1236: 'Sosnovy Bor (poselok)', 128: 'Siversky', 204: 'Bishkek', 191: 'Kingisepp', 784: 'Pervomaysk', 642: 'Gukovo', 1516495: 'Fremont', 2805: 'Oslo', 4691846: 'Guantánamo', 1517925: 'San Diego', 651: '?', 16972: 'Selyatino', 20281: 'Snezhnogorsk', 170: '?', 683: 'Khunzakh', 8741: 'Kirs', 5266910: 'Eichstätt', 5500: 'Beloozersky', 1068: 'Austin', 20863: 'Yevlakh', 20696: '?', 1942: 'Nikolskoe', 312: 'Mytischi', 762: 'Yerevan', 14486: 'Angren', 664: '?', 472: 'Kostomuksha', 326: 'Kandalaksha', 656: '?', 580: 'Elektrostal', 15402: 'Novosysoevka', 6156: 'Vozzhaevka', 1966426: 'Freiburg im Breisgau', 5264335: 'Heidelberg', 141: 'Tver', 476: 'Dimitrovgrad', 20404: 'Ivanteevka', 1964189: 'Hannover', 157: 'Cheboxary', 8542: 'Shenkursk', 1161166: 'Belushya Guba', 807: 'Murom', 203: '?', 38: 'Vladikavkaz', 17: 'Abakan', 17216: 'Venev', 455: 'Mariupol', 397: 'Stupino', 689: 'Suvorovskoe', 4011: 'Zapolyarny', 20641: 'Temirtau', 1913178: 'Sofia', 1909372: 'Imatra', 710: '?', 222: '?', 5267867: 'Ulm', 2482: 'Ust-Katav', 953: 'Bălţi ', 1802375: 'Miami', 4111: 'Berkeley', 153: 'Khabarovsk', 704: 'Bologoe', 3543: 'Tianjin', 2659: 'Kaduy (pgt)', 1074996: 'Moskva (derevnya)', 1535: 'Leeds', 1962177: 'Khartoum', 15: '?', 7462: 'Kommunarka', 1704031: '?', 739: '?', 428: 'Scherbinka', 8528: 'Novoanninsky', 1912584: 'Agia Napa', 649: 'Grodno', 213: 'Dudinka', 107: 'Orekhovo-Zuevo', 1246: 'Edinburgh', 57: 'Irkutsk', 135: 'Sterlitamak', 2622: 'Murfreesboro', 1515867: 'Gaithersburg', 725: 'Bryukhovetskaya', 91: 'Nakhodka', 5261832: 'Hagen', 3447: 'Bekabad', 283: 'Nadym', 7106: 'Dalnerechensk', 471: '?', 223: 'Donetsk', 1151: 'Tuapse', 374: 'Tiraspol', 9046: 'Dedovichi', 46: 'Gorno-Altaysk', 1906578: 'Guangzhou', 751: 'Pudost', 131: 'Snezhinsk', 398: 'Alexandrov', 910: 'Egoryevsk', 227: 'Tommot', 1344: 'Cherepanovo', 16015: 'Axu', 1379: 'Uppsala', 933: '?', 625: 'Dmitrov', 1056515: 'Eremino', 1056510: 'Gribki', 755: 'Dedenevo', 2974: 'Medvezhyegorsk', 340: 'Serpukhov', 210: 'Koryazhma', 8408: 'Palatka', 444: 'Chernihiv', 2914: 'Strelna', 4872: 'Cardiff', 21315: 'Mountain View', 22437: 'Kramatorsk', 1920097: 'Stanford', 361: 'Semey ', 205: 'Oskemen', 1925708: 'Olomouc', 2586: '?', 21657: 'Kostanay', 764: 'Slavutich', 29: 'Birsk', 706: 'Oral', 13: 'Borok', 4568: '?', 4726: 'Dunkerque', 338: 'Novodvinsk', 12928: 'Saint Andrews', 41: 'Vologda', 143: 'Tolyatti', 1517480: 'Palaiseau', 90: 'Nalchik', 34: 'Velikie Luki', 1078170: 'Mirny', 21122: 'Mirny', 1908876: 'Saclay', 2134: 'Montpellier', 316: '?', 4924430: 'Port Tampa', 4923818: 'Miami Springs', 1516454: 'Madrid', 152: 'Ukhta', 3252: 'Portland', 799: 'Evpatoria', 780: '?', 733: '?', 1003692: 'Markovskaya', 794: 'Zlatoust', 187: 'Monchegorsk', 859: 'Korolyov', 7979: 'Ariel', 59: 'Joshkar-Ola', 526: '?', 812: '?', 1026109: 'Kaladzhukh', 1704413: 'Pittsburgh', 21339: 'Brookline', 11701: 'Mikhaylov', 9: 'Buenos Aires', 832: 'Rijeka', 4275: 'Krasnogvardeysky', 2205585: 'A Coruña / La Coruña', 4725: 'Bordeaux', 721: 'Vlasikha', 722: 'Noginsk', 4890: 'Odintsovo', 1035628: 'Sokol', 376: 'Polyarnye Zori', 1058990: 'Puschino', 654: '?', 1916384: 'Nicosia', 1924736: 'Jena', 5267806: 'Darmstadt', 5265529: 'Nürnberg', 1359: 'Kremenki', 225: 'Klaipėda', 1058011: 'Bykovo', 1058010: 'Bykovo', 424: 'Rubtsovsk', 1704290: 'Cleveland', 8854: 'Nadvoitsy (pgt)', 1802374: 'Niagara Falls', 1068261: 'Lunino', 1097080: 'Joldyz', 19: 'Angarsk', 16049: 'Lavrentia', 4371: 'Ashtarak', 877: '?', 3302: 'Trondheim', 878: 'Posevnaya', 30: 'Blagoveschensk', 220: 'Tallinn', 15216: 'Bogoroditsk', 1971968: 'Limoges', 848: 'Shatura', 1129456: 'Mezhdurechensk', 882: 'Achinsk', 7406: 'Zaozersk', 885: 'Gorbunki', 501: 'Sarapul', 5369: 'Solnechnogorsk-7', 622: '?', 4490406: 'Sosnowiec', 2881: 'Będzin', 368: '?', 493: '?', 4258141: 'Lund', 449: 'Protvino', 873: '?', 1706220: 'Novoelnya', 1182: 'Axay', 4665253: 'Las Terrenas', 8555: '?', 1921147: 'Abano Terme', 4071: 'Tours', 1639: 'Metallostroy', 1705677: 'Sapporo', 2118: 'Bronnitsy', 3258101: 'Kiten', 2211377: 'Erfurt', 1446: 'Ozerny', 8534: 'Linköping', 9007: 'Angers', 317: 'Alexin', 1017: 'Chicago', 876: '?', 1969033: 'Lille', 1901538: 'Dubai', 1041416: 'Troitskaya', 1036: 'Ust-Ilimsk', 1058721: 'Sergiev Posad-6', 1950030: 'Beograd', 4548787: 'Castel di Casio', 148: 'Ulan-Ude', 12060: 'Kuzhener', 28: 'Birobidzhan', 1320: 'Aldan', 69: 'Kolomna', 1033: 'Istra', 7298: 'Londrina', 4642896: 'São Paulo', 1707488: 'Indianapolis', 868: 'Zelenogorsk', 942: '?', 70: 'Komsomolsk-Na-Amure', 1023852: 'Nikolskoe', 2722676: 'Corfu', 1906247: 'Nice', 1902812: 'Courchevel', 1714240: 'Valhalla', 1920563: 'Brno', 13974: 'Frederick', 1931617: 'Hanoi', 1515642: 'Bodø', 963: 'Kokoshkino', 1129878: 'Sheregesh', 345: 'Olekminsk', 2292: 'Yugorsk', 116: 'Pyatigorsk', 76: 'Kyzyl', 1930: 'Kansk', 2180: 'Koltsovo', 5267: 'Espoo', 1677: 'Millerovo', 980: 'Melbourne', 20306: 'Kubinka', 1002: 'Kushva', 1903827: 'Marseille', 6949: 'Lublin', 4298634: 'Gaming', 2189: 'Redmond', 319: 'Dallas', 1709744: 'Bothell', 1152096: 'Markovo', 1084301: 'Pavlovsk', 1903398: 'Suwon', 1009: '?', 1010: '?', 3804916: 'Gaozhou', 718: 'Maloyaroslavets', 1519350: 'Primorsko', 1949250: 'Osh', 12602: 'Bergamo', 19937: 'Nijmegen', 3828239: 'Gangneung', 1386: 'Sergiev Posad', 1060826: 'Pereluchi', 20860: 'Bremen', 1469: 'Engels', 4534764: 'Harstad', 7159: 'Miass', 2391: 'Novopavlovsk', 2393: 'Pullman', 7507: 'Naryshkino', 5327535: 'Teploklyuchenka', 16030: 'Kolovo (poselok)', 1562: 'Nauchny', 1050: 'Nemchinovka', 2093: 'Meleuz', 2895: 'Gulkevichi', 889: 'Elizovo', 1953016: 'Ankara', 21226: 'Almere', 2220: 'Utrecht', 1186: 'Tikhoretsk', 202: 'Pitkyaranta', 6600: 'Bishkul', 1777: 'Gusev', 7371: 'Ostrogozhsk', 3820: 'Zhigulevsk', 1305: 'Shakhunya', 5252: 'Shebekino', 1925548: 'Kuala Lumpur', 1947100: 'Turkmenbashy', 176: 'Svetlogorsk', 6198: 'Pionersky', 1901719: 'Firenze', 8068: 'Tovarkovo', 1121721: 'Verkh-Uymon', 16866: 'Ivot', 1769: 'Kimry', 11320: 'Nurlat', 1803337: 'Tartu', 1307: 'Boxitogorsk', 9930: 'Balakovo', 1056: 'Den Haag', 1713260: 'Luxembourg', 1906776: 'Mikkeli', 9048: 'Leuven', 18844: 'Schwerin', 5259828: 'Zittau', 1516: 'Kurchatov', 2446: 'Sovetskaya Gavan', 3054: 'College Park', 586: 'Zarechny', 1068349: 'Zarechny', 1096: 'Nizhneudinsk', 1426: 'Raduzhny', 1059191: 'Radumlya', 730: 'Taraz', 1063550: 'Soltsy 2', 1111: 'Safonovo 1', 1112: 'Ostrov', 1705371: 'Villigen', 1713669: 'Genève', 4430473: 'La Roche-sur-Foron', 8043: 'Sol-Iletsk', 21611: 'Dubna', 3659: 'Yasnogorsk', 9622: 'Revyakino', 20735: 'Marbella', 1055737: 'Opalikha', 154: 'Khanty-Mansiysk', 1917848: 'Courmayeur', 9027: 'Essentuxkaya', 1500567: 'Chernomorskoe', 1929244: 'Campinas', 1710582: 'Coral Gables', 1259: 'Znamensk', 8705: 'Zarechye', 1055710: 'Krasnoarmeysk', 617: 'Nevel', 1365: 'Chernomorsky', 6489: 'Severskaya', 10974: '?', 1920306: 'Taipei', 21941: 'Beijing', 2023: 'Tynda', 1783: 'Kaiserslautern', 12308: 'Tilburg', 1919614: 'Bilbao', 1137: 'Starodub', 2357: 'Jönköping', 4757: 'Pavlovsky Posad', 15686: 'Dalian', 1958117: 'Cairo', 20443: 'Mys Kamenny', 13623: 'Tevriz', 7075: 'Labytnangi', 4943: 'Nantes', 1518267: 'Redwood City', 1902815: 'Dublin', 12231: '?', 1972419: 'Santiago', 1936119: '?', 1122296: 'Rybnoe', 1134427: 'Verkhodvorye', 1629: '?', 1116677: 'Berezniki', 1711829: 'Dortmund', 1960757: 'Roskilde', 1941817: 'Nieuwegein', 1153: 'Gent', 4183: 'Stuttgart', 2210985: 'Stockholm', 7578: 'Fedotovo', 843: 'College Station', 1122574: 'Irkutsky', 1171: 'Okulovka', 500: '?', 1863: 'Dalnegorsk', 1174: 'Georgievsk', 68: 'Kovrov', 1127973: 'Markova', 1908412: 'Miami', 7201: 'Lukovetsky', 6594: 'Solnechnodolsk', 2162: 'Izluchinsk', 729: '?', 263: 'Leipzig', 1179: 'D/o Ershovo', 1709902: 'Brunswick', 15714: 'Uray', 1703182: 'Jyväskylä', 1058075: 'Ilinsky', 4645692: 'Porto Alegre', 67: 'Kislovodsk', 545: 'Zelenodolsk', 1901307: 'Magdeburg', 108: 'Orsk', 1057034: 'Chernogolovka (derevnya)', 728: 'Usolye-Sibirskoe', 3243: 'Krasnoturinsk', 1051: 'Bezhetsk', 421: 'Karakol', 1201: 'Glasgow', 2331: 'Partenit', 1515878: 'Petah Tikva', 5267866: 'Tübingen', 1708588: 'Panama', 1928465: 'Altea', 634: '?', 1057953: 'Pushkino', 8897: '?', 16729: 'Volgorechensk', 693: '?', 1100: 'Votkinsk', 5123: 'Sosnovo-Ozerskoe', 1057001: 'Obukhovo', 1712271: 'Pomona', 320: 'Lyon', 552: 'Luhansk', 1217: 'Lisichansk', 1160513: 'Kokuy', 1803194: 'Narva', 1969977: 'Sukhumi', 1950345: 'México', 8685: 'Nesterov', 2747: 'Labinsk', 264: 'Salavat', 1086: 'Kondopoga', 1829: 'Peschany', 5618: 'West Lafayette', 582: '?', 3880: 'Kineshma', 246: 'Kogalym', 1226: 'Kolpashevo', 1922703: 'Aarhus', 1484: '?', 1231: 'Nagorny', 94: 'Nizhnekamsk', 1803398: '?', 1494: 'Visaginas', 1934813: '?', 1032359: 'Ermolino', 1706561: 'Agate', 346: 'Kirovo-Chepetsk', 1915914: 'Pago Pago', 1004359: 'Axaraysky', 1908597: 'Abu Dhabi', 3268: 'Valkeakoski', 5387693: 'Tralee', 92: 'Nevinnomyssk', 1515935: 'Ouagadougou', 14754: 'Canton', 2194: 'Krasnoznamensk', 7666: 'Obolensk', 6612: 'Nikolaevsk', 3832919: 'Tenri', 1702: 'Toulouse', 1311: 'Klin', 14030: 'Glebovsky', 4905067: 'Papeete', 298: '?', 11689: 'Krasnaya Polyana', 6135: 'Alexandria', 1271: 'Kamenniki', 258: 'Yurga', 1803188: 'Kohtla-Järve ', 2216: 'Vesyegonsk', 653: '?', 1917549: 'Port-of-Spain', 17764: 'Sychevo', 9462: 'Schmalkalden', 243: 'Neftekamsk', 1451: 'Kristiansand', 10903: 'Milki', 7937: 'Braslav', 5211680: 'Tuchan', 761: 'Vinnytsia', 2812: 'Pontonny', 1069: 'Bilibino', 713: 'Rybnitsa', 7085: '\ufeffAlytus', 1361: 'Nikolo-Berezovka', 1901626: 'Portsmouth', 1710182: 'Rio de Janeiro', 1060526: 'Lyubino Pole', 1518316: 'Trento', 5330983: 'Zhavoronki', 18649: 'Tuchkovo', 3149: 'Yazhelbitsy', 527: 'Valday', 13274: 'Lesnoy', 1515634: 'Athens', 2615: 'Hrazdan', 1220: 'Belogorsk', 4236938: 'Hatfield', 20986: 'Eastbourne', 12723: 'Lancing', 21412: 'Ascot', 775: 'Edmonton', 499: 'Mainz', 790: 'Kanash', 1955: 'Alikovo', 2300611: 'Troyes', 1241: '?', 3798: 'Toxovo', 7950: 'Pelym', 1041698: 'Progress', 1047368: '?', 5062: 'Smorgon', 1060390: 'Shonguy', 1516930: 'Tahlequah', 15777: 'Nizino', 6512: 'Tekeli', 3428102: 'Ban Khao Lak', 3655108: 'Ho Chi Minh City', 1946698: 'Salamanca', 9702: 'Rudny', 671: '?', 1388: 'Ramat Gan', 20952: '?', 12126: 'Korkino', 2733: '?', 7785: 'Losino-Petrovsky', 1456: 'Leninogorsk', 27: 'Biysk', 4340048: 'Pütnitz', 1346: 'Budagovo', 628: 'Zaporizhia', 1517576: 'Sankt Gallen', 1713221: 'Rishikesh', 787: 'Desnogorsk', 4330013: 'Springen', 22427: 'Netanya', 1518546: 'Newark', 22007: 'Waterville', 593: 'Voskresensk', 479: 'Kuznetsk', 407: 'Béziers', 1911912: 'Zakynthos', 82: 'Magnitogorsk', 7036: 'Sagan-Nur', 2388: 'Santa Clara', 1008133: 'Pushkino', 1705918: 'Nouakchott', 14364: 'Gaza', 1074: '?', 650: 'Dnipropetrovsk (Dnipro)', 798: 'Rehovot', 880: 'Colchester', 1907: '?', 1938443: 'Santo Domingo', 5130465: 'Waterloo', 1796: '?', 1432: 'Loukhi', 5421165: 'Pattaya', 1084300: 'Olgino', 2208972: 'Hamilton', 1803516: 'Miami Beach', 1353: '?', 707: 'Kuybyshev', 2204899: 'İstanbul', 1483: 'Feodosia', 1488: 'Segezha', 475: 'Bakhchisaray', 1428: 'Stulnevo', 304: '?', 855: '?', 1427: 'Prostornoe', 2722648: 'Bogotá', 705: 'Kabul', 1679: 'Columbus', 495: 'Athens', 3396276: 'Chitungwiza', 2722634: 'Nairobi', 1959511: 'Liepāja', 1437: 'Skokie', 1612: 'Honolulu', 1208: '?', 1058: 'Kotovsk', 1056533: 'Marfino', 2763: 'Chongqing Municipality', 8566: 'Besançon', 3621: 'Mirny', 3234: 'Tacoma', 20468: 'Pocatello', 1287: '?', 2722591: 'Choluteca', 20799: '?', 1475: 'Calgary', 3020: 'Pensacola', 4142: 'Kirovsk', 542: 'Kamyshin', 1706331: 'Amman', 2722668: 'Tangier', 1460: 'Sindor (pgt)', 3229: 'Ust-Labinsk', 1242: '?', 17948: 'Mosrentgen', 1966694: 'Nha Trang', 3668057: 'Da Nang', 4113351: 'Kaya', 36: 'Vidnoe', 4955463: 'Knoxville', 1711780: 'Potsdam', 1903165: 'Trieste', 166: 'Elista', 1920043: 'Saint Petersburg', 165: 'Shuya', 22395: 'Livermore', 1006: 'Aktau', 1124699: 'Davsha', 4701: '?', 15766: 'Sokol', 1100374: 'Zavidovo', 4408746: 'Saint-Étienne', 1943933: 'Skopјe', 1982: 'Williamsburg', 1940504: 'Yorktown', 20541: 'Nakhabino', 1059839: 'Chekhov-4', 21830: 'Cherkasskoe', 3424765: 'Ko Samui', 3424764: 'Amphoe Ko Samui', 1963396: 'Nürtingen', 5266854: 'Reutlingen', 1507: 'Marsaskala', 1914553: 'Sliema', 21757: 'Greenbelt', 2956: 'Gold Coast', 8350: 'Adelaide', 150: 'Ussuriysk', 1516344: 'Jacksonville', 2616: 'Gainesville', 4951286: 'Baltimore', 823: 'Brisbane', 1701144: 'Novaya Bukhtarma', 1921079: 'Como', 3672: 'Torquay', 1032: 'Polotsk', 870: '?', 101: 'Novocherkassk', 833: 'Gagarin', 9196: 'Oktyabrsky', 1517414: 'Baden', 1941427: 'Fribourg', 3812: 'Paphos', 391: 'Kuzmolovsky', 4292: 'Kalininets', 1161172: 'Sofrino-1', 3925: '?', 11237: 'Nebolchi', 1017038: 'Ust-Alexeevo', 11229: "Ta' Kappara", 758: '?', 12096: 'Boulder', 4025: 'Shugozero', 2619: '?', 4611: 'Artemovsk', 993: 'Gusinoozersk', 329: '?', 492: '?', 680: 'Bugulma', 1903129: 'Perugia', 1949853: 'Žagarė', 13376: 'Zugalay', 325: '?', 521: 'Rzhev', 156: 'Chaykovsky', 1964269: 'Hong Kong', 5421199: 'Energetichesky', 1700709: 'Kokterek', 4922753: 'Florida Beach', 1538: '?', 1957236: 'Baku', 1797: 'Mineralnye Vody', 726: 'Belomorsk', 1956352: 'Caracas', 18521: 'Kalmar', 3338: 'Karviná', 328: 'Kamensk-Shakhtinsky', 1516208: 'Douala', 4155104: 'Koumra', 6984: 'Korsakov', 1906979: 'Suva', 1710361: '?', 2618: 'Raychikhinsk', 5073: 'Ruse', 4644: 'Zheleznogorsk', 2720: 'Bolshaya Kartel', 1706123: '?', 1336: 'Alakurtti', 1604: 'Kondrovo', 1937246: 'Dushanbe', 12577: 'Hildesheim', 2722508: 'Marmaris', 1927116: 'Sharm el-Sheikh', 1951699: 'Bad Homburg vor der Höhe', 1403: '?', 3691: '?', 1592: '?', 2451: 'Novocheboxarsk', 5099: 'Sovetsk', 10801: 'Nizhny Odes', 261: 'Sosnovoborsk', 2648: 'Tixi', 1130: '?', 415: '?', 1042240: 'Georgievskoe', 3439: 'Dobrinka', 1048949: 'Dobrinka', 8717: 'Khust', 1882: 'Antipayuta', 1948304: 'Mendoza', 1967003: 'Poti', 1159721: 'Sosnovka', 1945840: 'Larnaca', 22441: 'Bat Yam', 732: 'Bath', 1702171: 'Sevastopol', 1122798: 'Oryol', 1100945: 'Lesnoe', 1515684: 'Culver', 1666: 'La Massana', 1667: 'Schladming', 1668: '?', 1669: '?', 5151: 'Leicester', 2567: 'Chernigovka', 323: '?', 5254066: 'Belgravia', 4356: 'Vaasa', 525: 'Slantsy', 4280547: 'Zaanstad', 1693: 'Uyar', 1692: 'Krasnoobsk', 1980: 'Leningradskaya', 1908812: 'Yokohama', 85: 'Makhachkala', 715: 'Salekhard', 6111: 'Balakhna', 461: 'Novoshakhtinsk', 1951114: 'Newmarket', 655: 'Vyngapurovsky', 6193: 'Ridder', 293: 'Baltiysk', 1091: 'Trier', 20298: 'Sinyavino', 824: 'Veliky Ustyug', 3902: 'Dubăsari', 1530: 'Kommunar', 1746: 'Severobaykalsk', 19119: 'Gakhany', 5264303: 'Karlsruhe', 1704: 'Spas-Klepiki', 579: '?', 1709200: 'Aliso Viejo', 15575: 'Irvine', 1708078: 'Laguna Beach', 5096: 'Atlanta', 13048: 'Newbury', 1760: 'Khujand', 181: 'Plyussa', 5266239: 'Mechernich', 1738: '?', 1121281: 'Petrovskoe', 4196246: 'Rabat', 750: 'Bruxelles', 2767: 'Boca Raton', 1708303: 'Philadelphia', 1569: '?', -1: -1, 1704041: '?', 1850: 'Selenginsk', 1655: 'Novoe Devyatkino', 1956: 'Nikolaevsk-Na-Amure', 5261745: 'Aachen', 360: 'Ishimbay', 1467: 'Pevek', 1754: '?', 1944: '?', 2462: 'Saint Louis', 1159981: 'Tsingaly', 44: 'Gelendzhik', 8523: 'Clearwater', 4925083: 'Treasure Island', 3990: 'Jackson Lick', 3214265: 'Suolahti (Äänekoski)', 1054296: 'Vostryakovo', 1933226: '?', 14071: 'Klintsy', 1518210: 'Haguenau', 199: 'Volkhov', 562: 'Pyt-Yakh', 1907662: 'Vanadzor', 1959003: 'Red Bluff', 1910350: 'Perpignan', 6174: 'Varna', 821: '?', 7145: 'Murmashi', 1715417: '?', 1299: 'Navapolatsk', 4382870: 'Dessau-Roßlau', 1718: 'Farnham', 171: 'Derbent', 4510: 'Colombo', 3138584: 'Al Ain', 4536: 'Aprelevka', 1055910: 'Yakovlevo', 1923083: 'Padova', 1912973: 'Rennes', 852: '?', 2435: 'Arsenyev', 5744: 'Brevard', 874: 'Zhatay', 1086732: 'Zheleznodorozhny', 1597: 'Sovetsky', 1904771: 'Aix-en-Provence', 709: 'Klimovsk', 1601: 'Udachny', 941: 'Ozersk', 3052273: 'Al Khubar', 1124904: 'Dubna', 12825: 'Nyuxenitsa', 1682: '?', 1704931: 'Steinhausen', 100: 'Novouralsk', 1705847: 'Machala', 5266247: 'Gummersbach', 1709609: 'Ein Gedi', 1253: 'Trekhgorny', 12358: 'Drogobych', 12903: 'Brugge', 1082341: 'Izhevskoe', 19087: 'Nerastannoe', 2287: 'Zarafshan', 1212: '?', 533: 'Omaha', 17350: '?', 1952: '?', 1643: 'Yagodnoe', 4953513: 'Edgewater', 159: 'Cherkessk', 7391: 'Emetsk', 15839: 'Dolgorukovo', 3779: 'Psebay', 2829: 'Ust-Kut', 662: 'Limbyayakha', 2509: 'Denver', 1849: 'Ploskosh', 1041319: 'Krylovskaya', 377: 'Mykolaiv', 5028615: 'Buffalo Grove', 2568: 'Monino', 1519105: '?', 5689: 'Uzlovaya', 468: 'Prokopyevsk', 1515995: '?', 1515615: 'Rishon LeZion', 15769: 'Muravlenko', 11134: 'Beringovsky', 3491815: 'Bentota', 1711613: 'Denpasar', 1054299: 'Galchino', 12215: 'Ilinskoe', 1706044: 'Ashdod', 6963: 'Beersheba', 6799: 'Volosovo', 1161147: 'Iultin', 12827: 'Egvekinot', 6790: 'Sinegorye', 1086606: 'Serteya', 1106: '?', 1519017: 'Millburn', 1288: 'Kimovsk', 1289: '?', 1938720: 'Busan', 1571: 'Berezovka', 182: 'Tobolsk', 5054898: 'Flemington', 1708379: 'Macerata', 5034024: 'Cambridge', 1489: 'Novokuybyshevsk', 944: '?', 2202: 'Oktyabrskoe', 7497: 'Pavlovskaya Sloboda', 2390: '?', 1902227: 'Strasbourg', 10159: 'Oulu', 411: 'Pechenga', 1175: 'Urgench', 9801: 'Kortkeros', 1159266: 'Zavety Ilicha', 2734: 'Uzunovo', 1113: 'Lida', 1516528: 'Kfar Saba', 13718: 'Novokharitonovo', 1704094: '?', 788: 'Eysk', 1022922: 'Sazonovo', 11260: 'Khotkovo', 3138589: 'Ajman', 214: '?', 160: 'Grozny', 1504169: 'Vinogradov', 12673: 'Ilmenau', 652: 'Pereslavl-Zalessky', 21612: 'Sovetsky', 1295: 'Gdov', 1968700: 'Palermo', 2046: 'Zhigansk', 1938: '?', 21636: 'Vannes', 352: 'Solnechnogorsk', 609: 'Mtsensk', 5261785: 'Münster', 785: 'Uryupinsk', 17818: 'Dipkun', 4891: '?', 19977: 'Polevskoy', 3868: 'Khanymey', 3508: 'Belgorod-Dnestrovsky', 1977: 'Shovgenovsky', 1979: 'Enem', 3441: 'Chernomorsk / Ilichevsk', 3711405: '?', 3695374: 'Ubud', 2365: 'Onega', 1700905: 'Belbulak', 1800: '?', 1056907: 'Yakovlevskoe', 1927491: 'Khiva', 3196405: 'Aden', 1518436: 'Istarawshan', 2181: 'Chudovo', 1115: 'Abinsk', 3311955: 'Alta', 1922004: 'Hyderabad', 1036481: 'Peschanoe', 1058214: 'Chulkovo', 1708948: 'Slobodzeya', 1917: '?', 4225: 'Klagenfurt', 1586: 'Bugry', 21216: 'Stamford', 1953391: 'Jūrmala', 5259913: 'Bernburg (Saale)', 1516781: 'Sunnyvale', 1972637: 'Islamabad', 5375783: 'San Sebastián - Donostia', 1930737: 'Clermont-Ferrand', 1492: 'Pokrov', 364: 'Pikalevo', 742: '?', 618: '?', 2662: 'Novopodrezkovo', 4589: 'Kamloops', 7098: 'Sapernoe', 8307: 'Saint Charles', 4542806: 'Pescara', 2047: 'Askiz', 4390859: 'Baden', 4368415: 'Heidelberg', 1988: 'Milton Keynes', 21428: 'Qingdao', 7842: 'Dijon', 1630: 'Duldurga', 1518663: 'Makhtumkuli', 3330830: 'Zomba', 1714646: 'Bern', 2066: 'Kropotkin', 1922897: 'Warszawa', 610: 'Pinsk', 2040: 'Chapaevsk', 4547350: 'Crema', 1705820: 'Subotica', 3794003: 'Qinhuangdao', 2071: 'Słupsk', 1316: 'Dankov', 2205236: 'Talamona', 1934354: 'El Segundo', 1703407: 'Fountain Valley', 1040389: 'Odintsovo', 1114191: 'Koltsovka', 1046: 'Strezhevoy', 2091: 'Kirsanov', 669: 'Zheleznovodsk', 1018448: 'Fedotovo (poselok)', 1916936: 'Mohammedia', 1157108: 'Kaa-Khem', 3731: 'Shagonar', 12755: 'Zolotoe', 3513974: 'Allahabad', 10938: 'Khorol', 4148: 'Rostov', 2107: 'Snegiri', 536: 'Pavlodar', 1998: 'Nyagan', 5261721: 'Duisburg', 6485: 'Taldom', 2110: 'Lermontov', 1962: 'Krasnokamensk', 6083: '?', 2117: 'Krasnokamsk', 17896: 'Chersky', 5422738: 'Tainan', 3726888: 'Kaohsiung', 2123: 'Krasnoselkup', 1485: '?', 1875: 'Khovu-Axy', 13868: 'Kursavka', 7195: 'Yuzhno-Kurilsk', 16542: 'Chunsky', 5237: 'Ytyk-Kyuel', 2837: 'Worcester', 11671: 'Lesnoy', 2983: '?', 11445: 'Galenki', 999999: '?', 14113: 'Ivnya', 1703289: 'Sendai', 10583: '?', 4944559: 'Raccoon', 20781: 'Québec', 2001: 'Pervouralsk', 9512: '?', 13877: 'Edison', 14421: 'Tavda', 2113: 'Mary', 5535: '?', 4924154: 'Orlando', 5851: 'Storrs', 960: '?', 1944333: 'La Paz', 856: '?', 872: 'Chekhov', 6936: 'Yubileyny', 1956219: 'Nantwich', 6018: 'Ingolstadt', 18204: 'Detchino', 18: 'Almetyevsk', 2783: 'Luanda', 6820: 'Roschino', 1046394: 'Pobeda', 2175: 'Volzhsky Utes', 2171: '?', 2172: '?', 2174: '?', 2176: 'Alexandria', 1925013: 'Río San Juan', 1712803: 'Tampa', 1961: 'Taldykorgan', 19888: 'Otrado-Kubanskoe', 523: 'Nottingham', 13361: 'Totma', 1707735: 'Differdange', 1969201: 'Esch-sur-Alzette', 1148652: 'Berezovka', 286: '?', 13697: 'Mochily', 6659: 'Ulyanovka', 1009964: 'Gubkin', 2200: '?', 1058915: 'Dankovskoe Lesn-Vo', 1081129: 'Oktyabrsky', 2443: 'Likino-Dulevo', 3393: 'Kirzhach', 503: 'Lodeynoe Pole', 906: 'Kokshetau', 6087: '?', 5586: 'Teykovo', 1917965: 'Port Moody', 21910: 'Fukuoka', 21: 'Armavir', 3518: 'Snezhnoe', 1515643: '?', 1961332: 'Hurghada', 3853: 'Catania', 1904544: '?', 18489: 'Pasadena', 4544392: 'Minturno', 598: 'Dedovsk', 1046937: 'Ust-Luga', 1046812: 'Koskolovo', 6443: 'Windsor', 6482: 'Urzhum', 4410: 'Kudymkar', 1937213: '?', 708: 'Novotroitsk', 331: '?', 7320: 'Nanjing', 1902915: 'Mannheim', 1931860: '?', 9620: 'Perth', 2248: '?', 14057: 'Vyshesteblievskaya', 1046182: 'Peri', 5041303: 'Lake Odessa', 5569: 'Oktyabrsky', 1479: 'Roslyakovo', 2263: 'Alzey', 1974051: 'Antalya', 589: 'Pechora', 7516: 'Polotnyany Zavod', 21653: 'Zheltye Vody', 4011716: 'Tripoli', 1015163: 'Pallasovka', 12163: 'Maloe Verevo', 7480: '?', 1578: '?', 2102: '?', 129: 'Slavyansk-Na-Kubani', 3012: 'Gryazi', 952: 'Syzran', 20496: '?', 1024328: 'Kamenka', 1057000: 'Noginsk-9', 1519055: 'Amiens', 1300: 'Staraya Kupavna', 5421571: 'Saitama', 1122276: 'Gonokhovo', 1902419: 'London', 1700107: 'Baumanskoe', 1901980: 'Antibes', 1904565: 'Hakodate', 1932: 'Tulsa', 4646: 'Louvain-la-Neuve', 1935483: 'Ambrolauri', 6696: 'Newcastle upon Tyne', 1791: '?', 2295: '?', 1568: 'Chernovtsy', 14310: 'Podporozhye', 1017238: 'Piter (derevnya)', 1079715: 'Izumrudny', 1135702: 'Izumrudny', 52: 'Essentuki', 234: 'Kuopio', 137: 'Skhodnya', 9227: 'Sholokhovsky', 1913559: 'Bucureşti', 1063: 'Durham', 984: 'Lod', 596: '?', 2359: 'Volkovysk', 1385: '?', 3910: 'Zvenigorod', 2389: 'Rovaniemi', 1515843: 'Darinskoe', 5030: 'Morozova', 7083: 'Cherkizovo', 5122050: 'Fagatogo', 15447: 'Tura', 5267808: 'Wiesbaden', 2351: 'Pravda', 3151: 'Roseau', 2877: 'Shelekhov', 20592: 'Zyabrovka', 1064364: 'Medved', 2366: 'Domozhirovo', 9929: 'Ust-Kamchatsk', 8742: 'Sudislavl (pgt)', 2611: 'Nazarovo', 2106: 'Ivano-Frankovsk', 4538: 'Kodinsk', 1064833: 'Les', 2857: 'Khotilovo', 2000911: 'Sumqayit', 2859: 'Manturovo', 6902: 'Berngardovka', 324: 'Zarinsk', 20308: '?', 1975239: 'Weimar', 3676878: 'Ko Phangan', 2378: '?', 2205: 'Novaya Ladoga', 430: '?', 2479: '?', 1430: 'Eindhoven', 1424: '?', 1046240: 'Yanino 1-E', 1560: 'Bristol', 2396: 'Krasnouralsk', 1092: 'Kovdor', 2934: '?', 1032328: 'Balabanovo-1', 1032327: 'Balabanovo', 1907832: 'Granada', 5265085: 'Gilching', 1713593: 'Long Beach', 3260180: 'Botevgrad', 307: 'Copenhagen', 1705768: '?', 2256: 'Gorlovka', 3529468: 'Yangon', 1967489: 'Addis Ababa', 2655: '?', 818: 'Yalta', 1500164: 'Abrikosovka', 2541: 'Abaza', 1086258: 'Galon', 2204640: 'Lisboa', 11999: 'Alingsås', 1831: '?', 2949: 'Würzburg', 811: '?', 519: '?', 3475852: 'Medan', 1723: 'Naro-Fominsk', 1037: 'Golitsyno', 2527: 'Kaskelen', 5057953: 'Dickinson', 1706676: 'Dickinson', 505: 'Borisoglebsk', 2445: '?', 5100417: 'Stateline', 512: 'Svetogorsk', 4643906: 'Santa Maria', 4628266: 'Fortaleza', 127: '?', 21478: 'New Haven', 1103: '?', 2549: 'Korobitsyno (korobitsinsky S/s)', 1917808: 'Habana', 412: '?', 5015101: 'Saint Louis', 1658: 'Shrewsbury', 2130: 'Vychegodsky', 2444: 'Prokhladny', 2469: 'Termalny', 1826: 'Novolisino (tosnenskoe G/p)', 2488: '?', 2404: 'Buzuluk', 1394: 'Apsheronsk', 1159589: 'Mayna', 847: '?', 1042040: 'Rassvet', 1707187: 'Kotka', 2506: 'Chaldovar (chaldybar)', 14436: 'Pavlovskaya', 4281281: 'Veldhoven', 1703958: '?', 3809762: 'Cangzhou', 3634: 'Kharabali', 192: 'Ulaanbaatar', 2582: '?', 2496: 'Druzhkovka', 1131722: 'Udalenki', 18171: 'Okha', 2131: 'Atyrau', 2515: 'Innsbruck', 2364: 'Guildford', 9789: 'Machulischi', 1938620: 'Brzeg', 5974: 'Lutsk', 828: 'Anadyr', 3800: 'Rakhya', 1046207: 'Sertolovo', 1904530: 'Stony Brook', 21549: '?', 1715378: 'Mumbai', 4791003: 'Maturín', 1135223: 'Rossiyka', 18703: 'Udomlya', 2940: 'Navoi', 1516428: 'Kapshagay', 16641: 'Magistralny', 19296: 'Zavolzhye', 2581: 'Kharovsk', 408: '?', 1678: 'Gubkinsky', 1161138: 'Koashva', 18962: 'Urmary', 1048573: 'Ushaki (selo)', 5215: 'Genova', 1137324: 'Dalmatovo', 3891: 'Sønderborg', 2882: 'El Paso', 1185: 'Khasavyurt', 1709488: 'Springfield', 1221: 'Polyany', 1519197: 'Stavanger', 7555: 'Voyskovitsy (derevnya)', 1136712: 'Eruda', 3653: 'Minusinsk', 2207284: 'Guidonia', 2432: '?', 5360: 'Erdenet', 1274: '?', 1931640: 'Olaine', 2948: '?', 2736: 'Keros', 11899: 'Svetly', 1046126: 'Koshkino', 1355: 'Verkhnyaya Pyshma', 1975452: 'Paderborn', 663: 'Izmail', 19301: 'Chalna', 2494: 'Slavyansk', 1083531: 'Koshki', 5088291: 'Miami', 1704691: 'Kingston', 2613: 'Dneprorudnoe', 9391: 'Orotukan', 5265638: 'Schweinfurt', 748: '?', 5327605: 'Szarvas', 8724: 'Or Yehuda', 478: 'Kerch', 2410: 'Nukus', 11621: 'Kalitino', 763: 'Beloyarsky', 1935934: 'Johannesburg', 18077: 'Torrance', 4671104: 'Veracruz', 7086: 'Rouen', 15736: 'Porechye', 13859: 'Oxford', 5265148: 'Passau', 3048: 'Vyazma', 15357: 'Udelnaya', 1106686: 'Dmitrievskoe', 4415: 'Savvatia', 1916627: 'Lillehammer', 11644: 'Vagay', 7386: 'Charlotte', 1614: '?', 5094472: 'San Jose', 1043: 'Sharya', 524: 'Beloretsk', 1515807: '?', 7838: 'Severoonezhsk', 16578: 'Redkino', 1158978: 'Vanino', 1781: 'Kulebaki', 2486: 'Temryuk', 1587: '?', 1529: 'Kamenka', 5256191: 'Kassel', 1937941: 'Las Palmas de Gran Canaria', 1908844: 'Wuhan', 19787: 'Mongokhto', 1905276: 'Davie', 1708920: 'Bujumbura', 1932533: 'Sevilla', 8062: '?', 3408: 'Blagodarny', 21280: 'Gdańsk', 18445: 'Galich', 2985: 'Osmino', 1112422: 'Kazanovka', 3214: '?', 1438: 'Montreux', 4425: 'Kireevsk', 5489: 'Ozyory', 12249: '?', 4237994: 'Forest Row', 15370: 'Fevralsk', 4123: 'Tarnogsky Gorodok', 2697: 'Esik', 279: '?', 20: 'Arzamas', 7380: 'Lukoyanov', 4658: 'Borzya', 1807: 'Bogodukhov', 1002513: 'Sibir (derevnya)', 20528: 'Romanovka', 888: 'Aberdeen', 5259455: 'Freiberg', 5259320: 'Liebenwalde', 3131821: 'Agios Nikolaos', 13072: 'Safonovo', 2709: 'Northampton', 1035195: 'Sevastopol (selo)', 15827: 'Taraklia', 1935283: 'Cheneyville', 9405: 'Sokol', 4486993: 'Wronki', 2752: 'Bulava', 4645: '?', 6924: 'Fokino', 1660: 'Dyurtyuli', 1704011: 'Salt Lake City', 981: 'Gorki', 4705537: 'Fronteras', 6569: 'Granitny', 1156: 'Chernogorsk', 3402: 'Gostilitsy', 4667: 'Orzhitsy', 1518764: '?', 1974403: 'Balakhany (sabunchi)', 4130: 'Livny', 2802: 'Dombarovsky', 1961590: 'Kokand', 9600: 'Bavleny (selo)', 12140: 'Eugene', 3522: 'Bukhara', 644: '?', 2745: 'Volsk', 164: 'Shakhty', 2755: 'Arkhangelskaya', 21459: 'Martuk', 10036: 'Elan', 1304: '?', 632: '?', 7766: 'Fairbanks', 2760: 'Buy', 1947: 'Norwich', 16793: 'Shirvan', 445: 'Agalatovo', 1919616: 'San Pedro Sula', 7161: 'Ningbo', 1046440: 'Sosnovy Bor (poselok)', 1084: 'Breda', 3066: 'Wismar', 5265308: 'Regensburg', 1901292: '?', 1901580: '?', 8682: 'Jinan', 1260: 'Coventry', 8271: 'Khvoynaya', 1042: 'Gubkino', 2675: '?', 1809: 'Leninsk-Kuznetsky', 179: '?', 1328: 'Quito', 10307: 'Dixon', 4894: 'Muzhi', 1413: 'Brampton', 2810: '?', 6305: 'Dorokhovo', 6346: 'Razvilka', 4423: '?', 5266645: 'Leinfelden-Echterdingen', 5266714: 'Weikersheim', 1673: 'Boise', 15095: 'Harlingen', 1947677: 'Kirkkonummi', 14510: 'Berkakit', 1315: 'Melitopol', 5655: 'Komsomolsky', 1955454: '?', 516: 'Neftekumsk', 2987: 'Chernyshevsky', 1573: 'Kamensk-Uralsky', 2852: 'Baxan', 1517516: '?', 5331275: 'Serkovo', 1710986: 'Huittinen', 2858: '?', 5404414: 'Paris', 7139: 'Polyarny', 2511: 'Tomilino', 1707024: 'Joensuu', 1801741: 'Port Moresby', 14121: 'Guzyatino (guzyatinsky S/o)', 448: '?', 1070: '?', 1496: 'Aznakaevo', 691: 'Essen', 2722644: 'Douglas', 1517639: 'Annapolis', 1084290: 'Molodezhnoe', 2163: 'Belorechensk', 1706508: 'Towson', 9233: 'Lesnoy', 2322: 'Timashevsk', 434: '?', 2916: 'Pershotravensk', 1641: '?', 1084283: 'Lakhta', 2722455: 'Gaziantep', 2203360: 'İzmir', 2070: 'Ustyuzhna', 8344: 'Borisovo-Sudskoe', 6255: 'Des Moines', 18999: 'Zaigraevo', 1370: 'Maslyanino', 1014521: 'Preobrazhenskaya', 4834: 'Kolchugino', 290: 'Kurchatov', 1503: 'Annandale-on-Hudson', 3656318: 'Sóc Trăng', 2238: 'Balabanovo', 5266808: 'Offenburg', 21120: 'Horsham', 1647: 'Chirchik', 4338: 'Silantyevka', 2969: '?', 1060: 'Sosnogorsk', 10503: '?', 3943291: 'Changsha', 1704793: 'Pleasanton', 3928: 'Antratsit', 2998: 'Zvezdny', 1263: 'Sayansk', 1049: '?', 4424: 'Pindushi', 2022: '?', 16068: 'Nikolaevka', 5349: 'Chaltyr', 5640: 'Inzhavino', 2686: 'Nartkala', 2990: 'Linevo', 6911: 'Zhirnovsk', 20561: 'Romashki', 928: 'Shatalovo', 5915: 'Kiselevsk', 1158: 'Zhitomir', 480: '?', 3000: '?', 1046129: 'Kudrovo', 3113862: '`Ali Sabieh', 3006: 'Solginsky', 3008: '?', 3002: '?', 1048685: 'Gryazi', 9163: 'Bangalore', 1107: 'Bobrujsk', 988: '?', 1312: 'Aleysk', 3063: 'Kobrin', 18239: 'Novovoronezh', 1758: '?', 1511: 'Ivangorod', 9715: 'Voyskorovo', 1774: 'Poselok Telmana', 1453: '?', 1124340: 'Novoilinsk', 1676: 'Troitsko-Pechorsk', 1389: 'Lyantor', 2886: 'Buynaxk', 2236: 'Berezovsky', 849: 'Mikhnevo', 3755: 'Mozdok', 2728: '?', 4230: '?', 744: 'Uglich', 1076678: 'Vyshgorodok', 9435: 'Pytalovo', 11451: '?', 14356: 'Pyryta', 3340030: 'Pretoria', 1969283: 'Liberec', 4471362: 'Týniště nad Orlicí', 1161155: 'Novomikhaylovsky', 1752: '?', 1974: 'Suoyarvi', 12603: 'Nikolsky', 1084285: 'Lisy Nos', 3429: 'Canterbury', 3160: 'Linz', 6098: 'Michurinskoe', 9961: 'Waterbury', 1972450: 'Groton', 10138: 'Gavar', 1963511: 'Qurghonteppa', 1960869: 'Annaba', 1956305: 'Braunschweig', 1036190: 'Impilakhti', 3064: 'Madison', 1906065: 'Málaga', 9609: 'Myaundzha', 1007397: 'Parizh', 1956288: 'Longyearbyen', 1119: '?', 5884: 'Pravdinsk', 2561: '?', 506: '?', 3088: '?', 1670: 'Kamennogorsk', 22338: 'Doorn', 1330: '?', 2453: '?', 18694: 'Altayskoe', 1706: 'Boyarka', 3106: '?', 1516081: '?', 1190: '?', 1232: 'Vyazniki', 3781905: 'Zhuzhou', 1155077: 'Novy Byt', 2025: '?', 629: '?', 3043: '?', 1901401: 'Kampala', 898: 'Pestovo', 3667: 'Omutninsk', 1887: 'Dzhizak', 1515827: '?', 1762: 'Demyansk', 2044: '?', 8496: 'Houston', 2740: 'Sangar', 311: 'Sharypovo', 1033015: 'Iznoski', 3170: 'Rovno', 22359: '?', 1022898: 'Megrino', 1953593: 'Hillerød', 3994442: '?', 375: 'Mazyr', 1713629: 'Daugavpils', 3045: 'Dronten', 3196: 'Shakhrinav', 3033: 'Erlangen', 5023: 'Pustoshka', 1711248: 'Ontario', 13053: 'Shimsk', 5718: 'Mulino', 1028792: 'Lukh', 8414: 'Hangzhou', 4189791: 'Alicante', 1557: '?', 14989: 'Barvenkovo', 89: 'Nazran', 3221: '?', 429: 'Tegucigalpa', 18161: 'Gorshechnoe ', 3450: 'Bezhanitsy', 1803196: 'Sillamäe', 1902562: 'Santa Cruz de Tenerife', 3197: '?', 4695: 'Zapadnaya Dvina', 7047: 'Gissar', 12666: '?', 1401: 'San Ġwann', 18091: 'Kozelsk', 14413: 'Grigoriopol', 2722461: 'Samsun', 276: 'Kremenchug', 1014: 'Kashira', 132: 'Solikamsk', 1909043: 'Ventspils', 7214: 'Ivye', 16351: 'Saygatina', 6952: '?', 4982: 'Marina Gorka', 1602726: 'Marino', 2299: 'Reading', 21360: 'Gorki Leninskie', 16019: 'Panevėžys', 4124398: 'Bafatá', 3820658: 'Sihanoukville', 825: 'Izobilny', 694: '?', 21091: '?', 6593: '?', 3792251: 'Shenzhen', 13518: 'Klimovo', 3322: '?', 509: '?', 1917048: 'Fergana', 1908943: 'České Budějovice', 854: 'Navashino', 1161098: 'Iskateley', 1063142: 'Pestovo', 3336: '?', 5265804: 'Augsburg', 3337: 'Spartanburg', 5264821: 'Icking', 1035: 'Shakhtersk', 1703136: '?', 1197: 'Belye Berega', 957: 'Maysky', 1061062: 'Pestovo', 1122997: 'Soloneshnoe', 2326: 'Yangier', 2406: 'Igra', 3434: 'Tulcea', 14876: 'Iskitim', 1038497: 'Karavaevo', 2685: '?', 1934: '?', 2465: 'Malaya Vishera', 5316: 'Giaginskaya', 4687098: 'Santa Clara', 3382: '?', 548: 'Kstovo', 4654851: 'Belo Horizonte', 3414: 'Lyubinsky', 5349510: 'Karlsruhe', 13314: 'Alpharetta', 2203323: 'Jersey City', 15043: 'Poykovsky', 1710719: 'Daytona Beach', 22031: 'Znamenka', 4234: 'Uzhur', 774: '?', 1091466: 'Divnoe', 5098549: 'Los Alamos', 1223: 'Bender', 936: 'Altay (zyryanovsk)', 990: '?', 1517659: '?', 9189: 'Kalix', 4222694: 'Rødding', 3337011: 'Fleurs Jaunes-les Hauts', 1057248: 'Stary Gorodok', 12937: 'Wolverhampton', 759: '?', 1057199: 'Odintsovsky', 1057051: 'Akulovo (dubki P/a)', 1057104: 'Zhukovka', 2195: '?', 2514: '?', 1376: 'Oshmyany', 1953587: '?', 3047: 'Brestsky', 1046208: 'Sertolovo-1', 2135: '?', 3787: 'Kotelniki', 5004785: 'Lemonville', 3443: 'Ardon', 665: 'Konotop', 1532: 'Waterloo', 3017: '?', 2267: 'Opochka', 2136: '?', 3456: 'Knyaze-Volkonskoe', 6055: 'Barvikha', 4660: 'Pervomayskoe', 6921: '?', 1057415: 'Demikhovo (demikhovsky S/o)', 7849: 'Mikhaylovka', 3016: '?', 4059: 'Ruza', 607: '?', 1079406: 'Orlovsky', 853: 'Poronaysk', 3821: 'Zavolzhsk', 2551: 'Yangiyul', 20325: 'Kuloy', 3155: 'Aginskoe', 6061: '?', 4975943: 'Sunnyvale', 1803409: 'Sunny Isles Beach', 3466: 'Bogorodskoe', 1206: 'Lisakovsk', 1161170: '?', 3468: 'Karlykhanovo', 1894: 'Solnechny', 12340: 'Mendeleevo', 16300: 'Yverdon-les-Bains', 4471: 'Artezian', 3370: '?', 7014: 'Konstantinovo', 1710302: 'Kaunas', 1265: 'Detroit', 1134324: 'Leninskoe', 1516052: 'Palma', 1944918: 'Ottawa', 2089: '?', 1081804: '?', 1950532: 'Mingachevir', 1084331: 'Shushary', 2917: 'Khmelnitsky', 5818: 'Yuryevets', 1802034: 'Šiauliai', 18234: 'Palekh', 3505: '?', 467: 'Mogilev', 2262: 'Svetlogorsk', 2799: '?', 1544: 'Cannes', 120: 'Ruzaevka', 3517: 'Radoshkovichi', 5479316: 'Vatutinki-1', 1706452: '?', 1374: 'Stolin', 1600527: '?', 433: 'Tarasovka', 1482: 'Velizh', 1516541: 'Hyvinkää', 9579: 'Riihimäki', 1915576: 'Versailles', 20482: 'Kunya', 1070988: 'Borok', 1066: 'Lakhdenpokhya', 3978: 'Tsimlyansk', 1708365: 'Sanremo', 3531: 'Petrovsk', 3442: '?', 1634: 'Akhtubinsk', 18475: 'Kamskie Polyany', 1233: 'Orsha', 1037342: 'Yuger', 5091: 'Kitchener', 2065: '?', 2738: 'Berdichev', 14143: 'Vaganovo', 7164: 'Vysoky', 6966: 'Safonovo', 8710: 'Katunino', 1902842: 'New Delhi', 5433: 'Ofakim', 592: 'Ann Arbor', 1083: 'Soligalich', 1123380: 'Aba', 2816: 'Roshal', 2208942: 'Mogadishu', 1803186: 'Jõhvi', 4475773: 'Ostrov', 2030: '?', 22231: 'Marganets', 16648: 'Uelen', 8473: 'Emurtla', 1576: 'Tokmok', 826: '?', 22299: 'Revda', 3830: 'Gloucester', 5266425: 'Kelsterbach', 4356727: 'Lämmerspiel', 2209478: 'Hanau', 1001761: 'Kharitonovo (selo)', 5883: 'Shipitsyno', 20821: 'Hengelo', 3835067: 'Okayama', 1517678: 'Örebro', 3596: 'Okhotsk', 6981: '?', 1000215: 'Kirov', 1905134: 'Georgetown', 7112: 'Hastings', 3600: 'Schelkovo-4', 4186: 'Flint', 7416: 'Novotitarovskaya', 3594: '?', 1439: 'D/o Schelkovo', 2535: '?', 12070: 'Taoyuan', 3788776: 'Weinan', 3622: 'Tokko', 1705862: 'Snov', 1153062: 'Sergeevka', 5644: 'Providenia', 7223: 'Raleigh', 4280: 'Shilovo', 2300809: 'Valletta', 3650: 'Pyatigorsky', 126: 'Seversk', 891: 'Sortavala', 2564: '?', 1306: 'Fairfax', 5265422: 'Bamberg', 1143859: 'Tula (derevnya)', 20176: 'Lyuban', 675: '?', 2227: 'Shexna (pgt)', 3657: 'Nashville', 1526: 'Lukhovitsy', 15711: 'Mulymya', 8340: 'Bokovskaya', 1915171: 'Guadalajara', 3651: 'Zhanatas', 3652: '?', 1122946: 'Smolenskoe', 2642: 'Cherkassy', 3642: '?', 16704: 'Ovsische', 10558: 'Druzhnaya Gorka', 991: 'Mozhaysk', 1966: 'Mozhga', 1045489: 'Sosnovy Bor (derevnya)', 1091204: 'Nizhnee Khoronevo', 13161: 'Krasnoarmeysk', 17626: 'Cascais', 1189: 'Schelkino', 1951460: 'Damascus', 5907: 'Zheleznodorozhny', 20299: 'Kamyshlov', 2664: 'Dubrovo', 2334: 'Belaya Tserkov', 3967: 'Razdolnoe', 881: 'Raduzhny', 2743: '?', 603: '?', 3714: 'Los Alamos', 2682: '?', 2681: 'Lagolovo', 1057159: 'Malye Vyazemy', 3335681: 'Teyateyaneng', 1057088: 'Gorki-2', 1079322: 'Kamenolomni', 1956369: 'Mandrem', 1916: 'Russko-Vysotskoe', 86: 'Michurinsk', 2132: 'Toropets', 9139: 'Rodnikovskaya', 330: 'Brighton', 3690: 'Maloe Lavovo', 1041326: 'Oktyabrskaya', 3696: 'Krasny Kut', 16536: 'Selivanikha', 1074088: 'Belkovo', 1518517: 'Conakry', 14374: 'Svetly', 7708: 'Ames', 163: 'Shadrinsk', 2092: 'Chernetskoe', 3548: 'Borovsk', 12269: 'Velsk', 5437: 'Bely Gorodok', 2067: '?', 1077955: 'Krasnokutskaya', 3726: '?', 600: 'Balashov', 13552: 'Kiselevka', 2630: 'Luchegorsk', 1079280: 'Oblivskaya', 1122728: 'Sibirsky', 3727: 'Kozmodemyansk', 32767: '?', 1715607: 'Lech', 13033: 'Zürs', 3129625: 'Kattavía', 2481: 'Uzin', 1092394: 'Izmaylovka', 7358: '?', 1192: 'Rtischevo', 1053958: 'Gorki-25', 7899: '?', 1064: 'Kamenskoe / Dneprodzerzhinsk', 3781: 'Olshanka', 741: 'Orhei', 502: 'Liski', 14859: 'Yartsevo', 2079: 'Volokolamsk', 18553: 'Bolshie Kolpany', 3793: 'Zhaskeshu', 6062: 'Pori', 1804: '?', 830: 'Buguruslan', 13770: 'Emba', 20803: 'Ruzaevka', 6727: 'Chamlyxkaya', 5046548: 'Minneapolis', 5327487: 'Arlanda', 1928287: 'Chennai', 1702368: 'Kuryk', 1902834: 'Vientiane', 3424814: 'Hua Hin', 2125: 'Peresvet', 10096: 'Pereyaslovskaya', 1125366: 'Gorokhovets', 17571: 'Borodino', 4043: '?', 1046870: '?', 5469985: 'Novoe Stupino', 358: '?', 12923: 'Sokol', 13293: 'Lebyazhye', 5256284: 'Wildau', 1633: '?', 1061122: 'Shilovo', 3699: 'Nikolsk', 5001474: 'Atlanta', 4034025: 'Pointe-Noire', 4132567: 'Port-Gentil', 13894: 'Solntsevo', 12031: 'Tyrnyauz', 7559: 'Fort Lauderdale', 291: 'Isfara', 1046562: 'Kobrinskoe', 1057660: 'Voronovo', 5266933: 'Deggendorf', 2412: 'Priyutovo', 10685: 'Shenyang', 1012407: 'Asovitsa', 1705582: 'Tarrytown', 3848: 'Kizema', 4: 'Herzliya', 1517236: 'Napoli', 5257194: 'Chemnitz', 17582: 'Manhattan', 3856: 'Fairfield', 3477265: 'Weligama', 1015214: 'Rudnya', 2722585: 'Mata-Utu', 1705055: 'Scranton', 1073: 'Urengoy', 4514: '?', 7863: 'Kurilsk', 3041: 'Vyazemsky', 1003: 'Zheleznogorsk-Ilimsky', 3745: 'Melbourne', 3869: '?', 1161149: 'Kraskovo', 5266827: 'Villingen-Schwenningen', 4556: 'Belyov', 1163: '?', 1504472: 'Vishkovo', 1559: 'Ternopol', 1939574: 'Malakhovka', 1902256: 'Lebanon', 1683: 'Igarka', 1951677: 'Sigulda', 3510: '?', 1017252: 'Rostovskaya', 1708868: 'Alma', 1907529: 'Sugar Land', 3298: '?', 2417: 'Lyudinovo', 1067969: 'Kamenka', 10416: 'Haarlem', 1518039: 'Ieper', 1516269: 'Faro', 4049: 'Chekhov-3', 19464: '?', 917: 'Lokomotivny', 537: 'Varash / Kuznetsovsk', 3900: '?', 2116: 'Pechory', 2323: 'Alekhovschina', 1950095: 'Fleet', 18642: 'Krasnogvardeyskoe', 18889: 'Tempe', 1516682: 'Scottsdale', 2774: '?', 5847: '?', 13306: 'Lvovsky', 1049981: 'Stanovoe', 1584: '?', 18055: '?', 2722454: 'Adana', 1518895: 'Panama City Beach', 7718: 'Luton', 7101: 'Mostovskoy', 14032: 'Taranovskoe', 1919163: '?', 2161: 'Beslan', 1704175: '?', 8171: 'Schekino', 2049: 'Pervomaysky', 1433: 'Krasnoperekopsk', 1382: 'Novosokolniki', 3945: 'Przhevalskoe', 18977: 'Mshinskaya', 318: '?', 20905: 'Sheffield', 1031428: 'Krasny Bor', 1566: 'Yashkul', 3949: 'Vnukovo (poselok)', 3255: 'Chebarkul', 7018: 'Kasansay', 1601997: 'Gornaya Ruta', 688: 'Soltsy', 2460: 'Aykhal', 1087014: 'Akatovo', 5399: 'Abdulino', 3164: '?', 4085: 'Homburg', 3170759: 'Dekemhāre', 1046237: 'Scheglovo', 3961: 'Berezino', 4663119: 'Punta Cana', 1937087: 'Bávaro', 11715: 'Konergino', 4450: 'Vysotsk', 7395: 'Tomari', 2849: 'Zelenogradsk', 1861: '?', 1167: 'Belebey', 3973: '?', 12175: 'Salym', 3757: 'Kharp', 1218: '?', 3975: 'Frolischi', 5422503: 'Gromovo (poselok)', 4158: 'Begunitsy', 1048066: 'Solnechnoe', 1926680: 'Teplice', 1517533: 'Kufstein', 3454: 'Severodonetsk', 13629: 'Novozybkov', 743: '?', 1121776: 'Ust-Sema', 309: '?', 17939: 'Zelenchuxkaya', 31: 'Bor (poselok)', 1041006: 'Nikolenskoe', 232: 'Sayanogorsk', 1709483: 'Billings', 9672: 'Malysheva', 1135: 'Asbest', 413: 'Borisov', 20588: 'Olenegorsk-8', 1953710: 'Mönchengladbach', 2722510: 'Kemer', 4888: 'York', 8681: 'Shikhany', 1922: '?', 3685482: 'Chon Buri', 1969: 'Kolkata', 6725: 'Belogorsk', 1104: 'Balkhash', 1536: 'Pokachi', 1730: 'Osipovichi', 1950387: 'Balvi', 10025: 'Kochubeevskoe', 2225: 'Bogorodsk', 1047875: 'Yaschera', 12864: 'Lipki', 5874: 'Lopukhinka', 5043100: '?', 1518145: 'Greenwich', 1839: 'Vytegra', 1545: 'Efremov', 1991: 'Artem', 1707232: 'Lahti', 2722567: 'Libreville', 15730: 'Priozersk', 3985679: 'Kokopo', 15904: 'Vistino', 8980: '?', 22176: 'Cheonan', 4656: 'Palkino', 7311: 'Umeå', 583: '?', 1144448: 'Orsk', 1160072: 'Sherlovaya Gora 1-Ya', 1921403: 'Chkalovsk', 5266812: 'Zell am Harmersbach', 7213: '?', 3452: 'Talgar', 1956338: 'Kizil Kilisa', 334: 'Torzhok', 1706731: 'Radviliškis', 9453: '?', 9033: 'Oberlin', 4432: 'Ashkelon', 1161080: 'Velikovisochnoe', 1710100: '?', 6596: 'Svetlovodsk', 12677: 'Sambor', 1268: 'Yuzhnouralsk', 5835: 'Rechitsa', 1371: 'Chkalovsk', 3808: '?', 10406: 'Karachev', 1749: 'Mescherino', 1704751: '?', 1515844: '?', 21133: '?', 4121: 'Novogrudok', 7489: 'Druzhny', 379: 'Holon', 4139: 'Znamya Oktyabrya', 3799: '?', 2398: '?', 1943080: 'Vaduz', 22054: 'Winterthur', 4110: 'Southampton', 1061937: 'Yartsevo', 1803307: 'Kuressaare (kuressaare)', 1632: '?', 20547: 'Starominskaya', 1912526: 'Sharjah', 1955484: 'Kobuleti', 3836: 'Mga', 4920: 'Avdeevka', 1014311: 'Krasny Yar', 3232: 'Kyakhta', 1903535: 'Luzern', 4372: '?', 13416: 'Blois', 4722: '?', 1704136: 'Dunedin', 14620: 'Lüneburg', 3871: 'Chegem', 2411: 'Bykhov', 6181: 'Moskovsky', 2536: 'Elmer', 1906450: 'Bangkok', 1402: '?', 1937081: 'Los Altos', 4210: 'Los Altos Hills', 2508: 'Syasstroy', 1450: 'Harbin', 6429: 'Slobodskoy', 3566: '?', 5261853: 'Birkenau', 5261723: 'Krefeld', 16678: 'Karpogory', 1923: 'Severo-Eniseysky', 19568: '?', 1928932: 'Eberswalde', 13360: 'Gryazovets', 3662: 'Ryazhsk', 3103: 'Ivolginsk', 1245: 'Kumertau', 4790: 'Shagan', 5840: '?', 5303: 'Groningen', 16493: 'Storozhevaya-2', 302: '?', 462: 'Satka', 1059843: 'Chekhov-8', 2039: 'Luleå', 1715: '?', 3520: '?', 6766: 'Zemetchino', 1057440: 'Ilinsky Pogost (ilinsky S/o)', 10132: "Giv'atayim", 1055658: 'Peski', 1870: 'Priluki', 43: '?', 1045333: 'Zaborye', 366: '?', 7382: '?', 20506: '?', 2211: 'Morshansk', 2722547: 'Valencia', 3219637: 'Kouvola', 2087: 'Dubrovka (serebryanskoe S/p)', 1920358: 'University Heights', 14867: 'Raevsky', 1704590: 'Rye', 1911657: 'Pueblo', 1152: '?', 554: '?', 1916078: '?', 1090022: 'Uryupino', 1160889: 'Ozerny', 1506971: 'Miusinsk', 934: '?', 1520: 'Mikun', 896: 'Scheglovo', 15200: 'Verkhnekazymsky', 1161168: 'Roslyakovo-1', 1517642: 'Kyzylorda', 1183: 'Tarko-Sale', 1018447: 'Fedotovo (derevnya)', 1711740: '?', 6982: '?', 5425: '?', 4202: '?', 1999: '?', 2980: 'Nytva', 1908458: 'Thessaloniki', 1994: '?', 1938600: 'Neuchâtel', 1519129: 'Olbia', 14899: '?', 9868: 'Gorodok', 1056720: 'Kryokshino', 18827: 'Kluczewo', 1976786: 'Venezia', 2702: 'Liverpool', 1329: 'Batagay', 4462: 'Zhikharevo', 1148: '?', 1975: '?', 1377: '?', 781: 'Chekhov-2', 11666: 'Chekhov-7', 2538: 'Kamenets-Podolsky', 2373: 'Lapua', 4047: 'Kara-Kol', 1686: 'Raevka', 1046315: 'Kamenka', 3101: 'Drezna', 1066820: 'Topki', 1112121: 'Kundyukovka', 217: '?', 4393265: 'Allstedt', 1703160: 'Scunthorpe', 1707939: 'Wissen', 3141: '?', 1516801: 'Louisville', 5215484: 'Saint-Lucien', 1003329: 'Kukuevo', 1939380: 'Huizhou', 1705654: '?', 4419: '?', 3060: 'Ipatovo', 1932501: 'Marijampolė', 21568: 'Swansea', 17227: '?', 7200: 'Elnya', 1705696: '?', 1915465: '?', 2385: 'Morgantown', 5259568: 'Wurzen', 1515840: '?', 1709: '?', 1517117: 'Toowoomba', 3534: '?', 1750: '?', 20434: 'Taytsy', 1145: 'Dobropolye', 4445: '?', 1079491: 'Bolshoe Remontnoe', 1078: '?', 17952: 'Stepanovsky', 1015809: 'Kolpino (derevnya)', 860: '?', 1415: 'Mezhgorye', 1148547: 'Yasny', 3905: '?', 3369: 'Stakhanov', 6432: '?', 16812: 'Gavrilov Posad', 1516771: 'Kristiansund', 5703: 'Bolshaya Sludka', 5704: 'Rassypnoe', 5259879: 'Rostock', 4296: 'Yasnaya', 5648: 'Alchevsk', 5259507: 'Riesa', 5259564: 'Grimma', 16515: 'Priladozhsky ', 18033: 'Otradny', 11589: 'Kulob', 1941483: 'Ganja', 13570: 'Pochaev', 619: 'Dzhankoy', 4476: 'Boguslav', 1711294: '?', 2607723: 'Salaspils', 4479: 'Zubova Polyana', 1961775: 'Gagra', 4486: 'Lesnaya', 1958666: 'Ukmergė', 453: '?', 15724: 'Avsyunino (dorokhovsky S/o)', 3143: '?', 1936136: 'Malé', 1084841: 'Dukhovnitskoe', 50: 'Elabuga', 5385212: 'Glion', 1457: 'Elektrogorsk', 1105: '?', 1149: '?', 460: 'Vyshny Volochek', 3810: 'Malmö', 425: '?', 2695: '?', 17671: 'Providence', 12065: 'Kurtamysh', 6379: 'Gvardeysk', 17791: 'Los Gatos', 13880: 'Ocean City', 9800: 'Boguchany', 3210: '?', 1128: '?', 3644: 'Nyandoma', 1002409: 'Volkovskaya', 4231633: 'Saint Ives', 1921307: 'Ninove', 12770: 'Krasnoe-Na-Volge', 5421291: 'Alanya', 1055873: 'Pushkino', 3958: 'Sennoy', 595: 'Chagoda (derevnya)', 1160946: 'Zapolyarny', 3965: 'Yaransk', 1517640: 'Simsbury', 1712375: 'Lübeck', 1471: 'Tiberias', 8601: 'Rueil-Malmaison', 1927301: 'Bethany Beach', 1414: '?', 2722543: 'Adamstown', 4199: 'Leoben', 1933504: '?', 3782: '?', 3897: '?', 4707: 'Ulukulevo', 1937385: 'Kuhmo', 1518035: 'Tursunzade', 1606: 'Stepanavan', 3935: '?', 3095: 'Tuloma', 2142: 'Nikolsk', 2203643: 'Halifax', 1006478: 'Ismaylovo', 4518: '?', 6116: 'Port-Katon', 766: '?', 3969: 'Vazh Ezhva', 1517635: 'Rehoboth Beach', 2306: '?', 1803: 'Vorsma', 4000: '?', 1927224: '?', 3687: 'Schuchin', 1908070: 'Bratislava', 9488: 'Reftinsky', 4652: 'Gorodok', 3959606: 'Maanĭt', 1112554: 'Pisklovo', 2562: '?', 20686: 'Alexeevka', 4967674: 'Moss Point', 18237: 'Kayerkan', 720: 'Chistye Bory', 4094: 'Inozemtsevo', 1248: '?', 6658: 'Novodugino', 4243898: 'Sachseln', 9314: 'Kasnya', 4021: 'Kuvshinovo', 4777: 'Anderson', 2090: '?', 4494: 'Shostka', 4689: '?', 4691: '?', 1138691: 'Piter (selo)', 5879: 'Mikhaylovka', 4131429: 'Cotonou', 16975: 'Vysokovsk', 1042265: 'Oktyabrsky', 1705506: 'Heerlen', 1091129: 'Kholm-Zhirkovsky', 4294: '?', 206: '?', 1908590: 'Mobile', 14652: 'Sunzha (ordzhonikidzevskaya)', 507: '?', 6045: '?', 5963: 'Zarnisor', 531: '?', 5036301: 'Wilbraham', 1048513: 'Krasny Bor', 8801: 'Växjö', 1911487: 'Aalborg', 3102: 'Kaspiysk', 4741: '?', 4215: '?', 5240: 'Amderma ', 5115: 'Neya', 12801: 'Maidstone', 7357: 'Virginia Beach', 1493: 'Nizhny Arkhyz', 1121712: 'Yabogan', 4766: 'Staraya Sinyava', 1285: 'Chulman', 7741: 'Lisino-Korpus', 1047417: 'Maloe Karlino', 3798930: 'Linyi', 6912: 'Selizharovo', 1095953: 'Syukeevo', 13648: 'Novy Port', 5688: 'Shklov', 2663: '?', 5457343: 'Mashuki', 4905898: 'Klebeang', 4812: 'Pervomayskoe', 10191: 'Valencia', 13715: 'Glebychevo', 3183: 'Nizhnie Oselki', 10260: 'Leskolovo', 8202: '?', 6154: 'Zhukovka', 8631: 'Reboly', 8659: 'Sychevka', 14241: 'Vasyurinskaya (stanitsa)', 5622: 'Sibirtsevo', 5385: 'Ithaca', 1915787: 'Oak Park', 5042028: 'Oak Park', 1918631: '?', 1124: '?', 1706965: '?', 4833: 'Seredka', 11855: 'Bely Ruchey', 1964: '?', 1946939: 'Bø i Telemark', 4842: 'Arman', 668: 'Serov', 17037: 'Chelno-Vershiny', 1932202: 'Jeonju', 1159346: 'Anastasyevka', 5259921: 'Naumburg (Saale)', 4393053: 'Altenburg', 4853: '?', 1096276: 'Zverosovkhoz', 2722587: 'La Ceiba', 4862: 'Obozersky', 3750110: 'Lapu-Lapu City', 3637: 'Kalyazin', 4404: 'Krasnogorodsk', 1070902: 'Pokrovskoe', 19116: 'Kortrijk', 1042248: 'Dederkoy', 1154084: 'Bambuchek', 1879: 'Khandyga', 735: 'Svetlograd', 3732: 'Vichuga', 1516981: '?', 1086604: 'Selezni', 367: 'Almalyk', 6823: 'Łódź', 11040: 'Yolyoten', 5311: '?', 6700: 'Vyritsa', 1709145: '?', 5219: 'Dinskaya', 4961: '?', 1161157: 'Oganer', 4892: 'Kalach', 4869: 'Liinakhamari', 1352: 'Kirpichnoe', 4443: 'Boradigakh', 4129: '?', 4897: '?', 1891: '?', 1055584: 'Vozrozhdenie', 1515655: 'Wrocław', 3222745: 'Hamina', 4917: 'Lubny', 1918276: 'Odense', 22051: 'Herning', 1429: 'Ostashkov', 1021194: 'Obrosovo', 1035465: 'Psyzh', 779: '?', 1310: 'Lyubimets', 1704075: '?', 1518137: 'Myrtle Beach', 2255: '?', 1124788: 'Toltoy', 1564: 'Cincinnati', 4972: '?', 1973954: 'Dilizhan', 9508: '?', 5077: 'Svirsk', 1012396: 'Chemerna', 6309: '?', 5939: 'Bloomington', 11144: 'Tulsky', 1157867: 'Kazanskoe', 18180: 'Slavgorod', 5266191: 'Kleve', 1711857: 'Mažeikiai', 9533: '?', 1148156: 'Svetly', 1256: '?', 630: '?', 4116: 'Smela', 3507836: 'Goa', 3251740: 'Bogács', 4991: 'Melenki', 1546: '?', 1714897: 'Lugano', 6897: 'Novolabinskaya', 5265014: 'Ismaning', 1908558: 'Kurejoki', 4999: '?', 5076: 'Katav-Ivanovsk', 5056270: 'West Orange', 4951075: 'Anchorage', 11195: 'Peregrebnoe', 4886: '?', 3677: '?', 3209: 'Valuyki', 1015008: 'Novonikolaevsky', 13181: 'Jalal-Abad', 5022: 'Kerki (atamurat)', 9878: 'Starye Dorogi', 2064: 'Slutsk', 5078: 'Akhtyrsky', 3656: '?', 9044: '?', 5330984: 'Lesnoy Gorodok', 1813: 'Uvarovo', 3823: 'Kyren', 5075: 'Nizhny Lomov', 332: 'Aniva', 950: 'Ozherelye', 21032: 'Batumi', 6867: 'Kusa', 3490: '?', 7949: 'Verkhny Ufaley', 1900440: 'Ayanot', 5254: '?', 3665929: 'Hòa Bình', 4563: '?', 11442: 'Uchaly', 7274: '?', 6491: '?', 5051: '?', 1972: '?', 1181: '?', 1516332: '?', 1942393: '?', 1076: '?', 4937629: 'Raccoon', 5750: '?', 5749: 'Pazardzhik', 1517300: 'Kiryat Ono', 1871: '?', 5060500: 'Moravia', 2208: 'Maxatikha', 1059693: '?', 9338: 'Markovsky', 1160942: 'Polyarny', 3626: 'Buckingham', 1959944: '?', 5294: 'Idritsa', 7642: 'Lazarevskoe', 2643: '?', 3863: 'Leysin', 5059: '?', 5107: 'Woodland Hills', 1519184: 'Huntington Beach', 1933202: 'Tehran', 1936035: '?', 1908548: '?', 11371: 'Ocean City', 20212: 'Rameshki', 1500478: 'Perevalnoe', 1130651: 'Chernorechensky', 3036: 'Delft', 5152464: 'Niederglatt', 1973675: 'Victoria', 5136: 'Leningradsky', 3220874: 'Karjaa (Karis)', 1704666: 'Castelfranco Veneto', 1700949: 'Balykshi', 1914287: 'Khorog', 1787: '?', 6188: '?', 1710102: '?', 6082: 'Osnabrück', 4190408: 'Scicli', 12134: '?', 4737: 'Hollywood', 1114: '?', 20901: 'Gap', 2405: 'Partizansk', 1700033: 'Turgenevka', 7506: 'Eilat', 4930115: 'North Atlanta', 12820: 'Gorchukha', 1152860: 'Lazo', 1704848: 'Concord', 5162: 'Bagdarin', 3404: 'Nizhnyaya Tavda', 3952: 'Aktash', 1516864: 'Panemunė', 7593: 'Verkhnyaya Toyma', 1333: '?', 15732: 'Krasnousolsky', 5196: 'Battice', 5228120: 'Guerville', 2217: 'Olonets', 13964: 'Toroshkovichi', 2157: 'Yarensk', 5207: 'Mokrous', 4505: '?', 1151468: 'Lyady', 5013: 'Davidson', 1948929: '?', 5222: 'Zolochev', 2014: '?', 5226: 'Pervomaysky', 1115064: 'Verkhnie Kunashi', 1059569: 'Kvashonki', 1803164: 'Maardu', 7917: 'Strugi Krasnye', 1138487: 'Ust-Khakchan', 15106: 'Novy Urgal', 3579: 'Zelenoborsky', 4705: 'Kuvandyk', 201: 'Alexandrovskoe', 1301: 'Zhukov', 496: 'Tashtagol', 4448: '?', 4490: '?', 3299818: 'Përmet', 1930825: '?', 1518640: 'Manchester', 1933821: 'Pembroke', 1504012: 'Koshelevka', 4299: 'Zakamensk', 1638: 'Novorzhev', 14422: 'Perevolotsky', 3728432: '?', 16422: 'Trnava', 5289: 'Loknya', 1039260: 'Solovetskoe', 16535: 'Khyrov', 3695: 'Balakirevo', 1703761: 'Gyokdepe', 572: '?', 1516974: '?', 869: '?', 15191: '?', 2375: 'Energodar', 2368: 'Khromtau', 5304: '?', 12776: '?', 6558: 'Arkhangelskoe', 7763: 'Novoalexandrovsk', 3681: 'Zelenokumsk', 1937727: 'Annecy', 9260: 'Glazhevo (poselok)', 1705006: 'Kasakh', 3453: 'Saran', 13197: 'Yaroslavsky', 18253: 'Kokhma', 5377: 'Georgievskoe', 15081: 'Gyda', 2722513: '?', 5341: '?', 6335: 'Abramovka (abramovsky S/o)', 2824: '?', 5326: '?', 4067: '?', 8943: 'Slavsk', 16362: '?', 5027283: 'Runnells', 17534: 'Kamennomostsky', 4580: '?', 1615: 'Blagoevgrad', 13600: 'San Juan', 6240: 'Anchorage', 1927888: 'Poděbrady', 3165: '?', 18074: 'Yarmolintsy', 1054297: 'Aviatsionny', 3833410: 'Tachikawa', 4315: 'Karabulak', 5370: '?', 1973608: 'Tirana', 10610: '?', 1920792: '?', 1808: '?', 1953178: 'Rustavi', 10360: 'Caen', 1924339: 'Vitoria-Gasteiz', 4510400: 'Tuesta', 4522503: 'Espejo', 5418: 'Borodyanka', 1739: '?', 2269: 'Verevo', 7623: 'Borispol', 5630: '?', 6157: 'Trubchevsk', 84: 'Malakhovka', 10842: 'Radofinnikovo', 13529: 'Veschevo (poselok)', 2224: '?', 4537186: 'Ås', 1759: 'Kalach-Na-Donu', 3804: '?', 11166: 'Magnitka', 1904584: '?', 5266728: 'Schwäbisch Gmünd', 8139: 'Yanaul', 3004: 'Gorishnie Plavni / Komsomolsk', 1045876: 'Kirishi (derevnya)', 5431: '?', 7505: '?', 339: 'Monte-Carlo', 1517: 'Verkhoyansk', 1703: 'Pankovka', 5438: 'Chern', 1946257: 'Ormskirk', 441: '?', 5315: 'Kurganinsk', 1711157: 'Beirut', 2422: '?', 6905: '?', 1687: '?', 7677: '?', 4329: 'Lian', 10022: 'Panjakent', 3250: 'Nelidovo', 4221135: 'Tølløse', 1969675: 'Holbæk', 2722589: 'Tela', 6556: 'Minyar', 3858: 'Kasimov', 1079237: 'Sambek', 6871: 'Kirovsk', 2273: '?', 4686: 'Ungeny', 2209: 'Wichita', 10262: '?', 7354: 'Dunaevtsy', 1012525: 'Krasnaya Gora', 8098: 'Suntar', 1070498: 'Pozherevitsy', 3329766: 'Fomboni', 5571: 'Vasilkov', 1516356: 'Skidel', 2533: 'Bournemouth', 2228: 'Spassk-Dalny', 20488: 'Nizhnie Vyazovye', 1761: '?', 1976341: 'Trois-Rivières', 8564: 'Privodino', 5482: 'Rodinskoe', 6893: 'Bolgrad', 10752: 'Uspensky', 4791: 'Alagir', 1515703: 'Heilbad Heiligenstadt', 6875: 'Goryachy Klyuch', 11145: 'Bolotnoe', 5264208: 'Heilbronn', 4232081: 'Redhill', 4498: '?', 2048: '?', 1111134: 'Yar', 5528: 'Mikhaylovskoe', 3263: 'Zaraysk', 1089: '?', 1602: 'Bolshoy Kamen', 5544: 'Zhigalovo', 1158127: 'Verkhnie Aremzyany', 4161: 'Alatyr', 2796: '?', 13682: 'Khabary', 1041071: 'Dolzhanskaya', 5862: '?', 4797: 'Bogdanovich', 1162: '?', 1044028: 'Chernitsyno', 16703: '?', 1054663: 'Kupavna', 2210: '?', 5235: 'Dolmatovo', 1047106: 'Nikolskoe', 1601966: 'Lipnishki', 1012696: 'Aleshenka', 1058224: 'Yurovo', 1506038: 'Mironovka', 1082991: 'Osinki', 1048109: 'Vyskatka', 3125: 'Zherdevka', 8993: 'Shaykovka', 4597: 'Makarov', 9053: 'Lovozero', 1048: 'Leiden', 1508854: 'Balta', 3126498: 'Pýlos', 1908069: 'Geldrop', 5975: 'Zhabinka', 1707160: 'Ansan', 5587: '?', 3873: '?', 2935: '?', 15689: 'Zarya', 8384: 'Cahul', 2566: 'Toretsk / Dzerzhinsk', 1161: '?', 1600934: 'Lisuny', 1600943: 'Yurtsevo', 4552014: 'Shkodër', 2293: '?', 1505: '?', 1706369: '?', 1517419: 'Somerdale', 4594: '?', 3055: '?', 1054276: 'Agrogorod Zarya Podmoskovya ', 1745: '?', 4681: '?', 1099: 'Amherst', 5613: '?', 3999: '?', 4930782: 'Pooler', 1396: 'Belokurikha', 16336: 'Vishkil', 16214: 'Novogorny', 4940: '?', 1010571: 'Krasnoe', 20231: 'Sudogda', 5197: '?', 5646: 'Platnirovskaya', 1908914: 'Destin', 18898: 'Milkovo', 5651: 'Arnhem', 1705483: 'Sacramento', 18066: 'Korotchaevo', 510: '?', 18040: 'Bolshaya Atnya', 22491: "Ra'anana", 16907: 'Kurchanskaya', 1039187: 'Vlasikha', 10239: 'Naystenyarvi', 1927518: 'Toyama', 4331: 'Saki', 2544: 'Sobinka', 1942022: 'Bolzano', 7191: 'Energetik', 2001650: 'Balkanabad', 4968: '?', 1714581: 'Wellington', 5691: 'Kielce', 1200: '?', 2316: 'Krasnozavodsk', 1003144: 'Odinochka', 1046232: 'Chernaya Rechka (sertolovo)', 5685: '?', 14791: 'Turukhansk', 4463: '?', 5722: 'Novograd-Volynsky', 5712: '?', 5713: 'Pugachev', 16399: 'Lunino', 1116: '?', 5711: '?', 3684898: 'Nonthaburi', 8281: 'Marx', 1929305: 'Keansburg', 18872: 'Salair', 1704225: 'Grand Rapids', 5266838: 'Kandern', 1133845: 'Pedyaga', 1912209: 'Stresa', 4184727: 'Rociana', 1596: '?', 1704932: 'Barentsburg', 1909272: 'Fort-de-France', 2203658: 'Gibraltar', 1909703: 'Malvern', 1713557: 'Exton', 1704287: 'Downingtown', 5094425: 'San Bernardino', 1009610: 'Borisovka', 5752: '?', 18528: 'Karshi', 1517551: 'Cary', 4515: '?', 18759: 'Tsiolkovsky (uglegorsk)', 7292: '?', 8789: '?', 5767: 'Neverkino', 12067: '?', 5547: 'Nizhnyaya Tura', 1057087: 'Gorki-10', 4044: 'Krasny Sulin', 1910243: 'Nags Head', 5921: '?', 5266729: 'Aalen', 18840: 'Glyadyanskoe', 1918022: 'Novi Sad', 10753: '?', 9519: 'Zverevo', 1434: 'Burmakino', 4690: 'Shvartsevsky', 1499: 'Fosforitny ', 2938: '?', 1085444: 'Oktyabrsky', 3022: 'Elektrougli', 5794: '?', 5261818: 'Verl', 5266333: 'Blomberg', 1156268: 'Turinsk', 5633: 'Svetly', 6441: 'Kara-Suu', 5141: 'Vikhorevka', 12254: 'Novosinkovo', 10806: 'Evanston', 894: '?', 6231: 'Liozno', 1909853: 'Kos', 948: '?', 4230994: 'Sleaford', 1517706: 'Pirmasens', 5103: 'Chistopol', 1515620: '?', 5836: 'Sukhodol', 6784: '?', 8132: '?', 14856: 'Pleschenitsy', 13384: 'Pirogovsky', 13909: 'Gaysin', 5057688: 'Coram', 1703469: 'West Palm Beach', 5844: 'Camden', 7836: 'Letterkenny', 1238: 'Zhezkazgan', 5423388: '?', 1014618: 'Kotovo', 1153241: 'Slavyanka', 4677230: 'Palenque', 5800: '?', 1921996: 'Rēzekne', 8422: 'Abatskoe', 3796: '?', 3658: 'Kursk (poselok)', 760: 'Lebedyan', 10527: 'Fatezh', 5876: '?', 349: '?', 1057140: 'Kubinka', 5882: '?', 1934918: 'Toledo', 17997: 'St. Catharines', 901: '?', 5072: 'Zerkalny', 3256: '?', 5887: 'Bavly', 3123: 'Khatanga', 1517289: 'Saskatoon', 4575: 'Nanaimo', 1003103: 'Laysky Dok', 2856: 'Chishmy', 2657: 'Pervomaysky', 1971198: 'Managua', 1051221: 'Yubileyny', 1051967: 'Sovetsky', 21514: '?', 21244: 'Tuymazy', 2213: '?', 1010809: 'Monakovo', 1159726: 'Berezovo', 8838: 'Kievsky', 3804212: 'Guilin', 5918: '?', 1953191: 'Bagdad', 5470343: 'Schelkovo-3', 5299957: 'Depok', 3011: 'San José', 2722624: 'Praia', 4383393: 'Dannenberg (Elbe)', 5574: 'Kungur', 3913331: 'Bandung', 3694420: 'Yogyakarta', 3427: '?', 1423: 'Ludwigshafen am Rhein', 2638: '?', 3684796: 'Phra Nakhon Si Ayutthaya', 17693: 'Razmetelevo', 5533: '?', 5264223: 'Neckarwestheim', 7076: 'Zhodino', 1151345: 'Berezniki', 1903308: '?', 1515138: 'Korop', 2126: '?', 1923365: '?', 1512258: 'Dergachi', 14948: 'Talakan', 5090010: 'Cabazon', 1517203: 'Beverly Hills', 1868: 'Bolshoe Pavlovo', 2204322: 'Latacunga', 1920647: 'Williamsburg', 587: '?', 1273: '?', 717: '?', 5266505: 'Fulda', 1037817: 'Vorobyevitsa', 636: '?', 12148: 'Bezenchuk', 4633: '?', 6216: 'Kalinkovichi', 7205: 'Krems an der Donau', 1159032: 'Urgal', 5991: 'Padun', 5397: 'Porosozero', 1041: 'Pudozh', 1303: 'Krasnovishersk', 6771: 'Veliko Gradište', 5976: '?', 1158974: 'Pushkino', 5624: 'Stepnogorsk', 5981: '?', 5985: 'Sukhinichi', 5964: '?', 611: 'Vizinga', 299: '?', 5997: '?', 5994: 'Neman', 1225: '?', 9571: 'Koralovo', 5157: 'Nevelsk', 5999: 'Iglino', 1082806: 'Shatsk', 1082802: 'Chernaya Sloboda', 6100: 'Sadovoe', 1500323: 'Sadovoe', 21703: 'Kazreti', 3035: 'Achayvayam', 7367: 'Courbevoie', 5265424: 'Coburg', 2976: 'Waterford', 1711206: 'Eagan', 1517777: 'Simonichi', 2152: 'Eniseysk', 1710148: '?', 3908: '?', 6024: 'Chemnitz (Blankenhof)', 4257: 'Gai', 6039: 'Molochnoe', 1002932: 'Pocha', 1055616: 'Kolomna-1', 5265147: 'Landshut', 22351: 'Amberg (Oberpfalz)', 5266955: 'Sulzbach-Rosenberg', 5266949: 'Pfarrkirchen', 4312517: "Fontaine-l'Évêque", 1703515: 'Durham', 1159496: 'Ust-Kamyshta', 1056157: 'Tomilino', 15434: 'Kurlovo', 1901694: '?', 21166: 'Kant', 1519218: 'Stockton', 3212643: 'Virttaa', 1947981: 'Säkylä', 4351: 'Loimaa', 13275: 'Malenga (poselok)', 21348: 'Chimishlia', 1710953: 'Savannah', 12021: 'Vinsady', 6294: 'Agidel', 17057: 'Pavlovsk', 5235803: 'Beauchamp', 21601: 'Liège', 1975478: 'Marche-en-Famenne', 6577: '?', 1928334: 'Shaki', 8639: 'Bernau bei Berlin', 2553: 'Belozersk', 5063: '?', 3223132: '?', 18130: 'Shiroky Priluk', 5617: '?', 3156: 'Lesosibirsk', 1966031: 'Saldus', 4745: '?', 6006: 'Tbilisskaya', 1157760: 'Borovoe', 5342: 'Alga', 1603: '?', 1506: 'Zhlobin', 5266253: 'Bergisch Gladbach', 5266231: 'Brühl', 1161007: 'Nakhodka (poselok)', 5204: '?', 6928: 'Barda', 11552: 'Krasnaya Dolina', 18068: 'Kukushtan', 1148548: 'Komarovsky', 7664: 'Volochisk', 8007: '?', 2247: '?', 2319: 'Ekibastuz', 2102066: 'Charvak (bostanlyxky Rayon)', 17124: 'Staroscherbinovskaya', 1705250: 'Logan', 18724: 'Sofrino', 5176: 'Neteshin', 2145: 'Dolinsk', 4673: '?', 1722: 'Irbit', 6127: 'Garbolovo', 7673: 'Khiytola', 2350: '?', 22009: 'Gornozavodsk', 6597: 'Tambovka', 4266632: 'Eket', 2184: 'Kingston', 14683: 'Zapolyarny', 1681: 'Amursk', 21996: 'Vaughan', 22042: '?', 383: '?', 12840: 'Nazaryevo', 10634: 'Axakovo', 1936958: 'Manama', 6943: 'Zenkov', 4889: '?', 6165: 'Aktanysh', 5717: 'Butovo', 969: 'Rotterdam', 6317: '?', 5632: 'Verkhnedvinsk', 22371: 'Luzhesno', 13285: 'Smirnykh', 4321: '?', 1083212: 'Usinsky', 19699: 'Pułtusk', 7006: 'Sovetsk', 1363: '?', 13149: 'Bely Yar', 2147483647: '?', 6731: 'Rybnoe', 6258: '?', 1953059: 'Mladá Boleslav', 1902438: 'Lima', 5179494: 'Semarang', 4482: 'Krasnoslobodsk', 1015943: 'Toropovo', 1160478: 'Dosatuy', 1712222: '?', 3268191: 'Kırklareli', 3185: 'Surazh', 1012968: 'Stechna', 1057229: 'Savvinskaya Sloboda', 16547: 'Uspenskoe', 1041830: 'Nezamaevskaya', 5496: 'Pravdinsky', 11956: 'Razdolye', 3444: '?', 13928: 'Rugby', 3788: '?', 2240: '?', 1059010: 'Serpukhov-15', 7829: '?', 20523: 'Vokhma', 6273: 'Agvali', 3502786: 'Ludhiana', 1913588: 'Erkner', 6276: 'Dzerzhinsk', 1707666: 'Biella', 1160113: 'Gorny', 11117: 'Beloomut', 1906105: 'Cali', 1056290: 'Koloch', 6868: 'Tolmachevo', 13409: 'Fokino', 174: 'Bayreuth', 5461: 'Severo-Zadonsk', 5849: '?', 1032632: 'Klintsy (derevnya)', 4232983: '?', 17640: 'Esbjerg', 1928554: 'Passaic', 1041276: 'Trudobelikovsky', 1058052: 'Dubovaya Roscha', 5672: 'Shishkin Les', 6323: '?', 10246: 'Ryabovo', 9648: 'Putivl', 1710648: 'Turkmenabad', 2722595: 'Lusaka', 2722601: 'Livingstone', 3324340: 'Maamba', 7455: 'Minsky', 9250: 'Shakhtersk', 6970: 'Olenegorsk-2', 12228: 'Zelenogorsky ', 5021724: 'Williamsburg', 1936712: 'Newport News', 1011348: 'Vygonichi (pgt)', 2353: 'Lubbock', 5420846: '?', 9279: 'Poshekhonye', 6361: 'Hod HaSharon', 5306: 'Konosha', 5356: 'Szprotawa', 1452: '?', 5266197: 'Hilden', 5266400: 'Werl', 2968: 'Privetninskoe', 10528: 'Medyn', 1055642: 'Nepetsino', 4165: '?', 3860762: 'Osan', 451: '?', 1700914: 'Imeni Panfilova', 1141: '?', 1048278: 'Vyalgino', 4529: 'Rasskazovo', 10387: 'Chertkovo', 6373: '?', 2563: 'Kholm', 1153001: 'Rakushka', 4007: 'Rubezhnoe', 1697: 'Gyumri', 2876: 'Pokrovsk', 3826916: 'Mokpo', 1767: 'Sibay', 2253: '?', 1112352: 'Kropachyovo', 1509970: 'Orzhitsa', 1935729: 'Macclesfield', 6396: '?', 6284: '?', 1646: 'Novy Uchkhoz', 2342: '?', 802: '?', 1158245: 'Bogandinsky', 1015722: 'Babaevo', 4190738: 'Ribera', 1049849: 'Syrskoe', 4847: 'Kostino', 4902: 'Semikarakorsk', 15490: 'Dmitrovsk', 1161146: 'Ilovlya', 12659: 'Mys Shmidta', 1261: 'Mikhaylovsk', 20684: 'Worms', 5422710: 'Balaklava', 1623: '?', 6436: 'Mississauga', 21088: 'Upton', 5061506: 'Port Jefferson', 2937: '?', 3173: 'Zagreb', 3965474: 'Anshan', 3877: 'Rezh', 1055881: 'Rumyantsevo', 58: 'Ishim', 1461: 'Pasha', 1045989: 'Rybezhno', 5801: '?', 1083603: 'Krivoluchye-Ivanovka', 1083583: 'Androsovka', 1500052: 'Schastlivoe', 1054979: 'Lenino', 5048: 'Baymak', 6466: '?', 6475: 'Kosh-Khabl', 5312: 'Arlington', 4235: '?', 14173: 'Kizhinga', 1098843: 'Kuznetsovo', 4250: 'Kirovgrad', 1013490: 'Ilbovo', 1934400: 'Dobele', 5193: '?', 1511332: 'Druzhba', 251: 'Artemovsky', 5257: '?', 4620: '?', 1054369: 'Odintsovo', 4781: 'Ketovo', 6643: 'Faleshty', 1057929: 'Mamontovka', 6128: 'Alexandrovsk-Sakhalinsky', 1009559: 'Pushkarnoe', 1011097: 'Tomarovka', 21589: '?', 4639: 'Chadyr-Lunga', 6511: '?', 15006: 'Sverdlovsky', 11685: '?', 2218: '?', 1041731: 'Nezamaevsky', 1942213: 'Syrdarya', 228: '?', 6535: 'Sokolniki', 1907193: 'Cēsis', 5375: 'Freetown', 1030618: 'Kashkhatau', 1001748: 'Udimsky', 7463: 'Brentwood', 3704: 'East Lansing', 2078: '?', 1161078: 'Varandey', 5709: 'Kupyansk', 4260: 'Davis', 1950208: '?', 5530: '?', 1048752: 'Balovnevo', 5852: 'Gazoprovodsk', 21162: '?', 4069782: 'Malabo', 1903810: 'Palm Harbor', 1801712: 'Jelgava', 1059123: 'Krivtsovo', 1057684: 'Zheleznodorozhny', 253: 'Princeton', 6604: 'Podsosnovoe', 1504845: 'Novovasilyevka', 1967: '?', 1202: '?', 3260: 'Kartaly', 4498154: 'Legnica', 1905938: '?', 2246: '?', 1024683: 'Krasnoe', 3192649: 'Rhodes', 4662686: 'San Felipe de Puerto Plata', 6580: '?', 1156964: 'P/l Voskhod', 7619: 'Marcellus', 1919745: 'Varkaus', 1707271: 'Spokane', 1077: 'Andreapol', 14756: '?', 4243: '?', 6864: 'Shimanovsk', 20713: '?', 11278: '?', 1803355: 'Valga (valga)', 1911876: 'Wittstock/Dosse', 3085769: 'Dodoma', 1147196: 'Gai', 1129750: 'Promyshlennaya ', 1035498: 'Krasnogorskaya', 1919452: 'Kirov', 17449: '?', 958: 'Staronizhesteblievskaya', 5229: 'Nogliki', 5258127: 'Mahlwinkel', 5539: 'Mednogorsk', 1092096: 'Donskoe', 18026: 'Debaltsevo', 1421: '?', 3127: '?', 4531561: 'Rjukan', 2302: 'Usogorsk', 16233: 'Kiryat Motzkin', 1517559: 'Kiryat Bialik', 13307: 'Vyatskie Polyany', 12995: 'Smirnovo', 3508378: 'Gābharu', 13610: 'Lyubuchany', 22322: 'Bayramali', 6675: 'Zelenodolsk', 6398: 'Kirovskoe', 1950546: 'Dhahab', 5421012: 'Dahab', 1500014: 'Solnechnogorskoe', 4028: '?', 1106403: 'Opochnya', 3233: 'Solvychegodsk', 4590: 'Dobryanka', 19268: 'Nizhnyaya Omka', 12735: 'Norfolk', 5103990: 'Norfolk', 1925205: 'Budva', 6697: '?', 9528: 'Sebezh', 5329389: 'Tivat', 1153003: 'Timofeevka', 1518384: '?', 1707518: 'Windhoek', 4490733: 'Słubice', 1961156: 'Petaluma', 6708: 'Saint Donats', 1951581: 'Vantaa', 6710: '?', 1046330: 'Korobitsyno', 13927: 'Starobelsk', 2149: 'Molodechno', 9675: 'Zihron Yakov', 3962: 'Khrustalny / Krasny Luch', 1160086: 'Sherlovaya Gora', 2534: 'Taunton', 2936: '?', 1057190: 'Novoivanovskoe', 3676: 'Korsun-Shevchenkovsky', 1159456: '?', 1037117: 'Chim', 1945522: 'Bochum', 2448: 'Lgov', 926: '?', 994: 'Belovo', 9992: 'Kivertsy', 2502: '?', 4576: 'Belaya Glina', 6751: '?', 3099108: 'Kendale', 11722: 'Abay', 4241: 'Novokhopersk', 3931: '?', 2525: 'Sasovo', 9664: 'Kargopol', 8698: 'Kabardinka', 6814: '?', 1969145: 'Marneuli', 1700894: 'Kargaly', 4229: 'Grigoryevka', 6782: 'Bolokhovo', 6828: '?', 1138517: 'Verkhny At-Uryakh', 1025244: 'Arkhangelsk (khutor)', 6796: 'Makinsk', 1962432: '?', 300: 'Khurba', 1091604: 'Ptichye', 9894: 'Atkarsk', 4329541: 'Stein', 1517834: '?', 4185641: 'Maracena', 3437: 'Lensk', 5267195: 'Neuerburg', 5266018: 'Jülich', 1934339: 'Aarau', 6070: '?', 12318: 'Tovarkovsky', 1145935: 'Bobrinka', 1932824: '?', 4712: 'Bataysk', 5309009: 'Alimos', 6826: '?', 1708024: 'Lafayette', 16889: 'Oktyabrsky', 9268: 'Seltso', 3619: '?', 18884: 'Betlitsa', 3951: '?', 1055796: 'Volodarskogo', 1061377: 'Lychkovo', 2722511: 'Didim', 1915376: 'Montville', 6847: '?', 6848: 'Krasyukovskaya', 1056871: 'Taraskovo', 4567: '?', 7218: '?', 1904960: 'Escondido', 5185: 'Postavy', 4921798: 'Bal Harbour', 6855: '?', 1935056: 'Cold Spring Harbor', 4607: '?', 5806: 'Perevalsk', 6865: 'Kolymskoe', 4931051: 'Ringgold', 1391: 'Agrogorodok', 16091: 'Konstantinovsky', 1818: 'Lesozavodsk', 1154279: 'Artemovsky', 4844: 'Rogovskaya', 6872: '?', 1046561: 'Kobrino', 1046514: 'Vysokoklyuchevoy', 1055695: 'Cherkizovo', 1079478: 'Ryaska', 1078738: 'Komarov', 11940: 'Konstantinovsk', 2466: '?', 6920: '?', 1519215: 'Pogorodno', 18632: 'Voronovo', 1601872: 'Trokeli', 6935: 'Bastuny', 1057197: 'Odintsovo-1', 4182: 'Lotoshino', 1092057: 'Gorkaya Balka', 6886: 'Chernomorsky', 895: 'Buffalo', 6627: '?', 3329: '?', 1155306: 'Kalinovo', 1915477: 'George Town', 5232: 'Gruzino', 18300: 'Kizlyar', 20444: 'Kashin', 5634: 'Kilpyavr', 1032869: 'Kurilovo', 1906048: 'Gabala', 1903188: 'Annau', 1908481: 'Chambéry', 1924: 'Vagarshapat', 13085: 'Tsukuba', 2304: '?', 1038987: 'Alabukhino', 1519255: '?', 1713371: '?', 1712247: '?', 1972865: '?', 1516002: 'Phnom Penh', 8680: 'Puxoozero', 2574: 'Burshtyn', 3606: 'Menzelinsk', 1927155: 'Buttrio', 1147399: 'Podolsk', 5525: 'Naro-Fominsk-10', 5900: '?', 8360: '?', 6925: '?', 6293: 'Kilmez', 1516117: 'Highland Heights', 1515741: 'Borovoe', 13178: 'Chaadaevka', 6926: 'Belousovo', 9887: 'Chelmsford', 1517787: 'Rimini', 1952694: 'Bursa', 1522: '?', 1805: '?', 1061: 'Belaya Kalitva', 5799: 'Akhtyrka', 10359: '?', 1153351: 'Shkotovo', 2476: '?', 12045: 'Port-au-Prince', 19700: 'Sokal', 1514510: 'Chernobay', 5993: '?', 3248: 'Myski', 5194: 'Zimititsy', 1516998: 'Aurora', 1137924: 'Streltsy', 1913395: 'Rajshahi', 6939: '?', 1435: 'Bikin', 5211: 'Seredina-Buda', 2291: '?', 1127561: '?', 1000148: 'Khamyshki', 4218: 'Donskoe', 7073: 'Senno', 1057102: 'Ershovo', 1938356: 'Kyzyl-Kia', 1057938: 'Nagornoe', 6983: 'Kubrinsk', 1416: '?', 9397: 'Kongens Lyngby', 4906088: 'Saipan', 1205: '?', 6754: 'Akatovo', 5831: 'Iksha', 9824: 'Gastello', 5698: 'Korday', 1701484: 'Kogershin', 7272: 'Ozernovsky', 13169: 'Belanovichi', 11861: 'Tigil', 9371: '?', 3029: 'Terek', 1030833: 'Guryevsk', 2177: '?', 5300: 'Morioka', 4630: 'Zhengzhou', 5775: 'Vaskovo', 7021: '?', 4393: '?', 1091811: 'Edissia', 1077817: 'Rossiysky', 1159169: 'Pivan', 6171: 'Putyatino', 3081391: 'Mwanza', 3704626: 'Kuta', 3043610: 'Al Qadhādhimah', 322: 'Boguchar', 716: 'Unecha', 2706: '?', 719: 'Astafyevka', 1055074: 'Rozhdestveno', 9249: 'Petropavlovka', 5960: 'Sosnovka', 5779: 'Khatukay', 13872: 'Volodarsk', 1172: 'Novosmolinsky', 2716: 'Zima', 1506774: 'Vlasovka', 1057267: 'Uspenskoe', 7043: '?', 2708: 'Baykalsk', -10: -10, 6053: 'Orekhovo (stantsia)', 1748: '?', 1914355: 'Nuku`alofa', 1007247: 'Abdulino', 15896: '?', 12551: 'Dubrovka', 7026: '?', 4114424: "Fada N'Gourma", 3812655: 'Seria', 3203474: 'Ngozi', 3300640: 'Elbasan', 1884: '?', 4306: 'Novy Svet', 8773: '?', 20742: '?', 16897: 'Pervomaysky', 5165: 'Yar-Sale', 4553191: 'Durrës', 1397: 'Pavlograd', 7089: '?', 1890: 'Yakhroma', 21686: 'Ōsaka', 1343: 'Porkhov', 6894: 'Ust-Maya', 3933: '?', 2231: 'Vrangel', 7100: '?', 1714466: 'Put-in-Bay', 1974785: '?', 1517572: '?', 18397: 'Oktyabrsky', 15143: 'Nazareth', 2722607: 'Harare', 7048: '?', 5266016: 'Buchloe', 21571: 'Pamplona', 16118: 'Mamonovo', 22553: '?', 11455: 'Bayanday', 2454: 'Kizilyurt', 1056660: 'Gorchakovo', 1115459: 'Bolshoe Churashevo', 1051735: 'Kaleevo', 7137: '?', 20771: 'Scarborough', 7146: '?', 5261833: 'Hamm', 6366: '?', 1154288: 'Bulanash', 16330: 'Adelphi', 2367: 'Novoaltaysk', 5086751: 'Wisconsin Dells', 1284: 'Suzdal', 8123: 'Deputatsky', 1516167: '?', 12022: 'Golovino', 5210: 'Ponazyrevo (pgt)', 7705: '?', 1703745: 'Arlington', 2943: 'Vuktyl', 2305: 'Godalming', 1953817: 'Ely', 7184: 'Preobrazhenie', 4104901: 'Amassoma', 19843: 'Kozlovo', 1109: '?', 690: '?', 4272: '?', 7266: '?', 3514: 'Chengdu', 7212: '?', 6187: 'Lusakert', 5349127: 'Marbach am Neckar', 5266657: 'Ludwigsburg', 4372717: 'Griesheim', 5261726: 'Oberhausen', 1047439: '?', 1901793: 'Ozurgeti', 7222: 'Tukan', 9449: 'Tayga', 745: '?', 4810: 'Port Harcourt', 7229: 'Batetsky', 8954: 'Winnipeg', 1046178: 'Oselki', 1957581: 'Reggio di Calabria', 1922704: '?', 1059986: 'Pyshlitsy', 1046671: 'Semrino', 1086450: 'Koban', 1086370: 'Lesken', 5256148: 'Pforzheim', 4518285: 'Manresa', 9255: '?', 17259: 'Kara-Balta', 7238: 'Chapel Hill', 4122829: 'Gabú', 7197: '?', 1444: '?', 1057008: 'Pushkino', 4702: 'Kratovo', 1134194: 'Shurma', 7262: 'Dzhuma', 1803325: 'Kallaste', 6263: '?', 7230: '?', 1940738: 'Tskhinvali / Tskhinval', 7388: '?', 7496: 'Kuznetsovo', 3092: 'Izyum', 5266393: 'Siegen', 12419: 'Slavuta', 7276: '?', 7246: '?', 850: 'Slyudyanka', 19377: 'Sputnik', 20583: 'Slobozhanskoe / Komsomolskoe', 7301: '?', 5266669: 'Schorndorf', 1015651: 'Frolovo', 1602422: 'Chernikovschina', 3052246: 'Medina', 4552: '?', 7321: '?', 7318: '?', 1714650: 'Walnut Creek', 1056548: 'Pansionat Klyazminskoe Vodokhranilische', 22295: 'Svobodny', 838: 'Zeya', 466: '?', 2722: 'Svisloch', 1713848: 'Kill Devil Hills', 4972843: 'Kitty Hawk', 6136: 'Moorhead', 2358: 'Fargo', 4971190: 'Elizabeth City', 11605: '?', 1116006: 'Borisoglebsky', 13850: 'Kotelsky', 2939: 'Schigry', 4870: '?', 5962: 'Kanev', 9758: 'Gorodets', 63: 'Karachaevsk', 6382: '?', 5450: '?', 20535: '?', 2128: '?', 1121725: 'Zamulta', 1500472: 'Molodezhnoe', 1905198: 'Agra', 8502: 'Barabash', 6334: 'New Brunswick', 1901945: 'Ibiza Nueva', 6705: '?', 7384: 'Arden Hills', 7387: 'Rockville', 7383: 'Saint Louis Park', 1194: '?', 11194: 'Limerick', 5266732: 'Ettlingen', 1802482: 'Lagos', 4085581: 'Odogbolu', 7443: '?', 2265: '?', 1100503: 'Schelkovo', 7414: 'Zaborye', 11522: 'Komsomolsky', 6641: 'Nizhneyansk', 18879: 'Niigata', 1909511: 'Grevesmühlen', 1420: '?', 1715742: '?', 997: '?', 845: '?', 7389: '?', 7570: 'Fornosovo', 11835: '?', 1704279: 'Halle (Saale)', 7486: '?', 2631: '?', 1298: '?', 7293: '?', 6226: 'Novouzensk', 1936946: 'Kārsava', 7503: '?', 4832: 'Torez', 1113305: 'Roschino', 7508: '?', 1145977: 'Odesskoe', 1923058: 'Stadthagen', 702: '?', 1929447: 'Katowice', 5105: 'Accra', 7579: 'Dachnoe', 3807: 'Satpaev', 1153992: 'Vostok', 5266535: 'Volkmarsen', 4591: 'Porto', 1057375: 'Avsyunino (dorokhovsky S/o)', 7648: 'Tymovskoe', 7334: 'Zeleny', 1077716: 'Kuleshovka', 1945: 'Povarovka', 7655: '?', 7556: 'Novomoskovsk', 3824: 'Oboyan', 1127433: 'Leninsk', 6233: '?', 2340: '?', 1924834: "Saint John's", 1715142: 'Lautoka', 1516755: 'Viareggio', 17611: 'Agryz', 4608: 'Zaplyusye', 1128981: 'Podkamennaya', 7756: '?', 7233: '?', 4287954: 'Aalst', 2531: '?', 5923: 'Vulkaneshty', 5326982: 'Phi Phi Don Island', 13992: 'Uralsky', 7418: '?', 11696: 'Rauma', 3223097: 'Eurajoki', 1915267: 'Agadir', 1913974: 'Casablanca', 19561: 'Khoyniki', 1713769: 'Slough', 1517637: 'Winchester', 6342: 'Bereza', 1516671: '?', 8538: 'Sheremetyevo', 5725: '?', 7531: '?', 12680: 'Navoloki', 5987: 'Maloarkhangelsk', 1938273: 'Santiago de Cuba', 2241: '?', 7327: '?', 1102: 'Vũng Tàu', 6302: '?', 1331: '?', 1161139: 'Titan', 1517061: '?', 10038: '?', 1124521: 'Arzgun', 3790414: 'Taizhou', 6630: '?', 1713318: '?', 3895: '?', 7660: 'Sherbakul', 2455: '?', 14543: 'Tumanny', 1058722: 'Sergiev Posad-7', 9892: '?', 1032540: 'Nikola-Lenivets', 7690: 'Axay', 7521: 'Afula', 7494: 'Povarovo', 7501: '?', 1955917: '?', 8786: 'Zaklinye (zaklinskoe S/p)', 20666: 'Ust-Srednekan', 5103942: 'Longmont', 1710186: 'Port-Valais', 4068: '?', 1012: '?', 1920737: 'Marrakech', 7771: '?', 7768: '?', 7769: '?', 7402: 'Tara', 7051: '?', 1132654: 'Korshik', 1037272: 'Timsher', 1130161: '?', 6149: '?', 399: '?', 423: '?', 7784: '?', 21932: 'Hadera', 1957124: 'Nakhchivan City', 4310178: 'Incourt', 5245017: 'Montella', 7188: 'Sudak', 2215: '?', 9241: 'Parfino', 2722627: 'Santa Maria', 1044: 'Bada', 1703252: '?', 7114: '?', 9694: '?', 5006: '?', 2981: 'Dashoguz', 7841: '?', 5090: 'Zug', 4523: 'Tulun', 5855: '?', 7857: 'Pyaozersky', 5422723: 'Novozapolyarny', 1047394: 'Kipen', 13025: '?', 1705444: '?', 4551227: 'Arezzo', 7025: '?', 19612: 'Chamzinka', 1442: 'Wellington', 8211: '?', 1953: '?', 390: '?', 9726: 'Ust-Omchug', 1089197: 'Pochinok', 2912: 'Burgas', 3399: '?', 1705355: 'San Jose', 1150685: 'Troelga', 3573: '?', 3780: 'Plovdiv', 19734: 'Belorechensky ', 865: '?', 1516936: 'Sarasota', 15873: '?', 14935: 'Stoke-on-Trent', 18660: 'Peoria', 7878: '?', 5301: 'Kirensk', 7915: 'Podobnaya', 7916: 'Viktorovka', 12230: 'Pervomaysky', 1083941: 'Surgut', 5615: 'Agdam', 11433: '?', 21079: 'Severomorsk 3', 1705451: '?', 1924931: 'Anaseuli', 7924: 'Altengrabow', 7925: 'Kyappeselga (poselok)', 7931: 'Berezovka', 9183: '?', 2086: 'Biryusinsk', 1049839: 'Sentsovo', 7978: '?', 1947780: 'Schwäbisch Hall', 7869: '?', 1965157: 'Sparta', 1161171: 'Sosnovy Bor (poselok)', 11591: '?', 13088: '?', 7571: 'Broshnev', 1146008: 'Okoneshnikovo', 1047891: 'Vinnitsy', 1926530: 'Sarpsborg', 7932: '?', 9925: '?', 1910136: 'Sumgaitsky', 387: '?', 1075: 'Izberbash', 1116469: 'Gavrilov-Yam', 9927: '?', 1052: 'Zavolzhye', 3849: 'Talovaya', 7909: '?', 12345: 'Oshawa', 1953357: 'Holbeach', 1516553: 'Boston', 1971953: 'Abidjan', 1097345: 'Tyulyachi', 13112: 'Cherny Yar', 7987: 'Arcata', 7990: 'Eureka', 22584: 'Celle', 8173: '?', 1516571: 'Buxtehude', 8935: 'Krichev', 3837115: 'Kyōto', 7997: 'Rudny', 7998: 'Neytrino', 1001072: 'Selmenga', 1933707: 'Akhalkalaki', 5697: '?', 5459: 'Chusovoy', 1712782: 'Glendale', 8006: '?', 8390: 'Enschede', 3079695: 'Zanzibar', 15065: 'Plavsk', 15419: 'Molochnye Dvory', 4854: 'Bokhan', 1158767: 'Tarasa', 4756584: 'Cúcuta', 1332: '?', 3803841: 'Haikou', 1920000: 'Soldotna', 3336097: 'Molepolole', 1156550: 'Kedrovy', 1556: '?', 1710273: 'Palanga', 1160854: 'Ugolnye Kopi 3-J', 2977: '?', 8022: '?', 4669: 'Matveev Kurgan', 1029502: 'Ivanovo (derevnya)', 1077779: 'Axay', 20921: 'Gazadzhak', 7141: '?', 11430: '?', 4213: 'Aromashevo', 8064: 'Mirnograd / Dimitrov', 4159910: 'Zinder', 1705012: '?', 5266762: 'Walldorf', 5258753: 'Walldorf', 5045548: 'Henning', 18198: 'Belye Stolby', 1672: '?', 8082: '?', 8087: 'Saltozero', 8088: 'South Bend', 8090: 'Andover', 1709432: 'Bedford', 1706735: 'Burlington', 1515971: 'North Andover', 1516109: 'Montego Bay', 4696330: 'Liberta', 8096: 'Kuznetsovka', 1077339: 'Cherneya', 5266438: 'Nidderau', 5266432: 'Bad Orb', 4574697: 'Freigericht', 6592: '?', 5266636: 'Sindelfingen', 1153577: 'Polyarny', 8615: '?', 17454: 'Surovikino', 17886: 'Dubovka', 1516722: 'Tvarditsa', 1911927: 'Messina', 8124: 'Rezina', 1508286: 'Sosnovka', 1294: 'Zavety Ilicha', 8125: '?', 1224: '?', 2722649: 'Medellín', 8037: '?', 12085: 'Pologi', 1946387: '?', 6173: 'Dobrich', 1965737: 'Westerstede', 8159: 'Ein Shemer', 5331541: 'Elnesvågen', 4530373: 'Stavik', 8651: '?', 1555: '?', 1114981: 'Poretskoe', 10539: 'Namtsy', 15238: 'Sörenberg', 3806: 'Pushkinskie Gory', 8208: '?', 648: '?', 1992: '?', 1079593: 'Novy Egorlyk', 13899: 'Derzhavinsk', 8188: 'Chernorechye', 1148163: 'Andreevka', 736: '?', 4906827: 'Los Angeles', 19289: 'Baranchinsky', 6749: 'Okunaysky', 1794: 'High Wycombe', 3355: '?', 973: '?', 15037: 'Laramie', 19522: 'Casper', 1995: 'Gornyak', 13793: 'Dorogobuzh', 641: 'Divnogorsk', 819: '?', 8235: 'Zverinogolovskoe', 8229: '?', 1909317: 'Šilutė', 8238: 'Lakinsk', 8239: 'Novaya Usman', 8190: '?', 5266846: 'Bad Säckingen', 3763: 'Kakhovka', 1518452: 'Frunze', 9149: '?', 1080474: 'Syntul', 1041075: 'Krasnoflotsky', 1013294: 'Rognedino', 1049623: 'Sotnikovo', 1160417: 'Yasnaya', 8114: 'Basingstoke', 1908041: 'Pune', 1048459: 'Annolovo', 1908278: '?', 8038: 'Zubtsov', 10879: 'Chantilly', 8871: '?', 3428: 'Drokia', 1714427: 'Saarbrücken', 10853: 'Tashla', 21472: 'Dahn', 4919: 'Kuznechnoe', 6544: '?', 1516455: 'Deauville', 3336645: 'Beau Champ', 14737: 'Plesetsk', 1945238: 'Uden', 4286891: 'Culemborg', 1138408: 'Novy Mir', 7432: 'Abrau-Dyurso', 1113119: 'Metlino', 8301: '?', 657: '?', 4124: 'Perlovskaya', 3708: '?', 1151446: 'Kondratovo', 11088: 'Mariinsky Reyd', 4349: '?', 1706823: 'Andizhan', 11150: '?', 1046505: 'Voyskovitsy (poselok)', 1112104: 'Bogdashkino', 21401: 'Pleasant Hill', 14303: 'Ugra', 22723: 'Siena', 9113: 'Nurma', 8274: '?', 8253: '?', -99: -99, 1708120: 'Bakersfield', 6590: '?', 6961: 'Kovylkino', 3319: 'Shushenskoe', 5971: 'Pieksämäki', 21022: 'Kiskunlacháza', 259: 'Kuwait', 1038423: 'Kologriv', 1115239: 'Lapsary', 1954441: 'Hobart', 1724: 'Zarechny', 1957370: 'Bulawayo', 5468: 'Khartsyzsk', 1122: '?', 1709325: 'Świnoujście', 1962158: 'Szczecin', 20994: 'Brazzaville', 54: 'Zernograd', 13873: 'Khyrdalan', 1981: '?', 4014: 'Frolovo', 1040935: 'Vyselki', 8932: 'Kargasok', 8275: '?', 673: '?', 5422743: 'Livadia', 1154075: 'Uglegorsk', 1928010: '?', 1928875: '?', 1927015: '?', 10149: 'Pinega', 3494: 'Svirstroy', 4588: '?', 1711784: 'Fredonia', 1112588: 'Annenskoe', 8432: 'Vasilkovka', 7661: '?', 1905259: '?', 4118: '?', 13319: '?', 8447: 'Krasnograd', 7969: 'Stroganovo', 11389: 'Glafirovka', 3631: 'Kutaisi', 3137057: 'Şalālah', 793: 'Syracuse', 1918503: 'Pembroke Pines', 7488: 'Ust-Ordynsky', 908: 'Amstelveen', 5120181: 'Laie', 14706: 'Zarechensk', 8497: '?', 1601165: 'Germanovichi', 1161089: 'Karatayka', 6654: '?', 1928641: 'Toruń', 8532: '?', 15893: 'Kosterevo', 712: 'Rogachev', 1516338: 'Astara', 8506: 'Maly Kuyalnik / Chapaevka', 1030584: 'Stary Cherek', 5919: 'Erkin-Shakhar', 6608: '?', 8252: 'Morki', 4566: 'Starokonstantinov', 4793: 'Step', 4765: 'Kapan', 3034: 'Plast', 1011858: 'Zlynka', 5068: 'Kazanlŭk', 8491: '?', 2722574: '?', 8722: 'Suyda (poselok)', 9850: 'Borovoy', 8784: '?', 2129: '?', 1903363: 'Soldatsky', 9823: 'Leonidovo', 1125042: 'Strunino', 1944167: 'Tunis', 10336: 'Khor', 1518986: 'São Paulo', 1497: 'Pogar', 8546: 'Tarumovka', 5266460: 'Oestrich-Winkel', 4688: 'Boyarka', 2114: 'Swanage', 4127960: 'Bimbo', 15535: 'Kremovo', 2722609: 'Funafuti', 8569: '?', 8567: 'Aveiro', 1753: '?', 1048475: '?', 1159078: '34 Km', 1709670: 'Bhopal', 1043505: 'Makarovka', 16503: 'Semiluki', 17872: 'Ashukino', 7069: 'Akkol', 2756: '?', 1141697: 'Pavlovo', 4376728: 'Frankfurt (Oder)', 5115837: 'Utah Southern Addition', 1004248: 'Enotaevka', 1161307: 'Popovka', 5784: 'Levintsy', 1096333: 'S/z Pyatiletka', 1516317: 'Kiryat Gat', 10975: 'Beregovo', 2688: '?', 8529: '?', 8609: '?', 1135485: 'Plotbische', 1135506: 'Ust-Kem', 3163: '?', 9877: 'Tsokto-Khangil', 2819: '?', 8549: '?', 8625: 'Podelanka', 1927245: '?', 1937110: '?', 8634: 'Repki', 6130: 'Bichura', 1728: 'Kargapolye', 6037: 'Shumerlya', 1115402: 'Egorkino', 8650: 'Khodary', 8648: 'Khmelevitsy', 22713: 'Asunción', 16523: 'Gornopravdinsk', 21167: 'Denisovka', 6479: '?', 1058462: 'Teryaevo', 1008689: 'Oktyabrsky', 8515: 'Neftegorsk', 1713310: 'Noemberyan', 12957: 'Oknitsa', 1364: 'Vileyka', 426: '?', 6189: 'Fürstenfeld', 11731: 'Seymchan', 1462: 'Novovolynsk', 14702: 'Solnechny', 5514: 'Stry', 9155: 'Mezhitsa', 8706: '?', 3683: '?', 1156272: 'Useninovo', 3353: '?', 5393: 'Sysert', 8056: '?', 1046131: 'Kuzmolovo', 7652: 'Soroka', 1705709: 'Buġibba', 13735: 'Lipin Bor', 7313: '?', 1500498: 'Chistenkoe', 1503206: 'Novy Svet', 2603: 'Hasselt', 4092: 'Saint-Tropez', 8751: '?', 11596: 'Ashland', 6542: '?', 1161143: 'Dzhubga', 2722643: 'Cockburn Town', 3998177: 'Luganville', 1803282: 'Pärnu', 8779: 'Zverosovkhoz', 2794: 'Palana', 21905: 'Kirksville', 1066325: 'Khomutovo', 13849: 'Pyalma', 1517204: 'Marina del Rey', 5093594: 'Pacific Palisades', 8772: '?', 3787932: 'Xiamen', 1036694: '?', 20605: 'New Orleans', 1902290: 'Bludenz', 7647: 'Bussum', 1054766: 'Sablino', 4748404: 'Pereira', 8776: 'Topeka', 8780: 'Novy Toryal', 8320: '?', 1083858: 'Kashpir', 1966400: 'Stepanakert (Xankəndi)', 7641: 'Mar del Plata', 1153036: 'Oryol', 1124490: 'Shigaevo', 9264: 'Madurai', 4234836: 'Llanfairpwllgwyngyll', 1516406: 'Ploieşti', 4243450: 'Trun', 4244859: 'Laax', 22014: 'Podgorica', 4039: 'Vaskelovo', 6389: 'Mosty', 1063425: 'Vybiti', 7333: 'Luninets', 5561: '?', 12904: 'Kinel-Cherkassy', 13060: 'Athlone', 17823: 'Dundalk', 8785: '?', 1155360: 'Nizhnie Sergi', 1803187: 'Kiviõli', 14522: 'Utmanovo', 1927543: 'Burley', 19950: 'Smithfield', 1941745: 'Pawtucket', 4975: 'Kentau', 4779: 'Khotilitsy', 1704311: '?', 1799: 'Staritsa', 1104257: 'Staritsa', 7499: '?', 11905: '?', 4950962: 'Youngsville', 1705034: 'Mandal', 5656: 'Suzun', 4916467: 'Jessieville', 4245572: 'Davos Dorf', 4237751: 'Gaydon', 1651: 'Meridian', 1040259: 'Sholokhovo', 3067: '?', 6145: '?', 1709424: 'Beachwood', 9012: 'Russkaya Polyana', 1008943: 'Akyar', 3125986: 'Rethymno', 7876: 'Dobroe', 5224: '?', 20532: 'Truskavets', 2780: 'Sverdlova', 909: '?', 5868: 'Esso', 1046580: 'Lampovo', 9286: '?', 8957: 'Berea', 3541: '?', 18791: 'Kavalerovo', 8994: 'Vidin', 8996: '?', 5420589: 'Puerto Plata', 9724: 'Zerbst/Anhalt', 12542: 'Herzberg am Harz', 7734: 'Solnechny', 1895: '?', 1047586: 'Voloshovo', 1153345: 'Romanovka', 1030597: 'Nalchik-20', 6178: 'Yalutorovsk', 1074350: 'Novy Izborsk', 1060396: 'Revda 3-Ya', 15023: 'Swarthmore', 1905022: '?', 4287969: 'Nord', 7926: '?', 9040: '?', 2459: '?', 3893: '?', 9307: 'Udine', 5257303: 'Görlitz', 2074: 'Elgin', 1905546: '?', 1707191: '?', 8423: '?', 1602328: 'Veselovo', 5764: 'Smolenschina', 1058168: 'Rodniki', 3950: 'Urdoma (poselok Gorodskogo Tipa)', 9058: 'Voloshka', 1067763: 'Gorodische', 9372: '?', 347: '?', 9083: 'Prudy', 9080: 'Drofino', 5033: 'Kharkovsky', 9088: 'Vladimiro-Alexandrovskoe', 3740: 'Kalush', 1951841: 'Zugdidi', 7398: '?', 1902783: 'Raufoss', 1919697: '?', 1923038: '?', 5291: 'Konchezero', 534: '?', 1031967: 'Troitskoe', 1138722: 'Chernukha', 12050: 'Arsk', 17657: 'Cheremushki', 5261729: 'Wuppertal', 12420: '?', 4144: '?', 4152: '?', 5234938: 'Avon', 13520: 'Eremichi', 7590: '?', 3079317: 'Lapithos', 9140: 'Anzorey', 13738: '?', 9157: 'Burkhala', 10889: 'Narovlya', 4873: 'Shakhovskaya', 9153: 'Preobrazhenka', 1040769: 'Neftegorsk', 20944: '?', 21063: '?', 17379: '?', 6541: 'Salsk', 1967968: 'Dana Point', 1127565: 'Kropotkin', 1062850: 'Uglovka', 3478: 'Kurkino', 1516474: 'Belmont', 15174: 'Vylgort', 3494638: 'Tiruppuvanam', 624: 'Korenovsk', 5070: '?', 1905852: '?', 1159767: 'Listvenichny', 4037: 'Drammen', 1709912: 'Buzzards Bay', 1160954: 'Priozerny', 10256: 'Uchkeken', 925: '?', 19581: 'Navlya', 18801: 'Beshenkovichi', 6929: 'Yuganskaya Ob', 15187: 'Kiselnya', 1932487: 'Kathmandu', 1909006: 'Lhasa', 9184: '?', 2251: '?', 9188: 'Shulbinsk', 6420: 'Narynka', 1047144: 'Staraya Maluxa', 1046782: 'Zakhonye-1', 2261: 'Kresttsy', 8729: 'Fredericton', 1063482: 'Lemenka', 15727: "Ma'alot-Tarshiha", 1936162: 'Güstrow', 2771: 'Osinniki', 5413: 'Asha', 5266897: 'Sigmaringen', 9226: '?', 16264: '?', 1337: '?', 10713: 'Ust-Donetsky', 1033332: 'Podborki', 2190: '?', 1908924: 'Cottbus', 5091522: 'Grand Terrace', 3991573: 'Munda', 1710494: 'Abovyan', 1906703: 'Seaside Heights', 1021773: 'Khabarovskaya', 1026895: 'Untsukul', 7427: 'Pogranichny', 1517370: '?', 8833: 'Primorsko-Akhtarsk', 1091671: 'Komsomolets', 8662: '?', 674: '?', 9265: 'Kamenets', 9281: 'Karabanovo', 9236: 'Avnyugsky', 9530: '?', 11688: 'Mars', 1710590: 'Cranford', 1111829: 'Novaya Sloboda', 3896: 'Sengiley', 8825: 'Zatobolsk', 1136802: 'Taseevo', 1154972: 'Lesnoy', 1109859: 'Malye Mazgi', 8331: '?', 9285: '?', 1040976: 'Botanika', 1593: '?', 4843: '?', 1946697: 'Santiago de Compostela', 1056976: 'Kroliki', 1517033: 'Llantwit Major', 5423701: 'Vadul-Luy-Vode', 5265089: 'Tutzing', 1509379: 'Berezino', 2897: 'Podolsk / Kotovsk', 3117872: 'Jinja', 15236: 'Pribelsky', 1045270: 'Bor (borskoe S/p)', 1519298: 'Karmiel', 996: '?', 822: '?', 6567: 'Zhidachov', 1908937: 'Plzeň', 9057: '?', 1059689: 'Firsanovka', 2408: '?', 3854: '?', 738: '?', 1079: '?', 2902: '?', 1925: '?', 2815: 'Zugres', 1084305: 'Petro-Slavyanka', 5298: 'Strunino', 14000: '?', 9274: 'Dzhida', 10807: 'Lyubotin', 11310: '?', 5721: 'Petrovo-Dalnee', 3458: 'Hilversum', 20210: 'Juneau', 4046: 'Juneau', 9276: '?', 9364: 'Elgen', 1917688: 'Cádiz', 8316: 'Aykino', 1047154: 'Shum', 5953: 'Nowy Sącz', 16101: 'Krasnoe', 1219: '?', 4799: '?', 4581: '?', 1023387: 'Fokino', 20756: '?', 1342: 'Pristen', 9447: '?', 9393: '?', 1134756: 'Kamenskoe', 1765: 'Kamenskoe', 310: '?', 22038: 'Chuncheon', 2722631: 'Yaoundé', 9413: 'Bad Liebenstein', 1929087: 'Kaltennordheim', 1922923: 'Bad Salzungen', 6464: 'Pokrov / Ordzhonikidze', 1058209: 'Fryazino', 3808743: 'Chongqing', 5265: '?', 7171: '?', 7458: 'Mikhaylovka', 1704264: '?', 8396: 'Annino', 4603: 'Ivanovo', 6887: 'Sibirsky', 12428: 'Barysh', 1970034: 'Zvolen', 1701534: 'Chapaev', 17548: 'Novye Aneny', 3965315: 'Baoji', 1515752: '?', 2207: '?', 1710776: 'Siĕmréab', 9968: '?', 9742: 'Novoagansk', 20067: 'Fresno', 1940292: 'Jagannath Puri', 5667: 'Kirillov', 7207: 'Pau', 1602439: 'Zaostrovechye', 1708327: 'Graz', 1068521: 'Zarechny', 1041952: 'Korzhevsky', 1516500: 'Sderot', 4316266: '?', 1707343: 'Alexandria', 5160: 'Nyurba', 10600: 'Ayagoz', 9468: 'Dvinskoy', 8504: '?', 13939: '?', 1885: 'Yadrin', 4654: 'Khorinsk', 15841: 'Syvdarma', 4660689: 'Portmore', 9143: 'Adyge-Khabl', 6215: '?', 10911: '?', 5955: 'Mariinsk', 5077803: 'Tyrone', 18047: 'Barybino', 9433: '?', 561: 'Retyun', 4246221: 'Aesch', 1907282: 'Verneuil-sur-Avre', 10097: '?', 1907995: 'Politotdel', 1091816: 'Vladimirovka', 5203: '?', 9503: 'Novoe Kashirovo', 9504: 'Novy Ishteryak', 6282: '?', 7704: 'Zaoxky', 9509: 'Malygino', 10032: 'Orlovka', 1046659: 'Rozhdestveno', 5110854: 'Medford', 9072: 'Torrevieja', 1708007: '?', 5247: 'Staraya Ruza', 1903946: 'Jesi', 9521: '?', 5947: '?', 1101: 'Yarovoe', 9546: 'Korosten', 3043582: 'Benghazi', 3026262: 'Kūm', 9544: '?', 9550: '?', 4177: '?', 2890: 'Skovorodino', 1923437: 'Bremerhaven', 6747: 'Karatau', 1515691: '?', 9340: 'Alapaevsk', 9559: '?', 1909874: 'Tauragė', 1931679: '?', 1940068: '?', 1129124: 'Berezovsky', 2317: 'Mamontovka', 9565: 'Kirovskaya', 1091935: 'Krasnochervonny', 9719: 'Senigallia', 9284: 'Bobo Dioulasso', 1803171: 'Saue', 9513: '?', 9558: '?', 6804: "Saint John's", 9589: '?', 2722616: 'Mashhad', 5631: 'Bolshie Vyazemy', 2500266: 'Roshtkala', 16546: 'Sergeevka', 1269: '?', 4002: '?', 1795: '?', 9549: '?', 8109: 'Arykbalyk', 1050608: 'Usola', 1009560: 'Razumnoe', 4539622: 'Schio', 1070173: 'Podborovye (gdovskaya Volost)', 4303734: 'Sint-Niklaas', 9501: '?', 1901102: 'Kfar Yona', 8938: '?', 1060282: 'Rayki', 9662: 'Kurkieki', 7167: 'Krasnodon', 1009908: 'Belgorod-22', 4930327: 'Ohio', 2296: '?', 1707556: 'Sammamish', 8645: '?', 2450: 'Lincoln', 5170: '?', 1715183: '?', 2635: 'Ushaki (poselok)', 1048442: 'Tsaritsyno Ozero', 1050080: 'Terbuny', 10031: '?', 9652: '?', 1046690: 'Syaskelevo', 456: '?', 2211773: 'Declo', 5414: '?', 5105647: 'Big Timber', 1907447: 'Būsān', 9704: 'Cherkasskoe', 4064: '?', 1905702: '?', 9705: 'Kerchevsky', 11839: '?', 6369: '?', 6044: '?', 6650: 'Posyet', 5823: '?', 3074291: 'Būshehr', 12889: 'Bryanka', 1707905: '?', 5228141: 'Mantes-la-Jolie', 10797: 'Montevideo', 7163: '?', 2548: '?', 3486: 'San Marcos', 9733: 'Kecskemét', 6781: 'Bodaybo', 1517327: '?', 11977: 'Kyoneurgench', 184: '?', 21739: '?', 1517885: '?', 5042: '?', 6589: 'Dubki', 1277: 'Krasnoufimsk', 1780: 'Verkhnyaya Salda', 1040726: 'Sukko', 1517025: 'Incheon', 1961292: 'Leer (Ostfriesland)', 285: 'Bolshaya Vruda', 1789: 'Baltimore', 1160892: 'Egvekinot 1-J', 9477: '?', 65: 'Kinel', 1035535: 'Virandozero', 1092157: 'Pelagiada', 4470: 'Galway', 4753: '?', 4341: '?', 9774: '?', 9677: '?', 1159430: 'Arshanovo', 3124: 'Balakleya', 1902104: 'Kingsville', 3734: 'Potsdam', 1130771: 'Sosnovka', 9787: '?', 9786: '?', 1154105: 'Chekhov', 9808: 'Velichaevskoe', 2289: 'Chashniki', 13966: 'Borovukha', 1516629: 'Washington', 9755: '?', 10932: 'Chernolesskoe', 1011: '?', 1709684: 'Koprivnica', 9839: '?', 9843: '?', 9838: '?', 4270726: 'Älmhult', 14537: 'Saraktash', 3416: '?', 11216: '?', 16379: 'Hanover', 9841: '?', 3112: '?', 10318: 'Dauria', 9685: 'Sretensk', 1035828: 'Poyakonda', 1932943: 'Vangaži', 2400664: 'Ninotsminda', 4694089: 'Bayamo', 8033: '?', 1763: 'Kamen-Rybolov', 1516798: '?', 9866: 'Bashtanka', 11253: 'Nizhnyaya Poyma', 1702740: 'Alexandrovka', 14445: 'Telavi', 7094: 'Tayynsha', 6143: '?', 1901049: 'Omer', 6194: 'Almaznaya', 7934: '?', 1072569: 'Nasva', 9050: '?', 4696300: 'Saint Johnston Village', 5449: 'Totskoe', 1147237: 'Grachevka', 9907: 'Tatarbunary', 4660389: 'Spanish Town', 2722647: 'Willemstad', 1078367: 'Dvurechye', 1515707: '?', 2068: '?', 9381: 'Iisalmi', 9625: 'Kumkurgan (kumkurgansky Rayon)', 2202745: 'Rodgau', 1905606: 'Neu-Isenburg', 1951150: 'Speyer', 4346058: 'Nordhausen', 14224: 'Fedorovka', 9638: 'Kichigino', 6888: '?', 4545405: 'Lecco', 8749: 'Bromsgrove', 1519036: 'Melun', 9956: '?', 1062576: 'Novoselitsy', 1708618: 'Riyadh', 1740: '?', 6050: 'Kyshtym', 5937: '?', 4399091: "Villeneuve-d'Ascq", 9967: '?', 4288: '?', 6842: '?', 1027: '?', 9569: '?', 1516560: 'Mahwah', 1142498: 'Sokolskoe', 1517344: 'Kongsberg', 8763: 'Osa', 962: 'Kurovskoe', 9135: 'Novaya Kakhovka', 1801468: 'Frunze', 1262: 'Tetritskaro', 1941587: 'Ochamchira', 5001: '?', 1710907: 'Suwanee', 9993: '?', 10016: '?', 20367: '?', 8381: 'Artsiz', 1118: '?', 3168: '?', 10051: '?', 10641: 'Volovo', 8652: '?', 3080157: 'Tanga', 1712009: 'Lae', 10041: '?', 10317: 'Ryrkaypy', 9009: 'Kiryat Yam', 10047: 'Vvedenskoe (selo)', 12186: '?', 7189: '?', 21491: '?', 16770: 'Yagelny', 22208: 'Lloret de Mar', 19399: 'Boží Dar', 1803370: 'Viljandi', 5425654: 'Dzhardam', 10068: '?', 1915909: 'Paducah', 3323128: 'Monze', 1705498: 'Rochester', 1033693: 'Kirovka', 19889: '?', 3832972: 'Tateyama', 2191: '?', 10103: 'Zalesovo', 8242: '?', 10179: 'Areda', 919: '?', 10114: 'Karagash', 6632: 'Gliwice', 1052909: 'Bolshaya Elkhovka', 10072: '?', 20427: 'Aga-Khangil', 1121492: 'Orlovsky', 11037: '?', 1056944: 'Vorovskogo', 3679: 'Vorovskogo', 1068156: 'Makhalino', 8861: 'Roschinsky ', 19245: '?', 11936: '?', 2206: '?', 10144: '?', 7820: 'Susanino', 11228: 'Ado-Tymovo', 2138: 'Babstovo', 10164: 'Alexandro-Nevsky', 14061: 'Templin', 1152822: 'Shmakovka', 2839: '?', 13456: 'Oktyabrsky', 9112: 'Saryagash', 12575: '?', 1051606: 'Orshanka', 14049: '?', 11173: 'Bigosovo', 6676: 'Enakievo', 1711816: 'San Marino', 9754: 'Salmi', 1902517: 'Terracina', 21631: '?', 2337: '?', 1160717: 'Gongota', 7198: '?', 5661: 'Stary Nadym', 10192: '?', 8439: 'Vaziani', 10447: 'Altes Lager', 5510: '?', 10075: '?', 2017: 'Borovlyany', 10302: 'Krylovskaya', 1519059: 'Vilhelmina', 9222: '?', 1033536: 'Voylovo', 21110: 'Korostyshev', 20955: 'Ivanichi', 1901642: 'Majuro', 1703827: 'DeLand', 1920668: 'Winter Park', 1703566: 'Eskişehir', 4008: '?', 10213: 'Araltobe', 3695338: 'Makassar', 5259832: 'Torgau', 4693: 'Ugolnye Kopi', 10220: 'Stepnoy', 9926: '?', 3663: '?', 10119: '?', 9239: '?', 10225: '?', 10278: '?', 1800704: 'Larga', 1046125: 'Kornevo', 1123: '?', 1036273: 'Meliorativny', 17150: 'Otradnaya', 6743: 'Bethlehem', 12367: 'Kiryat Arba', 1531: 'Slonim', 10240: 'Lunevo', 5131: 'Zaprudnya', 4194: 'Yuzhnoukrainsk', 12133: 'Kilia', 1942531: 'Ostrava', 14210: 'Davlekanovo', 2823: '?', 1709035: '?', 8632: '?', 1908264: 'Merced', 1939859: 'Bra', 4944: 'Gurzuf', 8672: '?', 2124: 'Columbia', 1003044: 'Vaskovo (stantsia)', 16687: 'Nesterovo', 1080458: 'Samuilovka', 1635: '?', 14435: 'Krasnoarmeyskoe', 1925790: 'Lankaran', 1199: '?', 3150: 'Turovets', 4240086: 'Cleethorpes', 1516346: 'Marblehead', 10299: 'Kochki', 20580: 'Rovenki', 1113342: 'Berlin', 1160718: 'Domna', 7363: 'Tsagan-Ol', 1910973: '?', 2801: 'Ob', 4358991: 'Koblenz', 1518450: '?', 1703600: 'Shaoxing', 4287430: 'Best', 14868: 'Verkhnyaya Sinyachikha', 1001438: 'Mirny', 3588: '?', 15127: 'Belaya', 10150: '?', 1156936: 'Svetly', 1046171: 'Novoe Toxovo', 11311: 'Sofino', 1002709: 'Pinega', 1711922: 'Perth', 3141933: 'Taşucu', 13734: 'Bolshaya Ucha', 1036071: 'Shunga', 10444: 'Aki', 1030758: 'Znamensk', 1067847: 'Kirillovo', 1914596: '?', 1000: 'Sukhoy Log', 5582: 'Novoozernoe', 5004: 'Mirny', 1905907: 'Madison', 10183: 'Evensk', 1950907: 'Cagliari', 1517373: '?', 20515: 'Halmstad', 4232292: 'Preston', 1090: '?', 1516557: 'Shusha', 1113989: 'Alatyr', 3181: 'Ladushkin', 1902577: 'San Luis Obispo', 1057413: 'Davydovo (davydovsky S/o)', 11362: '?', 11361: '?', 1936570: '?', 10396: '?', 1491: 'Alexino', 10431: '?', 10341: '?', 604: 'Kachkanar', 10334: '?', 10445: 'Zelenogorskoe', 7938: '?', 1910676: 'San Ġiljan', 19111: 'Kamenka', 16141: '?', 15526: 'Ertsevo', 315: '?', 1008630: 'Alexeevka', 2828: '?', 10450: '?', 1047578: 'Vetchiny', 20992: '?', 3135865: 'Batroûn', 8413: '?', 10488: '?', 1928031: 'Cholet', 1092944: 'Davydovo', 14048: '?', 1350: '?', 1704188: 'Livorno', 10506: '?', 1504320: 'Chinadievo', 1121551: 'Kosh-Agach', 1121548: 'Dzhazator', 1152826: 'Vostok', 3796166: 'Nanchang', 10525: 'Novoorsk', 10519: '?', 11393: '?', 4328: 'Babino (poselok)', 4293: 'Srednebeloe', 7581: '?', 2807: 'Savinsky', 1164: 'Albuquerque', 10566: '?', 10504: '?', 4653: '?', 11400: '?', 8642: '?', 3963450: 'Jinzhou', 2690: 'Skadovsk', 1517177: 'Fairfield', 1949129: 'Hilton Head Island', 3167426: 'Kombolcha', 12767: 'Yamm', 14878: 'Serdar', 10483: '?', 1518277: 'Teaneck', 5387: '?', 6106: 'Bazarny Syzgan', 6492: 'Balezino', 6732: 'Kantemirovka', 10410: 'Ostrovets', 21323: 'Runan County', 1057982: 'Chelyuskinsky', 4770: '?', 1933436: 'Rovereto', 20291: 'Schelkovo-7', 1857: '?', 10782: 'Borki', 1943417: 'Candolim', 4294771: 'Mayrhofen', 5032: '?', 1702942: 'Atakent', 10599: '?', 10603: 'Werneuchen', 4295: 'Mosalsk', 1030635: 'Bagrationovsk', 1932656: 'Mukilteo', 1911081: 'Ridgefield', 1933: '?', 2722414: 'Giza', 20957: 'Canberra', 3244: 'Topki', 1123579: 'Tomichi', 17332: 'Priamursky', 20833: 'Verona', 1703415: 'Lincoln', 10572: '?', 4316: 'Berdyansk', 7049: '?', 1161144: 'Debdirge', 15482: 'Oktemtsy', 15032: 'Hackettstown', 12295: 'Vorotynets', 829: '?', 10668: 'Obukhovo', 1075696: 'Neelovo-1', 5266775: 'Heimsheim', 1317: '?', 1079069: 'Lenina', 11530: 'Lenino', 11703: 'Toybokhoy', 1707799: '?', 2211003: 'Cuenca', 5432: 'Arad', 1518969: 'Kosteshty', 1019340: 'Yurovo', 4127: '?', 9667: '?', 10730: 'Pavlogradka', 1059051: 'Andreevka', 2722411: 'Snegiri', 2722629: 'Trindade', 10745: '?', 5142: 'Ibresi', 11423: 'Kholodny', 1046269: 'Vozrozhdenie (stantsia)', 10763: 'Excelsior', 1976: 'Elban', 4813: 'Ropsha', 8345: 'Priobye', 350: 'Purpe', 12482: 'Kestenga', 4787: '?', 3633: 'Poddorye', 3957: '?', 12704: 'Borovskoy', 1701960: 'Pervomayskoe', 9716: '?', 21400: 'Monterrey', 12741: 'Yarega', 7689: '?', 10789: 'Verkhoshizhemye', 2073: 'Palatine', 20760: 'Lyakhovichi', 10795: '?', 477: 'Urbana', 10811: '?', 5746: '?', 1786: 'Yakovlevka', 3519: '?', 4734: 'Novy Oskol', 21438: 'Cranfield', 2011: 'Berezovka', 1708342: '?', 10819: '?', 1881: '?', 1709102: 'Anaheim', 6501: '?', 1031047: 'Krasnotorovka', 2277: 'Lecce', 18341: 'Elkhovka', 1570: 'Vorotynsk', 10838: '?', 12534: 'Yushala', 5331109: 'Torquay ', 3206: 'Ispravnaya', 1964968: 'Naantali', 1709585: 'Raisio', 5422441: 'Fujimi', 1084318: 'Smolyachkovo', 1015045: 'Oktyabrsky', 1057708: 'Krasnaya Pakhra', 7202: 'Balchik', 21469: 'Steamboat Springs', 5086558: 'Waunakee', 13776: 'Kulotino', 10881: 'Pushnoe', 11767: '?', 1919024: 'Estes Park', 8550: '?', 7280: '?', 1156590: 'Urtam', 10899: 'Turovlya', 10900: '?', 1710737: 'Oakville', 1091873: 'Novotersky', 1601443: 'Krasny Bereg', 16746: 'Serdobsk', 1703713: '?', 12885: '?', 4313: 'Poitiers', 4702180: 'Sololá', 4702731: 'San Marcos La Laguna', 6280: '?', 1113081: 'Nyazepetrovsk', 1707818: 'Kansas City', 4473: '?', 10800: 'Bulungur', 7332: '?', 1517301: '?', 1032819: 'Vysokinichi', 5663: '?', 2739: '?', 10929: '?', 5462: '?', 1803251: 'Tapa', 5769: '?', 5936: 'Rosh HaAyin', 4262796: 'Helsingborg', 4495935: 'Mysłowice', 10965: 'Remmash', 3446: '?', 1113164: 'Petrograd', 22696: 'Tijuana', 1513010: 'Tavriysk', 3502356: 'Malappuram', 13542: 'Muezersky', 17835: 'Novaya Derevnya', 1148884: 'Vereschagino', 1143377: 'Sharapovo', 1928594: 'Ipswich', 6298: 'Stolbische', 4342713: 'Osterholz-Scharmbeck', 10995: '?', 2719: 'Zayanye', 1074576: 'Lyady', 3117: 'Levanger', 21233: 'Debrecen', 2941: 'Kolomyya', 4655: 'Polysaevo', 1093635: 'Sampur', 517: '?', 2243: 'Vanino', 18535: '?', 1156358: 'Nosok', 7552: 'Mglin', 11020: '?', 8823: 'Uva', 6115: '?', 15157: 'Kalininskaya', 21366: 'Gvardeyskoe', 6955: '?', 11026: '?', 8220: '?', 1941096: 'Garfield', 1917665: 'Wayne', 1517263: 'Elizovo', 1602313: 'Loshnitsa', 839: '?', 1153768: 'Petropavlovsk', 11081: 'Sharlyk', 1149179: 'Divya', 6012: '?', 804: '?', 11086: '?', 1153787: 'Kachikattsy', 3673: '?', 3449: 'Glinischevo', 4343226: 'Oldenburg', 11128: 'Elgan', 9863: 'Ak-Dovurak', 11136: '?', 12434: 'Carlsbad', 3840: '?', 5580: 'Torgay', 1901127: 'Yokneam Ilit', 11159: '?', 1519325: '?', 162: 'Churapcha', 16073: '?', 1155828: 'Sukhoy Log', 20487: 'Blacksburg', 862: 'Pokhara', 1096121: 'Laishevo', 3138056: 'Umm Sa`īd', 5267212: 'Kitzingen', 5267080: 'Marktbreit', 11187: 'Vradievka', 17052: 'Fryanovo', 1013520: 'Lozhki', 1715275: 'Maputo', 1047630: 'Zaklinye (voloshovskoe S/p)', 1690: 'Susuman', 11854: '?', 1143829: 'Linevo', 11198: '?', 1803267: 'Räpina', 11204: '?', 6682: 'Cirencester', 5933: 'Molodtsovo', 1864: '?', 2722456: 'Konya', 1516597: '?', 11212: '?', 6350: 'Alexandria', 540: 'Sevenoaks', 2345: 'Oklahoma City', 2730: '?', 1500034: 'Kuybyshevo', 1801902: 'Hillsboro', 2789: 'Dubno', 1137182: 'Belozerskoe', 1503854: 'Slovechno', 20934: 'Jaffna', 6472: 'Ivanovskoe', 18273: 'Terekli-Mekteb', 1060824: 'Peredki', 1122820: 'Novotroitsk', 1503071: 'Elizavetovka', 6880: '?', 6476: '?', 5192407: 'Yangsan', 4308: '?', 10108: '?', 11344: 'Iwerne Minster', 15829: 'Tyshkovichi', 5074882: 'Newtown', 11230: '?', 491: '?', 11283: '?', 11285: '?', 4695540: 'East End Village', 10901: '?', 11286: '?', 8693: 'Vyoshenskaya', 1160927: 'Polyarny', 11232: '?', 1509: 'Brovary', 5152: '?', 1135003: 'Zykovo', 1708807: 'Ürümqi', 1918073: '?', 2820: '?', 1053490: 'Schitnikovo', 4010055: '?', 3979104: 'Weno', 21346: 'Naryn', 4566299: 'Bar', 1706102: 'Vista', 1801266: 'Soroca', 7173: 'Ilinsky', 18296: 'Tsugol', 18297: 'Bezrechnaya', 16752: 'Lanciano', 1276: '?', 12009: '?', 1934353: 'Solothurn', 3493907: 'Varkkallai', 16815: 'Vladimirovka', 5251: 'Glendale', 2308: 'Albany', 9392: 'Khachmaz', 1906333: 'Guba', 1902665: 'Fort McMurray', 5130077: 'Thorold', 11375: '?', 17863: 'Lukashi', 1122255: 'Zimari', 11380: 'Novonikolsky', 4176065: 'El Aaiún', 4128: '?', 1515575: '?', 1079342: 'Mokry Log', 1145017: 'Medvedsk', 1042023: 'Esto-Sadok', 10495: 'Baran', 11466: 'Panino', 21194: 'Lauenburg/Elbe', 11416: 'Vilkovo', 8282: 'Afrikanda', 7379: 'Magas', 22132: '?', 5052: '?', 10979: 'Pereyaslavka', 1917608: 'Cranston', 11243: 'Armyansk', 21539: '?', 6430: 'Erie', 16038: 'Fayetteville', 10837: 'Telford', 4931: 'Krasavino', 1600: '?', 4949261: 'Phoenix', 4637339: 'La Plata', 7495: '?', 16289: 'Yuryuzan', 792: 'Pruzhany', 1901962: 'Benidorm', 10779: 'Petrikov', 15551: 'Oakland', 11502: 'Saint Clair Shores', 9409: 'Narvik', 3723: 'Sandovo', 1003008: 'Yurmala', 2192: '?', 1078666: 'Pushkin', 1025296: 'Novaya Kalitva', 11507: 'Biokombinat', 1133430: 'Ukhta (derevnya)', 1901766: 'New Westminster', 1705964: 'Salem', 2532: 'Babaevo', 1971506: '?', 15757: 'Oranjestad', 2500216: 'Obigarm', 1159416: 'Khabarovsk-43 (taezhnoe)', 12567: '?', 5060160: '?', 4992: '?', 1908244: '?', 1517644: 'Predgornoe', 16472: 'Pervomaysky', 17723: 'Volka', 1079172: 'Krasny Desant', 11536: 'Svetlodarsk', 11540: 'Yaloveny', 4822: 'Dukhovschina', 1159105: 'Pereyaslavka Vtoraya', 11619: 'Bloomingdale', 1057193: 'Novy Gorodok', 18631: 'Petrovsk-Zabaykalsky', 4692: '?', 12352: '?', 1044339: 'Ledovskoe', 3316874: 'Pambuka African Township', 1399: 'Sosensky', 2654: '?', 9582: '?', 1917496: 'Bad Schönborn', 1517862: '?', 1706921: '?', 9141: '?', 1165: '?', 5670: 'Sarpa', 3086917: 'Tartus', 1931563: 'Skrunda', 12628: 'Hjørring', 21347: 'Sedona', 14261: 'Colmar', 1507196: 'Rubezhnoe', 1055132: 'Khvolovo', 1054858: 'Voskhod', 1080395: 'Lashma', 11570: '?', 11716: 'Malopeschanka', 1037610: 'Dyakonovo', 11705: 'Bagerovo', 5261727: 'Remscheid', 1938981: 'Varanasi', 5401: 'Emanzhelinsk', 20164: '?', 1906960: 'Bruntál', 4945: '?', 11631: '?', 6585: 'Novoorlovsk', 12490: 'Glastonbury', 1906386: '?', 3643: '?', 21497: 'Monmouth', 6505: 'Salem', 1041886: 'Azovskaya', 12461: 'Tekos', 6575: 'Colorado Springs', 17069: '?', 1904692: 'Moscow', 1134017: 'Astrakhan (derevnya)', 1631: '?', 3123431: 'Abéché', 4513: 'Nikopol', 1711194: '?', 9223: '?', 8436: 'Arkalyk', 1707320: 'Danville', 19891: 'Soldato-Alexandrovskoe', 5417: '?', 6581: '?', 1193: 'Zavitinsk', 11673: '?', 1515870: 'Lebedinovka', 566: '?', 4089: '?', 2407: 'Lowell', 1957829: 'Natick', 1923883: 'Westford', 1905720: '?', 8973: '?', 5265637: 'Aschaffenburg', 16669: 'Bakal', 17404: 'Dukat', 1837: '?', 11719: '?', 6182: 'Kagan', 4906: '?', 1004468: 'Polynny', 1047348: 'Varixolovo', 9115: 'Anzhero-Sudzhensk', 11733: 'Zaslavl', 9633: '?', 2684: 'Molochny', 7803: 'Pripyat', 2148: '?', 1031146: 'Krasnoznamensk', 3362: '?', 11753: '?', 19408: 'Toyvola', 9745: '?', 1943125: 'San Fernando', 2356: '?', 16905: 'Lyubytino', 4693389: 'Cienfuegos', 1091675: 'Marinskaya', 1121869: 'Uryupino', 3554: '?', 4654237: 'Brasília', 8736: 'D/o Pribrezhny', 1927420: 'San Angelo', 1250: '?', 1916437: 'Kadzhi-Say', 4651162: 'Florianópolis', 10971: 'Taman', 1084874: 'Ekaterinovka', 12763: 'Chigirin', 6477: 'Bradford', 11820: 'Schuchinsk', 6269: '?', 11830: '?', 1929: 'Verkhnedneprovsky', 10734: '?', 1710499: 'Serkhetabad', 3827: 'Pervomaysk', 1048028: 'Larionovo', 1901777: 'Kummersdorf-Gut', 1100418: 'Mirny', 11873: '?', 11042: 'Smolevichi', 1122083: 'Srosty', 9272: 'Voznesenye', 4640: 'Ijevan', 11862: '?', 1512: '?', 1600913: 'Baran', 12039: '?', 1100044: 'Pushkino', 19367: '?', 9168: '?', 992: '?', 5973: '?', 11902: '?', 4457: '?', 1939409: '?', 5099795: 'East Las Vegas', 15415: 'Kedrovy', 3249: 'Volzhsk', 6383: 'Shepetovka', 6404: 'Vostochnoe', 6405: 'Kozyrevsk', 1707075: 'Verbania', 3199: 'Steklyanny', 20157: 'Krasny Kholm', 11944: '?', 4559: '?', 1507386: 'Brody', 1069180: 'Isakovo', 14933: 'Meiningen', 1958115: '?', 3839669: 'Hiratsuka', 1517058: 'Castine', 1711173: 'Sophia Antipolis', 12279: '?', 17358: 'Izmalkovo', 2921: '?', 11043: 'Veydelevka', 6172: 'Guelph', 5023874: 'Warren', 1516407: 'Hoboken', 1704671: 'Lawrenceville', 5605: '?', 12012: '?', 4988: '?', 1710299: 'Corolla', 1830: 'Ushtobe', 3748: 'Tallahassee', 4267: 'Nerchinsk', 1901056: 'Katzrin', 4472: '?', 1518603: 'Orange', 16587: 'Fullerton', 2722661: 'Bukavu', 4830180: 'Alta Gracia', 1703864: '?', 7922: 'Milovice', 10947: '?', 6631: '?', 12996: 'Tikhmenevo', 9379: '?', 5001181: '11 North-Victoria Road-FM 493 Colonia', 1913756: '?', 4415095: 'Pau', 1008500: 'Tashkent', 1708345: 'Ipoh', 1160907: 'Baranikha', 5742: 'Verkhnevilyuysk', 18079: 'Ulyoty', 5743: '?', 12078: '?', 18411: 'Mirny', 1007176: 'Karaidel', 2203: 'Termez', 5260686: 'Satrup', 2301: 'Blagoevo', 12100: 'Yutsa', 3786426: 'Xining', 12131: '?', 6423: '?', 12124: '?', 13519: 'Uren', 7935: '?', 5266638: 'Esslingen am Neckar', 2352: '?', 1057242: 'Solmanovo', 676: '?', 2722408: 'Falls Church', 1103225: 'Toporovo', 12156: '?', 4998: 'Auliekol', 6454: '?', 20317: 'Dno', 21913: '?', 1703960: 'Hettstedt', 1121730: 'Katanda', 1993: 'Chegdomyn', 1129921: 'Tisul', 1082649: 'Pertovo', 1002722: 'Sosnovka', 4268: '?', 1519137: 'Ingichka', 4170: '?', 1243: '?', 18696: 'Pyazhelka', 1137431: 'Krasny Oktyabr', 10123: '?', 11312: 'Revda', 14732: 'Lesogorsk', 1125864: 'Pershino', 229: '?', 12209: '?', 1518777: '?', 12730: 'Engel-Yurt', 12232: 'Orlovka', 1601228: 'Buda-Koshelyovo', 11741: '?', 8539: '?', 5265090: 'Weßling', 1990: '?', 11267: 'Sverdlovsk / Dolzhansk', 12524: 'Kraskino', 9560: '?', 12246: 'Ust-Kalmanka', 13845: 'Tonshalovo', 12260: 'Adyshevo', 1904878: 'Cape Town', 18272: 'Red Lodge', 3926: '?', 1517546: '?', 1019491: 'Sosnovka', 1019404: 'Kaduy (derevnya)', 1127719: 'Moskovskaya', 12364: '?', 4182177: 'Constantine', 3062: 'Teplodar', 7663: '?', 1920116: 'Stillwater', 1515735: '?', 15623: 'Oyskhar', 1947595: 'Oran', 1516845: 'Roeselare', 842: 'Guatemala', 4706718: 'Ciudad de Guatemala', 9906: '?', 1052521: 'Yavas', 1002982: 'Undozero', 12320: '?', 2178: 'Bakaly', 6776: 'Kavkazskaya', 12455: '?', 1158581: 'Sovetsky', 2556: '?', 18986: '?', 6311: 'Fizuli', 8727: 'Khobda (novoalexeevka)', 6792: '?', 11130: 'Kamenka', 8214: 'Barsuki', 5191: 'Malin', 1015741: 'Verkhnevolsky', 12317: '?', 13612: 'Lesnye Polyany', 12363: '?', 1058522: 'Bereznyaki', 4542084: 'Ponte San Pietro', 12378: '?', 12407: 'Romanovo', 10833: 'Lysva', 3383: '?', 20461: 'Girey', 5786: 'Muchkapsky', 11384: '?', 5422783: 'Markovsky', 5339: 'Kuyvozi', 1057646: 'Bolshoe Tolbino', 2946: 'Molodezhny', 1036554: 'Valaam', 12400: '?', 1114325: 'Atnashevo', 15057: 'Shikhazany', 1161182: '?', 1049748: 'Lev Tolstoy', 8194: 'Atazhukino', 1059192: 'Rakhmanovo', 11412: 'Mnogovershinny', 10116: '?', 2464: '?', 8911: '?', 16533: '?', 16957: '?', 12425: 'Tyubyak-Chekurcha', 1138486: 'Udarnik', 12777: 'Pervomayskoe', 1114504: 'Nizhnie Byurtli-Shigali', 8526: 'Mgachi', 16603: 'Altsynkhuta', 7484: 'Khomutovka', 16391: 'Asekeevo', 16476: 'Sarbay', 12442: '?', 1123025: 'Solton', 12159: '?', 12446: '?', 1703245: 'Lakeland', 3747: 'Gadyach', 12558: '?', 5267788: 'Lingen (Ems)', 1145365: 'Isilkul', 1049583: 'Krasnoe', 8273: 'Kent', 1513252: 'Gorodok', 12462: 'Zaysan', 1153783: 'Bestyakh', 5243451: 'Girona / Gerona', 6328: 'Mayskoe', 8890: '?', 4005: '?', 871: '?', 1966429: 'Gjøvik', 8771: 'Bolbasovo', 3219636: 'Kouvola', 2211374: 'Naxxar', 12408: 'Kotyrkol', 5059214: 'Hempstead', 7754: '?', 1958478: 'Akhaltsikhe', 1046694: 'Tervolovo', 1155999: 'Lobazikha', 1030539: 'Uchebnoe', 9517: 'Gan Shmuel', 5259542: 'Schkeuditz', 13333: 'Mstera', 12700: '?', 12701: '?', 19636: 'Bykov', 1006750: 'Yamansaz', 1915518: 'Okinawa', 5267837: 'Rotenburg an der Fulda', 1003195: 'Uemsky', 8493: 'Newark', 10233: 'Mayya', 13270: '?', 4731: '?', 15750: 'Slobodische', 12554: 'Im Stepana Razina', 1030260: 'Elnat', 10708: 'Gzhel', 12553: 'Northampton', 20465: 'Parfenyevo', 5609: '?', 11189: 'Trudovaya', 14383: 'Buena Vista', 1712334: '?', 4752: 'Krupki', 9181: '?', 1702016: 'Prirechenka', 12601: 'Kueda (poselok)', 3311467: 'Kilpilahti', 1515623: '?', 3586: 'Severomuysk', 3239: '?', 4176064: 'Smara', 3135299: 'En Nâqoûra', 3111312: 'Bunia', 3187492: 'Abiey', 5171856: 'Tarragona', 17269: 'Stary Chirchim', 8354: 'Simeiz', 1918118: '?', 1002781: 'Bukhalovo', 1010955: 'Krasnoe', 1010993: 'Rzhevka', 12580: 'Greenfield', 9627: 'Izyaslav', 1811: 'Kotelnikovo', 1913359: 'Dakar', 1711020: 'Maynooth', 12719: '?', 12606: '?', 22525: '?', 1702864: 'Gorodetskoe', 5166555: 'Castelldefels', 12641: '?', 1009252: 'Nureevo', 5266913: 'Freising', 3359: '?', 3980: 'Knoxville', 5056023: 'Spotswood', 1518380: 'Belovodskoe', 1100204: 'Emmaus', 4466: 'Achkhoy-Martan', 5367: '?', 1741: 'Chervonograd', 9305: '?', 13128: '?', 1110209: 'Staraya Bodya', 4229190: 'Warwick', 1948623: 'Leamington Spa', 308: 'Oxford', 18460: 'Poninka', 4303: 'Orlov', 1153489: 'Asyma', 1704748: 'Reston', 7872: '?', 3396380: 'La Gaulette', 1089182: 'Peresna', 3800799: 'Jinhua', 1081872: 'Kurgan (derevnya)', 1153791: 'Mokhsogollokh', 4499: 'Serebryanye Prudy', 1082185: 'Gorlovo', 1046141: 'Lembolovo', 1516623: '?', 5089: 'Zolotonosha', 14354: 'Nizhneangarsk', 1936080: 'Białystok', 12853: '?', 13958: 'North Conway', 1517279: 'Key West', 10319: 'Bolshaya Pustomerzha', 5264745: 'Oberteuringen', 18160: 'Pavlovo', 4437: 'Bedford', 1923946: 'Chittagong', 3053118: 'Zanjān', 12716: '?', 12717: '?', 12724: 'Hammerfest', 1901498: 'Arendal', 12714: 'Rostovka', 11579: 'Asaka', 544: '?', 1057119: 'Izmalkovo', 1907790: 'Playa del Carmen', 12720: 'Pola', 18754: 'Tselina', 12692: '?', 1711: 'Uman', 8503: '?', 12736: 'Smithtown', 4352: '?', 12661: '?', 13683: 'Kaindy', 1040881: 'Rodniki', 1055934: 'Vvedenskoe', 1900209: 'Lehavot Haviva', 12657: '?', 12750: 'Manassas', 7152: '?', 4027: '?', 553: '?', 12831: '?', 4940010: 'Minneapolis', 7187: '?', 20671: 'Sudzha', 5575: '?', 1516468: 'Brichany', 14128: 'Krasnogorovka', 12795: '?', 9594: 'Atbasar', 10576: 'Berezovo', 5266727: 'Oberkochen', 1971344: 'Welwyn Garden City', 5263511: 'Frankenthal (Pfalz)', 1159766: 'Leushi', 7588: '?', 1929512: '?', 9869: 'Dyatkovo', 11472: 'Koslan', 1905502: '?', 4807: '?', 13713: '?', 12532: 'Ivankov', 1065728: 'Ulyanovka', 1059584: 'Kurilovo', 12773: '?', 12807: 'Plungė', 1169: '?', 1707595: '?', 12806: 'Ksenyevka', 13272: 'Novaya Igirma', 8267: 'Cheremkhovo', 8077: 'Omsukchan', 12819: '?', 1957917: '?', 1943383: 'Kok-Yangak', 1926519: 'Montana', 10820: 'Topar', 1755: '?', 14404: 'Viktoropol', 2653: 'Nor Kharberd', 11078: '?', 11668: '?', 15481: 'Vorgashor', 5036081: 'Waltham', 1505929: 'Kagarlyk', 18746: 'Kaltan', 12839: 'Topolevo', 5056217: 'Washington', 14116: '?', 1118715: 'Veskovo', 1709828: '?', 12847: '?', 12850: 'Vasilyevo', 5266877: 'Friedrichshafen', 9857: 'Vladimirsky Lager', 1130683: 'Kalachigi', 11894: 'Koltsovo', 5395: '?', 12866: 'Kostopol', 3426: 'Drogichin', 10815: 'Batalnoe', 4573: '?', 3994824: 'Akita', 2832: 'Rovenki', 2862: 'Rodniki', 1803247: 'Rakvere (rakvere)', 21014: 'State College', 1517681: 'Parchim', 1964412: '?', 7472: 'Lucca', 1154397: 'Achit', 8767: 'Putilkovo', 7694: 'Kletnya', 16052: '?', 21871: 'Dovsk', 1027956: 'Kokhma (stantsia)', 15401: 'Bakhmach', 15400: 'Baturin', 2472: 'Savonlinna', 20758: 'Gardabani', 1046268: 'Vozrozhdenie (poselok)', 2237: '?', 12025: 'Vyartsilya', 14163: '?', 1128009: 'Karam', 4884359: 'Los Mochis', 21295: 'Gaydary', 13377: 'Bnei Brak', 14838: 'Kondratyevo', 15998: '?', 1919935: 'Schiller Park', 1159172: 'Razezd 101 Km', 1119473: 'Zheleznodorozhnaya Budka 220 Km', 1510267: 'Dolgovolya', 4243211: '?', 1974698: '?', 1914518: '?', 1948339: 'Cham', 4070: '?', 10619: 'Kiknur', 1519134: 'Katerinovka', 4289: '?', 6102: '?', 4568118: 'Brockhausen', 1515802: "Xi'an", 12982: 'Skvira', 2670: '?', 20708: 'Aktogay', 12990: '?', 13096: '?', 6351: '?', 16075: 'Floreshty', 3627: 'Chausy', 1923185: 'Comilla', 1923714: 'Dhaka', 13153: 'Zolskaya', 3385: '?', 3640: '?', 12960: '?', 3830160: 'Chinhae', 13008: '?', 5470315: 'Babushara', 13012: 'Volnovakha', 16054: 'Kukmor', 10111: 'Vishnevoe', 1902638: 'Haren (Ems)', 1911244: 'Meppen', 18325: 'Bolshaya Berestovitsa', 1518802: '?', 1004648: 'Khusainovo', 20791: '?', 20447: '?', 1517291: '?', 1519009: '?', 1516538: '?', 1516123: '?', 14877: 'Fort Collins', 1708512: 'Agarak (gorod)', 1732: '?', 6774: 'Almont', 1713043: '?', 1518527: '?', 1517592: 'Finnsnes', 5565: '?', 10110: '?', 5250: 'Kattakurgan', 7411: '?', 8635: 'Dunay', 13068: '?', 3153: '?', 1920363: 'University Park', 13075: '?', 5146: '?', 13079: 'Kletsk', 4560: '?', 17893: '?', 14369: 'Oktyabrsky', 6357: 'Bolshie Leushi', 4285152: 'Heythuysen', 16604: 'Ershovo', 209: 'Fedorovsky', 5266887: 'Ravensburg', 1025489: 'Talovaya', 1602415: 'Stankovo', 8478: 'Christchurch', 1516155: 'Paralimni', 3079092: 'Pyla', 1516203: 'Mission Viejo', 4854992: 'Huancayo', 14843: 'Tolsky Maydan', 22654: '?', 8353: 'Belozerskoe', 16327: '?', 5083633: 'Elkhorn', 4531732: 'Rånåsfoss', 1714688: '?', 16833: 'Parabel', 4373: '?', 13172: '?', 1406: 'Pyongyang', 1707598: 'Abasha', 1045754: 'Torosovo', 13832: 'Taximo', 6303: 'Kanevskaya', 1137037: 'Dubinino', 10362: 'Lyaskelya (poselok)', 8086: '?', 21984: 'Tankovoe', 1918491: 'Pasadena', 22147: 'Aktyubinsky', 1097067: 'Bolgar', 21512: 'Corbeil-Essonnes', 3488: 'Suvorov', 1037579: 'Vyatka', 1916021: 'Le Lavandou', 4240966: 'Bude', 4936: 'Yuzhny', 5487: 'Nerekhta', 1010310: '?', 13664: 'Biryuch (krasnogvardeyskoe)', 2722665: 'San Pedro', 1016131: 'Antushevo', 8398: 'Polessk', 1458: '?', 1024218: 'Shilovo', 13239: 'Berezovka', 2595: '?', 1025017: 'Petropavlovka', 1115839: 'Mytischi (derevnya)', 9295: 'Magdanly', 16844: '?', 1782: '?', 11650: '?', 1114474: 'Tyurlema', 22127: '?', 13556: 'Ratno', 21857: 'Verkhny Tagil', 1155191: 'Polovinny', 1127703: 'Vladimir (selo)', 20383: 'Kirillovskoe', 1710295: 'Jonava', 13287: '?', 5520: 'Seryshevo', 1156149: 'Dubrovina', 551: '?', 5130363: 'Victoria', 4993807: 'Arcadia', 1501458: 'Chernevtsy', 11908: '?', 1151736: 'Siva', 1144439: 'Moshkovo', 1919779: 'Rolla', 22050: 'Plano', 1928184: 'Unterach', 394: '?', 4013: 'Gorodische', 9788: 'Ilsky', 13336: '?', 13340: '?', 1514995: 'Varva', 2094: '?', 13357: '?', 13383: 'Yangel', 1089590: 'Chizhovka 2-Ya', 3879378: 'Zhongshan', 7324: 'North Wildwood', 3998: 'Serafimovsky', 14526: 'Duplyato-Maslovo', 9700: '?', 13367: 'Shamary', 13365: 'Nazarovka', 13366: 'Maryevka', 1136003: 'Novosibirsky', 1127125: 'Gavrilovskoe', 1010317: 'Malobykovo', 1519252: 'Hoofddorp', 6147: 'Krolevets', 5452: '?', 1709687: '?', 1929233: 'Gampaha', 21929: '?', 13374: '?', 1159552: 'Pervomayskoe', 19657: 'Peno', -9277: -9277, 9277: 'Sundsvall', 1046773: 'Domashovo', 14872: '?', 2144: 'Glusk', 1128780: 'Ruchey', 9643: 'Svetly Yar', 1907643: '?', 14547: 'Reshety', 1706082: '?', 1036120: 'Vidlitsa', 11931: 'Stary Krym', 5266907: 'Dachau', 1036119: 'Verkhovye', 13677: 'Turar Ryskulov', 1518006: '?', 3410: '?', 1803536: 'Monterey', 4688637: 'Pinar del Río', 3598: '?', 1912388: 'Abed', 13439: 'Kalikino (kantaurovsky S/s)', 5235738: 'Suresnes', 20963: 'Siegburg', 2512: 'Acton', 13444: 'Morzhegory', 1001091: 'Khetovo', 19857: 'Zhitkovo', 16492: 'Alexeevka', 14545: 'Vyezdnoe', 1505754: 'Trebukhov', 10647: 'Kakhun', 13461: 'Akhangaran', 1078537: 'Pervomayskoe', 4162: '?', 1147380: 'Kinzelka', 13479: 'Cluj-Napoca', 13480: 'Târgu Neamţ', 10354: '?', 5853: 'Stekolny', 1390: '?', 12415: 'Ardatov', 14672: 'Vacha', 1517927: 'Troy', 1912463: 'Ulsan', 1108923: 'Schekino', 4675: '?', 1517764: 'Yonkers', 19608: '?', 15198: 'Radchenko', 4216: 'Rylsk', 2382: 'Koblenz', 4917423: 'Murfreesboro', 1012795: 'Grozny (poselok)', 1707380: 'Aurora', 14580: 'Melnikovo', 5297: 'Shumikha', 10786: 'Murashi', 1132233: 'Oktyabrsky', 5043238: 'Washington', 1508: 'Bethesda', 1707364: 'Madras', 11105: '?', 3223: '?', 1314: '?', 1517133: 'Aurora', 1803236: 'Oru', 1516262: '?', 1957831: 'Palm Coast', 1901378: 'Nassau', 1057240: 'Skolkovo', 573: 'Chernobyl', 2498: '?', 3190: '?', 13516: '?', 16759: 'Pryazha', 4546128: 'Gorgonzola', 20044: 'Nitra', 1008291: 'Uchugan-Asanovo', 20978: 'Vale', 13524: 'Sirotinskaya', 6890: 'Krasnogvardeyskoe', 1514: '?', 12541: '?', 7143: '?', 13525: '?', 1113561: 'Sarafanovo', 14735: '?', 13538: '?', 1109720: 'Zavyalovo', 20654: 'Pinyug', 11551: 'Pochinok', 1137550: 'Ikovka', 1098349: 'Kuzhenkino', 20022: 'Pécs', 13561: 'Krasnorechenskoe', 1955945: '?', 4917709: 'Orlando', 3001: 'Herat', 1051039: 'Po Rechke Kupta', 1079139: 'V-Gruzinovo', 1500028: 'Dolinnoe', 1518494: 'Parkany', 21086: 'Wernigerode', 1081: 'Springfield', 4346: '?', 13579: 'Nizhny Kuranakh', 2723: 'Cupertino', 1930694: '?', 7339: 'Newport Beach', 5682: '?', 1056866: 'Stupino', 4440: 'Inza', 12028: 'Nazia (poselok)', 1101830: 'Mirny', 6607: '?', 9197: 'Khasyn', 1046801: 'Kingiseppsky', 2762: '?', 9631: '?', 1912978: '?', 13605: '?', 1906976: '?', 22075: 'Zholymbet', 13607: 'Baktybay', 1013640: 'Suzemka', 7420: '?', 13628: '?', 13625: '?', 13630: 'Klyastitsy', 10870: 'Komsomolsky', 3754715: 'Dumaguete', 12116: 'Chikola', 5076467: 'Saint Petersburg', 8157: 'Olenya Guba', 13639: 'Ilovaysk', 1814: '?', 1121899: 'Tourak', 18065: 'Mendeleevsk', 17810: 'Ephraim', 5086065: 'Sister Bay', 21005: 'Baileys Harbor', 2732: 'Pochep', 1011418: 'Uruchye', 1011420: 'Khmelevo', 1012979: 'Chekhovka', 2209344: 'Nyíregyháza', 10921: '?', 16488: 'Bolshoy Sabsk', 1001768: 'Churkino', 13674: '?', 3886: '?', 3188: '?', 2786: 'Appleton', 13592: 'Leiria', 10094: '?', 1500049: 'Skalistoe', 10646: 'Rechlin', 19246: 'Plotnikovo', 14008: '?', 1146976: 'Belyaevka', 10823: '?', 4375800: 'Fürstenberg/Havel', 8559: '?', 1152117: 'Berezniki', 4516825: 'Navarcles', 1026778: 'Kuybyshev', 1127405: 'Valdgeym', 1138789: 'Aleshkovo', 1082345: 'Kiritsy', 14730: 'Stavische', 1049271: 'Solidarnost', 1973095: '?', 1898: 'Staraya Ladoga', 1915945: 'Germersheim', 1034992: 'Voskresenskoe', 8067: '?', 13741: '?', 13743: 'Temizhbexkaya', 13746: 'Ust-Tarka', 18152: 'Savasleyka', 3031: 'Mukachevo', 1035570: 'Pushnoy', 13753: '?', 21476: 'Yavne', 4237540: 'Gotham', 13757: 'Dondukovskaya', 1518345: '?', 1915739: '?', 1518344: 'Zhamashuy', 5396329: 'Siggerud', 11684: '?', 1155687: 'Cheremukhovo', 1124305: 'Telemba', 12496: 'Luza', 1915582: 'Val Thorens', 5111136: 'Rockford', 13791: '?', 2722584: 'Pointe-à-Pitre', 1048832: 'Mirny', 1705363: 'Falkenberg/Elster', 14880: 'Beloglinny', 6564: '?', 16718: 'Ossora', 22470: 'Zakharovka / Frunzovka', 5326042: 'Cayenne', 12638: '?', 6785: '?', 13679: 'Argayash', 485: 'Paratunka', 11622: 'Krasnaya Gorbatka', 1091554: 'Obilnoe', 13788: 'Lebyazhye', 4923882: 'Montverde', 2601460: 'Ilūkste', 4361155: 'Kernen im Remstal', 13789: '?', 9221: '?', 6392: 'Durham', 1902839: 'Hopatcong', 1097068: 'Bolgar', 5699: 'Olympia', 1705113: '?', 14997: 'Metsamor (gorod)', 19482: '?', 11292: 'Purovsk', 13812: 'Volchansk', 1516957: '?', 1240: '?', 1500170: 'Zolotoe Pole', 5096134: 'Cañon City', 3813: '?', 6690: 'Ananyev', 5266427: 'Rüsselsheim', 13218: '?', 1706196: 'West Des Moines', 4258122: 'Lund', 1803163: 'Loksa', 1136112: 'Petropavlovka', 12502: 'Ebelyakh', 3820743: 'Bătdâmbâng', 4547: 'Shemonaikha', 16559: '?', 1141971: 'Pochinki', 13063: 'Nizhnyaya Salda', 13862: 'Littlestown', 13869: 'Bedyuk', 10564: 'Chuguevka', 7943: '?', 1516373: '?', 1517295: '?', 1009914: 'Grayvoron', 17199: 'Kopyevo', 14368: '?', 13879: '?', 1126005: 'Nerekhta', 13903: '?', 13904: '?', 10611: 'Ray (derevnya)', 2458: '?', 1159361: 'Garovka-2', 1113309: 'Sargazy', 9761: 'Tatarsk', 8858: 'Timonovo', 15397: 'Perechin', 10665: 'Konstantinovskoe', 490: '?', 1114106: 'Batyrevo', 1142150: 'Sukhobezvodnoe', 18196: '?', 13938: 'Kozhurla', 4998990: 'Pigeon Forge', 1146543: 'Nagibino', 14454: 'Zmeinogorsk', 1009915: 'Dobroe', 4938304: 'Abilene', 6813: '?', 9723: 'Semenovka', 1919773: 'Vancouver', 4300261: 'Birnbaum', 5127285: 'Mill Bay', 13968: 'Ozerki', 20802: '?', 1703641: '?', 4059425: 'Takoradi', 4744725: 'Tunja', 6057: '?', 20564: 'Barguzin', 5266218: 'Wesel', 4029: '?', 3189: '?', 5542: 'Kasli', 4648: 'Reshetikha', 1052841: 'Krasnoslobodsk', 1096796: 'Pestretsy', 2402: '?', 10569: '?', 1059096: 'Esipovo', 1518714: 'Peremetnoe', 3273: 'Chaplygin', 18146: 'Nor Achin', 3212795: 'Vihti', 3501502: 'Miāo', 1007095: 'Krasnokholmsky', 4072: 'Zarasai', 9021: '?', 6993: 'Rokitnoe', 6999: 'Zheshart', 20394: 'Zolotoe', 1020825: 'Gorodischna', 16538: 'Spas-Demensk', 1055624: 'Lesnoy', 6035: '?', 1926252: 'Belize City', 9014: 'Kizel', 3493267: 'Phuntsholing', 14028: '?', 3942: '?', 14021: '?', 4155: '?', 14038: 'Äänekoski', 3424571: 'Surat Thani', 3802: 'Yasny', 1500539: 'Koktebel', 257: '?', 1121756: 'Ust-Koxa', 21314: '?', 1711076: 'Brewster', 4967915: 'Oxford', 7685: '?', 1041447: 'Oktyabrsky', 1000955: 'Ryabovskaya', 1513962: 'Drabov', 14075: 'Tarascha', 14084: 'Goteshty', 14830: '?', 14100: 'Merefa', 3204: '?', 5029: 'Odoev', 12238: '?', 1126415: 'Pestenkino', 1914756: 'Apex', 1086418: 'Sovetsky', 4913001: 'Texas', 1138080: 'Tselinnoe', 773: '?', 14125: 'Krasnoe', 7955: '?', 22459: 'Tamchy', 1158654: 'Nygda', 4976182: '?', 1121803: 'Ynyrga', 14139: '?', 4650654: 'Guanambi', 1045819: 'Volkhov (poselok)', 1112204: 'Agapovka', 6096: 'Hyannis', 1502826: 'Kirillovka', 3361: '?', 1004137: 'Kapustin Yar', 2658: 'Ivdel', 3258558: 'Gulyantsi', 3025: '?', 1004400: 'Pushkino', 1512222: 'Stary Saltov', 8488: 'Pokrovsk / Krasnoarmeysk', 1132769: 'Torfyanoy', 1132597: 'Bystritsa', 1121583: 'Mayma', 4242: 'Zainsk', 2339: '?', 1943711: 'Beau Bassin', 20884: 'Karagayly', 2211225: 'Kirkuk', 3835676: 'Nirasaki', 1039666: 'Neya', 1511016: 'Yaroslavets', 14476: 'Spasskoe', 14182: 'Gostovsky', 1018691: 'Mirny', 9107: 'Kandry', 3985: 'Comrat', 1084928: 'Ershov', 13345: '?', 1970052: 'Iaşi', 1507911: 'Pustomyty', 14188: 'Podosinovets', 1133276: 'Schetkino', 7617: 'Blachly', 1082600: 'Yalta', 1906098: 'Bahia', 6568: '?', 5261758: 'Nörvenich', 14201: '?', 1790: 'Chernyanka', 4350: 'Istiklol (taboshar)', 17457: 'Mikhaylovka', 6957: '?', 5127178: 'Meaford', 6503: '?', 4347: 'Zharkent', 7408: 'Ross', 21645: 'Petrovka', 1161187: 'Zvenigorodka', 1514152: 'Katerinopol', 22486: 'Mostiska', 2769: 'Elkhart', 14279: 'Maromitsa', 14677: 'Kutulik', 10590: '?', 2617: '?', 1908813: 'Otaru', 17010: 'Nezlobnaya', 16083: 'Buraevo', 9344: 'Chinarly', 6861: '?', 1946740: 'Roosevelt', 1132142: 'Malmyzh', 1133155: 'Demyanovo', 5926: '?', 8505: 'Bydgoszcz', 9217: 'Mstislavl', 6825: 'Kadamdzhay', 21004: 'Asheville', 3424689: 'Amphoe Muang Phuket', 1025465: 'Novaya Chigla', 1112472: 'Mezhozerny', 6310: 'Troitskoe', 17849: 'Kugesi', 13400: 'Evsino', 1516431: 'Lepsy', 14287: '?', 1084207: 'Shentala', 1711457: 'Elmhurst', 5087841: 'Flagstaff', 19094: 'Pashia', 1153044: 'Khmylovka', 14300: 'Kizner', 4881: 'Gremyachinsk', 1007593: 'Yumaguzino', 1912460: 'Alessandria', 13268: '?', 7444: 'Zhmerinka', 5267067: 'Treuchtlingen', 1006033: 'Tashlykul', 12690: 'Buzdyak', 1704959: 'Vetka', 2722504: 'Side', 3047735: 'Erbil', 5267724: 'Kempten (Allgäu)', 4815: '?', 15253: 'Yusva', 4977749: 'Lindenwold', 1962051: 'Kragujevac', 5237350: 'Thionville', 1516925: '?', 5576: 'Vartemyagi', 1803157: 'Keila vald', 9842: 'Santa Cruz', 1032395: 'Mityaevo', 11661: '?', 5095237: 'Temecula', 2209993: 'Lake Elsinore', 9601: 'Zato Sibirsky', 1601666: 'Bronnoe', 1117506: 'Schelkovo (derevnya)', 11593: 'Rokosovo', 1095247: 'Malaya Buinka', 21406: '?', 12178: '?', 11474: '?', 6297: 'Andrianovo', 5370981: 'Lanzarote', 1161074: 'Andeg', 1706177: 'Oswestry', 20926: 'Tokmak', 1926960: 'Naknek', 17448: 'Kodiak', 1022299: 'Ustye', 14384: '?', 1976180: 'Székesfehérvár', 1153194: 'Kamen-Rybolov', 1966331: '?', 1965307: '?', 14387: 'Sargatskoe', 1005627: 'Kamenka', 5470540: 'Innopolis', 2179: 'Horki', 1083073: 'Yuzhny', 14416: 'Poltevo', 1083171: 'Dubovy Umet', 11140: '?', 5042569: 'Roseville', 12478: '?', 1038: '?', 14414: 'Aravan', 14432: 'Nurlino', 1154573: 'Sovkhozny', 12811: '?', 11307: 'Kunicha', 1057624: '1 Avtoparka', 1061561: 'Kresttsy', 8297: '?', 9035: 'Alexandrovsk', 1517048: '?', 1036945: 'Nibel', 1502911: 'Svyatogorovka', 21664: '?', 19011: '?', 8719: 'Buchach', 15000: 'Sarny', 236: '?', 1076808: 'Nalivayki', 1147573: 'Verkhnenovokutlumbetyevo', 1147577: 'Emelyanovka', 8045: 'Avdon', 1138795: 'Arapovo', 1928853: '?', 1978: '?', 10061: '?', 12887: 'Skopin', 1704345: '?', 1155610: 'Pyshma', 1057280: 'Chupryakovo', 8427: '?', 7723: 'Ballsh', 1705531: '?', 11611: '?', 14490: 'Igmas', 7350: 'Snovsk / Schors', 18578: 'Dzhangi-Dzher', 8268: '?', 2722528: 'Hamilton', 1704335: 'Commack', 5059174: 'Hauppauge', 1065038: 'Dolgoe', 5202: 'Krasny Bor', 1712307: 'Norrköping', 10389: 'Novy Razdol', 1607: '?', 19107: 'Gvardeyskoe', 3870: '?', 511: 'Migdal HaEmek', 1924794: 'Löningen', 5411: '?', 1703648: '?', 12392: 'Zhavoronki', 1041411: 'Sauk-Dere', 14521: 'Manas', 7068: 'Kupino', 19790: 'Shaturtorf', 1058353: 'Lidino', 21405: 'Fort Wayne', 4081: 'Orlovka', 14530: 'Ekaterinino', 5266664: 'Bietigheim-Bissingen', 13288: 'Belinsky', 1501548: 'Yampol', 3711563: 'Badung Regency', 9125: 'Tavricheskoe', 9254: 'Buinsk', 9203: 'Borovka', 1094675: 'Nizhnyaya Maktama', 1046128: 'Krasnaya Zvezda', 16952: 'Mechelen', 1155342: 'Druzhinino', 1122113: 'Zavyalovo', 14562: 'Svetloe', 1939234: 'Curepipe', 1007290: 'Karlaman', 3994: 'Ust-Bolsheretsk', 14558: '?', 1705924: 'Merseburg', 2109: '?', 14784: '?', 11532: 'Vanavara', 1707064: 'Surat', 2000020: 'Agdamkend', 8535: 'Shortandy', 1134989: 'Berezovka', 16470: 'Bolshaya Martynovka', 14583: '?', 5431126: 'Konyrat ', 1517417: 'Alcalá de Henares', 10834: '?', 1132484: 'Vostochny', 1045543: 'Beseda', 3971: '?', 1043482: 'Dichnya', 5217700: 'Corenc', 17488: 'Meschovsk', 14614: 'Grachevka', 1047571: 'Vagoshka', 10407: '?', 4828242: 'General Roca', 1953801: '?', 1901352: '?', 8790: 'Tauranga', 1703625: 'Dayton', 4981621: 'Yellow Springs', 3169: 'Karpinsk', 4885: 'Uzgen', 1519088: 'Portsmouth', 7861: 'Sredneuralsk', 1914859: 'Tjörn', 15622: 'Spijkenisse', 2887: 'Victoria', 20887: 'Shtormovoe', 10102: '?', 19313: '?', 6980: 'Zadonsk', 3198: 'Mezhdurechensky', 7074: 'Reni', 14665: 'Sinzig', 1703908: '?', 9361: 'Voskresenskoe', 1952381: 'Jakarta', 1008499: 'Tatyshly Verkhnie', 1008515: 'Yalgyz-Narat', 11654: 'Myadel', 6822: 'Konstantinovka', 1637: 'Nizhnesortymsky', 1046610: 'Nikolskoe (derevnya)', 1138477: 'Belichan', 11470: 'Irpen', 1516769: 'Ferrum', 1516768: 'Kent', 1517523: '?', 2703: '?', 3090469: 'Aleppo', 1127567: 'Mamakan', 6582: 'Chernushka', 1141712: 'Tumbotino', 3827909: 'Kongju', 5984: '?', 2203009: 'Tripoli', 1708119: 'Lake Placid', 14800: 'Saranac Lake', 1005002: 'Mustafino', 1150345: 'Bikbarda', 7162: '?', 10588: 'Sovetskaya', 6458: 'Cherny Otrog', 1950388: 'Bad Kreuznach', 66000: '?', 1042313: 'Konokovo', 1713646: '?', 1704828: 'Proctor', 5258969: 'Nohra', 1714552: 'Mimoň', 5828: 'Emva', 22181: 'Concord', 470: '?', 20320: 'Arkhipo-Osipovka', 1128752: 'Tubinsky', 8613: 'Kez', 1901921: '?', 4359299: 'Klingenbrunn', 1801998: 'Farmington Hills', 5040435: 'Ferndale', 1710743: 'Southfield', 21202: 'Mostar', 14126: '?', 17274: '?', 10271: 'Akhalsheni', 14739: 'Agirish', 1512887: 'Golaya Pristan', 1927324: 'Wetaskiwin', 15818: 'Staraya Kriusha', 10378: 'Degtyarsk', 14285: 'Liman', 3833256: 'Takaoka', 6356: 'Tsagan Aman', 14752: '?', 9610: 'Bershad', 4939739: '?', 9858: 'Lawrence', 10106: 'Glodyany', 1083663: 'Krasny Yar', 1516676: 'Vejle', 1920037: 'Kolding', 22140: 'Wolfsburg', 1078376: 'Kirovskaya', 740: '?', 4631: 'Tetovo', 2920: '?', 5911: '?', 1919045: 'Ocean View', 14727: 'Pervomaysk', 16580: 'Dmitrievka', 5466159: 'Yiwu', 1921952: 'Châtenay-Malabry', 5228191: 'Rocquencourt', 17573: 'Spirovo', 15561: 'Voznesenskoe', 5094582: 'Santa Barbara', 6146: '?', 3076774: 'Ardabīl', 3019: 'Lyalichi', 1125275: 'Sergeevo', 4017: 'Karasuk', 14841: 'Derazhnya', 5177: 'Mogilev-Podolsky', 2722654: 'Plymouth', 1713651: '?', 4619: 'Tovuz', 7325: '?', 1153139: 'Plastun', 7338: 'Karaulbazar', 1138041: 'Dudinka (derevnya)', 5267795: 'Voerde (Niederrhein)', 1901432: 'Macon', 4616837: 'Ponta Delgada', 1906485: '?', 1915921: 'Panama City', 17732: 'Novosemeykino', 14873: 'Zalukokoazhe', 5346: 'Binghamton', 1015252: 'Chervlenoe', 1152988: 'Vesely Yar', 1412: '?', 1712797: 'Kunming', 1517164: 'Gan Yavne', 1058709: 'Samotovino', 1161061: 'Sabetta', 1518896: '?', 1518083: '?', 15842: 'Oredezh', 10798: '?', 6493: 'Yukhnov', 1031831: 'Primanych', 5802: 'Kildinstroy', 1178: 'Guryevsk', 1080340: 'Gus-Zhelezny', 1011660: 'Star', 1060405: 'Laplandia', 1714294: '?', 1105304: 'Ryad', 16285: 'Zirgan', 17787: 'Kuschyovskaya', 1043851: 'Afanasyevo', 15507: 'Kokhany', 2268: '?', 1122478: 'Kurya', 1030460: 'Psynadakha', 14936: '?', 1515896: 'Nara', 4261: '?', 15231: 'Ivano-Slyusarevskoe', 18709: 'Chemal', 14956: '?', 8947: 'Kolychevo', 4641076: 'Vila Velha', 1704962: 'Szeged', 5261725: 'Mülheim an der Ruhr', 1908565: 'Kopitnari', 1503167: 'Nikolaevka', 4340454: 'Preetz', 7679: 'Tsvelodubovo', 1079523: 'Voloshino', 4277: 'Dekhkanabad (dekhkanabadsky Rayon)', 1512814: 'Verkhny Rogachik', 1959739: 'Phan Thiết', 1080: '?', 14155: '?', 1507282: 'Khoroshee', 12592: '?', 1014769: 'Katasonov', 1113721: 'Gudermes', 14262: 'Shirin', 8065: '?', 1712766: 'Geneva', 8556: 'Krasnoborsk', 5983: 'Cherevkovo', 17645: '?', 9311: '?', 1516636: '?', 15701: 'Vabkent', 6499: 'Coral Springs', 4546828: 'Fiesole', 1712200: 'Ho Chi Minh City', 15713: 'Dmitriev', 7699: 'Kara-Kul', 3992: 'Gubakha', 20651: 'Balykchy', 3840931: 'Beppu', 15097: 'Fauglia', 1923084: 'Pisa', 1054991: 'Leshkovo', 1713606: 'Sulyuktu', 1077815: 'Rassvet', 1041396: 'Novopokrovskoe', 1041853: 'Borodinskaya', 8101: 'Dubrovitsy', 1106768: 'Sosnovy', 6341: 'Kayrakkum', 5228142: 'Mantes-la-Ville', 15060: 'Svatovo', 4924413: 'Port Charlotte', 1086241: '?', 15089: 'Dovbysh', 15058: '?', 1046806: 'Kommunar (derevnya)', 9597: 'Karabash', 10711: '?', 1518319: '?', 1518446: '?', 15763: '?', 13188: 'Boiling Springs', 1706171: 'Yeghegnadzor', 1059402: 'Mescherino', 1937214: '?', 13004: 'Mizur ', 1105733: 'Tula-50', 5507: '?', 6381: 'Bolshoy Tsaryn', 1714060: '?', 783: '?', 15206: 'Beylagan', 12006: 'Gurdzhaani', 20407: '?', 1948856: 'Olsztyn', 4184: '?', 1704903: 'Langley', 1939838: 'Ridgewood', 1054329: 'Konstantinovo (gpz)', 1701588: 'Volodarskoe', 11720: '?', 1058391: 'Novovolkovo', 15813: '?', 21357: 'Issaquah', 16467: 'Filimonovo', 4625: 'Karazhal', 12912: 'Chesham', 21746: 'Novodnestrovsk', 5058: 'Leshukonskoe', 13555: 'Minkush', 15172: '?', 1900877: 'Nahalal', 5422011: 'Eniwa', 1938983: '?', 956: '?', 4873429: 'Zapopan', 1158309: 'Uspenka', 4983: 'Kushmurun', 15190: '?', 7331: 'Richmond Hill', 1930165: '?', 1068152: 'Kuznetsk-12', 15195: '?', 1091499: 'Mirnoe', 1704302: 'Sittard', 4693402: 'Ciego de Ávila', 1515748: 'Vysokoe', 9134: 'Lokot', 16960: 'Novogeorgievka', 4695500: 'Melrose', 20852: 'Davos', 5359605: 'Göttingen', 1917130: 'Burnaby', 5092950: 'Milpitas', 1078403: 'Likhovskoy', 9275: '?', 8298: '?', 1013970: 'Krym', 5307: '?', 15251: 'Carthage', 1052056: 'Ardatov', 4599: 'Dokuchaevsk', 15870: 'Suda', 15255: 'Duminichi', 1161237: '?', 20393: '?', 15257: 'Hagfors', 13684: 'Urechye', 9836: 'Naushki', 12262: 'Mogocha', 9130: 'Cherlak', 3215: '?', 12192: '?', 15267: 'Howell', 13891: 'Klyonovo', 1125527: 'Dobryatino', 1039896: 'Soligalich (stantsia)', 15460: 'Bielsko-Biała', 15276: 'Aratskoe', 15274: '?', 16838: 'Krasnogvardeyskoe', 1706526: '?', 5031180: 'South Park', 5094942: 'South Park', 1518483: '?', 18399: 'Lykhma', 15280: '?', 15326: 'Barabinsk', 1144707: 'Neudachino', 15330: '?', 15256: '?', 10624: '?', 2018: 'Pervomayskoe', 1155129: 'Elansky', 5929: 'Luostari', 13015: '?', 4545428: 'Lazise', 1515250: 'Nezhin', 196: 'Novomichurinsk', 20382: 'Teignmouth', 12443: 'Stockport', 1803167: 'Paldiski', 6192: 'Razdelnaya', 1803229: 'Haapsalu (khaapsalu)', 5259555: 'Markkleeberg', 6412: 'Manila', 5410452: 'Kirrwiller', 3309: 'New Acadia', 14996: 'Aschibulak', 8888: 'Mesyagutovo', 15327: 'Tavricheskoe', 17044: 'Tungor', 1008698: 'Podymalovo', 15331: 'Shelek', 1091556: 'Padinsky', 2205955: 'Wedemark', 1050753: 'Semenovka', 20175: 'Fedorovskoe', 1078985: 'Turilovka', 9292: 'Buturlinovka', 9328: 'Glubokoe', 15346: 'Dyugabul', 1021084: 'Kadnikov', 1124328: 'Zvezdny', 1156055: 'Elan', 1046096: 'Elizavetinka', 1061274: 'Veliky Zakhod', 3484: '?', 13221: '?', 1989: '?', 16043: 'Lokot', 13083: 'Krasnogorskoe', 3171: '?', 8734: 'Chutovo', 1122773: 'Pospelikha', 1902831: 'Hollywood', 1045775: 'Yablonitsy', 1133596: 'Ilinskoe', 1516321: '?', 9262: 'Bolshoe Kuzemkino', 1079818: 'Uglegorsky', 1066059: 'Zhilino', 4830: 'Truro', 1047354: 'Villozi', 5484: 'Acre', 15378: '?', 9333: 'Moshenskoe', 1037237: 'Kebanel', 9441: '?', 2722449: 'Asyut', 4397: 'Syamzha', 1129478: '?', 450: '?', 1900851: 'Tal-El', 1125132: 'Novovyazniki', 1348: '?', 4301: 'Nurak', 15408: 'Perleberg', 4302: 'Shangaly', 1136719: 'Teya', 1062973: 'Sergeevo', 15423: '?', 1153478: 'Sydybyl', 1071860: 'Pygi', 1160084: 'Tsagan-Oluy', 1046763: 'Vybye', 1124291: 'Tsagan-Usun', 11241: 'Vydropuzhsk', 1127: 'Dubrovno', 5266214: 'Kamp-Lintfort', 5105244: 'Shelley', 1078497: 'Verkhnesvechnikovo', 9457: '?', 10954: '?', 1517967: 'Tórshavn', 1960816: 'Milazzo', 19933: 'Sevsk', 1057124: 'Karinskoe', 1707251: 'Champaign', 21696: '?', 5888: 'Grigoropolisskaya', 21085: '?', 13186: 'Scherbinovsky', 1042375: 'Eyskoe Ukreplenie', 1144987: 'Chany', 1004289: 'Ninovka', 15455: 'Sheboygan', 1009520: 'Dubovoe', 1517653: '?', 4521281: 'Gondomar', 4372295: 'Großenhain', 15462: 'Sered’', 1030663: 'Kornevo', 1056152: 'Belaya Dacha', 1502742: 'Bakhmut / Artemovsk', 1918637: 'Valence', 18150: 'Urzhar', 2202761: 'North Providence', 5079010: 'East Providence', 1853: 'Cheltenham', 5267827: 'Gießen', 5606: 'Gunib', 1602329: 'Staroborisov', 9975: 'Dunay', 10868: '?', 1516369: '?', 1961522: 'Pangkor', 1123410: 'Charyshskoe', 15505: 'Tatarsky Klyuch', 4537133: 'Asker', 17095: 'Kazachinskoe', 15073: 'Ekaterinoslavka', 7449: '?', 3790413: 'Taizhou', 3788172: 'Wuxi', 10719: 'Nevyansk', 1948839: 'Ad Dammām', 1015381: 'Repino', 1708885: 'Toledo', 2392: 'Arzgir', 6183: '?', 1083851: 'Bestuzhevka', 11268: 'Kashpir', 3503831: 'Kota', 1046071: 'Borisova Griva', 13811: 'Usvyaty', 11328: '?', 15930: 'Bizhbulyak', 11686: 'Ureliki', 1517466: 'Burlingame', 1215: 'Ostafyevo', 1059797: 'Pleshkino', 864: '?', 3346881: 'Durban', 2286: 'Bangor', 2573: '?', 19083: '?', 15560: 'Grakhovo', 1160739: 'Lesnoy Gorodok', 16102: '?', 15612: '?', 1961247: 'Zweibrücken', 1713851: 'Oceanside', 1706204: 'Kunmadaras', 15588: 'Ivashka', 15589: '?', 21949: '?', 1966360: 'Takhiatash', 1005: 'Vozhega', 11279: 'Bolshaya Orlovka', 13123: 'Vani', 8079: '?', 5266329: 'Warburg', 1515635: 'Independence', 1709872: '?', 4914495: 'Burlington', 1962284: 'Burlington', 1515: 'Burlington', 1023: '?', 16197: '?', 1943824: 'Kiotoga', 1067: 'Miskolc', 1509614: 'Dikanka', 1616: '?', 18661: 'Ust-Kuyga', 3085801: 'Dar es Salaam', 13597: '?', 3087: 'Kadomka', 2208784: 'Nîmes', 1906139: 'Reims', 7525: '?', 1803385: 'Võru (vyru)', 1010251: 'Krasnoe', 15638: '?', 8153: 'Camerino', 3370575: 'Lahabe', 11452: '?', 21417: '?', 1929581: 'Madona', 20361: 'Obluchye', 14961: 'Strathmore', 1100383: 'Izoplit', 5264302: 'Baden-Baden', 16910: '?', 11240: '?', 13588: 'Potma', 21772: 'Vakhrushevo', 15669: '?', 8347: 'Aktash (dekhkanabadsky Rayon)', 14850: 'Krasnozerskoe', 14973: 'Kazalinsk', 1708371: 'Khyncheshty', 1078637: 'Komissarovka', 2436: '?', 1059683: 'Novogorsk', 15708: 'Tselinny', 15709: 'Itkulovo', 14539: 'Sorum', 8341: 'Kichmengsky Gorodok', 3485: '?', 2597: 'Emanzhelinka', 3451: 'Itatka', 16902: 'Asubulak', 1910904: 'Nurabad (nurabadsky Rayon)', 747: '?', 5025531: 'Grinnell', 20485: 'Vokhtoga (pgt)', 15227: '?', 15245: 'Sarala', 4377716: 'Fallingbostel', 3553: '?', 1086743: 'Ivanovo (derevnya)', 1904843: 'Sousse', 4310: 'Lyskovo', 4214: '?', 4012: 'Poltavskaya', 1942608: 'Kutná Hora', 21403: 'Glukhov', 9150: 'Peshawar', 10076: 'Kurskaya', 1965805: 'Burnsville', 15767: 'Verkhny Uslon', 22645: 'Kŭrdzhali', 1057936: 'Mogiltsy', 17568: '?', 15780: '?', 15874: '?', 15875: '?', 18338: 'Narynkol', 11881: 'Bogotol', 15939: 'Zmeyskaya', 1518488: 'Tikhinichi', 1042033: 'Kanelovskaya', 1123696: 'Sosnovy Bor (selo)', 1706385: 'Bad Honnef', 5471: '?', 20165: 'Arbazh', 15610: '?', 12421: '?', 15804: '?', 4798: 'Novolukoml', 12613: '?', 7716: '?', 5537: '?', 13504: 'Peschanokopskoe', 1965068: 'Kirovskoe', 12688: '?', 1903719: 'Morganville', 16869: 'Exeter', 3163090: 'Afyonkarahisar', 22020: '?', 8299: '?', 4370067: 'Haldensleben', 7606: 'Rudnya', 6049: 'Ladyzhin', 3547: '?', 1026609: 'Rutul', 15823: '?', 1047816: 'Skreblovo', 1969513: 'Neuwied', 1517835: '?', 3104: 'Chupa', 1914899: '?', 4636: '?', 1135372: 'Minino (poselok)', 13492: 'Chandigarh', 17314: 'Petrovskoe', 12810: 'Amga', 10804: '?', 15862: '?', 15863: '?', 18302: 'Khvalovo', 977: 'Tazovsky', 5238: 'Ust-Dzheguta', 1115196: 'Atlashevo', 14481: 'Dubrovka (pgt)', 17583: 'Fastov', 1032112: 'Vorotynsk', 9538: 'Starotitarovskaya', 8521: 'Furmanov', 15903: 'Kabanovo', 3312190: 'Vierumäki', 15887: '?', 1517261: 'Gera', 6947: 'Mezen', 1054812: 'Anosino', 4232593: 'Petersfield', 1715568: 'Agdzhabedi', 4540807: "San Damiano d'Asti", 1150910: 'Uralsky', 15912: '?', 1041036: 'Chaplygin', 15931: 'Turgenevo', 1112511: 'Nizhny Ufaley', 1062785: 'Okulovka', 9174: 'Antropovo', 11473: 'Anastasievskaya', 15919: '?', 1905282: 'Valmiera', 16029: '?', 11766: 'Medvezhi Ozera', 4372783: 'Greven', 2727: 'Efimovsky', 1061343: 'Knevitsy', 4926411: 'California', 1905850: 'Forte dei Marmi', 11988: 'Sergach', 1516180: 'Yeovil', 4857: 'Kingstown', 1954: '?', 12766: '?', 16011: '?', 1950057: 'Saint John', 11987: 'Belidzhi (pgt)', 4505171: 'Cieszyn', 1091527: 'Praskoveya', 5421602: 'Severny', 1042514: 'Glushkovo', 1009407: 'Alexeevka', 5843: '?', 1107002: 'Lvovo', 1908926: '?', 13208: '?', 4828: '?', 17620: '?', 1058547: 'Vozdvizhenskoe', 6: 'Chop', 11494: '?', 1037240: 'Klimovsk', 1518181: 'Nesher', 8536: 'Belaya Kholunitsa', 1121: '?', 1150993: 'Petropavlovsk', 1914370: '?', 1040900: 'Garbuzovaya Balka', 17933: '?', 16004: 'Guzar', 10217: 'Zhizhitsa', 1909923: '?', 15859: '?', 13594: 'Gritsovsky', 16014: 'Ismailly', 1006241: 'Mrakovo', 1011019: 'Alexeevka', 5604: 'Znamenka 1-Ya', 20024: 'Bucaramanga', 6099: 'Tunoshna', 1087489: 'Mitino', 1594: 'Knyaginino', 405: 'Kremennaya', 4026837: 'Saint-Louis', 1938820: 'Acapulco', 1960358: 'Pikesville', 1709443: 'Bel Air', 4611703: 'Huambo', 5344: '?', 1073838: 'Kachanovo', 1056769: 'Nazaryevo', 18461: 'Kachug', 16032: '?', 8636: '?', 12377: '?', 1084232: 'Kyakhta', 6692: '?', 12417: 'Kobralovo (poselok)', 6300: '?', 1129075: 'Inskoy', 3078814: 'Lucapa', 4182962: 'Batna', 3387: 'Vyshgorod', 1500045: 'Pochtovoe', 5266310: 'Gütersloh', 15414: 'Stendal', 1097237: 'Kuzkeevo', 6465: 'Gorokhovets', 15910: 'Aban', 10832: 'Isyangulovo', 1704506: 'Bereket', 16123: 'Allak', 7155: 'Yanino', 11529: 'Waco', 16098: '?', 5805: '?', 16099: '?', 1156994: 'Podgornoe', 16113: 'Varfolomeevka', 10187: 'Malino', 6031: 'Kalevala', 2266: '?', 1707016: '?', 1518000: '?', 5945: '?', 5259309: 'Rathenow', 2349: 'Biržai', 1900975: 'Nehalim', 16145: 'Ulyun', 6445: '?', 5033970: 'Brighton', 1927087: '?', 7683: 'Losevo', 1071701: 'Kolonitsy', 14633: 'Akyar', 1703318: 'Bradenton', 1010030: 'Popov Verkh', 14909: 'Chernomorskoe', 1132930: 'Orlov', 16178: '?', 1139921: 'Ilinogorsk', 1971292: '?', 1062716: 'Demikhovo', 16263: '?', 13838: 'Velikaya Novoselka', 3660: 'Rochester', 16192: '?', 17495: 'Yuma', 686: '?', 15920: 'Karabogaz', 16196: '?', 8666: '?', 4970324: 'Chapel Hill', 16334: '?', 16203: '?', 10205: 'Oktyabrsk', 2147: 'Vilyuysk', 1917826: 'Hillersleben', 1135360: 'Kedrovy ', 13924: '?', 18599: 'Papendrecht', 13111: '?', 16179: '?', 1502453: 'Boginevka / Braginovka (selo)', 1153654: 'Delgey', 16230: '?', 16231: '?', 1154729: 'Verkhoturye', 1008607: 'Subkhankulovo', 568: '?', 2320: '?', 1077664: 'Tserkovische', 1148376: 'Chernoyarovo', 1515991: '?', 4402: 'Primorsky', 20752: '?', 21365: 'Blagoveschensk', 1518632: 'Lake George', 22689: 'Cobleskill', 16471: 'Goreloe', 16710: 'Igodovo', 1369: '?', 16271: 'Krestyakh', 1509045: 'Ivanovka', 1157141: 'Turan', 16283: '?', 2075: '?', 777: '?', 1094589: 'Tatarstan', 2625: 'Pargolovo', 11054: 'Shieli', 11030: 'Medford', 12005: '?', 5329387: 'Herceg-Novi', 15247: 'Arti', 1709900: 'Brownsville', 11643: '?', 11675: 'Peleduy', 16305: '?', 16309: 'Den Helder', 14211: 'Lindsay', 16307: '?', 14883: 'Dundas', 7437: '?', 15052: '?', 11386: 'Arys', 21712: '?', 1518302: 'Macedo de Cavaleiros', 2680: '?', 1905858: 'Vedbæk', 1711987: '?', 8870: '?', 1841: '?', 1102561: 'Moskva (derevnya)', 3489: 'Karmaskaly', 1129744: 'Plotnikovo (derevnya)', 1516136: 'Parygino', 1014758: 'Burov', 12849: 'Bogorodskoe', 1078428: 'Gluboky', 16567: '?', 1714579: 'Münstermaifeld', 18371: 'Kormilovka', 6951: 'Bolshevik', 1948420: 'Siedlce', 1158668: 'Chukhlinskaya', 1502589: 'Solenoe', 16512: '?', 2537: '?', 16365: 'Little Rock', 16371: '?', 1112736: 'Izmaylovsky', 9251: 'Lenger', 10063: 'Kondol', 6578: 'Aygeovit', 1516382: '?', 11413: '?', 14064: '?', 15407: '?', 16389: 'Bolshie Alabukhi', 12356: 'Steyr', 1974697: 'Samtredia', 1933039: '?', 4243246: 'Wangen bei Olten', 12396: '?', 1052429: 'Achadovo', 1086685: 'Vyazma-Bryanskaya', 1009984: 'Istobnoe', 1927764: 'Ossendrecht', 16319: '?', 21887: 'Dribin', 1055606: 'Zarudnya', 1096926: 'Bogatye Saby', 1705915: 'Shnokh', 16405: 'Protichka', 1077829: 'Bagaevskaya', 1703631: '?', 1704785: '?', 1073317: 'Dubrovka', 16427: '?', 16429: 'Palmer', 2667: '?', 13988: 'Gashun Zh/d', 16437: 'Vladykinka', 3818: '?', 17906: 'Ilinsko-Podomskoe', 816: '?', 15717: 'Svir', 118: '?', 19177: 'Kirkland', 16454: '?', 21733: 'Ukrainsk', 99999999: '?', 1153011: 'Lozovy', -8723: -8723, 8723: 'Karlstad', 16457: 'Kultuk', 1959709: '?', 6605: '?', 4285632: 'Grubbenvorst', 4004: 'Vulkanny', 1129156: 'Ursk', 14041: 'Prokhorovka', 9337: 'Korzunovo', 20835: 'Bollnäs', 5935: 'Salo', 1068208: 'Kozlovka', 8142: 'Chuguev', 1915397: 'Zaragoza', 17385: 'Taezhny', 1012243: 'Stary Gorodok', 20581: '?', 21689: 'Dolinskaya', 2098: 'Vladimir-Volynsky', 1094322: 'Muslyumovo', 1096515: 'Muslyumovo', 1503086: 'Prechistovka', 11914: '?', 1936660: 'Murcia', 1704156: 'Vorontsevichi', 1704157: 'Kokhanovo', 16499: '?', 1516600: 'Yehud-Monosson', 12715: '?', 12566: '?', 1137089: 'Kaptyrevo', 1050441: 'Elasy', 14946: '?', 920: 'Tetyushi', 1712007: '?', 4800: 'Michurinskaya', 1924282: '?', 16525: '?', 16526: '?', 16527: '?', 17497: 'Bykovo', 16354: 'Stara Zagora', 1707265: 'Westpoint', 1516834: 'Olgino', 1500033: 'Krasny Mak', 10257: 'Chinyavoryk', 16554: 'Ambato', 16553: '?', 16558: '?', 7981: '?', 15645: '?', 4115: 'Cranbrook', 1015: '?', 5816: 'Amarillo', 2210103: 'Haugesund', 1506659: 'Novoukrainka', 4832119: 'Maitencillo', 12495: 'Ovruch', 1924771: '?', 16659: 'Telekhany', 1517169: 'Givat Ada', 6238: 'Volozhin', 1055785: 'Butovo', 12841: 'Derevyannoe', 15521: 'Tyulkubas', 1518843: '?', 9382: 'Or Akiva', 1127709: 'Irkutsk-45', 12338: 'Krechevitsy', 16607: 'Teramo', 21445: 'Utena', 1031350: 'Novostroevo', 1056937: 'Bolshoe Bunkovo', 1704432: '?', 1705806: 'Khudat', 17537: '?', 1093121: 'Chaschino', 16615: '?', 1705384: '?', 16618: '?', 3448: '?', 1031921: 'Priyutnoe', 16728: '?', 2300025: 'Moskva', 16166: 'Sasykoli', 1709229: 'Annandale', 1156470: 'Katayga', 10121: 'Pervomaysky', 1007687: 'Ermolaevo', 17562: 'Irbeyskoe', 1159101: 'Mukhen', 21266: 'Mezhevaya', 10790: '?', 3312: '?', 5132: '?', 3995: 'Povorino', 15214: '?', 21191: 'Brody', 1942588: 'Ishtykhan', 1057050: 'Axinino', 1055714: 'Angelovo', 22004: 'Kungrad', 1048521: 'Lyuban (poselok)', 1014943: 'Panfilovo', 1015449: 'Buratsky', 16671: 'Roshkany', 1707453: 'Bulboki', 13881: 'Naroch', 16672: '?', 9588: 'Olya', 4414: 'Likhoslavl', 3704628: '?', 6017: 'Razdolnoe', 6663: 'Besedino', 1005782: 'Blagovar', 13115: 'Ryzdvyany', 1139062: 'Bor', 5265526: 'Ansbach', 1146678: 'Borisovskoe', 1908261: '?', 16753: 'Bolshaya Rechka', 1154613: 'Baraba', 1129007: 'Koryaki', 19183: 'Morkiny Gory', 14320: 'Tolon (bakhsytskogo Naslega)', 1148158: 'Stepnoy', 16699: '?', 11052: 'Neuss', 16711: 'Novonukutsky', 1158805: 'Novolenino', 1003043: 'Vaskovo (poselok)', 5265425: 'Hof', 1058051: 'Dubki', 1138484: 'Nexikan ', 1054804: 'Agrogorodok', 16724: '?', 1004559: 'Solenoe Zaymische', 4243107: 'Zuzwil', 15395: 'Khokholsky', 14770: 'Kenger-Meneuz', 2701341: 'Jonava', 6573: '?', 16738: 'Askania-Nova', 16740: 'Otar', 1919652: 'Merrill', 1519067: 'Ciudad Juárez', 16311: 'Monrovia', 1703718: '?', 6230: 'Rovdino', 11076: 'Ust-Padenga', 2203756: 'Veliko Tŭrnovo', 16760: '?', 20550: 'Stolbtsy', 1153613: 'Khani', 1706754: 'Short Hills', 1973494: 'Berkeley Heights', 1037150: 'Vezhayka', 4239: '?', 1518869: 'Uchkuduk', 14396: '?', 18391: '?', 15362: 'Ileza', 1160704: 'Gorny-1 (chita-47)', 17958: 'Sorogozhskoe', 16964: 'Zubovo (sholsky S/s)', 10310: 'Pavlovsk', 1035222: 'Alexeevka', 1703572: 'Nahariya', 1384: '?', 8456: 'Kurilovo', 1704134: 'Sion', 7725: '?', 16313: '?', 16819: '?', 1802254: '?', 5266564: 'Bendorf', 11725: 'Volnogorsk', 1601763: 'Parichi', 1711771: 'Franklin', 11493: 'Poplar Bluff', 1515888: 'Ridderkerk', 2133: '?', 1517397: 'Gwangju', 16825: 'Olga', 5046931: 'Onamia', 16884: '?', 3960342: 'Alag Hötöliin Örtöö', 11546: 'Khatassy', 16857: '?', 16858: '?', 765: '?', 1041871: 'Priazovskaya', 1004461: 'Narimanov', 17782: 'Opechensky Posad', 1908754: 'Moon', 16874: 'Besharyk', 16133: 'Vodnobuerachnoe', 4140: '?', 16879: '?', 2601: '?', 1947383: 'Mubarek', 5266823: 'Furtwangen im Schwarzwald', 1153420: '?', 7435: '?', 1601205: 'Bragin', 21311: 'Zdolbunov', 1015075: 'Olkhovka', 15941: 'Kozulka', 9636: 'Zyryanka', 3274761: 'Bandırma', 1042341: 'Voronezhskaya', 1702996: 'Aktobe', 1517503: '?', 16934: 'Elatma', 5803: 'Temnikov', 16885: '?', 16912: '?', 16913: '?', 5729: 'Slavyanka', 5290: '?', 5860: '?', 15525: '?', 3937: '?', 1705783: '?', 5995: 'Ridgecrest', 1061949: 'Burga', 9578: '?', 1902605: 'Burlington', 16966: '?', 20604: 'Mirnoe', 5266243: 'Geilenkirchen', 6444: '?', 14044: '?', 18365: 'Kochubey', 18412: 'Mikhaylovka', 11681: 'Uporovo', 19632: 'Nezhinsky', 16257: '?', 16225: '?', 1613: '?', 3581: 'Kaushany', 16258: '?', 1085987: 'Lyubimovo', 1056743: 'Lyubanovo', 4613: '?', 1703839: 'Renton', 5546: '?', 1503249: 'Zuevka', 1015384: 'Srednyaya Akhtuba', 4189159: 'Cabo de Palos', 1092091: 'Stepnoe', 21501: '?', 1920051: 'Saint Clairsville', 17007: '?', 8624: 'Shurab', 1091522: 'Orlovka', 1703979: 'Pennington', 8397: '?', 12497: '?', 3805628: 'Foshan', 17025: '?', 17026: '?', 4740: 'Kfar Habad', 4328399: 'Straßbach', 5007861: 'Valley View', 3276467: 'Żukowice Stare', 1711975: 'Gainesville', 4984151: 'Thackerville', 5008196: 'Whitesboro', 5003501: 'Gainesville', 17033: '?', 17041: '?', 1037736: 'Safonovo', 1715161: 'Ogre', 1487: '?', 17196: '?', 1128967: 'Bolshoy Lug', 1148333: 'Uran', 5327141: 'Haniotis', 17048: '?', 7553: 'Malgobek', 17053: 'D/o Pleskovo', 6222: 'Tayshet', 4217: '?', 9732: 'Sursk', 1517848: 'Novokamenka', 20695: 'Bucha', 7307: '?', 8479: 'Chekhov', 1047362: 'Globitsy', 14670: '?', 1079301: 'Alexeevka', 17064: 'Mikhaylovskoe', 17472: 'Malye Derbety', 1042297: 'P/l Alye Parusa', 1053008: 'Romodanovo', 4335: '?', 1052347: 'Akcheevo', 1047583: 'Volodarskoe', 5600: 'Bolshoe Nagatkino', 1010438: 'Kozlovsky', 1517244: 'Bracknell', 1902739: 'Avarua', 1026807: 'Genekolob', 1803481: '?', 16715: 'Popasnaya', 1147279: 'Karaganda', 2108: '?', 1927265: '?', 1703185: 'Kumanovo', 5267208: 'Biberach an der Riß', 2309: '?', 17206: 'Ertil', 12555: '?', 11143: '?', 19179: 'Mamontovo', 17116: '?', 1036840: 'Kadzherom', 4640218: 'La Pedrera', 16626: 'Amankaragay', 4916497: 'Jonesboro', 3501: '?', 5611: '?', 1803156: 'Keila', 1035560: 'Mashozero', 11922: 'Nizhnedevitsk (selo)', 4375: 'Demidovo', 1136099: 'Marinino', 15061: 'Wageningen', 17140: 'Vratsa', 1091619: 'Burukshun', 4994: 'Reno', 3254: '?', 1133755: 'Yaroslavl (derevnya)', 5470320: 'Akhalkakhati', 22185: 'Kurakhovo', 16737: '?', 17068: 'Varenikovskaya', 1706317: 'Steinbach', 5022712: 'University Park', 1140986: 'Kovernino', 5897: '?', 1002248: 'Urdoma (selo)', 1060389: 'Ura-Guba', 1157996: 'Omutinskoe', 5261728: 'Solingen', 17019: 'Akron', 17198: 'Borodkino', 13582: 'Vichuga Staraya', 17036: 'Bolshaya Irba', 9055: '?', 1147813: 'Donguz', 1144826: 'Toguchin', 18523: 'Oktyabr', 17211: '?', 11659: 'Ust-Usa', 5751: 'Iskra', 10585: '?', 1095336: 'Kuralovo', 1055732: 'Ilinskoe', 1056939: 'Borovkovo', 22221: '?', 1515831: '?', 17252: '?', 1016073: 'Petukhovo', 1086217: 'Oktyabrskoe', 14700: 'Novoshakhtinsky', 17256: 'Ust-Muta', 7434: 'Talmenka', 1102795: 'Itomlya', 1059718: 'Venyukovo', 1136286: 'Razdolinsk', 1711092: 'Tualatin', 18665: 'Strelitsa', 6347: 'Katyuzhanka', 5266194: 'Erkrath', 1515879: '?', 5266198: 'Mettmann', 5266199: 'Ratingen', 1112140: 'Sakhalin', 8115: 'Lozovaya', 5464819: 'Povarovo', 12404: '?', 13099: 'Sudromskaya', 17306: '?', 4309: '?', 13463: 'Zhaltyr', 1003798: 'Svetly', 1518705: 'Zadar', 15591: 'Sadovoe', 1969599: 'Seinäjoki', 1052812: 'Semiley', 1902428: '?', 4690104: 'Las Tunas', 15616: '?', 17323: '?', 17268: '?', 1155187: 'Levikha', 1711586: 'Florissant', 20479: '?', 11080: 'Bulaevo', 17045: 'Chushevitsy', 4897078: 'Aguascalientes', 1703426: 'Poole', 20486: 'Druzhba', 5332051: '?', 1081753: 'Listvyanka', 17355: 'Bolshie Yalchiki', 20614: 'Saint Austell', 15855: 'Novaya Chara', 1712618: '?', 12564: 'Braunau am Inn', 17359: '?', 4075: 'Bobrovichi', 4134854: 'Franceville', 1117707: 'Sera', 17372: 'Chobruchi', 5259863: 'Neunkirchen', 1923506: '?', 1702223: 'Kenaral', 5400: '?', 1159209: 'Troitskoe', 17381: 'Springfield', 17382: '?', 17388: 'Mokrusha', 15615: 'Kortuz', 1918478: 'Parkville', 1136533: 'Partizanskoe', 11234: 'Sim', 14769: 'Sigaevo', 17317: '?', 6576: 'Rogovo', 13689: 'Tyamsha', 1926789: 'Woodinville', 1709486: 'Balkautsy', 6679: '?', 17277: '?', 9178: 'Chechersk', 11581: 'Kalinka', 17418: 'Yuzhno-Alexandrovka', 14394: 'Bar Harbor', 1124055: 'Erofey Pavlovich', 17692: 'Zmiev', 17615: 'Fort Krasnaya Gorka', 1116017: 'Veska', 17749: 'Yurkino', 1028500: 'Komsomolsk', 1161023: 'Gorki', 17451: '?', 17347: '?', 17867: '?', 1507379: 'Borislav', 14176: '?', 5422400: 'Yamanashi', 1918: 'Dnestrovsk', 1518708: 'New Britain', 5087186: 'Bristol', 1050330: 'Kabak-Sola', 5471672: 'Zhengning County', 13514: 'Nia', 17680: 'Vazhiny', 5326979: 'Chiang Mai', 1025722: 'Mugi', 5126214: 'Kingston', 2186: '?', 6533: '?', 4653581: 'Campinas', 2590: '?', 17830: 'Omchak', 3357: '?', 1707883: 'Curitiba', 1036930: 'Vis', 21845: '?', 12201: '?', 11528: '?', 17523: '?', 17540: '?', 10784: 'Taukent', 13300: 'Vozdvizhenka', 13915: 'Arkhonskaya', 4965750: 'Cleveland', 20565: 'Memphis', 18075: 'Kalininsk', 11273: 'Tkibuli', 17532: '?', 1040721: 'Pyatikhatki', 17533: '?', 11730: 'Novovelichkovskaya', 17535: '?', 2235: '?', 1066507: 'Kaluga (derevnya)', 19916: 'Golovinka', 7299: '?', 4555065: 'Ulcinj', 7599: '?', 3348: 'Gazalkent', 6051: 'Borzhomi', 1710165: '?', 1149524: 'Karagay', 14919: '?', 3079006: 'Oroklini', 4451: 'Pardes Hanna-Karkur', 1431: '?', 1935099: 'Krāslava', 1803153: 'Anija vald', 5475: '?', 1026781: 'Novodmitrievka', 20112: 'Reydovo', 1515777: 'Kiryat Ata', 9363: 'Alabaster', 4567941: 'Wettenberg', 8865: '?', 1024393: 'Mitrofanovka', 2203883: 'Sarajevo', 10064: '?', 17590: 'Irshava', 4542146: 'Pontecchio Polesine', 2722476: 'Trabzon', 1161321: '?', 3693: '?', 8047: '?', 17591: '?', 1058848: 'Novoklemovo', 4717254: 'Cerro Pedroso', 1159050: 'Vidnoe', 13535: 'Emelyanovo (gorsky S/o)', 3538061: 'Meiktila', 17691: '?', 10418: 'Compton', 1159368: 'Kazakevichevo', 1902238: 'Las Vegas', 5004731: 'Las Vegas', 4742: 'Lethbridge', 1081888: 'Sapozhok', 1105216: 'Krasny May', 1636: 'Yasinovataya', 1699: '?', 4336: '?', 5621: '?', 17637: '?', 17638: 'Zonalnoe', 1712915: '?', 1934113: '?', 17644: 'Usharbay', 1036524: 'Kamenny Bor', 1154107: 'Yablochnoe', 17674: 'Takhtamukay', 17647: 'Ermekeevo', 1143940: 'Kargat', 17656: 'Strelka', 1160710: 'Atamanovka', 17659: '?', 1703967: '?', 12774: '?', 10673: '?', 20318: 'Verbilki', 1042333: 'Uspensky', 1056999: 'Noginsk-5 ', 17600: 'Agoy', 11588: 'Vurnary', 18743: '?', 1912306: '?', 1601818: 'Pogranichny', 21387: '?', 19793: 'Karlskrona', 17686: '?', 1712262: 'Odessa', 2483: 'Severny', 1900411: 'Gadot', 1077706: 'Kayalsky', 1517123: '?', 2413: '?', 6400: 'Kalashnikovo', 1893: 'Hameln', 1506361: 'Sukhoy Tashlik', 7906: '?', 1507248: 'Chervonopartizansk', 3960181: 'Berkh', 10851: 'Choibalsan', 11526: '?', 17904: 'Tatsinskaya', 12989: '?', 1058329: 'Kozhino', 17731: '?', 17844: '?', 1519108: 'Zhelezinka', 1000046: 'Koshekhabl', 1040685: 'Kholmskaya', 1505711: 'Klavdievo-Tarasovo', 22710: 'Gifhorn', 17710: '?', 1004474: 'Rassvet', 1375: '?', 1170: '?', 17767: '?', 1058028: 'Vyalki', 2722592: 'Nuuk', 541: 'Kuragino', 1003411: 'Sovetsky', 1943525: 'Gulistan', 17897: 'Grushevka', 5254720: 'Mechouar Casablanca', 7586: '?', 1703418: 'Michalovce', 1053488: 'Saltykovka', 17785: 'Kitskany', 1000817: 'Cherny Ruchey', 4892991: '?', 19066: 'Pryamitsyno', 1924636: 'Naftalan', 2397: '?', 1053955: 'Gorki Rogachevskie', 1516713: 'Modena', 1711606: 'Fort Myers', 5982: 'Lesogorsky', 1132178: 'Savali', 9429: '?', 1084112: 'Kamenny Brod', 1959172: 'Laxenburg', 2281: '?', 11388: '?', 1053957: 'Gorki', 1083942: 'Sukhodol', 15036: 'Dorking', 12987: 'Kopyl', 5381: 'Msida', 3348910: 'Xai-Xai', 13142: 'Paisley', 21791: '?', 1095412: 'Borisoglebsk', 1512712: 'Berislav', 17870: 'Vostochny', 16961: 'Borisovsky', 16267: '?', 1901057: 'Binyamina', 3585: '?', 18036: '?', 10185: '?', 18035: '?', 1519153: '?', 1006421: 'Mulkat', 16224: '?', 1032799: 'Belousovo', 1707710: 'Northeim', 2493: '?', 1833: 'Shantobe', 1803195: 'Narva-Jõesuu (ust-Narva)', 3: '?', 17197: 'Aralsk', 17902: '?', 1097016: 'Kyzyl Bakcha', 17909: 'Rodina', 3589: 'Borisovka', 3825: '?', 1909759: '?', 1924743: 'Nordenham', 13523: '?', 5004418: 'Kilgore', 6402: '?', 9783: 'Platonovka', 11580: 'Banská Štiavnica', 18766: '?', 1963: 'Mödling', 1150988: 'Oktyabrsky ', 8049: 'Opolye', 1046275: 'Gavrilovo', 17930: '?', 4548398: 'Cecina', 18749: '?', 18279: 'Dyatlovo', 5094431: 'San Carlos', 4053: 'Veshkayma', 1515860: '?', 1705249: '?', 22575: '?', 1107021: 'Novolvovsk', 5674: 'Reshetnikovo', 6637: '?', 21423: '?', 17967: '?', 1657: '?', 999: '?', 22219: 'Matusov', 404: '?', 1513003: 'Dnepryany', 5031604: 'Westmont', 13843: 'Olovyannaya', 1122575: 'Malinovoe Ozero', 18002: 'Mirskoy', 1094535: 'Alexeevskoe', 1121493: 'Sakhyurta', 1153781: 'Ust-Yansk', 7096: 'Korocha', 18166: '?', 6706: '?', 9642: 'Novopokrovskaya', 1926291: '?', 1733: 'Serebryansk', 1051001: 'Lyusiner', 1108126: 'Chekalin', 2288: '?', 1059221: 'Solnechnogorsk-30', 5405: '?', 1500551: 'Dalekoe', 19492: 'Yuktali', 5522: '?', 1029800: 'Mosyakovo', 18058: 'Novotarmansky', 1044731: 'Litva', 1006137: 'Tangatarovo', 1500098: 'Azovskoe', 1500150: 'Tabachnoe', 4991732: 'North Charleston', 10291: 'Batken', 1951478: '?', 14067: 'Kameshkovo', 18017: '?', 1036501: 'Tambichozero', 1905962: '?', 1156880: 'Magadaevo', 9246: 'Haparanda', 18081: '?', 1515705: '?', 8050: '?', 1512403: 'Kolomak', 1057957: 'Klyazma', 1088401: 'Gusino', 1903097: 'Westborough', 6959: '?', 8108: '?', 11585: 'Brest', 1927732: 'Hsinchu', 1109695: 'Babino', 5264136: 'Mayen', 1916364: 'Bizerte', 5091526: 'Granite Bay', 1709216: 'Alvin', 22335: '?', 1957282: 'Karlovy Vary', 1703191: 'Eton', 1006145: 'Frunze', 5782: 'Smolino', 19744: 'Axuyek', 3752: 'Metz', 14083: 'Le Mans', 1909196: 'Muscat', 7814: 'Ola', 1058525: 'Bogorodskoe ', 1159288: 'Solnechny', 1121509: 'Tokchin', 8460: '?', 4283: 'Volnoe', 1326: 'Kokuy', 1964729: 'Elektrėnai', 18183: '?', 16707: 'Santa Fe', 1091505: 'Stavropolsky', 1505868: 'Novaya Alexandrovka', 18490: '?', 4636510: 'Stanley', 18042: '?', 1506852: 'Krasny Kut', 1158599: '?', 1709287: 'Simi Valley', 18428: 'Kamyshnya', 18080: '?', 1900117: 'Kaduri', 13249: 'Novosergievka', 1043492: 'Ivanino', 20007: 'Kutsurub', 1123368: 'Pobeda', 2211398: 'Bethlehem', 18010: '?', 10741: '?', 21373: '?', 1713022: 'Grayslake', 12927: '?', 18438: '?', 1936365: "L'Aquila", 4921579: 'Wilmington', 1714486: 'Dimitrovgrad', 18053: '?', 1510490: 'Mizoch', 18245: 'Ryazanskaya', 19240: '?', 4421: 'Purchase', 4967972: 'Pearl River', 18447: 'Alexikovsky', 20716: 'Yam-Tesovo', 18083: '?', 18251: '?', 1518171: '?', 1142043: 'Zhuzhelka', 1920333: 'Wokingham', 17210: 'Smuravyevo-2', 17937: 'Altayskoe', 10180: 'Kėdainiai', 18275: 'Vélez-Málaga', 3604: '?', 12697: '?', 1916170: '?', 1937556: '?', 5423715: 'Krikova', 17445: 'Lavry', 18003: '?', 2547: '?', 18286: 'Kapal', 14145: 'Regina', 9283: 'Yurya', 1704915: 'Portimão', 1705736: 'Anqing', 18099: '?', 9193: 'Shakhtersky', 21104: 'Greensburg', 1518095: '?', 1602635: 'Lebedevo', 21241: '?', 393: 'Stralsund', 1941819: 'Pervomaysky', 1512540: 'Lipkovatovka', 620: 'Verden (Aller)', 1705984: 'Nienburg/Weser', 1904832: 'Vallendar', 16942: 'Kochetok', 18313: 'Epsom', 8361: '?', 1067876: 'Pashkovo', 1907387: '?', 5006894: 'San Diego', 4696396: 'All Saints', 1713820: 'Provo', 4020825: 'Uíge', 1123674: 'Beregovoy', 5266800: 'Ettenheim', 18330: 'Parsippany', 1128730: 'Usolye 7-E', 1187: 'Ermolino', 1159678: 'Dzhirim', 18340: 'Cherepet', 1516758: 'Novara', 1136491: 'Snezhnogorsk', 18351: '?', 20268: 'Deventer', 18061: '?', 18090: 'Ulyanovo', 16796: 'Kamo', 1012261: 'Churovichi', 1956481: 'Pripyat', 2208168: 'Delray Beach', 1020880: 'Matveevo', 1056646: 'Vereya', 4477447: 'Milovice', 2997: 'Plymouth', 18140: '?', 1257: 'Kochenevo', 1064685: 'Verkhovye', 13277: 'Novozavidovsky', 1927731: '?', 1707002: '?', 1160119: 'Zabaykalsk', 18509: 'Voskresenskoe (oktyabrsky S/s)', 5086: 'Charentsavan', 9269: '?', 1508946: 'Sergeevka', 1015439: 'Kharkovka', 6134: '?', 4579: '?', 4287: '?', 1155676: 'Cheremisskoe', 19300: 'Yavan', 1958: '?', 8530: '?', 5791: '?', 1908371: '?', 2206525: '?', 1958969: 'Masally', 1800263: 'Volodeny', 1708474: 'Lipkany', 1708488: 'Springfield', 17078: 'Zaostrovye', 7349: 'Bereznik', 1281: '?', 2722625: 'Mindelo', 5259396: 'Neustrelitz', 18419: 'Gonokhovo', 5266849: 'Waldshut-Tiengen', 14728: '?', 1160023: 'Novy Akatuy', 10423: 'Newton Corner', 1920475: 'Nyon', 18427: 'Tsentralny', 18873: '?', 4993: 'Yuzha', 6693: '?', 18086: '?', 1047839: 'Torkovichi', 7147: 'Medvedevo', 2343: 'Mulhouse', 13902: 'Dejima', 1920656: 'Wilmington Beach', 4976948: 'Wilmington', 1054268: 'Svkh Ostankino', 18025: '?', 1061584: 'Novoe Rakhino', 1919222: 'Ranger', 6332: 'Pokrovka', 5266363: 'Witten', 18591: '?', 954: 'Marino', 18193: '?', 3138142: 'Al Khawr', 1952347: 'Słubice', 3963519: 'Jilin', 599: '?', 3024: 'Chistye Klyuchi', 1122529: 'Gornyak', 2400170: 'Dzhvarisa', 1006104: 'Lenin-Bulyak', 7421: 'Khvoyny', 1064270: 'Pokrovskoe', 1129019: 'Razdolny', 14525: '?', 11774: 'Cypress', 19541: '?', 13198: 'Kilmez', 19539: '?', 5612: 'Ust-Tsilma', 1060164: 'Sereda', 18504: '?', 4455626: 'Agen', 2294: '?', 18456: '?', 1954634: 'Maracay', 1157203: 'Chaa-Khol', 4686355: 'Varadero', 5266851: 'Metzingen', 1901652: '?', 1966566: '?', 1517273: 'Ilich', 12681: 'Dobrush', 1062635: 'Staroe Rakomo', 6101: '?', 10888: 'Shopokov', 1516404: 'Elsk', 13893: '?', 1600827: 'Borovka', 6547: 'Danilov', 8057: 'Edintsy', 18485: '?', 5366107: 'Dvůr Králové nad Labem', 1957463: 'Dvůr Králové nad Labem', 2202087: 'Cartagena', 18606: '?', 19286: '?', 19287: 'Ballymena', 1130328: 'Vanino', 18556: '?', 1516214: '?', 18857: '?', 905: '?', 20536: 'Ruem', 1051647: 'Ilpanur', 21100: '?', 18585: '?', 18586: 'Novodolinka', 10014: 'Gornouralsky', 6678: '?', 1099960: 'Nelidovo', 5266294: 'Ibbenbüren', 2927: '?', 3564: '?', 4339: '?', 6312: 'Sosnovets', 7428: '?', 3175: '?', 1009890: 'Stary', 15922: 'Kesova Gora', 1057075: 'Vniissok', 7186: '?', 1903968: '?', 1084276: 'Kamenka', 1952229: '?', 1161615: '?', 1055517: 'Spas-Zaulok', 9167: '?', 18625: '?', 15411: '?', 1511418: 'Turilchye', 12157: 'Kotovo', 10941: '?', 5095794: 'Whittier', 14349: 'Kfar Hasidim Alef', 1903324: 'Heinola', 1966094: 'Ponte in Valtellina', 20570: 'Sondrio', 2300827: 'Hämeenlinna', 1111834: 'Silikatny', 1036640: 'Sherdino', 1130634: 'Rudnichny', 5470068: 'Manzhouli', 1513127: 'Stroganovka', 4331819: 'Seelbach', 5266482: 'Herborn', 16586: 'Highland Park', 1060333: 'Luvenga', 7653: 'Pernik', 6836: 'Komarovo', 10785: 'Ferney-Voltaire', 18498: '?', 18684: '?', 19931: 'Saint Paul', 5055444: 'Monmouth Junction', 18687: 'East Brunswick', 10631: 'Vostok', 7975: '?', 18690: '?', 5262970: 'Stockum-Püschen', 5227239: 'Ville-la-Grand', 1126928: 'Golovino', 1063597: 'Bolshie Bory', 13786: 'Nurabad (akhangaransky Rayon)', 3807245: 'Dengfeng', 18701: 'Gulyaevka', 1958871: 'Łeknica', 2115: 'Shumilino', 4570: '?', 17780: '?', 6504: '?', 1714227: 'Westfield', 18716: '?', 2203080: 'Atsugi', 2426: '?', 18718: '?', 19378: '?', 1705151: 'Tsalka', 14389: 'Chaplinka', 17059: 'Wiener Neustadt', 18785: '?', 1024402: 'Pasekovo', 1092653: 'Kochetovka', 1954848: 'Böblingen', 1134821: 'Petropavlovka', 1347: '?', 5274: '?', 19893: 'Petrov Val', 4963: 'Svecha', 12936: '?', 1941192: 'Pôrto Alegre', 2204: '?', 4154: 'Borodinskoe', 4816: '?', 1069315: 'Ostrov', 6391: 'Nikolo-Poloma (poselok)', 1049719: 'Shovskoe', 14834: 'Kedrovka', 18782: 'Chernyshevsk', 7515: 'Opytny', 20709: 'Alupka', 10593: 'Izhma', 13870: 'Obyachevo', 18793: 'Gornorechensky', 4421828: 'Luzy', 930: '?', 1519188: 'Hercules', 4574: 'Zaozerny', 4950: '?', 5720: 'Yukamenskoe', 1053764: 'Chismena', 1900939: "Ma'agan Mihael", 18802: 'Prosvet', 3322794: 'Mufulira', 18808: 'Bidzhan', 9132: 'Mirny', 18810: 'Novokursk', 5435: 'Budogosch', 10689: 'Kara-Zhygach', 1113767: 'Znamenskoe', 18817: '?', 1904368: 'Parma', 1156360: 'Ust-Port', 18876: '?', 13961: 'Portland', 7747: 'Zhanaozen', 1002451: 'Kstovo', 1084312: 'Repino', 13665: 'Zerenda', 2400677: 'Tsinubani', 5266301: 'Beckum', 1707736: '?', 1152803: 'Gornye Klyuchi', 4236261: 'Hyde', 1907213: 'Segovia', 3761011: 'Buenavista', 1108875: 'Sovetsk', 18758: '?', 18853: '?', 1149302: 'Ilinsky', 1704204: 'Kópavogur', 4961503: 'Florida', 18871: 'Ben Shemen', 8321: '?', 19958: 'Sharanga', 8130: 'Darovskoy', 18899: 'Reshetilovka', 1705796: 'Karpineny', 18882: '?', 1110651: 'Selty', 1064573: 'Pavlodar', 6807: '?', 20755: 'Vatutino', 5431128: 'Sayak ', 1517380: 'Druzhba', 2701: '?', 8106: 'Raos', 18943: 'Adischevo', 12828: 'Churovskoe', 4189623: 'Arona', 8335: 'Monastyrschina', 10062: 'Kōbe', 7775: '?', 1239: 'Novaya Vilga', 5122912: 'Bradford West Gwillimbury', 18938: 'Mashevka', 6670: 'Koporye (selo)', 11628: '?', 1009154: 'Penza', 3424624: 'Pran Buri', 5431910: 'Poroslyany', 14690: 'Woking', 1939932: 'Rocky Hill', 1086051: 'Svetly', 7306: '?', 18973: '?', 18971: '?', 2101929: 'Jultushgan', 19413: 'Larba', 1928505: 'South Amboy', 20719: '?', 1517012: '?', 4195: '?', 7446: 'Umba', 1911678: 'Northridge', 17152: '?', 19507: 'Marlborough', 12619: 'Sherborne', 1517408: 'Almazar (chinazsky Rayon)', 1018087: 'Marfino', 8966: 'Allakh-Yun', 19945: 'Lyangasovo', 1706274: '?', 4838: 'Kataysk', 1140622: 'Strochkovo (kumokhinsky S/s)', 1153287: 'Monastyrische', 21989: '?', 1920601: 'Fürstenwalde/Spree', 19034: '?', 1703985: 'Brentwood', 9765: 'Tuzla', 22332: '?', 1915864: 'Breskens', 4286240: 'Eede', 1932976: 'Halsteren', 4369878: 'Hamm', 19051: '?', 19036: '?', 5266417: 'Griesheim', 19165: 'Yanshikhovo-Norvashi', 18809: 'Yubileyny', 5296: '?', 1705114: '?', 1703661: 'Oegstgeest', 19134: '?', 1161426: 'Solonitsevka', 19049: '?', 1005472: 'Novobelokatay', 9308: 'Mena', 8073: 'Morino', 2211883: '?', 1710001: 'Chesapeake', 21737: 'Kuusamo', 4008559: 'Wanaka', 1010966: 'Murom', 1048195: 'Novoselye', 1923435: '?', 19195: 'Nekrasovsky', 3960046: 'Darkhan', 1929380: '?', 5687: '?', 21836: 'Sunderland', 4198574: 'Kenitra', 12147: 'Folkestone', 20890: '?', 1710473: '?', 12988: 'Polazna', 1946291: '?', 2725: 'Kirkenes', 1905192: '?', 18964: 'Zasimovichi', 1159000: 'Toki', 1554: '?', 1912312: 'Uherské Hradiště', 1908652: '?', 1082055: 'Aleshino', 1907078: 'Pula', 1071252: 'Valuevskoe', 4924014: 'North Fort Myers', 11497: '?', 1155877: 'Dvurechensk', 1159862: 'Talinka', 5266377: 'Iserlohn', 5047953: '?', 17107: '?', 19166: '?', 7453: '?', 1015315: 'Serafimovich', 8800: '?', 1705324: 'Denia', 1704246: 'East Rochester', 19192: '?', 1909596: '?', 1512745: 'Belozerka', 14658: '?', 1035210: 'Khvastovichi', 3474: 'Baley', 13472: '?', 1930548: 'Jēkabpils', 1948240: 'Tukums', 1129054: 'Klyuchi-1', 19197: 'Olenino', 1068153: 'Kuznetsk-8', 1137256: 'Barnaul (derevnya)', 7319: 'Novaya Shulba', 19208: '?', 4935840: 'Augusta', 21240: 'Augusta', 2303: '?', 1125524: 'Demidovo', 6986: 'Aramil', 3419: '?', 1152977: 'Pokrovka', 22477: 'Molodogvardeysk', 1060416: 'Luostari Verkhnee', 19807: '?', 10659: '?', 1138528: 'Spornoe', 19235: 'Irgeli', 1602406: 'Petkovichi', 19237: '?', 1927509: 'Hallandale Beach', 1057443: 'Kabanovo (gorsky S/o)', 3118: '?', 3590: '?', 19241: '?', 1701014: 'Dossor', 1801859: 'Farnborough', 13967: 'Novaya Khrubna', 18120: 'Tedzhen', 11878: '?', 21068: 'Kirovsk', 19250: 'Unal', 9078: 'Moultonborough', 1155346: 'Klenovskoe', 18386: '?', 3787755: 'Zhuhai', 19270: 'Khatazhukay', 3255398: 'Sopot', 4058092: 'Akafou Kofi', 1518154: '?', 1054167: 'Rybnoe', 1040645: 'Shekshema', 19271: 'Podstepnoe', 7676: '?', 1512325: 'Taranovka', 14768: 'Bagramyan', 11697: 'Denau', 1904713: 'Foster City', 21768: '?', 1713329: 'Aurora', 1504545: 'Skelki', 4617214: 'Stepney', 1903360: '?', 20624: 'Novotsurukhaytuy', 9727: 'Talas', 16310: 'Igrim', 3670: 'Andra', 1135086: 'Bogotol', 14468: '?', 21185: 'Kiryat Shmona', 4954: '?', 1948880: 'Lannion', 4624: '?', 1100960: 'Monakovo', 8099: 'Baykov', 19327: '?', 1025860: 'Atlanaul', 20828: '?', 2205187: '?', 1705879: '?', 1802152: 'West Long Branch', 15470: 'Fontainebleau', 13000: 'Romny', 14674: 'Visby', 19332: '?', 2484: '?', 6922: '?', 4483: '?', 9595: 'Pravokhettinsky', 19369: '?', 6789: '?', 19373: 'Middletown', 1293: 'Tkvarcheli', 1966470: '?', 13754: '?', 1074595: 'Orekhovno', 1123203: 'Zavodskoe', 1516384: '?', 21056: '?', 1136636: 'Rybnoe', 1136220: 'Znamenka', 14644: 'Ermakovskoe', 1046499: 'Vekkelevo', 1713854: '?', 1048069: '?', 1507023: 'Lutugino', 19427: '?', 12865: '?', 1970830: 'Artik', 18390: '?', 1091544: 'Georgievskaya', 4222334: 'Skårup', 1929121: 'Skurup', 13913: 'Pokrovskoe', 7767: 'Barsovo', 14296: 'Bolshevo', 5357627: 'Gronau (Westfalen)', 5266742: 'Rastatt', 1935775: 'Dranda', 1927068: '?', 19400: '?', 15443: 'Saseny', 19487: 'Sazonovo', 1517044: '?', 20573: 'Dornod Province', 4337: '?', 1015200: 'Ilmen', 1705441: '?', 3386: '?', 15335: '?', 1011314: 'Suponevo', 19551: 'New Castle', 19201: '?', 4952212: 'Catonsville', 18614: 'Velikaya Pisarevka', 1020250: 'Nakhodka (poselok)', 6094: '?', 11422: 'Bolsherechye', 17828: 'Niagara Falls', 1803688: '?', 1929301: 'Hillsborough', 1920444: 'Brocēni', 1803584: 'Huntsville', 19452: '?', 1515647: '?', 19453: '?', 4674351: 'San Juan del Río', 1107392: 'Barsuki', 1062615: 'Savino', 14059: '?', 20452: 'Ust-Belaya', 7459: '?', 371: '?', 4530458: 'Sørumsand', 19263: '?', 19261: '?', 21316: 'Taypak', 19477: '?', 9099: '?', 1900696: 'Beit Alfa', 1712884: '?', 4989268: 'Carolina', 14636: '?', 19486: 'Staraya Toropa', 1159136: 'Kherpuchi', 1120: 'Valdosta', 1084469: 'Marfino', 1931336: 'Formia', 1715684: '?', 1900147: 'Alonei Yitzhak', 10860: 'Zvenigovo', 4912681: '?', 1899: '?', 4379: '?', 1803185: 'Illuka', 1925047: 'Old Bridge', 13056: '?', 1935278: 'Milledgeville', 1518638: 'Lynchburg', 7193: 'Dzharkurgan', 19526: 'Novaya Kachemka', 22384: '?', 1516170: '?', 1070747: 'Chernobozhye', 14901: 'Dalnee Konstantinovo', 1042101: 'Za Rodinu', 5166678: 'Sabadell', 5589: 'Shali', 19546: '?', 18143: 'Srednekolymsk', 2777: '?', 1004282: 'Ikryanoe', 1712625: 'Peine', 1918202: 'Salzgitter', 2836: '?', 19565: 'São João do Estoril', 5094535: 'San Ramon', 19586: '?', 19860: '?', 20229: 'Bagdati', 1971038: '?', 1154808: 'Gari', 19591: '?', 19592: '?', 5094511: 'San Mateo', 5329573: 'Ruka (Rukatunturi)', 1502886: 'Novgorodskoe', 12587: '?', 20533: '?', 19629: '?', 1135418: 'Elita', 19819: '?', 1920393: 'Valdivia', 1149235: 'Suganka', 19510: '?', 4736731: 'Santo Domingo de los Colorados', 9158: 'Vadinsk', 22239: '?', 1904081: 'Garni', 9701: 'Vygonichi (selo)', 17365: 'Korenevo', 19702: 'Krasnoe', 19642: 'Kumordino', 19645: 'Mednoe', 1053407: 'Medaevo', 5128613: 'Richmond', 17290: 'Vityazevo', 1032842: 'Protva', 1161178: 'Chapaevka', 21745: '?', 1905432: '?', 1946920: '?', 16397: '?', 1129329: 'Krasnobrodsky ', 19665: '?', 19674: '?', 19675: 'Chojna', 19672: '?', 1018560: 'Belousovo', 18268: 'Beloozersk', 1161145: 'Zagoryansky', 19695: 'Geraneny', 3134: '?', 8294: '?', 20464: 'Kennesaw', 11626: 'Dashtabad', 1138745: 'Gidrotorf', 1138730: '1 Maya (bolshoe Kozino)', 2722458: 'Mersin', 1703856: 'Maryland City', 9232: '?', 1047962: 'Svir', 5287: 'Ust-Talovka', 1934027: '?', 16036: '?', 21138: '?', 5332773: '?', 4912: '?', 1129071: 'Bachatsky', 3174: 'Chinaz', 11387: '?', 15885: 'Kolpna', 9028: '?', 2341: '?', -125: -125, 14204: 'Mirny', 6376: '?', 2919: '?', 1785: 'Birmingham', 19753: '?', 21446: '?', 1515584: 'Nizhnegorsky', 1514851: 'Storozhinets', 19768: 'Rödermark', 1900146: 'Kfar Hananiya', 17819: 'Leovo', 18382: 'Zhitikara', 1084264: 'Alexandrovskaya (pushkinsky R-N)', 1096783: 'Lenino-Kokushkino', 1203: '?', 4887135: 'La Huerta', 1093411: 'Pervomaysky', 1101526: 'Fabrika', 20471: '?', 21490: '?', 1110757: 'Kungur', 1135352: 'Emelyanovo', 5423706: 'Gratieshty', 1156321: 'Staroutkinsk', 14803: 'Świętoszów', 1701934: 'Krasnaya Polyana', 4476409: 'Nové Hrady', 10722: 'Ledmozero', 1041519: 'Pervomaysky (khutor)', 1013470: 'Desyatukha', 4244397: 'Nendaz', 20305: '?', 5063474: '?', 1514553: 'Vizhnitsa', 19779: '?', 1708564: 'Aylesbury', 19892: 'Ferrol', 1715622: 'Sadovoe', 5781: '?', 1665: '?', 1041247: 'Krasnodarsky', 17257: 'Kichera', 1923615: '?', 1103911: 'Spirovo', 19761: '?', 1902421: 'Rukla', 4134: '?', 1703981: '?', 10286: 'Chuchkovo', 12862: 'Kasumkent', 9928: 'Lyubim', 18961: '?', 3795: '?', 1521: '?', 1931564: 'Halden', 14254: 'Verkhnedneprovsk', 5577: '?', 9322: 'Primalkinskoe', 4908810: 'Detroit', 19979: 'Mindyak', 1927596: '?', 1704456: 'Castelo Branco', 19964: 'Mospino', 1084334: 'Alexandrov Gai', 19973: '?', 1123124: 'Togul', 20333: '?', 10725: '?', 13874: 'Aryktakh', 19986: '?', 1517185: 'Gdynia', 19991: '?', 19987: 'Karsovay', 1111899: 'Staraya Mayna', 8314: 'Verkhneyarkeevo', 17931: 'Shalya', 20030: 'Kalocsa', 8379: 'Opole', 13362: 'Uzynagash', 19965: '?', 1706559: '?', 1128382: 'Nerkha', 16872: 'Bestuzhevo', 1146317: 'Sedelnikovo', 18565: '?', 1131407: 'Prosnitsa', 6987: '?', 1113643: 'Argun', 9017: 'Novoyavorovsk', 1708139: 'Armavir', 1519139: 'Ada', 2782: 'Abuja', 14401: 'Goris', 12812: 'Alexandrovskoe', 6460: 'Fairmount', 7672: 'Claremont', 11723: 'Konstantinovskaya', 4456099: 'Port Erin', 1502815: 'Vladimirovka', 4952016: 'California', 20066: 'Elan-Kolenovsky', 5266867: 'Albstadt', 1946732: '?', 1704236: 'Santander', 1515949: '?', 1060268: 'Novaya Sloboda', 1030026: 'Kitovo', 1713421: '?', 20074: 'Volno-Nadezhdinskoe', 20789: '?', 20089: '?', 1091755: 'Krasnogvardeyskoe', 18388: 'Little Malvern', 2722583: 'Basse-Terre', 5830: 'Tucson', 11726: 'Lokosovo', 3843: 'Krivandino', 1030733: 'Primorsk', 19679: 'Fastovetskaya', 13201: 'Tolbazy', 17096: 'Makaryev', 20123: '?', 1008020: 'Kirgiz-Miaki', 2606: '?', 1936715: 'Browns Mills', 1963367: '?', 17371: 'Tugolessky Bor', 2430: '?', 1060367: 'Murmashi-3', 1513046: 'Novotroitskoe', 5512: 'Asino', 10876: 'Dagestanskie Ogni', 1027054: 'Kharakhi', 1011302: 'Seltso', 1960015: 'Kingston upon Hull', 15718: 'Voznesenskaya', 1918725: 'Khoni', 1081355: 'Denisovo', 1706836: '?', 22414: '?', 1706839: '?', 567: 'Hayward', 1515839: 'Ludwigslust', 10437: '?', 20177: '?', 7012: '?', 17517: 'Bari', 20200: 'Ilya-Vysokovo', 1049269: 'Klyuch Zhizni', 11674: '?', 5266880: 'Tettnang', 2707325: 'Vilnius (Kupiškis)', 13792: '?', 21508: 'Ness Ziona', 11073: 'Chortkov', 4660871: 'Negril', 19333: '?', 20433: '?', 1007230: 'Uryush-Bitullino', 17200: 'Bobrov', 20244: 'Nosovka', 2722588: 'Puerto Cortés', 1017304: 'Shelota', 1920186: 'Ak-Suu', 4778: '?', 10523: '?', 19823: '?', 2203026: 'Rinteln', 20252: 'Dorogino', 4098: '?', 12779: 'Smolyaninovo', 11172: 'Klyazminsky Gorodok', 5003399: 'Fort Worth', 1065: '?', 13330: 'Ogun State', 20275: 'Mikhaylovsk', 1516599: '?', 20277: 'Ilino', 1085615: 'Zavolzhsky', 1500006: 'Izobilnoe', 7674: 'Trzebień', 1160: '?', 15136: 'Zelenchuk', 20761: 'Shishaki', 3791: 'Dafna', 3148082: '?', 6702: 'Gaz-Sale', 1309: '?', 5302289: 'Toulon', 3104470: 'Mbuji-Mayi', 2722635: 'Mombasa', 8382: 'Sevan', 13739: '?', 14794: 'Anuchino', 1708521: 'Weißenfels', 3215022: 'Salo', 18293: 'Bolshaya Vishera', 1020182: 'Koskovo', 21193: 'Stepnogorsk', 1157135: 'Mogay', 22725: '?', 18897: 'Sotnikovka', 21065: 'Yagotin', 1142300: 'Sechenovo', 20352: 'Bratslav', 1961508: 'Darlington', 15387: 'Kikerino', 1000652: 'Zelennik', 301: '?', 1517365: 'Qiqihar', 14738: '?', 1086335: 'Kirovo', 3042: '?', 7995: 'Swindon', 20389: '?', 1701594: 'Zelenoe', 20372: '?', 19206: '?', 1149690: 'Severny Kospashsky', 1519353: '?', 20400: 'Kukushkino', 1921247: 'Kirchheim unter Teck', 12925: '?', 14209: 'Zavetnoe', 6913: 'Esil', 1006633: 'Kalimullino', 3718: 'Kysyl-Syr', 1695: 'Windsor', 20423: '?', 20440: '?', 17135: '?', 1950563: 'Kourou', 1516489: 'Évry', 5453: '?', 1031492: 'Zheleznodorozhny', 2500171: '?', 2761: 'Ochakov', 20493: 'Doschatoe', 16725: 'Sorochinsk', 2722572: 'Gonaïves', 1056577: 'Sukharevo', 15523: 'Archabil', 2428: 'Shatsk', 4305879: 'Oud-Heverlee', 2722646: 'Alofi', 20459: 'Tash-Kumyr', 1508850: 'Teplitsa', 5210523: 'Valbonne', 5266225: 'Düren', 1123222: 'Tyumen (selo)', 8319: 'Malokurilskoe', 15410: 'Schaan', 1917757: '?', 1161160: 'Pavlodolskaya', 14829: 'Pokhvistnevo', 1504242: 'Priborzhavskoe', 20492: '?', 9161: '?', 5266899: 'Altötting', 5021: 'Unyugan', 1914316: '?', 1710769: 'Buzău', 20679: 'Shemordan', 6471: 'Mevo Hama', 20311: '?', 17298: '?', 20518: 'Ambarny', 13727: 'Kelozi', 20445: '?', 20529: 'Spasskoe', 10735: 'Tyukalinsk', 1066604: 'Plescheevo', 4341036: 'Plech', 20555: 'Novaya Olkhovka', 20765: 'Dimitrovka', 5266343: 'Minden', 1000134: 'Sevastopolskaya', 1714882: '?', 1961754: '?', 20714: '?', 20562: '?', 2300693: 'Almería', 17748: 'Banbury', 20715: '?', 1056513: '?', 5471436: 'Somoniyon', 20569: 'Golovchino', 10884: '?', 19879: '?', 20574: '?', 19122: 'Ezerische', 4475: 'Newcastle', 1903763: '?', 5266215: 'Moers', 1970752: 'Gulbene', 647: '?', 1135056: 'Novobirilyussy', 1062468: 'Borki', 1920249: '?', 3981: '?', 20599: 'Mikhaylovka', 1073911: 'Nebogi', 1918422: 'Levallois-Perret', 1503761: 'Bronitskaya Guta', 1128334: 'Abalakovo', 18864: 'Dzerzhinsky', 20656: '?', 21374: '?', 1009551: 'Oktyabrsky', 4315975: 'Aywaille', 22421: 'Khmelnik', 1518222: 'Cleveland', 6250: 'Staroe Shaygovo', 1504363: 'Yasinya', 1511478: 'Kopychintsy', 1084055: 'Staraya Racheyka', 1910425: '?', 19331: 'Zalegosch', 1941996: 'Jijel', 1506371: 'Zavalye', 14179: 'Darwin', 1006483: 'Kirgizki', 1504063: 'Chernyakhov', 2207190: '?', 1516331: '?', 1160777: 'Vershino-Shakhtaminsky', 1943421: '?', 1939365: '?', 11520: 'Novominskaya', 5931: 'Shtefan-Vode', 1706016: '?', 1515579: '?', 1031353: 'Ozersk', 7942: 'Limanskoe', 1700297: 'Uspeno-Yuryevka', 1934634: '?', 1509137: 'Dobroslav / Kominternovskoe', 1506127: 'Polesskoe', 1151458: 'Kultaevo', 1052265: 'Andreevka', 1516143: 'Treviso', 1934831: '?', 1714970: 'Bauska', 1153369: 'Belaya Gora', 1909219: '?', 1155881: 'Kashino', 1515061: 'Ichnya', 6091: 'Grand Forks', 1942049: 'Kamienna Góra', 1922327: '?', 1513829: 'Zakupnoe', 1138047: 'Kazak-Kocherdyk', 1042115: 'Sennoy', 3712485: 'San Nua', 6281: '?', 1925029: '?', 1160914: 'Rytkuchi', 16602: 'Egorlyxkaya', 1927756: '?', 1907293: '?', 1928682: '?', 21212: 'Emilchino', 1941592: '?', 1902798: '?', 12883: 'Yayva', 1133722: 'Stulovo', 12932: 'Kodyma', 1940166: '?', 1927379: '?', 1927380: '?', 1708955: 'Tskhaltubo', 1010067: 'Voznesenovka', 21748: 'Clemson', 1925601: '?', 1518865: 'Khamza (karakulsky Rayon)', 1014399: 'Golubinskaya', 1931278: '?', 1908515: '?', 1514205: 'Buzhanka', 1015917: 'Smorodinka', 1916913: '?', 15664: 'Essoyla', 1707309: 'Košice', 1910829: '?', 1902781: '?', 1139424: 'Vad', 1518887: 'Kalamazoo', 1506156: 'Gorobeevka', 2650: 'Zhashkov', 1802058: '?', 1503919: 'Strokov', 1935780: '?', 1114849: 'Morgaushi', 1941043: '?', 1925604: '?', 1711802: '?', 1036667: 'Izhma', 19703: 'Kamenka-Dneprovskaya', 1940002: '?', 1502116: 'Shatsk', 1500891: 'Zbarazh', 1511561: 'Zbarazh', 10282: 'Ukholovo', 20670: 'Svetly', 1907762: '?', 1134058: 'Sardyk', 1508962: 'Veliky Dalnik', 1519311: 'Salisbury', 1518519: 'Denton', 1078746: 'Krivoy Liman', 4551082: 'Averara', 1941019: '?', 1905114: '?', 7341: 'Novaya Inya', 1705757: 'Byuregavan', 1909285: '?', 1161587: 'Goscha', 1705063: 'Vigo', 1917729: '?', 2204641: '?', 5264374: 'Sandhausen', 1703863: 'Kuritichi', 1113881: 'Chiri-Yurt', 3123763: 'Irbid', 1938778: 'Aracaju', 1928168: '?', 17412: 'Gergebil', 1907648: '?', 1153976: 'Nekrasovka', 3852: 'Karabalyk', 4485942: 'Zgorzelec', 1506251: 'Pyatigory', 7597: 'Kalinovka', 4610999: 'Namibe', 1902449: 'North Miami Beach', 3315: 'Kurumkan', 1936668: '?', 1946046: 'Kusary', 1938363: 'Neochória', 1908459: '?', 1920007: '?', 1910413: '?', 15513: 'Bolshaya Murta', 1949141: '?', 1927368: '?', 1518563: '?', 1713065: 'Greenfield', 1929678: '?', 1112199: 'Cherdakly', 1112050: 'Isheevka', 1128068: 'Verkholensk', 1153445: 'Ugolnoe', 22480: 'Chasov Yar', 1015434: 'Staraya Poltavka', 5371: 'Presnovka', 1147934: 'Abramovka', 22360: '?', 1144632: 'Zakovryazhino', 1112788: 'Pervomaysky', 1128713: 'Novomaltinsk', 20097: 'Tayturka', 21850: 'Loma Linda', 1914820: 'Van Nuys', 1158484: 'Yurginskoe', 1932832: '?', 1143750: 'Suzdalka', 10704: 'Romanovka', 1937745: '?', 1711289: '?', 1942181: 'Kegeyli', 7991: 'Zhezkent', 1710780: '?', 1084525: 'Svobodny', 1151825: 'Rodniki', 1131302: 'Karinka', 1007380: 'Dushanbekovo', 1941956: '?', 1059715: 'Vaskino', 4755: 'Boralday', 20153: 'Elstal', 1127707: 'Zalari', 17826: 'Starozhilovo', 16229: 'Kamyzyak', 6336: 'Novy Byt', 1126414: 'Penza', 1160138: 'Chara', 1124363: 'Shabur', 1057090: 'Gorodok-17', 1941016: '?', 1144503: 'Krasny Yar', 12584: 'Sarkand', 1942190: '?', 1124748: 'Kuytun', 1124183: 'Uro', 14579: 'Radomyshl', 2540: 'Nagoya', 1916875: 'Drachten', 1712881: '?', 1140830: 'Diveevo', 10841: 'Shakhrisabz', 1035499: 'Kubina', 21763: 'Kissimmee', 1701600: 'Makarovo', 1036898: 'Noshul', 1803668: '?', 8014: 'Tetiev', 1085994: 'Pushkino', 1151489: 'Nizhnie Mully', 1032090: 'Babynino', 1918518: '?', 1500068: 'Bogatoe', 1112649: 'Vishnevogorsk', 5386: 'Novaya Bryan', 1926050: '?', 1902497: '?', 1009744: 'Urazovo', 1931702: '?', 1127779: 'Zulumay', 5332789: '?', 1138939: 'Bolshoe Boldino', 1939141: '?', 14766: 'Gagino', 1140254: 'Yuryevo', 1141274: 'Zhdanovsky', 1505835: 'Volodarka', 5332369: '?', 1504258: 'Mezhgorye', 1628: '?', 1939350: '?', 1078171: 'Moskovsky', 1904369: '?', 1926747: '?', 1003916: 'Vyatkinskaya', 1153655: 'Zarechny', 1501185: 'Rudnitskoe', 1916309: '?', 1906714: '?', 1502698: 'Novovyazovskoe', 1934607: '?', 21865: '?', 1932011: '?', 1045797: 'Berezhki', 1507566: 'Zhuravno', 1941093: '?', 22233: 'Oster', 1908358: '?', 16513: 'Fanipol', 1505941: 'Rzhischev', 1122052: 'Volchikha', 5891: 'Kovel', 16900: 'Vetluga', 1509590: 'Grebenka', 1508713: 'Novaya Odessa', 1512677: 'Malinovka', 1932997: '?', 1503900: 'Kornin', 1133810: 'Kolyanur', 5642: 'Goncharovskoe', 1939157: '?', 1927934: '?', 1911768: 'West Hollywood', 16854: 'Yazykovo', 1703971: '?', 9949: 'Ostrog', 1136172: 'Nizhnyaya Esaulovka', 6830: '?', 1502399: 'Orlovschina', 1015938: 'Timoshino', 1507642: 'Magerov', 5426136: 'Kazakhstan ', 1161694: '?', 8021: 'Popelnya', 1008131: 'Pavlovka', 1502064: 'Smidin', 1506432: 'Pomoshnaya', 1153421: 'Verkhnevilyuysky', 20644: 'Lagodekhi', 1036759: 'Griva', 1702712: 'Ozernoe', 1128943: 'Novobalturina', 1153793: 'Oy', 18742: 'Tyulgan', 1517361: '?', 1923965: '?', 1017684: 'Bilibino', 15355: 'Oktyabrsky', 1054790: 'Chulki-Sokolovo', 1505684: 'Dudarkov', 1514549: 'Vali', 1941042: '?', 19811: 'Shumen', 1937687: '?', 1512766: 'Stanislav', 1159737: 'Pripolyarny', 1083932: 'Sergievsk', 1935315: '?', 1602573: 'Bolshevik', 1083202: 'Rozhdestveno', 1011031: 'Gostischevo', 1933511: '?', 1515420: 'Semenovka', 3372: 'Georgievka', 1942349: '?', 1923649: '?', 13699: 'Kotsyubinskoe', 1032347: 'Vorsino', 1901680: '?', 1904422: '?', 1041002: 'Maykopskoe', 1936272: 'Vorontsovka', 1908174: 'Maryville', 1043728: 'Vysokonskie Dvory', 6457: 'Akbulak', 1518407: 'Staroe Selo', 13407: 'Kazatin', 1949696: '?', 1087271: 'Vasyuki', 9709: '?', 1079046: 'Alexandrov', 1500521: 'Chapaevka', 1907746: '?', 1930024: '?', 1083278: 'Isakly', 1707714: 'Yangibazar (yangibazarsky Rayon)', 1803407: '?', 17320: 'Shargorod', 1929114: '?', 1505695: 'Rogozov', 1515096: 'Kozelets', 1938853: '?', 1907804: '?', 1803471: '?', 1137578: 'Novaya Sidorovka', 1154621: 'Gryaznovskoe', 13667: 'Borodinsky', 1030409: 'Surkhakhi', 6225: 'Semenov', 1058720: 'Sergiev Posad-15', 1513216: 'Lozovaya', 1511653: 'Kozova', 1003201: 'Khavrogory', 5373: 'Kholmogory', 1706324: 'Sperenberg', 1515591: 'Pereyaslav-Khmelnitsky', 22353: 'Novoselki', 1512480: 'Kupyansk Uzlovoy', 3697: 'Belousovka', 1501216: 'Pogrebische', 1933879: '?', 22078: 'Desna', 1505277: 'Stary Gvozdets', 1154306: 'Mironovo', 1155928: 'Kuznetsovo', 1921: 'Chulym', 1000038: 'Volnoe', 1111159: 'Patrikeevo', 1006547: 'Beketovo', 1129491: 'Atamanovo', 10247: 'Boshnyakovo', 1714076: '?', 1518903: '?', 1942365: 'Topoľčany', 14501: 'Aysha', 2205177: 'Basseterre', 1503017: 'Liman / Krasny Liman', 1508974: 'Mayaki', 1049823: 'Novodmitrievka', 1942054: '?', 1127510: 'Smidovich', 1930784: '?', 1517097: 'Klichev', 1123828: 'Kalinino', 1942360: '?', 1135212: 'Minsk (derevnya)', 1037207: 'Ust-Vym', 4765912: 'Panama', 1907185: '?', 1513936: 'Vyazovok', 18337: 'Grebenki', 1142840: 'Tonshaevo', 1927089: '?', 1517878: 'Toytepa', 8629: 'Charleston', 9713: 'Borovsky', 1126294: 'Lyakhi', 2200189: '?', 1917501: '?', 1916955: '?', 1509776: 'Kamennye Potoki', 1009601: 'Yasnye Zori', 1942375: '?', 1144560: 'Verkh-Irmen', 17260: 'Gantsevichi', 1959289: 'Rendsburg', 4361853: 'Kappeln', 1112975: 'Medvedevka', 1933780: '?', 1138630: 'Bebyaevo', 1161181: 'Entuziastov', 1711653: 'Chuchulya', 1512972: 'Malokakhovka', 1921657: '?', 1035577: '?', 1153715: 'Elgyay', 7783: 'Pyatikhatki', 17907: 'Ružomberok', 1506729: 'Ulyanovka', 1018155: 'Nepotyagovo', 4375755: '?', 18775: 'Khorol', 1122206: 'Karamyshevo', 9507: 'Radovitsky', 11867: 'Lvovo', 9510: '?', 1711908: '?', 1151425: 'Karagay', 1505568: 'Tlumach', 1065567: 'Kavkaz', 1123425: 'Novoobintsevo', 1075174: 'Khilovo', 1052231: 'Bolshie Berezniki', 1518459: 'Irtyshsk', 1903464: '?', 13833: 'Nesvizh', 1713460: '?', 8653: 'Obukhov', 4176: 'Teplaya Gora', 5332784: '?', 1939737: '?', 21931: 'Malenkoe', 1113781: 'Naurskaya', 1715005: '?', 20697: 'Donets / Chervony Donets', 1123185: 'Staroaleyskoe', 1902308: '?', 1513759: 'Teofipol', 5233: 'Selidovo', 1050483: 'Kulakovo', 5978: 'Ostrovskoe', 22216: 'Grushovka', 1507922: 'Cherkassy', 20637: 'Belovodsk', 2926: 'Novoulyanovsk', 1908442: '?', 1143300: 'Fokino', 5850: 'Krasnye Baki', 9011: 'Yashalta', 4662553: 'Santiago de los Caballeros', 1709956: 'Carrollton', 1003428: 'Ulyanovskaya', 1939338: '?', 1920093: '?', 1001804: 'Bereznik', 1117662: 'Myshkin', 15254: 'Buturlino', 1036992: 'Yb', 1006409: 'Kalmash', 1506807: 'Sabatinovka', 1041034: 'Tysyachny', 3689: '?', 11656: 'Ust-Khayryuzovo', 3837836: 'Kitakyūshū', 21829: 'Kobelyaki', 1507306: 'Stanitsa Luganskaya', 1146799: 'Obilny', 4993923: 'Banner Springs', 13318: 'Ryshkany', 1942282: '?', 1942196: '?', 1908376: '?', 1008409: 'Cherkassy', 21940: 'Verkhny Mamon', 1053935: 'Verbilki', 1086055: 'Tatischevo', 1504761: 'Novonikolaevka', 1151242: 'Berezniki', 1037281: 'Yugydyag', 1157672: 'Kolesnikovo', 16392: 'Piryatin', 17790: 'Miory', 16847: 'Kalanchak', 5261748: 'Leverkusen', 22715: 'Belfort', 1512612: 'Sakhnovschina', 5267015: 'Kronach', 1705338: 'Višķu pagasts', 1703909: 'Osveya', 1085855: 'Svyatoslavka', 1085839: 'Krasnoznamensky', 1906829: '?', 1961565: '?', 2102301: 'Khamza (yangiyulsky Rayon)', 1929254: '?', 21127: 'Alyat (karadag)', 1509596: 'Maryanovka', 1112081: 'Salmanovka', 21187: 'Ruzhin', 1155563: 'Sinegorsky', 1942470: '?', 10498: 'Berd', 1935041: '?', 1515309: 'Mrin', 1701077: 'Altaysky', 19000: 'Setúbal', 1059297: 'Bolshoe Alexeevskoe', 1136275: 'Motygino', 1010009: 'Morozovo', 6446: 'Peremyshl', 1702867: 'Sergeevka', 1941731: '?', 2639: 'Margilan', 16244: 'Lapichi', 1904071: '?', 1502763: 'Novoluganskoe', 1514203: 'Boyarka', 1705447: 'Caterham', 1502758: 'Krasnoe', 1913793: 'Baladzhary', 1517966: 'Sandhurst', 1923867: '?', 1909640: 'Sulingen', 1941756: '?', 11299: 'Okdarya', 1142728: 'Prostokvashino', 19885: 'Terebovlya', 20332: 'Peschanka', 1920978: '?', 2202240: 'Raahe', 6624: 'Novotalitsy', 1002605: 'Porog', 1113077: 'Fershampenuaz', 1927085: '?', 1509186: 'Novoselovka', 1042100: 'Golubitskaya', 14595: 'Karlovka', 1970833: 'Hessisch Oldendorf', 1942529: 'Extertal', 1929532: '?', 1507927: 'Schirets', 1968340: 'Gori', 18088: 'Vorzel', 18616: 'Sergino', 1923453: '?', 1161063: 'Se-Yakha', 5346879: '?', 1111800: 'Radischevo', 5266952: 'Dingolfing', 1903862: 'Hildburghausen', 1158490: 'Berkut', 15756: '?', 6728: 'Safed', 1036864: 'Chikshino', 1012401: 'Zaymische', 1509226: 'Zelenogorskoe', 1505915: 'Gostomel', 1517158: '?', 22719: 'Gardelegen', 1144476: 'Borovoe', 1508510: 'Trikraty', 1081015: 'Chernava', 1046533: 'Elizavetino', 1505732: 'Gogolev', 5040804: 'Grosse Pointe Woods', 1505703: 'Babintsy', 1902918: '?', 1706716: '?', 1961308: '?', 1012391: 'Unecha', 1134860: '?', 1060273: 'Oboldino', 1921351: 'Baltoji Vokė', 1036512: 'Shalsky', 1156121: 'Talitsa', 1923944: '?', 11281: 'Berezayka', 4307427: 'Meerbeek', 1913846: '?', 1702416: 'Aktogay', 1516502: 'Zhitkovichi', 1515917: 'Sastobe', 16655: 'Bilmak / Kuybyshevo', 1705930: 'Eckernförde', 1136595: 'Borodino', 1505728: 'Bobrik', 1505678: 'Vishenki', 1506019: 'Chervonaya Sloboda', 3756: 'Khvalynsk', 1113863: 'Urus-Martan', 1032711: 'Zhizdra', 1138818: 'Doskino', 1010701: 'Rakitnoe', 1918732: '?', 1905278: 'Wheeling', 1011096: 'Ternovka', 14153: 'Ternovka', 1942163: '?', 5309: 'Weesp', 13829: 'Alexeevka', 1505734: 'Zavorichi', 1505737: 'Kalita', 1154683: 'Tagilsky', 1091464: 'Voznesenovskoe', 1008766: 'Yumatovo', 1803289: 'Tori', 6884: '?', 1909537: 'Les Ménuires', 1500582: 'Livadia', 1096710: 'Pushkino', 16853: 'Verkhnie Sergi', 1940057: '?', 1113225: 'Mezhevoy', 1015999: 'Verkhoturye', 1506369: 'Gayvoron', 1928923: '?', 1911027: 'Hässleholm', 13132: 'Bloomsburg', 1919348: 'Piraeus', 1130160: 'Scherbinovka', 1702593: 'Novoukrainka', 1941606: '?', 1517991: 'Harrisburg', 1141821: 'Perevoz', 2779: 'Vavozh', 1921085: '?', 13696: 'Khislavichi', 1036779: 'Adzherom', 1918776: '?', 21600: 'Kitsman', 1708761: 'Quedlinburg', 1939048: '?', 1069828: 'Rusanovo', 1071117: 'Naumovo', 19188: 'Pereslegino', 1117094: 'Sereda', 1506061: 'Kozin', 5526: 'Makarov', 1708134: 'Kansay', 1944409: 'Tramore', 1944392: 'Bartoszyce', 1912188: '?', 21909: 'Lysyanka', 1920785: '?', 17703: 'Novogrodovka', 1109805: 'Yakshur', 1932089: '?', 4672: 'Kulunda', 1914688: 'Vsetín', 1714887: '?', 1029187: 'Privolzhsk', 1050378: 'Privolzhsky', 1119611: 'Porechye-Rybnoe', 1928117: '?', 12895: 'Iki-Burul', 1600726: 'Udelo', 1142639: 'Krasny Vatras', 17312: 'Chernyshevka', 1942594: '?', 1921204: '?', 1712834: 'Alamedin', 1914630: '?', 1942606: '?', 1040895: 'Baturinskaya', 7563: 'Zolotaya Dolina', 4230200: 'Swindon', 1962920: '?', 1014835: 'Nekhaevskaya', 10280: 'Urussu', 1933384: '?', 4676: 'Sukhodolsk', 1911036: '?', 1084665: 'Bolshie Ozerki', 1143607: 'Trunovskoe', 1903793: '?', 1713866: 'Wigan', 1904264: '?', 1501301: 'Vapnyarka', 1000743: 'Podolskaya', 1506607: 'Skaleva', 9730: 'Zavodoukovsk', 1500519: 'Razdolnoe', 1941941: '?', 1706126: 'Shakhrikhan', 1031886: 'Khanata', 1929490: '?', 2200432: 'Martuni', 1029177: 'Plyos', 1068032: 'Russky Kameshkir', 1910411: '?', 1036765: 'Koygorodok', 21663: 'Sovetskoe', 1035482: 'Kurdzhinovo', 1941022: '?', 1903809: '?', 1706055: 'Gallaaral', 4538769: 'Todi', 1937429: 'Nauen', 4543305: 'Orsogna', 1929691: '?', 5418391: 'Antakya', 11801: 'Proletarsky', 1119632: 'Semibratovo', 14945: 'Timişoara', 1705067: 'Xuzhou', 1041751: 'Verkhnebakansky', 1940211: '?', 1939252: '?', 1006489: 'Mayadyk', 21911: 'Weiden in der Oberpfalz', 1906174: 'Ivanovka', 1935785: '?', 1130215: 'Yashkino ', 5581: 'Voznesensk', 14433: 'Gorodkovka', 1002543: 'Antsiferovsky Bor', 1714656: '?', 19589: 'Totskoe 2-E', 1132755: 'Sosnovy Bor ', 1932400: '?', 1932949: '?', 1702131: 'Shishkinskoe', 1713216: 'Belleville', 1926163: '?', 18987: 'Sinegorsk', 1502313: 'Priyut', 1918084: '?', 1079572: 'Gigant', 1712035: '?', 1929217: '?', 1913375: '?', 1700088: 'Novoselskoe', 1042348: 'Kirpilskaya', 1714307: '?', 1934535: '?', 2205992: 'Kandahar', 1903988: '?', 22262: 'Apostolovo', 1933784: 'Greater Napanee', 1122337: 'Kosikha', 5267842: 'Korbach', 1508954: 'Shabo', 17561: 'Beya', 1917123: '?', 1924236: '?', 1704171: 'Balaken', 1922225: 'Rzeszów', 1004292: 'Oranzherei', 1069319: 'Pavlovo', 1014986: 'Kikvidze', 1509153: 'Kurisovo / Petrovka', 1033747: 'Nedelnoe', 1516878: '?', 1502936: 'Uglegorsk', 1707956: '?', 1942694: '?', 15779: 'Khorostkov', 1924750: '?', 1910359: 'Frankenthal', 1247: '?', 17831: 'Penzyatka', 1709583: '?', 5377539: 'Kehra', 1916842: '?', 22063: 'Tarutino', 21543: 'Buffalo', 1505580: 'Baryshevka', 1911065: 'Baldone', 1939000: 'Asūne', 1511303: 'Trostyanets', 1041246: 'Korzhevsky', 15966: 'Pyatovsky', 1903437: 'Adrian', 1128145: 'Vizirny', 1802008: 'Saint Denis', 1500406: 'Krymskoe', 16529: 'Otegen Batyr', 19528: 'Voyvozh', 1100230: 'Nerl', 1939671: '?', 1501873: 'Lyubeshov', 1511344: 'Yampol', 21101: 'Molodovo', 1048615: 'Zakharovka', 1099890: 'Kuvshinovo', 20412: 'Babai', 12983: 'Obsharovka', 15233: 'Bolsheustikinskoe', 1058335: 'Kolyubakino', 1515078: 'Yuzhnoe', 1941138: '?', 1515339: 'Ladan', 1507655: 'Rava-Russkaya', 1501351: 'Trostyanets', 1138011: 'Borovichi', 1704985: 'Mikhanovichi', 1129012: 'Nagorny', 1942659: '?', 1503438: 'Irshansk', 1507006: 'Schastye', 1518456: '?', 20647: 'Khaydarkhan', 569: '?', 1933515: 'Alūksne', 1802178: 'Aizpute', 1602709: 'Rudensk', 1919170: 'Socnovka', 16222: 'Babayurt', 1920167: '?', 1914320: '?', 21114: 'Slavgorod', 1703602: 'Gudogay', 1502570: 'Nadievka / Zhdanovo', 1502587: 'Privolnoe', 19440: '?', 1026515: 'Mugergan', 20329: 'Krasnopolye', 4101: 'Zelva', 1926351: 'Dzhany-Pakhta', 1512412: 'Berestovenka', 5264318: 'Oberhausen-Rheinhausen', 1902801: 'Redditch', 1505268: 'Pyadiki', 1714794: '?', 2208190: 'Fès', 1502938: 'Yunokommunarovsk', 1911053: 'Bingen am Rhein', 4539827: 'San Vincenzo', 14806: 'Lelchitsy', 1921814: '?', 1707813: '?', 1502621: 'Sofievka', 3960285: 'Baga Mandal', 1901400: '?', 2722672: 'Bamako', 1928774: '?', 18384: 'Ladozhskaya', 1063718: 'Lipetsko', 2203667: 'Mecca', 1058098: 'Kuzyaevo', 14726: 'Talnoe', 1514025: 'Gusakovo', 1706859: '?', 1504536: 'Malaya Belozerka', 1942900: '?', 1901140: 'Netivot', 16540: 'Nolinsk', 1928092: '?', 1705571: 'Gruyères', 1926376: '?', 1942420: '?', 15086: 'Tomakovka', 5451361: 'Jerusalem', 1934387: '?', 1503679: 'Lyubar', 1931593: '?', 1942815: '?', 1903884: '?', 1327: '?', 1602557: 'Sorochi', 1922672: '?', 1078612: 'Bolshaya Fedorovka', 3323654: 'Matero', 1930321: 'Zabrat (sabunchi)', 1923910: '?', 1091897: 'Achikulak', 11092: 'Ukrainka', 1000081: 'Saratovsky', 1507623: 'Dublyany', 1966972: '?', 1068212: 'Lopatino', 1714006: '?', 1911481: '?', 21985: 'Funchal', 5086103: 'South Milwaukee', 19103: 'Temirgoevskaya', 1003055: 'Vyselki', 1715054: 'Naperville', 1504799: 'Orekhov', 1147030: 'Druzhina', 6570: 'Fabrichny', 1121708: 'Ust-Kan', 1519054: '?', 1123492: 'Arkhara', 1143553: 'Slavyanka', 1709173: 'Adrian', 1136436: 'Stretenka', 1124207: 'Mongoy', 1518968: 'Mount Prospect', 1925278: 'Alexander', 1943396: '?', 1124074: 'Urusha', 1136649: 'Ural', 1937765: 'Garliava', 1160412: 'Ulyatuy', 3577: 'Sioux Falls', 1128938: 'Lesogorsk', 1124758: 'Tarbagatay', 1112378: 'Bredy', 1927182: '?', 17993: 'Kabanbay', 1032049: 'Ulyanovskoe', 1112645: 'Bagaryak', 4056353: 'Darala', 1160271: 'Khapcheranga', 1157370: 'Berdyuzhye', 1113282: 'Kremenkul', 1965621: 'Compiègne', 1940145: '?', 1157547: 'Balagany', 1129260: 'Razvedchik', 1144178: 'Khabarovsky', 1969482: '?', 15890: 'Povenets', 5346884: 'Orto-Nakhara', 1153522: 'Bechencha', 6974: '?', 1505136: 'Vygoda', 1067618: 'Pokhvistnevo', 7662: '?', 1153392: 'Olenegorsk', 1802141: '?', 1503298: 'Andrushevka', 14831: 'Nekrasovskoe', 1702003: 'Chernigovka', 1935094: '?', 10761: 'Pirovskoe', 1129056: 'Krutoberegovo', 1502214: 'Pokrov / Ordzhonikidze', 1443: 'Lepel', 1929632: '?', 22293: 'Bolshoe Murashkino', 1128903: 'Talniki', 1059174: 'Peshki', 1920944: '?', 4236514: 'Holmbury Saint Mary', 1157286: 'Armizonskoe', 1114291: 'Novoe Churashevo', 1124032: 'Sosnovka', 1941994: '?', 1937159: '?', 1922637: '?', 1924950: '?', 1505719: 'Nemeshaevo', 1009550: 'Novosadovy', 1515173: 'Rybinsk', 1901269: '?', 1127475: 'Amurzet', 1904939: '?', 1800061: 'Baurchi', 1035519: 'Khabez', 1514241: 'Mankovka', 1934709: '?', 1144887: 'Ubinskoe', 1931066: '?', 1514509: 'Khrestitelevo', 1138559: 'Ideal', 11012: 'Ekaterinogradskaya', 1033018: 'Kirovo', 1919384: '?', 1911842: '?', 5266282: 'Datteln', 1134926: 'Balakhta', 18920: 'Braintree', 1121494: 'Suduntuy', 1121496: 'Khoyto-Aga', 1802470: '?', 1122262: 'Novoromanovo', 1038522: 'Nikolskoe', 1089486: 'Oster', 1908890: '?', 1504895: 'Rozovka', 1925103: '?', 1503591: 'Kozhukhovka', 1040528: 'Zeblyaki (derevnya)', 1507216: 'Poltava', 13497: '?', 1079224: 'Pokrovskoe', 1042282: 'Tenginka', 1112492: 'Surmenevsky', 1084252: 'Surinsk', 1505852: 'Rudoe Selo', 1574: '?', 4418717: 'Montauban', 1509295: 'Nagornoe', 17400: 'Izykhskie Kopi', 1902436: 'Tyup', 1711993: '?', 1911618: '?', 1113161: 'Oktyabrskoe', 1600321: 'Divin', 1137425: '?', 17438: 'Polovinnoe', 1942973: '?', 1704589: 'Napa', 1931806: 'Divonne-les-Bains', 1518038: 'Vladimirovka', 1912008: '?', 1136093: 'Krasnokamensk', 1055384: 'Zubovo', 3121142: 'Bangui', 1084052: 'Sborny', 15700: 'Sokol', 1703239: 'Issyk-Kulskaya', 1160871: 'Aliskerovo', 1709202: 'Allen Park', 1023309: 'Ryazan (derevnya)', 1514515: 'Vasilkov', 1109026: 'Mikhnevo', 1519346: 'Kiruna', 1095802: 'Raifa', 1129671: 'Novosafonovsky', 21555: 'Sinelnikovo', 1936471: '?', 1908930: '?', 22674: 'Bar', 1500634: 'Chemeriskoe', 1500598: 'Balki', 14152: 'Shpola', 1091993: 'Sukhaya Buyvola', 3133411: 'Safra', 1136725: 'Atamanovo', 1515629: "King's Lynn", 2572: '?', 11335: 'Mednogorsky', 1154015: 'Pobedino', 1093480: 'Rasskazovo', 1515593: 'Shkolnoe', 1083140: 'Novy Kutuluk', 1008590: 'Nurkeevo', 1124310: 'Uldurga', 1099843: 'Kablukovo', 1509808: 'Lokhvitsa', 10397: '?', 4355901: '?', 9997: 'Shantalovo', 1513095: 'Novaya Mayachka', 1153110: 'Krasny Kut', 1512506: 'Krasnopavlovka', 1058715: 'Selkovo', 1160607: 'Zhipkhegen', 1154110: 'Golovnino', 1934571: '?', 1505750: 'Rusanov', 1019312: 'Chernava', 20011: 'Bolshoe Sedelnikovo', 1508934: 'Mologa', 5261922: 'Sinn', 1506221: 'Lesovichi', 5109889: 'Tuscarora', 5110460: 'Fields', 1711176: 'Dillon', 5119363: 'Saratoga', 5105169: 'Riddle', 1713091: 'Gresham', 5047275: 'Ramsey', 1147055: 'Mikhaylovka', 1057956: 'I. Armand', 1505786: 'Plesetskoe', 1514141: 'Tagancha', 1937526: '?', 1032535: 'Milyonki', 1115611: 'Novye Shimkusy', 1134742: 'Kostroma (selo)', 1121890: 'Nizhnekamenka', 7431: 'Saryozek', 14359: 'Kharlu (poselok)', 1035441: 'Pervomayskoe', 1709203: 'Allendale', 1938598: '?', 21168: 'Aktas', 20726: 'Schukozero', 20272: 'Sakmara', 1803182: 'Aseri', 1505589: 'Lukashi', 1803368: 'Suure-Jaani', 1505943: 'Stavy', 1905639: 'Kawasaki', 20749: '?', 1918628: '?', 1098429: 'Khotilovo', 1508975: 'Mirnoe', 1154527: 'Shadrinka', 1941525: '?', 1974573: '?', 1961856: '?', 1967502: 'Dedoplistskaro', 1148168: 'Bolshedorozhnoe', 1024602: 'Volya', 1505712: 'Kozintsy', 1516255: 'Aberdeen', 5741: 'Khlevnoe', 8992: 'Azovy', 1700273: 'Novokubanka', 4821: 'Dalnie Zelentsy', 1600716: 'Podsvilye', 17349: 'Medvedovskaya', 1113507: 'Vyazovaya', 1502114: 'Svityaz', 1502049: 'Krymnoe', 5327549: 'Gorokhov', 5833: 'Yuryev-Polsky', 5428282: 'Novodolinsky', 1512679: 'Novopokrovka', 1505724: 'Peskovka', 1025773: 'Akhty', 1154454: 'Baykalovo', 1514929: 'Bobrovitsa', 20701: '?', 1135176: 'Takuchet', 20554: 'Levokumskoe', 1158910: 'Khabarovsk (derevnya)', 1158295: 'Perevalovo', 1149143: 'Evropeyskaya', 1514269: 'Monastyrische', 1506314: 'Bobrinets', 10301: 'Zaslonovo', 19043: 'Molokovo', 1713433: 'Gyachrypsh', 1132381: 'Arkul', 2201374: 'Puerto del Rosario', 1153643: 'Oymyakonsky', 1915302: '?', 1941263: '?', 8333: 'Turuntaevo', 1702226: 'Peshkovka', 1943415: '?', 3301: 'Priazovskoe', 1951299: '?', 1937289: 'Gällivare', 1040867: 'Molodezhny', 1513886: 'Sudilkov', 6801: 'Teberda', 14725: 'Foros', 1516628: 'Cheremshanka', 1507065: 'Zorikovka', 9903: 'Kharba', 5257196: 'Zwickau', 16108: 'Sobolevo', 5116890: 'Duvall', 1112281: 'Derbisheva', 1509839: 'Zhdany', 1509949: 'Rudenkovka', 1517449: 'Bensalem', 1705222: 'Abington', 1934892: '?', 1943120: '?', 1943094: '?', 1154198: 'Kostroma (derevnya)', 1159885: 'Zelenoborsk', 1513983: 'Shramkovka', 1932123: '?', 20997: 'Nemirov', 1710504: 'Cholpon-Ata', 1942954: '?', 22175: 'Snigirevka', 1506744: 'Pavlysh', 8830: 'Bisert', 1506811: 'Blagoveschenskoe / Ulyanovka', 4719372: 'Masaya', 9747: 'Mariánské Lázně', 1971110: 'Gudauta', 1085145: 'Gorny', 9995: 'Babīte', 1904487: 'Latina', 723: 'Duino', 1042353: 'Nekrasovskaya', 1516908: 'Nishan', 1929026: '?', 1097250: '66-J', 1516003: '?', 21381: 'Rozhische', 16994: 'Buribay', 1931107: 'Acadia', 1921891: '?', 1081655: 'Solntse', 1803438: '?', 7510: 'Novospasskoe', 1010324: 'Nikitovka', 1015984: 'Babushkina', 1502151: 'Debaltsevo', 1714823: '?', 5348933: 'Singen (Remchingen)', 1919650: '?', 20844: 'Shterovka', 1801187: 'Savka', 6753: 'Gvardeysky', 1902557: 'Dmanisi', 1141037: 'Pavlovo', 1514693: 'Rososhany', 1509354: 'Zarya', 1123068: 'Serebropol', 1503882: 'Olevsk', 11060: 'Tolka', 1124778: 'Mondy', 1906866: '?', 1517200: 'Vidzy', 1500717: 'Sosonka', 18214: 'Starodubskoe', 2137: 'Spassk-Ryazansky', 1703393: 'Karmėlava', 1710745: 'North Port', 1928637: '?', 1929802: '?', 1503463: 'Romanov (dzerzhinsk)', 1068072: 'Nikolsk', 1079556: 'Rodionovo-Nesvetayskaya', 19299: 'Kegichevka', 1092033: 'Suvorovskaya', 1507214: 'Travnevoe / Pervomaysk', 12122: 'Conway', 22126: '?', 3420: 'Kamenka-Bugskaya', 1912929: '?', 1026229: 'Dubki', 1916695: 'Azerbaydzhan', 1935915: '?', 21987: 'Dokshitsy', 1911614: '?', 1509964: 'Kuybyshevo', 1111764: 'Pavlovka', 1914745: 'Desenzano del Garda', 1943198: '?', 1000015: 'Kelermesskaya', 1938539: '?', 13799: 'Starosubkhangulovo', 1004866: 'Bashkortostan', 6470: 'Kushnarenkovo', 3044: 'Chekmagush', 1006509: 'Semiletka', 1921068: '?', 19570: 'Pleven', 1502875: 'Panteleymonovka', 1704924: '?', 1500477: 'Pervomayskoe', 1519288: '?', 21382: 'Markuleshty', 1037330: 'Vodny', 1006492: 'Moskovo', 1923424: 'Aberdeen', 1900906: 'Kvuzat Yavne', 1915074: '?', 14027: 'Koblevo', 1702958: 'Myrzakent', 1923603: '?', 1707930: '?', 1514711: 'Kiselev', 1012499: 'Yupiter', 21558: 'Petropavlovka', 3578: 'Orichi', 1707477: '?', 1908316: '?', 1706149: 'Pravets', 1971161: 'Arco', 4595: 'Ugledar', 1917101: 'Capelle aan den IJssel', 1506315: 'Bobrinka', 1934527: '?', 1084184: 'Romanovka', 3379: 'Korablino', 1111026: 'Mukshi', 1144539: 'Tolmachevo', 22288: 'Skala-Podolskaya', 5267875: 'Au in der Hallertau', 2203536: 'Jalalabad', 1124029: 'Seryshevo-2', 1918576: 'Veisiejai', 1031755: 'Petrozavodskoe', 1507276: 'Slavyanoserbsk', 1011089: 'Seretino', 1078085: 'Ryabichev', 11309: 'Bend', 1937531: 'Ada', 1502480: 'Velikomikhaylovka', 1068920: 'Zubrilovo', 1921089: '?', 1043493: 'K. Libknekhta', 14467: 'Yablonovsky', 1079452: 'Budennovskaya', 1514273: 'Sarny', 1504483: 'Koshelevo', 1105146: 'Vyskodnya', 1011224: 'Bryansk-4', 1147545: 'Kurmanaevka', 1513035: 'Gromovka', 1083215: 'Chernorechye', 7353: 'Ust-Shonosha (derevnya)', 13979: 'Svobodny', 1903776: 'Alexandria', 1902894: '?', 1907757: 'Hollywood', 21160: 'Sarybulak', 1024191: 'Rudnya', 1713518: '?', 1516215: 'Karabulak', 1503406: 'Brusilov', 1939657: '?', 1943236: '?', 1943079: '?', 1916002: '?', 9644: 'Karsun', 1931787: 'Anjuna', 13417: 'Isetskoe', 1961873: '?', 1708002: 'Szombathely', 1934666: '?', 1507267: 'Lozovsky', 20166: 'Logishin', 1925945: '?', 1515146: 'Ponornitsa', 9568: 'Gorodnya', 1943250: 'Bad Dürkheim', 1514444: 'Khutora', 1602398: 'Ivenets', 1802282: '?', 1941290: '?', 1042586: '?', 22296: 'Axubaevo', 1502851: 'Nikolskoe / Volodarskoe', 1044337: 'Kshensky', 1703983: '?', 1954180: 'Salyan', 1050945: 'Yuledur', 6646: 'Sosnovskoe', 21418: 'Veseloe', 1917829: '?', 1934595: '?', 1511795: 'Podvolochisk', 1505244: 'Kornich', 1503970: 'Verkhovnya', 1111857: 'Staraya Kulatka', 5231: 'Vitim', 1519093: 'Vechta', 4384652: 'Burg Dinklage', 1926410: '?', 1502356: 'Primisskoe / Menzhinskoe', 17921: 'Magdagachi', 1155754: 'Sosva', 1077034: 'Glembochino', 1921401: '?', 1507002: 'Privolye', 1051116: 'Krasnooktyabrsky', 1139000: 'Kishkino', 1917443: 'Ferrara', 1943282: '?', 1910484: '?', 1158943: 'Ayan', 1907225: 'Brescia', 1514037: 'Olkhovets', 1711590: 'Fond du Lac', 1121988: 'Glyaden', 1923905: '?', 1028655: 'Lezhnevo', 1943287: '?', 19290: 'Evseevo', 1930421: '?', 1143824: 'Keramkombinat', 1144510: 'Lozhok', 1059385: 'Luzhniki', 1802444: '?', 1708776: '?', 1947739: '?', 1062685: 'Borovenka', 17593: 'Novoselitsa', 5245: 'Częstochowa', 1026555: 'Chapaevo', 1083447: 'Chubovka', 1712115: '?', 1931019: '?', 1073263: 'Vankovo', 14954: 'Shatki', 1961385: '?', 3729: 'Malinovsky', 1155750: 'Romanovo', 1943313: '?', 1510787: 'Strelsk', 1904195: '?', 1129995: 'Itatsky', 1136061: 'Artemovsk', 1079934: 'Krasnoyarskaya', 1058007: 'Bronnitsy (stantsia)', 1922072: '?', 18000: 'Kastornoe', 21041: 'Stepnyak', 1938602: '?', 13907: 'Krasnogorsky', 1031855: 'Kegulta', 2204642: '?', 1509347: 'Savran', 1509077: 'Suvorovo', 1935338: '?', 1518285: '?', 1052115: 'Atyuryevo', 1053368: 'Torbeevo', 1008046: 'Novye Ishly', 16061: 'Cherven', 1133409: 'Sanchursk', 16215: 'Västerås', 1915955: 'Kajaani', 1801177: 'Redoaya', 5266731: 'Bruchsal', 1095065: 'Atnya', 12764: 'Vasilyevka', 3139: 'Bogovarovo', 14424: 'Ushachi', 1041242: 'Ivanovskaya', 1704682: 'Chist', 1947256: '?', 3023: 'Oktyabrsky', 1708553: 'Alaverdi', 1941593: '?', 1927851: '?', 1943344: '?', 1010110: 'Bekhteevka', 1502941: 'Kirovskoe', 1927430: 'Hailsham', 1122697: 'Zudilovo', 1138659: 'Kovaxa', 1157607: 'Gladilovo', 1054371: 'Pavlovskoe', 1513401: 'Pluzhnoe', 15250: 'Verkhovazhye', 1703611: 'Stargard Szczeciński', 1122533: 'Kirovsky', 1502208: 'Obukhovka / Kirovskoe', 1146770: 'Adamovka', 1602595: 'Senitsa', 1913828: '?', 1942354: '?', 4119: 'Bellingham', 21784: 'Abilene', 21440: 'Ivano-Frankovsk-16', 1903036: 'Fayziabad (altyaryxky Rayon)', 5334636: '?', 1015483: 'Savinsky', 1098139: 'Bely', 1042196: 'Malorossiysky', 1705398: 'Ala-Archa', 2722664: 'Puntarenas', 1519258: 'Smilovichi', 1008873: 'Bala-Chetyrman', 5446441: 'Kazimirovka', 1943373: '?', 5235331: 'Gordes', 1517431: 'Avignon', 1905027: 'Victorville', 1903140: '?', 1508560: 'Kalinovka', 1072059: 'Vybor', 4487300: 'Wodzisław Śląski', 1931020: '?', 1502998: 'Novoekonomichnoe', 1010916: 'Arkhangelskoe', 1517782: 'Beit Zera', 1149566: 'Mendeleevo', 1969961: 'Enghien-les-Bains', 1136257: 'Tes', 21734: 'Indiana', 1505882: 'Gornostaypol', 21276: 'Sukleya', 5470215: 'Vostochny', 1106484: 'Efremov-3', 1517630: 'Logoysk', 1922954: '?', 20962: 'Kamenka', 1504913: 'Novoprokopovka', 1510217: 'Berezno', 1510225: 'Gorodische', 1510231: 'Knyazevka', 1906757: '?', 1508573: 'Voskresenskoe', 1149814: 'Kiev', 1706110: 'Tsnori', 1937754: 'Bandar Seri Begawan', 1942515: '?', 1124505: 'Mikhaylovka', 1503559: 'Ozernoe', 1930094: '?', 1962870: 'Brande', 1935031: 'Grindsted', 1503766: 'Gorodnitsa', 1137468: 'Tverdysh', 1712652: '?', 1801362: 'Talmaza', 1927946: '?', 1053382: 'Bolshoe Maresevo', 1036619: 'Severny', 6254: 'Lebedin', 1918685: '?', 1102930: 'Ramenskoe', 1924955: 'Līvāni', 1138465: 'Chaybukha', 12412: 'Lovech', 1943471: '?', 1929110: '?', 1017137: 'Drugosimonovskaya', 1511729: 'Lanovtsy', 1925761: '?', 14651: 'Ozinki', 11601: 'Primorsk', 14223: 'Hartford', 1518604: 'West Hartford', 1910516: '?', 1933446: '?', 1908206: '?', 1516700: 'Krampnitz', 1923458: 'Piacenza', 1706862: '?', 1930715: 'Gavardo', 4540959: 'Salò', 1122652: 'Cheremnoe S/z', 1939948: '?', 5463041: 'Perekol', 1943943: '?', 1026791: 'Yurkovka', 1603087: 'Zhilichi', 1973716: 'Huizhou City', 1704174: '?', 1006973: 'Almaly', 5012939: 'Lorton', 1602806: 'Dolgoe', 1940934: '?', 1919645: 'Bloemfontein', 1000113: 'Krasnooktyabrsky', 1709175: '?', 1915092: '?', 1946396: '?', 1905818: '?', 8908: 'Maloshuyka', 1516192: '?', 1505139: 'Dolina', 1505264: 'Otynya', 1908981: '?', 3283783: 'Puńsk', 2703148: 'Pakuonis', 1138512: 'Talaya', 5257195: 'Plauen', 1940080: 'Isola Albarella', 1943682: '?', 22022: 'Belopolye', 1505981: 'Khotov', 1918147: '?', 1713633: '?', 5118476: 'Stevenson', 1940601: '?', 1909492: 'Nevada', 1930333: '?', 1926378: '?', 1944271: '?', 1905024: 'Suffern', 1951419: '?', 1600100: 'Lyschitsy', 8516: '?', 1712210: '?', 16576: 'Krasnoe', 1123981: 'Ogodzha', 1516793: 'Molodezhny', 1516751: '?', 1943233: '?', 1152742: 'Krasnorechensky', 1967494: '?', 8342: 'Lazo', 20435: 'Kytmanovo', 1516934: '?', 1152893: 'Abramovka', 1919216: 'Rancho Cordova', 1108261: 'Kosaya Gora', 1702231: 'Lenino', 1905996: 'Tskhaltbila', 18220: 'Chokurdakh', 1943548: '?', 1158051: 'Sladkovo', 12944: 'Stepnoe', 7821: 'Berelekh', 1152846: 'Roschino', 1937731: '?', 1946333: '?', 1109974: 'Karakulino', 1050026: 'Vtorye Terbuny', 1156572: 'Kozhevnikovo', 18975: 'Spassk', 3871889: 'Wakō', 1144505: 'Krivodanovka', 1500207: 'Krasnoznamenka', 1041699: 'Prochnookopskaya', 17195: 'Tilichet', 4916297: 'Hot Springs', 6209: 'Vershino-Darasunsky', 1155479: 'Zyuzelsky', 1942812: '?', 1040772: 'Nizhegorodskaya', 1086256: 'Verkhny Fiagdon ', 1516261: '?', 1903951: '?', 21900: 'Borschev', 5094246: 'Riverside', 1159431: 'Bely Yar', 1106948: 'Donskoy', 1130134: 'Ishim', 5479318: 'Abez', 1504340: 'Belaya Tserkov', 22377: '?', 1058958: 'Mescherinovo', 2848: 'Stolbovaya', 1518088: 'Ramat HaSharon', 1115030: 'Tansarino', 1115011: 'Kulgeshi', 1512825: 'Vysokopolye', 1937552: '?', 21860: 'Uladovka', 1110375: 'Ilinskoe', 1503114: 'Sedovo', 1078322: 'Kuteynikovskaya', 1127482: 'Polevoe', 1153907: 'Solovyevka', 20870: 'Podgaytsy', 1124368: 'Bayangol', 1501463: 'Bondurovka', 16962: 'Lebyazhye', 602: '?', 1145643: 'Tsentralno-Lyubinsky', 1905633: 'Ivanovka', 21139: '?', 1110772: 'Nylga', 1711317: '?', 1927897: 'Romitan', 1026892: 'Maydanskoe', 1129174: 'Izhmorsky', 19997: '?', 19646: 'Zafarabad (zafarabadsky Rayon)', 1943608: 'Jurbarkas', 1927388: '?', 4124806: 'Nouâdhibou', 1915043: '?', 1508221: 'Morshin', 1060606: 'Anufrievo', 1714213: 'Kamashi', 13681: 'Samarskoe', 1097371: 'Kutema', 18076: 'Kostyukovichi', 1154542: 'Verkhnee Dubrovo', 1917414: '?', 14895: 'Torbeevo', 1155042: 'Belovodye', 17444: 'Malinovka', 1151296: 'Ocher', 1906125: 'Lynchburg', 1030946: 'Khrabrovo', 5430745: 'Bestyube ', 1500348: 'Pervomayskoe', 1505808: 'Glebovka', 1505810: 'Dymer', 22490: 'Berezan', 1124718: 'Gusinoe Ozero', 1144730: 'Uvalskoe', 2069: 'Ust-Abakan', 21561: 'Belitskoe', 3194: 'Novoslobodsk', 21320: 'Seversk', 1121860: 'Plotava', 1500720: 'Strizhavka', 1145547: 'Krutinka', 1138147: 'Krasnaya Zvezda', 6234: 'Kudever', 1041800: 'Poputnaya', 1902167: 'Yangiabad (yangiabadsky Rayon)', 5761: 'Sosnovka', 1005572: 'Slantsy (selo)', 13694: 'Uvat', 4447: 'Pilna', 1053300: 'Narovatovo', 1505755: 'Shevchenkovo', 1507951: 'Radekhov', 18845: 'Korzhovo-Golubovka', 1107113: 'Dedilovo (dedilovsky S/o)', 1107112: 'Dedilovo (bykovsky S/o)', 2737: 'Glevakha', 2199: 'Bolshoe Sorokino', 1943414: '?', 1939435: '?', 7168: 'Usolye', 1503289: 'Ocheretinoe', 9056: 'Shigony', 1136932: 'Lokshino', 4519061: 'León', 2102051: 'Khalkabad (yangiyulsky Rayon)', 1014201: 'Loboykovo', 1157555: 'Vikulovo', 7890: '?', 1130636: 'Svetlopolyansk', 1113525: 'Varlamovo', 6363: 'Kambarka', 1600241: 'Omelnaya', 1512006: 'Andreevka', 1505818: 'Nizhnyaya Dubechnya', 1068139: 'Verkhozim', 1921457: 'Sovkhoz Im. Karla-Marxa', 1917534: 'Cesvaine', 1934537: '?', 1910974: 'Brooklyn', 1936709: '?', 1508991: 'Bannovka', 5308449: 'Westcliff-on-Sea', 1505807: 'Gavrilovka', 15940: 'Pakhtaabad (pakhtaabadsky Rayon)', 1013697: 'Ivanov', 1517457: 'Shargun', 1071241: 'Bogdanovo', 1071377: 'Mikhaylov Pogost', 1942388: '?', 1802431: 'Cloppenburg', 4238242: 'Farnborough', 8748: 'Zimovniki', 1702099: 'Karasu', 1060097: 'Ivashkovo', 1083316: 'Kamyshla', 5979: 'Oxovsky', 1511347: 'Berezhany', 1502940: 'Zhdanovka', 11627: 'Lyambir', 1705600: '?', 1702106: 'Tselinny', 1508559: 'Elanets', 1914219: 'Betalbatim', 1041687: 'Lyapino', 1509012: 'Velikaya Mikhaylovka', 1518806: 'Chak Bāglān', 1941811: '?', 1915137: '?', 1973337: '?', 1513773: 'Gvardeyskoe', 1152827: 'Vostretsovo', 5266318: 'Herford', 1902422: '?', 1505769: 'Doslednitskoe', 1122595: 'Podsosnovo', 1083880: 'Pribrezhny', 11392: 'Shatrovo', 1941581: '?', 1932088: '?', 1031804: 'Gorodovikovsk', 1092124: 'Otradny', 1147259: 'Tally', 1505658: 'Isayki', 1918227: 'Oława', 1504422: 'Tyachev', 1023186: 'Malechkino', 6686: 'Borodulikha', 18218: 'Usadische', 1502268: 'Gulyaypole', 1701595: 'Dostyk (furmanovo)', 1602533: 'Kalachi', 1010384: 'Otradovka', 17567: 'Pakhachi', 1513937: 'Gorodische', 1516305: '?', 5261811: 'Beelen', 5266308: 'Warendorf', 20601: 'Tamala', 1918609: '?', 5259920: 'Laucha an der Unstrut', 1500970: 'Rososha', 1936728: 'Akkyya', 1822: 'Darasun', 1500408: 'Mityaevo', 17380: 'Gornozavodsk', 1901683: '?', 1136284: 'Pervomaysk', 18689: 'Merke', 1042213: 'Ternovskaya', 1033240: 'Glupeevo', 5426188: 'Akan', 1912490: '?', 11016: 'Volginsky', 4168395: 'Sikasso', 1600199: 'Rudsk', 5423711: 'Kodru', 1097131: 'Bolshie Tarkhany', 1712758: '?', 1112825: 'Miasskoe', 1125893: 'Filippovskoe', 1058419: 'Pokrovskoe', 1161161: 'Pokrovskoe-Sheremetyevo', 1503650: 'Luginy', 2206248: 'Wittlich', 17551: '?', 1110108: 'Staraya Gyya', 4749: 'Burkandya', 1502791: 'Krasnaya Polyana', 4192337: 'Alcamo', 1930142: 'Sandefjord', 18901: 'Voronezh', 2975: 'Warwick', 1922898: 'Aglona', 1704723: '?', 1901171: 'Nazareth Illit', 1052240: 'Mariupol', 1907343: '?', 5789: 'Vysokaya Gora', 1515025: 'Konotop', 1700832: 'Ulken Shygan', 1707073: 'Isfana', 1141119: 'Vetluzhsky', 1961162: 'Novy Afon', 15722: 'Mayna', 1942487: '?', 1705038: 'Domzheritsy', 1705565: 'Bolshie Doltsy', 16619: 'Schuchye', 1904190: '?', 1943224: '?', 5334643: '?', 1915349: 'Meria', 1931304: 'Senaki', 1516648: 'Amersfoort', 6275: 'Khotin', 1502664: 'Tsarichanka', 15076: '?', 1053308: 'Takushevo', 1702768: 'Lenino', 2208756: 'Niš', 1705943: '?', 1507625: 'Zhovkva', 8557: 'Orongoy (poselok)', 1946837: '?', 1701196: 'Mirolyubovka', 1159278: 'Gorny', 2722557: 'Lospalos', 1122401: 'Krasnoschekovo', 3959: 'Aleshki / Tsyurupinsk', 1943832: '?', 1941021: '?', 1042554: 'Tetkino', 1500360: 'Botanicheskoe', 1700040: 'Astrakhanka', 1057838: 'Synkovo', 22291: 'Progress', 1050681: 'Krasnogorsky', 1000930: 'Ostrovskaya', 1053863: 'Fedino', 1018032: 'Kurkino (selo)', 16644: 'Novoe Pole', 1601992: 'Mir', 1706131: 'Batsevichi', 1006461: 'Venetsia', 1702596: 'Kamenny Brod', 1702744: 'Vozvyshenka', 3799401: 'Liaocheng', 1929531: '?', 1513337: 'Velikaya Poboynaya', 1500338: 'Kalinino', 3805398: 'Fuzhou', 1943881: '?', 1910687: '?', 1507348: 'Shulginka', 1507314: 'Baydovka', 1505809: 'Demidov', 1161359: 'Nerubayskoe', 1515847: '?', 5428525: 'Kachar', 5266450: 'Michelstadt', 1085263: 'Osinovka', 1514310: 'Sunki', 1905312: '?', 1059836: 'Chekhov-1', 1901491: '?', 1914312: '?', 1919887: 'Saratoga Springs', 13498: 'Volokonovka', 1504968: 'Radivonovka', 1086338: 'Michurino', 1927016: 'Dashkesan', 1905526: '?', 3882: 'Molokovo', 4567710: 'Rehlingen-Siersburg', 1928992: 'Dillingen/Saar', 1011319: 'Tolbino', 20249: '?', 1965209: '?', 1905713: '?', 1931196: '?', 15273: 'Krasnolesny', 1929873: 'Sarstedt', 11785: 'Golyshmanovo', 1505330: 'Yablonov', 1235: 'Tsivilsk', 1509965: 'Lazorki', 1708959: 'Apple Valley', 1704298: '?', 1112540: 'Etkul', 1008579: 'Nizhnetroitsky', 5363: 'Rybnaya Sloboda', 1078907: 'Kamenka', 1915877: '?', 1802417: 'Gaborone', 1939681: '?', 1145243: 'Bolshie Uki', 1507716: 'Dobrotvor', 20984: 'Radivilov', 1008859: '?', 1130162: 'Yaya', 1037012: 'Isanevo', 1037010: 'Zaozerye', 1704674: 'Ala-Buka', 1106345: 'Podlesny', 1918433: '?', 1512997: 'Novoalexandrovka', 1912359: 'Lielvārde', 1506766: 'Petrovo', 1933178: '?', 1052901: 'Atemar', 1001221: 'Lokhovo', 1057325: 'Emelyanovka', 1601010: 'Kozlovschina', 1053071: 'Krasnoe Seltso', 1053043: '?', 1086746: 'Isakovo', 1086505: 'Gorodische', 1922501: '?', 10133: 'Yantikovo', 1134837: 'Sterlitamak (derevnya)', 1125973: 'Kovrov-35', 1155896: 'Polevoy', 4480969: 'Ivančice', 1077404: 'Zhdani', 16000: 'Turtas', 1138739: 'Bolshoe Kozino', 1010048: 'Troitsky', 3712477: 'Savannakhét', 1057412: 'Gubino (gubinsky S/o)', 1026072: 'Velikent', 1505781: 'Markhalovka', 1919680: '?', 1054144: 'Podyachevo', 1517458: 'Rossony', 1029795: 'Mezhdurechensk', 1144354: 'Kyshtovka', 1601301: 'Eremino', 1155620: 'Talitsa', 1037948: 'Talitsa', 6579: 'Uyskoe', 5436403: 'Päkste', 1149440: 'Chermoz', 1506112: 'Tsibli', 8730: 'Korf', 1009145: 'Novotroitskoe', 1513575: 'Novaya Ushitsa', 1958592: 'Svishtov', 4677485: 'Oaxaca de Juárez', 1078591: 'Nikolaevskaya', 1159768: 'Lugovoy', 6588: 'Yar', 1092683: 'Zavoronezhskoe', 1500999: 'Litinka', 1132130: 'Kalinino', 1051102: 'Ezhovo', 5069390: 'California', 1941120: '?', 1931136: '?', 1517023: 'Elk River', 1097477: 'Alma-Ata', 1094332: 'Sapeevo', 1918377: '?', 1913540: '?', 5330592: 'Ávila', 1975436: 'Subang Jaya', 11397: 'Bogolyubovo', 1924116: 'Alexandria', 1508066: 'Velikie Mosty', 1153137: 'Malaya Kema', 1926137: '?', 1509231: 'Lyubashevka', 1143468: 'Odintsovo', 1510348: 'Demidovka', 1502443: 'Petrikovka', 4502354: 'Grudzielec', 1943783: '?', 1503746: 'Narodichi', 1081673: 'Alexandrovo', 1085422: 'Grachev Kust', 1029699: 'Savino', 1013726: 'Lopazna', 1905976: 'Buka', 1008285: 'Sterlibashevo', 1055828: 'Kartmazovo', 1710367: 'Chula Vista', 1943992: 'Imperial Beach', 1505694: 'Revnoe', 1905735: 'Druzhba (bayautsky Rayon)', 1153766: 'Zvezdochka', 1040185: 'Kishino', 1514921: 'Strelniki', 1600060: 'Mezhdulesye', 1008853: 'Urazovo', 1713566: '?', 16706: 'Tolochin', 5266279: 'Lüdinghausen', 5126909: 'Macklin', 1505644: 'Fursy', 1518487: 'Ataki', 1040943: 'Krupskaya', 5057062: '?', 1916746: '?', 1915871: 'Oregon City', 1056728: 'Kuznetsovo', 8001: 'Pes', 1153679: 'Olenek', 1110529: 'Cheryomushki', 1516056: 'Sovetskoe', 1708022: 'Salvador', 20209: 'Svalyava', 1010495: 'Staraya Bezginka', 1067819: 'Chaadaevka', 1125559: 'Kupreevo', 1519126: 'Yavlenka', 1907931: '?', 1150489: 'Bogorodsk', 1509417: 'Delzhiler / Dmitrovka', 1706764: 'Balaovit', 2200466: 'Abovyan', 1042939: 'Zolotukhino', 1506386: 'Golovanevsk', 5304563: '?', 1504744: 'Prishib', 1099693: 'Balakovo', 1704578: '?', 1001211: 'Lazarevskaya', 1500850: 'Vishnevoe / Zhovtnevoe', 1110277: 'Vasilyevskoe', 1942389: '?', 15665: 'Stroitel', 1915886: 'Ottawa', 1917113: '?', 2207854: '?', 1916577: '?', 1951623: '?', 1507173: 'Lisichansky', 1126213: 'Tovarkovo', 5428283: 'Shakhan', 1943987: '?', 1507476: 'Komarno', 18129: 'Bogdanovka', 1082025: 'Sarai', 1516733: 'Dzhermuk', 15154: 'Tetkino', 1935677: '?', 1703850: 'Hacienda Heights', 15695: 'Dneprovskoe', 5266672: 'Winnenden', 1514150: 'Erki', 1008602: 'Sovkhoza 1 Maya', 1502903: 'Novodonetskoe', 1153532: 'Saldykel', 1076636: 'Belorussky', 1944110: '?', 1970913: 'Smederevo', 1709831: '?', 1511383: 'Borschev', 1019171: 'Ploskoe', 1139963: 'Kalinovets', 5421025: 'Kota Bharu', 4677: 'Mironovsky', 1911039: '?', 1502392: 'Meliorativnoe', 1508530: 'Sirovo', 15272: '?', 1925079: '?', 1504415: 'Solotvino', 1129619: 'Yachmenyukha', 1939322: 'Ludza', 21962: 'Dyatlovo', 1602783: 'Plisa', 1714741: '?', 2207962: 'Ballenstedt', 1916272: '?', 14771: 'Chukhloma', 1508794: 'Pershotravnevoe', 1007439: 'Kuyanovo', 1903672: '?', 1803252: 'Tamsalu', 5221: 'Mamadysh', 5407842: 'Tartaras', 1941121: '?', 1051182: 'Pizhma', 13157: 'Megri', 1907015: 'Khichauri', 1026570: 'Nariman', 1012560: 'Yalovka', 2111: '?', 1015260: 'Bolshoy', 1514908: 'Dmitrovka', 4915: 'Nikologory', 3941: 'Bolkhov', 1704429: '?', 1940799: '?', 1066902: 'Nikolskoe', 1929986: 'Abul', 1161153: 'Mezmay', 1500353: 'Stakhanovka', 1932303: '?', 1086348: 'Digora', 1086379: 'Stur-Digora', 1129335: 'Arinichevo', 1141327: 'Podlesovo', 22440: 'Manevichi', 1061282: 'Votolino', 1143892: 'Lugansk (selo)', 1009954: 'Bobrovy Dvory', 1907218: '?', 21798: '?', 1515004: 'Ozeryany', 1600886: 'Povyatye', 1601354: 'Valavsk', 18104: 'Yuzhny', 1965259: 'Leighton Buzzard', 1706167: 'Bronnaya Gora', 5110: 'Firovo', 4544967: 'Magenta', 1117964: 'Nazarovo', 1084791: 'Dergachi', 1014393: 'Bereslavka', 1501534: 'Mironovka', 1927610: '?', 1031734: 'Mezhdurechye', 5038028: 'North Windham', 1113821: 'Meskety', 1705201: 'Burlecheny', 1016175: 'Glushkovo', 11287: 'Nizhny Enangsk', 1944212: '?', 1023511: 'Glupovskoe', 1912558: '?', 4978284: 'Wildwood', 15501: 'Valki', 1512145: 'Gontov Yar', 1008117: 'Krasnaya Gorka', 1008102: 'Baygildino', 1918278: '?', 1518712: 'Buynovichi', 1515590: '?', 4176505: 'Sfax', 1943665: '?', 1002825: 'Ivanovo (derevnya)', 1026334: 'Khosrekh', 1501333: 'Gubnik', 6229: 'Kristinehamn', 1950542: '?', 5056390: 'Alabama', 1112398: 'Pavlovsky', 1059131: 'Lozhki', 1504168: 'Vilok', 1920368: 'Upland', 5081388: 'Bennington', 1516831: '?', 1119489: 'Ivanovo (derevnya)', 7183: 'Abingdon', 1930471: '?', 1041757: 'Kamchatka (khutor)', 1029996: 'Voronezh (derevnya)', 1910693: '?', 1121488: 'Budalan', 1121490: 'Kunkur', 1057219: 'Polushkino', 1057231: 'Sanatory Im Gertsena', 1092746: 'Novonikolskoe', 1915491: '?', 1123695: 'Snezhnogorsky', 1908432: 'Michigan City', 1944128: '?', 1944127: '?', 1942192: '?', 1957718: '?', 1907117: '?', 1515859: 'Jaén', 1158602: 'Alar', 1159311: 'Bogorodskoe', 1143625: 'Varlamovo', 1915786: 'Oak Park', 6561: 'River Grove', 1139957: 'Vasilsursk', 3924: 'Chattanooga', 1911547: '?', 1124634: 'Tsolga', 1124344: 'Onokhoy', 1156498: 'Zyryanskoe', 1959008: 'Pennsylvania Furnace', 1154066: 'Krasnopolye', 1135937: 'Imbinsky', 1701736: 'Izumrudny', 1941605: '?', 1935930: '?', 21095: 'Ereymentau', 1943915: '?', 1710390: 'Cleveland', 1152948: 'Sirenevka', 1701478: 'Lugovoy', 1155968: 'Azanka', 1129153: 'Sosnovka', 1129730: 'Kamenka', 1701969: 'Novoalexeevka', 1083014: 'Bogatoe', 1711012: '?', 1700195: 'Ualikhanov', 1016064: 'Mulino', 1136813: 'Yalay', 1918870: '?', 19189: 'Leninskoe', 1157880: 'Ognevo', 1701405: 'Oytal', 1507068: 'Melovoe', 1502537: 'Illarionovo', 1923330: '?', 1114516: 'Polevoy Sundyr', 1128585: 'Yurty', 1081547: 'Kuzminskoe', 1510929: 'Gruzskoe', 1944264: '?', 1152691: 'Tyumen (derevnya)', 1009198: 'Bukhara', 1941024: '?', 3174085: 'Adama', 1512561: 'Alexeevka', 8703: 'Vengerovo', 1901813: 'Pristan Przhevalskogo', 1036821: 'Storozhevsk', 1121584: 'Manzherok', 1136982: 'Gromadsk', 1511272: 'Stepanovka', 1926755: 'Ayntap', 22431: 'Rudolstadt', 1941023: '?', 1516842: 'Northbrook', 2207656: 'Schaumburg', 1712156: 'Mundelein', 1148949: 'Komary', 1146355: 'Novouralsky', 1159540: 'Bograd', 1510955: 'Saltikovo', 1158849: 'Primorsky', 1153716: 'Tattinsky', 1504867: 'Bolgarka / Kolarovka', 1121582: 'Kyzyl-Ozek', 1003157: 'Pertominsk', 1512003: 'Shumsk', 1121897: 'Sarasa', 1505679: 'Voronkov', 1503055: 'Mangush (pershotravnevoe)', 1515592: 'Feodosia-13', 1014677: 'Kumylzhenskaya', 1701213: 'Toskayyn', 1517671: 'Leningradskoe', 14380: 'Ivatsevichi', 1514044: 'Stetsovka', 1040789: 'Tverskaya', 7450: 'Pivovarikha', 1006890: 'Buraly', 2414: 'Pravokubansky ', 1502760: 'Minkovka', 1917590: '?', 1127884: '9 Km Avtodorogi Irkutsk-Shelekhovo', 1122299: 'Stolbovo', 1939879: '?', 1153563: 'Tyungyulyu', 1910746: 'Kemin', 17570: 'Dzerzhinskoe', 1941124: '?', 1008653: 'Zubovo', 1104141: 'Lukovnikovo', 1504509: 'Berestovoe', 1504206: 'Zhdeneevo', 1912223: '?', 7364: 'Orsha', 1601730: 'Koshara', 5195: 'Nikiforovka', 1041918: 'Oktyabrsky', 1100047: 'Ragodino', 1905596: '?', 1512076: 'Novonadezhdino', 1503106: 'Novoazovsk', 1701195: 'Ulgili-Malshy', 1675: 'Mogoytuy', 21158: 'Kryzhopol', 1010287: 'Verkhnyaya Pokrovka', 1054867: 'Gomovo', 1512637: 'Liptsy', 1502772: 'Soledar', 1503123: 'Vysokopolye', 1159274: 'Amgun', 1008298: 'Aygul', 1036635: 'Podcherye', 1004955: 'Bishkain', 1057172: 'Moskvoretskogo Lesparkkhoza', 1000105: 'Dagestanskaya', 1510921: 'Shevchenkovo', 3125428: 'Solákion', 1154002: 'Tikhmenevo', 1803244: 'Kunda (kunda)', 15866: 'Sonkovo', 1128336: 'Alzamay', 1014442: 'Antipovka', 2276: 'Volovo', 1048660: 'Spasskoe', 18094: 'Ryazantsevo', 1006730: 'Nadezhdinsky', 6251: 'Petukhovo', 1908107: '?', 1507743: 'Vinniki', 18375: 'Dondyushany', 1509403: 'Serpnevoe', 3405: 'Mariinsky Posad', 1941894: '?', 1509487: 'Gogolevo', 5261755: 'Langerwehe', 12214: '?', 15574: 'Almazny', 1502927: 'Bulavinskoe', 1942327: '?', 1943991: '?', 1511472: 'Grimaylov', 1924535: '?', 1714828: 'Randers', 1127205: 'Sadovy', 1110327: 'Tura', 1714543: 'กรุงเทพมห&', 1803474: 'Wedel', 22317: 'Laish', 1003096: 'Kurgan (derevnya)', 1932373: '?', 1924724: '?', 6411: 'Suna', 1510920: 'Shalygino', 1040724: 'Supsekh', 9570: '?', 1935149: '?', 12224: 'Great Yarmouth', 1944279: '?', 5839: 'Soldatskaya', 1136224: 'Kavkazskoe', 1502602: 'Devladovo', 1053801: 'Vinogradovo', 1951746: '?', 1957241: '?', 1010378: 'Krasnaya Yaruga', 1010396: 'Sergievka', 1972037: '?', 1946393: 'Glandorf', 1517359: '?', 1504615: 'Gulyaypole', 1926986: 'Ohrdruf', 1505814: 'Lebedovka', 1083035: 'Pechineno', 1705204: 'Kvasevichi', 1938002: '?', 2208493: '?', 1086402: 'Kizlyar', 1517325: 'Oguz', 5266747: 'Walldürn', 1351: 'Ivanovka', 16723: 'Velikodolinskoe', 1144459: 'Tashara', 1602521: 'Zavishino', 1930608: '?', 1513135: 'Belogorye', 1080960: 'Miloslavskoe', 1509281: 'Ovidiopol', 1515645: 'Timiryazevo', 1134973: 'Tyulkovo', 1084625: 'Malaya Semenovka', 1708420: 'Sadovoe-1', 1042071: 'Oktyabrsky', 4562: 'Yantarny', 1711502: 'Lachin', 1507519: 'Mikhaylevichi', 1906468: '?', 1505443: 'Rozhnyatov', 10684: 'Oparino', 1509095: 'Primorskoe', 2461: 'Shu', 1148493: 'Kazanka', 1148039: 'Krasny Kommunar', 1060250: 'Litvinovo', 1113939: 'Altyshevo', 1500885: 'Glukhovtsy', 1139255: 'Pamyat Parizhskoy Kommuny (ppk S/s)', 1051147: 'Medvedevo', 1916324: '?', 1092086: 'Olgino', 1938851: '?', 1075887: 'Seredka', 1100433: 'Ozerki', 1123221: 'Troitskoe', 1123634: 'Novobureysky', 17440: 'Im. Abdurakhmana Dzhami (kuybyshevsk)', 1004792: 'Andreevka', 1948708: '?', 1963729: '?', 1040441: 'Suday', 5054746: 'Delaware', 1159942: 'Ugut', 1123423: 'Makarovo', 1922413: '?', 4706207: 'El Estor', 1078113: 'Dubovskoe', 1500199: 'Klepinino', 10034: 'Tilichiki', 1903053: '?', 1041212: 'Dyadkovskaya', 1086460: 'Oktyabrskoe', 1514318: 'Vesely Kut', 12213: 'Turtkul', 1123037: 'Verkh-Suetka', 1158405: 'Emurtlinsky', 1926696: '?', 1515583: '?', 1068240: 'Bolshoy Vyas', 1059826: 'Troitskoe', 1922871: '?', 1503425: 'Soloveevka', 3556: 'Oktyabrsky', 13385: 'Novaya Zaimka', 11248: 'Ålesund', 1965950: '?', 1968751: '?', 7743: 'Orda', 3840612: 'Fujinomiya', 1143987: 'Kolyvan', 16561: 'Ust-Vaenga', 1096866: 'Kutlu-Bukash', 1936602: '?', 1935587: 'Nau', 1518440: 'Paramus', 1085016: 'Vinnitsa', 1082859: 'Lesnoy', 1713836: 'Kupchin', 1700056: 'Kamyshenka', 1709368: 'Branson', 1956205: '?', 1049714: 'Troekurovo', 1518666: 'Ashtabula', 1099082: 'Korolevschina', 1930279: '?', 1931782: '?', 1505752: 'Semipolki', 1000002: 'Adygeysk', 1500032: 'Kashtany', 1504685: 'Gusarka', 1106845: 'Zakopy', 1142118: 'Pavlovo', 1929605: 'Balmoral', 1113935: 'Shelkovskaya', 22264: 'Domanevka', 1711209: 'East Hartford', 9960: 'Naugatuck', 1944510: '?', 5331528: 'Askvoll', 1509665: 'Lanna', 1083721: 'Bogdanovka', 1903338: '?', 1130701: 'Moskva (derevnya)', 6292: 'Ust-Barguzin', 1941866: '?', 1513285: 'Khmelevka', 1951518: '?', 1914337: 'Leninskoe', 1505731: 'Velikaya Dimerka', 1078702: 'Millerovo', 1507540: 'Stebnik', 18440: 'Snetin', 15045: 'Teplik', 1500039: 'Novopavlovka', 1007081: 'Kaltasy', 1701409: 'Sarymoldaev', 1500410: 'Molochnoe', 1516182: '?', 1515179: 'Kholmy', 1700277: 'Petrovka', 1706188: '?', 1503199: 'Komsomolskoe', 1503085: 'Pavlovka', 1518993: 'Tsalendzhikha', 1703304: 'Lanzhou', 1707031: '?', 1922350: '?', 1092020: 'Novoblagodarnoe', 1920111: 'Vodňany', 1502520: 'Saxagan', 1937227: '?', 1056100: 'Lovtsy', 1052444: 'Dubitel', 1099516: 'Knyazhi Gory', 1142823: 'Pizhma', 1056439: 'Uvarovka', 1092736: 'Michurinsky Svkh', 5266350: 'Delbrück', 5266313: 'Rietberg', 1514395: 'Verkhnyachka', 3834914: 'Onna', 5422204: 'Kyōtanabe', 1161275: 'Shevchenkovo', 1901135: 'Beitar Illit', 22209: 'Loev', 1936457: '?', 1947741: '?', 1907939: '?', 1128176: 'Makarovo', 1058133: 'Nikulino', 1919772: 'Boston', 1949356: '?', 1032336: 'Borisovo', 14063: 'Kolodischi', 11533: 'Lincroft', 1059904: 'Dmitrovsky Pogost', 3785432: 'Yancheng', 1051906: 'Krasnaya Polyana', 1151584: 'Yugo-Kamsky', 1071812: 'Opukhliki', 1036783: 'Bogorodsk', 1518146: 'Oktyabrsky', 2722620: 'Saint-Pierre', 1155459: 'Kuzino', 3676907: 'Khon Kaen', 21450: 'Bakht', 1967479: 'Oktyabrsky', 1931398: '?', 15635: 'Askino', 1701764: 'Aktobe', 1715117: '?', 20576: 'Stepankovo', 1153192: 'Ilinka', 21277: 'Zaozerny', 1935087: '?', 20738: '?', 1032482: 'Dyatkovo', 5696: 'Rechitsy', 1934757: '?', 1703886: 'Jüterbog', 5776: 'Longyugan', 1927184: '?', 1512481: 'Kurilovka', 1025611: 'Dzerzhinsky', 1707268: 'Manalapan', 5056521: 'Arlington', 5022412: 'Almond', 3793808: 'Qufu', 5072121: 'Harrisburg', 5082508: 'Alaska', 1903795: '?', 1916552: 'Kaspi', 1137645: 'Kaminskoe', 1513087: 'Brilovka', 1013539: 'Mishkovka', 1708896: 'Nuri Vakhsh', 11053: 'Kaarst', 4938: '?', 8520: 'Molvotitsy', 1086186: 'Burny', 1909490: 'Apeldoorn', 1901531: '?', 1508305: 'Ivano-Frankovo', 1078325: 'Maykopsky', 4362187: 'Kaldenkirchen', 1136474: 'Novoselovo', 1705845: '?', 1913940: 'Kuva', 1008677: 'Milovka', 1153186: 'Rudnevo', 1040763: 'Kurinskaya', 1940956: '?', 3739: 'Águeda', 1079226: 'Primorka', 6399: 'Baykit', 1078263: 'Novoivanovka', 1154911: 'Sama', 1927100: '?', 1516989: '?', 1943825: '?', 1505964: 'Dmitrovka', 1503146: 'Gornyak', 1089325: 'Gabaevschina', 4025387: 'Thiès', 1092080: 'Irgakly', 1161744: '?', 1144157: 'Mayskoe', 1927195: 'Ventimiglia', 1902486: 'Kuvasay', 1149226: 'Osinovik', 1512791: 'Velikaya Alexandrovka', 1517626: 'Pacifica', 1127447: 'Bira', 1112646: 'Beregovoy', 1941566: '?', 1934228: '?', 1922034: 'West Kirby', 1971861: '?', 20720: 'Sukkozero', 1907897: '?', 6249: '?', 7962: 'Karkateevy', 1709983: 'Ravda', 1507010: 'Beloe', 4905: 'Pordenone', 1023683: 'Pacha', 1935642: '?', 1504818: 'Pologi Selo', 1142969: 'Usta', 1944671: 'Borne', 2722545: 'Thimphu', 1944623: '?', 1903162: '?', 1096219: 'Timyashevo', 1085867: '?', 22692: 'Krasilov', 1506145: 'Romashki', 1130950: 'Zuevka', 1091879: 'Prikumskoe', 1944395: '?', 1084650: 'Sukhaya Elan', 1054315: 'Zarya Podmoskovya (gpz)', 1502481: 'Vishnevoe', 1942652: 'Scarsdale', 1944687: '?', 1500075: 'Zuya', 1903392: 'Akhuryan', 1011074: 'Novocherkassky', 1094187: 'Umet', 18477: 'Dyachevo', 1504978: 'Bogorodchany', 3831: 'Arkadak', 1513587: 'Khrebteev', 1512458: 'Krasnokutsk', 2205245: '?', 1032472: 'Dvortsy', 1518066: 'Novopokrovka', 1512094: 'Guty', 1154796: 'Volchansk', 1145937: 'Bolshegrivskoe', 1946397: '?', 1505782: 'Maryanovka', 1600277: 'Vysokoe', 1515772: 'Yaren', 1910689: 'Texas City', 1971019: '?', 3156242: 'Denizli', 1516068: 'Taranto', 1932439: '?', 1702655: 'Sokologorovka', 1150620: 'Nevolino', 1600099: 'Chernavchitsy', 17557: 'Cherikov', 1600385: 'Zherebkovichi', 1007520: 'Isimovo', 1921944: 'Bethlehem', 1152111: 'Foki', 1509341: 'Kapustyanka', 1509276: 'Molodezhnoe', 1133808: 'Kichma', 1912605: '?', 1146089: 'Novoomsky', 1081125: 'Novopanskoe', 1519050: 'Krasny Yar', 1015529: 'Dobrinka', 1138760: 'Lukino', 1083419: 'Malaya Malyshevka', 22397: 'Okny / Krasnye Okny', 1136843: 'Svetlogorsk', 1911109: '?', 1023869: 'Sadovoe', 1025363: 'Latnaya', 1510289: 'Rafalovka', 1944734: '?', 1602649: 'Naroch', 1037060: 'Yaksha', 1711434: '?', 1902673: '?', 3805234: 'Ganzhou', 1515589: 'Novgorod-Seversky', 4103: 'Yavorov', 1959490: '?', 14590: 'Voronovitsa', 7360: 'Krasnaya Sloboda', 1146960: 'Starokulsharipovo', 8831: 'Valka', 1114401: 'Khuchel', 1115649: 'Turmyshi', 1505266: 'Pechenezhin', 1515216: 'Makoshino', 1506199: 'Rozkoshnaya', 4542: 'Gatovo', 1155157: 'Obukhovskoe', 15702: 'Lyuban', 1511799: 'Skalat', 1922960: '?', 1512589: 'Pechenegi', 1708498: '?', 1924190: '?', 21740: 'Rapid City', 1102026: 'Klimovka', 2722512: 'Bodrum', 1513867: 'Gritsev', 1928280: '?', 1700617: 'Malovodnoe', 1041210: 'Burakovsky', 1907059: '?', 1922567: '?', 1514906: 'Gorodische', 22193: 'Buryn', 1903974: '?', 1515817: 'Porto Cervo', 1976866: '?', 3980077: 'Wewak', 21938: 'Söderhamn', 1914003: '?', 1927013: '?', 1709941: 'Canton', 1005515: 'Verkhny Avzyan', 21029: 'Pervomaysk', 20414: '?', 1702605: 'Aysary', 1054122: 'Orevo', 1079893: 'Ordzhonikidze', 1945797: '?', 1930619: 'Levoča', 1019676: 'Zhokhovo', 1912082: '?', 1942419: '?', 1707095: 'Valya Perzhey', 1012198: 'Lyubechane', 1012211: 'Novy Ropsk', 1933551: 'Krasnogorsky', 1514956: 'Borzna', 7430: 'Korelichi', 1940781: '?', 1922830: '?', 1908715: 'West Springfield', 1000050: 'Natyrbovo', 1904596: '?', 4931863: 'Stone Mountain', 1803539: 'Liepa', 1105369: 'Velikooktyabrsky', 1712673: '?', 2722565: 'Cần Thơ', 1900910: 'Mihmoret', 1112525: 'Zauralsky', 9417: 'Bolshoy Karay', 1516284: '?', 3963: '?', 1014365: 'Log', 1048997: 'Parshinovka', 18417: '?', 1711666: '?', 1700548: 'Lepsinsk', 1508362: 'Novokrasnoe', 1927290: '?', 2209489: 'Oceanside', 1123625: 'Bureya', 20659: 'Konstantinovka', 1937116: '?', 1912503: '?', 1144316: 'Steklyannoe', 1909532: 'New London', 1942162: '?', 1910181: '?', 1700082: 'Marinovka', 1704309: 'Sterling', 5330080: 'Petrer', 1040824: 'Novopavlovka', 1709944: 'Canyon', 1008738: 'Mokrousovo', 1942820: '?', 1511762: 'Monastyriska', 3202: 'Mayskoe', 1123694: 'Sian', 1514293: 'Konstantinovka', 5917: 'Kalachinsk', 1518605: 'Zhdanovichi', 9598: 'Valyava', 1091437: 'Kaskadny', 1130175: 'Itkara', 21341: 'Vasischevo', 1512948: 'Maxima Gorkogo', 1504529: 'Vasilyevka', 1011158: 'Krupets', 8417: 'Chesma', 1154538: 'Beloyarsky', 111: 'Persianovsky', 19536: 'Galimy', 1514393: 'Velikaya Sevastyanovka', 1139922: 'Inzhenerny', 1114483: 'Yantikovo', 1115638: 'Mozharki', 1502820: 'Donskoe', 1944298: '?', 1057089: 'Gorlovka', 1944609: '?', 1705526: 'Geytepe', 1707211: '?', 4222: 'Omolon', 1144647: 'Myshlanka', 1013738: 'Nivnoe', 1112296: 'Kuluevo', 1154465: 'Gorodische', 1705287: '?', 1513710: 'Adampol', 1106131: 'Mordves', 1922070: '?', 1947229: 'Seda', 1913525: '?', 1704686: '?', 1950385: '?', 1109199: 'Balezino-3', 1055471: 'Petrovskoe', 1514855: 'Chudey', 1155548: 'Novoasbest', 1938841: '?', 1123913: 'Pozdeevka', 1500076: 'Zybiny', 1920161: '?', 11975: 'Afanasyevo', 1057904: 'Eldigino', 1500494: 'Ukromnoe', 1517241: 'Motol', 1500155: 'Yarkoe', 1156182: 'Tugulym', 1600847: 'Kamen', 1502568: 'Iverskoe / Dzerzhinovka', 1509622: 'Stasi', 1136236: 'Malaya Minusa', 4246: 'Lebyazhye', 1701323: 'Sarykemer', 4056718: 'Bouaké', 1128501: 'Utulik', 12746: 'Verkh-Miltyushi', 5083957: 'Gotham', 4919864: 'Massachusetts Avenue Heights', 22201: 'Dneprovskoe', 4956497: 'New Mexico', 1001015: 'Gora', 1056584: 'Fedoskino', 3959558: 'Nalayh', 1138735: 'Pravdinsk', 1915706: '?', 1700099: 'Novobratskoe', 9999999: '?', 3558: 'Shar', 3039: 'Belaya Berezka', 1503068: 'Georgievka', 1005853: 'Yazykovo', 1065983: 'Arsenyevo', 1068858: 'Sosnovoborsk', 16634: 'Nurlaty', 17720: 'Mezhdurechensk', 1709471: 'Wall', 4312: 'Novosil', 6047: 'Shilka', 1910328: '?', 1906775: '?', 1080371: 'Kletino', 1159912: 'Barsovo', 1157843: 'Strekhnino', 1935550: '?', 1114184: 'Kalinino', 1507137: 'Toshkovka', 1908141: 'Marinette', 5332370: '?', 1000959: 'Saranchikha', 1904434: '?', 1925154: '?', 1940301: '?', 3334: 'Novy', 1159084: 'Bichevaya', 1941137: '?', 1092106: 'Trunovskoe', 1931361: 'Saulkrasti', 14715: 'Voskresenskoe', 1155622: 'Trifonovo', 1048568: 'Trubnikov Bor', 1926394: '?', 1160616: 'Sosnovka', 1707451: 'Hebron', 1926325: '?', 1156042: 'Butka', 1939284: '?', 20559: 'Novoishimsky', 1933191: '?', 1923479: '?', 1712542: 'Amburan', 1045562: 'Vruda', 3812667: 'Kuala Belait', 1146725: 'Artemyevka', 2300059: 'Arslanbob', 20724: 'Kshen', 1041928: 'Stavropolskaya', 1928291: '?', 1930317: '?', 1513101: 'Solontsy', 1024864: 'Alexandrovka', 1153043: 'Frolovka', 1704425: 'Avshen', 1944763: '?', 1940414: '?', 1956544: '?', 1125575: 'Mezinovsky', 1091657: 'Sovetskoe Runo', 1148009: 'Ponomarevka', 14427: 'Novolaxkoe', 1950678: '?', 1924088: '?', 1706249: 'Ratomka', 5466: 'Golovino', 1098167: 'Dunaevo', 1102216: 'Shizderovo', 1015472: 'Nizhny Chir', 1512719: 'Kachkarovka', 1911572: '?', 1944405: '?', 1602216: 'Krevo', 1515129: 'Atyusha', 1517335: '?', 1135966: 'Tagara', 8959: 'Axarka', 1135840: 'Krasny Mayak', 1508141: 'Dobromil', 19808: 'Porechye', 1938890: '?', 1155867: 'Aramil', 1025059: 'Vitebsk', 4636106: 'Hafnarfjörður', 1961480: '?', 1914440: '?', 1517176: '?', 1705927: 'Yad Mordehai', 1129263: 'Silino', 1938085: '?', 1004340: 'Razdor', 5265149: 'Straubing', 1700132: 'Erkinshilik (pavlovka)', 1926870: '?', 1143828: 'Legostaevo', 1033617: 'Berezovka', 1150484: 'Berezovka', 1975470: 'Taivalkoski', 4904767: 'Rikitea', 1939799: '?', 1159344: 'Ussuriysky', 1110716: 'Syumsi', 1912023: '?', 1702175: 'Tagilskoe', 1110481: '?', 1111738: 'Fabrichnye Vyselki', 1500858: 'Kordelevka', 1516966: 'Kyrenia', 18890: 'Oktyabrskoe', 1518758: 'Scharbakty', 1112735: 'Zingeysky', 1701993: 'Novonezhinka', 1506721: 'Novaya Praga', 5265805: 'Kaufbeuren', 1159225: 'Mago', 1154078: 'Lesogorskoe', 1078105: 'Andreevskaya', 1912746: '?', 1918681: '?', 1011849: 'Vyshkov', 1922719: '?', 7090: 'Cheremshan', 6337: 'Ust-Kulom', 1903184: 'Bilyasuvar', 1902069: '?', 1601995: 'Voroncha', 1052050: 'Yurino', 1145464: 'Kolosovka', 1968468: 'Pitsunda', 1917455: '?', 1062783: 'Ozerki', 3740463: 'Puerto Princesa', 1045444: 'Pikalevo', 1900798: 'Mizra', 1113362: 'Klyuchevka', 5169322: 'Guissona', 1945942: 'Khazar', 18469: '?', 1938441: '?', 1145186: 'Bolsherechye', 1702810: 'Kellerovka', 1932917: 'Bathurst', 20987: 'Beliki', 1910545: '?', 1518976: 'Gindeshty', 16891: 'Mukhorshibir', 1068651: 'Pachelma (posyolok)', 1938562: 'Šalčininkai', 1095066: 'Baltasi', 1710455: 'Columbia', 10878: 'McLean', 1126479: 'Gorodischi', 21717: 'Veselinovo', 1508486: 'Stavki', 22246: 'Svetly', 20998: 'Tulchin', 1006291: 'Yangiskain', 1507161: 'Yaschikovo', 1940398: 'Zielona Góra', 13839: 'Stroevskoe', 1093642: 'Svkh Rossia', 684: 'Shamilkala ', 1054973: 'Kursakovo', 1929237: '?', 1151904: 'Suxun', 18430: 'Chishmikyoy', 9320: 'Alexeevsk', 1032580: 'Tovarkovo 1-E ', 16993: 'Gafurov', 1956635: '?', 1900455: 'Meir Shefia', 1955953: 'Schwarzenbek', 4349741: '?', 1904561: '?', 1081468: 'Putyatino', 1901963: 'Damala', 1518475: '?', 21794: 'Zhaxy', 1054729: 'Letunovo', 18151: 'Bely Yar', 1934460: '?', 1049908: 'Zlobino', 1929887: '?', 1510108: 'Semenovka', 2722553: 'Dili', 1934358: '?', 1511086: 'Olshana', 1704890: '?', 1702696: 'Korneevka', 1515059: 'Ivanitsa', 9766: 'Arshaly', 1710635: 'Gagarin (mirzachulsky Rayon)', 4026: 'Komarichi', 13453: 'Olkhovatka', 1931269: '?', 1094993: 'Kulle-Kimi', 4186230: 'Lepe', 3166: 'Meget', 1714297: '?', 1700154: 'Svobodnoe', 14029: 'Serebryansky', 1600303: 'Bereza', 1026077: 'Duzlak', 1058062: 'Zavorovo', 1118848: 'Nagorye', 21751: 'Belynichi', 1145153: 'Alexandrovka', 20397: 'Nadezhda', 1925025: '?', 1059249: 'Chernaya Gryaz', 5057063: '?', 1702479: 'Berezovka', 1515364: 'Yablonovka', 21252: 'Darina', 1909914: '?', 1150349: 'Bolshoy Gondyr', 1105642: 'Arsenyevo', 1927855: '?', 6622: 'Malorita', 1139666: 'Chulkovo', 7904: 'Borogontsy', 1153751: 'Mayagas', 1041488: 'Kalininsky', 1705256: 'Kingston', 1904347: 'Kalinovka', 1924507: '?', 1501332: 'Gordeevka', 1926144: '?', 13222: '?', 13353: '?', 1919791: 'Roswell', 1036859: 'Synya', 1003734: 'Orletsy (derevnya)', 1945512: '?', 1937873: '?', 1700545: 'Beskol', 1160869: 'Khatyrka', 1945606: '?', 9076: 'Khristinovka', 1701089: 'Verkhneberezovsky', 1709526: 'Hradec Králové', 1937771: 'Payson', 13023: 'Nalobikha', 1135595: 'Idrinskoe', 1052994: 'Lipki', 1700052: 'Kaynar', 1934080: '?', 1123245: 'Tyumentsevo', 4131237: 'Djougou', 1024871: 'Bolshaya Kazinka', 1507408: 'Podkamen', 1500226: 'Pyatikhatka', 18303: 'Volzhsky', 1913937: '?', 6385: 'Dzhalil', 1117967: 'Nekouz', 4297558: 'Hallstatt', 1503022: 'Redkodub', 1122658: 'Berezovsky', 3127581: 'Mílos', 1124127: 'Chilchi', 1927398: '?', 1918131: '?', 1067772: 'Kanaevka', 1145962: 'Slavyanka', 1123816: 'Uglovoe', 1517617: 'Kaarina', 4723: 'Zarechye', 19547: 'Mechetinskaya', 1020771: 'Terebaevo', 1138808: 'Voznesenskoe', 1078183: 'Taganrogsky', 1701267: 'Ayyrtau (zavidnoe)', 1083466: 'Klyavlino', 1504805: 'Balochki', 3685: 'Alnashi', 1500818: 'Ilintsy', 1602504: 'Khotyukhovo', 1702771: 'Voskresenovka', 1051268: 'Zelenogorsk', 1713072: '?', 1600336: 'Khidry', 1160282: 'Gorky', 1094773: 'Apastovo', 16175: 'Synzhereya', 1155632: 'Chetkarino', 1510807: 'Vorozhba', 1088110: 'Yaroslavl (derevnya)', 1010975: 'Novaya Tavolzhanka', 4978706: 'California', 1937982: '?', 1143511: 'Shakhunya (derevnya)', 1081790: 'Polyany', 1945301: '?', 1907771: '?', 1095798: 'Osinovo', 1917096: '?', 1044069: 'Ponyri 1-E', 1079501: 'Pervomayskoe', 1056806: 'Petrovskoe', 3618: 'Falenki', 1922598: '?', 1108320: 'Dubovka (kvartal 5/15)', 1076679: 'Gavry', 1502057: 'Polesskoe', 1934832: '?', 1905215: '?', 1036083: 'Voloma', 1081512: 'Vysokoe', 1943751: '?', 1117983: 'Novy Nekouz', 1504101: 'Chudnov', 1506843: 'Ivanovka', 17578: 'Guayaquil', 1957555: 'Concepción', 1951611: '?', 1501478: 'Chechelnik', 2209918: 'Greater Sudbury', 1515750: '?', 1004450: 'Volzhskoe', 1080046: 'Kalininsky', 4352398: 'Martinsried', 4346026: 'Nordhorn', 1709419: 'Bayamon', 1514411: 'Khristinovka', 1147315: 'Sukhorechka', 1708996: 'Adairsville', 1603235: 'Romanovichi', 1159002: 'Tumnin', 2101905: 'Dustabad', 22320: 'Ulla', 17348: 'Anna', 20862: 'Białogard', 1028813: 'Petrovo', 1134004: 'Tuzha', 1033121: 'Tikhonova Pustyn', 1909039: '?', 1710607: 'Culver City', 18262: 'Kholmech', 21954: 'Ashford', 1090834: 'Mariupol', 18329: 'Rzhaxa', 1512774: 'Velikaya Lepetikha', 1036720: 'Koshki', 1943836: 'Neustadt am Rübenberge', 1064858: 'Tagino', 1002585: '?', 8647: 'Kodino ', 1083757: 'Maryevka', 1126897: 'Andreevo', 18060: 'Koxun', 1942082: '?', 1702090: 'Mayskoe', 6025: 'Putilovo', 1048017: 'Kommunary', 1910827: '?', 1138750: 'Istomino', 1082729: 'Lesnaya Polyana', 1159775: 'Polovinka', 1060299: 'Trubino', 1045148: 'Kosorzha', 1714056: '?', 1938714: '?', 1028405: 'Reshma', 1094931: 'Srednyaya Korsa', 1004562: 'Stupino', 1062007: 'Kashira', 1161327: 'Kremenets', 1602220: 'Soly', 1058657: 'Mishutino', 5266815: 'Rottweil', 1091789: 'Mozdoxky', 1602707: 'Pukhovichi', 1505991: 'Gruzskoe', 18730: 'Borskoe', 1114281: 'Malye Karmaly', 1123420: 'Krutishka', 15134: 'Olaneshty', 1916559: '?', 1508673: 'Stepovoe', 1000956: 'Ryazan (derevnya)', 1915899: 'Carcassonne', 15329: 'Chernyshkovsky', 1519203: 'Spitak', 1800178: 'Byrnovo', 1012869: 'Vadkovka', 1601182: 'Obol', 1508302: 'Dubrovitsa', 1500679: 'Yalanets', 1705189: 'Menden (Sauerland)', 1905111: '?', 1706029: 'Bourges', 1803455: '?', 1045726: 'Seltso', 1504671: 'Dneprovka', 1514139: 'Stepantsy', 1041573: 'Pervaya Sinyukha', 1918218: '?', 1095445: 'Kurkachi', 1506882: 'Novoalexandrovka', 1037096: 'Mezhdurechensk', 1140601: 'Smirkino (smirkinsky S/s)', 1903444: '?', 1513021: 'Novovorontsovka', 1946238: 'Highland', 1125807: 'Gorka', 1702213: 'Uzynkol', 1942101: '?', 1511517: 'Zaleschiki', 4243659: 'Sins', 1945472: '?', 1042103: 'Zaporozhskaya', 1923987: '?', 1158290: 'Onokhino', 1093725: 'Sosnovka', 4178: 'Kolyshley', 22234: 'Bemidji', 1945482: 'Blackduck', 1945080: '?', 1917394: '?', 1968507: '?', 1944419: '?', 1121218: 'Mokeevskoe', 1123551: 'Zarechnoe', 1002088: 'Ulyanovskaya (verkhneuftyugsky S/s)', 8694: 'Sokuluk', 4440995: 'La Baule-Escoublac', 1030515: 'Maysky', 1935321: '?', 1703238: 'Auburn', 17918: 'Breytovo', 1932323: '?', 4242754: 'Andover', 1945491: '?', 21969: '?', 1902610: 'West Winfield', 1926775: '?', 1940835: '?', 1507351: 'Irmino (teplogorsk)', 4386044: 'Bremen', 4337308: 'Röbel/Müritz', 1507190: 'Klenovy', 1945502: '?', 6498: 'Severo-Kurilsk', 1513943: 'Mleev', 1945640: '?', 1935267: '?', 5267843: 'Eschwege', 19543: 'Esztergom', 5988: 'Batagay-Alyta', 1505657: 'Ivanovka', 1031032: 'Irkutskoe', 1954251: 'Tarawa', 4153760: 'Moundou', 1921844: '?', 1600699: 'Yanovichi', 1940423: '?', 1092007: 'Vysokogorny', 1153809: 'Dyabyla', 1944919: '?', 1128319: 'Rudnogorsk', 1501262: 'Udich', 11927: 'Saskylakh', 1159275: 'Berezovy', 1969002: 'Albany', 1917642: '?', 1945041: '?', 1003105: 'Lastola', 1001468: 'Ponomarevskaya', 1159223: 'Lazarev', 1504714: 'Novobogdanovka', 3736: 'Novoselitskoe', 15720: 'Nadvornaya', 1009567: 'Severny', 1157283: 'Yurga', 19962: 'Nelkan', 1711950: 'Kansas City', 1709505: 'Bolivar', 1068993: 'Sinodskoe', 1037641: 'Knyaginino', 1927476: '?', 1124794: 'Kharbyaty', 12832: 'Vakhrushev', 1509193: 'Chubovka', 1091713: 'Kazminskoe', 1518635: 'Lindsborg', 1090394: 'Talashkino', 1030439: 'Kishpek', 1500770: 'Dubovaya', 16765: 'Kozlovka', 7627: 'Sorsk', 1009206: 'Dyurtyuli', 1059774: 'Manushkino', 1029206: 'Tatischevo', 21513: 'Chistopolye', 1012094: 'Mirny', 17530: 'Khanabad', 1004368: 'Bryansky', 1502675: 'Ingulets', 1052702: 'Kochelaevo', 1943993: '?', 7877: 'Alatau', 18741: 'Mikashevichi', 1516324: 'Gorodeya', 1936463: '?', 1146384: 'Vasiss', 1138433: 'Yurgamysh', 1129101: 'Novobachaty', 4190742: 'Rende', 1705013: 'Parokhonsk', 9266: 'Podyuga', 1122252: 'Altay (poselok)', 5428284: 'Dubovka', 4345: 'Sergeevka', 1017289: 'Urusovskaya', 1080030: 'Bazkovskaya', 1084700: 'Volsk-18', 1109546: 'Ponino', 1945648: 'Malovodnoe', 1154906: 'Maslovo', 1927558: 'Eli', 1147398: 'Pleshanovo', 1937137: '?', 1500169: 'Zhuravki', 1056300: 'Krasny Baltiets', 1012697: 'Altukhovo', 1084761: 'Elshanka', 1060227: 'Dubrovo', 1505660: 'Medvin', 1505954: 'Belogorodka', 1714983: '?', 1928651: '?', 1936470: '?', 1506764: 'Novy Starodub', 1131692: 'Svetly', 1026513: 'Magaramkent', 1052173: 'Atyashevo', 3423: 'Litin', 4671: '?', 13878: '?', 4394: 'Dovolnoe', 4308129: 'Lichtaart', 1518074: 'Aalst', 4533091: 'Lier', 1503833: 'Ignatpol', 1010849: 'Shatalovka', 4361753: '?', 1041760: 'Myskhako', 1504518: 'Novotroitskoe', 1128766: 'Zvezdny', 1515336: 'Ivkovtsy', 1703300: 'Varėna', 1025548: 'Ternovka', 1094746: 'Samarkand', 1011243: 'Dobrun', 1059498: 'Shugarovo', 1963502: 'Alexandroupoli', 7344: 'Davydovo', 1001066: 'Rochegda', 1902575: 'Oostende', 1929657: '?', 4605426: 'Petrovac', 1905243: '?', 1141375: 'Gremyachevo', 22080: 'Biruintsa', 1518890: '?', 1710298: '?', 1918738: '?', 1155243: 'Nizhneirginskoe', 1918666: '?', 1093182: 'Cheboxary', 1500560: 'Medvedevo', 1516810: 'Novka', 1159316: 'De-Kastri', 1513393: 'Klubovka', 1155163: 'Poroshina', 1090793: 'Znamenka', 1108122: 'Khanino', 1929816: '?', 1029248: 'Vereschagino', 22099: 'Danu', 1130961: 'Kosino', 1927143: '?', 2722593: 'Hagåtña', 1146175: 'Dobryanka', 1106581: 'Pavlo-Khutor', 1006724: 'Kyzlar Birgan', 1923142: '?', 1921040: '?', 5261827: 'Hüllhorst', 1957693: '?', 1929554: '?', 1005577: 'Tirlyansky', 1958763: 'Bełchatów', 6267: 'Banská Bystrica', 1124624: 'Podlopatki', 17223: 'Verkhneusinskoe', 1143522: 'Bagan', 1904078: '?', 1907416: '?', 1500190: 'Amurskoe', 1509051: 'Petrovka', 1910791: '?', 1901369: '?', 1910332: '?', 1907705: 'Wilhelmshaven', 1121971: 'Srostki', 1113301: 'Poletaevo', 1509550: 'Gradizhsk', 1505935: 'Mirovka', 1516859: 'Yuzhny', 1132729: 'Ray (derevnya)', 14474: 'Balkashino', 16001: '?', 1502933: 'Olkhovatka', 20683: 'Staromyshastovskaya', 1158971: 'Orenburgskoe', 1100278: 'Goritsy', 1505680: 'Glubokoe', 1929282: '?', 9752: 'Nayman', 1160111: 'Shirokaya', 1933245: '?', 1505979: 'Tarasovka', 1145713: 'Krasnoe Znamya', 1515906: 'Kirovsk', 1500266: 'Voykovo', 1092076: 'Varenikovskoe', 12805: 'Bolshakovo', 1500684: 'Bokhoniki', 14779: 'Moskalenki', 1060949: 'Valday-3', 1109143: 'Muvazhi', 1945857: '?', 1918136: '?', 15765: 'Novoaydar', 1702776: 'Pokrovka', 21695: 'Pivdennoe', 1146844: 'Sagarchin', 1002690: 'Mezhdurechensky', 15196: 'Sia', 1944545: '?', 1507376: 'Troitskoe', 1036093: 'Lendery', 1036664: 'Gam', 1903459: '?', 1122240: 'Sokolovo', 1601965: 'Bobrovichi', 21484: 'Krivoshin', 1153380: 'Lebediny', 12491: 'Vasilyevsky Mokh', 1507731: 'Remenov', 6109: 'Stroitel', 15751: 'Pervomayskoe', 1069474: 'Chikhachevo', 1905945: '?', 1945895: '?', 1512890: 'Zhelezny Port', 1516405: 'Dusti', 16373: "Kiryat Tiv'on", 1149781: 'Ust-Kishert', 5267322: 'Mainleus', 1713857: 'Markhamat (bekabadsky Rayon)', 19812: 'Vniiss', 1921524: '?', 1920077: '?', 4295338: 'Leonding', 897: 'Sosnowiec', 1706195: 'Nezhdaninskoe (do 2000 G.)', 21178: 'Belorechensky', 1515194: 'Kulikovka', 1507425: 'Busk', 1005714: 'Kalinniki', 1709673: 'Brooklyn Park', 22549: 'Khoroshev / Volodarsk-Volynsky', 1041449: 'Petropavlovskaya', 1903240: '?', 1506463: 'Bogdanovka', 1709237: '?', 1096904: 'Urakhcha', 1512627: 'Vysoky', 15409: 'Petryaxy', 1912324: '?', 1155909: 'Schelkun', 1504519: 'Osipenko', 1500460: 'Krasnaya Zorka', 2722594: 'Dededo', 1056589: 'Khovrino', 1078698: 'Kuybyshevo', 1150363: 'Verkhnyaya Sava', 1143776: 'Nizhny Chulym', 1114147: 'Toysi', 1937908: '?', 1036571: 'Khelyulya', 1519227: '?', 1512968: 'Korobki', 1121998: 'Novokulundinka', 1124115: 'Lopcha', 1063952: 'Levocha', 1967146: '?', 1152437: 'Trun', 5710: 'Sescha (poselok)', 1702707: 'Blagoveschenka', 1926280: '?', 1918739: 'Kazybek', 20280: 'Numgi', 1155838: 'Znamenskoe', 1153888: 'Uglezavodsk', 1132090: 'Khristoforovo', 1945619: '?', 1703696: '?', 1000170: 'Starobzhegokay', 1928826: '?', 1500390: 'Vorobyevo', 6299: '?', 1010227: 'Yablonovo', 5040: 'Mama', 3838638: 'Kamakura', 1051187: 'Russky Kukmor', 1161059: 'Panaevsk', 1148363: 'Novokamenka', 1501289: 'Sutiski', 1159364: 'Elabuga', 1157847: 'Cheremshanka', 1159665: 'Ust-Byur', 1962921: '?', 1928598: '?', 21424: '?', 1004162: 'Aktyube', 1934912: '?', 1098968: 'Solnechny', 1160925: 'Leningradsky', 21858: 'Novaya Lyalya', 1155422: 'Lobva', 1100578: 'Kolpino (derevnya)', 1922597: '?', 1937223: '?', 1945033: '?', 1917916: '?', 1054196: 'Sportbaza Ozero Krugloe', 1012699: 'Belgorod (poselok)', 1112783: 'Starokamyshinsk', 1128729: 'Tyumensk', 1140634: 'Timiryazeva (timiryazevsky S/s)', 1926302: '?', 1517149: 'Kongaz', 1955974: '?', 1901534: '?', 1500547: 'Schebetovka', 2722502: 'Fethiye', 1926558: '?', 1939749: '?', 1906111: '?', 1933205: 'Zhergalan', 9439: '?', 12489: 'Shushkodom', 1502100: 'Turiysk', 1127599: 'Beseda', 2722614: 'Musul', 8367: '?', 1958398: '?', 1600625: 'Nurovo', 1135066: 'Rassvet', 1078623: 'Gukovo (khutor)', 1600065: 'Starye Peski', -762: -762, 1702182: 'Apanovka', 1928006: '?', 1702485: 'Kalinovka', 5070761: 'East Pittsburgh', 1908647: '?', 1122132: 'Zalesovo', 1121685: 'Ulagan', 1516199: '?', 1042373: 'Vostochny', 19444: 'Buzharovo', 1509332: 'Yakovlevka', 1508102: 'Sebechov', 1937021: 'Shamakhy', 1121510: 'Uzon', 1063930: 'Kabozha', 1517290: 'Elizabeth', 1702007: 'Antonovka', 1918859: '?', 1945206: '?', 1143869: 'Shibkovo', 1136032: 'Krasnoturansk', 1146065: 'Klyuchi', 4224615: 'Kokkedal', 20336: 'Vargashi (pgt)', 1923566: '?', 1931353: '?', 1709830: '?', 1703721: '?', 1905978: '?', 21336: '?', 1519262: 'Jelšava', 21480: 'Alexandrovka', 1037023: 'Chukhlem', 1903586: '?', 1500176: 'Lgovskoe', 17171: 'Maloyaz', 1008201: 'Tatarsky Maloyaz', 1032865: '?', 1945353: 'Paravakar', 1702112: 'Altynsarino', 1091721: 'Novoekaterinovskaya', 1919661: '?', 21719: 'Neftchala', 16802: 'Karpenkovo', 1500013: 'Rybachye', 1500008: 'Malorechenskoe', 1516796: '?', 1957227: '?', 1516004: 'Agadyr', 15643: 'Moy-Urusta', 1713292: 'Sardoba', 1509002: 'Kalchevaya', 1504865: 'Zelenovka', 1504883: 'Yuryevka', 1505096: 'Gorodenka', 1512514: 'Orelka', 1922763: 'Gendzhlik', 1064386: 'Podgoschi', 1936924: '?', 5423713: 'Kondritsa', 1931115: '?', 1504946: 'Chernigovka', 21824: 'Dvurechnaya', 2203654: 'Alger', 1938634: 'Andizhan (akaltinsky Rayon)', 7534: '?', 1938639: '?', 20347: 'Bashmakovo', 5364712: 'Néa Moudhaniá', 1011884: 'Chekhov', 1501921: 'Shtun', 1081037: 'Vilenka', 6138: '?', 1151794: 'Krasny Bereg', 1518468: 'Dzholtay', 1042076: 'Severin', 1945815: '?', 5266832: 'Trossingen', 1715236: '?', 1972696: 'Nettuno', 1903716: '?', 1042119: 'Tamansky', 1506746: 'Uspenka', 1513981: 'Svechkovka', 20971: '?', 1507681: 'Zolochev', 1052839: 'Krasnaya Podgora', 1079505: 'Remontnoe', 1060030: 'Cherusti', 1059984: 'Pustosha', 1934578: '?', 1141071: 'Sukhonoska', 1516237: 'Leninsky', 1907616: '?', 1506797: 'Iosipovka', 1112090: 'Timiryazevsky', 1146847: 'Sovetskoe', 1514484: 'Irkliev', 1108346: 'Maysky', 1515581: '?', 1902923: '?', 1054402: 'Stupino', 1514343: 'Talyanki', 22516: '?', 1045727: 'Seltso', 1510374: 'Mirogoscha Vtoraya', 1040961: 'Divnomorskoe', 1922333: 'Huelva', 5423698: 'Budeshty', 1707134: 'Mafeteng', 1909681: '?', 8877: 'Sharkovschina', 1011246: 'Dubrovka', 1030526: 'Priblizhnaya', 1506073: 'Tripolye', 1157995: 'Okunevskoe', 1508995: 'Vinogradovka', 1900878: 'Kfar Sirkin', 1906643: '?', 1937461: '?', 1685: '?', 1517130: '?', 1710424: 'College Place', 1602480: 'Timkovichi', 1111746: 'Baklushi', 1084095: 'Khvorostyanka', 1060431: 'Afrikanda 2', 1513606: 'Polonnoe', 1910522: '?', 1924224: 'Maevka', 1058719: 'Sergiev Posad-14', 1051821: 'Sernur', 1050754: 'Silikatny', 14133: 'Kilemary', 1711178: 'Dixon', 1946239: '?', 1079242: 'Sovetka', 1602571: 'Axakovschina', 1113704: 'Petropavlovskaya', 1925662: '?', 1921408: 'Lučenec', 1092363: 'Sukmanovka', 1915965: '?', 1969806: 'Vasilyevka', 21262: '?', 1111960: 'Surskoe', 1945192: 'Latakia', 6158: 'Derby', 22327: 'Lukov', 1124149: 'Svobodny Trud', 1153773: 'Eldikan', 3664: 'Khulimsunt', 1905112: '?', 1707308: 'Avon Lake', 7355: 'Vaiņode', 1508830: 'Vesely Kut', 1508841: 'Novaya Ivanovka', 1925179: 'Tuscaloosa County', 1123549: 'Vozzhaevka-1', 1908303: '?', 1709713: 'Stroudsburg', 1711213: 'East Stroudsburg', 1152806: 'Kirovsky', 13440: 'Plymouth', 7181: 'Urdo-Aga', 1153434: 'Orget', 1919119: 'Poplar', 1143551: 'Savkino', 1709485: 'Bismarck', 1153428: 'Dyullyukyu', 1517587: '?', 1901920: '?', 1901699: '?', 1700159: 'Kovylnoe', 1148770: 'Bolshaya Sosnova', 1151178: 'Dubrovo', 1081346: 'Vostochny', 1934147: '?', 1122022: 'Mikhaylovka', 1122910: 'Znamenka', 1915824: 'Oakland Park', 4684200: 'Chichén-Itzá', 1701027: 'Makhambet', 1083393: 'Bobrovka', 1136157: 'Kamarchaga', 1134753: 'Khailino', 1920148: 'Sylva', 1153396: 'Abaga', 1144781: 'Kourak', 946: 'Cherdyn', 14918: 'Yugorenok', 1025041: 'Peski', 1049444: 'Denisovo', 13548: 'Skole', 1700554: 'Sakhzavod', 1518828: 'Ahmedabad', 1938424: '?', 1941018: '?', 1015242: 'Privolny', 1510246: 'Sosnovoe', 1908832: '?', 10923: 'Melnikovo', 1946050: '?', 6506: 'Lebanon', 1933886: '?', 18993: 'Bolsheokinskoe', 1147763: 'Oktyabrskoe', 1127639: 'Tanguy', 1091947: 'Raduga', 1138832: 'Kamenki', 20538: 'Rudny', 1107323: 'Mikhaylovsky', 1107089: 'Borodino', 1122084: 'Titovka', 1904981: 'Bir Kerala', 1939624: 'Norashen', 1112009: 'Terenga', 3684: 'Kirovsky', 1501256: 'Sobolevka', 1515443: 'Sosnitsa', 1946177: '?', 1129052: 'Klyuchi', 20961: 'Mārciena', 1903399: '?', 5332415: 'Verbochki', 1136580: 'Troitsa', 9206: 'Kadoshkino', 1511085: 'Nedrigaylov', 1098350: 'Kuzhenkino', 1121588: 'Souzga', 1004105: 'Shegovary', 1508755: 'Lysaya Gora', 9002: 'Zborov', 1000102: 'Grozny (poselok)', 1128015: 'Kunerma', 1153245: 'Khasan', 1153667: 'Torgo', 1126556: 'Peksha', 1515813: 'Altyaryk', 1600505: 'Linovo', 1913177: '?', 1113426: 'Kamensky', 1946335: '?', 1920585: '?', 1107225: 'Secheno', 1028337: 'Korsakovo', 1044071: 'Ponyri', 1503486: 'Barashi', 1066501: 'Ivanovskoe', 1511262: 'Nizhnyaya Sirovatka', 5332692: '?', 1500362: 'Zimino', 1067631: 'Studenka', 1702397: 'Pavlodarskoe', 1513957: 'Birlovka', 1506308: 'Chernyakhovka', 1514799: 'Vasilyevka', 5266206: 'Meerbusch', 1011639: 'Lyubokhna', 13119: 'Kandyagash', 1926670: '?', 4056006: 'Divo', 1514174: 'Derenkovets', 1132572: 'Chursya', 7285: 'Kiryat Malakhi', 1912692: '?', 1709168: 'Acworth', 18880: 'Dukent', 8963: 'Ketchenery', 1069419: 'Suchkino', 1946361: 'Chust', 1129543: 'Kuzedeevo', 1147298: 'Ilek', 1082262: 'Pobedinka', 1121915: 'Sitnikovo', 1089260: 'Shatalovo 1-E', 1155300: 'Verkh-Neyvinsky', 1518847: 'Vernon', 1602623: 'Gorodok', 1158271: 'Kulakovo', 1114339: 'Vutabosi', 1045079: 'Chernyanka', 1038626: 'Ivanovo (derevnya)', 1955000: '?', 1905240: '?', 1707940: '?', 1111020: 'Lynga', 15377: 'Yakshur-Bodya', 1158084: 'Novotroitsk', 1509284: 'Roxolany', 1501236: 'Velikaya Mochulka', 1043249: '?', 1962307: 'Athabasca', 1503058: 'Priazovskoe', 1917805: 'Siesikai', 1042746: 'Selino', 1929258: 'Maple Grove', 1912528: '?', 1508189: 'Bratkovtsy', 18213: 'Ekimovichi', 1927253: '?', 1924138: 'Piešťany', 1674: '?', 1135731: 'Stepanovka', 1913096: '?', 1931647: '?', 1704840: 'Zhemchuzhny', 1508277: 'Turka', 1126880: 'Cherkutino', 1946412: '?', 1946414: '?', 1505820: 'Novye Petrovtsy', 1945348: '?', 1907230: '?', 1030811: 'Aprelevka', 2722651: 'Barranquilla', 1122159: 'Golukha', 1946037: '?', 1713595: '?', 1907942: '?', 1026241: 'Nechaevka', 1905274: '?', 1146759: 'Savelyevka', 1513277: 'Satanov', 1084662: 'Baltay', 1006402: 'Duvan', 1111649: 'Praskovino', 1153331: 'Shumnoe', 1902178: 'Libourne', 1127452: 'Izvestkovy', 1946120: '?', 1150802: 'Grigoryevskoe', 1023936: 'Sloboda', 1512260: 'Kazachya Lopan', 1512911: 'Chulakovka', 1702206: 'Ershovka', 1160166: 'Kurort-Darasun', 1905717: 'Springfield', 5011224: 'Fredericksburg', 1083869: 'Stepnyaki', 1921217: '?', 1137237: 'Svetly Dol', 1511054: 'Lipovaya Dolina', 1941330: '?', 15376: 'Selychka', 1091900: 'Zaterechny', 1907657: '?', 1925256: '?', 1123735: 'Srednebeloe-2', 1067762: 'Vysheley', 1516355: '?', 11146: 'Fedovo', 1937827: 'Kuldīga', 1122819: 'Mirny', 1946786: '?', 1506030: 'Zelenki', 1147590: 'Matveevka', 5451359: 'Ramallah', 1048381: 'Pashozero', 1902016: '?', 1509884: 'Ryaskoe', 1715436: '?', 5020069: 'Miami', 1943152: '?', 1510519: 'Korets', 1154591: 'Kedrovka', 1123701: 'Yubileyny', 1102138: 'Rasskazovo', 1600145: 'Osipovichi', 9187: 'Maribor', 1060455: 'Chavanga', 1060382: 'Pushnoy', 1504350: 'Kosovskaya Polyana', 1937109: 'Armidale', 1711982: 'Garden City', 5058107: 'East Garden City', 1006739: 'Saratovsky', 1129352: 'Krasnoe', 1129359: 'Musokhranovo', 1949443: 'Gillingham', 1042266: 'Olginka', 1902457: '?', 1933734: '?', 1707720: '?', 1049532: 'Chermoshnoe', 1158251: 'Vinzili', 1153917: 'Goryachie Klyuchi', 1601398: 'Khvoensk', 1146051: 'Goryachy Klyuch', 1703756: '?', 1945244: '?', 1915256: '?', 1014533: 'Ventsy', 1703108: 'Kazakhstan', 15953: 'Chunoyar', 22376: 'Gazli (romitansky Rayon)', 1933480: '?', 1154197: 'Kostino', 1084085: 'Novokurovka', 5004957: 'Los Ebanos', 1802329: '?', 1971938: 'Sopot', 1709169: 'Ada', 1509529: 'Rozbyshovka', 15418: 'Krinichki', 1923073: '?', 1128860: 'Krasny Brod', 1148222: 'Severnoe', 1136088: 'Kordovo', 1602668: 'Krivichi', 1055040: 'Novopetrovsky', 1501896: 'Gorokhovische', 1931810: '?', 5121865: 'Wasilla', 1963996: '?', 1517815: 'Eisenstadt', 1943561: '?', 4543301: 'Orte', 22651: 'Cesena', 1062470: 'Bronnitsa', 1503026: 'Terny', 1516469: 'Worcester', 1901682: 'Droitwich', 16369: 'Sayansky', 1148398: 'Kirsanovka', 1910711: '?', 1512324: 'Sokolovo', 1500426: 'Frunze', 9959: 'Novofedorovka', 1159684: 'Kommunar (pgt)', 1507281: 'Frunze', 1947468: '?', 1024485: 'Liski (selo)', 1906453: '?', 1514348: 'Babanka', 1086121: 'Dolina', 1083897: 'Kalinovka', 1500197: 'Kalinino', 1131398: 'Polom', 1500290: 'Uvarovo', 10697: 'Novye Sanzhary', 13615: 'Akkurgan', 1127448: 'Birakan', 1504265: 'Sinevir', 1113455: 'Khomutinino', 4361226: 'Kemnitz', 1929981: '?', 1127469: 'Teploozersk', 1017723: 'Vasilyevskoe', 5267097: 'Aichach', 1949245: '?', 1078499: 'Vtoroy Kievsky', 1913296: '?', 1600539: 'David-Gorodok', 1148244: 'Burannoe', 16155: 'Mordovskaya Polyana', 1518737: 'Kurchum', 5266304: 'Oelde', 1122597: 'Protasovo', 1091880: 'Rozovka', 16901: 'Privolnoe', 1035453: 'Kavkazsky', 1035487: 'Pregradnaya', 1123319: 'Ust-Charyshskaya Pristan', 1113646: 'Bamut', 16401: 'Usharal', 1701231: 'Prirechnoe', 1140036: 'Vladimirskoe', 1036746: 'Trakt', 1083747: 'Vysokoe', 1083763: 'Pestravka', 1008988: 'Ufimsky', 1602960: 'Osovo', 1935789: '?', 1924557: 'Pleiku', 4980626: 'Pitsburg', 1712411: '?', 1068880: 'Isheevka', 1085217: 'Sheremetyevka', 1916929: '?', 1155649: 'Glinskoe', 7315: 'Podberezye', 1026575: 'Chervlennye Buruny', 1158198: 'Priirtyshsky', 1158228: 'Usharova', 12485: 'Burevestnik', 1901116: "El'ad", 1714707: '?', 1117690: 'Povodnevo', 1922930: '?', 1041845: 'Uporny', 1943335: '?', 1930282: 'Fredericia', 1078080: 'Pobeda', 1914306: '?', 1517682: 'Richland Center', 1951921: '?', 1517757: 'Dzhambay', 1055600: 'Dubna', 1015064: 'Zenzevatka', 1962106: '?', 1136841: 'Podkamennaya Tunguska', 5428519: 'Rodina', 1050603: 'Troitsky Posad', 1946630: 'Przemyśl', 1115654: 'Shimkusy', 1926620: '?', 1154171: 'Deevo', 1709493: 'Bloomington', 1514448: 'Yasnozorye', 1031154: 'Nemanskoe', 1144825: 'Surkovo', 1114534: 'Urmaevo', 1111112: 'Pudem', 1056247: 'Drovnino', 1083686: 'Novy Buyan', 1705158: '?', 1803535: '?', 1102242: 'Boloshovo', 1713793: 'Sabirabad', 1002459: 'Lepsha Novy', 1016523: 'Novokemsky', 1514128: 'Martynovka', 1092055: 'Andreevsky', 1015543: 'Kamenka', 1135633: 'Abakumovka', 1054271: 'Khlebnikovo', 1923829: '?', 1927109: 'Poylu', 1900389: 'Sasa', 1040705: 'Gostagaevskaya', 1514941: 'Novaya Basan', 1112491: 'Stepnoe', 8490: 'Pomozdino', 1111884: 'Krasnaya Reka', 1926218: '?', 1501598: 'Maryanovka', 1926047: '?', 1096229: 'Shugurovo', 1500746: 'Kuna', 1092428: 'Tyumenyevskie Vyselki', 1023134: 'Korotovo', 1513538: 'Letichev', 1941714: '?', 1957763: '?', 1904303: '?', 1923636: '?', 1157663: 'Bigila', 5267647: 'Neumarkt in der Oberpfalz', 1927895: '?', 1068143: 'Evlashevo', 1935262: '?', 1918495: '?', 1518149: 'Salzwedel', 5267779: 'Lüchow (Wendland)', 1010082: 'Novy Poselok', 1503911: 'Pavoloch', 16702: 'Bogushevsk', 1946673: '?', 1702126: 'Zarechnoe', 1135435: 'Verkhnepashino', 1147285: 'Polevoy', 1506669: 'Alexandrovka', 1110398: 'Norya', 1951112: '?', 5477955: 'Sinitsino', 3731227: 'Zamboanga', 1126545: 'Novoe Annino', 7788: 'Togur', 1505862: 'Zgurovka', 1067007: 'Novognezdilovo', 1501540: 'Pridnestrovskoe', 1800544: 'Kiriet-Lunga', 20369: 'Vannovskoe', 1112759: 'Put Oktyabrya', 1902456: '?', 1093967: 'Svkh Komsomolets', 1004280: 'Zhitnoe', 1503961: 'Chaykovka', 1516452: 'Sholdaneshty', 1525: '?', 1109723: 'Italmas', 1056667: 'Dedenevo', 1002441: 'Kargopol-2', 1159770: 'Mortka', 1157831: 'Ravnets', 1707909: '?', 1602592: 'Samokhvalovichi', 1010065: 'Verkhopenye', 1712707: 'Kotovskoe', 1097502: 'Yutaza', 22612: 'Molde', 1509400: 'Petrostal', 1704334: 'Malaeshty', 1942417: '?', 4543133: 'Palaia', 1904865: 'Pontedera', 1509786: 'Potoki', 1715092: '?', 1517727: 'Troebratsky', 19825: 'Pobuzhskoe', 1510933: 'Dubovyazovka', 1503342: 'Kashperovka', 1146070: 'Krasnoyarka', 1603355: 'Kamenka', 17431: 'Vakhtan', 1929866: '?', 1714362: 'Privolnoe', 1510290: 'Romeyki', 1702561: 'Orlovka', 1935622: 'Bad Harzburg', 1516278: 'Masis', 1110470: 'Lyuga', 1004791: 'Alexeevskoe', 1049805: 'Krasnoe', 11875: 'Dimona', 1042381: 'Novoscherbinovskaya', 1026083: 'Kullar', 1501461: 'Bely Kamen', 1040964: 'Marina Roscha', 1913638: '?', 1944411: '?', 1036270: 'Ladva', 1920016: '?', 1502199: 'Alexandrovka', 1030463: 'Sovkhoznoe', 1033133: 'Bolshie Zheltoukhi', 1122218: 'Talovka', 1069024: 'Ashevo', 1099004: 'Kholokholenka', 5328081: 'Borne Sulinowo', 1009536: 'Maysky', 1077789: 'Grushevskaya', 1901552: '?', 1600484: 'Rovbitsk', 1515132: 'Vishenki', 1506969: 'Zaporozhye', 1918549: '?', 15988: 'Novodruzhesk', 1916058: 'Kladno', 1803483: '?', 1063773: 'Pestovo', 1904988: 'Lünen', 14091: 'Verkhovye', 1132727: 'Pustoshi', 1706403: '?', 21890: 'Libertyville', 1801727: 'Wentzville', 7302: 'Novoselovo', 1917646: 'Avan', 1946709: '?', 1510907: 'Slout', 1514556: 'Dolishny Shepot', 1014732: 'Leninsk', 1933201: 'Jihlava', 1709766: 'Bristol', 1706886: 'Sevierville', 9785: 'Kazachi Lageri', 1503966: 'Berezyanka', 1516064: '?', 1935000: '?', 1502362: 'Pavlopolye', 1903176: '?', 1507917: 'Solonka', 1700990: 'Ganyushkino', 1111577: 'Novaya Mayna', 1512263: 'Olshany', 1156611: 'Novogornoe', 1715139: '?', 1600601: 'Opsa', 1150347: 'Bolshaya Usa', 1703663: "Ma'ale Adumim", 1902985: '?', 1711517: 'Fenton', 1096859: 'Kozyakovo-Chelny', 1115442: 'Shumerlya', 4058341: 'Abadjin-Kouté', 1910057: '?', 1925515: '?', 1942132: 'Ignalina', 1942216: '?', 6207: 'Sviritsa', 1709999: 'Cheney', 1517702: 'Dangara', 1938503: '?', 1925207: 'Lleida', 1902975: '?', 1705180: 'Sterling', 1951858: '?', 1966089: '?', 1964489: '?', 1036773: 'Podz', 1511538: 'Tolstoe', 1915205: '?', 1714906: '?', 1500676: 'Viytovka', 22547: 'Lyuboml', 9399: 'Bad Pyrmont', 1704695: 'Bessarabka', 1946655: '?', 1710021: '?', 4284883: 'Houten', 1921995: '?', 1939937: 'Chuburkhindzhi', 1506004: 'Makovische', 1085961: 'Storozhovka', 1963927: '?', 1602620: 'Berezinskoe', 1136170: 'Narva', 1501506: 'Rakhny-Lesovye', 1500707: 'Mizyakovskie Khutora', 1517207: 'Whitehorse', 1505530: 'Uzin', 1027655: 'Mytischi (derevnya)', 1508600: 'Poligon', 1506222: 'Luka', 1931102: '?', 1926970: '?', 2202932: 'Rumburk', 9398: 'Petrovskoe', 1946852: '?', 1935746: '?', 21923: 'Kamen-Kashirsky', 22650: 'Svessa', 1019522: 'Cherepanovo', 1516028: 'Troy', 5039497: 'Birmingham', 13240: 'Warren', 19292: 'Aversa', 1036271: 'Ladva-Vetka', 1128728: 'Talyany', 1706690: '?', 1107971: 'Sovetsky', 5035211: 'Newton', 1932666: 'Nizwá', 1600368: 'Lakhva', 14514: 'Townsville', 5219448: 'Meilhan-sur-Garonne', 1946860: '?', 1512874: 'Schastlivtsevo', 1713679: '?', 1947419: '?', 1507035: 'Yuryevka', 1600194: 'Dostoevo', 1947235: '?', 1024419: 'Khreschaty', 1014782: 'Otradnoe', 1947392: '?', 1519317: 'Conyers', 1947423: 'Snellville', 1000387: 'Makarovskaya', 1128318: 'Rechushka', 5090984: 'El Cajon', 11421: 'Berdigestyakh', 18877: 'Harrisonburg', 13831: 'Chumikan', 1713999: 'South Lake Tahoe', 4759: 'Nikolaev', 1946897: '?', 1145692: 'Alexeevka', 1945241: 'Brand', 1146093: 'Omsky', 1518439: 'Auburn', 1153470: 'Ilbenge', 1153497: 'Orto-Surt', 1149094: 'Gayny', 1707445: 'Herndon', 1710482: 'Leesburg', 22495: '?', 1129802: 'Kaz ', 1024204: 'Nikolskoe', 1154114: 'Krabozavodskoe', 1054934: 'Pavlovskoe', 1918974: '?', 1010568: 'Kostroma (selo)', 1518448: 'Zarmitan', 1518036: '?', 1037075: 'Vozhsky', 1037098: 'Mozyndor', 15450: 'Ozero-Karachi', 1137365: 'Uraltsevskoe', 1093183: 'Yurlovka', 1072983: 'Matyushkino', 1072973: 'Makushino', 1076080: 'Verbilovo', 1124431: 'Babushkin', 4192: 'Kadykchan', 1930976: '?', 1715618: '?', 1700800: 'Koxu', 1702747: 'Poludino', 1090065: 'Ballastny Karyer', 1012808: 'Katashin', 1505025: 'Verkhovina', 1916707: '?', 3963658: 'Hunchun', 1518194: 'Vadodara', 1921418: 'Borj Cedria', 1603197: 'Krugloe', 1153342: 'Podyapolsky', 1802453: '?', 1506453: 'Molodezhnoe', 1130600: 'Kamsky', 1124297: 'Gunda', 1602866: 'Lyubkovschina', 2206271: '?', 1903002: '?', 1058130: 'Nizhnee Myachkovo', 1927660: '?', 2600092: 'Nereta', 1095456: 'Memdel', 1129141: 'Malaya Salairka', 1129130: 'Biryulya', 19910: '?', 1703400: '?', 12366: 'Koryukovka', 1514261: 'Knyazhaya Krinitsa', 1156471: 'Klyukvinka', 12027: 'Sopron', 5458: 'Pibanshur', 1048688: 'Debri', 1518927: 'Dunedin', 1517742: 'Axu', 5030743: 'Poplar Grove', 1141711: 'Taremskoe', 1091414: 'Kruglolesskoe', 1121697: 'Keley', 1921983: '?', 1946952: 'Lubmin', 21925: '?', 1801936: '?', 1913212: '?', 11676: 'Karymskoe', 1709445: 'Belleville', 4948786: 'Metairie', 1160424: 'Verkhny Tsasuchey', 1946458: '?', 1946956: 'Astrakhanovka', 1917600: '?', 1703664: '?', 1515586: '?', 1062376: 'Orekhovno', 4627: 'Nebug', 1508610: 'Vladimirovka', 1602405: 'Volma', 14195: 'Sarmanovo', 1934766: '?', 1918005: '?', 1032622: 'Duminichi', 1908945: 'Český Krumlov', 1134760: 'Slautnoe', 1147451: 'Ibragimovo', 1918092: '?', 20279: 'Verkhneuralsk', 1112467: 'Krasninsky', 1500095: 'Tsvetochnoe', 1095795: 'Observatoria', 1507144: 'Zorinsk', 1905000: '?', 21634: 'Vetrino', 1517478: '?', 1946506: '?', 1924628: 'Didi-Shiraki', 1505978: 'Sofievskaya Borschagovka', 100500: '?', 575: 'Mokshan', 1939258: '?', 17632: 'Verkhnie Emangashi', 20608: 'Slavkovichi', 1159647: 'Moskovskoe', 1929053: '?', 1515483: 'Talalaevka', 1702521: 'Presnoe', 1934991: 'Kavala', 1714521: '?', 6707: 'Konobeevo', 1914201: '?', 1127549: 'Kumareyka', 1508704: 'Balovnoe', 1511878: 'Strusov', 5423714: 'Choresku', 1505774: 'Kalinovka', 17327: 'Skhodnitsa', 1515361: 'Sukhopolovaya', 1519136: 'Oxford', 1947026: 'Korinth', 1934673: '?', 1704145: '?', 1000155: 'Druzhny', 1129479: '?', 1005175: 'Akhmanovo', 13209: 'Kazaklia', 1067524: 'Bekovo', 21008: 'Žilina', 1944013: '?', 1802445: 'Mtskheta', 1144883: 'Raisino', 22520: 'Hohenmölsen', 1501072: 'Murovanye Kurilovtsy', 1137416: 'Zhitnikovskoe', 10332: 'Priargunsk', 1008210: 'Chebarkul', 1106712: 'Lanshinsky', 1113778: 'Kalinovskaya', 1904214: 'Logroño', 1518731: 'Kantemir', 1944152: '?', 3226487: 'Târgovişte', 1144488: 'Izdrevaya', 1144504: 'Krakhal', 1113952: 'Voskhod', 1911: '?', 1514817: 'Sokiryany', 1602326: 'Velyatichi', 1934700: '?', 1150530: 'Ergach', 1943519: '?', 1095732: 'Belo-Bezvodnoe', 1043348: 'Kamyshi', 1507199: 'Goncharovka', 1041091: 'Oktyabrsky', 6175: '?', 16299: 'Usady', 1152250: 'Nyrob', 1902721: '?', 1801454: 'Floreshty', 1005480: 'Starobelokatay', 1503062: 'Yalta', 1700703: 'Zhetigen', 5848: 'Selikhino', 1058035: 'Gzhel', 20288: 'Krasny Put', 1159201: 'Lidoga', 1086455: 'Mikhaylovskoe', 1058184: 'Sofino', 1121987: 'Blagoveschenka', 15203: 'Novye Belokorovichi', 1506627: 'Novomirgorod', 16935: 'Svyatogorsk', 1140746: 'Kremenki', 1503280: 'Keramik', 1917403: '?', 1007970: 'Starokulchubaevo', 1007983: 'Churaevo', 2206536: '?', 1939868: '?', 1911500: '?', 1713965: '?', 1159020: 'Listvenny', 1712621: 'Tuyabuguz', 1099598: 'Pogoreloe Gorodische', 1908247: '?', 1510703: 'Kvasilov', 1925159: '?', 1030072: 'Odintsovo', 1095164: 'Karabash', 1152566: 'Yurla', 1512721: 'Kostirka', 1505276: 'Spas', 1515515: 'Mikhaylo-Kotsyubinskoe', 1084719: 'Koloyar', 1601396: 'Turov', 1600086: 'Domachevo', 13071: 'Shemursha', 1509822: 'Zavodskoe / Chervonozavodskoe', 1503923: 'Khodorkov', 22162: 'Orekhovoe', 1502836: 'Novotroitskoe', 1143316: 'Arkhangelskoe', 1704841: 'Radun', 1946914: '?', 1700021: 'Konstantinovka', 1503558: 'Novoguyvinskoe', 1947112: '?', 1137853: 'Krepost', 1500545: 'Primorsky', 1710055: '?', 4485: '?', 1052902: 'Belogorsk', 1944056: '?', 1713899: '?', 1709074: '?', 1705488: '?', 5257284: 'Lauter-Bernsbach', 1071193: 'Uschitsy', 5427958: 'Sarylakh', 1908033: '?', 1059247: 'Chashnikovo', 1964998: 'Kędzierzyn-Koźle', 1009409: 'Afanasyevka', 1504960: 'Kirillovka', 1504974: 'Shelyugi', 1711865: '?', 1505013: 'Bolekhov', 1704534: 'Egorovka', 1063135: 'Odintsovo', 14757: 'Disna', 22183: 'Chester', 1056107: 'Matyra', 1906316: 'Chungju', 1500227: 'Rovnoe', 1939998: '?', 1700300: 'Zeleny Bor', 5259050: 'Dorndorf-Steudnitz', 4367487: 'Hermsdorf', 4501472: 'Jelenia Góra', 1041228: 'Razdolnaya', 1913257: '?', 1122585: 'Galbshtadt', 1945964: '?', 1510704: 'Klevan', 20855: 'Novonikolskoe', 5090048: 'California City', 1929405: '?', 1124102: 'Tambovka', 2753: 'Taezhny', 1124091: 'Nikolaevka', 1020864: 'Kukuevo', 1036614: 'Komsomolsky', 1136004: 'Novochernorechensky', 1713412: '?', 3821288: 'Yesan', 1508314: 'Krakovets', 1930535: 'Mynämäki', 9581: 'Sinyava', 1095361: 'Sviazhsk', 22712: '?', 1112377: 'Borovoe', 1503477: 'Romanovka', 1503582: 'Gulyanka', 1127404: 'Birofeld', 1965759: 'Grudziądz', 5445426: 'Golovintsy', 1513293: 'Volkovintsy', 1711992: 'Aomori', 1055892: 'Sovkhoz Im Lenina', 3122: 'Insar', 1505817: 'Lyutizh', 1095533: 'Gorodische', 1514092: 'Blagodatnoe / Chapaevka', 1943874: '?', 1137020: 'Dubinino', 1124038: 'Ukraina', 1962738: 'Inari', 1514751: 'Mamalyga', 1701351: 'Grodikovo', 1928083: '?', 1915008: '?', 1513411: 'Khoten', 1901351: 'Mayly-Suu', 5404: 'Craiova', 16456: 'Focşani', 1922071: '?', 1146074: 'Luzino', 1141368: 'Sheloksha', 1110737: 'Bulay', 22057: '?', 1936408: '?', 1085436: 'Natalin Yar', 1914804: '?', 1079262: 'Alexeevsky', 1903285: '?', 1054952: 'Kostrovo', 6839: 'Burla', 1022298: 'Ulyanovskaya', 1517655: 'Kokpekty', 1152661: 'Pozhva', 1041213: 'Zhuravskaya', 1518616: 'Vedi', 1518263: 'Mucenieki', 18392: 'Karmanovo', 1035831: 'Sosnovy', 1002726: 'Syloga', 1031532: 'Mozyr', 1110421: 'Yagan', 1122050: 'Berezovsky', 5039428: '?', 1962919: 'Enns', 20973: 'Semisotka', 1942915: '?', 1144301: 'Novoklyuchi', 1510264: 'Vladimirets', 1032078: 'Tsagan Usn', 1512282: 'Zachepilovka', 1502636: 'Kitaygorodka', 1160951: 'Nyda', 1136419: 'Pavlovka', 1057847: 'Fedyukovo', 1044739: 'Makeevka', 1160189: '?', 1129696: 'Trudarmeysky', 1514600: 'Glubokaya', 11779: 'Arya', 21391: '?', 1801417: 'Ternovka', 22169: 'Kazanka', 5266211: 'Willich', 1928326: '?', 1068659: 'Reshetino', 1068799: 'Roschino', 1803587: 'Hutchinson', 1050749: 'Kuyar', 9837: '?', 1084284: 'Levashovo', 1507157: 'Faschevka', 1923380: '?', 1062659: 'Chechulino', 7441: 'Vakhrushi (pgt)', 1917332: '?', 3992627: 'Gizo', 3992506: 'Honiara', 13531: 'Volodarskoe', 4011978: 'Misrata', 12696: 'Yuzhny', 5422069: 'Nanao', 1706493: 'Vidibor', 1515053: 'Gmiryanka', 1509298: 'Plavni', 1155328: 'Tsementny', 20983: 'Makinka', 16322: 'Onguday', 1049396: 'Skornyakovo', 1093521: 'Zimbulatovo', 1714997: '?', 1506580: 'Novgorodka', 1947009: '?', 1506086: 'Devichki 1', 1036461: 'Kubovo', 2000015: 'Fatmai', 1922550: '?', 19861: 'Osakarovka', 1004489: 'Assadulaevo', 2211489: 'Lemvig', 1142277: 'Krasny Ostrov', 1933389: '?', 1139068: 'Oktyabrsky', 1956265: '?', 1515369: 'Vishnevoe', 1904948: '?', 1115039: 'Shigali', 1708144: '?', 6333: 'Kvarkeno', 1703264: 'Kolosovo', 1014752: 'Archedinskaya', 1515946: '?', 1926356: 'Musselburgh', 1904206: 'Monroe', 5102760: 'Bellevue', 1950676: '?', 1715136: '?', 1503042: 'Nizhnyaya Krinka', 1503011: 'Drobishevo', 1708102: 'Beshtasheni', 5125879: 'Huntingdon', 11066: 'Markovo', 10219: 'Milyutinskaya', 1061494: 'Yamnik', 1900685: 'Amir', 1944123: '?', 1702636: 'Kialy', 1917930: '?', 1513168: 'Vinkovtsy', 1941807: '?', 1512667: 'Volokhov Yar', 3811: 'Krasochny', 13980: 'Dmitrievka', 1504395: 'Dubovoe', 1966608: '?', 1706018: 'Baalbek', 1705475: '?', 1085958: 'Sokolovy', 1514688: 'Novoselitsa', 5266364: 'Arnsberg', 1511907: 'Ostrov', 1935261: '?', 14318: 'Yakshanga', 1902056: '?', 1045973: 'Potanino', 7912: 'Pomorye', 1706702: '?', 1714457: '?', 1050788: 'Krasny Most', 1501485: 'Dzhurin', 1509809: 'Luka', 1137083: 'Idzha', 1931809: '?', 1800837: 'Myndra', 1943643: '?', 1509221: 'Bobrik Pervy', 1026220: 'Pervomayskoe', 1014549: 'Kremenskaya', 1007324: 'Novotroitsk', 1079198: 'Natalyevka', 1074233: 'Kirshino', 1046286: 'Gorkovskoe', 14217: 'Krasnoselskoe', 1053101: 'Pushkino', 1026722: 'Ersi', 1503282: 'Krasny Partizan', 1008408: 'Khutor', 21806: 'Pesochin', 1505779: 'Losyatin', 1500026: 'Golubinka', 5256187: 'Detmold', 1153128: 'Sungach', 13769: 'Bolek', 21502: '?', 1506115: 'Vilcha', 1932649: 'Mālpils', 1512019: 'Melovaya', 4294511: 'Mollands', 1925707: '?', 1901067: 'Tel Mond', 2201666: '?', 21883: '?', 22240: 'Tsel', 1506303: 'Sulimovka', 1938464: 'Treuen', 1113929: 'Sary-Su', 1946657: '?', 1963737: '?', 1703193: 'Kozloduy', 5266515: 'Naumburg', 20324: '?', 4907470: 'New York', 1935624: '?', 2400005: 'Bambora', 1913200: 'Pesaro', 1930130: '?', 1114651: 'Krasnye Chetai', 1961579: 'Ückeritz', 1519062: 'Wolgast', 4153548: "N'Djamena", 1135491: 'Podtesovo', 1946524: '?', 1129290: 'Karagaylinsky', 1601869: 'Zhirmuny', 1013301: 'Seltso', 1907862: 'El Ejido', 1709837: '?', 1945764: '?', 1509986: 'Velikaya Krucha', 1955227: '?', 5219751: 'Seiches-sur-le-Loir', 1909038: '?', 1901310: '?', 1128231: 'Kuytun', 1928911: '?', 1003054: 'Volochek', 1153352: 'Shtykovo', 1124702: 'Kumora', 1903009: 'Osimo', 1946401: '?', 1766: 'Ulkan', 1160395: 'Zolotorechensk', 1947403: 'Moose Creek', 1928101: '?', 1518588: 'Stamford', 1802435: '?', 1913714: '?', 3360: 'Baton Rouge', 1128214: 'Barluk', 5094589: 'Santa Cruz', 1135588: 'Dobromyslovsky', 1094131: '№ 12', 1153940: 'Gornozavodsk', 1127515: 'Baykalsk', 1060335: 'Pinozero', 1939420: '?', 1106580: 'Okhotsky', 2300: 'Ertom', 1914100: '?', 4779883: 'Les Cayes', 7776: 'Rexburg', 11135: 'Kondinskoe', 12702: 'Tonnelny', 1135481: 'Novy Gorodok', 1702760: 'Molodogvardeyskoe', 1135876: 'Filimonovo', 1933433: '?', 1083075: 'Avgustovka', 1914591: '?', 1922480: '?', 1153201: 'Novokachalinsk', 1145939: 'Ermak', 1509004: 'Krinichnoe', 1042338: 'Bolgov', 1702698: 'Nikolaevka', 1515341: 'Linovitsa', 1026226: 'Utamysh', 1917385: '?', 1136894: 'Tyukhtet', 3115702: 'Mbale', 1941017: '?', 1134757: 'Manily', 1134779: 'Berezovka', 1122582: 'Rakity', 1002130: '1180 Km', 1145958: 'Pobeda', 1907220: '?', 1928838: '?', 1112416: 'Varna', 1511056: 'Moskovskoe', 20989: 'Kogaly', 1964426: '?', 1709577: 'Tryavna', 20618: 'Kochki', 1517181: 'Halifax', 1111854: 'Novye Zimnitsy', 1971838: 'La Habra', 1508475: 'Tokarevka / Kudryavtsevka', 1714049: 'Humenné', 21677: 'Trostyanets', 1700947: 'Axay', 1083738: 'Utevka', 1159980: 'Urmanny', 1704206: 'El Salvador', 1703339: '?', 1035594: 'Kepa', 1053203: 'Kondrovka', 1014784: 'Plotnikov 2-J', 1041495: 'Krasnaya Polyana', 1928089: '?', 1144760: 'Dolgovo', 1124475: '?', 16544: 'Novonezhino', 1036523: 'Idel', 1123775: 'Tygda', 1948062: '?', 1515699: '?', 9668: 'Uglovoe', 1121826: 'Cherga', 1602749: 'Gresk', 1143767: 'Zdvinsk', 1159350: 'Vladivostoxkoe Shosse 18 Km', 1111956: 'Sara', 1146155: 'Tikhvinka', 1077811: 'Olginskaya', 4661847: 'Cedar Valley', 1011292: 'Paltso', 1704358: 'San Bruno', 1934779: '?', 1909401: 'Mount Olive', 1122451: 'Kursk (selo)', 1113073: 'Severny', 1515197: 'Smolyanka', 2608213: 'Tukums', 1129311: 'Krapivinsky', 1946418: '?', 5430751: 'Otenay', 1024317: 'Yasenovka', 19044: 'Yantal', 1904725: '?', 1143331: 'Kerzhemok', 1940510: '?', 1141319: 'Novolikeevo', 1905696: '?', 1003291: 'Zadorye', 1715283: '?', 1003280: 'Gluboky', 1159932: 'Russkinskaya', 1502345: 'Alexeevka', 1511089: 'Terny', 1923392: 'Bollwiller', 1144829: 'Shakhta', 1505776: 'Kodaki', 1037079: 'Edva', 1515377: 'Dobryanka', 1107253: 'Shakhty-1', 1155553: 'Pokrovskoe', 1712909: '?', 3168904: 'Gonder', 1500236: 'Bratskoe', 1514305: 'Rotmistrovka', 1135149: 'Gremuchy', 1920547: '?', 1136819: 'Bor (poselok)', 1057120: 'Institut', 1803581: 'Huntingdon', 1014089: 'Ust-Buzuluxkaya (stanitsa)', 1513917: 'Pravdovka', 1151024: 'Schuchye Ozero', 1150936: 'Almaz', 5387471: 'Ennis', 1062592: 'Podberezye', 1929033: '?', 1712119: '?', 1095502: 'Usady', 1082971: 'Ekaterinovka', 1077000: 'Boyarinovo', 9825: 'Ropcha', 17694: 'Novy Uoyan', 1954460: '?', 1918651: '?', 1971097: '?', 1504204: 'Volovets', 1510450: 'Zarechnoe', 1800214: 'Varzareshty', 1145847: 'Nazyvaevsk', 1034000: 'Voroshilovogradsky', 1146533: 'Korshunovka', 1156051: 'Gorbunovskoe', 1025651: 'Schuchye', 1147507: 'Sara', 1714746: '?', 1941768: '?', 1913597: '?', 3978111: 'Mandurah', 1134981: '?', 1064917: 'Dudinka (derevnya)', 1155692: 'Andrianovichi', 1003196: 'Uyma', 1514195: 'Steblev', 20717: 'Starobaltachevo', 20694: 'Berezanka', 1501341: 'Letkovka', 1106752: 'Polenovo', 1069223: 'Krasny Luch', 1500186: 'Shubino', 1128055: 'Argun', 1516107: 'Uspenka', 1602743: 'Veseya', 1953303: 'Suifenhe', 1948063: '?', 1943071: '?', 1515838: 'Geneva', 1005083: 'Aktau', 1112978: 'Petropavlovka', 1501184: 'Rudnitsa', 20767: 'Karkaralinsk', 1927580: '?', 1506245: 'Kashperovka', 1152470: 'Skalny', 1152468: 'Polovinka', 2722611: 'Boneh-ye Karbalā’ī Ḩājj', 1906454: '?', 21108: 'Knyagininok / Mayaki', 1090138: 'Gusino', 20366: 'Verkhnyaya Tura', 5352003: 'Altenkirchen', 1914783: '?', 1004591: 'Davletovo', 9898: 'Athens', 7580: 'Florence', 1602805: 'Skovshin', 1928996: '?', 1509886: 'Seleschina', 1112488: 'Smelovsky', 1512264: 'Peresechnaya', 1152716: 'Anuchino', 6288: 'Charleroi', 1936165: '?', 1122960: 'Kolbany', 1080656: 'Malakhovo', 16210: 'Ult-Yagun', 3810497: 'Baoding', 1922536: '?', 1947638: '?', 13489: 'Skövde', 1921557: '?', 1042112: 'Primorsky', 1071805: 'Novokhovansk', 1153265: 'Priluki', 1154688: 'Baltym', 1502765: 'Paraskovievka', 1028250: 'Batmany', 1713319: '?', 5266316: 'Bünde', 1141953: 'Naruxovo', 1939686: '?', 12856: 'Gnivan', 1002874: 'Malinovka', 1913362: 'Purcellville', 1517156: '?', 1975593: 'Badia Polesine', 1502844: 'Rybinskoe', 1944895: '?', 1088820: 'Bolshevo', 18022: 'Ilansky', 1512643: 'Olkhovka', 1702096: 'Oktyabrskoe', 1702119: 'Oktyabrskoe', 22370: 'Banilov', 1968877: '?', 1943545: '?', 5266017: 'Niebüll', 1501567: 'Ovadnoe', 1924744: '?', 1135891: 'Karatuzskoe', 1909672: '?', 666: 'Sharapovo', 1092393: 'Znamenka', 1160082: 'Ust-Ozernoe', 1700401: 'Stepanovka', 4016: 'Venlo', 1505749: 'Rudnya', 1910190: '?', 1069002: 'Shemysheyka', 1060318: '?', 8942: 'Khrustalny', 1158980: 'Vysokogorny', 1124763: 'Arshan', 1032743: 'Ovsorok', 1083933: 'Sernovodsk', 1506007: 'Motizhin', 1112908: 'Kunashak', 1714292: '?', 1932128: '?', 1513921: 'Sokolovka', 1709176: 'Ahoskie', 16741: 'Timashevo', 1084738: 'Sennaya', 4373417: 'Gotha', 1132757: 'Strizhi', 1913391: 'Romsey', 1151601: 'Berezniki', 1122217: 'Savvushka', 1603049: 'Ovsyanka', 1136271: 'Kulakovo', 1957072: '?', 1703246: 'Plattsburgh', 1931858: '?', 3542: 'Ontario', 1706882: 'Partskhanakanebi', 1913109: '?', 1928401: '?', 1933324: '?', 1514117: 'Bobritsa', 1710104: '?', 1040912: 'Novodzherelievskaya', 1156929: 'Rassvet', 1138389: 'Kislyanskoe', 1710355: 'Johnston', 1505483: 'Snyatin', 19858: 'Germantown', 1925869: '?', 1953504: 'Karakert', 4184607: 'San Fernando', 1041402: 'Pavlovsky', 1157450: 'Kazanskoe', 1145952: 'Novovarshavka', 8105: 'Ramon', 1702523: 'Rozhdestvenka', 1059220: 'Solnechnogorsk-2', 1602888: 'Litvyany', 1000032: 'Tambovsky', 1709530: 'Šumperk', 18637: 'Puchezh', 1928402: '?', 1923439: '?', 9848: 'Drakino', 1504820: 'Semenovka', 10250: 'Shalushka', 1941044: '?', 1147273: 'Dombarovka', 1705271: '?', 1912506: '?', 4825531: 'San Miguel de Tucumán', 1087404: 'Demidov', 1935665: '?', 1940502: '?', 10204: 'Dogoy', 1151463: 'Lobanovo', 1124036: 'Tomskoe', 1014411: 'Komsomolsky', 1712944: 'Česká Třebová', 1803453: 'Lake Charles', 1903108: '?', 1713048: '?', 1046607: 'Natalyevka', 1097422: 'Ishalkino', 15723: 'Demyanka', 1130653: 'Chus', 1135704: '?', 1069949: 'Blyansk', 1108530: 'Luzhny', 1931684: 'Alaska', 1143361: 'Svetlogorsk', 1137122: 'Kuyumba', 19397: 'Ushkonyr (shamalgan)', 1041629: 'Barakaevskaya', 1510047: 'Suprunovka', 1903152: '?', 1029017: 'Ivanovo (derevnya)', 1159884: 'Alyabyevsky', 1956322: '?', 21700: 'Selets', 5268693: '?', 1008809: 'Komsomolsk', 1923767: 'Nelkan', 1519058: 'Bountiful', 1025391: 'Semiluki (selo)', 1706601: 'Belovezhsky', 1600267: 'Verkhovichi', 1051021: 'Mari-Turek', 1007780: 'Voskresenskoe', 1710222: 'Atlantic City', 2001840: 'Vercelli', 21994: 'Koper', 1709037: 'Zagatala', 1128281: 'Lugovsky', 21358: 'Uzda', 1904936: '?', 1801275: 'Speya ', 1147125: 'Elshanka Pervaya', 1105435: 'Rozhdestvo', 4381397: 'Dressendorf', 1901347: '?', 1127993: 'Khomutovo', 1517728: 'Zguritsa', 1148225: 'Sergushkino', 1508669: 'Vesely Sad / Radsad', 1159808: 'Ust-Yugan', 1518119: 'Vvedenka', 5378035: 'Koosa', 1803322: 'Alatskivi', 3090445: 'Hama', 15356: 'Gribanovsky', 1096570: 'Bolshoe Afanasovo', 1118228: 'Kstovo', 1068581: 'Zelenodolskoe', 11853: 'Peterborough', 1161120: 'Shoyna', 9129: 'Chebenki', 1937647: 'Veles', 20687: 'Kagalnitskaya', 1078374: 'Kagalnichek', 1095310: 'Vvedenskaya Sloboda', 1937398: '?', 1148767: 'Baklushi', 1148827: 'Petropavlovsk', 1151556: 'Ust-Kachka', 4925439: 'Acworth Beach', 1712092: 'Schwechat', 1702139: 'Borki', 8161: 'Tønsberg', 1504510: 'Dmitrovka', 1953609: 'Shamkir', 1095938: 'Krasnovidovo', 1708440: '?', 5259541: 'Eilenburg', 1517978: 'Kievka', 1151544: 'Sylva', 1042124: 'Yubileyny', 4240842: 'Bury Saint Edmunds', 1947851: 'Cervia', 1094848: 'Apazovo', 1515156: 'Shabalinov', 1925856: '?', 9402: 'Argada', 1147402: 'Proletarka', 1944230: 'Almerimar', 1514009: 'Sokolovka', 1113850: 'Sernovodsk', 1014324: 'Novinka', 14373: '?', 1055744: 'Nikolo-Uryupino', 18323: '?', 1091410: 'Grushevskoe', 14191: 'Novobessergenovka', 1093005: 'Morshanskoe Lesn-Vo', 1158357: 'Demyanka', 1507297: 'Nizhneteploe', 1123839: 'Poyarkovo', 1947893: '?', 9815: 'Stavrovo', 1947545: '?', 1042179: 'Eremizino-Borisovsky', 1705951: 'Novitskovichi', 1908448: '?', 1919346: '?', 1703725: 'Euskirchen', 1703720: '?', 1515462: 'Srebnoe', 1040669: 'Mingrelskaya', 1507947: 'Pavlov', 1710124: 'Yakima County', 1111442: 'Kuzovatovo', 6105: '?', 4943413: '?', 1923828: '?', 1911126: '?', 1122816: 'Kayaushka', 1517476: '?', 1949762: 'Oviedo', 1505559: 'Obertin', 1094876: 'Kazanbash', 1934033: '?', 1141873: 'Krasnaya Gorka', 1049324: 'Donskoe', 1015074: 'Oktyabrsky', 1500876: 'Chernyatin', 1029472: 'Bukharino', 1512041: 'Gavrilovka', 1511340: 'Stepnoe', 1950901: '?', 1915109: '?', 1907179: '?', 1937032: '?', 1713474: '?', 1509979: 'Chevelcha', 1159890: 'Pionersky', 1505700: 'Schastlivoe', 17125: 'Viborg', 4244598: 'Martigny', 5327226: 'Vihamanaafushi', 4043111: 'Carcavelos', 1085996: 'Sovetskoe', 1946572: '?', 1904974: '?', 1908934: 'Wildeshausen', 1503291: 'Peski', 1086200: 'Komintern', 1975022: 'Brasília', 1714391: '?', 1025227: 'Repyevka', 1602285: 'Poplavy', 1112223: 'Magnitny', 1928355: '?', 1052160: 'Strelnikovo', 1083861: 'Novospassky', 15587: 'Vatutino', 4272104: 'Trofa', 1139161: 'Kantaurovo (kantaurovsky S/s)', 1135407: 'Udachny', 1903010: '?', 1508831: 'Vinogradovka', 1079954: 'Alexeevo-Lozovskoe', 14329: 'Podgorodnoe', 1049712: 'Tomilino', 1916705: 'Salaspils', 1710451: 'Columbia', 1922811: '?', 1086203: 'Krasny Yar', 1509973: 'Savintsy', 1931091: '?', 1971286: '?', 1928100: 'Haiphong', 1115366: 'Bichurga-Baishevo', 1115392: 'Yablonovka', 1505174: 'Ugorniki', 1518807: 'Wylie', 1948920: '?', 1710105: '?', 1503915: 'Romanovka', 5267730: 'Höchstädt an der Donau', 1097262: 'Nizhny Suyk-Su', 1956165: '?', 1044087: 'Bobryshevo', 1925040: 'Lanaken', 1079847: 'Pukhlyakovsky', 1032036: 'Krasnomikhaylovskoe', 1510592: 'Mlynov', 1930076: '?', 1930082: '?', 6041: '?', 1714768: '?', 4279821: 'Anadia', 1947856: '?', 11478: 'Olymsky', 1927377: '?', 1933601: '?', 1917856: '?', 1506047: 'Tsentralnoe', 1510883: 'Yamnoe', 1124121: 'Solovyevsk', 18184: 'Osinovaya Rechka', 1929002: '?', 22261: 'Broskaya', 3021: 'Ilpyrskoe', 1130104: 'Proskokovo', 1136463: 'Kamchatka (derevnya)', 1928870: '?', 1948238: 'Pakhtakor (pakhtakorsky Rayon)', 16606: 'Dzhebariki-Khaya', 1947785: '?', 1938231: '?', 1136743: 'Kononovo', 1703859: '?', 1600986: 'Parizh (byvsh. Novodrutsk)', 18688: 'Alonka', 1005518: 'Dubinino', 1948043: '?', 1945402: '?', 1136532: '?', 1002338: 'Bychye', 1135169: 'Osinovy Mys', 1152728: 'Oleny', 1516434: 'Shardara', 1948046: '?', 8405: '?', 1128280: 'Kolotovka', 1145152: 'Azovo', 1128809: 'Ust-Uda', 1136659: 'Aginskoe', 1127634: 'Priboyny', 1932866: 'El Dorado Hills', 1505975: 'Svyatopetrovskoe / Petrovskoe', 11015: 'Lancaster', 16044: 'Elovo', 1001129: 'Vasilyevo', 4983690: 'Ponca City', 1113959: 'Kirya', 1150330: '3 Goskonezavod Tsentralnaya Usadba', 1513355: 'Makov', 1042228: 'Yugo-Severnaya', 1508970: 'Kamenka', 1084888: 'Krutoyar', 1067525: 'Vertunovka', 1115091: 'Konar', 1911718: '?', 1145297: 'Serebryanoe', 1145159: 'Zvonarev Kut', 1068023: 'Mamadysh', 1135105: 'Kashtan', 1701959: 'Bolshaya Churakovka', 1947708: '?', 4690850: '?', 21224: 'Klimovichi', 1093907: 'Novaya Zhizn', 1948068: '?', 1055051: 'Obushkovsky', 1905185: 'Buzovna (azizbekov)', 1940066: '?', 1032837: 'Durakovo', 10086: 'Klepovka', 1024045: 'Gvazda', 1705298: 'Welzow', 1132776: 'Tyumen (derevnya)', 1113270: 'Esaulsky', 1514233: 'Dobraya', 1943710: '?', 17229: 'Bazarny Karabulak', 1051514: 'Stary Toryal', 1504909: 'Molochansk', 1111849: 'Novaya Kulatka', 1928954: 'Marathon', 1927483: '?', 1600519: 'Olshany', 1705476: 'Spišská Nová Ves', 1517518: 'Karabulak', 1504356: 'Rakhov', 14864: 'Klyuchi', 1155573: 'Uralets', 1917435: '?', 1160402: 'Mirnaya', 20283: 'Lopatino', 1136669: 'Vyatka', 1112415: 'Borodinovka', 1914173: '?', 1078703: 'Novaya Nadezhda', 14747: 'Stukovo', 1122599: 'Shumanovka', 1129072: 'Gramoteino', 1155816: 'Turinskaya Sloboda', 1518502: 'Kenzhekol', 1150642: 'Plekhanovo', 3352914: 'Nampula', 1918667: 'Voenno-Antonovka', 1946320: '?', 1936646: '?', 1507622: 'Dobrosin', 1927101: '?', 1037176: 'Komi Yb', 14161: 'Aden', 1933295: 'Luxor', 1901911: 'Mazār-e Sharīf', 1961644: 'Dar-es-Salaam', 1911523: '?', 1083783: 'Bolshoy Tolkay', 1954339: '?', 1008092: 'Amzya', 1701175: 'Soldatovo', 1504950: 'Akimovka', 1500425: 'Uyutnoe', 1091576: 'Novospitsevsky', 1504683: 'Vershina', 1504691: 'Maryanovka', 4707746: 'Yuscarán', 1077810: 'Oktyabrsky', 1932914: '?', 1501956: 'Rudniki', 1064994: 'Samara (poselok)', 1506858: 'Nikitovka', 1910986: '?', 1601810: 'Malaya Berestovitsa', 5266270: 'Borken', 20979: 'Vakhdat', 1948461: '?', 1709165: 'Aberdeen', 1701105: 'Auezov', 1011127: 'Glodnevo', 1137587: 'Prosvet', 1132021: 'Lalsk', 1914326: 'Ķekava', 1904151: '?', 1064799: 'Yurty Livenskie', 1155358: 'N-Sergi-3', 1949009: '?', 1961901: 'Novopavlovka', 1159764: 'Kuminsky', 1152902: 'Ivanovka', 1153304: 'Bulyga-Fadeevo', 9008: 'Clamart', 1155465: 'Novoutkinsk', 1125081: 'Kommunar', 13301: 'Uvelsky', 1506830: 'Ustinovka', 1711824: '?', 4598: 'Krzywa', 1702786: 'Vishnevka', 4173: 'Verkhny Baskunchak', 1147321: 'Alandsk', 1052191: 'Lobaski', 1149623: 'Savino', 5266506: 'Hünfeld', 1708249: '?', 1026565: 'Karagas', 1135879: 'Checheul', 1602101: 'Vornyany', 1153360: 'Sysoevka', 1709448: 'Bellevue', 1919608: '?', 4376558: 'Freiburg', 1903032: 'Abastumani', 1152726: 'Knevichi', 1043003: 'Solnechny', 1505527: 'Tysmenitsa', 1901579: '?', 1043874: 'Zorino', 1042627: 'Soldatskoe', 1602479: 'Staritsa', 1124214: 'Uakit', 1502651: 'Kitaygorod', 1093379: 'Vernadovka', 1927563: '?', 1029554: 'Parskoe', 1905041: '?', 1714529: 'Teya', 1153757: 'Tumul', 5002487: 'Colorado', 1946948: '?', 1042097: 'Volna', 1938546: '?', 1927130: '?', 1511473: 'Gusyatin', 2205768: '?', 1008311: 'Buguruslan', 19306: 'Kamensk', 1091585: 'Beshtau', 1144349: 'Kolbasa', 1945652: '?', 1945809: '?', 5266839: 'Lörrach', 1024397: 'Novomarkovka', 1080818: 'Klyuch', 1803266: 'Põlva vald', 1947954: '?', 1938403: '?', 1143495: 'Syava', 11288: 'Tuma', 1044539: 'Makhnovka', 1155794: 'Lipchinskoe', 1155817: 'Ust-Nitsinskoe', 1906400: '?', 1504961: 'Mirnoe / Leninskoe', 1144265: 'Chumakovo', 1936184: '?', 1505599: 'Sadovoe', 20371: 'Chiba', 5058154: '?', 1707446: '?', 1925831: '?', 8498: 'Poim', 1041052: 'Krasnoselskoe', 1136393: 'Kanifolny', 5063218: 'West Babylon', 1097232: '?', 1948396: '?', 1019971: 'Talitsy', 1803616: '?', 16835: 'Kabansk', 1940060: '?', 3261: 'Istomino', 1517342: '?', 1927462: 'Lake Bluff', 1947540: 'Sieradz', 1929840: '?', 1930969: '?', 1041876: 'Svobodny', 1041185: 'Pridorozhnaya', 2203099: '?', 1948283: '?', 1131213: 'Raduzhny', 1512852: 'Novogrigoryevka', 16088: 'Zmievka', 2201568: 'Homsār', 1503607: 'Sushki', 1944756: '?', 22527: 'Velikaya Bagachka', 1040694: 'Anapskaya', 1800228: 'Verezheny', 1903840: '?', 1933230: '?', 1948375: '?', 1129241: 'Malinovka', 1911080: '?', 1083196: 'Preobrazhenka', 1712372: '?', 2800: 'Huddersfield', 1948383: '?', 4923667: 'Loxahatchee', 1113547: 'Kundravy', 1138852: 'Kudma', 1083820: 'Podbelsk', 1703565: '?', 1147698: 'Pokrovka', 1929640: '?', 1946489: 'Kelasuri', 1712253: '?', 1500428: 'Chervonoe', 1509968: 'Novoorzhitskoe', 1059032: 'Turovo', 1706727: 'Framingham', 1517700: 'Rakov', 1948410: '?', 11083: 'Khotimsk', 14246: 'Dobrovelichkovka', 1909142: 'Warstein', 5266398: 'Soest', 1909137: '?', 1912695: '?', 1960003: '?', 1059332: 'Dubnevo', 1903110: '?', 1936393: '?', 1901278: 'Jupiter', 1510166: 'Chernukhi', 1135566: 'Dodonovo', 1078510: 'Kashary', 1042319: 'Marino', 1067915: 'Issa', 1502430: 'Ozhenkovka', 1095957: 'Tenki', 1500497: 'Chaykino', 1507395: 'Komarovka', 1102471: 'T/b Sokol', 19571: 'Uppingham', 7316: 'Elgin', 1947449: '?', 1005776: 'Akhunovo', 7407: 'Marshala Zhukova', 1123980: 'Norsk', 1031950: 'Baga-Chonos', 1053405: 'Mary', 1058854: 'Petrovo', 1946551: '?', 14202: 'Novopskov', 1509755: 'Kotelva', 1906529: '?', 1122000: 'Orlean', 9566: 'Pravokumskoe', 1928652: 'Matawan', 1909606: 'Marlboro', 1097205: 'Biklyan', 1940172: '?', 1141471: 'Shandrovo', 1027690: 'Shekshovo', 1602760: 'Lenki', 1518715: 'Kossovo', 1079908: 'Sladkaya Balka', 1517928: 'Wels', 19617: 'Klopitsy', 1517900: 'Paplaka', 4741279: 'Durán', 1113631: 'Svetloe', 1515814: 'Komotini', 1133079: 'Pizhanka', 1080096: 'Ermish', 1030602: 'Chegem 2-J', 1125928: 'Bolshie Vsegodichi', 21988: '?', 1504604: 'Sokolovka', 1504506: 'Androvka', 1946823: '?', 1091616: 'Bolshaya Dzhalga', 2722659: 'Kinshasa', 1928152: '?', 1014166: 'Novy Rogachik', 1714765: 'Eupen', 1113696: 'Goryacheistochnenskaya', 1047969: 'Tumazy', 1939718: '?', 1906941: '?', 10269: 'Skvortsovo', 1077786: 'Vodopadny', 1041398: 'Novoukrainsky', 5334635: '?', 1084606: 'Danilkino', 1048321: 'Koskovo', 1156126: 'Trekhozernaya', 1514990: 'Yaduti', 1509677: 'Butenki', 19647: 'Dyudkovo', 1931823: 'Langley', 1093531: 'Krapotkino', 1922174: '?', 1704430: 'Beaverton', 1506141: 'Olshanitsa', 1096682: 'Kulbaevo-Marasa', 1118611: 'Semenovskoe', 1004900: 'Novye Kazanchi', 1944478: 'Shelton', 1702239: 'Abay', 2204427: '?', 1941122: '?', 1160966: 'Beloyarsk', 1703813: '?', 1046298: 'Ermilovo', 8378: '?', 1096105: 'Gabishevo', 1917924: '?', 4347284: 'Neuzelle', 1002679: 'Kushkopala', 1083208: 'Stroykeramika', 5094232: 'Ripley', 1081785: 'Podvyazye', 1927943: 'La Rioja', 1960159: '?', 5259534: 'Kamenz', 5257432: 'Schwepnitz', 5259532: 'Elstra', 1506598: 'Novoarkhangelsk', 1511714: 'Belozerka', 17219: 'Loyma', 1077986: 'Kazanskaya', 1909859: '?', 1503845: 'Pershotravnevoe', 1941020: '?', 1711305: 'Šilalės kaimiškoji seniūnija', 1023001: 'Velyaminovo', 1917274: 'Yale', 1912795: '?', 1513054: 'Chkalovo', 1947735: '?', 1921554: '?', 5266461: 'Rüdesheim am Rhein', 1136560: 'Komarovka', 1152168: 'Chastye', 1099234: 'Ilino', 1502872: 'Golmovsky', 1902434: '?', 1130522: 'Dubrovka', 1057146: 'Letny Otdykh', 1930341: '?', 1045817: 'Volosovo', 1513404: 'Radoshovka', 1516919: '?', 1600119: 'Deniskovichi', 1901807: '?', 1803205: 'Mustvee', 1505962: 'Gorenka', 17049: 'Privolzhye', 1506261: 'Borovaya', 1924926: '?', 1517650: '?', 1801220: 'Semenovka', 1710233: '?', 1083755: 'Mayskoe', 4695619: 'San Juan', 1600196: 'Druzhilovichi', 5266878: 'Markdorf', 1713942: '?', 1920622: 'West Sacramento', 1505960: 'Gatnoe', 1049786: 'Venera', 1011100: 'Fastov', 22605: '?', 5029311: 'Forest Park', 1948620: '?', 1712769: 'Germantown', 5002111: 'Camp Dallas', 1906113: 'Loudonville', 1926539: '?', 1096943: 'Kildebyak', 7317: 'Hefei', 1142740: 'Tonkino', 1932255: 'Zarasų seniūnija', 1912448: 'Ephrata', 1121820: 'Mariinsk', 21920: 'Hackensack', 1907336: '?', 5031536: 'Wauconda', 1948661: '?', 1800345: 'Gura Galbeney', 2095: '?', 1113087: 'Araslanovo', 15547: 'West Chester', 18470: 'Predivinsk', 1159786: 'Yagodny', 1158303: 'Salairka', 19409: 'Staroalexandrovka', 1158597: 'Yarkovo', 8451: 'Dolgoderevenskoe', 1037111: 'Solnechny', 1914138: '?', 1150856: 'Novoilinsky', 12519: 'Turochak', 1005041: 'Stepanovka', 1153387: 'Chagda', 1711832: '?', 1602447: 'Schepichi', 1036264: 'Zaozerye', 1037322: 'Kharyaga', 1014396: 'Buzinovka', 1510152: 'Gorodische', 1150999: 'Sars ', 1702763: 'Chistovskoe', 1943931: 'Franklin Park', 1152023: 'Lysva', 1922961: '?', 1800817: 'Michurin', 1515993: 'Karmanovo', 1501938: 'Kolki', 1948694: '?', 20970: '?', 1040496: 'Bukhalkino', 1947479: '?', 1912976: 'Pattaya', 1927552: '?', 1926985: '?', 1802: 'Wollongong', 5470163: 'Ynykchan', 1161656: 'Volnyansk', 1006270: 'Tabynsk', 1079331: 'Krasnogornyatsky', 1945146: '?', 1030656: 'Znamenka', 1114794: 'Bolshoy Sundyr', 5041698: 'Memphis', 7557: 'Vereschagino', 1931771: '?', 1041199: 'Ukraina', 1700153: 'Zarechnoe', 1149279: 'Dmitrievskoe', 1129057: 'Mayskoe', 1501414: 'Lozna', 1131306: 'Karintorf', 1927960: '?', 1710992: '?', 18056: '?', 1079371: 'Bystryansky', 1148926: 'Zyukayka', 1130202: 'Polomoshnoe', 1930739: '?', 1702716: 'Presnoredut', 1010964: 'Maslova Pristan', 1077730: 'Novoalexandrovka', 1506293: 'Zhoravka', 1144786: 'Kurundus', 1156890: 'Moryakovsky Zaton', 1156922: 'Polovinka', 5266863: 'Hechingen', 5649: 'Marevo', 1041436: 'Konstantinovskaya', 1153671: 'Uolbut', 1060313: 'Ostafyevo', 1150399: 'M.kaskasal', 1930053: 'Ikšķile', 1047930: '?', 1507098: 'Raygorodka', 3285157: 'Piastów', 3279557: 'Ursus', 1708538: 'Pruszków', 1153830: 'Kangalassy', 1512683: 'Chkalovskoe', 4956596: 'North Ocean City', 1908917: '?', 1715687: '?', 1922493: '?', 1502221: 'Chumaki', 1159351: 'Vladivostoxkoe Shosse 24 Km', 1910963: '?', 1506133: 'Biryuki', 1702125: 'Sadchikovka', 5266477: 'Lollar', 5266448: 'Bad König', 1715163: 'Schwanewede', 1122258: 'Kalmanka', 1701154: 'Feklistovka', 1157576: 'Ozernoe', 1915735: 'North Las Vegas', 1124434: 'Bolshaya Rechka', 1030607: 'Yanikoy', 1502402: 'Peschanka', 1156863: 'Kislovka', 1710257: 'Karavan', 1934943: '?', 1504621: 'Lyubimovka', 16110: 'Nunligran', 1509644: 'Oposhnya', 1710285: '?', 1518833: 'Petaling Jaya', 1920673: 'Woodridge', 19350: 'Zura', 1024243: 'Listopadovka', 3790623: 'Suzhou', 1932516: '?', 1083065: 'Ozersk', 1148873: 'Berezniki', 1931694: '?', 1040610: 'Rozhdestvenskoe', 1700224: 'Pukhalskoe', 1037313: 'Sinegorye', 1079499: 'Krasnopartizansky', 1514254: 'Bachkurino', 3370120: 'Mahajanga', 1129673: 'Novy Put', 1948828: '?', 1936838: '?', 1511846: 'Druzhba', 1053976: 'Drochevo', 1507099: 'Smolyaninovo', 1160367: 'Gorny Zerentuy', 1931370: '?', 1948871: 'Kidderminster', 1161114: 'Kharuta', 1708968: 'Frunze', 5330890: 'Zaraysky', 1137556: 'Koltashevo', 1031978: 'Achinery', 5421166: 'Kulsary', 1928239: '?', 1064281: 'Syabrenitsy', 20253: 'Starovelichkovskaya', 1031424: 'Kamenka', 1055278: 'Topkanovo', 1010926: 'Bolshetroitskoe', 17105: 'Kosov', 1052514: 'Udarny', 1501026: 'Kozlov', 1037147: 'Aykino', 1000030: 'Sergievskoe', 8151: 'Elisenvaara', 19442: 'Shira', 1924133: '?', 1601643: 'Kopatkevichi', 1941965: '?', 1510751: 'Rokitnoe', 14731: 'Balagansk', 1704256: '?', 3256778: 'Obzor', 1504955: 'Vladimirovka', 1509143: 'Kryzhanovka', 1090569: 'Sereda', 1082998: 'Prepolovenka', 1507105: 'Shtormovoe', 1159804: 'Sentyabrsky', 1713726: '?', 1122312: 'Klyuchi', 1931835: '?', 2204113: 'Česká Lípa', 5043084: 'Traverse City', 1002363: 'Mezen-1', 17874: 'Tyarlevo', 1505746: 'Pukhovka', 1127568: 'Marakan', 1138601: 'Sakony (sakonsky S/s)', 1915200: '?', 1948890: '?', 1042258: 'Lermontovo', 1128968: 'Vvedenschina', 1136527: '?', 1925793: '?', 1939610: '?', 17352: 'Zibo', 1509117: 'Pisarevka', 1506893: 'Belokurakino', 1114686: 'Khozankino', 1030598: 'Nartan', 11469: 'Perepravnaya', 1703088: 'Michurin', 1508598: 'Pervomayskoe', 1507925: 'Chishki', 1143529: 'Voskresenka', 1010746: 'Nagorye', 1504470: 'Velyatino', 1159954: 'Bobrovsky', 1042256: 'Krivenkovskoe', 1948393: '?', 1507326: 'Liman', 1932322: '?', 1709391: 'King of Prussia', 1901431: '?', 1915320: 'Alimkent', 5398690: 'Gżira', 1715528: "Ta' Xbiex", 1066141: 'Otradinskoe', 1136818: 'Bakhta', 20264: 'Malaya Viska', 1516445: 'Huntsville', 1946426: '?', 1704758: 'Hønefoss', 1500620: 'Mankovtsy', 19465: 'Urazovka', 1512754: 'Kiselevka', 1159790: 'Vysoky', 1906677: '?', 20889: 'Chernukhino', 1948938: '?', 1138148: 'Krasnaya Niva', 1156777: 'Samus', 17020: '?', 1093427: 'Taraxa', 1094044: 'Sergievka', 1000970: 'Sorovo (derevnya)', 2722636: 'Nakuru', 17393: 'Kazaki', 1084989: 'Ivanteevka', 1048711: 'Kuzovka', 18835: 'Chinar', 1600967: 'Zelenka', 1600423: 'Berezovichi', 1083198: 'Prosvet', 1065576: 'Krasnaya Zarya', 1144866: 'Ksenyevka', 1700206: 'Aydabol', 1096339: 'Sokolka', 1095929: 'Zaton Im Kuybysheva', 1154368: 'Sverdlovskoe', 3215516: 'Riihimäki', 1006943: 'Starotatyshevo', 2101840: 'Yangier (khavastsky Rayon)', 1909155: 'Grugliasco', 18034: 'Iriklinsky', 1702058: 'Bestobe', 1058340: 'Kosmodemyansky', 1902447: '?', 1602579: 'Vishnevka', 1110233: 'Ermolaevo', 2102001: 'Pskent', 1000432: 'Pakshengskaya', 1001153: 'Elizarovo', 1948813: '?', 1950569: '?', 1955032: '?', 1004793: 'Arkhangelskoe', 1123476: 'Tugozvonovo', 1904581: '?', 1036303: 'Shuya', 1138696: 'Poshatovo', 1009203: 'Dmitrieva Polyana', 5304680: 'Thoiry', 1500473: 'Nikolaevka', 1931969: '?', 5477: '?', 1508695: 'Novy Bug', 1046103: 'Irinovka', 1945213: '?', 1151000: '?', 1506357: 'Olshanka', 1093618: 'Ivanovka', 1513088: 'Velikie Kopani', 21059: 'Usva', 1132275: 'Kobra', 1507742: 'Bryukhovichi', 21367: 'Algrange', 1907405: 'Alastaro', 5266341: 'Espelkamp', 1948021: 'Zilupe', 1518607: '?', 1003173: 'Rikasikha', 20681: 'Malaya Purga', 14671: 'Varzi-Yatchi', 1501740: 'Tsuman', 1515582: '?', 1508969: 'Kagarlyk', 1048950: 'Dubovoe', 1079517: 'Bolshekrepinskaya', 1714268: 'Gulcha', 1949062: '?', 1925077: '?', 5266409: 'Lampertheim', 1083338: 'Ust-Kinelsky', 1057282: 'Sharapovo', 1902378: 'Aragats', 1511756: 'Koropets', 1908575: 'Mississippi County', 1924208: '?', 1101735: 'Arbuzovo', 1513016: 'Zolotaya Balka', 1091083: 'Igorevskaya', 12438: '?', 1509220: 'Bobrik Vtoroy', 1153413: 'Anabarsky Natsionalny', 21337: 'Holstebro', 1503598: 'Meleni', 1057587: 'Kuznetsy', 1113035: 'Turgoyak', 1500490: 'Teplovka', 1139947: 'Yuganets', 1905565: 'Sylmar', 77: 'Lesnikovo', 1602997: 'Grudinovka', 1900158: 'Nitzana', 1929756: '?', 1513044: 'Novopokrovka', 1515308: 'Makeevka', 1028412: 'Selo Staroe', 1702180: 'Mayak', 2002135: 'Hachenburg', 1974746: '?', 1600606: 'Dalekie', 1500442: 'Vinnitskoe', 1944878: '?', 1932534: '?', 1509476: 'Shiryaevo', 1516221: 'Żagań', 1946131: '?', 1156152: 'Zavodouspenskoe', 1013427: 'Azarovka', 2722667: 'Yamoussoukro', 1512723: 'Lvovo', 1049207: 'Golikovo', 1502383: 'Gubinikha', 1003893: 'Arkhangelskaya', 1519200: 'Ahlen', 1924660: '?', 1502291: 'Bozhedarovka / Schorsk', 1121798: 'Syoyka', 1041635: 'Vostochny', 4530874: 'Ski', 1517749: '?', 3987: '?', 1703737: 'Alfreton', 1916261: '?', 4519: '?', 1949168: '?', 1949169: '?', 4294968: 'Mandarfen', 5381485: 'Tieflehn', 4124734: 'Rosso', 1501798: 'Lokachi', 1097627: 'Lubenkino', 1927913: 'Oranienburg', 1049979: 'Solovyevo', 1512859: 'Pavlovka', 1949131: '?', 1945655: '?', 1801711: '?', 18393: 'Gizhduvan', 1704910: '?', 1803363: 'Kõpu', 21720: 'Greensboro', 1935526: '?', 1506972: 'Petrovskoe', 1507631: 'Zvertov', 1937447: '?', 1951013: '?', 1930846: '?', 1041111: 'Kazanskaya', 1911182: '?', 1503692: 'Strizhevka', 1518311: '?', 1941498: '?', 1601838: 'Volpa', 1950059: '?', 17473: 'Rozhdestveno', 1923948: 'Balykchi (balykchinsky Rayon)', 1518451: 'Kadzharan (gorod)', 1931834: '?', 1600080: 'Vistychi', 1004480: 'Starokucherganovka', 1944372: 'Bytom', 1516427: 'Bückeburg', 1941090: '?', 1052526: 'Vasina Polyana', 4497666: 'Łobzów', 5041153: 'Jenison', 11438: 'Mons', 1123675: 'Berezovka', 1903727: 'Gex', 22032: 'Novaya Vodolaga', 1505698: 'Staroe', 1515841: 'Zhirovichi', 20132: 'Nisporeny', 21687: 'Nova Gorica', 1058203: 'Ulyanino', 4546785: 'Fisciano', 1603080: 'Myshkovichi', 1146322: 'Unara', 1703592: 'Bissau', 1939140: '?', 1930122: '?', 20522: 'Agoura', 1022391: 'Zhelyabova', 1055823: 'Izmaylovo', 1949410: '?', 5004379: 'Keller', 1153652: 'Daban', 1124224: 'Bilyutay', 1602013: 'Berezovka', 1122122: 'Kharitonovo', 1036910: 'Talitsa', 1951247: '?', 1768: '?', 1153912: 'Chapaevo', 3795735: 'Nanyang', 1506424: 'Lipnyazhka', 1055338: 'Vozdvizhenskoe', 1130025: 'Tyazhinsky', 1160094: 'Gazimursky Zavod', 18054: 'Dobrynikha', 1129076: 'Novy Gorodok', 1145601: 'Zameletenovka', 1515632: '?', 1014483: 'Talovka', 1502814: 'Valeryanovka', 1129330: '?', 1926621: '?', 1109796: 'Khokhryaki', 1139889: 'Naryshkino', 1507264: 'Krasny Luch', 1001481: 'Sovza', 1155843: 'Kuri', 1701408: 'Granitogorsk', 14093: 'Nikonovskoe', 1005484: 'Urgala', 1705657: 'Adamsville', 3807195: 'Deyang', 1085688: 'Rovnoe', 2722610: "Az Zarqā'", 21981: 'Adrasman', 1501936: 'Karasin', 16368: 'Mrakovo', 1137540: 'Vyatka', 3669566: 'Cam Ranh', 1020952: 'Arkhangelskoe', 1704980: 'Rapperswil-Jona', 1500988: 'Gorodische', 1707755: '?', 1905851: '?', 1113197: 'Polyanovka', 22270: 'Turgen', 1700648: 'Karakemir', 1040796: 'Chernigovskoe', 1506215: 'Kivshovataya', 1701872: 'Priishimskoe', 1908426: '?', 1512673: 'Kamennaya Yaruga', 1007528: 'Kugarchi', 1911584: 'Serekunda', 14006: 'Aleshki', 1140854: 'Satis', 1925419: '?', 1156755: 'Orekhovo', 12146: 'Tarnovo', 1701146: 'Zubovka', 1504505: 'Andreevka', 1951368: '?', 1083043: 'Bolshaya Glushitsa', 1114942: 'Yunga', 1114824: 'Kalaykasy', 1942206: 'Preiļi', 1513552: '?', 1502209: 'Lyubimovka', 1160842: 'Shilka Svkh', 1052997: 'Malye Berezniki', 1148441: 'Blagodarnoe', 1936908: '?', 17139: 'Zaykovo', 1705234: 'Kurgantepa (fergansky Rayon)', 8227: 'Dolgorukovo', 1709870: 'Avdarma', 3751: '?', 1500941: 'Olshanka', 1154663: 'Basyanovsky', 1128887: 'Rysevo', 1708500: 'Sassnitz', 1710184: 'Laytown-Bettystown-Mornington', 1944262: '?', 1505592: 'Morozovka', 1110894: 'Sharkan', 1500318: 'Okhotskoe', 1932663: '?', 1509244: 'Yasenovo Vtoroe', 1004685: 'Vozdvizhenka', 1803323: 'Elva (elva)', 20491: 'Badamsha', 20243: 'Knyaschiny', 1501614: 'Rzhischev', 1159163: 'Nizhnetambovskoe', 1602314: 'Moiseevschina', 1907937: '?', 1949513: 'Rankweil', 1902607: '?', 1918463: '?', 4907: '?', 1146081: 'Nadezhdino', 18597: 'Staropolye', 12994: '?', 1095537: 'Malaya Tsilna', 4719528: 'León', 1153255: 'Leninskoe', 1014429: 'Primorsky', 1949349: '?', 1709198: 'Alexandria', 1068088: 'Sumy', 1706354: 'Kolibabovka', 1949361: '?', 1951893: '?', 1602466: 'Grozov', 1113440: 'Nagorny', 2722673: 'Macau', 1111706: 'Krasnoselsk', 4548493: '?', 17604: 'Koelga', 1060334: 'Nivsky', 1121792: 'Nikolskoe', 1942302: '?', 1907158: 'Artem', 2571: 'Zhetysay', 3065825: 'Karaj', 1134053: 'Porez', 1115536: 'Persirlany', 1902529: '?', 1122950: 'Sychevka', 1915760: '?', 1053306: 'Standrovo', 18926: 'Ordynskoe', 1903600: 'Kvareli', 1044070: 'Ponyri 2-E', 1944701: 'Petersburg', 1908663: '?', 1702681: 'Yalty', 1007177: 'Karayar', 1600471: 'Chukhovo', 4637: 'Strasheny', 1157190: 'Aryg-Uzuu', 1135382: 'Pamyati 13 Bortsov', 1157068: 'Kyzyl-Mazhalyk', 1603067: 'Ryasno', 1516756: '?', 1801718: 'Anaheim Hills', 1712243: '?', 4543379: 'Omegna', 1903816: '?', 1150736: 'Kormovische', 1111606: 'Baranovka', 1710767: 'Breckenridge', 1701696: 'Fedorovka', 1507206: 'Melovatka', 1136277: 'Novoangarsk', 1136443: 'Tinskoy', 1967958: '?', 1080677: 'Naumovo', 1156469: 'Druzhny', 1156761: 'Sergeevo', 1156765: 'Torbeevo', 1112789: 'Roza', 1948725: '?', 1122053: 'Vostrovo', 1918657: '?', 1911972: '?', 3294260: 'Głogów', 1949435: '?', 5097797: 'Black Mesa Grant', 1706198: '?', 1161070: 'Kharasavey', 1922633: '?', 20946: 'Tashir', 1942223: '?', 1924370: '?', 1708732: 'Ayni', 1966382: 'Yorkton', 1928921: '?', 1124695: 'Angoya', 1047035: 'Pchevzha', 1031719: 'Kaluzhskoe', 1707465: 'Marijampolės seniūnija', 1515461: 'Sokirintsy', 1925783: '?', 3049744: 'Sulaymaniyah', 1041278: 'Cheburgolskaya', 1946324: '?', 1159519: 'Kuybyshevo', 1154195: 'Koptelovo', 1948921: '?', 1909056: '?', 1038117: 'Loparevo', 1159847: 'Gornorechensk', 1907522: '?', 1507247: 'Khmelnitsky', 1519082: 'Uryupinka', 1511197: 'Perekopovka', 1508369: 'Semenovka', 5327950: 'Wólka Kosowska', 21644: 'Sosnovka', 1949406: 'Sankt Johann in Tirol', 1714: 'Surok', 1501953: 'Okonsk', 1945164: '?', 1500077: 'Krinichnoe', 1601902: 'Svisloch', 1002285: 'Zasulye', 15486: 'Barrington', 1503893: 'Andrushki', 4447277: 'Cesson', 1003194: 'Tundra', 1914202: '?', 1923155: 'Baja', 1503573: 'Belka', 6092: 'Erakhtur', 1909304: 'Zemo-Alvani', 22600: 'Gatineau', 1703581: 'Belousha', 1005658: 'Novy Biktyash', 1148576: 'Berezniki', 1507016: 'Georgievka', 1030612: 'Verkhnyaya Balkaria', 1040959: 'Vozrozhdenie', 1507949: 'Pozdimir', 1507937: 'Korchin', 1143827: 'Lebedevka', 1957934: '?', 1004530: 'Volnoe', 1934791: '?', 5259334: 'Neuruppin', 1418: 'Ozerechye', 17309: 'Shorkistry', 22413: 'Starye Petrovtsy', 6440: 'Atyashevo', 1706912: 'Oregon House', 4324: 'Bagramovo', 1705822: 'Coimbra', 1060421: 'Pechenga (stantsia)', 1031894: 'Idzhil', 17336: '?', 14594: 'Tetskany', 1057505: 'Savinskaya (belavinsky S/o)', 1114498: 'Komsomolskoe', 1500137: 'Pobednoe', 2666: 'Shuntuk', 1071969: 'Khibiny', 1503097: 'Bezymennoe', 1600019: 'Podleseyki', 1706631: '?', 1053814: 'Zolotovo', 1082119: 'Nizhnee Maltsevo', 1123677: 'Verkhnezeysk', 1026325: 'Vachi', 1082999: 'Priboy', 1947519: '?', 1906305: '?', 16346: 'Zeitz', 1948442: '?', 1161142: 'Bechevinka', 1058171: 'Ryleevo', 1157938: 'Miassy', 1928140: '?', 1094543: 'Bilyarsk', 1094592: 'Shama', 1943888: '?', 1908370: '?', 1802224: '?', 2001496: '?', 1913209: '?', 1500233: 'Yantarnoe', 1950925: 'Battle Ground', 1018490: 'Cherny Porog', 1067069: 'Korsakovo', 1159719: 'Polnovat', 1500649: 'Dzhulinka', 1146231: 'Russkaya Polyana', 1146215: 'Volotovka', 1146213: 'Bologoe', 1926933: 'Skjern', 1705215: 'Auce', 1911863: '?', 5308946: '?', 1935891: '?', 1711694: '?', 1701972: 'Amangeldy', 15676: 'San Salvador', 3317290: 'Fort Rixon', 3212519: 'Yläne', 5267822: 'Langen (Hessen)', 1503846: 'Peschanitsa', 1051278: 'Korkatovo', 1705184: 'Ruzhany', 1705503: 'Cherry Hill', 1510786: 'Stepan', 5266267: 'Troisdorf', 1055846: 'Maloe Vidnoe', 1508425: 'Bereznegovatoe', 1509910: 'Petrovtsy', 1084004: 'Varlamovo', 1094648: 'Starye Salmany', 1516935: '?', 1124377: 'Mikhaylovka', 1502223: 'Slobozhanskoe / Yubileynoe', 3138261: 'Al Muḩarraq', 1707564: 'Media', 21397: 'Rosemont', 1144646: 'Meret', 20431: 'Debin', 1519342: '?', 1027296: 'Yuzhno-Sukhokumsk', 1508958: 'Belyaevka', 1504569: 'Menchikuri', 1083864: 'Privolzhye', 12032: 'Waldorf', 1030084: 'Peremilovo', 1936253: '?', 3335999: 'Selebi-Phikwe', 1941865: '?', 17558: 'Yamburg', 1035501: 'Novaya Dzheguta', 1503529: 'Barashovka', 1504964: 'Novodanilovka', 1925385: '?', 1909974: '?', 1707919: '?', 11569: 'Issad', 1702018: 'Sverdlovka', 4550810: 'Bastia Umbra', 1944391: '?', 1161402: 'Nikolaevka', 1506601: 'Podvysokoe', 1705399: 'Krivonosy', 1041617: 'Oktyabrsky', 2844: 'Boone', 1096281: 'Kamsky Lespromkhoz', 1128326: 'Khrebtovaya', 1516045: '?', 1093383: 'Gagarino 1-E', 1000115: 'Kuzhorskaya', 1949622: '?', 1134242: 'Fileyka', 1902640: '?', 1916053: '?', 1904678: '?', 1949203: '?', 1907353: '?', 1702662: 'Efimovka', 1508625: 'Troitsko-Safonovo', 1901985: '?', 1153644: 'Artyk', 1104402: 'Volosovo', 1081282: 'Vysokie Polyany', 1503064: 'Alexandrovka', 1505639: 'Trushki', 1903666: '?', 1046390: 'Peski', 1123691: 'Oktyabrsky', 1059092: 'Durykino', 1079755: 'Tarasovsky', 13566: 'Atka', 2718: 'Znamenskoe', 1131760: 'Yuryevo', 1009630: 'Novoborisovka', 1930221: 'Bedford', 12486: 'Lynnwood', 12643: 'Krasnaya Polyana', 21924: '?', 1158162: 'Ldps', 5259467: 'Rodewisch', 1112093: 'Undory', 5267805: 'Wickede (Ruhr)', 20823: 'Foggia', 1915860: '?', 1921960: '?', 5130603: 'Whitecourt', 1064914: 'Domakha', 5261747: '?', 1026966: 'Ashaga-Yarak', 9299: 'Atasu', 1949694: '?', 1949695: '?', 1066303: 'Pankovo', 1513500: 'Kremenchuki', 1500354: 'Stepnoe', 1113443: 'Petrovskoe', 1902007: '?', 1910540: '?', 1901281: 'Kahului', 2207076: 'Andernach', 1148552: 'Vsevolodo-Vilva', 1032655: 'Paliki', 1801552: 'Tsaul', 1701870: 'Pionerskoe', 1802236: '?', 1600400: 'Tukhovichi', 1602075: 'Negnevichi', 1800424: 'Elizaveta', 1126665: 'Novlyanka', 1509725: 'Kozelschina', 1160868: 'Meynypilgyno', 1503749: 'Norintsy', 4325516: 'Ulm', 1077760: 'Solnechny', 1500531: 'Morskoe', 1160396: 'Kalanguy', 1147344: 'Kulma', 1965554: 'Paltamo', 1958204: '?', 515: '?', 1516631: 'Castro Valley', 1152984: 'Fadeevka', 19372: '?', 1926297: '?', 1938485: '?', 1927904: '?', 1129237: 'Kuzbassky', 3209241: 'Dalaman', 3159806: 'Bergama', 1949636: '?', 1031227: 'Tushino', 15986: 'Buranny', 1500574: 'Gaspra', 1700176: 'Kayrakty', 1702672: 'Lomonosovka', 1153790: 'Kytyl-Dyura', 4083178: 'Owerri', 1920327: '?', 1159523: 'Novokursk', 1933864: '?', 1903417: '?', 1914172: '?', 1032518: 'Kurovskoy', 3823839: 'Sokcho', 1145603: 'Kazanka', 1905780: '?', 1506341: 'Charivnoe', 1506320: 'Vityazevka', 13779: '?', 1102432: 'Solnechny', 1503326: 'Chervonoe', 1033727: 'Mamontovo', 3051056: 'Tabuk', 1503526: 'Yablonets', 1913655: '?', 1096617: 'Sheremetyevka', 1952945: '?', 1155545: 'Nikolo-Pavlovskoe', 4722255: 'Limón', 1093414: 'Pichaevo', 1035654: 'Girvas', 1121677: 'Aktash', 1047932: 'Lukinskaya', 1947674: '?', 1108880: 'Sotsialistichesky', 1949801: '?', 1139196: 'Linda (lindovsky S/s)', 1063394: 'Yazvischi', 1935876: '?', 1504414: 'Russkoe Pole', 1945307: 'Orléans', 1128042: 'Nadezhdinsk', 1949808: '?', 1083693: 'Riga', 1702630: 'Vlasovka', 4653488: 'Campo Grande', 1901983: 'Zarbdar (pastdargomsky Rayon)', 1114707: 'Bichurino', 1109845: 'Kushya', 1940821: '?', 1141261: 'Volzhsky', 1505500: 'Ezupol', 1503140: 'Spasko-Mikhaylovka', 1501925: 'Budki', 22019: 'Eskhar', 1000025: 'Novy', 1148005: 'Nauruzovo', 1904746: 'Uchkurgan', 1085857: 'Tulsky', 6026: 'Ostrovtsy', 1052688: 'Izosimovka', 1124579: 'Sudzha', 5264923: 'Maisach', 10009: 'Gornozavodskoe', 5266769: 'Nagold', 1006484: 'Kukkuyanovo', 1601366: 'Zasintsy', 1108870: 'Selivanovo', 1155560: 'Severka', 1031099: 'Romanovo', 1500401: 'Kamenolomnya', 1701922: 'Zhezdy', 1944311: '?', 1949856: 'Fossano', 1036300: 'Shoksha', 1949844: '?', 1095023: 'Bakaly', 1518928: '?', 21161: 'Leura', 1947061: '?', 1701168: 'Bolshenarymskoe', 1012179: 'Kirillovka', 1913555: '?', 1939467: '?', 1603123: 'Timonovo', 1705805: 'Anklam', 5004133: 'Hubbard', 1151209: 'Okhansk', 1906232: '?', 1013538: 'Mikhaylovsk', 1037219: 'Vad', 1000846: 'Vilegodsk', 1945765: '?', 1600535: 'Glinka', 14801: 'Tabory', 1054563: 'Mikhali', 1600176: 'Mateevichi', 1517328: '?', 1038310: 'Kady', 1093974: 'Kh-Vo Mamontovo', 1603273: 'Khodosy', 1701725: 'Kurminskoe', 1506921: 'Donetsky', 1135167: '?', 1509745: 'Dmitrovka', 2205195: '?', 1602069: 'Lyubcha', 1923178: '?', 1924956: '?', 1962877: 'Francavilla Fontana', 1935914: '?', 1110785: 'Porshur-Tuklya', 1512634: 'Kulinichi', 1041609: 'Krylovskaya', 1500042: 'Peschanoe', 11637: 'Zagradovka', 1061146: 'Volot', 1092636: 'Sokolovo', 1703726: '?', 1916668: 'Middlesbrough', 1503350: 'Pershotravensk', 1914522: '?', 1908940: 'Ústí nad Labem', 1927631: '?', 10392: 'Idar-Oberstein', 1015318: 'Terkin', 1600104: 'Medno', 4476305: 'Nový Bor', 1952624: '?', 1509158: 'Fontanka', 1937485: '?', 2722618: 'Sanaa', 1129340: 'Demyanovka', 1511970: 'Velikie Zagaytsy', 1008235: 'Buzatovo', 1508878: 'Puzhaykovo', 1943165: '?', 16690: 'Staroyuryevo', 1128928: 'Vesely', 4695512: 'Bermuda', 1137364: 'Uxyanskoe', 1511920: 'Belobozhnitsa', 1905552: '?', 1701547: 'Akbulak', 1708370: 'Alexandria', 1703605: '?', 1945953: '?', 1503469: 'Miropol', 1050293: 'Troekurovo', 1934740: '?', 1129937: 'Zarubino', 1502068: 'Staraya Vyzhevka', 1929467: '?', 1519080: '?', 1922483: '?', 1112527: 'Krasnogorsky', 1111404: 'Sosnovka', 1913701: '?', 1950007: '?', 1946603: '?', 1093235: 'Staroseslavino', 1941223: '?', 1142762: 'Burepolom', 1000752: 'Rechnoy', 14865: 'Sadovoe', 1036137: 'Kuytezha', 1709222: 'Anderson', 11634: 'Letka', 1134945: 'Kozhany', 1137930: 'Baydary', 1948534: '?', 1923136: '?', 1938144: '?', 1160909: 'Valkumey', 1715150: '?', 1932000: '?', 1912325: '?', 1602210: 'Sinki', 1086334: 'Kadgaron', 1092867: 'Novopokrovka', 1803198: 'Toila', 2207482: 'Bad Segeberg', 5259994: 'Neumünster', 1122228: 'Lugovskoe', 1122803: 'Rebrikha', 1095134: 'Chutay', 1095135: 'Shishiner', 754: '?', 1936265: '?', 1041098: 'Sovetsky', 1158058: 'Usovo', 1950039: '?', 1706302: '?', 1704101: 'Port Hope', 1714238: '?', 1129914: 'Polutornik', 1951436: '?', 1504849: 'Primorsky Posad', 1037210: 'Yb', 1929228: '?', 1927190: '?', 1075952: 'Toroshino', 1502713: 'Artemovka', 1602455: 'Lesnoe', 1517622: 'Lesnoy', 1111163: 'Sosnovy Bor', 1967396: 'Basra', 1602582: 'Ostroshitsky Gorodok', 1915356: '?', 1949956: '?', 1075028: 'Pavy', 1129417: 'Krasnye Orly', 19848: 'Neftyanaya', 1079884: 'Mikhaylovka', 1079032: 'Svetoch', 1079079: 'Ozerny', 1151374: 'Gamovo', 1930573: '?', 1105576: 'Novogurovsky', 1907308: '?', 1948158: '?', 1157296: 'Ivanovo (selo)', 1036258: 'Vilga', 1505211: 'Stary Ugrinov', 1928828: '?', 1093476: 'Platonovka', 1095960: 'Chelny', 13883: 'Mekhonskoe', 1137333: 'Krutikha', 1920483: '?', 1601288: 'Pokolyubichi', 20572: 'Bystry Istok', 1085538: 'Alexashkino', 1510877: 'Ryabina', 1713923: '?', 8579: 'Tsilna', 1151856: 'Chernoe', 1041705: 'Sovetskaya', 1508443: 'Bratskoe', 1124912: 'Zhuklino', 1935024: 'Bad Dürrenberg', 1702137: 'Arkhipovka', 5521: 'Sredny', 1924456: '?', 1708926: 'Södertälje', 1947772: '?', 1008664: 'Krasny Yar', 1134404: 'Shokhorda', 1517761: '?', 1703147: 'Lamoni', 4161904: 'Maradi', 1113137: 'Goreloe', 1948811: '?', 1803388: 'Muruntau', 1031102: 'Rybachy', 1005525: 'Inzer', 1122850: 'Tambovsky', 1126245: 'Voynovo', 1126270: 'Ilkino', 5423703: 'Vatra', 1114127: 'Novoe Akhperdino', 1067662: 'Grabovo', 20115: 'Vorovskolesskaya', 1093013: 'Novotomnikovo', 1914784: 'Marlton', 1505683: 'Gora', 1950128: '?', 1515891: 'Keles', 1044435: 'Ivanovka', 1950139: '?', 1146195: 'Poltavka', 16390: 'Ede', 12615: 'Saarijärvi', 1914291: 'Lutherstadt Wittenberg', 1078284: 'Chernyshevka', 1950308: 'Mendocino', 1933268: 'Vysoké Mýto', 4176324: '?', 1155894: 'Patrushi', 1918804: '?', 4922754: 'Florida City', 1147644: 'Chapaevka', 1509389: 'Krasnoe', 1086126: 'Kaluga (selo)', 4956455: 'Nantucket', 1503308: 'Gorodkovka', 1704455: 'Auburn Hills', 1031997: 'Prikumsky', 1140386: 'Zinyaki (zinyakovsky S/s)', 1132493: 'Lesnye Polyany', 1701558: 'Pugachevo', 1934719: '?', 1950189: '?', 9991: 'Sarata', 1505974: 'Muzychi', 5016864: '?', 1154370: 'Siminchi', 8836: 'Annensky Most', 1510978: 'Miropolye', 1701080: 'Perevalnoe', 1947359: '?', 1602456: 'Buchatino', 21642: 'Shakat', 5122: 'Krasnoarmeyka', 1143689: 'Zarechye', 1095596: 'Kosteneevo', 1946998: '?', 1154711: 'Shakhty', 1915415: '?', 11120: 'Khilok', 4553160: 'Fier', 1504095: 'Stetkovtsy', 1504084: 'Krasnopol', 1504090: 'Nosovka', 1601277: 'Stolbun', 1709690: 'Radom', 1508199: 'Dashava', 1053422: 'Sabur-Machkassy', 5266642: 'Plochingen', 1939281: '?', 1904099: 'Essex', 1504638: 'Balabino', 1903269: '?', 1514762: 'Rokitnoe', 1510411: 'Dubrovitsa', 1508076: 'Zhvirka', 1905400: 'Burg', 5326961: '?', 1009182: 'Yabalakly', 1000106: 'Dakhovskaya', 1040930: 'Balkovskaya', 1154496: 'Lyapunovo', 1058949: 'Lipitsy', 1949306: '?', 1907322: 'Telšiai', 1098655: 'Tuchkovo', 14745: 'Szolnok', 1510395: 'Stovpets', 1002841: 'Konevo', 1084078: 'Ierusalimsky', 21531: '?', 1929546: '?', 1922353: '?', 1919239: '?', 1938610: '?', 1949675: '?', 1946871: 'Fort Lee', 1509658: 'Belukhovka', 1500238: 'Voinka', 1518945: 'Ptuj', 1601572: 'Krinichny', 1904323: 'Saykhunabad', 1708087: '?', 1913534: '?', 1512587: 'Martovo', 1147203: 'Kalinovka', 1060226: 'Dolgoe Lyodovo', 1041727: 'Kubansky', 1712939: '?', 1935691: '?', 1924041: '?', 5266040: 'Oldenburg in Holstein', 1707695: 'Overland Park', 1512081: 'Samoylovka', 1519257: 'Celje', 1703327: 'Calais', 20845: '?', 1013675: 'Vysokoselische', 1041732: 'Novoivanovskaya', 4924739: 'Seminole', 1113789: 'Chernokozovo', 1945180: '?', 1919051: '?', 1913581: '?', 1507988: 'Kalinov', 1027967: 'Kulikovo', 16262: '?', 1709221: 'Andalusia', 1504231: 'Kushnitsa', 2203636: '?', 3303: 'Norwalk', 1919770: '?', 1952559: 'Ninh Bình', 1710: 'Niterói', 1700223: 'Elenovka', 20878: '?', 1950448: 'Biên Hòa', 1156069: 'Kazakovskoe', 17168: 'Devichki', 1146803: 'Sovkhozny', 3266936: '?', 1145705: 'Zvezdino', 1063879: 'Antsiferovo', 1914136: '?', 1933008: '?', 1143840: 'Novolokti', 1502803: 'Staromayorskoe', 1078232: 'Gulyay-Borisovka', 1129164: 'Berezovsky', 20469: 'Alkino-2', 1158848: 'Osa', 1113894: 'A. Sheripova', 1141919: 'Baykovo', 1800481: 'Ilichevka', 13216: 'Mukhtolovo', 1932911: '?', 1151056: 'Opachevka', 4978897: '?', 21627: 'Tsulukidze', 1111122: 'Ukan', 1135483: 'Ozernoe', 1919064: '?', 1024695: 'Novokhopersky', 1713953: '?', 1504352: 'Lazeschina', 1157385: 'Melekhino', 11426: 'Saranpaul', 1036531: 'Nadvoitsy (derevnya)', 6358: 'Pronsk', 1514487: 'Krasenovka', 1077915: 'Sinegorsky', 1704100: 'Sinkevichi', 1914346: '?', 1098304: 'Vypolzovo', 17172: 'Sokiryany', 19520: '?', 12072: 'Listvyansky', 1512956: 'Preobrazhenka / Chervony Chaban', 1123085: 'Kashkaragaikha', 1078616: 'Vladimirovskaya', 1158968: 'Lermontovka', 3172: 'Urman', 1962794: '?', 1135376: 'Muzhichkino', 1704010: 'Vladimirovka', 1136927: 'Krutoyar', 1011060: 'Kustovoe', 21242: 'Axuat', 1702222: 'Novoshumnoe', 1083209: 'Sukhaya Vyazovka', 5083818: 'Fox River', 1064284: 'Tregubovo', 1500108: 'Zarechnoe', 1031960: 'Iki-Chonos', 1709166: 'Abingdon', 1145086: 'Chistoozernoe', 1004885: 'Korolevo', 5267107: 'Günzburg', 1601001: 'Guta', 10203: 'Kurumoch', 1950496: '?', 1094179: 'Sofinka', 11094: 'Jiamusi', 1025195: 'Yamnoe', 1507806: 'Krukenichi', 1129034: 'Sharomy', 1014114: 'Primorsk', 22702: '?', 21163: 'Pervomayka', 16981: '?', 1502175: 'Verkhovtsevo', 1123483: 'Shipunovo', 5330006: 'Alykel', 13747: 'Shitkino', 1513567: 'Ivashkovtsy', 1966762: '?', 1918636: '?', 1002664: 'Kevrola', 1918780: '?', 1055044: 'Rumyantsevo', 1007181: 'Krasny Uryush', 1950717: 'Shihezi', 1515168: 'Naumovka', 1913929: '?', 1913639: '?', 1513976: 'Nekhayki', 1150081: 'Verkh-Inva', 21660: 'Kibray', 1507586: 'Novye Strelischa', 1915427: 'Arzni', 5331435: 'Sovetsky', 1500520: 'Urozhaynoe', 1949909: '?', 1514006: 'Pugachovka', 1932855: '?', 1054381: 'Rastunovo', 1501574: 'Ustilug', 1122283: 'Lugovoe', 15838: 'Podgorensky', 1514717: 'Mamaevtsy', 19785: '?', 21413: 'Kelmentsy', 1948303: '?', 1052803: 'Novye Turdaki', 1715072: '?', 1514167: 'Yampol', 1030769: 'Livny', 1507645: 'Matsoshin', 1947568: '?', 1948908: '?', 1077481: 'Ostrov', 1092000: 'Borgustanskaya', 1945828: '?', 1157129: 'Chaa-Suur', 1503260: 'Kontarnoe', 1701565: 'Kyzyloba', 4532458: 'Myre', 1929951: 'Smiltene', 1025226: 'Repye', 1109721: 'Izhevsky Lesouchastok-2', 5809: 'Ladovskaya Balka', 1505982: 'Chabany', 1503580: 'Gorschik', 1908824: 'Orange County', 1602607: 'Churilovichi', 1041201: 'Chelbasskaya', 1963665: 'Gal', 1068933: 'Malaya Sergeevka', 1929939: '?', 1115119: 'Opytny', 1706612: 'Green Bay', 1901785: '?', 1600377: 'Golovnintsy', 1600390: 'Rusinovichi', 1934899: '?', 21591: 'Zherebkovo', 1512885: 'Geroyskoe', 5417027: 'Valkenburg', 1005969: 'Yablochnoe', 1505944: 'Stayki', 1911995: '?', 1914668: '?', 1937446: '?', 1950669: '?', 4437216: 'Grignan', 1949556: '?', 3803: 'Mezhdurechye', 1018608: 'Depo', 9799: 'Zastavna', 21177: 'Glubokoe', 20778: 'Borkovichi', 1502247: 'Lozovatka', 1950632: '?', 1158105: 'Abalak', 1910703: 'Aukštadvaris', 1947557: '?', 1907399: '?', 1085567: 'Niva', 1706458: '?', 1039093: 'Neverovo', 1945931: '?', 1947563: '?', 1135410: 'Ustyug', 12964: 'Khurmuli', 6746: '?', 1011816: 'Rzhanitsa', 1950667: '?', 1515815: 'Sisian', 1601519: 'Miloshevichi', 1600612: 'Druya', 1022304: 'Filenskoe', 1925401: '?', 1040922: 'Svobodnoe', 1029615: 'Arkhipovka', 1000602: 'Velikaya', 1078660: 'Platovo', 1506300: 'Panfily', 9256: 'Peninga (poselok)', 4549455: 'Carpi', 4548596: 'Castelrotto - Kastelruth', 4541242: '?', 16361: 'Epifan', 1012844: 'Stary Krivets', 1139660: 'Filinskoe', 4114941: 'Dédougou', 1701650: 'Algabas', 1507369: 'Privolye', 1705165: 'Krasnoarmeyskoe', 1950706: '?', 1030908: 'Petrovo', 14610: 'Road Town', 1132503: 'Permskaya', 21399: 'Red Deer', 1503330: 'Baranovka', 1111682: 'Novaya Malykla', 1011366: 'Kokino', 1601618: 'Luchitsy', 1602520: 'Oktyabr', 1071790: 'Moshenino', 1924388: '?', 1160532: 'Firsovo', 4539373: 'Sinalunga', 1094833: 'Cheremshan', 1074724: 'Volyshovo', 16301: '?', 1514628: 'Chagor', 1500341: 'Krestyanovka', 1514576: 'Gertsa', 1919409: 'Salerno', 1915951: '?', 1923298: '?', 20938: '?', 1144630: 'Verkh-Suzun', 1134092: 'Buyskoe', 1927454: '?', 1921363: 'Southampton', 1949760: '?', 1149176: 'Visim', 1509548: 'Globino', 1504386: 'Bushtyna', 20360: 'Sharan', 2722569: 'Delmas', 1700415: 'Mikhaylovka', 3099335: 'Butare', 1124725: 'Nur-Tukhum', 1946734: '?', 1954233: '?', 1602390: 'Dovbeni', 1508663: 'Nechayannoe', 1136708: 'Bryanka', 1136716: 'Pit-Gorodok', 1112294: 'Kuznetskoe', 1122865: 'Zelenaya Dubrava', 4203972: 'Beni Mellal', 3879: 'Letnerechensky', 1158248: 'Borki', 1601287: 'Bobovichi', 5998: 'Umet', 1134161: 'Savinovo', 10518: 'Ergeninsky', 1516669: '?', 1022852: 'Babushkino', 1032812: 'Verkhovye', 1160131: 'Naminga', 1122863: 'Dalny', 1094601: 'Bazarnye Mataki', 1140188: 'Shimorskoe', 4250393: 'Stockholm', 1026789: 'Talovka', 1506207: 'Yasenovka', 1086442: 'Gizel', 1702207: 'Suvorovo', 1155682: 'Kalya', 1506638: 'Verbovka', 1922657: '?', 1953844: '?', 1144585: 'Ust-Lukovka', 1078675: 'Topolevy', 1508949: 'Starokazachye', 1800699: 'Kerbuna', 1912426: '?', 1047271: 'Rassvet', 1091710: 'Zavetnoe', 1510628: 'Mezhirich', 1050380: 'Sotnur', 1043166: 'Konyshevka', 22642: 'Baynasay (novomikhaylovka)', 1951302: '?', 1906343: '?', 1500557: 'Krasnaya Polyana', 1136243: 'Novotroitskoe', 1502952: 'Ivanopolye', 2001716: '?', 2001218: 'Pardubice', 1513738: 'Voronovtsy', 1513757: 'Svyatets', 16466: 'Yartsevo', 7041: 'Almalybak', 1701876: 'Sadovoe', 1035496: 'Dzheguta', 1710675: '?', 13511: 'Mamlyutka', 1509331: 'Scherbanka', 1508803: 'Suvoroe / Chervonaya Zirka', 1947329: 'Province de Laayoune', 1143833: 'Mayak', 1122204: 'Galtsovka', 1052893: 'Shaverki', 1705556: '?', 1122074: 'Novoegoryevskoe', 1052792: 'Kochkurovo', 5436878: 'Knyazhitsy', 1950410: '?', 1051968: 'Solnechny', 1509076: 'Staraya Nekrasovka', 11093: 'Temkino', 11103: 'Topchikha', 1711198: 'Victoria', 1937576: '?', 8896: 'Chemodanovka', 1516780: 'Maracaibo', 1914532: 'South Portland', 1701738: 'Abay', 11752: 'Vasilkovo', 4228690: 'Whittlesford', 1518016: 'Aygedzor', 1709220: '?', 4289750: 'Trumau', 1947420: 'Mayfield Heights', 1918484: 'Parma', 1513988: 'Buzovka', 4223955: 'Maribo', 20525: '?', 1950871: '?', 1503973: 'Vcherayshe', 1109645: 'Debesy', 1917405: '?', 1950870: '?', 1949347: '?', 5267019: 'Kulmbach', 5259830: 'Döbeln', 1602713: 'Svisloch', 5328: 'Melekhovo', 1055573: 'Biorki', 12647: 'Eagle River', 4036: 'Sosnovka', 1160418: 'Yasnogorsk', 5428889: 'Solnechny', 1050250: 'Kolybelskoe', 1702081: 'Smirnovka', 1505681: 'Gnedin', 1703169: '?', 1045379: 'Leningradsky Shlyuz', 6069: 'Beltsy', 1005242: 'Penkozavod', 1038160: 'Novo-Petrovskoe', 1802213: 'Warsaw', 1128557: 'Rybinsk (derevnya)', 1701307: 'Rulikha', 1509564: 'Manzhelia', 1714532: 'Gulripsh', 1713559: 'Holyoke', 1012947: 'Posudichi', 1940260: '?', 1152455: 'Verkhnee Kalino', 5264811: 'Saaldorf-Surheim', 5266902: 'Bad Reichenhall', 1096711: 'R.bogdashkino', 1930460: '?', 1501427: 'Salnitsa', 1950332: '?', 1065097: 'Aleshnya', 1061045: 'Nebylitsy', 1155299: 'Byngi', 1023925: 'Nikolskoe 2-E', 6009: 'Pervomaysky', 1714710: 'São Carlos', 1086170: 'Sosnovaya Maza', 20449: 'Rodakovo', 1700398: 'Voznesenovka', 1058131: 'Nikitskoe', 1917138: '?', 1090586: 'Khotkovo', 17553: '?', 1155685: 'Sosva', 1517739: 'Kochkor-Ata', 1152273: 'Ryabinino', 1923112: '?', 1947750: '?', 1516514: 'Lansing', 1931867: '?', 1081267: 'Studenki', 1518532: 'Efremovka', 1133578: 'Denisovy', 1926656: 'Carlstadt', 1505194: 'Kopanki', 1703303: 'Tuscaloosa', 19946: 'Montgomery', 1022289: 'Syanino', 1502128: 'Grushevka / Leninskoe', 1500271: 'Ilichevo', 1035326: 'Savolenka', 1035861: 'Velikaya Guba (poselok)', 1595: 'Naples', 2100002: 'Abduby', 1042205: 'Parkovy', 1500333: 'Alexeevka', 1704898: 'Bad Friedrichshall', 3113835: 'Tadjoura', 1075680: 'Moskvino', 1516099: 'Khakulabad (narynsky Rayon)', 4320223: 'Westerburg', 1502272: 'Katerinopol', 1948102: '?', 1058661: 'Mukhanovo', 1502307: 'Novopetrovka', 1944202: 'Somma Lombardo', 1601620: 'Lyaskovichi', 1160757: 'Smolenka', 1906022: 'Castellón', 1940961: '?', 1504319: 'Chervenevo', 1105801: 'Ivanovo (derevnya)', 9834: 'Bolshaya Chernigovka', 1019610: 'Gvozdevo', 1512504: 'Mirolyubovka / Komsomolskoe', 1516869: 'Watford', 1931735: '?', 1053279: 'Barashevo', 1085090: 'Panitskaya', 1600407: 'Doropeevichi', 1700248: 'Maximovka', 1950199: '?', 1946316: '?', 1929612: '?', 1951006: '?', 1935022: '?', 1514403: 'Oradovka', 1913743: 'Meißen', 1940406: '?', 1918520: '?', 1159389: 'Novokurovka', 1910197: '?', 1135089: 'Bolshaya Kosul', 1514050: 'Shevchenkovo', 1509629: 'Borki', 18560: "Beit She'an", 1703857: 'Campbell', 1159338: 'Ukhta (selo)', 1711046: 'Saarlouis', 4657324: 'Pedro Gonzalez', 21292: 'Delta', 20078: 'Klyuchevsky', 1042690: 'Kamenka', 1518343: 'Corsicana', 1129822: '?', 1023120: 'Klimovskoe', 10380: 'Danilovka', 1014207: 'Ostrovskaya', 1006772: 'Bratsk', 17071: 'Nagalyk', 1519186: 'Navabad', 1157725: 'Ishimsky', 1153295: 'Snegurovka', 1128771: 'Markovo', 1157124: 'Sagly', 1077950: 'Karginskaya', 1950968: '?', 1943227: '?', 2722527: 'Porto-Novo', 1933790: '?', 4155597: 'Kélo', 22442: '?', 16824: 'Nikolaevka', 1158626: 'Zabituy', 4124967: 'Kiffa', 1159166: 'Novy Mir', 1142950: 'Semenovo', 1124279: 'Naryn', 1052797: 'Mordovskoe Davydovo', 1701668: 'Taskala', 1938292: '?', 1123985: 'Tokur', 1924179: 'Nordheim', 1092142: 'Demino', 1949022: '?', 1928931: '?', 1077752: 'Poltava 2-Ya', 1097033: 'Rangazar', 1123122: 'Stary Togul', 1923747: '?', 1500345: 'Oktyabrskoe', 1931189: '?', 1950071: '?', 1130321: 'Bor', 1086394: 'Elkhotovo', 1113823: 'Nozhay-Yurt', 1055707: 'Pervomaysky', 1902521: '?', 1702502: 'Koktobe', 1509136: 'Troyandovoe / Kirovo', 1909173: '?', 1506863: 'Faschevka', 15595: 'Adyk', 1517441: 'Baltabay', 1031683: 'Yasnoe', 1004863: 'Askino', 1939714: '?', 1156390: 'Alexandrovskoe', 1109766: 'Pirogovo', 1916079: '?', 982: 'Bychok', 1127990: 'Ust-Kuda', 1708123: '?', 1509873: 'Bazilovschina', 1127969: 'Revyakina', 1113567: 'Timiryazevsky', 5231085: 'Châteaurenard', 1058139: 'Obukhovo', 1115628: 'Amalykovo', 22149: 'Cebu City', 1942266: '?', 1950525: '?', 13772: 'Baklanniki', 1519097: 'Gargždai', 1040734: 'Chekon', 1004561: 'Staritsa', 1000142: 'Trekhrechny', 1127617: 'Koblyakovo', 1043596: 'Oktyabrsky', 1931950: '?', 1500682: 'Agronomicheskoe', 1123707: 'Berezovka', 1953476: '?', 1908805: '?', 1518071: 'Landau in der Pfalz', 1128751: 'Sedanovo', 22287: 'Velikaya Belozerka', 1014162: 'Kotluban', 1700180: 'Barankol', 1965780: 'Ādaži', 1944615: '?', 2202785: 'Törökbálint', 15390: 'Makushino', 1700278: 'Damsa', 1051672: 'Paranga', 1512633: 'Korotich', 1042094: 'Veselovka', 1149168: 'Ugleuralsky', 1701070: 'Zhernovka', 1124030: 'Seryshevo-4', 1000924: 'Nikolsk', 1128677: 'Sheragul', 1511278: 'Staroe Selo / Chervonoe', 11942: 'Krasnye Tkachi', 1031937: 'Korobkin', 1014515: 'Machekha', 2055: 'Zarechnoe', 1153290: 'Rettikhovka', 1100391: 'Kozlovo', 19279: 'Ekaterinovka', 1503154: 'Alexandrovka', 1112384: 'Knyazhensky', 1930029: 'Nantucket', 1140162: 'Nizhnyaya Vereya', 1502642: 'Semenovka', 1151967: 'Chernushka', 20088: 'Middletown', 20552: 'Pervomaysk', 1506143: 'Ostrov', 1050540: 'Oktyabrsky', 1512914: 'Gornostaevka', 1952066: '?', 1949679: '?', 1507495: 'Cherlyany', 3845731: 'Sariwon', 8103: '?', 1031600: 'Primorye', 1514523: 'Lebedin', 1903708: 'Ribnitz-Damgarten', 1933822: '?', 1600021: 'Polonechka', 5266876: 'Riedlingen', 1924838: '?', 1153027: 'Ekaterinovka', 1506785: 'Pavlovka', 1026543: 'Shamkhal-Termen', 1059068: 'Vniipp ', 1902548: '?', 1705713: '?', 1700028: 'Volgodonovka', 1501838: 'Podgaytsy', 1506431: 'Peschany Brod', 1950850: '?', 1908045: '?', 1945149: '?', 1959521: '?', 1971494: '?', 6903: 'Ust-Bagaryak', 21096: 'Mikhaylovka', 1153574: 'Zarya', 1917466: '?', 1153690: 'Suntarsky', 1135210: 'Mezhovo', 1708869: 'Moskovey', 1503489: 'Bobritsa', 4177122: 'Ben Arous', 5328976: 'Friedland', 1107464: 'Inshinsky', 12576: 'Losinovka', 13327: 'Nagorsk', 1084126: 'Novoe Adelyakovo', 1951301: '?', 1501852: 'Torchin', 10655: 'Winston-Salem', 1138578: 'Lichadeevo', 1138614: 'Chuvarley Maydan', 1508918: 'Alexeevka', 1141059: 'Semino', 1141088: 'Khokhloma', 1915254: '?', 1509005: 'Novye Troyany', 1516394: 'Beshgyoz', 1512878: 'Alexeevka / Schorsovka', 5266431: 'Usingen', 1916889: '?', 1911660: '?', 1948809: '?', 1507768: 'Nikolaev', 1081444: 'Letniki', 4473929: 'Roudnice nad Labem', 1514283: 'Sharnopol', 1153055: 'Dukhovskoe', 4008894: 'New Plymouth', 1702788: 'Gorkoe', 1710620: 'Surfside Beach', 1009467: 'Podserednee', 1710245: '?', 14025: 'Kromy', 1098792: 'Esenovichi', 1149587: 'Odintsovo', 1908782: '?', 1514557: 'Zamostya', 1501378: 'Pechera', 1959444: '?', 1128248: 'Oktyabrsky', 1800272: 'Vulkaneshty', 1928144: '?', 1926328: 'Tŭrgovishte', 1947891: '?', 4280649: 'Winterswijk', 1928798: '?', 3255480: 'Slivnitsa', 1914275: '?', 1921027: '?', 1024464: 'Vyazniki', 1155450: 'Bilimbay', 1961516: '?', 1961841: '?', 1091955: 'Temizhbexky', 1509052: 'Radostnoe', 5257368: 'Zeithain', 1904402: '?', 1124467: 'Oymur', 7: '?', 17471: 'Sukhobuzimskoe', 3256287: 'Popovo', 1027743: 'Derevnya Novaya', 1153350: 'Tsentralnoe', 5094575: 'Santa Ana', 1135164: 'Novokhaysky', 1504807: 'Verbovo', 1512718: 'Kazatskoe', 1708888: '?', 1707350: '?', 1146973: 'Alabaytal', 1135130: 'Chaykovsky', 1923688: '?', 3959400: 'Sharïngol', 1112366: 'Uk', 1920479: 'Alta', 1968358: '?', 1974333: '?', 1507945: 'Novy Vitkov', 1138206: 'Barino', 1514058: 'Palmira (voznesenskoe)', 1501364: 'Zaozernoe', 1505788: 'Pologi', 1084060: 'Usinskoe', 1921689: 'Kottayam', 1013452: 'Voronok', 1505444: 'Svarichov', 1103720: 'Odintsovo', 1951276: '?', 1008096: 'Tashkinovo', 1948767: 'Unna', 1151561: 'Ferma', 1060274: 'Obraztsovo', 1072150: 'Klin (derevnya)', 1965817: '?', 1915085: '?', 1025241: 'Alexandrovka', 1008634: 'Bulgakovo', 1701937: 'Zharylgap Batyr (akchatau)', 1056145: 'Fruktovaya', 2100099: 'Kurgantepa (kurgantepinsky Rayon)', 3069: 'Uralsk', 1000934: 'Perevoz', 1713083: 'Greenville', 1916135: 'Saint-Étienne', 1122208: 'Kuzminka', 1934432: '?', 1085695: 'Serebryany Bor', 1105491: 'Bunyrevo', 1091489: 'Burlatskoe', 1112562: 'Selezyan', 1005612: 'Demsky', 1147042: 'Kiryushkino', 9577: '?', 1935323: '?', 1951885: '?', 1079437: 'Krasnaya Polyana', 1917583: '?', 1927594: '?', 1909516: 'San Lucía', 1050176: 'Kon-Kolodez', 1517251: 'Tyre', 1154072: 'Porechye', 1053792: 'Ashitkovo', 1913985: '?', 1082832: 'Zheludevo', 1092673: 'Glazok', 4492561: 'Radomsko', 1703401: '?', 1506938: 'Izvarino', 1059938: 'Levoshevo', 1503426: 'Stavische', 1511129: 'Boyaro-Lezhachi', 1083391: 'Alakaevka', 1082934: 'Alexeevka', 1036459: 'Krivtsy', 1021895: 'Krasny Bor (derevnya)', 5265806: 'Memmingen', 1085255: 'Lipovka', 1003023: 'Bobrovo', 1517007: '?', 1052079: 'Maloe Kuzmino', 1516634: 'Strachów', 1907961: '?', 1036879: 'Guryevka', 1940229: '?', 1157657: 'Ust-Lamenka', 1944635: '?', 1123141: 'Krutikha', 1705121: '?', 1507835: 'Bobrka', 1059467: 'Tatarinovo', 1158413: 'Korkino', 1071237: 'Bashovo', 1507238: 'Leninskoe', 1918714: 'Neringa', 1931701: 'Cambridge', 1948958: '?', 1000987: 'Fominsky', 1957471: '?', 1518662: 'Gavrilovka', 1951793: '?', 1951794: 'Khatai (baku)', 1058319: 'Ivanovo (derevnya)', 1504441: 'Kamenitsa', 1000040: 'Druzhba', 1917635: '?', 1701302: 'Verkhubinka', 1046379: 'Olshaniki', 1942407: '?', 20278: '?', 1954149: '?', 1139058: 'Bolshoe Pikino', 5266632: 'Herrenberg', 1949935: '?', 1079104: 'Bolshie Saly', 1500476: 'Partizanskoe', 1137263: 'Vargashi (selo)', 5759: 'Telmanovo', 1519141: 'Atherton', 1951050: '?', 1512648: 'Pokotilovka', 1091764: 'Privolnoe', 3188896: 'Ar Rifā`', 1951648: 'Alexandria', 1920911: '?', 1509097: 'Starye Troyany', 1037763: 'Upyrevka', 1057422: 'Drezna-2 (gorbachikhinsky S/o)', 1705120: 'Qualicum Beach', 1506701: 'Alexandrovka', 1929785: '?', 1929294: 'Córdoba', 1931550: '?', 1111091: 'Elovo', 4861: 'Gertsena', 1084570: 'Mayanga', 1951348: '?', 1035398: 'Storozhevaya', 1515542: 'Khalyavin', 1041540: 'Shkurinskaya', 1139283: 'Redkino (redkinsky S/s)', 1076995: 'Borisenki', 1933016: '?', 1501770: 'Povorsk', 1046815: 'Kotly (derevnya)', 20663: 'Bishops Stortford', 1918104: '?', 1925994: '?', 1134084: 'Baysa', 1079654: 'Topilin', 1515979: 'Rangsdorf', 1953145: '?', 16639: 'Dudelange', 5266379: 'Lüdenscheid', 1024434: 'Kashirskoe', 1093817: 'Belomestnaya Dvoynya', 1601660: 'Ozerschina', 1147228: 'Kherson', 1949198: '?', 1912497: 'Gorinchem', 4284130: 'Leerbroek', 3832: '?', 1713686: '?', 1939810: '?', 1948050: '?', 5266312: 'Rheda-Wiedenbrück', 1953315: '?', 1909231: '?', 1938106: 'Altenburg', 1501218: 'Pogrebische Pervoe', 1509412: 'Belolesye', 1098833: 'Krasnomaysky ', 1080469: 'Sidorovo', 1080481: 'Tokarevo', 1915753: '?', 1947644: '?', 1803582: 'Huntington', 1047799: 'Rel', 1968366: 'Ponce', 15417: 'Chastsy', 5675: 'Smolino', 21299: '?', 1951658: '?', 1916795: '?', 1060409: '19 Km', 1600364: 'Kozhan-Gorodok', 1948373: '?', 1933427: '?', 1091825: 'Novokumsky', 1507604: 'Khodorov', 21556: 'Bobrovnik', 1708749: 'Shofrynkany', 3641495: '?', 3797570: 'Luoyang', 1505983: 'Shpitki', 1512729: 'Novoraysk', 1078571: 'Gapkin', 1030425: 'Sernovodsk', 1904318: '?', 1518026: 'Kalarash', 1517153: '?', 1518180: 'Rypin', 1938552: '?', 1007202: 'Oktyabrsky', 1902208: '?', 1925479: '?', 1913614: 'Garbsen', 1708548: 'Ganakhleba', 1709815: '?', 1125541: 'Zolotkovo', 1927663: '?', 1951716: '?', 1951718: '?', 5119680: 'Kailua', 1122879: 'Novorossiysky', 4922136: 'Cape Coral', 8788: 'Volodarsky', 1032153: 'Muromtsevo', 1908547: 'Holmestrand', 1951727: '?', 1518040: '?', 1910753: '?', 11512: 'Suslonger', 1085260: 'Novaya Zemlya', 11070: 'Emmen', 4280298: 'Zwolle', 1711526: 'Fitchburg', 1903451: 'Mankato', 6910: 'Karamken', 4960293: 'Boonville', 15063: 'Myshanka', 5125946: 'Inuvik', 1144454: 'Sokur', 1708963: 'Warrington', 1114332: 'Bolshie Bikshikhi', 1129751: '?', 1712178: 'Frenštát pod Radhoštěm', 1159620: 'Tashtyp', 1802060: 'Gagarin Nomli', 1925805: '?', 1152833: 'Izmaylikha', 1158759: 'Novaya Ida', 1012444: 'Komarichi', 1932164: '?', 1949976: '?', 1803667: '?', 1906099: '?', 14399: 'Axenovo', 1041581: 'Sladky', 19842: 'Gankovo', 1084256: 'Ulyanovsky', 1096304: 'Nizhny Takanysh', 13537: 'Tyret 1-Ya', 1517381: 'Dokuchaevka', 1951008: '?', 1035509: 'Besleney', 1931660: '?', 1091601: 'Novotroitskaya', 1112620: 'Ozerny', 1947899: '?', 1950161: '?', 1004353: 'Chagan', 1936339: '?', 1909982: '?', 1919478: '?', 1912580: 'Tsikhisdzhvari', 1711060: '?', 9210: 'West Yellowstone', 1143062: 'Katunki', 1702533: 'Lozovoe', 1519284: '?', 1502365: 'Pokrovskoe', 1123002: 'Topolnoe', 1145004: 'Dorogino', 1514480: 'Vesely Khutor', 1008132: 'Pervomaysk', 1095854: 'Bolshie Kaybitsy', 1701156: 'Chapaevo', 1700721: 'Chapaev', 1122454: 'Myshkino', 14362: 'Safakulevo', 1123975: 'Zlatoustovsk', 1010502: 'Sharapovka', 1951708: '?', 1122677: 'Pankrushikha', 19210: 'Addison', 1026163: 'Madzhalis', 5111691: 'Deadwood', 1159176: 'Snezhny', 1158929: 'Litovko', 1004998: 'Meseli', 1505987: 'Byshev', 1911582: '?', 3282998: 'Rudna Mała', 1956660: '?', 1929149: '?', 1510469: 'Rechitsa', 1921954: '?', 1936124: '?', 2201590: '?', 1953230: '?', 1703023: 'Abay', 1041738: 'Ploskaya', 1518709: '?', 1084144: 'Tokmakla', 1091317: 'Kapyrevschina', 1031230: 'Shepetovka', 1951863: '?', 1930588: '?', 1500184: 'Tokarevo', 1951869: '?', 1513945: 'Olshana', 1951721: '?', 1067482: 'Lipovka', 1943691: '?', 1942831: '?', 1971554: 'Wroxham', 4309583: 'Knokke', 14910: '?', 1146801: 'Rechnoy', 1127633: 'Pokosnoe', 1931331: '?', 1906029: 'Stade', 1145354: 'Barrikada', 21169: 'Gozha', 1951909: '?', 1511114: 'Malaya Pavlovka', 1501715: 'Zhidichin', 1139441: 'Oryol', 1008124: 'Nimislyarovo', 1055800: 'Gazoprovod', 1010736: 'Kopanki', 1503862: 'Belokorovichi', 1512552: 'Rokitnoe', 1095528: 'Bolshaya Axa', 1135988: 'Kemchug', 1024435: 'Kolodezny', 17734: 'Staroe Drozhzhanoe', 1905253: '?', 1035166: 'Kremenets', 1702108: 'Chelgashi', 1122749: 'Solovikha', 16430: '?', 1508905: 'Raukhovka', 1706733: 'Reus', 1048397: 'Samara (derevnya)', 1505921: 'Burty', 1041668: 'Besskorbnaya', 1931779: 'Arambol', 2027: 'Nikolskoe', 1094250: 'Sarsak-Omga', 1512933: 'Novodmitrovka Vtoraya', 1153388: 'Yllymakh', 1902811: 'Cumming', 1041500: 'Kubanets', 1043350: 'Kasinovsky', 1157689: 'Padun', 1950695: '?', 1916660: '?', 1516151: 'Korten', 1008884: 'Goncharovka', 1509841: 'Zasulye', 1114102: 'Almanchikovo', 1149478: 'Voskresensk', 1002474: 'Martynovskaya', 1714115: '?', 1947996: '?', 1127757: 'Kharagun', 1008034: 'Meneuztamak', 1711005: 'Owensboro', 5264747: 'Sipplingen', 1154135: 'Zyryanovsky', 1001585: 'Zalupya', 1159029: 'Suluk', 1925276: '?', 4474209: 'Rakvice', 1000010: 'Goncharka', 1129823: 'Mundybash', 1702809: 'Roschinskoe', 1937341: 'Shamaldy-Say', 1937233: '?', 1702785: 'Letovochnoe', 1063217: 'Belebelka', 1084213: 'Beregovoy', 1952000: '?', 1509039: 'Belka', 1504993: 'Krichka', 1019933: 'Sazonovo', 1518717: 'Muskegon', 1503706: 'Granitnoe', 1123977: 'Isa', 1128964: 'Baklashi', 1008528: 'Bakhchisaray', 1901696: '?', 1159923: 'Lyamina', 1095241: 'Koshki-Tenyakovo', 1500224: 'Poltavka', 1909543: '?', 1516737: 'Agdash', 1116630: 'Shopsha', 1707935: 'Moose', 1509084: 'Vasilyevka', 1916982: '?', 1085250: 'Kolos', 1085248: 'Karaman', 1113652: 'Samashki', 1030457: 'Malka', 1504616: 'Dobropolye', 1078835: 'Novonikolaevka', 1008277: 'Rodionovka', 5042666: 'Saugatuck', 1946283: '?', 21666: 'Novaya Borovaya', 1091506: 'Shishkino', 1937144: '?', 1000760: 'Selo', 1155190: 'Neyvo-Rudyanka', 1513379: 'Chankov', 1599: 'Shiroky', 5058282: 'Elizaville', 1929239: 'Fairless Hills', 1046648: 'Pribytkovo', 1500107: 'Zavet-Leninsky', 1134071: 'Uray', 1504965: 'Okhrimovka', 1602370: 'Kurenets', 1036766: 'Koydin', 1135444: 'Eniseysk-15', 1932160: 'Burgkirchen an der Alz', 1130304: 'Yaransk', 1930112: '?', 1515578: 'Vilino', 1934342: '?', 1939990: '?', 1933334: '?', 1503173: 'Raygorodok', 1085702: 'Alexeevsky', 1009457: 'Mukhouderovka', 1084871: 'Galakhovo', 1951490: '?', 1950319: '?', 16965: 'Chebsara', 1914847: '?', 1150715: 'Yugovskoe', 1157789: 'Karasul', 1506541: 'Sasovka', 1508358: 'Konstantinovka', 1940538: '?', 1513852: 'Chemerovtsy', 1932446: '?', 1960552: '?', 1065471: 'Alexandrov', 1145668: 'Maryanovka', 19178: 'Grinnell', 4697495: 'Grenville', 1049318: 'Degtevoe', 1501014: 'Shevchenko', 1122286: 'Myski', 1507766: 'Lipovka', 17430: 'Pavlovsky', 1025973: 'Sogratl', 1517388: 'Saalfelden am Steinernen Meer', 1053325: 'Drakino', 1505405: 'Rogatin', 1052317: 'Dubenki', 1514267: 'Lukashovka', 1007673: 'Abdulovo', 1147749: 'Kuzminovka', 1939801: '?', 1040880: 'Pshekhskaya', 4436355: 'Hendaye-Plage', 5032834: 'Miami', 1078426: 'Volchensky', 2208425: '?', 1508996: 'Vladichen', 1951361: '?', 12531: 'Stodolische', 1121528: 'Nurinsk', 1138437: 'Uptar', 1601113: 'Dubrovka', 17822: 'Rzhevskoe', 1932621: 'Wirges', 4389578: '?', 1704716: 'Montabaur', 1041155: 'Novonikolaevskaya', 1083214: 'Chernovsky', 1506381: 'Khaschovatoe', 1972816: '?', 1505775: 'Kovalovka', 18587: 'Loymola', 1091531: 'Starodubskoe', 1952079: '?', 1925189: '?', 5266221: 'Eschweiler', 1508745: 'Zoryanoe / Zhovtnevoe', 1095855: 'Bolshoe Podberezye', 1156631: 'Chazhemto', 1803356: 'Õru', 1700837: 'Koktal', 2206055: 'Sutton Coldfield', 1515065: 'Monastyrische', 1131107: 'Azikovo', 1518226: 'Kokemäki', 1082990: 'Olgino', 1971769: 'Ringkøbing', 1911425: 'Pervomayskoe', 1516900: 'Abbotsford', 5738: 'Zarya', 1709317: 'Sukkur', 17204: 'Novoalexandrovka', 1154899: 'Atymya', 1926304: '?', 1943365: '?', 1504595: 'Matveevka', 5029619: 'Hawthorn Woods', 21769: 'Buffalo Grove', 20263: 'Fair Lawn', 1963560: 'Geychay', 13578: 'Bystrogorsky', 1001019: 'Gridinskaya', 5229144: 'Saint-Raphaël', 12663: 'Kudinovo', 1064031: 'Yubileyny', 1132361: 'Nema', 1902288: '?', 1110347: 'Buranovo', 1084743: 'Tersa', 1519135: '?', 1055902: 'Tupikovo', 1003188: 'Talagi', 19660: 'Vstrechny', 1033119: 'Sosnovy Bor (poselok)', 1052316: '?', 1052086: 'Nizovka', 1705899: 'Yuratishki', 1906236: '?', 1041831: 'Novoleushkovskaya', 1159030: 'Tyrma', 1061528: 'Dolgy Bor', 1062530: 'Krasnye Stanki', 1148472: 'Tashla', 1951999: '?', 1020328: 'Saraevo', 1908582: 'Trakai', 1901628: '?', 1155056: 'Kislovskoe', 1965391: 'Sömmerda', 1910906: 'Famagusta', 1082731: 'Lesnoe Konobeevo', 1715473: '?', 1124107: 'Anosovsky', 1155258: 'Sarana', 1040706: 'Dzhiginka', 21625: 'Almoradí', 1091750: 'Dmitrievskoe', 1057318: 'Boyarkino', 1135942: 'Kezhma', 1706197: '?', 1952306: '?', 1967594: 'Pabradė', 1925846: '?', 16284: 'Novosheshminsk', 4697504: 'Gouyave', 1108228: 'Severny', 1084698: 'Verkhnyaya Chernavka', 1023828: 'Vasilyevka', 5256190: 'Cham', 5266706: 'Bad Mergentheim', 1507265: 'Krymskoe', 5267821: 'Dietzenbach', 1509272: 'Dobroalexandrovka', 1969882: '?', 1948302: '?', 1914497: '?', 1953821: '?', 1091545: 'Krasnokumskoe', 1500492: 'Trudovoe', 1915012: '?', 1516685: '?', 1902360: 'Longview', 1059334: 'Zhilevo', 1938901: '?', 1903262: 'Cuenca', 1005838: 'Troitsk', 1006321: 'Ivangorod (derevnya)', 1508504: 'Pribuzhany', 1041719: 'Gorky', 1042339: 'Bratsky', 1917738: '?', 1800387: 'Dorotskoe', 1943402: '?', 1715267: 'Bexhill', 1709655: 'León', 4343: 'Berezanskaya', 1950607: 'Mokva', 1925789: '?', 1112854: 'Taukaevo', 1944068: '?', 1503407: 'Vodoty', 17235: 'Kaalamo', 1502743: 'Artemovskoe', 22677: 'Kuchurgan', 1710886: '?', 1602381: 'Podberezye', 4496480: 'Mikołów', 1936765: 'Asbury', 1932540: '?', 1084165: 'Deniskino', 1514879: 'Nedoboevtsy', 1059758: 'Kryukovo', 1952446: '?', 1111642: 'Nikolaevka', 1601899: 'Indura', 1161108: 'Telviska', 1030918: 'Prokhorovka', 1005360: 'Bazhenovo', 22039: 'Karakul (karakulsky Rayon)', 1149161: 'Shumikhinsky', 1600508: 'Sheni', 1508747: 'Ivanovka', 1935070: 'Dimi', 1127825: 'Chelyaba', 1009775: 'Dolgoe', 1952452: '?', 1514786: 'Putila', 1700140: 'Krasivoe', 1936381: '?', 17142: 'Novorozhdestvenskaya', 1917536: '?', 1108947: 'Bogoslovskoe', 1109039: 'Pervomaysky', 1108984: 'Zakharino', 11481: 'Kadnikovsky', 1906733: '?', 1514043: 'Stebnoe', 1500286: 'Ostaninnoe', 1918553: '?', 5259468: 'Treuen', 1004576: 'Askarovo', 1079067: 'Kostino-Bystryansky', 1948770: '?', 1950376: 'Paramaribo', 1502418: 'Bulakhovka', 1518521: '?', 1600124: 'Khotynichi', 1502944: 'Alexandro-Kalinovo', 1153196: 'Kirovka', 2207137: '?', 19363: 'Novopokrovka', 1803501: '?', 1954390: '?', 16712: 'Rosario', 1952517: '?', 1947560: '?', 1014363: 'Krasnoyarsky', 1517641: 'Lakewood', 1803648: '?', 1944773: '?', 1150020: 'Overyata', 1938736: '?', 1128707: 'Mishelevka', 1918164: '?', 1137011: 'Sushinovka', 1118692: 'Berendeevo', 1025738: 'Usisha', 1937062: 'Andorra la Vella', 1949364: '?', 1702357: 'Beyneu', 1952681: '?', 1113064: 'Nagaybaxky', 1708122: 'Orangevale', 1113610: 'Belovka', 1154541: 'Brusnyatskoe', 1975316: '?', 1903139: '?', 1951757: 'Arvada', 1150593: 'Lensk', 1949954: '?', 1160549: 'Verkh-Usugli', 19383: 'Khonuu', 1022937: 'Chagoda (rp)', 1952588: '?', 1122560: 'Krestyanka', 1123455: 'Korobeynikovo', 1123436: 'Andreevka', 1946752: '?', 1715592: '?', 1702865: 'Semipolka', 1510812: 'Nikolaevka / Zhovtnevoe', 1711515: 'Federal Way', 1940377: '?', 1920464: '?', 20001: 'Kudara-Somon', 1078038: 'Krasny Kut', 1157111: 'Sukpak', 1926215: '?', 1911155: '?', 1023105: 'Irdomatka', 4923552: "Land O' Lakes", 1046080: 'Voeykovo', 1802183: '?', 1503537: 'Vysokaya Pech', 1122339: 'Losikha', 7986: 'Kozhva', 5045883: 'Key West', 5866: 'Terskol', 1512777: 'Zaporozhye', 1502123: 'Granitnoe', 1503221: 'Granitnoe', 1041223: 'Novoberezansky', 1083997: 'Uzyukovo', 1158305: 'Sorokino', 1509503: 'Ustivitsa', 1146100: 'Pokrovka', 1050736: 'Shelanger', 1124666: 'Ilinka', 1113855: 'Gekhi', 1153362: 'Yablonovka', 1949968: '?', 1934994: '?', 14548: 'Staroderevyankovskaya', 1704177: '?', 1095439: 'Konstantinovka', 19748: 'Peremyshlyany', 1510339: 'Tuchin', 1146890: 'Novospasskoe', 1094896: 'Mamsya', 1094948: 'Tashkichu', 5346900: 'Ämari', 21770: 'Nesebŭr', 1929750: '?', 1032382: 'Krivskoe', 1139067: 'Neklyudovo', 1145379: 'Medvezhye', 1095088: 'Kugunur', 1090634: 'Zamytskoe', 1506801: 'Lozovataya', 1106346: 'Rudnev', 2272: 'Ous', 1702111: 'Michurinskoe', 1147137: 'Krasnogvardeets', 5264982: 'Ampfing (Oberbayern)', 1008549: 'Kaznakovka', 1937794: '?', 1911519: '?', 1146270: 'Nizhneirtyshskoe', 1128058: 'Biryulka', 1510429: 'Orvyanitsa', 1517122: 'Robinson', 1936074: '?', 1508515: 'Yastrebinovo', 1701553: 'Axu', 1507263: 'Zimogorye', 1514335: 'Moshurov', 1148334: 'Fedorovka', 1952720: 'Chkhorotsku', 1945034: '?', 1500960: 'Lipovets', 1512563: 'Bereka', 1507231: 'Daryevka', 1908035: '?', 1123161: 'Funtiki', 1067441: 'Somovo', 1053862: 'Faustovo', 1076420: 'Issa', 1951900: '?', 1093421: 'Rudovka', 1916651: 'Klosterneuburg', 1058253: 'Belyanaya Gora', 1953588: '?', 1041445: 'Mikhaylovskaya', 5124: 'Novye Burasy', 1083406: 'Kinelsky', 1112830: 'Oktyabrsky', 19820: 'Oktyabrsky', 1057680: 'Erino', 1134188: 'Shevnino', 1505736: 'Kalinovka', 1111756: 'Mordovsky Shmalak', 1024792: 'Voloshino', 1908665: '?', 13131: 'Khara-Shibir', 1602900: 'Novye Zelenki', 5115807: 'Twin Peaks', 4687656: 'San Galillo', 1518034: 'Kyzyl-Adyr', 1078430: 'Gusev', 1506189: 'Vinarovka', 1086102: 'Perevesinka', 1710300: '?', 1509096: 'Priozernoe', 1917596: 'At-Bashy', 1943726: '?', 1086263: 'Dagom', 1515187: 'Gorbovo', 1709604: 'Linkaičiai', 1708628: 'Świdnica', 1509396: 'Nikolaevka', 1035414: 'Dzhingirik', 1834: '?', 1921550: '?', 1700551: 'Dostyk', 1702491: 'Beskaragay', 1919131: '?', 1036674: 'Krasnobor', 1952722: '?', 1024298: 'Prigorodny', 1602586: 'Privolny', 4530102: 'Stryn', 1050776: 'Vizimyary', 1507913: 'Semenovka', 3558680: 'Rangamati', 1500128: 'Novokrymskoe', 11645: 'Slantsevy Rudnik', 1036998: 'Krasnozatonsky', 1956104: '?', 1065843: 'Pokrovka Vtoraya', 1024217: 'Tenisty', 1509007: 'Orekhovka', 1005283: 'Zilyazekulevo', 1803411: '?', 1952786: '?', 1004508: 'Nachalovo', 1908902: '?', 8808: 'Molodoy Tud', 1707978: 'Larvik', 1601672: 'Vedrich', 1512965: 'Kalinovka', 1509082: 'Malodolinskoe', 1051015: 'Mari-Bilyamor', 1934331: 'Avon', 1951183: 'Agudzera', 1140772: 'Nizhegorodets', 1518141: 'Ogden', 1510634: 'Ozhenin', 1508759: 'Podgorodnaya', 1134846: 'Ustyansk', 1705760: 'Terneuzen', 10993: 'Novomyshastovskaya', 1803375: 'Haanja', 1947171: '?', 3881: 'Peredovaya', 1034712: 'Shlippovo', 1054040: 'Kulikovo', 1904072: '?', 4910899: 'Melborne', 3789: 'Neftepechorsk', 5261340: 'Marschacht', 1952837: '?', 1107490: 'Leninsky', 1083635: 'Volzhsky', 17390: 'Verkh-Amonash', 1904425: 'Sherwood Park', 1508011: 'Ralovka', 5266257: 'Wermelskirchen', 1710599: 'Cromwell', 1908615: 'Monsey', 1705711: 'Novaya Guta', 1104408: 'Vysokoe', 15725: 'Donets', 1154896: 'Kurmanka', 1951590: '?', 1121867: 'Troitsky', 1123192: 'Beloe', 1064945: 'Lubyanki', 1518112: 'Urgut', 1035190: 'Podbuzhye', 1129608: 'Chistogorsky', 5266936: 'Freyung', 5259986: 'Regen', 1950814: '?', 1930534: 'Viļāni', 1115693: 'Bolshoe Selo', 1022035: 'Khrenovo', 1002888: 'Monastyr', 1058124: 'Morozovo', 1952343: '?', 1952895: '?', 22289: 'Sebino', 1906309: 'Chaozhou', 1032402: 'Pekino', 1144478: 'Verkh-Tula', 1701048: 'Bolshaya Vladimirovka', 1083625: 'Bolshaya Kamenka', 1144756: 'Gorny', 1146790: 'Krasnoyarsk', 2722617: 'Eşfahān', 1135810: 'Antsir', 1715263: 'Maramonovka', 1920491: '?', 1121875: 'Aya', 4343056: 'Oppenheim', 1705948: '?', 1502132: 'Niva Trudovaya', 1100242: 'Verkhnyaya Troitsa', 1501970: 'Blagodatnoe / Zhovtnevoe', 5166694: 'Sant Cugat del Vallès', 1501830: 'Lipiny', 1912822: '?', 1500131: 'Novostepnoe', 1504539: 'Orlyanskoe', 1507242: 'Novoborovitsy', 1515348: 'Okhinki', 1105128: 'Brusovo', 5261805: 'Mettingen', 1010696: 'Proletarsky', 1712854: '?', 15948: 'Turki', 20811: 'Sliven', 1952971: '?', 21195: 'Glenview', 20872: '?', 1103836: 'Eremeevka', 1103846: 'Kozlovo', 1504226: 'Zarechye', 5266387: 'Olpe', 1919461: '?', 1144990: 'Scheglovo', 1146637: 'Elizavetinka', 1933303: '?', 1019997: 'Ferapontovo', 4230982: 'Slough', 1501128: 'Ruban', 4094596: 'Ijanikin', 5134: 'Sardarapat (oktember)', 4321964: 'Warnsdorf', 1505793: 'Salivonki', 22678: 'Turkestan', 1158368: 'Mugen', 3038458: 'Taizz', 1158005: 'Sitnikovo', 1951678: '?', 1071401: 'Podberezye', 1123179: 'Pervokamenka', 1508549: 'Pribuzhye', 1512529: 'Yakovlevka', 1949847: '?', 1148150: 'Gostepriimny', 1126905: 'Beg', 1500376: 'Senokosnoe', 1053310: 'Tengushevo', 1147664: 'Zarechny', 1003289: 'Edma', 11786: 'Izdeshkovo', 5259562: 'Brandis', 1509578: 'Svyatilovka', 1708510: 'Westfield', 7574: 'Khryaschevka', 1057021: 'Stepanovo', 1036743: 'Sindor (derevnya)', 1063015: 'Bogoslovo', 1501403: 'Voytovtsy / Zhdanovka', 1134424: 'Velikoretskoe', 1602687: 'Kartsevichi', 1515880: '?', 1002773: 'Bobrovo', 5261772: 'Marienheide', 1005093: 'Bashkortostan', 1949892: 'Barßel', 1715327: '?', 1914570: '?', 1704745: '?', 1034732: 'Voznesenye', 1010712: 'Sukhoy Log', 1056291: 'Kolychevo', 1935175: '?', 1922545: 'Camara', 1907123: 'Zeist', 1946174: '?', 1700232: 'Chaglinka', 1514427: 'Irdyn', 3090787: 'Dayr az Zawr', 1949735: '?', 1945102: '?', 1007103: 'Kuterem (derevnya)', 1905281: '?', 1947472: '?', 1950822: '?', 1091573: 'Kugulta', 1505696: 'Senkovka', 1904372: '?', 1087209: 'Sergo-Ivanovskoe', 1509063: 'Kamenka', 1083427: 'Oktyabrsky', 1953185: '?', 1944921: '?', 1516288: 'Shubarkuduk', 1157228: 'Boldyrevo', 1510360: 'Verba', 1913347: 'Pyandzh', 1119599: 'Petrovskoe', 4654268: 'Botafogo', 1802379: '?', 1923052: '?', 1080578: 'Davydovo', 1910972: '?', 1048999: 'Plavitsa', 1505649: 'Shkarovka', 3838177: 'Katano', 1706950: '?', 1509141: 'Krasnoselka', 1506056: 'Grigorovka', 1505685: 'Ivankov', 1006443: 'Yaroslavka', 1513265: 'Lesovody', 1508814: 'Dolinskoe', 4062693: 'Kpandu', 1710574: 'Warminster', 5266718: 'Heidenheim an der Brenz', 22684: 'Safyany', 1517306: 'Petropavlovka', 5259717: 'Bad Blankenburg', 4318331: 'Wolfenbüttel', 1041724: 'Ilinskaya', 1041745: 'Yuzhny', 1506622: 'Korobchino', 1915711: '?', 1507823: 'Tvirzha', 1934508: '?', 1963954: '?', 2722477: 'Tarsus', 1143192: 'Chistoe', 1903243: '?', 2300551: 'Stepnoe', 1927415: '?', 1713625: '?', 7610: 'Bangor', 1973897: '?', 1518142: '?', 1708594: 'Bloomington', 1933953: '?', 1136281: 'Partizansk', 4593: '?', 22580: '?', 3791992: 'Shijiazhuang', 1153222: 'Zarubino', 1950197: '?', 1093770: 'Lyubov', 1500700: 'Lavrovka', 1141498: 'Drug Krestyanina', 12817: 'Keperveem', 3788428: 'Wuhu', 1706088: 'Chico', 1112650: 'Vozdvizhenka', 1943990: '?', 1702480: 'Peschanoe', 1700299: 'Chernoyarka', 1039490: 'Pavino', 1154386: 'Belokamenny', 1701257: 'Vasilyevka', 19466: 'Nekrasovka', 1803527: 'Big Bear Lake', 1153630: 'Malykay', 1041924: 'Svobodny', 11420: 'Malodory', 20026: 'Maykain', 1906537: 'Biarritz', 1091503: 'Sotnikovskoe', 1129326: 'Taradanovo', 1160081: 'Solovyevsk', 1040957: 'Beregovoe', 1040967: 'Pshada', 1512557: 'Staroverovka', 1093225: 'Pervomaysky', 1602665: 'Starye Gaby', 1128532: 'Kvitok', 1501154: 'Oratov', 1002795: 'Glazovo', 1927950: 'Deer Park', 1000306: 'Dolmatovo', 1907069: '?', 4235149: 'Limavady', 1155467: 'Progress', 1916667: 'Turakurgan', 1114444: 'Kinery', 1938475: 'Lahore', 1146761: 'Starye Shalty', 1025825: 'Botlikh', 1135892: 'Kachulka', 1952271: '?', 2203469: 'Venice', 1953235: '?', 1114354: 'Karakly', 1160879: 'Mandrikovo', 1038462: 'Uzhuga', 1156164: 'Lugovskoy', 1028023: 'Pochinki', 1161140: 'Koltsevoe', 1152750: 'Lazo', 4924341: 'Pinellas Park', 1112532: 'Belonosovo', 1901329: '?', 1934445: '?', 1952466: '?', 19123: '?', 1073015: 'Norkino', 1060344: 'Rikolatva', 1942749: '?', 1085193: 'Lysye Gory', 5470224: 'Maysky', 1916778: '?', 1085446: 'Perelyub', 1008017: 'Kacheganovo', 1511031: 'Kurgan', 1917198: '?', 1148063: 'Ukrainka', 1005028: 'Semenkino', 5266833: 'Tuttlingen', 1514101: 'Kosari', 1136689: 'Orye', 1930139: '?', 1946423: '?', 1513639: 'Manyatin', 1975396: 'Terdzhola', 1064911: 'Dmitrovsky', 1085341: 'Dmitrievka', 1937023: '?', 1046611: 'Nikolskoe (selo)', 1943873: '?', 1000080: 'Sadovoe', 1501894: 'Golovno', 1703294: 'Kendal', 1931899: '?', 4956145: 'Miami Beach', 1157166: 'Sosnovka', 1953319: '?', 1937469: '?', 1500688: 'Gavrilovka', 1911438: '?', 17389: 'Gorin', 1161664: '?', 1902981: '?', 1143169: 'Stupino', 1011275: 'Netinka', 1517583: 'Krasnaya Belarus', 1920432: '?', 1078033: 'Vesely', 1130032: 'Verkh-Chebula ', 1712765: 'Azatamut', 19918: 'Bakchar', 1149574: 'Nerdva', 1113409: 'Chernorechye', 1149151: 'Sarany', 1953373: '?', 1145273: 'Gorkovskoe', 1508491: 'Alexandrovka', 1955245: '?', 1081309: 'Pitelino', 1081406: 'Tyrnovo', 1126575: 'Sanino', 1046164: 'Nenimyaki', 22449: 'Kamenskoe', 1928676: 'Komsomol', 1060386: 'Teriberka', 1921866: '?', 3748922: 'Los Baños', 1149361: 'Novaya Kamenka', 1124237: 'Okino-Klyuchi', 1922017: 'Priekule', 18780: 'Urukh', 1144816: 'Repyevo', 1020392: 'Yugsky', 1513053: 'Fedorovka', 1708785: 'Geranboy', 1902821: '?', 1937065: 'همه جای ای&#1585', 4710620: 'Namanamuk', 17676: 'Lugavskoe', 1083602: 'Krasnoarmeyskoe', 12874: 'Zhirnov', 1702064: 'Kamysty', 5046620: 'Mora', 1935599: '?', 1135160: 'Nevonka', 1078118: 'Korolev (khutor)', 1132176: 'Ralniki', 1502200: 'Balovka', 1020510: 'Poplevino', 1602857: 'Zaluzhye', 1949038: '?', 1506046: 'Khodorov', 1505961: 'Gorenichi', 1113568: 'Travniki', 1930412: '?', 1160064: 'Undino-Poselye', 1902225: '?', 1800057: 'Bardar', 1502811: 'Andreevka', 22647: 'Ilinka', 1952289: '?', 1701165: 'Novo-Khayruzovka', 5267828: 'Limburg an der Lahn', 1058673: 'Novy', 1110239: 'Kiasovo', 1601888: 'Ozery', 1510265: 'Voronki', 1713522: '?', 3336309: 'Francistown', 1137013: 'Tolstikhino', 1502804: 'Staromlinovka', 3825607: 'Pohang', 1921993: '?', 1950094: '?', 1942924: '?', 1159205: 'Naykhin', 1904743: '?', 21466: 'Chiatura', 1705353: 'Kyurdamir', 5192: '?', 5463777: 'Zabolotye', 1137882: 'Travnoe', 1123332: 'Korotoyak', 1601717: 'Zhuravichi', 1516216: 'Kołobrzeg', 1512346: 'Pisarevka', 1956272: '?', 1114757: 'Sotnikovo', 1148248: 'Divnopolye', 1005798: 'Kashkalashi', 18043: 'Semiozerye', 1504530: 'Verkhnyaya Krinitsa', 1501789: 'Zaturtsy', 8568: 'Troitskoe', 1149544: 'Kotelniki', 1503056: 'Melekino', 1515984: 'Mirny', 1514206: 'Vinograd', 1512144: 'Vysokopolye', 1905783: 'Anjalankoski', 1952007: '?', 1000111: 'Komintern', 5092580: 'Los Altos', 1919949: 'Seaside', 1510273: 'Kanonichi', 1910378: '?', 1708328: '?', 18387: 'Kriulyany', 4190625: 'San Gavino Monreale', 1802161: '?', 1091723: 'Novokubansky', 1706107: '?', 2001455: '?', 1074793: 'Dubrovno', 1501139: 'Yurkovtsy', 1507195: 'Yasenovsky', 1135062: '?', 1943385: '?', 7064: '?', 1934364: '?', 1515116: 'Mostische / Petrovskoe', 1602688: 'Seylovichi', 1086224: 'Pridorozhny', 1509223: 'Gvozdavka Vtoraya', 17845: 'Sergievsky', 13970: 'Nizhny Ingash', 1130243: 'Kazan (derevnya)', 1500819: 'Kalnik', 1078008: 'Parizhsky', 1148243: 'Boevaya Gora', 1009705: 'Nasonovo', 1914843: '?', 1042367: 'Tenginskaya', 1085804: 'Slantsy (selo)', 1509282: 'Petrodolinskoe', 1912737: '?', 1091463: 'Vozdvizhenskoe', 1026794: 'Albania', 1020801: 'Bobrovskoe', 1931000: 'Kenitra', 1055998: 'Osheykino', 5266353: 'Salzkotten', 1128067: 'Butakovo', 1500101: 'Volnoe', 1018338: 'Sazonovo', 1923304: '?', 6344: 'Starye Tuymazy', 5261872: 'Ginsheim-Gustavsburg', 1512516: 'Panyutino', 1701150: 'Solovyevo', 1038479: 'Apraxino', 4185363: '?', 1712074: 'Fleetwood', 1701499: 'Tole Bi', 1112016: 'Barataevka', 1034314: 'Gorki', 2001461: '?', 1952504: '?', 1966937: '?', 2001861: 'Xanthi', 1945597: '?', 8972: 'Costa Mesa', 1925801: '?', 1923991: '?', 1935694: '?', 1160750: 'Pervomaysky', 1902938: '?', 1091866: 'Nagutskoe', 1704861: 'Almelo', 18655: 'Davydovka', 4505282: 'Ciasna', 4490157: 'Stare Olesno', 4497460: 'Lubliniec', 1113866: 'Avtury', 1517066: 'Sagaredzho', 1949140: '?', 1104674: 'Selikhovo', 1083854: 'Ekaterinovka', 1505574: 'Palyanitsa', 1506611: 'Torgovitsa', 1091801: 'Rostovanovskoe', 1715416: '?', 1903045: '?', 5259649: 'Schönebeck (Elbe)', 1700258: 'Priozernoe', 1517240: 'Priozernoe', 1500117: 'Krymka', 1953647: '?', 1005701: 'Ponomarevka', 1026331: 'Sumbatl', 1090916: 'Kobylkino', 1953374: '?', 1160372: 'Mikhaylovka', 1942753: '?', 1057237: 'Sidorovskoe', 1508351: 'Arbuzinka', 21633: '?', 1918236: '?', 1601608: 'Ugly', 1933793: '?', 1953610: '?', 1514107: 'Mikhaylovka', 1000093: 'Khanskaya', 1146622: 'Ust-Ishim', 1094912: 'Novy Kiner', 1094945: 'Syurda', 1049008: 'Pushkino', 1091904: 'Kayasula', 1500055: 'Tenistoe', 1935476: '?', 1950922: '?', 1909193: 'Chánia', 5267405: 'Wiesentheid', 1700168: 'Zhana-Kiyma', 15026: 'Mayagüez', 1704135: 'Meadville', 1708247: 'Norwood', 1707424: 'Needham', 1943376: '?', 1602378: 'Vishnevo', 1508833: 'Voznesenka Pervaya', 1506663: 'Rovnoe', 1514654: 'Pogorelovka', 1013936: 'Vysokoe', 1947979: '?', 1048637: 'Naberezhnoe', 1023865: 'Ramonye', 2206175: '?', 1956680: '?', 1500798: 'Stanislavchik', 1004439: 'Yandyki', 1085230: 'Borodaevka', 1050377: 'Pomary', 22290: '?', 1051373: 'Shorunzha', 1509630: 'Velikaya Pavlovka', 1017705: 'Borisoglebskoe', 1016951: 'Poldarsa', 1504194: 'Chernotisov', 1508155: 'Nizhankovichi', 15500: 'Novoukrainskoe', 1502547: 'Pervomayskoe', 1510335: 'Simonov', 1940289: '?', 1905536: '?', 10640: '?', 1915719: 'Karakom', 5420568: 'Scherbakty', 1951433: '?', 1515523: 'Pakul', 1907664: '?', 1091598: 'Moskovskoe', 1155549: 'Novopanshino', 1935626: '?', 1906463: '?', 1007948: 'Mishkino', 1042244: 'Gorskoe', 4717851: 'Barra Seca', 1124686: 'Turka', 1706699: 'Crossville', 4076508: 'Zaria', 4095896: 'Gwagwalada', 1082869: 'Mosolovo', 1156418: 'Minaevka', 1021963: 'Pogorelovo', 1010697: 'Pskovskoe', 1946031: '?', 1161091: 'Kotkino', 5266297: 'Rheine', 3632: 'Köthen', 14333: '?', 1093877: 'Krasnosvobodnoe', 4038529: 'Sintra', 1954705: '?', 1517416: 'Krasnoselsky', 1921934: 'Beauvais', 1513604: 'Novoselitsa', 1519194: 'Cranbury', 1937014: '?', 1092373: 'Shpikulovo', 1901863: 'Tamworth', 1131082: 'Potnyak', 1907304: '?', 1068689: 'Bogoslovka', 1603242: 'Kadino', 1926003: '?', 1902574: '?', 1708380: '?', 1144785: 'Kudrino', 1015640: 'Obraztsy', 1938294: '?', 1953816: '?', 22043: 'Radolfzell am Bodensee', 1519110: 'Bloomfield Hills', 1929424: '?', 6034: 'Slavny', 20996: 'Neustadt an der Weinstraße', 5165624: 'Slanchev Bryag', 3260398: 'Belovo', 1153733: 'Krest-Khaldzhay', 1924021: '?', 6704: 'Shepsi', 1147331: 'Brient', 1711621: 'Vayk', 20543: '?', 21699: 'Tallimarzhon', 1145315: 'Butakovo', 4924863: 'South Tampa', 1086122: 'Eruslan', 1500506: 'Ilichevo', 1904710: '?', 1137915: 'Pashkovo', 1136356: 'Sokhnovka', 4287750: 'Appingedam', 1065673: 'Kutafino', 1146807: 'Shilda', 5442882: 'Kizilovoe', 1502246: 'Krivbas', 1006399: 'Voznesenka', 1154123: 'Dalnee', 1156813: 'Timiryazevo', 4271: 'Priozerny', 1953856: '?', 1153900: 'Ozerskoe', 1153551: 'Pavlovsk', 1953857: 'Padar', 1952117: '?', 1505586: 'Korzhi', 1515225: 'Stolnoe', 1513959: 'Veliky Khutor', 1519032: 'Crawley', 1146359: 'Pristanskoe', 1506116: 'Levkovichi / Volodarka', 1059823: 'Talalikhino', 1040874: 'Pervomaysky', 16643: 'Vimovets', 1511861: 'Mikulintsy', 1930772: 'Winter Springs', 4924175: 'Oviedo', 4925366: 'Winter Garden', 4921725: 'Apopka', 1158942: 'Aeroport', 1079009: 'Dobropolye', 1092095: 'Bezopasnoe', 1147587: 'Kuzkino', 1073897: 'Mednikovo', 1511097: 'Buymerovka', 1506102: 'Pristromy', 1000256: 'Blagoveschenskaya', 1158537: 'Bor', 1058832: 'Livadia', 1954175: 'Moravská Třebová', 1915332: 'Nobitz', 1056625: 'Bekasovo', 1907805: '?', 1602027: 'Dokudovo', 1705601: 'Berdovka', 1041390: 'Nizhnebakanskaya', 1000037: 'Blechepsin', 1000681: 'Lazarevskaya', 1708956: '?', 1078351: 'Savoskin', 1953934: '?', 1005639: 'Kosh-Elga', 4069: 'Zharkovsky', 1159527: 'Tabat', 1703438: 'Hohhot', 1056901: 'Shustikovo', 1915: 'Martin', 1945761: '?', 1019520: 'Khokhlovo', 1057926: 'Lesnye Polyany', 1953642: 'Tagtabazar', 4529123: 'Vikersund', 1510375: 'Mirogoscha Pervaya', 1154211: 'Makhnevo', 1131011: 'Chepetsky', 1501077: 'Obukhov', 1702807: 'Podlesnoe', 1154598: 'Monetny', 20981: 'Alexandrovka', 1155168: 'Skatinskoe', 11406: 'Svetlogorye', 1702078: 'Kosoba', 1058161: 'Pushkino', 1128321: 'Semigorsk', 7314: 'Gromovo', 1004146: 'Pokrovka', 1950414: '?', 2102097: 'Yangikhaet (urtachirchixky Rayon)', 1509663: 'Klimovka', 5259819: 'Mittweida', 1953827: '?', 7194: '?', 1512149: 'Kovyagi', 1123462: 'Nechunaevo', 1068075: 'Panovka', 1954019: '?', 1700578: 'Bakanas', 1953743: '?', 1700202: 'Lvovskoe', 1060275: 'Ogudnevo', 1050542: 'Paygusovo', 1936243: '?', 1040768: '?', 1945485: '?', 1124506: 'Mogsokhon', 1086115: 'Chernavka', 5266531: 'Frankenberg (Eder)', 1945223: '?', 1706438: '?', 1908148: 'Nieder-Olm', 1601683: 'Rovenskaya Sloboda', 1710116: '?', 1915019: '?', 1152745: 'Rudnaya Pristan', 1036319: 'Vidany', 1927657: '?', 1135349: 'Drokino', 1954051: '?', 1936373: '?', 1955085: '?', 5075229: 'Orson', 7992: 'Halstead', 1091524: 'Pokoynoe', 1511120: 'Solnechnoe', 1509434: 'Zatishye', 1953950: '?', 1160349: 'Olinsk', 1087698: 'Ryazan (derevnya)', 1007619: 'Ilikovo', 1945808: '?', 1012705: 'Byakovo', 1954092: '?', 1941414: '?', 1015545: 'Kotovsky', 1509533: 'Sary', 1083395: 'Bolshaya Malyshevka', 1514978: 'Pliski', 1954084: '?', 1509034: 'Tsebrikovo', 1130022: 'Tisul', 1906831: '?', 3561726: 'Gujrāt', 18480: 'Alexeevskaya', 1955975: '?', 1939207: 'Hudiksvall', 21215: 'White Plains', 1927348: '?', 1707928: 'Tarbes', 1515058: 'Ivangorod', 20396: 'Ryazanovo', 1025585: 'Staronikolskoe', 17284: 'Hanover', 1706224: 'Lake City', 1044290: 'Azovka', 1701177: 'Solonovka', 19006: 'Khotush', 11516: 'Volot', 1939914: '?', 1122552: 'Bukanskoe', 5218: 'Kashary', 1516133: '?', 1501899: 'Zabuzhye', 1914667: '?', 1150396: 'Kueda (derevnya)', 17370: '?', 1506284: 'Motovilovka / Chervonaya Motovilovka', 1141436: 'Maloe Mamleevo', 1504482: 'Kopashnovo', 1041401: 'Ordzhonikidze', 1008759: 'Chesnokovka', 1060654: 'Volok', 1702177: 'Timiryazevka', 1051165: 'Nurma', 1924002: 'Dzheyranbatan', 1144070: 'Ovchinnikovo', 1905363: '?', 1145317: 'Znamenskoe', 1506079: 'Vinintsy', 16252: 'Glotovka', 1067595: 'Lermontovo', 1137281: 'Mostovskoe', 11567: 'Kamskoe Ustye', 1051310: 'Mari-Kuzhery', 4796: 'Derevyanka', 1515824: '?', 1918341: 'Broken Hill', 4185728: 'Los Yébenes', 1951357: '?', 1122002: 'Stepnoe Ozero', 1036942: 'Malaya Pera', 1125466: 'Fominki', 1125549: 'Kolp', 8128: 'Siva', 1703522: '?', 1928015: '?', 1920769: '?', 1507134: 'Gorskoe', 1710125: '?', 8034: 'Caserta', 4538919: 'Teano', 1941781: '?', 1936134: 'Primorsky', 1510699: 'Zarya', 1954188: 'Nshavan', 1129396: 'Shabanovo', 14641: 'Myrza-Ake', 1702829: 'Michurino', 1803405: '?', 1150165: 'Kuva', 3174186: 'Abrascico', 1076044: 'Ababkovo', 3493263: 'Punākha', 1155760: 'Tyumenskaya', 1936239: 'Leselidze', 1128705: 'Malta', 1953482: '?', 1042882: 'Studenok', 1002180: 'Ivanovka', 1113509: 'Minka', 12822: 'Vsevolodovo', 1136604: 'Dvurechnoe', 1702725: 'Nalobino', 1084258: 'Usolye', 1091996: 'Shangala', 1049116: 'Ekaterinovka', 1031114: 'Kholmogorovka', 1152456: 'Verkhnechusovskie Gorodki', 1500187: 'Yarkoe Pole', 1700178: 'Kalininskoe', 1147324: 'Asbestny', 1974632: 'Mount Pleasant', 1505854: 'Targan', 5430757: 'Zarechnoe', 1600130: 'Antopol', 1803223: 'Paide (payde)', 1036464: 'Kuganavolok', 1056602: 'Alabino', 16986: 'Terskaya', 1115305: 'Trenkasy', 1115325: 'Chemursha', 1934091: 'Laguna Niguel', 1159698: 'Tuim', 1905321: '?', 1140831: 'Elizaryevo', 1958751: '?', 1940451: '?', 1031885: 'Ungn-Teryachi', 4602: 'Apapelgino', 1929253: '?', 1036218: 'Rautalakhti', 1036202: 'Lyaskelya (stantsia)', 1516175: 'Tobol', 15189: 'Brugg', 1500029: 'Zheleznodorozhnoe', 1517952: '?', 1517154: 'Burevestnik', 1127629: 'Ozerny', 22704: 'Karabuta', 1100304: 'Privolzhsky', 1110661: 'Khaldy', 5057706: '?', 1705947: '?', 1087426: 'Zaborye', 1037046: 'Nizhnyaya Omra', 1700564: 'Kazakhstan', 1951416: '?', 1041180: 'Novoderevyankovskaya', 21551: 'Krivichi', 1007330: 'Podlubovo', 1512064: 'Bliznyuki', 1008771: 'Yasny', 1715201: '?', 1940530: 'Tashaul', 1940564: '?', 1091777: 'Galyugaevskaya', 1914919: '?', 1106456: 'Bolshie Ploty', 1502401: 'Pereschepino', 1057589: 'Levkino', 1079467: 'Nikolaevsky 2-J', 1911114: '?', 1932524: '?', 1515950: 'Ananyevo', 1918078: '?', 1926764: 'Leszno', 1715058: '?', 1026069: 'Berikey', 1004436: 'Protochnoe', 1012217: 'Partizanskaya', 1509142: 'Kremidovka', 20706: 'Voropaevo', 1113067: 'Parizh', 1511814: 'Golgocha', 1080540: 'Bolon', 20912: 'Beit Shemesh', 1136046: 'Sayansk', 1707001: 'Ziadin', 1703270: 'Shatlyk', 1951617: '?', 1957751: '?', 1030178: 'Mosta', 1954343: 'Kalamata', 1942462: '?', 1516574: 'Oktyabrsky', 1600648: 'Shayterovo', 1137562: 'Kurtamysh', 1512877: 'Chongar', 3127527: 'Mytilene', 1137883: 'Uvarovo', 1949716: '?', 1710284: 'Freehold', 1044107: 'Kirovsky', 1078928: 'Malchevskaya', 1501345: 'Obodovka', 1145356: 'Boevoy', 1955078: 'Drax', 5039105: 'Alaska', 1031923: 'Uldyuchiny', 1705240: 'Limbaži', 1948536: '?', 1917480: '?', 20201: 'Luzhinki', 1959001: 'Gryfino', 1157211: 'Elegest', 1005011: 'Nikolskoe', 4373648: 'Gonzerath', 1506820: 'Dokuchaevo', 1091903: 'Kara-Tyube', 1512261: 'Malaya Danilovka', 1505871: 'Lyubomirovka / Pravo Zhovtnya', 1160613: 'Mogzon', 1930247: 'Sozopol', 1000228: 'Svobodny Trud', 1500726: 'Yakushintsy', -5539: -5539, 1917090: '?', 1010456: 'Mozhayskoe', 1712598: '?', 1903616: 'Abbeville', 1933834: '?', 1926989: '?', 1911087: '?', 1600718: 'Prozoroki', 1113474: 'Gribanovka', 1505897: 'Olizarovka', 1060951: 'Valday-5', 1938854: '?', 1600126: 'Chudin', 2778: 'Gurez-Pudga', 1704149: 'Hawley', 1929304: 'Vinaròs', 1132501: 'Omutninsky', 5266495: 'Stadtallendorf', 1135552: 'Razezzhee', 1518920: 'Langenfeld', 1905840: 'Bustan (zarbdarsky Rayon)', 1706582: '?', 1952625: 'Columbia', 1904047: '?', 1700695: 'Umbetali Kayyrbaev', 1092167: 'Tatarka', 20942: 'Tarzana', 1951204: '?', 1703265: '?', 1945622: '?', 1057278: 'Chastsy-1', 1057217: 'Pokrovskoe (chastsovsky S/o)', 1966402: '?', 1125766: 'Sergeikha', 1912846: '?', 1926619: '?', 1138469: 'Verkhny Seymchan', 1108310: 'Vysotskoe', 1501019: 'Vendichany', 1507941: 'Lopatin', 1907951: '?', 1919979: 'Shoreline', 1951174: '?', 1143791: 'Chulym', 1929365: '?', 1153549: 'Nizhny Bestyakh', 1158882: 'Kapsal', 19458: 'Mishkino', 3202893: 'Canika', 1127806: 'Ukhtuy', 1952418: '?', 1157346: 'Novoberezovka', 1709468: 'Berlin', 2722570: 'Cap-Haïtien', 1110171: '?', 1706424: 'Valladolid', 1028528: 'Pistsovo', 1158040: 'Nikulino', 1007031: 'Petrovskoe', 1909723: '?', 1508634: 'Krivoe Ozero', 2252: 'Gorny', 1500363: 'Kovylnoe', 1002340: 'Dorogorskoe', 19091: 'Beit Dagan', 1012299: 'Zaporozhye', 1948109: '?', 1954530: '?', 17465: '?', 1914913: '?', 1026096: 'Sabnova', 1151534: 'Sokol', 1152627: 'Krokhalevo', 1050786: 'Kotenovo', 1080234: 'Kadom', 1500508: 'Krasnoflotskoe', 1160627: 'Khushenga', 1152732: 'Petrovka', 1086007: 'Vyazovka', 1700090: 'Voznesenka', 1940545: 'Aparan', 1514955: 'Berestovets', 1938200: '?', 1509536: 'Sosnovka', 1517371: 'Kugaly', 1946450: '?', 1148581: 'Elpachikha', 1036918: 'Ust-Lopyu', 1036922: 'Chernysh', 1913734: '?', 1006035: 'Tugay', 5266885: 'Isny im Allgäu', 1024718: 'Troitskoe', 1501188: 'Studenaya', 1954585: '?', 22111: 'Bitola', 1963316: '?', 1702495: 'Zhambyl', 1128305: 'Igirma', 1040838: 'Bzhedukhovskaya', 1954479: '?', 1918976: 'Peniche', 6834: '?', 1941373: '?', 1954651: '?', 1914249: '?', 1003494: 'Brin-Navolok', 1030688: 'Nivenskoe', 1152858: 'Kievka', 1918915: '?', 5346880: 'Pervomaysky ', 1079957: 'Artamoshkin', 1715600: '?', 1952011: '?', 1153796: 'Sinsk', 1079608: 'Sandata', 1701431: 'Moyynkum', 1055788: 'Vatutinki (derevnya)', 1913157: '?', 1148460: 'Novosergievka', 1086748: 'Kaydakovo', 1955830: '?', 1518299: '?', 1152464: 'Lyamino', 1515585: 'Makarov-1', 1800639: 'Koshnitsa', 1504227: 'Ilnitsa', 8709: 'Ikhala', 1001880: 'Dom U Piloramy', 1086638: 'Andreykovo', 1014854: 'Upornikovskaya', 1123297: 'Charyshskoe', 20763: 'Teresva', 1504726: 'Terpenye', 1916118: '?', 1702446: 'Bashmachnoe', 1708727: 'Willow Grove', 1132186: 'Stary Burtek', 1937381: '?', 1935451: 'Santa Cruz de la Sierra', 1800179: 'Bychok', 1905569: 'Varpaisjärvi', 1937295: '?', 1048204: 'Penino', 10414: 'Gayter-1', 1601980: 'Traby', 1504495: 'Sokirnitsa', 1055987: 'Mikulino', 1092863: 'Mordovo', 1903835: '?', 1516383: 'Saliena', 1902913: 'Dornbirn', 1908438: 'Kateríni', 1133465: 'Kazan (derevnya)', 1144375: 'Usmanka', 1705340: 'Oxford', 1959578: 'Khavast (khavastsky Rayon)', 1129038: 'Krutogorovsky', 1933091: '?', 1085853: 'Samoylovka', 12355: 'Orlovo', 1701255: 'Bozanbay', 5266264: 'Rheinbach', 1512444: 'Alexeevka', 1927677: '?', 2203849: 'Hoover', 1134504: 'Podgortsy', 1505439: 'Pereginskoe', 1086392: 'Komsomolskoe', 1127085: 'Chamerevo', 1117531: 'Bogorodskoe', 1954592: '?', 1706558: 'Sulinowo', 1711940: 'Shabran (devechi)', 1954813: '?', 3692: 'Lesozavodsky', 3828107: 'Gimpo', 4257169: 'Motala', 14839: 'Friedberg', 1904113: '?', 2100420: 'Zaamin', 1513050: 'Sivashskoe', 1137345: 'Novopetropavlovskoe', 1713321: '?', 1092787: 'Terskoe', 1058711: 'Svatkovo', 1949912: '?', 1946464: '?', 1936905: '?', 17663: 'Kazachinskoe', 1071367: 'Markovo', 1011142: 'Kazinka', 1500817: 'Ilinetskoe', 1702447: 'Mikhaylovka', 1702169: 'Sarykol', 1914366: 'Thisted', 1944602: '?', 1131824: 'Kumeny', 1715259: '?', 5266764: 'Wiesloch', 1156319: 'Sarga', 2500369: 'Shuroabad', 1950196: '?', 1513603: 'Novolabun', 1513103: 'Schastlivoe', 2332: 'Verkhnyaya Khava', 1127570: 'Perevoz', 4430489: 'La Rochelle', 1027345: 'Kamenki', 1159459: 'Beltirskoe', 1602347: 'Osipovichi', 5264794: 'Rosenheim', 4984897: 'East York', 1131578: 'Karpushino', 1924324: '?', 1513025: 'Ukrainka', 1124532: 'Mogoyto', 1505687: 'Kuchakov / Kirovo', 1133991: 'Pachi', 5110915: 'Mulino', 1705544: 'Piscataway', 1514546: 'Beregomet', 1002358: 'Lampozhnya', 8285: 'Tashla', 1903064: '?', 1041843: 'Staroleushkovskaya', 1018723: 'Oktyabrsky', 1950236: '?', 3090219: 'Homs', 1950266: '?', 1509108: 'Ivashkov', 1942105: '?', 1155869: 'Bobrovsky', 1115185: 'Akulevo', 5267062: 'Roth', 1111081: 'Dizmino', 1132171: 'Porez', 1931080: '?', 16382: 'Kuterem (selo)', 1518209: 'Gorodets', 1600525: 'Plotnitsa', 1155073: 'Martyush', 1500814: 'Dashev', 1111933: 'Kirzyat', 1934041: 'Vladimirovka', 1912252: '?', 1509566: 'Novomoskovskoe', 1901692: '?', 1503172: 'Ray-Alexandrovka', 1948390: 'Surakhany (surakhany)', 1707861: '?', 1931451: '?', 1146892: 'Petrovka', 4220396: 'Vipperød', 5043533: 'Albany', 1953341: '?', 1908790: '?', 1702101: 'Koybagar', 1512342: 'Odnorobovka', 1709370: 'Atlantis', 1936300: '?', 1502792: 'Neskuchnoe', 1502796: 'Blagodatnoe / Oktyabr', 3162183: '?', 1967466: 'Córdoba', 1940171: 'Mardakan (azizbekov)', 7585: 'Kochevo', 4908809: 'Denver', 1500579: 'Koreiz', 1004801: 'Blagoveschenka', 1096847: 'Verkhny Timerlek', 1055723: 'Golyevo', 1921380: 'Woodbury', 1512623: 'Budy', 1125553: 'Krasnoe Ekho', 1079929: 'Kalininskaya', 1014757: 'Bolshoy', 1121841: 'Druzhba', 1954995: '?', 1951776: '?', 1907365: '?', 1912927: '?', 1047332: 'Yanega', 1086417: 'Sadovy', 1501051: 'Yaruga', 1502858: 'Kremenevka', 1932231: 'Zahlé', 1002195: 'Lena', 1040926: 'Chepiginskaya', 1089625: 'Golynki', 1504779: 'Tavricheskoe / Kirovo', 1955017: '?', 1706658: 'Hamilton', 1072306: 'Sebezh', 1707126: 'Chirakchi', 1143945: 'Marshanskoe', 1031456: 'Saranskoe', 1600023: 'Polonka', 1160992: 'Samburg', 5093813: 'Placerville', 1800090: 'Blizhny Khutor', 4184436: 'Santiago del Teide', 1515054: 'Gorodnya', 1146302: 'Keyzes', 767: 'Gezgaly', 1967954: '?', 1931628: '?', 1036299: 'Sheltozero', 1518664: 'Terekhovka', 1042249: 'Defanovka', 1512447: 'Vyazovaya', 1949671: '?', 1711456: '?', 1936078: 'Kleinblittersdorf', 1955089: '?', 1930229: '?', 1054842: 'Glebovsky', 1949541: 'Aragva', 1087852: 'Ozerny', 1946877: '?', 21930: 'Voskhod', 1504079: 'Ivanopol', 5123342: 'Ceylon', 1040932: 'Beysuzhek Vtoroy', 1503943: 'Krymok', 1101522: 'Truzhenik', 1043078: 'Lachinovo', 11568: 'Kemlya', 5266510: 'Baunatal', 5266539: 'Hessisch Lichtenau', 1601254: 'Uvarovichi', 1159159: 'Komsomolsk-31', 1131103: 'Shapta', 2002069: 'Galaţi', 6769: 'Novobazhenovo', 1513615: 'Varvarovka', 14307: '?', 1968436: '?', 1906204: '?', 1050131: 'Oktyabrskoe', 1500089: 'Pavlovka', 1038519: 'Miskovo', 1029875: 'Balakhna', 1159359: 'Galkino', 1153374: 'Aldansky', 5266434: 'Bruchköbel', 15844: 'Greenville', 1954292: 'Imishli', 2722566: 'Asmara', 1906134: '?', 1713473: '?', 1516173: '?', 1141785: 'Balakhna', 1924225: 'Beverly Hills', 2717: '?', 1509355: 'Krivaya Balka', 1509374: 'Uspenovka', 1042090: 'Akhtanizovskaya', 1939321: '?', 1976126: '?', 1041081: 'Kamyshevatskaya', 1706491: 'Jenin', 1714364: '?', 1023943: 'Khrenovoe', 19138: '?', 1139999: 'Fokino', 1213: 'Corpus Christi', 1928955: '?', 1938526: '?', 1949214: '?', 1935026: 'Novi Ligure', 1505908: 'Teterevskoe', 1948872: '?', 1948629: '?', 1937777: '?', 1919969: 'Shawnee', 1949366: '?', 1505619: 'Makeevka', 1067710: 'Kamenka', 1957059: '?', 1035356: 'Schelkanovo', 1148302: 'Gamaleevka 2-Ya', 1701562: 'Uspenovka', 1122393: 'Berezovka', 5023519: 'Old Greenwich', 1938518: 'Druskininkai', 1923720: '?', 1952163: '?', 1929372: '?', 1920505: 'Vincennes', 1955039: '?', 1124300: 'Komsomolskoe', 1096820: 'Chita (selo)', 1036906: 'Prokopyevka', 1506271: 'Kozhanka', 22225: 'Villahermosa', 1906985: '?', 2201550: '?', 2206188: '?', 1955243: '?', 1953210: '?', 1701727: 'Samarka', 1152813: 'Pavlo-Fedorovka', 1702778: 'Chistoe', 1024096: 'Osetrovka', 1707635: 'Sherabad', 1937306: '?', 1933657: '?', 1127560: 'Balakhninsky', 1709348: 'Loudon', 1123091: 'Larichikha', 1079443: 'Polivyanka', 1711442: '?', 1601430: 'Luxky', 1040529: 'Zeblyaki (poselok)', 1145864: 'Spassk', 1955287: 'Emmaus', 1067507: 'Sosedka', 1702189: 'Pritobolsky', 1506347: 'Dobroe', 20296: 'Matur', 21388: 'Markham', 1041855: 'Brinkovskaya', 5267451: 'Zusmarshausen, Markt', 1908561: '?', 814: 'Ramsgate', 6802: 'Spokoynaya', 5331174: 'Yuzhakovo', 1159269: 'Lososina', 1073343: 'Zaborovye', 1702498: 'Yamyshevo', 1071855: 'Pukino', 1907626: 'Noordwijk', 1948428: 'Aydarken', 15379: 'Krivosheino', 1158927: 'Izvestkovy', 10642: 'Kagalnik', 1024436: 'Kolomenskoe', 5280: 'Kommunistichesky', 1501533: 'Klembovka', 12233: 'Vernoe', 1701153: 'Maleevsk', 2204260: 'Cisterna di Latina', 1098509: 'Ilinskoe', 1146389: 'Ekaterininskoe', 1514285: 'Balakleya', 1160784: 'Kopun', 1922443: '?', 1503947: 'Malaya Racha', 3572952: 'Hyderabad', 1927561: '?', 5041532: 'Madison Heights', 1082220: 'Kornevoe', 3058700: 'Qom', 1113924: 'Kobi', 1086189: 'Generalskoe', 1905074: '?', 4923798: 'Melbourne Village', 1145512: 'Novoselye', 1915156: '?', 1500337: 'Grishino', 21174: '?', 1159104: 'Obor', 1049929: 'Lamskaya', 1711219: 'Edina', 1108321: 'Dubovka', 1077841: 'Manychskaya', 5261770: 'Engelskirchen', 1113480: 'Kidysh', 1121489: 'Guney', 1040702: 'Vinogradny', 1133074: 'Pavlovo', 1031883: 'Plodovitoe', 1505454: 'Balintsy', 1932971: '?', 1096948: 'Leskhoz', 1700034: 'Izhevskoe', 1917168: 'Malnava', 20587: 'Novotroitskoe', 1502848: 'Yasnoe', 1921975: '?', 1950034: '?', 5330639: 'Winscombe', 1702648: 'Birlik', 1005356: 'Axakovo', 20923: 'Bezlyudovka', 1143805: 'Burmistrovo', 1700424: 'Kenkiak', 1971789: 'Kudowa-Zdrój', 1129115: 'Starobachaty', 1713561: '?', 1085924: 'Krasny Oktyabr', 1515074: 'Trostyanets', 1700102: 'Karaozek (kolokolovka)', 1043668: 'Manturovo', 1091418: 'Novokavkazsky', 1159339: 'Tsimmermanovka', 1158253: 'Gorkovka', 1156127: 'Troitsky', 1512026: 'Savintsy', 1039675: 'Ponazyrevo (derevnya)', 1122394: 'Verkh-Kamyshenka', 1515095: 'Karpilovka', 1516362: 'Glinoe (slobodzeya)', 1503976: 'Derganovka', 1713570: 'Genk', 1951250: '?', 1002669: 'Krasnaya Gorka', 1712201: 'Floréal', 3336562: 'Flic en Flac', 1905967: '?', 5266598: 'Hillesheim', 1041059: 'Plastunovskaya', 14596: '?', 1951498: '?', 1502991: 'Mikhaylovka', 1955457: 'Dewsbury', 1033941: 'Peredel', 1505967: 'Kryukovschina', 1928441: '?', 1508201: 'Dobryany', 1601843: 'Dulevtsy', 1921504: '?', 1501415: 'Lozovaya', 1057920: 'Kostino', 1968816: '?', 1159436: 'Kirovo', 1934345: '?', 1712008: '?', 1953498: '?', 1136033: '?', 1139300: 'Sitniki (sitnikovsky S/s)', 3134660: 'Dahr el Ahmar', 1707502: '?', 1503780: 'Kolodyanka', 1702104: 'Ushakovo', 1975685: 'Szekszárd', 1518013: 'Chkalovo', 1140160: 'Motmos', 1136882: 'Novomitropolka', 1127494: 'Volochaevka-1', 21427: 'Gayvoron', 1078704: 'Novikovka', 1511276: 'Tokari', 1000203: 'Shevchenko', 1951548: 'Dinklage', 4349630: 'Munster', 1904263: 'Soltau', 1078153: 'Balko-Gruzsky', 1010038: 'Skorodnoe', 12742: 'Kovran', 13458: 'Imantau', 2200424: 'Lichk', 1713573: '?', 11314: 'Zuoz', 5259917: 'Köthen (Anhalt)', 14812: 'Turbov', 5538: 'Kulikovo (poselok)', 1057472: 'Mistsevo (dorokhovsky S/o)', 1949931: '?', 1943809: '?', 1041341: 'Timashevka', 4689354: 'Matanzas', 7657: 'Smyshlyaevka', 1046153: 'Medvezhy Stan', 1518412: 'Lobanovo', 1137173: 'Uchkulevo', 8020: 'Uspenka', 1083164: 'Voskresenka', 1106056: 'Gorodenets', 1159137: 'Im. P. Osipenko', 1939767: '?', 2722577: 'Tamale', 2722578: 'Sekondi', 1026343: 'Korkmaskala', 1013992: 'Pavlovka', 1700757: 'Tausamaly (kamenka)', 1903927: 'Brattleboro', 1952865: '?', 1030216: 'Kholuy', 1968076: '?', 1940207: '?', 1952233: '?', 4237899: 'Frimley', 1601190: 'Sloboda', 4515075: "Platja d'Aro", 1007195: 'Novomullakaevo', 1975209: 'Udzhar', 1078890: 'Dolotinka', 1501330: 'Verkhovka', 1006473: 'Ivanaevo', 5303888: "Laudun-l'Ardoise", 4949: 'Stolbischi', 1942311: 'Al Mukallā', 1509914: 'Savintsy', 1504781: 'Kopani', 1504800: 'Preobrazhenka', 1087026: 'Ashkovo', 1951309: '?', 1514112: 'Telepino', 1514282: 'Shabastovka', 1501630: 'Buzhanka', 1955596: '?', 1086434: 'Khumalag', 17560: 'Novovoronezhsky', 1122109: 'Gilevka', 1138945: 'Dmitrievka', 19922: 'Dustlik (dustlixky Rayon)', 1159742: 'Sosva', 5259474: 'Zschopau', 1113943: 'Atrat', 1083857: 'Ilmen', 1509189: 'Stanislavka', 14483: 'Choya', 1508964: 'Gradenitsy', 1511924: 'Davydkovtsy', 1511933: 'Kolindyany', 1513531: 'Goloskov', 1037186: 'Mikun (derevnya)', 1701391: 'Stepnoe', 1919925: '?', 1036960: 'Zelenets', 1939424: '?', 1509150: 'Oniskovo', 1158986: 'Kenada', 4522031: 'Fontanar', 4521117: 'Guadalajara', 1948057: '?', 1002035: 'Ponomarevskaya', 1907174: '?', 1510481: 'Derman Vtoraya', 1035603: '12 Km', 1910133: '?', 1951442: '?', 2205966: 'Ranong', 1931317: '?', 1124191: 'Yubileyny', 1515316: 'Stepnye Khutory', 1152141: 'Merkushi', 1503257: 'Dmitrovka', 1035390: 'Kardonixkaya', 8827: 'Lemez-Tamak', 1508676: 'Mikhaylovka / Ulyanovka', 4952519: 'Clarksville', 1112262: 'Bazhikaeva', 1007775: 'Berezovsky', 1954709: '?', 1157737: 'Minino', 1927061: '?', 1051646: 'Ilet', 22088: 'Pelische', 1124116: 'Marevy', 1939694: '?', 1512243: 'Olshana', 1045445: 'Pikalevo-1', 1077713: 'Krasny Sad', 1955074: '?', 1915894: 'Spalding', 1040998: 'Kuban', 1932657: '?', 1951241: 'Smolyan', 1940460: '?', 1940969: '?', 1157520: 'Tukuz', 1514324: 'Zelenkov', 1503818: 'Yarun', 1946800: '?', 1701578: 'Akoba', 1143216: 'Bolshoe Ustinskoe', 1955677: '?', 17241: 'Starobeshevo', 1962746: '?', 1041344: 'Adagum', 1914358: '?', 1510282: 'Novaki', 1930129: 'Cherokee', 1502213: 'Novonikolaevka', 1006910: 'Kaenlyk', 3364823: 'Toliara', 1066494: 'Znamenka', 1601372: 'Belev', 1049533: 'Chernava', 1049507: 'Pyatnitskoe', 1712714: 'Valparaíso', 1955473: '?', 1514319: 'Vishnepol', 5034507: 'Florida', 1602443: 'Karatsk', 1602442: 'Sinyavka', 1028741: 'Vorsino', 20924: 'Slobodskoe / Frunze', 1152459: 'Kalino', 1159848: 'Zarechny', 1034770: 'Lopatino', 1092065: 'Niny', 1942146: '?', 1062985: 'Fedorkovo', 1932765: '?', 1082175: 'Verderevo', 1924490: '?', 1714736: '?', 1517348: '?', 1707273: '?', 1514476: 'Vasyutintsy', 1113165: 'Podovinnoe', 1154606: 'Staropyshminsk', 1951991: '?', 1518780: 'Zabrze', 1021732: 'Sverdlovskaya', 1602131: 'Murovanaya Oshmyanka', 1039835: 'Levashovo', 1802469: '?', 1952707: '?', 5266305: 'Sassenberg', 1058824: 'Krutoe', 1706118: 'Mayak', 1952201: '?', 14018: 'Sumsky Posad', 1803202: 'Jõgeva', 1951001: '?', 1711988: '?', 4463922: 'Csurgó', 1083136: 'Neprik', 1917687: '?', 1114520: 'Pochinok-Ineli', 4684144: 'Chihuahua', 1026046: 'Urkarakh', 1095138: 'Yangulovo', 1015035: 'Zalivsky', 1513789: 'Malinychi', 1939425: '?', 5259964: 'Bad Lobenstein', 1904480: '?', 1714633: 'Howell', 1955761: 'Rastede', 1964669: '?', 1060034: 'Kerva', 1091820: 'Kumskaya Dolina', 1937912: '?', 1012177: 'Kamensky Khutor', 1085983: 'Zolotaya Step', 1031052: 'Kulikovo', 1505572: 'Vorokhta', 1920870: '?', 1915929: '?', 1913878: 'Edmondsham', 22277: 'Vicenza', 1115592: 'Koshki-Kulikeevo', 1922574: 'Shrīnagar', 5304388: 'Saint-Dié-des-Vosges', 5420596: 'Quevedo', 1078079: 'Pirozhok', 5357: 'Talalaevka', 1946063: '?', 1502838: 'Olenovka', 5130686: 'Windsor', 1509103: 'Alexeevka', 1926430: '?', 1955878: '?', 1067857: 'Krym', 1502419: 'Verbki', 1500268: 'Gornostaevka', 1954285: 'Brunei', 1955845: 'Siemianowice Śląskie', 1129400: 'Belogorodka', 1146418: 'Mezhdurechye', 1927636: '?', 1061474: 'Filippova Gora', 15568: 'Nagovo', 1026787: 'Razdolye', 1921856: '?', 1943426: '?', 1507822: 'Sudovaya Vishnya', 1516626: 'Trenton', 8702: 'Uglekamensk', 3049922: 'Ramadi', 5068975: 'Bloomsburg', 1953142: '?', 1908569: 'Miramar', 5256281: 'Schwerin', 1122427: 'Krutikha', 1504424: 'Uglya', 8961: 'Dzigovka', 1153538: 'Megino-Kangalassky', 4951288: 'Baltimore Highlands', 1904254: 'Montijo', 13501: 'Montclair', 1129078: 'Artyshta', 1709980: 'Center Valley', 1700522: 'Matay', 1153682: 'Srednekolymsky', 1153178: 'Timiryazevsky', 1515871: 'Oswego', 17650: 'Vertikos', 1158313: 'Chervishevo', 1135182: 'Shiversky', 1159754: 'Altay', 16217: 'Fedorovka', 1095916: 'Barguzino', 3837534: '?', 1051883: 'Vyatskoe', 1093888: 'Lesnoy', 1901100: '?', 1702124: 'Zhambyl', 1079336: 'Krivyanskaya', 1923146: '?', 1709179: 'Alamogordo', 1159673: 'Borets', 4696397: 'Aberdeen', 1512428: 'Natalino', 5094471: 'San Jose', 2208585: '?', 1933366: '?', 1512899: 'Novaya Zburyevka', 1144325: 'Yarkul', 1155946: 'Tomskaya', 1057040: 'Vishnyakovskie Dachi', 1159965: 'Lugovskoy', 1137716: 'Menschikovo', 1002326: 'Tsenogora', 1120311: 'Yasenevo', 1078484: 'Chistoozerny', 1945556: '?', 1514419: 'Belozerye', 1515127: 'Chemer', 1501635: 'Zabolottsy', 1055750: 'Otradnoe', 1517057: 'Finsterwalde', 1110381: 'Kechevo', 1602868: 'Tesnovaya', 1136294: 'Yuzhno-Eniseysk', 3280721: 'Świętochów', 1031606: 'Vzmorye', 1954454: '?', 1942621: '?', 1909481: '?', 1139858: 'Blagodatovka', 1954981: '?', 14250: 'Zaplavnoe', 1092180: 'Bondari', 1500526: 'Veseloe', 1944456: '?', 1918416: '?', 1015282: 'Kletsko-Pochtovsky', 1509265: 'Ulyanovka', 1156963: 'D/o Siny Utes', 1502129: 'Maryanskoe', 1917961: '?', 1956653: '?', 1956050: '?', 1952094: '?', 1159282: 'Duki', 1900322: 'Kfar Silver', 1956379: 'Tatev', 1109782: 'Sovkhozny', 1511802: 'Stary Skalat', 1144572: 'Novy Sharap', 1936234: '?', 1959570: '?', 1064289: 'Chudovo 1-E', 1112332: 'Khudayberdinsky', 1156370: 'Kayak', 1600710: 'Obrub', 1956071: '?', 1010104: 'Annovka', 1914445: '?', 1953284: 'Rosebud', 1940253: '?', 1956041: '?', 1942448: '?', 10048: 'Yagnitsa', 1156181: 'Troshkovo', 1146664: 'Solyanoe', 1064243: 'Krasnofarforny', 4447893: 'Carpentras', 1035430: 'Khurzuk', 1518127: 'Čačak', 1145576: 'Yaman', 1154010: 'Onor', 1906212: 'Berlin', 1006083: 'Davlekanovo', 1042437: 'Sukhodol', 1153488: 'Gorny', 1004710: 'Krymskoe', 1514418: 'Baybuzy', 1518480: 'Kostyukovka', 1947416: 'Barrie', 4000183: 'Wagga Wagga', 4281261: 'Velp', 1002630: 'Shomoksha', 1929736: 'Teruel', 1710485: 'Columbus', 1126713: 'Berezniki', 1936047: '?', 1700623: 'Novoalexeevka', 1059619: 'Pavlovichi', 1110225: 'Yamaykino', 1129994: '?', 1069353: 'Pskovki', 1510532: 'Storozhov', 10635: 'Yaremche', 1512460: 'Mirnoe', 14395: 'Kut-Yakh', 5166756: 'Sitges', 4909525: 'Goddard', 1514603: 'Dimka', 1514606: 'Karapchov', 1159122: 'Briakan', 1911683: 'Saatly', 1942042: '?', 1945663: '?', 1137007: 'Semenovka', 1051492: 'Pektubaevo', 1124359: 'Khara-Shibir', 1010128: 'Zhigaylovka', 1516386: 'Nine Mile Falls', 1921110: '?', 1960057: 'Aden', 1922486: '?', 13227: 'Kovernino', 1108344: 'Lesnoy', 1949020: '?', 1057947: 'Ostankino', 1146906: 'Engels', 1923267: '?', 1054121: 'Olyavidovo', 1937523: 'Inčukalns', 1154122: 'Bereznyaki', 1041926: 'Smolenskaya', 1160912: 'Krasnoarmeysky', 1091433: 'Vodorazdel', 1963529: 'Erba', 1508492: 'Belousovka', 1158590: 'Chechkino', 1073749: 'Velikie Suki', 1130773: 'Srednyaya Toyma', 1602662: 'Knyaginin', 1700187: 'Pyatigorskoe', 1041252: 'Krupskoy', 1028127: 'Ilinskoe-Khovanskoe', 1137879: 'Staropershino', 1602259: 'Zheludok', 1157348: 'Novopetrovo', 1057042: 'Yamkino', 1942897: '?', 1505822: 'Rovy', 10178: 'Martynovskoe', 1501978: 'Datin', 1712346: '?', 19712: 'Gvardeyskoe', 1518157: 'Ubinka', 1701097: 'Kozhokhovo', 1701269: 'Kamenka', 961: '?', 1706451: 'Eagle Point', 12911: '?', 1122925: 'Verkh-Obsky', 1502882: 'Kirovo', 1145957: 'Platonovka', 1507962: 'Uzlovoe', 4924195: 'Palm Bay', 1930299: '?', 1954408: '?', 1135887: 'Verkhny Kuzhebar', 1952001: '?', 1925613: '?', 1135695: 'Verkhnyaya Urya', 1504071: 'Velikie Korovintsy', 1057028: 'Fryazevo', 1058170: 'Rybolovo', 1145785: 'Muromtsevo', 1515200: 'Berezna', 1510752: 'Rokitnoe Selo', 1958156: '?', 6266: 'Podkumok', 1704070: '?', 4661145: 'Konigsberg', 15284: 'Alexandrovo', 1157679: 'Lebedevka', 7558: 'Korotoyak', 1915522: '?', 20582: 'Širvintos', 10135: 'Woodbridge', 1058497: 'P/l Almaz', 1702492: 'Cheka', 1051357: 'Uilem', 1925425: '?', 1707242: '?', 1159543: 'Borozda', 1087542: 'Saki', 3128533: 'Lávrion', 1713698: 'Azadbosh', 1133353: 'Korlyaki', 1509623: 'Chapaevka', 22307: 'Vergulovka', 1507146: 'Komissarovka', 20693: 'Grivenskaya', 1085473: 'Berezovka', 1093095: 'Kulyabovka', 1955685: '?', 15406: 'Goncharovo', 1503237: 'Starognatovka', 1006712: 'Zilair', 1703778: 'Almondsbury', 5056074: 'Summit', 1713894: '?', 5421845: 'Hiroshima', 1954562: '?', 1923066: '?', 1956368: '?', 1157615: 'Evsino', 1919712: '?', 3221503: '?', 1057910: 'Zelenogradsky', 1506468: 'Dikovka', 1924997: '?', 1518077: 'Bayanaul', 1008288: 'Tyater-Araslanovo', 1946480: '?', 10033: 'Bershet', 1509500: 'Rokita', 1068059: 'Krasnaya Gorka', 1601403: 'Krasny Bor', 1926798: '?', 4341093: 'Planken', 1708282: 'Augstkalne', 3809210: 'Changzhou', 1909950: '?', 1706518: 'Kreiensen', 1918715: '?', 1030091: 'Pustosh', 1947541: '?', 20600: 'Churilkovo', 1501254: 'Rososha', 1097391: 'Starye Kutushi', 1509855: 'Novoorekhovka', 1128355: 'Zarechye', 1071025: 'Dolgovitsa', 1071077: 'Kresty', 1518051: 'Castellanza', 1036146: 'Mikhaylovskoe', 16516: 'Sashkino', 1030680: 'Medovoe', 1602940: 'Tekhtin', 6448: 'Saint Cloud', 1137466: 'Tagilskoe', 1024160: 'Uglyanets', 1955525: '?', 4333914: 'Schleiz', 1944304: '?', 12058: 'Sankt Pölten', 5244545: 'Credaro', 1510088: 'Vesely Podol', 1507143: 'Gorodische', 1933046: 'Elkton', 4243543: 'Sursee', 1904535: '?', 1975256: '?', 1027379: 'Myt', 5260600: 'Owschlag', 1508357: 'Kavuny', 1934927: '?', 1711614: '?', 5208749: 'Adi Ferti', 1504829: 'Botyevo', 1601909: 'Sopotskin', 1007915: 'Biryubash', 1514168: 'Yaroshevka', 1145174: 'Sosnovka', 1005987: 'Gafuri', 1516478: '?', 1923898: '?', 1013403: 'Rabochy', 1941868: '?', 1068450: 'Narovchat', 1059431: 'Petrovo', 1085988: 'Mechetnoe', 1946804: '?', 1922088: 'Lienz', 1956485: '?', 1702527: 'Chernoretskoe', 2300299: 'Akterek', 5266331: 'Bad Salzuflen', 5266336: 'Lemgo', 1086155: 'Vozrozhdenie', 1951456: '?', 1049433: 'Bykovo', 1956552: 'Šakiai', 1702168: 'Barvinovka', 1956443: '?', 1602305: 'Zembin', 1082860: 'Lipetskoe Lesn-Vo', 1938776: '?', 1901484: '?', 1004401: 'Seitovka', 1506192: 'Ivanovka', 1928008: '?', 1916490: '?', 9861: '?', 11099: 'Tsentoroy', 5032135: 'DeMotte', 1918386: 'Tsandrypsh (gantiadi)', 1154007: 'Buyukly', 1927989: '?', 1091982: 'Mayak', 1703503: '?', 1934251: '?', 1153441: 'Khoro', 1923672: '?', 2206067: 'Sankt Wendel', 1502462: 'Nikolaevka', 1958948: '?', 1128349: 'Voznesensky', 20723: 'Kevsala', 1156783: 'Bely Yar', 1057052: 'Akulovo (naro-Osanovsky S/o)', 1936839: '?', 1124366: 'Erkhirik', 1159374: 'Korfovsky', 1152917: 'Pervomayskoe', 1908609: 'Monroe', 17843: 'Yasnoe', 1932153: 'Panfilovka', 1129534: 'Kostenkovo', 1948003: '?', 13563: 'Sitne-Schelkanovo', 10446: 'Sayylyk', 1007504: 'Volostnovka', 1701722: 'Karabas', 1155286: 'Khrebet-Uralsky', 1956627: '?', 1115170: 'Chirichkasy', 1712664: 'Kennebunkport', 1026118: 'Usukhchay', 1153007: 'Avangard', 1127548: 'Konovalovo', 1030518: 'Minsky', 1094866: 'Verkhnyaya Ura', 1096567: 'Bolgar', 4901: 'Ronga', 1014413: 'Krep', 2722453: 'Kular', 1922001: '?', 1920801: '?', 1147782: 'Krasnokholm', 1128269: 'Kharik', 1084750: 'Shiroky Buerak', 1008197: 'Sanatory Yangantau', 14403: 'Kubenskoe', 1031302: 'Gavrilovo', 1031282: 'Chernyakhovo', 1955047: '?', 1092079: 'Zelenaya Roscha', 1153070: 'Verkhny Pereval', 1504544: 'Pyatikhatki', 1115182: 'Abashevo', 1115266: 'Novye Trenkasy', 1510730: 'Berezovo', 1059554: 'Ermolino', 1512449: 'Dublyanka', 1006426: 'Oktyabrsky', 1518610: 'Muynak', 4967799: 'Norfolk', 1508218: 'Lyubintsy', 1504435: 'Velikie Lazy', 1127974: '?', 1155871: 'Bolshoy Istok', 1948826: 'Ayr', 1010196: 'Prokhodnoe', 1146821: 'Kayrakty', 1156849: 'Zonalnaya Stantsia', 1086317: 'Khataldon', 1904259: '?', 1926439: '?', 1711903: 'Övertorneå', 1123949: 'Novgorodka', 1950211: '?', 2722628: 'São Tomé', 1507909: 'Podbirtsy', 1145145: 'Chikman', 1151250: 'Vereschagino', 3630: 'Oktyabrskoe', 1128295: 'Vidim', 1094305: 'Karamaly', 1124362: 'Chelutay (3 Km)', 1128935: 'Kamensk', 1702000: 'Kazanbasy', 4247489: 'Väröbacka', 1150626: 'Obukhovo', 1506403: 'Peregonovka', 1062598: 'Proletary', 2100490: 'Ugat', 1017954: 'Kozhevnikovo', 1159705: 'Tselinnoe', 1512908: 'Staraya Zburyevka', 1518120: 'Olekhnovichi', 1702862: 'Afanasyevka', 1907034: 'Karachi', 1950895: 'San Juan de Alicante', 1510755: 'Tomashgorod', 1151563: 'Froly', 1067668: 'Kizhevatovo', 1153721: 'Uolba', 4316560: 'Zusenhofen', 5266805: 'Kehl', 1148713: 'Perebor', 1148657: 'Brazhniki', 1932735: '?', 1504254: 'Kolochava', 1159277: 'Gorin', 1119458: 'Demyanskoe', 1157525: 'Chernoe', 1129125: 'Barzas', 4340415: 'Prenzlau', 1955187: '?', 1948197: 'Kalveliai', 1711018: '?', 1921909: '?', 1601934: 'Kozlovschina', 1006673: 'Tazlarovo', 1952010: '?', 1130550: 'Syryany', 1932956: '?', 1509546: 'Velikie Krynki', 1053960: 'Gorshkovo', 1154147: 'Berezovsky', 1157233: 'Vostok', 1956785: '?', 1128219: 'Buzuluk', 1927238: '?', 1956611: '?', 1918011: '?', 1147278: 'Kamsak', 1602851: 'Vishnevets', 1802328: '?', 1041342: 'Shevchenkovskoe', 2202143: 'Longueuil', 1014699: 'Siskovsky', 1049685: 'Olkhovets', 1152364: 'Esaul', 4381542: 'Dransfeld', 5059832: 'Larchmont', 1514479: 'Veremeevka', 1500411: 'Natashino', 2202829: '?', 1506445: 'Gurovka', 1509574: 'Pustovoytovo', 1055208: 'Kamenka', 1148411: 'Molodezhny', 1014361: 'Kondrashi', 1952554: 'Des Moines', 1504182: 'Oleshnik', 1923089: '?', 1920910: '?', 2211205: '?', 5267685: 'Neustadt an der Aisch', 1703931: 'Northfield', 1505018: 'Polyanitsa', 1924826: '?', 1956920: 'Egeln', 5266347: 'Rahden', 1512763: 'Mirolyubovka / Radyanskoe', 1147272: 'Goluboy Fakel', 1947008: '?', 5266284: 'Gladbeck', 4617654: 'Animal Flower Cave', 3649945: 'Colonia', 1510103: 'Obolon', 10000: '?', 4236960: 'Harwich', 1706923: '?', 1136557: 'Kirikovo', 1953624: '?', 1146282: 'Uvalnaya Bitia', 1028067: 'Chernorechensky', 1155700: 'Vostochny', 1702217: 'Bannovka', 15126: 'Olhão', 1145288: 'Novopokrovka', 1135211: '?', 1501473: 'Olgopol', 1947777: '?', 10751: 'Ravenna', 1129766: 'Ufimtsevo', 4235959: 'Kent', 1080117: 'Narma', 5261783: 'Bottrop', 1923419: '?', 1923187: 'Yosemite Lakes Park', 1906512: '?', 1938950: '?', 1096669: 'Erykla', 4542915: 'Pavullo nel Frignano', 1500865: 'Novaya Greblya', 1908781: '?', 1146112: 'Rozovka', 1110229: 'Atabaevo', 1057902: 'Dobroe', 1068787: 'Mescherskoe', 1702113: 'Moskovskoe', 1507893: 'Lapaevka', 1124119: 'Olekma', 1008761: 'Shamonino', 1509933: 'Zachepilovka', 1034579: 'Vyazma', 1094527: 'Churakaevo', 4678074: 'Metepec', 1101417: 'Malyshevo', 1950476: 'Tarquinia', 1502035: 'Sokol', 1075577: 'Krupp', 1598: 'Shiroky', 1953004: '?', 5427929: 'Kalininskoe', 1953939: '?', 1044128: 'Otradny', 1007452: 'Novokabanovo', 1509362: 'Nikolaevka-Novorossiyskaya', 1015081: 'Solodcha', 1915662: 'Bülach', 1907188: '?', 1113920: 'Grebenskaya', 5117080: 'Forks', 1500310: 'Listvinnoe', 3997885: 'Port-Vila', 1509280: 'Novogradkovka', 1912999: '?', 1068339: 'Gorodische', 21165: '?', 1508295: 'Voroblyachin', 1508324: 'Nemirov', 1967310: '?', 1084438: 'Baranovka', 1156104: 'Pionersky', 1600063: 'Sporovo', 1954163: 'Argel', 1101307: 'Volodarka', 1021744: 'Sluda', 1021603: 'Zarechye', 1112518: 'Cheremshanka', 1040937: 'Grazhdansky', 1956894: '?', 1500767: 'Brailov', 1513472: 'Staraya Ushitsa', 1146788: 'Komsomolsky', 1909583: 'Bzhni', 1508952: 'Udobnoe', 1957044: '?', 1136036: 'Lebyazhye', 1134611: 'Karaksha', 11748: 'Kuimikha', 1513618: 'Gannopol', 1083592: 'Grazhdansky', 1107550: 'Plekhanovo', 1091612: 'Tischenskoe', 1058808: 'Dmitrievsky', 1513117: 'Magdalinovka', 1500372: 'Orlovka', 1711006: 'Al-Khorazmy', 1949114: '?', 1801281: 'Staraya Bogdanovka', 1911089: '?', 1140119: 'Staroustye', 1511754: 'Kovalovka', 1947028: '?', 1135425: 'Abalakovo', 1009970: 'Dubyanka', 4230833: 'South Molton', 1060979: 'Edrovo', 1957092: '?', 1508963: 'Vygoda', 1913249: 'Kalnciems', 1057266: 'Usovo-Tupik', 1025693: 'Gapshima', 1511833: 'Varvarintsy', 1512980: 'Tavrichanka', 8358: 'Letnyaya Stavka', 17243: 'Ovoschi', 1602784: 'Prilepy', 1922186: '?', 4249798: 'Sundbyberg', 1150580: 'Komsomolsky', 1056820: 'Ptichnoe', 3478752: 'Trincomalee', 1504070: 'Vakulenchuk', 1500565: 'Olenevka', 1514127: 'Litvinets', 21650: 'Kiryat Haim', 1709106: 'Milford', 1702595: 'Saumalkol', 1946975: '?', 1945279: 'Burgos', 1902361: '?', 1094134: '№ 16', 3668104: 'Đà Lạt', 1015337: 'Verkhnepogromnoe', 1087620: 'Vasino', 1505507: 'Lisets', 5263706: 'Jockgrim', 1075633: 'Lyalyakhovka', 1902130: 'La Grange', 1949755: '?', 1012397: 'Yagodka', 4111113: 'Ouahigouya', 1153717: 'Borobul', 1952459: '?', 1514923: 'Tynitsa', 1939589: 'Port Coquitlam', 1933056: 'Los Montesinos', 1951990: 'Khashuri', 1951366: '?', 1135548: 'Oysky', 1737: '?', 5030935: 'Rolling Meadows', 1953943: '?', 1153806: 'Churapchinsky', 1957239: '?', 1708257: 'Alfred', 1503718: 'Pirozhki', 1940327: '?', 22362: 'Everett', 1513380: 'Chechelnik', 1121832: 'Aleysky', 1956101: 'Avshar', 1700915: 'Taldybulak', 1063175: 'Spirovo', 1940140: '?', 1041870: 'Olginskaya', 14561: 'Zhamansor', 1020563: 'Shuyskoe', 1110505: 'Pychas', 1802287: '?', 22069: '?', 21957: '?', 16325: 'Ramla', 1508983: 'Usatovo', 1904466: '?', 3828555: 'Goyang', 20795: 'Veselovka', 1130352: 'Gordino', 1511123: 'Chernechchina', 1950523: '?', 1033045: 'Myatlevo', 1015070: 'Nezhinsky', 16647: 'Belaya Gora', 1127219: 'Stary Dvor', 1940391: '?', 1514057: 'Bubnovskaya Slobodka', 1712757: 'Slidell', 1099940: 'Mermeriny', 1111683: 'Novocheremshansk', 1135931: 'Bolturino', 1030406: 'Dolakovo', 1153951: 'Val', 1914097: '?', 1136633: 'Pereyaslovka', 1947581: '?', 1004884: 'Klyuchi', 1957299: 'Linksmakalnis', 1507912: 'Rakovets', 1060423: 'Prirechny', 1600013: 'Molchad', 1036683: 'Tom', 1050112: 'Zavalnoe', 1010281: 'Biryuch (kolomytsevskoe S/p)', 1114166: 'Apnery', 1514475: 'Bogodukhovka', 1127487: 'Samara (selo)', 1954369: '?', 5067716: 'Upper Sandusky', 1944432: '?', 1507107: 'Belolutsk', 1949648: '?', 1015032: 'Gromoslavka', 1059320: 'Gorki', 1955555: '?', 1511892: 'Velikie Birki', 1961637: '?', 1147371: 'Donskoe', 1160222: 'Krasny Chikoy', 1938241: '?', 1061440: 'Polnovo', 1056644: 'Vasilchinovo', 1905886: 'Petrovka', 12711: 'Großenhain', 1954436: '?', 4232819: 'Oxted', 1600028: 'Gorodische', 10017: 'Itzehoe', 1956962: '?', 1801830: 'Monument', 1109164: 'Staraya Shudya', 4191276: 'Locri', 1945081: 'Flekke', 2827: 'Sionainn', 1138447: 'Talon', 1160745: 'Novokruchininsk', 1034551: 'Asanovo', 1067659: 'Vazerki', 5259538: 'Radeberg', 1512270: 'Slatino', 1600149: 'Radostovo', 1514893: 'Shirovtsy', 9573: '?', 3108552: 'Kananga', 1083624: 'Belozerki', 1603078: 'Lyubonichi', 1078641: 'Likhoy', 1083805: 'Mochaleevka', 1706818: '?', 1084271: 'Gorelovo', 1151551: 'Troitsa', 1514334: 'Maydanetskoe', 1907738: '?', 1933654: '?', 1021010: 'Vorobyevo', 1957418: '?', 1947783: '?', 1057540: 'Chistoe (gubinsky S/o)', 1123762: 'Gonzha', 1153617: 'Kolymskoe', 1925502: '?', 1704765: 'Korma', 1947746: 'Wisbech', 1159352: 'Vladivostoxkoe Shosse 40 Km', 1506902: 'Nescheretovo', 1966268: '?', 1509557: 'Ivanovo Selo', 1091504: 'Spasskoe', 1000852: 'Vypolzovo', 5010708: 'East Hampton', 1136641: 'Solovyevka', 1957437: '?', 1078878: 'Voloshino', 1950461: '?', 1514159: 'Petrakovka', 1097833: 'Dorokhovo', 1803726: 'Jefferson City', 20948: 'Fulton', 1065781: 'Zdorovetskie Vyselki', 1953617: '?', 1702395: 'Leninskoe', 1955647: '?', 1515852: 'Arnasay', 1142433: 'Letnyaya Baza', 1123367: 'Ovsyannikovo', 1037750: 'Talitsa (derevnya)', 13247: 'Glusha', 1957504: 'Katima Mulilo', 10691: 'Libezhevo', 1013673: 'Vlazovichi', 1104270: 'Strana Sovetov', 1000496: 'Solga', 1513831: 'Zarechanka', 1037444: 'Mikhaylovskoe', 5040798: 'Grosse Pointe', 1506008: 'Nalivaykovka', 1059578: 'Koshelevo', 1509099: 'Furmanovka', 1975201: '?', 1507049: 'Markovka', 1602917: 'Chernova', 1036624: 'Tsementnozavodsky', 1509239: 'Troitskoe', 5267101: 'Königsbrunn', 1957347: '?', 1012251: 'Khoromnoe', 1972003: '?', 1511218: 'Golubovka', 18372: 'Batama', 1079343: 'Nizhnedonskoy', 1059006: 'Serpukhov-11', 1516890: 'New London', 1518108: '?', 1510392: 'Smyga', 1955836: '?', 1939204: 'Serres', 1957578: '?', 1945393: '?', 1504585: 'Dneprovka', 1039625: 'Safonovo', 1510440: 'Udritsk', 1957583: 'Tomiño', 1118595: 'Prechistoe', 1001362: 'Bolshoy Dvor', 978: 'Yuzhny', 1139133: 'Zheleznodorozhny (sitnikovsky S/s)', 1500085: 'Muromskoe', 1954144: '?', 1940384: '?', 1123478: 'Ust-Porozikha', 1707266: 'Juva', 1930887: '?', 1502107: 'Pischa', 1600531: 'Rechitsa', 1904036: 'Puumala', 1508059: 'Belz', 1148537: 'Komarovo', 1923886: '?', 5266246: 'Bergneustadt', 1801612: 'Chumay', 1957618: '?', 1947128: '?', 947: '?', 1108360: 'Partizan', 1024668: 'Elan-Koleno', 3146244: 'Mardin', 1708969: '?', 1517791: '?', 1513067: 'Alexandrovka / Ptakhovka', 1508432: 'Murakhovka', 8463: 'Sherbrooke', 1506724: 'Priyutovka', 1903488: '?', 1943179: '?', 1509328: 'Stepovoe', 1902425: '?', 1130997: 'Semushino', 1923876: '?', 1504208: 'Nizhnie Vorota', 1129760: 'Tarasovo', 1600807: 'Osintorf', 1930632: '?', 1129983: 'Akimo-Annenka', 1151812: 'Oktyabrskaya', 1963161: '?', 1914155: 'Paytug', 1924375: '?', 1032646: 'Mirny', 1957655: '?', 1509254: 'Isaevo', 1509249: 'Andreevo-Ivanovka', 1111579: 'Novoselki', 1903545: '?', 1705272: 'An Nabaţīyah', 1914481: '?', 1141838: 'Shpilevo', 1158578: 'Pokrovskoe', 1939342: '?', 1500012: 'Privetnoe', 1918434: 'Barda', 21102: 'Prokhladny', 1904137: '?', 1507904: 'Obroshinoe', 1082054: 'Aglomazovo', 1502889: 'Scherbinovka', 2206933: 'Świebodzin', 1156060: 'Zavyalovskoe', 1508495: 'Voznesenskoe', 1950833: '?', 1917587: 'Āqābād', 1505466: 'Zabolotov', 1155334: 'Atig', 1136928: '?', 1712825: '?', 1114048: 'Pizipovo', 1903378: 'Khobi', 1005510: 'Brishtamak', 1005587: 'Usmangali', 1041917: 'Oazis', 1918962: '?', 1044251: 'Popovka (derevnya)', 1507209: 'Nizhnyaya Duvanka', 1085514: 'Ruzaevka', 1957780: 'Karlovac', 4187112: 'Jalón', 1937271: '?', 1924329: 'Plymouth', 1500812: 'Gorodok', 10671: 'Brookville', 1026105: 'Avadan', 1953535: '?', 1111575: 'Nikolskoe-Na-Cheremshane', 1008179: 'Lakly', -617: -617, 1946783: '?', 1704435: 'Spremberg', 1041982: 'Cherny Erik', 1500053: 'Tabachnoe', 2010: 'Norman', 1149131: 'Kharino', 1470: 'Thunder Bay', 4548754: 'Castel Goffredo', 1509015: 'Velikoploskoe', 1955127: '?', 1936102: '?', 5423644: 'Gindeshty', 1050253: 'Krivopolyanye', 1939475: '?', 1514998: 'Zhuravka', 1501649: 'Poromov', 1945875: 'Opava', 1505739: 'Krasilovka', 1008158: 'Arkaulovo', 1059659: 'Tempy', 1032877: 'Lyubitsy', 1000510: 'Tegro-Ozero', 1002400: 'Burachikha', 1137564: 'Lesnikovo', 1138050: 'Kosolapovo', 1932271: '?', 1003339: 'Loyga', 1025760: 'Karata', 2552: 'Raduzhnoe / Kommunarovka', 1935801: '?', 20922: 'Kostobobrov', 1941573: '?', 4553443: 'Berat', 1953845: '?', 14184: 'Kfar Blum', 1065632: 'Grozny (poselok)', 1058993: 'Respublika', 1502464: 'Osadchee', 1963238: '?', 1920996: '?', 1917174: '?', 1101249: 'Tolmachi', 1957325: '?', 1909300: 'Adamuz', 1954187: '?', 8406: '?', 1511484: 'Malaya Luka', 1505329: 'Sheshory', 1712103: '?', 1602034: 'Porechye', 1955508: 'Geesthacht', 1925850: '?', 1703312: 'Cremona', 1966107: '?', 1948299: '?', 1129244: 'Metallploschadka', 1923539: '?', 1039280: 'Alexandrovskoe', 1135155: 'Krasnogoryevsky', 17978: 'Ust-Volchikha', 1135159: 'Manzya', 1909554: 'New Wilmington', 1700051: 'Petrovka', 19550: 'Petropavlovka 1', 1903973: 'Scarborough', 1702535: 'Nadarovka', 1700430: 'Shubarshi', 1518894: 'Cape May', 1705823: 'Vertelishki', 1601895: 'Zhitomlya', 1517563: 'Rockford', 1147403: 'Pushkinsky', 1145924: 'Solovetskoe', 1154603: 'Sarapulka', 1156831: 'Bogashevo', 1155678: 'Bayanovka', 1097065: 'Antonovka', 1130000: 'Kubitet', 1091626: 'Vinodelnensky', 1091465: 'Derbetovka', 1500215: 'Naydenovka', 22033: '?', 5217201: 'Sète', 1947287: '?', 20378: 'Amguema', 1158549: 'Ievlevo', 1091763: 'Pregradnoe', 1144938: 'Blyudchanskoe', 1053257: 'Tarkhany', 1501321: 'Tomashpol', 1123850: 'Varvarovka', 1010738: 'Ladomirovka', 1160460: 'Novopavlovka', 1144533: 'Sadovy', 4545777: 'Ischia', 1705474: 'Northfield', 1112726: 'Bogdanovskoe', 1011375: 'Lopush', 1085077: 'Kamensky', 1508965: 'Dachnoe', 1511209: 'Smeloe', 3051734: 'Ḑubā', 1509857: 'Orekhovka', 1505690: 'Mirnoe', 3502209: 'Manali', 1161150: 'Lentyevo', 1111200: 'Kalda', 1715152: '?', 1958234: 'Aurich', 1014620: 'Kuptsovo', 1005151: 'Stary Sibay', 1948597: '?', 1124682: 'Staroe-Tataurovo', 1700333: 'Ushkatty', 1709977: 'Cedarville', 1939375: '?', 1149093: 'Verkhnyaya Staritsa', 1077884: 'Koxovy', 1112313: 'Miassky', 1153108: 'Knorring', 1140182: 'Turtapka', 1900221: 'Kanot', 1112581: 'Yuzhny', 18106: 'Voznesenskoe', 1701755: 'Torangylyk', 1025222: 'Platava', 18252: 'Novokizhinginsk', 1957895: '?', 1153972: 'Moskalvo', 4635906: 'Selfoss', 1702832: 'Dokuchaevo', 10972: 'Dolina', 1135082: 'Alexandrovka', 1509713: 'Svechkarevo', 1502254: 'Shevchenkovskoe / Ordzhonikidze', 1958040: '?', 1083725: 'Dmitrievka', 1030482: 'Kotlyarevskaya', 5019289: 'Herndon Heights', 1085244: 'Zorkino', 1083950: 'Alexandrovka', 1517507: '?', 1500458: 'Kolchugino', 1093132: 'Golitsino', 1056850: 'Selyatino', 1137475: 'Chashi', 1056052: 'Astapovo', 1050105: 'Grachevka', 1123472: 'Samsonovo', 1506730: 'Chervonaya Kamenka', 1953862: 'Alberta', 1949927: '?', 1915569: '?', 2722640: 'Machakos', 1511805: 'Toki', 1939853: '?', 1927772: '?', 1958027: '?', 1508558: 'Vossiatskoe', 1122637: 'Novye Zori', 1513978: 'Pogreby', 1506295: 'Kapustintsy', 1929423: '?', 1930353: '?', 1958126: '?', 1501847: 'Sadov', 1135627: 'Sibir (poselok)', 1506117: 'Volchkov', 1152815: 'Preobrazhenka', 1970207: '?', 9306: 'Perovo', 5266874: 'Laupheim', 1129741: 'Okunevo', 1090897: 'Dukhovschina', 1108706: 'Golovenkovsky', 1958496: 'Langedijk', 7583: 'Alkmaar', 1038978: 'Totomitsa', 1003479: '?', 17968: 'Erdnievsky', 1129295: 'Bannovo', 1939655: 'Encino', 1131776: 'Bereznik (derevnya)', 1904428: 'Pescara', 1706797: 'Chieti', 1122586: 'Grishkovka', 1701147: 'Severnoe', 1148556: 'Karyer Izvestnyak', 1943807: '?', 1081916: 'Borets', 22466: 'Partizanka', 1015069: 'Mikhaylovka', 1516207: '?', 5259525: 'Freital', 1925290: '?', 1949785: '?', 1095393: 'Aldermysh', 13286: 'Glukhovka', 1124721: 'Zhargalanta', 20363: 'Izborsk', 1921057: '?', 1945131: '?', 1001007: 'Vazhsky', 1136134: 'Cheremshanka', 1127619: 'Kuvatka', 1913880: '?', 1702633: 'Tokushi', 1022382: 'Dolotskoe', 1942828: '?', 1503256: 'Grabovo', 1973467: '?', 1043457: 'Cheryomushki', 1955216: '?', 1957316: '?', 1158283: 'Moskovsky', 1156077: 'Kuznetsovsky', 22292: 'Berdyaush', 1041594: 'Bely', 1903764: '?', 1100475: 'Staroe Melkovo', 21272: 'Turets-Boyary', 1122919: 'Selektsionnoe', 1907854: '?', 1713039: '?', 1913000: '?', 1515599: 'Chichester', 1700261: 'Kamenka', 1927819: '?', 1156672: 'Mogochino', 1136101: 'Mozharka', 18295: 'Juuka', 1704482: '?', 6462: 'Dutovo', 1036632: 'Dutovo', 4095475: 'Ibadan', 1943996: '?', 1705370: '?', 1714939: '?', 1131188: 'Bogorodskaya', 7645: 'Soest', 1512022: 'Petrovskoe', 1023887: 'Svkh Pugachevsky Tsentralnaya Usadba', 16924: '?', 1956641: '?', 1106054: 'Gati', 1154449: 'Ufimsky', 1095132: 'Tsipya', 1801924: '?', 1502314: 'Priorelsky / Proletarskoe', 1001414: 'Klimovskaya', 1154612: 'Bayny', 1112089: 'Tetyushskoe', 1707313: '?', 2608: 'Kelmė', 3478238: 'Unawatuna', 2203089: 'Galle', 13386: 'Grigiškis', 1055916: 'Lugovaya', 1972088: '?', 1518406: 'Fgura', 1935479: '?', 1700524: 'Molaly', 1517315: 'Porozovo', 1148300: 'Voykovsky', 1505738: 'Knyazhichi', 1146432: 'Pologrudovo', 1803633: 'Jackson', 1515379: 'Zamglay', 1059322: 'Gorodische', 1956449: '?', 1958407: '?', 1938946: '?', 1507149: 'Mikhaylovka', 1158012: 'Shabanovo', 1029033: 'Kurmysh', 1957520: '?', 1515970: 'Agawam', 11170: 'Petrovsky', 1109921: 'Lipovaya Roscha', 1975021: '?', 1705116: 'Remezy', 4529223: 'Vestby', 1962234: 'Birštonas', 1925400: '?', 1052270: 'Bolshoe Ignatovo', 1065735: 'Shakhovo', 1502337: 'Novopavlovka', 1705603: 'Rajkot', 1061605: 'Ruchi', 1008973: 'Petropavlovsky', 1160560: 'Tungokochen', 1515856: 'Benevento', 1707331: 'Takoma Park', 1904772: '?', 1502828: 'Grafskoe / Komsomolsky', 1929677: '?', 1132319: 'Shevyrtalovo', 1701874: 'Rodnikovskoe', 5266098: 'Laatzen', 1601886: 'Odelsk', 1914490: '?', 1503644: 'Mirolyubov / Zhovtnevoe', 1510565: 'Mokvin', 1113934: 'Chervlennaya-Uzlovaya', 1712974: '?', 10182: '?', 1966583: 'Koszalin', 19707: 'Shurchi', 1131889: 'Vetoshkino', 1131891: 'Votskoe', 1922683: '?', 1500326: 'Uvarovka', 1906811: '?', 1113299: 'Poletaevo 1-E', 1600420: 'Khotislav', 18814: '?', 17762: 'Somerset', 1025586: 'Ustye', 1052724: 'Novaya Tolkovka', 1955955: '?', 1513062: 'Mikhaylovka', 1504662: 'Razumovka', 1115343: 'Yrashpulykh', 1923555: '?', 1014488: 'Ust Gryaznukha', 8409: 'Shalakusha', 1947525: '?', 1601850: 'Shilovichi', 1952871: '?', 1965691: '?', 5693: 'Sochikhino', 1955821: '?', 1035439: 'Krasny Kurgan', 1055054: 'Pokrovskoe', 1506933: 'Vlasovka', 1919807: 'Salem', 1007533: 'Maxyutovo', 1974840: 'Gijón', 1927334: '?', 20054: '?', 5054805: 'Edison', 1083832: 'Srednee Averkino', 1506217: 'Kislovka', 1914936: 'Wheaton', 1110168: 'Kizner Sadoogorod Yubileyny ', 1113706: 'Pravoberezhnoe', 1061640: 'Artem', 1112433: 'Leyptsig', 1070324: 'Gorodok (sorokinskaya Volost)', 5266794: 'Emmendingen', 1083358: 'Krotovka', 1703184: 'Poughkeepsie', 1515933: 'Gabrovo', 1007348: 'Starobabichevo', 1712937: '?', 1918642: '?', 5030069: 'Lombard', 15528: 'Glen Ellen', 1122848: 'Romanovo', 1122835: 'Gilev Log', 1500355: 'Susanino', 1153834: 'Markha', 1909403: 'Mount Pleasant', 1083890: 'Vorotnee', 1123169: 'Ekaterininskoe', 1091803: 'Russkoe', 1157830: 'Prokutkino', 1705164: 'Palmyra', 1079815: 'Skosyrskaya', 1512851: 'Novoalexeevka', 1708736: '?', 1517474: 'Nikolaevka', 5266451: 'Dreieich', 1512235: 'Bogdanovskoe / Zhovtnevoe', 1013976: 'Liski', 1152573: 'Antipino', 1107105: 'Gvardeysky', 1705139: '?', 1902782: '?', 14915: '?', 1004758: 'Tavrichanka', 1957654: '?', 1150964: 'Zuevsky', 1027310: 'Vanino', 1513268: 'Nemirintsy', 1513260: 'Kremennaya', 1513258: 'Kamenka', 1135335: 'Areyskoe', 1701358: 'Bauyrzhan Momyshuly', 1512780: 'Konstantinovka', 5267068: 'Bad Brückenau', 1500963: 'Lukashovka', 1156096: 'Osinniki', 5266774: 'Calw', 1504374: 'Polyana', 3960131: 'Bulgan', 16364: 'Tsybanobalka', 5022741: 'Wareham', 1960370: 'Thiruvananthapuram (Trivandrum)', 1916318: '?', 21862: 'Zashirye', 1511221: 'Znob-Novgorodskoe', 19864: 'Kurkovitsy', 3959951: 'Züünbayan', 1129079: 'Bekovo', 1709177: 'Aiken', 1127454: 'Kuldur', 1127476: 'Blagoslovennoe', 4149: '?', 1112819: 'Lazurny', 1503081: 'Marinka', 1506490: 'Adzhamka', 1515235: 'Vertievka', 1146914: 'Alexeevka', 1602647: 'Budslav', 1907345: "Cortina d'Ampezzo", 1927023: '?', 18001: 'Borovlyanskoe', 1936363: '?', 1513698: 'Samchiki', 1936854: 'Harzgerode', 1093036: 'Raksha', 1091409: 'Vsadnik', 1702666: 'Toxan Bi (zapadnoe)', 3068502: 'Hamadān', 1920972: 'Mâcon', 1109441: 'Pervomaysky', 1152746: 'Serzhantovo', 1015265: 'Gorbatovsky', 1506265: 'Veprik', 1702735: 'Sokolovka', 14887: 'Tsagan-Chelutay', 1152635: 'Maykor', 1122969: 'Sovetskoe', 1001199: 'Kraskovo', 1124767: 'Dalakhay', 1112383: 'Kalininsky', 1904421: 'Gräfenhainichen', 1085143: 'Bolshaya Sakma', 1903980: '?', 1500400: 'Ilinka', 1935836: 'Esenguly', 1960685: '?', 1514093: 'Shabelniki', 1052655: 'Nagaevo', 1096609: 'Starosheshminsk', 1507335: 'Petrovskoe', 1915520: '?', 6241: 'Ensky', 4978265: 'West Wildwood', 4978285: 'Wildwood Crest', 1123485: 'Estonia', 1014296: 'Alexandrovka', 1043914: 'Rudavsky', 15125: 'Oek', 1014455: 'Guselka', 1705911: '?', 13171: 'Gultyai', 1138225: 'Kodskoe', 1031087: 'Pereslavskoe', 1088246: 'Kardymovo', 6291: 'Ryabovo', 1113495: 'Oktyabrsky', 1912020: '?', 1914917: '?', 1952893: '?', 1505637: 'Terezinoe', 1007997: 'Bogdanovo', 1021457: 'Ploskovo', 1045267: 'Bolshoy Dvor (bolshedvorskoe S/p)', 1093693: 'Novositovka', 17221: 'Masalsky', 1018423: 'Terentyevskoe', 1504631: 'Uspenovka', 1601825: 'Vereyki', 1931245: 'Yangibazar (yukarychirchixky Rayon)', 1964575: '?', 1007335: 'Savaleevo', 1509892: 'Velikie Sorochintsy', 1509997: 'Novye Martinovichi', 5331796: 'Revúca', 1044376: 'Raskhovets', 1943808: '?', 1093777: 'Novikovo', 1933592: '?', 1947050: '?', 1710263: 'Kirsova', 1147366: 'Voznesenka', 1128812: 'Yugolok', 21183: 'Mikhaylovka', 1070893: 'Pideli', 1129492: 'Ashmarino', 7013: 'Bestyakh', 1518337: 'Beverly', 22045: 'Shirokoe', 1501515: 'Khomenki', 1601884: 'Obukhovo', 5266252: 'Wipperfürth', 1517783: 'Michurinskoe', 1952524: '?', 21361: 'Kazatskoe', 1078479: 'Uryvsky', 1148963: 'Kungur', 1901576: 'Kretinga', 1030498: 'Khasanya', 1112812: 'Kanashevo', 1518030: 'Englewood', 1600143: 'Novaya Popina', 1095341: 'Makulovo', 1973829: '?', 16969: 'Tuxa', 1956268: '?', 1143617: 'Acha', 5124852: 'Esterhazy', 1514351: 'Gorodetskoe', 1514591: 'Khryatskaya', 1046172: 'Novosergievka', 1043163: 'Kashara', 1506692: 'Rodnikovka', 1923561: '?', 1093122: 'Shapkino', 1949795: '?', 1088064: 'Staroe Mutische', 1918862: '?', 1926237: 'Videbæk', 1112742: 'Kizilskoe', 1043785: 'Mozdok (khutor)', 1602933: 'Vishov', 1917837: '?', 1507759: 'Drogovizh', 1708546: '?', 1004129: 'Grachi', 1903023: 'Arad', 1920472: '?', 1514248: 'Rogi', 1149930: 'Yuxeevo', 1026255: 'Bolshaya Zadoevka', 1954757: '?', 1057400: 'Vereya (vereysky S/o)', 1915613: '?', 4427: '?', 1949365: '?', 1506238: 'Vysokoe', 1505345: 'Krasnaya', 5460273: 'Bakharovichi', 1113308: 'Sakkulovo', 1958512: '?', 1513394: 'Kunev', 1712177: '?', 1139920: 'Ilino', 1903610: '?', 3906956: 'Ban Phônsavan', 10942: 'Shumyachi', 1949828: '?', 1014626: 'Mokraya Olkhovka', 1046898: '?', 1931514: '?', 1042330: 'Ubezhenskaya', 1041177: 'Kubanskaya Step', 5266730: 'Bretten', 5016153: 'Tysons Corner', 5009135: 'Bluemont', 1905199: '?', 14088: 'Dylym', 1502839: 'Olginka', 1137412: 'Dolgovskoe', 1953898: '?', 1126925: 'Vyatkino', 1922823: '?', 1600094: 'Kleyniki', 1510279: 'Maly Zheludsk', 1517108: '?', 4621616: 'São Luís', 1912598: '?', 1713506: '?', 1942998: 'Bad Bederkesa', 1000566: 'Avnyuga', 1924887: 'Konin', 3203642: 'Muyinga', 1094380: 'Krivoozerki', 1008383: 'Roschinsky', 1952927: 'Agsu', 1500322: 'Pshenichnoe', 1067897: 'Chernoyar', 1056751: 'Martemyanovo', 2300547: 'Spartak', 1500200: 'Klimovo', 1939047: '?', 1944769: '?', 1715462: '?', 1918189: '?', 1708354: 'Siracusa', 1153311: 'Kamenka', 4377: 'Arshan Zelmen', 1958638: '?', 1114665: 'Novye Atai', 1505741: 'Litki', 4544752: '?', 1955271: '?', 1602770: 'Alesino', 1925758: '?', 1062958: '?', 1131165: 'Rybnaya Vataga', 1802285: 'Papenburg', 1601492: 'Yurovichi', 1109353: 'Kakmozh', 1014516: 'Mikhaylovka', 1704163: 'Puebla', 1903929: 'McAllen', 5261813: 'Ostbevern', 4341896: 'Peitz', 4079: 'Sherlovaya', 1802326: '?', 1942280: '?', 4889168: 'Guanajuato', 1964786: 'Villarreal', 1506949: 'Novoalexandrovka', 1514900: 'Bakhmach Selo', 1602894: 'Khotlyany', 1518835: '?', 1602869: 'Naliboki', 1505302: 'Kuty', 5023501: '?', 1507268: 'Lotikovo', 1940795: '?', 1968929: '?', 1150924: 'Sherya', 1959089: '?', 1123020: 'Neninka', 1508173: 'Terlo', 1519089: 'Golshany', 1934346: '?', 1963200: '?', 1511893: 'Velikie Gai', 1955290: '?', 1904742: '?', 1710645: '?', 1030880: 'Marshalskoe', 1706292: 'Kara-Kuldzha', 22451: '?', 5267797: 'Leichlingen (Rheinland)', 5030459: 'North Chicago', 1121994: 'Melnikovka', 1122008: 'Shimolino', 4978008: 'Pleasantville', 4977837: 'Millville', 3301656: 'Tutin', 1156889: 'Molodezhny', 5264833: 'Karlsfeld', 1131044: 'Kokshaga', 1144558: 'Vagaytsevo', 1104372: 'Bolshoe Svyattsovo', 1159773: 'Nazarovo', 1123330: 'Zyatkova Rechka', 22630: 'Ulken Agash', 1014054: 'Krasny Oktyabr', 1518255: 'Yanvartsevo', 1959182: '?', 1914567: 'Nemenčinė', 1508103: 'Selets', 1137875: 'Rassvet', 1600910: 'Andreevschina', 1128236: 'Listvyanka', 1030530: 'Proletarskoe', 1714894: 'Kosovo Polje', 1148647: 'Bateriki', 1082841: 'Inyakino', 1082915: 'Tyrnovo', 1708108: 'Bērziņi', 1959170: '?', 4509051: 'Vilagarcía de Arousa', 1123809: 'Razdolnoe', 5347596: 'Weiden', 1037182: 'Madmas', 1801290: 'Starye Dubossary', 1502801: 'Razdolnoe', 1957052: '?', 1904609: '?', 1071958: 'Ust-Dolyssy', 1501862: 'Velikaya Glusha', 1159062: 'Krasitskoe', 1016542: 'Pokrovskoe', 1137919: 'Petukhovo (selo)', 1503336: 'Dubrovka', 20046: 'Zaporozhskoe', 1508216: 'Lisovichi', 1508187: 'Banya-Lisovetskaya', 1138068: 'Polovinnoe', 1058840: 'Moskovskaya Selektsionnaya Stantsia', 1155241: 'Natalinsk', 15550: 'Kunbatar', 1129353: 'Krasnoyarka (derevnya)', 1956632: 'Arkivan', 1137085: 'Ilichevo', 1136049: 'Tubinsk', 1124316: 'Egita', 1924841: '?', 11534: 'Klepka', 1051731: 'Joshkar Pamash', 1154003: 'Trudovoe', 4043420: 'Bombarral', 1601630: 'Novoselki', 1005123: 'Komsomolskogo Otdelenia', 1092392: 'Znamenka 2-Ya', 1958327: '?', 2203357: '?', 2204879: '?', 1133987: 'Mikhaylovskoe', 1506605: 'Sverdlikovo', 1511401: 'Lanovtsy', 21557: 'Tarasovka', 1944901: '?', 1901353: '?', 1013113: 'Milech', 20591: 'Albufeira', 1510402: 'Berezhki', 1035394: 'Marukha', 5230381: 'Belley', 1500423: 'Suvorovskoe', 1063833: 'Syroezhino', 1958992: '?', 1040794: 'Khadyzhenskaya', 1601853: 'Konvelishki', 1084002: 'Balasheyka', 5430762: 'Kerbulak', 1506815: 'Alexandrovka', 1008458: 'Kurdym', 1500295: 'Akimovka', 1024479: 'Kolomytsevo', 1083323: 'Novoe Usmanovo', 1131981: 'Verkhne-Lalye', 2207483: 'Charlotte Amalie', 1113922: 'Karagalinskaya', 1957524: '?', 1715693: 'Pembroke', 1141172: 'Prudy', 14944: 'Primorskoe', 1702542: 'Kozyketken (ilichevka)', 1500: 'Ovgort', 1958308: '?', 1003244: 'Alferovskaya', 1965270: '?', 1959173: '?', 3539: 'Kholmy', 4945850: 'Arizona', 21354: 'Trofa', 1153771: 'Ust-Mil', 1079702: 'Gorny', 1085412: 'Starye Ozinki', 1123690: 'Ogoron', 1959378: '?', 1955128: '?', 1509293: 'Kotlovina', 1014183: 'Belye Prudy', 1506583: 'Petrokorbovka', 1949514: '?', 1959376: '?', 1113632: 'Tarasovka', 1035110: 'Ferzikovo', 335: 'Urusovo', 1903515: '?', 21831: '?', 1518512: 'Joroinen', 1516292: 'Danbury', 1008889: 'Deniskino', 1968560: 'Salford', 1518940: 'Hereford', 1081371: 'Malinischi', 1508217: 'Lisyatichi', 1502329: 'Veseloe', 1509001: 'Karakurt / Zhovtnevoe', 1032224: 'Vysokaya Gora', 1500698: 'Komarov', 1510675: 'Teslugov', 1954402: '?', 1925954: '?', 1155395: 'Is', 1078781: 'Cheremukhi', 1093908: 'Novaya Lyada', 1801525: 'Khyzhdieny', 22325: 'Bolnisi', 5089300: 'Alameda', 1945433: '?', 1150529: 'Ergach', 1950074: '?', 5013849: 'North Virginia Beach', 1508733: 'Parutino', 1149693: 'Yuzhny Kospashsky', 1505514: 'Poberezhye', 1152191: 'Verkhnyaya Kolva', 1925120: '?', 3136272: 'Nablus', 19560: 'Permas', 1803295: 'Järvakandi (yarvakandi)', 1904548: '?', -3827: -3827, 1700496: 'Novogodnee', 1110001: 'Alexandrovo', 1956099: 'Orre', 4230392: 'Stratford-upon-Avon', 1958454: '?', 1711787: '?', 1113315: 'Solnechny', 1950193: '?', 1916547: 'Kolkhozabad', 1114313: 'Shirtany', 1500985: 'Bruslinov', 1910188: '?', 4550763: 'Bellagio', 4640070: 'Paysandú', 5067909: 'West Akron', 1517840: 'Sinnamary', 1500495: 'Urozhaynoe', 1060155: 'Pyankino', 1711650: 'Rolle', 11498: 'Cullera', 1962225: 'Carcaixent', 1938550: '?', 1511102: 'Grun', 1958338: '?', 1958506: '?', 1152104: 'Prikamsky', 1039766: 'Vasilyevo', 4547526: 'Corinaldo', 1503088: 'Staromikhaylovka', 1008185: 'Mursalimkino', 1059124: 'Kryukovo', 1947192: '?', 5266348: 'Bad Lippspringe', 1042392: 'Bobrava', 1912787: '?', 1142889: 'Vedenino', 1142886: 'Bolshoy Tersen', 5063228: 'West Bloomfield', 1905071: '?', 1078344: 'Plotnikov', 1505432: 'Lipovitsa', 1153153: 'Vozdvizhenskaya', 1036850: 'Ozerny', 22579: 'Lindenhurst', 1049930: 'Lamskoe', 1712102: '?', 11829: 'Caldas da Rainha', 1501489: 'Kalinovka', 1602631: 'Krasnoe', 1925184: '?', 1961679: '?', 1907767: '?', 18172: 'Kanukovo', 3159953: '?', 1705764: '?', 1054240: 'Khrabrovo', 1968466: '?', 1714606: 'Cambridge', 1505053: 'Galich', 21566: 'Cleveland', 1147903: 'Miroshkino', 1146763: 'Stepanovka 2-Ya', 1518205: 'Dubrovnik', 1913980: '?', 1077311: 'Tomsino', 1161100: 'Nes', 1935953: '?', 1922144: '?', 1959595: '?', 4182388: 'Bou Regaa', 1921174: '?', 1515976: '?', 1929862: 'Bridgewater', 1008224: 'Aydarali', 18608: 'Serakhs', 1902099: '?', 1921340: '?', 1124438: 'Bryansk (selo)', 1145671: 'Moskalensky', 1951706: 'Uelzen', 5062978: 'Valley Cottage', 1109255: 'Kozhilo', 4367647: 'Herbolzheim (Emmendingen)', 1802125: '?', 5329353: '?', 1037069: 'Vazhgort', 1707070: 'Lagos', 1017329: 'Beketovskaya', 1096017: 'Lubyany', 1952660: '?', 1512649: 'Ponomarenki', 1709431: 'Beckley', 1155227: 'Klyuchiki', 1026521: 'Tagirkent', 1961075: '?', 1944517: '?', 1933824: '?', 1911349: 'Aurillac', 18032: 'Volgodonskoy', 1055043: 'Novopetrovskoe', 1502726: 'Kuteynikovo', 1948091: 'Vrindavan', 1001340: 'Shelokhovskaya', 1512122: 'Borovaya', 1024094: 'Olkhovatka', 1952880: '?', 5266261: 'Lohmar', 1713158: '?', 1122591: 'Kusak', 4522166: 'Figueres', 10557: '?', 1709053: 'Mława', 1940134: '?', 12544: 'Fort Smith', 1902716: 'Russellville', 1902549: 'Freeport District', 1518213: 'Middletown', 1934594: '?', 1904971: '?', 1079516: 'Boldyrevka', 1032077: 'Khulkhuta', 1518214: 'Etulia', 3167672: 'Jijiga', 1705923: '?', 1965332: '?', 1941585: 'Wayne', 12897: 'Morristown', 1081148: 'Poyarkovo', 1963782: '?', 1601938: 'Leonovichi', 1920291: 'Marília', 22134: 'Melaka', 1106365: 'Voskresenskoe', 1951545: 'Brigantine', 1903071: 'Egg Harbor City', 21972: 'Cairns', 1124413: 'Orongoy (ulus)', 1501876: 'Malaya Glusha', 1518014: '?', 1136163: 'Kolbinsky', 5428518: 'Molodezhnoe', 1702753: 'Tamanskoe', 1975624: 'Saint Cloud', 1936285: '?', 1906608: '?', 1936667: '?', 1506900: 'Lozno-Alexandrovka', 1065261: 'Znamenskoe', 5095110: 'Sunland', 1105179: 'Eremkovo', 1146920: 'Bugulma', 3970007: 'Chongjin', 2526: 'Lysogorskaya', 1024171: 'Vorobyevka', 1051966: 'Semenovka', 1959939: '?', 1954064: '?', 1501169: 'Chovnovitsa', 1518739: 'Saryshagan', 1104475: 'Zeleny', 1701283: 'Naualy', 1124479: 'Sukhaya', 1153631: 'Maar', 1159572: 'Kobyakovo', 1510525: 'Novy Korets', 1513306: 'Korzhovtsy', 1037143: '?', 5479349: 'Ust-Usa', 1709456: 'Belmont', 1926319: '?', 1512971: 'Lyubimovka', 1800855: 'Nezavertaylovka', 1950045: '?', 1923730: '?', 1502868: 'Truzhenka', 1803672: '?', 1157115: 'Tselinnoe', 1154696: 'Kedrovoe', 1083092: 'Krasnooktyabrsky', 1128628: 'Ikey', 1507924: 'Chizhikov', 1153098: 'Vishnevka', 1510766: 'Znosichi', 1069226: 'Kryzhovo', 1937239: '?', 1156948: 'Tomskoe', 1927425: '?', 1150427: 'Oshya', 1911628: 'Blue Lagoon', 1087120: 'Kotikovo', 1132655: 'Kotiki', 1161278: 'Alexandrovka', 1091843: 'Vozrozhdenie', 1063376: 'Trupekhino', 1704662: 'Krasnoe', 1024085: 'Derezovka', 14471: '?', 1904870: 'Port-Ilich', 4256602: 'Nora', 1154283: 'Berezniki', 1004909: 'Starye Kazanchi', 1934466: '?', 1160979: 'Chapaevsk', 5332772: 'Uzunlarovo', 18165: 'Hampton', 1041944: 'Galitsyn', 1096021: 'Mamashir', 2271: 'Polunochnoe', 1098695: 'Afimino', 1109804: 'Yagul', 1099105: 'Ozyory', 1502992: 'Nikolaevka', 1962797: '?', 1702404: '?', 1107898: 'Gorbachevo', 1708268: 'Mudanjiang', 1510387: 'Privolnoe', 1015191: 'Elton', 14900: 'Lyubnitsa', 1110989: 'Gopgurt', 1602802: 'Gavrilchitsy', 1925292: '?', 1904525: 'Marsá al `Alam', 5327008: 'El Gouna', 3657824: 'Phú Quốc', 1062348: 'Megletsy', 1159857: 'Palyanovo', 1058659: 'Mostovik', 1021792: 'Yugra', 2203403: '?', 1918499: 'Pemberton', 1918448: '?', 1700094: 'Ergolka', 1153056: 'Zharikovo', 1513966: 'Zolotonoshka', 1071155: 'Pukhnovo', 1114760: 'Sutchevo', 1049945: 'Mtsenka', 1942469: '?', 1915368: '?', 1027303: 'Bazhenovo', 1902953: '?', 5261235: 'Warmsen', 1119863: 'Durdino', 1503724: 'Chopovichi', 1948898: '?', 1502823: 'Zlatoustovka', 1602562: 'Tal', 1111572: 'Mullovskaya Fabrika ', 1111571: 'Mullovka', 15380: 'Molchanovo', 1942428: '?', 1940679: 'Ancaster', 1113447: 'Rozhdestvenka', 1004802: 'Valentinovka', 1936717: '?', 3998465: 'Kérémbitia', 3317348: 'Dangamvura', 1121958: 'Lesnoe', 1111113: 'Sada', 1149948: 'Verkh-Yazva', 1113066: 'Ostrolensky', 1942174: '?', 1118508: 'Koza', 1510744: 'Kisorichi', 1094342: 'Tumutuk', 1087274: 'Glinka', 1486: 'Khotiml', 1934814: '?', 1922730: 'Cupar', 1092138: 'Verkhnerusskoe', 1084987: 'Znamensky', 1038264: 'Chmutovo', 1952771: 'Oaxaca', 16865: 'Taldan', 1957001: '?', 1159054: 'Dormidontovka', 1000438: 'Pasva', 5265216: 'Bruckberg (Niederbayern)', 5261784: 'Gelsenkirchen', 3786495: 'Xingtai', 4401960: 'Tours', 2722475: 'Balıkesir', 1035233: 'Belyaevo', 1705712: 'Ratzeburg', 1007815: 'Nugush', 1500272: 'Kalinovka', 1080697: 'Oskino', 1945431: '?', 1026207: 'Bashlykent', 1514332: 'Lesovoe', 1948863: '?', 1912897: '?', 4540689: 'San Giorgio di Nogaro', 1057908: 'Zverosovkhoz', 1940871: '?', 1516114: '?', 1121854: 'Mokhovskoe', 1501731: 'Palchye', 1939890: '?', 1122667: 'Zyatkovo', 1055708: 'Textilschik', 1501762: 'Lyublinets', 1127507: 'Partizanskoe', 4007035: 'Back Plains', 1153960: 'Nysh', 1922833: '?', 1085614: 'Zhestyanka', 1902217: 'Largo', 4537798: 'Villadossola', 4537941: 'Vico Canavese', 1502786: 'Zeleny Gai', 1023799: 'Charomskoe', 1129693: 'Tikhonovka Karagaylinskaya', 1512086: 'Uplatnoe', 1059253: 'Shelepanovo', 1057481: 'Novoe (novinsky S/o)', 1512772: 'Shirokaya Balka', 1157716: 'Bobylevo', 1924240: '?', 1013242: 'Voronovo', 1709318: 'Anykščiai', 1959465: '?', 1123362: 'Druzhba', 1702789: 'Mironovka', 1959557: '?', 1158037: 'Maslyansky', 1703032: 'Sanatory Saryagash', 1053550: 'Valuyki', 1947203: 'North Dartmouth', 7425: 'Starkville', 1706305: 'Braşov', 1909284: 'Cambridge', 1518569: 'Bratusheny', 1146411: 'Lozhnikovo', 2400594: 'Potskho', 1902931: 'Marden', 5267023: 'Lichtenfels', 1519142: 'Dezginzhya', 1705372: '?', 4696395: '?', 18750: 'Krasnye Barrikady', 1937077: 'Dumpiai', 1082129: 'Pichkiryaevo', 1929071: '?', 1960121: '?', 1715435: '?', 1517434: '?', 1108244: 'Tsentralny', 1515222: 'Sinyavka', 1909131: '?', 1518885: 'Malta', 1916491: '?', 1504528: 'Balki', 1122527: 'Georgievka', 18905: 'Sokolskoe', 1139603: 'Kazakovo', 1916845: '?', 1097496: 'Stary Karazerik', 1922316: 'Mārupe', 5266269: 'Bocholt', 1037041: 'Mitrofan-Dikost', 3960089: 'Saynshand', 1112172: 'Krestovo Gorodische', 1003359: 'Mirny', 1502825: 'Kalinino', 1057562: 'Bolshie Dvory', 1152853: 'Valentin', 5423718: 'Stavcheny', 1800577: 'Kozhushna', 1947813: 'Banka', 1704868: 'Farsund', 1905100: '?', 1959818: '?', 5501: 'Raduzhny', 1041981: 'Chernoerkovskaya', 4243957: 'Rorschach', 1802145: '?', 1065730: 'Fedotovo', 1079091: 'Staropetrovsky', 1518310: 'Järvenpää', 1931922: '?', 5798: 'Chirsky', 1041369: 'Kievskoe', 1904551: '?', 1956138: '?', 1517163: 'Kungsbacka', 1959374: '?', 5266271: 'Gescher', 1153878: 'Vzmorye', 1500314: 'Mikhaylovka', 1035820: 'Malinovaya Varakka', 1802345: '?', 9406: 'Argi-Pagi', 1518136: '?', 4977487: 'East Vineland', 1129217: 'Berezovo', 1123777: 'Ushumun', 1950501: '?', 1960344: '?', 1710484: 'Columbus', 1711345: 'Stafford', 1959036: '?', 1160568: 'Ablatuysky Bor', 11443: 'Obruchevka', 1127499: 'Kamyshovka', 1159851: 'Komsomolsky', 1945321: 'Oakville', 1109249: 'Kestym', 1145223: 'Takmyk', 1513002: '?', 1504851: 'Rozovka', 1154558: 'Kochnevskoe', 1955874: '?', 1159735: 'Nyaximvol', 1713947: '?', 1911650: 'North Hollywood', 16899: 'Verkhny Landekh', 3331: 'Timofeevka', 1708187: '?', 1955121: '?', 1509712: 'Svetlogorskoe', 1114172: 'Burtasy', 1141333: 'Rabotki', 1155252: 'Rakhmangulovo', 5266682: 'Möckmühl', 17356: 'Bay-Khaak', 1091645: 'Liman', 1513674: 'Grigorovka', 1916617: '?', 1154076: 'Udarnoe', 1921922: 'Buxton', 1958905: '?', 1514536: 'Tereshki', 12664: 'Ugroedy', 1901079: "Be'er-Yakov", 1134829: 'Pochet', 1079998: 'Poltava', 5434598: 'Pürksi', 1965807: '?', 1122400: 'Karpovo Pervoe', 1702103: 'Komsomolskoe', 16862: '?', 1067936: 'Uvarovo', 1511036: 'Moskovsky Bobrik', 1149994: 'Ust-Yazva', 1942929: '?', 5127884: 'Odessa', 1700697: 'Ungirtas', 1914962: 'Gaillard', 1160643: 'Zhireken', 1059999: 'Serednikovo', 1714804: '?', 21632: 'Johor Bahru', 10738: 'Atlasovo', 1709422: '?', 1937169: '?', 1150668: 'Serga', 1512451: 'Kachalovka', 1904184: '?', 1517573: 'Sitka', 5267691: 'Stockstadt am Main', 1154049: 'Kirovskoe', 1082380: 'Orekhovo', 1715660: '?', 1148112: 'Novocherkassk (selo)', 1505906: 'Sukachi', 1501675: 'Karpilovka', 1144615: 'Severnoe', 1908803: '?', 21251: '?', 1124455: 'Klyuevka', 1503568: 'Stanishovka', 1158397: 'Bunkovo', 1031891: 'Voskhod', 1128136: 'Alexeevka', 5266288: 'Recklinghausen', 1512365: 'Kapitolovka', 1960516: '?', 5343831: 'Baja Sardinia', 1087366: 'Boroda', 1147252: 'Pobeda', 1927572: 'Missoula', 1144433: 'Krasnogorskoe', 1505436: 'Nizhny Strutin', 1001359: 'Bobrovskaya', 1078363: 'Vasilyevo-Shamshevo', 1111839: 'Shilovka', 1037057: 'Ust-Ilych', 1091950: 'Rasshevatskaya', 1000247: 'Argunovsky', 1934050: '?', 1602587: 'Priluki', 1109421: 'Iyulskoe', 1513164: 'Yampol', 1110425: 'Alexandrovo', 1507421: 'Marmuzovichi / Andreevka', 1507430: 'Zadvorya', 1508749: 'Kamenny Most', 1956752: '?', 6277: 'Veliky Rakovets', 1118224: 'Krasny Profintern', 1155606: 'Pecherkino', 1960671: '?', 1036576: 'Vegarus', 3134133: 'Jbail', 3134120: 'Joünié', 1701697: 'Novaya Zhizn', 1701085: 'Bobrovka', 1925955: '?', 1087886: 'Safonovo', 1106980: 'Yasny', 1030763: 'Komsomolsk', 4541514: 'Riccione', 1508499: 'Doroshovka', 5331442: 'Yastrembel', 1964817: 'Jeseník', 5423707: 'Dobrodzhya', 1149155: 'Ust-Koyva', 1705573: 'Lipno', 1931934: '?', 1960335: '?', 1058328: 'Kozhino', 1518498: 'Vienna', 1600548: 'Korotichi', 1016621: 'Aristovo', 1715478: 'Maralik', 1922060: '?', 1040693: 'Blagoveschenskaya', 1945197: '?', 1962053: 'Livad', 1515063: 'Krupichpole', 1506055: 'Germanovka', 1048020: 'Krasnoozernoe', 1509203: 'Mayaki', 1021896: 'Krasny Bor (poselok)', 1934513: '?', 1971867: '?', 4922492: 'Denver', 1713612: '?', 1701249: 'Satpaev', 1157628: 'Malyshenka', 1122045: 'Priobskoe', 1060538: 'Moyka', 1701967: 'Lermontovo', 12658: 'Ostrozhka', 4395491: 'Newcastle', 1924114: '?', 1509603: 'Slobodo-Petrovka', 1011901: 'Berezovka', 1150738: 'Kyn', 1702798: 'Zeleny Gai', 1914334: '?', 1911043: '?', 1052519: 'Shiringushi', 1503609: 'Ushomir', 1067425: 'Navlya', 1701713: 'Chingirlau', 1136034: 'Kursk (derevnya)', 4248566: 'Tranemo', 1124852: 'Arsaki (poselok)', 1961729: 'Česká Kamenice', 1513733: 'Bazalia', 1966329: '?', 4325515: '?', 3212260: 'Boden', 1709252: 'Dagda', 1049822: 'Novaya Derevnya', 1091970: 'Schelkan', 1952355: '?', 1939031: 'Conegliano', 1060838: 'Polonoe', 1803599: '?', 1914771: '?', 1515219: 'Nikolaevka', 1000096: 'Abadzekhskaya', 5256265: 'Wandlitz', 1602113: 'Rytan', 1092029: 'Sadovoe', 1960774: '?', 1112283: 'Ishalino', 1512928: 'Voskresenka', 20728: 'Pinerovka', 1147606: 'Saray-Gir', 1501668: 'Vorokomloe', 1931829: '?', 1507946: 'Oglyadov', 5072667: 'Iowa', 1501034: 'Nemia', 1958133: '?', 1960770: '?', 1930381: 'Delmenhorst', 1014197: 'Kievsky', 1074414: 'Sokolovo', 1960810: '?', 1948136: '?', 4578: 'Braga', 1013620: 'Kokorevka', 1024629: 'Rykan', 1501382: 'Timanovka', 1955378: '?', 1958216: '?', 1943158: '?', 8207: 'Pupyshevo', 1502610: 'Makorti', 1939942: 'Albenga', 1094755: 'Taysuganovo', 1519324: 'Teleneshty', 1924050: '?', 1025346: 'Devitsa', 1041819: 'Atamanskaya', 5225803: 'Saint-Louis', 1950886: '?', 1500210: 'Leninskoe', 1703852: 'Ilya', 1905268: 'Nurmijärvi', 4024697: 'Ziguinchor', 1501842: 'Radomyshl', 1943718: '?', 1701970: 'Scherbakovo', 1939167: '?', 22342: '?', 1516421: '?', 1500734: 'Gubnik', 1504367: 'Golubinoe', 1960680: '?', 5266683: 'Neckarsulm', 1938222: '?', 1059237: 'Trusovo', 1011061: 'Loknya', 1501557: 'Zarya', 1501780: 'Ukhovetsk', 1119798: 'Voronkovo', 1516438: 'Kane', 1105157: 'Gorodische', 1509988: 'Vishnevoe', 1510000: 'Prikhodki', 1138171: 'Olkhovka', 1513468: 'Sakhkamen', 1061417: 'Ostrov', 1602162: 'Dashkovichi', 1944580: '?', 1058037: 'Gzhelsky Kirpichny Zavod', 1120480: 'Golovino', -194: -194, 1961390: '?', 1950066: '?', 4283940: 'Lopik', 4286298: 'Drunen', 1921800: '?', 1960898: '?', 1505692: 'Proliski', 5266831: 'Spaichingen', 1947351: '?', 1915598: '?', 1018994: 'Ida', 4387857: 'Blankenhain', 1956455: '?', 1064266: 'Oskuy', 1600285: 'Kalenkovichi', 1516195: 'Veluta', 20648: 'Mayak', 18488: '?', 1911864: '?', 5265528: 'Fürth (Mittelfranken)', 1905913: 'Greenville', 1957368: '?', 4703323: 'Quetzaltenango', 1960958: '?', 1960962: '?', 1083375: 'Sadgorod', 1506803: 'Mechislavka', 1944494: '?', 1945286: '?', 1514234: 'Ivanki', 8015: 'Kuanda', 1082146: 'Sotnitsyno', 1122369: 'Krasnogorskoe', 1008422: 'Axaitovo', 1083957: 'Vasilyevka', 1707457: 'Waukesha', 1056765: 'Molodezhny', 1511310: 'Ivot', 1514327: 'Kolodistoe', 1502406: 'Spaskoe', 1041900: 'Kaluzhskaya', 16617: 'Bichevinka', 1042052: 'Geymanovskaya', 1960982: '?', 1902675: '?', 1024092: 'Nizhny Mamon (nizhnemamonsky 1-J S/s)', 1505735: 'Zazimya', 1705210: 'Santa Clarita', 1054737: 'Mendyukino', 1931688: '?', 12334: 'Chastoozerye', 1054431: 'Yam', 1042095: 'Vinogradny', 1506071: 'Semenovka', 1700105: 'Abay', 1005670: 'Sedyak-Bash', 1021845: 'Dedov Ostrov', 5087926: 'Grand Canyon Village', 1509401: 'Podgornoe', 1026259: 'Bryansk (selo)', 1914186: '?', 2206959: 'Mália', 1041184: 'Privolnaya', 1961680: '?', 1153530: 'Nyuya', 11849: 'Yaroslavskaya', 1138149: 'Krasnomylskoe', 1121757: 'Chendek', 1112683: 'Poldnevo', 1505966: 'Zabyrye', 1515425: 'Cherny Rog', 1956980: '?', 1961065: '?', 1602501: 'Ukhvala', 1957436: '?', 5121410: 'Cordova', 1961077: '?', 1701450: 'Saudakent', 5043016: 'Taylor', 21820: 'Dearborn', 1976544: '?', 1043206: 'Staraya Belitsa', 19222: 'Erbogachen', 1093678: 'Kulevatovo', 1937416: '?', 1143638: 'Karasevo', 1035370: 'Ikon-Khalk', 1050870: 'Konganur', 1602653: 'Osovo', 12722: 'Verkhny Mityakin', 1951464: '?', 1913706: 'Carregado', 1091460: 'Apanasenkovskoe', 1078413: 'Belgorodtsev', 12648: 'Stexovo', 1955788: '?', 1923486: '?', 2300294: 'Ak-Bulak', 1057378: 'Antsiferovo (davydovsky S/o)', 1708449: '?', 1157522: 'Ufa', 1510684: 'Velikaya Omelyana', 1037230: 'Derevyansk', 5267862: 'Singen (Hohentwiel)', 1936890: '?', 1500580: 'Krasnokamenka', 1500583: 'Massandra', 4832736: 'La Florida', 1130119: 'Yurginsky', 1960813: '?', 1961046: '?', 1160876: 'Dalny', 1904074: '?', 1509277: 'Nadlimanskoe', 1160305: 'Sbega', 1150698: 'Cheremukhovo', 1150693: 'Ufa', 1157749: 'Soloboevo', 11435: 'Uoyan', 1030441: 'Kuba', 1041939: 'Baranikovsky', 1060372: 'Port-Vladimir', 3768744: 'Kuching', 1908731: 'Zeulenroda-Triebes', 1150633: 'Parashino', 1961232: '?', 1961601: '?', 1600733: 'Lomashi', 1032071: 'Ulan Zuukh', 1025190: 'Stupino', 1144994: 'Bezmenovo', 1512977: 'Semenovka', 1124999: 'Pikalevo', 1949973: '?', 17668: 'Faisalabad', 1950919: '?', 1964509: 'Mosjøen', 1969915: 'Tamga', 3498379: 'Querim', 1508171: 'Strelbichi', 1500397: 'Zhuravli', 1100061: 'Ryazanovo', 1941786: '?', 1500904: 'Nikolaevka', 1505945: 'Stretovka', 5783: 'Wilmette', 1014164: 'Kuzmichi', 1706825: 'Lancaster', 1085841: 'Kriusha', 1083553: 'Orlovka', 1038192: 'Pronino', 1502368: 'Chervonogrigoryevka', 1910725: '?', 1128543: 'Novobiryusinsky', 11968: '?', 1135568: 'Podgorny', 1501539: 'Porogi', 1504831: 'Voskresenka', 1055073: 'Pavlovskaya Sloboda', 1004703: 'Kim', 1933223: '?', 1135786: 'Podporozhye (derevnya)', 1153825: 'Eveno-Bytantaysky Natsionalny', 1505976: 'Petropavlovskaya Borschagovka', 1513648: 'Polyan', 1114051: 'Raskildino', 1157513: 'Supra', 1512846: 'Genicheskaya Gorka', 5267069: 'Bad Kissingen', 1518793: 'Chartak', 1150437: 'Rabak', 1112776: 'Gornyak', 19588: 'South Orange', 1030511: 'Karagach', 2204994: '?', 1909805: '?', 1006374: 'Tokmak', 18776: 'Staromaryevka', 1084051: 'Rameno', 1012359: 'Pervoe Maya', 17992: 'Varnavino', 1123069: 'Tabuny', 1127456: 'Londoko (zavod)', 1800753: 'Maximovka', 1909313: '?', 1504098: 'Troscha', 1925686: '?', 1161167: 'Rogachevo', 1708787: 'Savage', 1943500: 'Apple Valley', 1042029: 'Eysky', 1035435: 'Dzhaga', 1930311: '?', 1111041: 'Pushkari', 1962934: '?', 1502855: 'Kalchik', 1127003: 'Moshok', 1960648: '?', 1700643: 'Kazakhstan', 1508079: 'Zabuzhye', 1512163: 'Stary Merchik', 1938260: '?', 5266024: 'Meldorf', 1960268: '?', 5364708: 'Kallithea', 1708551: 'Cottage Grove', 1136203: 'Shalinskoe', 1019841: 'Nikolsky Torzhok', 1931770: '?', 1912616: 'Děčín', 1961406: '?', 4207: 'Shuryshkary', 1078179: 'Rogovsky', 1951485: 'Wyoming', 1949014: '?', 1142094: 'Maloe Zinovyevo', 1500870: 'Salnik', 4191197: 'Marina Schiavonia', 4547528: 'Corigliano', 1917854: '?', 1506390: 'Zhuravlinka', 1506411: 'Troyanka', 1950479: '?', 1503522: 'Stepanovka', 1093729: 'Stezhki', 1600814: 'Zaruby', 1085675: 'Lugovskoe', 5210428: 'Vachères', 1961414: '?', 18089: 'Razvilnoe', 1144455: 'Sokur-1', 1147167: 'Podkolki', 1046487: 'Bolshie Taytsy', 5459016: 'Semkovo', 1961427: '?', 1516201: 'Vadul-Turkuluy', 1939626: '?', 1937330: '?', 1500880: 'Belopolye', 3228541: 'Sfântu Gheorghe', 1902704: '?', 4356996: 'Kusel', 5263846: 'Schönenberg-Kübelberg', 1053093: 'Lukhovka', 1945673: '?', 1082822: 'Borovoe', 1948230: '?', 1513621: 'Golovli', 1957606: '?', 22321: 'Pap', 1504237: 'Negrovo', 1505704: 'Blistavitsa', 1506101: 'Pomokli', 1930744: '?', 1953192: '?', 1943651: '?', 1911615: '?', 1962295: 'Riviera Beach', 1078818: 'Krynka', 1803657: '?', 1504222: 'Dolgoe', 1078083: 'Progress', 1115594: 'Lasch-Tayaba', 1958826: 'Yéou', 1500702: 'Luka-Meleshkovskaya', 19334: 'Yasnaya Polyana', 2203565: 'Wysokie Mazowieckie', 3291347: 'Klukowo', 1907300: 'Jabalpur', 1961869: '?', 1700191: 'Tassuat', 1026329: 'Kuli', 1511505: 'Yablonov', 1937741: '?', 1962182: '?', 1028062: 'Khrabrovo', 1920804: '?', 1514942: 'Novy Bykov', 5327489: '?', 1007909: 'Babaevo', 1954312: '?', 1056551: 'Pirogovo', 1129852: '?', 1513060: 'Lazurnoe', 1930225: '?', 1009658: 'Borki', 22153: '?', 1565: '?', 1706330: '?', 1020024: 'Shexna (poselok)', 1949188: '?', 1600980: 'Farinovo', 1505334: 'Bitkov', 1508875: 'Perelety', 1921144: 'Hamilton', 1910544: 'Holland', 1005805: 'Kyzyl-Yulduz', 8829: 'Watertown', 1065744: 'Baranovo', 1931422: '?', 4456109: '?', 1503534: 'Veresy', 1503270: 'Serditoe', 1036841: 'Kedrovy Shor', 1515573: 'Chepelov', 5266673: 'Bad Rappenau', 1503084: 'Novoukrainka', 1923984: '?', 1962222: '?', 1600289: 'Ryasna', 1027595: 'Khokhlyata', 4532432: 'Nærbø', 1961595: '?', 1932665: 'Great Neck', 1947413: '?', 18739: '?', 1940170: '?', 1513634: 'Krupets', 1095540: 'Mataki', 1067384: 'Khotynets', 3827228: 'Gyeongju', 1955069: '?', 1907370: '?', 6107: 'Charvak (asakinsky Rayon)', 1138133: 'Kamchatka (derevnya)', 1136215: 'Gorodok', 5235764: 'Champigny-sur-Marne', 1128329: 'Shestakovo', 1157097: 'Saryg-Sep', 1074671: 'Blyanitsy', 1904927: 'Auroville', 1079651: 'Strakhov', 4722459: 'Heredia', 1160900: 'Sireniki', 1160896: 'Novoe Chaplino', 1936142: '?', 1149408: 'Sadki', 1024494: 'Nizhny Ikorets', 1965588: '?', 1932513: 'Lake Arrowhead', 5036744: 'Charlotte', 1704759: 'Shaartuz', 1948943: '?', 1944206: 'Sakarchyage', 1709489: 'Blackwood', 1518834: 'Tampico', 4683908: 'Ciudad Madero', 1708534: '?', 1944813: '?', 1081164: 'Samara (derevnya)', 1124644: 'Orlik', 8728: 'Orlik', 1143816: 'Evsino', 1506146: 'Savintsy', 3200: 'Klyuchevsk', 1112766: 'Syrtinsky', 3879920: '?', 1508932: 'Kurortnoe', 1500381: 'Chernyshovo', 5455656: 'Zalesye', 1141250: 'Bezvodnoe', 1909785: '?', 15248: 'Uddevalla', 1508793: 'Pavlovka', 19630: 'Kletskaya', 1114421: 'Andreevo-Bazary', 1910009: '?', 1127609: 'Zyaba', 1508959: 'Berezan', 1961379: '?', 1917926: '?', 1014146: 'Yuzhny', 1145507: 'Nemirovka', 1011294: 'Putevka', 1500923: 'Verbka', 2204954: 'Buderim', 1601713: 'Gorodets', 1154026: 'Krasnogorsk', 1047426: 'Mukholovka', 1709306: '?', 1079655: 'Chebachy', 12563: 'Novozolotovskaya', 5259786: 'Eisenhüttenstadt', 1091831: 'Turxad', 18544: 'Vorontsovka', 1506023: 'Yasnogorodka', 1038821: 'Shulevo', 1701028: 'Beybarys (chkalovo)', 1500846: 'Guschintsy', 1510443: 'Borovoe', 1951819: '?', 4365994: 'Hoff', 1114937: 'Shorkasy', 1114783: 'Akramovo', 1114905: 'Syatrakasy (syatrakasinskoe S/p)', 16247: 'Tonezh', 1008205: 'Turnaly', 1093402: 'Lipovka', 2063: '?', 1052006: 'Yasny', 1954593: '?', 1924524: '?', 1923039: 'Kaldakhuara', 4228551: '?', 1138684: 'Novoselki', 1501601: 'Mirnoe', 1136628: 'Novokamala', 5356126: 'Gut Leerodt', 1000931: 'Pavlovsk', 1705834: 'Neglyubka', 8183: 'Wakefield', 1015353: 'Kletsky', 1013676: 'Vyukovo', 1127473: 'Khingansk', 4539944: "Sant'Arsenio", 6321: 'Romashkino', 5120520: 'Paia', 1507497: 'Bolekhovtsy', 2500145: '?', 1960436: '?', 1903429: '?', 1707212: '?', 1917021: '?', 1707522: '?', 1914707: '?', 4915894: 'Grapevine', 1015206: 'Matyshevo', 1500564: 'Okunevka', 1960258: '?', 5470298: 'Ikalto', 1961694: '?', 1935368: 'Czersk', 1943575: '?', 1081726: 'Zaoxkoe', 1973288: '?', 1937060: 'همه جای ای&#1585', 1962747: 'Piotrków Trybunalski', 1055838: 'Leninsky', 1960343: '?', 1909687: '?', 6649: 'Magansky', 1006319: 'Dyurtyuli', 1139429: 'Dubenskoe', 1704278: 'Monterotondo', 1154619: 'Garashkinskoe', 4002997: 'Mareeba', 1514374: 'Rodnikovka', 1710568: 'Concord', 1516874: 'Starobin', 1060995: 'Ivanteevo', 1515576: 'Beloe-1', 1058047: 'Dergaevo', 19321: 'Dmitrova Gora', 1153021: 'Boets Kuznetsov', 1602242: 'Ostrino', 1970302: '?', 1515305: 'Kozary', 1500789: 'Noskovtsy', 2722470: 'Batman', 1510725: 'Shubkov', 1960994: '?', 1020534: 'Spas-Yamschiki', 1020536: 'Staroe', 1944975: '?', 1915066: '?', 1949729: '?', 1960205: '?', 1916505: '?', 1516654: 'Kopchak', 1601063: 'Nemoyta', 1700139: 'Axay', 1501085: 'Snetkov', 1146643: 'Krasny Oktyabr', 1057228: 'Ryazan (derevnya)', 1037296: 'Zamezhnaya', 1801151: 'Rogi', 1960443: '?', 1954266: 'Kanpur', 4923: 'Flensburg', 1712389: '?', 1961922: '?', 1600664: 'Vorony', 1115173: 'Churachiki', 1502155: 'Zeleny Gai', 5078619: '?', 1931012: 'Kingston', 1084621: 'Lesnoe', 1092066: 'Otkaznoe', 1928425: 'Bramsche', 1704714: 'Genthin', 1516470: 'Bersenbrück', 1147074: 'Pilyugino', 1956696: 'Perryville', 1041446: 'Novoalexeevskaya', 1014801: 'Sukhov 2-J', 2202386: '?', 1944362: '?', 1158656: 'Otradnaya', 2202775: 'Żory', 1500614: 'Kopaygorod', 4532809: 'Måløy', 5264808: 'Bayerisch Gmain', 5491: '?', 1031803: 'Vinogradnoe', 1937387: '?', 1961008: '?', 1702551: 'Alexeevka', 4493423: 'Police', 1156639: 'Volodino', 1702940: 'Asykata', 10991: 'Galveston', 5420876: '?', 1943921: 'Paola', 1924556: '?', 1843: '?', 1911178: '?', 15737: '?', 1032554: 'Ostrozhnoe', 1601595: 'Dzerzhinsk', 1144555: 'Berezovka', 1514764: 'Sloboda', 4395492: 'Newbridge', 4038885: 'Santarém', 1952102: '?', 1960909: '?', 19335: 'Ilyushino', 1929199: 'Švenčionys', 1094137: 'Bibikovo', 1922736: '?', 1957677: 'Svolvær', 1030502: 'Blagoveschenka', 1007413: 'Apasevo', 1091227: 'Ponyatovka', 1041085: 'Kukharivka', 1066781: 'Nikolskoe', 1053671: 'Ostashevo', 1121977: 'Usyatskoe', 1109954: 'Kama', 22581: 'Magdalinovka', 1025105: 'Saguny (poselok)', 1102423: 'Svyatoe', 1504673: 'Ivanovka', 1601463: 'Peretrutovsky Vorotyn', 1042424: 'Peny', 1511555: 'Dobrovody', 4659091: 'Tucupido', 1904134: '?', 1704569: '?', 1921413: '?', 1959752: '?', 1150010: 'Maysky', 1007889: 'Oktyabrsk', 1506388: 'Emilovka', 1083901: 'Karmalo-Adelyakovo', 2204757: '?', 1708194: '?', 1500686: 'Vinnitskie Khutora', 1500671: 'Ternovka', 1008295: 'Yasherganovo', 1906883: '?', 1026037: 'Novy Urkarakh', 1513512: 'Mikhaylovtsy', 1700067: 'Pokrovka', 1511403: 'Melnitsa-Podolskaya', 1961949: '?', 1518625: '?', 8643: 'Alfimovo', 1114221: 'Sanarposi', 1501113: 'Monastyrskoe / Marxovo', 1955902: '?', 1601896: 'Porechye', 1144197: 'Bulatovo', 4530387: 'Stathelle', 1710908: 'Rønne', 1917592: '?', 14455: 'Öland', 1156633: 'Yudino', 1714544: '?', 1953547: '?', 1714437: 'Lemwerder', 4388938: 'Berne', 22085: 'Bilzen', 1600136: 'Brashevichi', 1962119: '?', 1803658: '?', 1502255: 'Radushnoe', 1925880: '?', 1102086: 'Mirny', 1934933: '?', 17076: 'Khadakhan', 1927152: '?', 1910884: '?', 1113754: 'Kurchaloy', 1025572: 'Orlovka', 1921707: '?', 1505666: 'Poberezhka', 21439: 'Znamenka / Chervonoznamenka', 1952288: 'Lexington Park', 1908623: '?', 1050190: 'Otskochnoe', 1945628: 'Imantas', 1943740: '?', 1920680: 'York', 1510070: 'Peschanoe', 1500349: 'Pravda', 1514230: 'Buki', 1027224: 'Tlyarosh', 1902377: '?', 1105480: 'Bogucharovo', 10367: 'Komsomolets', 1075517: 'Karamyshevo', 1514412: 'Khristinovka Selo', 1601976: 'Subbotniki', 2722469: 'Gebze', 1965829: 'Santa Severina', 1514051: 'Yurkovka', 1904519: 'Vlorë', 1512181: 'Prikolotnoe', 1923567: '?', 1926213: '?', 1803174: 'Viimsi', 1954152: '?', 1939585: 'Split', 1959832: '?', 5050722: 'West Fargo', 21709: 'Biel / Bienne', 1701839: 'Yntaly', 1144273: 'Blagoveschenka', 5267794: 'Langenfeld (Rheinland)', 1962200: '?', 1706269: 'Basildon', 1005376: 'Elizavetino', 4722707: 'Dominical', 1959500: '?', 1910215: '?', 1961600: 'Southgate', 1703441: '?', 1503384: 'Miroslavka', 1508459: 'Obukhovka', 1154365: 'Pristan', 20301: 'Novoseleznevo', 1952619: '?', 1502452: 'Alexandropol', 1918449: 'Canelli', 4543539: 'Nizza Monferrato', 12016: 'Poltavka', 1035471: 'Udarny', 1158782: 'Khokhorsk', 2722642: 'Eldoret', 1939168: '?', 1156445: 'Vavilovka', 1083044: 'Bolshaya Dergunovka', 1000219: 'Mamkheg', 1144358: 'Mezhovka', 1005424: 'Sanatory Glukhovskaya', 1156933: 'Rybalovo', 1095234: 'Kaybitsy', 1112821: 'Lugovoy', 1138425: 'Talovka', 1708177: '?', 1122336: 'Kontoshino', 1003010: 'Yangory', 14174: 'Hamilton', 1921258: 'Alsfeld', 1159994: 'Narasun', 1041022: 'Pushkinskoe', 1010663: 'Dmitrievka', 1930132: '?', 1149206: 'Bryukhovo', 1069854: 'Smolyaninovo', 1600657: 'Oktyabrskaya', 1939957: '?', 1509457: 'Petroverovka / Zhovten', 1905328: '?', 22298: '?', 1960181: '?', 20357: 'Ulanov', 1505876: 'Usovka', 5928: '?', 1113245: 'Suleya', 1007668: 'Sharipovo', 1954300: '?', 1964348: '?', 1704978: 'Chandler', 1905768: 'Hattersheim am Main', 1507720: 'Zapitov', 1507727: 'Novy Yarychev', 1010582: 'Lvov', 1145409: 'Velikorusskoe', 1506382: 'Chemerpol', 1920949: '?', 1702145: 'Stepanovka', 1514358: 'Ivanovka', 1931069: '?', 1971363: 'Galkynysh', 1159335: 'Takhta', 1974341: 'Witley', 1704021: '?', 1505573: 'Mikulichin', 1128686: 'Belaya', 1503864: 'Dibrova', 1954993: '?', 1512215: 'Petropavlovka', 13662: 'Ulma', 1959914: '?', 7257: '?', 1084241: 'Novodevichye', 1514839: 'Krasnoilsk', 1084792: 'Zhadovka', 1510168: 'Skorokhodovo / Artemovka', 1113414: 'Yasnye Polyany', 5039104: 'Alanson', 1154142: 'Asbestovsky', 1137585: 'Pimenovka', 1504306: 'Novoe Davydkovo', 1514550: 'Vashkovtsy', 1096410: 'Tikhonovo', 1940461: '?', 1114762: 'Syatrakasy', 1912772: '?', 4261287: 'Jokkmokk', 1911353: '?', 1092044: 'Yasnaya Polyana', 1153903: 'Pikhtovoe', 1953748: '?', 17601: 'Kopys', 1508205: 'Duliby', 1138476: 'Arkagala', 1936278: '?', 1931166: '?', 1031406: 'Golovkino', 5266402: 'Kamen', 1702775: 'Krasnoznamennoe', 1114931: 'Shatmaposi', 1114908: 'Tiushi', 1047721: 'Mkhi', 1006383: 'Chistopol', 1010865: 'Ezdochnoe', 5259270: 'Frechen', 1085218: 'Shiroky Karamysh', 4808554: 'Medellín y Piqua Primera Sección', 17866: 'Klimovo (klimovskoe S/p)', 1973787: '?', 2001371: '?', 1128293: 'Bereznyaki', 1942734: '?', 1908440: '?', 1930980: '?', 13496: 'Mezhvodnoe', 1959220: '?', 1915301: '?', 6703: 'Preston', 1915617: 'Melle', 5266332: 'Barntrup', 1917110: '?', 1502398: 'Novotroitskoe', 1938847: 'East Hampton', 3131788: 'Ágios Nikólaos', 1091965: 'Kitaevskoe', 1909639: '?', 1917640: '?', 1500534: 'Solnechnaya Dolina', 1160479: 'Duroy', 1518602: 'Farmington', 1143363: 'Silino', 1964942: '?', 1505697: 'Soshnikov', 1960993: '?', 1079512: 'Alexeevo-Tuzlovka', 1121107: 'Kozmodemyansk', 1009181: 'Shingak-Kul', 1936261: '?', 5266212: 'Dinslaken', 10732: '?', 1951748: '?', 1901358: '?', 1041217: 'Komsomolsky', 1026540: 'Sulak', 1504670: 'Vodyanoe', 1702857: 'Kobensay', 1106650: 'Shumsky', 1034912: 'Novaya Derevnya', 1919837: '?', 1135987: 'Kedrovy', 21112: 'Zihuatanejo', 1122359: 'Dolina Svobody', 5262819: 'Daubach', 1926889: '?', 1030759: 'Zorino', 1000558: 'Yura', 1965504: 'Im. Frunze', 1918794: '?', 1600226: 'Byten', 1600248: 'Domanovo', 1014088: 'Ust-Buzuluxkaya (derevnya)', 1052445: 'Zhukovka', 1962147: '?', 1702769: 'Beloe', 12099: 'Sura', 1500112: 'Kalinovka', 3317044: 'Masvingo', 1026084: 'Mamedkala', 1962516: '?', 1959583: '?', 1028521: 'Oktyabrsky', 22653: 'Duluth', 1962745: '?', 1504240: 'Osy', 1928725: '?', 1714616: '?', 1069053: 'Borovichi', 1041347: 'Armyansky', 1024192: 'Solontsy', 2207140: 'Husum', 4207355: 'Nadur', 1147251: 'Petrokhersonets', 1155437: 'Staraya Lyalya', 1962741: 'Ureki', 1507518: 'Medenichi', 1079015: 'Mankovo-Berezovskaya', 1045686: 'Rabititsy', 1512798: 'Malaya Alexandrovka', 1947221: '?', 8623: 'Lentvaris', 1131790: 'Vozhgaly', 1962755: '?', 1013163: 'Pochep-2', 1144147: 'Kolybelka', 1962847: 'Treviglio', 1962773: '?', 1916971: 'Pietermaritzburg', 1964596: 'Schleswig', 16385: '?', 3053416: 'Yazd', 1014478: 'Salomatino', 1962809: '?', 1031943: 'Salyn Tugtun', 1506330: 'Novogradovka', 20820: '?', 1031423: 'Iyulskoe', 1961913: '?', 1094098: 'Nizhny Shibryay', 1971389: '?', 1960274: 'Zrenjanin', 1961958: '?', 1112184: 'Oktyabrsky', 1512657: 'Ternovaya', 5104656: 'Grace', 1503992: 'Rogachi', 1600076: 'Bolshie Motykaly', 1976115: 'Viesīte', 1049227: 'Kamenskoe', 1504708: 'Konstantinovka', 3983780: 'Mount Hagen', 1519171: '?', 1949852: '?', 1041259: 'Oktyabrsky', 1928387: 'Pinedale', 1009675: 'Zherdevka', 1055425: 'Maleevka', 4483138: 'Dobříš', 1907077: 'Monastir', 1801990: '?', 1026130: 'Gostala', 1906864: '?', 1947466: '?', 1904732: 'Bathurst', 5421407: 'Bathurst', 1145455: 'Brazhnikovo', 1924121: '?', 1953014: '?', 1005889: 'Ilina-Polyana', 1088279: 'Luna', 1600495: 'Klepachi', 1134755: 'Ayanka', 1602320: 'Novoselki', 1935380: '?', 1800585: 'Kolosovo ', 1505226: 'Gvozdets', 1961506: '?', 1961533: '?', 1082282: 'Kogotkovo', 1503202: 'Maryanovka', 1504232: 'Lisichovo', 1974948: '?', 1709780: '?', 1140532: 'Pervomaysky (pervomaysky S/s)', 4977638: 'Hammonton', 1903456: 'Buena Vista', 2300440: 'Ylay-Talaa', 1057911: 'Zeleny Gorodok', 1942731: '?', 1959735: '?', 1159404: 'Sergeevka', 1083327: 'Staroe Ermakovo', 4189677: 'Antequera', 1086159: 'Goryushi', 5430723: 'Kantagi ', 1518028: 'Partizanskaya', 1928895: '?', 1951969: '?', 1156455: 'Parbig', 1152951: 'Tavrichanka', 1154178: 'Zarya', 1517829: '?', 5430360: 'Axukent', 1950984: 'Richboro', 1962968: '?', 1943687: 'Cluny', 1509931: 'Drabinovka', 1058076: 'Ilinskoe', 1601456: 'Lipov', 1959730: '?', 1928910: '?', 1122815: 'Zeleny Lug', 1913106: '?', 1040996: 'Krasnoselsky', 1708298: 'Yangikhaet (bekabadsky Rayon)', 1963553: '?', 10479: 'Taezhny', 1700441: 'Akrab', 1137206: 'Lebyazhye', 1915115: '?', 1928061: '?', 1500803: 'Chernyatin', 1946457: '?', 4547943: 'Cividate Camuno', 1023911: 'Korshevo', 1124540: 'Ulyunkhan', 1035510: 'Zhako', 1063878: 'Antsiferovo (brodsky S/s)', 5267213: 'Lindau (Bodensee)', 4635833: 'Þorlákshöfn', 1904156: 'Grundarfjörður', 4635932: 'Reykhólar', 1501503: 'Plebanovka', 1917492: '?', 1961747: '?', 1038369: 'Stolpino', 1904983: 'Handan', 1512245: 'Peski', 1925867: '?', 1801333: 'Sukhaya Rybnitsa', 1149817: 'Kosa', 1702661: 'Takhtabrod', 1026001: 'Ashty', 1095513: 'Shapshi', 1702074: 'Burli', 1099247: 'Kozino', 1060492: 'Dorogobuzh', 1955269: '?', 1916000: 'Yalama', 5996: 'Bolshoy Uluy', 8661: 'Sármellék', 1924107: '?', 1157245: 'Leninka', 12649: 'Beloe', 21470: 'Dzhalilabad', 1055793: 'Vnukovo (derevnya)', 1028545: 'Svetikovo', 5098200: 'Florida', 5057053: 'Bronxville', 1602651: 'Naroch (derevnya)', 1712075: '?', 1030407: 'Kantyshevo', 1917239: 'Al Qāmishlī', 1080108: 'Liver', 1915143: 'Niamey', 1504343: 'Veliky Bychkov', 1503279: 'Zhelannoe', 1080049: 'Kolundaevsky', 1510854: 'Uspenka', 1706010: 'Syke', 1091542: 'Balkovsky', 1962619: '?', 1953340: '?', 1906958: '?', 1000184: 'Dzhidzhikhabl', 5266945: 'Pocking', 1124480: 'Tankhoy', 1044387: 'Sredny Raskhovets', 1046263: 'Veschevo (stantsia)', 1714452: '?', 1154469: 'Elan', 4546009: 'Grisignano di Zocco', 1508998: 'Gorodnoe', 1946552: 'Peschiera del Garda', 1124583: 'Ungurkuy', 19352: 'Cheremisinovo', 1107849: 'Rylevo', 1963162: '?', 1084388: 'Grachevka', 1927392: 'Great Falls', 1149913: 'Sepol', 1007169: 'Zuevka', 1707387: 'Gandia', 1709067: 'Pyrlitsa', 1508308: 'Kamenobrod', 1079609: 'Seyatel Severny', 1124607: 'Ust-Muya', 1506140: 'Nastashka', 1079800: 'Mikhaylov', 1511312: 'Klishki', 1057288: 'Yagunino', 1139454: 'Troitskoe 1-E', 1702737: 'Yakor', 1938908: '?', 1042285: 'Tyumensky', 1023665: 'Nifantovo', 1503736: 'Zalesye', 1503745: 'Motiyki', 1500241: 'Ilinka', 1160258: 'Mangut', 1129042: 'Apacha', 1947612: 'Vachiani', 1011624: 'Bytosh', 1124154: 'Uralovka', 14923: 'Brodokalmak', 4179: 'Verkhnetulomsky', 14192: 'Glazunovka', 1937356: '?', 1800358: 'Delakeu', 1153803: 'Khotochchu', 1957221: '?', 1927243: 'Avrora', 1507461: 'Veliky Lyubin', 1501428: 'Semaki', 2500349: 'Chorukh-Dayron', 1080159: 'Zakharovo', 1932798: '?', 1138626: 'Abramovo', 1156403: 'Baturino', 5470547: 'Byuyuk Kolatan', 1110492: 'Nynek', 1519248: '?', 1962750: '?', 2206113: '?', 1713738: 'Banja Luka', 2204146: 'Achères-la-Forêt', 1705599: 'Alastani', 1602799: 'Pogost-2', 1903449: '?', 4904926: 'Alaki Fonua', 1501030: 'Kukavka', 1081689: 'Varskie', 16608: 'Algasovo', 1041637: 'Gubskaya', 1514724: 'Revakovtsy', 1959782: '?', 1515872: 'Energetikov', 21585: 'Perekrestovo', 5267088: 'Karlstadt', 1963333: '?', 1140866: 'Chelatma', 1042386: 'Shabelskoe', 1007155: 'Baykibashevo', 1503843: 'Norinsk', 1601219: 'Zarechye', 1094053: 'Ertil', 1017428: 'Krapivino', 5334671: '?', 13118: '?', 1512462: 'Parkhomovka', 1014237: 'Pichuga', 1015097: '3 Ferma', 1041875: 'Sadki', 1907009: 'Bhilai', 19231: 'Puxa', 14787: 'Ulan-Erge', 5266916: 'Landsberg am Lech', 1944621: '?', 1501356: 'Belousovka', 1123289: 'Ogni', 1964778: '?', 1963388: '?', 1114586: 'Pikshiki', 5256236: 'Wallerfangen', 1501790: 'Zayachitsy', 1509378: 'Alexandrovka', 1509125: 'Alexandrovka', 1014099: 'Demidov', 1042261: 'Messazhay', 1505382: 'Zhovchev', 1062514: 'Zaveryazhye', 1920474: '?', 1921562: 'Ipatinga', 1504951: 'Atmanay', 1128308: 'Korshunovsky', 1061634: 'Yarkovo', 1601901: 'Kvasovka', 3281353: 'Stary Sącz', 1068801: 'Sazanye', 1078754: 'Maloorlovsky', 1961061: '?', 1503898: 'Kvitnevoe / Zhovtnevoe', 1907067: '?', 1045883: 'Kolchanovo', 1049058: 'Kalikino', 1115220: 'Ishlei', 1932518: '?', 1909560: '?', 1134792: 'Gorodok', 1141829: 'Tanaykovo', 1079426: 'Cherkessky', 1150512: 'Goldyrevsky', 1503051: 'Demyanovka', 1104370: 'Bolshoe Vishenye', 1161179: '?', 1927722: '?', 701: 'Talitsa', 1711220: 'Edinboro', 1600842: 'Stai', 1505288: 'Sheparovtsy', 1953755: '?', 5081897: 'Middlebury', 1902384: 'Lorain', 1708975: 'Roseburg', 1517338: 'Velichkovichi', 1024007: 'Gubari', 1057546: 'Schetinovo (belavinsky S/o)', 15145: '?', 17758: 'Krasnoe', 1500196: 'Znamenka', 1013540: 'Mokhonovka', 1927975: 'Huntington Station', 1129018: 'Pionersky', 1962505: '?', 1068171: 'Sosnovka', 1953679: '?', 1046713: 'Shpankovo', 1159089: 'Georgievka', 1700679: 'Mynbaev', 1973310: 'Zestafoni', 20387: 'Novorudny', 1942479: '?', 1099632: 'Stolipino', 1958654: '?', 3984676: 'Madang', 1505009: 'Starye Bogorodchany', 1149216: 'Kizhi', 1959547: '?', 1117796: 'Bukhalovo', 1037306: 'Novy Bor', 1081734: 'Iskra', 2208453: '?', 1506105: 'Sosnovaya', 1140123: 'Sysuevo', 1003548: 'Dvinskoy', 1041713: 'Engels', 1083408: 'Komsomolsky', 1703176: '?', 1007376: 'Vakiarovo', 1040737: 'Yurovka', 1514718: 'Nepolokovtsy', 1904096: 'Chartres', 1052738: 'Poltso', 1962860: '?', 1970480: '?', 4612: 'Tsakir', 1080951: 'Lipyagi', 1052486: 'Partsa', 1060223: 'Grebnevo', 1151910: 'Torgovische', 1910547: '?', 1943215: 'Brookline', 1036446: 'Karshevo', 4688598: 'Playa Baracoa', 1963677: '?', 1053971: 'Dmitrov-4', 1962592: '?', 4348921: 'Nettetal', 1507155: 'Sofievka', 1505780: 'Malaya Soltanovka', 1000017: 'Kolkhozny', 1963694: '?', 1000986: 'Fominskaya', 1079143: 'Veselo-Voznesenka', 1955030: '?', 1703456: 'Steinfurt', 1033222: 'Bobrovka', 1936: '?', 6218: 'Ballarat', 1136341: 'Pavlovka', 1903499: '?', 1600717: 'Derkovschina', 1963724: '?', 1513483: 'Antoniny', 1032679: 'Khotkovo', 1024225: 'Verkhny Karachan', 1123062: 'Lebedino', 1159103: 'Novostroyka', 2722621: 'Al Ḩudaydah', 1960979: 'Addison', 1713690: 'Livingston', 1031938: 'Lista', 1058751: 'Torgashino', 1021786: 'Shebengsky Pogost', 2100830: 'Nurata', 1513704: 'Stary Ostropol', 1960934: '?', 1972922: '?', 1511552: 'Vishnevets', 1963803: '?', 1704866: '?', 1602007: 'Tsirin', 1000936: 'Petukhovo', 1122744: 'Nikolaevka', 1129401: 'Blagoveschenka', 1963798: '?', 1078360: 'Khutorskoy', 1012982: 'Yudinovo', 5470: 'Peskovka', 1502264: 'Auly', 1509407: 'Yarovoe', 1517220: 'Knyazevka', 5267677: 'Höchstadt an der Aisch', 1914644: '?', 1918178: '?', 1049414: 'Khmelinets', 1963847: '?', 1925031: '?', 1501237: 'Veselovka', 1953473: '?', 1083263: 'Solnechnaya Polyana', 1057081: 'Gar-Pokrovskoe', 1506991: 'Makeevka', 1957530: '?', 1963873: '?', 1061731: 'Zarubino', 1507779: 'Ternopolye', 22662: 'Kvaysa', 1702311: 'Kyzyl Zhuldyz', 1085170: 'Sulak', 1950917: '?', 1006794: 'Kommunar (derevnya)', 1096590: 'Krasny Klyuch', 16638: 'Sloboda', 5266232: 'Erftstadt', 1502538: 'Kislyanka', 17756: 'Egla', 1713299: '?', 1509825: 'Yakhniki', 1079530: 'Daryevka', 1086042: 'Oktyabrsky Gorodok', 1907856: '?', 1509335: 'Baksha', 1701258: 'Novo-Azovoe', 1962551: '?', 1910357: '?', 1962318: '?', 1512995: 'Nizhnie Serogozy', 11154: '?', 5382878: 'La Croix-de-Rozon', 1156392: 'Lukashkin Yar', 1948433: '?', 1512456: 'Konstantinovka', 18487: 'Shereshevo', 4549970: 'Calolziocorte', 1092722: 'Kryukovka', 1092773: 'Sestrenka', 1092721: 'Krugloe', 1946059: 'Tsintskaro', 1963574: '?', 1078502: 'Dibrovy', 3501998: 'Manipala', 4962939: 'Miami', 2714: '?', 1704353: 'Silkeborg', 1600861: 'Vysochany', 1962739: 'Kilkís', 3169754: 'Fukumu', 1116457: 'Velikoe', 1961135: '?', 1514098: 'Zhabotin', 1093812: 'Avdeevka', 3508867: 'Dindigul', 1147135: 'Koltubanovsky', 18692: 'Nizhny Baskunchak', 1700145: 'Dvurechnoe', 1033763: 'Panskoe', 1150176: 'Leninsk', 1042153: 'Novoleninsky', 1136273: 'Mashukovka', 1210: 'Matveevka', 1963823: '?', 1148056: 'Svetly', 1943050: '?', 1964583: '?', 1709181: '?', 1514260: 'Ivakhny', 3043485: 'Tobruk', 1705376: 'Bacău', 19780: '?', 5264850: 'Markt Schwaben', 1516304: 'Silistra', 1937906: '?', 4653993: 'Cabo Frio', 1152146: 'Nozhovka', 1801121: 'Pyrlitsa', 1505745: 'Pogreby', 1037200: 'Studenets', 1015241: 'Privolzhsky', 5436: 'Pestyaki', 1043447: 'Khalino', 1040107: 'Sudislavl (stantsia)', 1707464: 'Győr', 1130613: 'Loyno', 1963920: '?', 1506193: 'Krasilovka', 1950630: '?', 1602513: 'Logoza', 1134692: 'Sosnovka', 1508940: 'Primorskoe', 1503075: 'Konstantinovka', 1510775: 'Krichilsk', 1602275: 'Mikulichi', 1602702: 'Bor', 20227: '?', 3788332: 'Changde', 1703390: 'Mountmellick', 1702127: 'Ulyanovskoe', 5266222: 'Herzogenrath', 5259269: 'Alsdorf', 1510935: 'Kurilovka / Zhovtnevoe', 9653: 'Zagorskie Dali', 1603222: 'Buynichi', 1919918: '?', 1600132: 'Bezdezh', 4978198: 'Tuckerton', 1963947: '?', 1084642: 'Repnoe', 1601670: 'Vasilevichi', 1601307: 'Teryukha', 4661117: 'Liberty Castle', 1147155: 'Novoalexandrovka', 1940150: '?', 1700222: 'Prirechnoe', 1703215: 'Latham', 1129692: 'Terentyevskoe', 1035150: 'Elensky', 1901779: 'Plainsboro', 1516165: 'Tyler', 2722546: 'Vila', 1109442: 'Perevoznoe', 9019: 'Masali', 1947370: 'Mělník', 1505130: 'Yasenev-Pylny', 1950511: '?', 1963430: '?', 1964562: 'Stabio', 1094795: 'Karatun', 8817: 'Schelyayur', 1123755: 'Orlovka', 1123993: 'Belonogovo', 2300505: 'Kamyshevka', 4225945: 'Greve', 21344: '?', 1067537: 'Macha-Rodniki', 1053848: 'Pushkino', 19801: 'Soluno-Dmitrievskoe', 1146038: 'Andreevka', 1025414: 'Alexandrovka', 1709205: 'Alliance', 1132412: 'Medvedok', 19603: 'Deryabino', 1154353: 'Manchazh', 1964222: '?', 1153378: 'Verkhny Kuranakh', 1153035: 'Novolitovsk', 1024066: 'Nizhny Kislyay', 1514681: 'Lenkovtsy', 1161174: 'Tamtachet', 1136664: 'Bolshoy Arbay', 1134967: 'Rovnoe', 1158896: 'Oloy', 1128095: 'Magdan', 1056873: 'Tatischevo', 1510913: 'Sukhodol', 1125322: 'Shatnevo', 1031845: 'Yuzhny', 1503760: 'Broniki', 1011435: 'Gordeevka', 1086380: 'Surkh-Digora', 1007087: 'Keltey Bolshoy', 5364923: 'Apostoli', 1086149: 'Alexeevka', 1602350: 'Dolginovo', 1500505: 'Zavetnoe', 3894: '?', 1957812: '?', 1503003: 'Sergievka', 1954627: 'Brčko', 1600322: 'Ostromichi', 1949189: 'Littlehampton', 5265530: 'Schwabach', 1702458: 'Amangeldy', 1154080: 'Telnovskoe', 1953057: 'Narara', 1503070: 'Dobrovolye', 1972179: '?', 3371: 'Ivanovsky', 1096146: 'Sokury', 1146774: 'Anikhovka', 17395: 'Progress', 1964280: '?', 1964347: '?', 1964350: '?', 3820751: 'Ban San Keo', 1502470: 'Ukrainskoe', 1928511: '?', 1112048: 'Zelenaya Roscha', 1158496: 'Karabash', 1015368: 'Lebyazhya Polyana', 1933063: '?', 1963490: '?', 1705434: 'Kentfield', 1121074: 'Ivnyaki', 1974580: '?', 1906792: '?', 1055095: 'Prechistoe', 1711581: '?', 18830: 'Veseloe', 1138446: 'Raduzhny', 1964326: '?', 1137790: 'Butyrskoe', 1122588: 'Degtyarka', 1800822: 'Mokryaki', 1505181: 'Voynilov', 1952664: '?', 1086187: 'Vzletny', 1060988: 'Zagorye', 1510041: 'Novoselovka', 1712768: 'Georgetown', 1920270: '?', 1511617: 'Mylnoe', 1500563: 'Novoselskoe', 1800821: 'Mokra', 1001754: 'Fedotovskaya', 1969103: 'Wallingford', 1510389: 'Rachin', 1139918: 'Zolino', 1959966: '?', 1928429: '?', 1506174: 'Samgorodok', 1961082: '?', 1703152: '?', 1160877: 'Ilirney', 1108386: 'Brusyansky', 1041255: 'Maryanskaya', 1505178: 'Bodnarev', 1513042: 'Novomikhaylovka', 1705036: '?', 22241: 'Mir', 1949416: '?', 1046186: 'Petrokrepost', 2158: 'Komárom', 1013245: 'Gobiki', 1079405: 'Orden Lenina', 1509274: 'Karolino-Bugaz', 4400: 'Bolshie Klyuchischi', 1714767: '?', 1713683: '?', 1015388: 'Sukhodol', 1500909: 'Polichintsy', 1012991: 'Baklan', 1509985: 'Berezovaya Rudka', 1914654: 'Jašiūnai', 1957118: '?', 1509464: 'Novoandreevka', 1509862: 'Solonitsa', 1143421: 'Klin (derevnya)', 1006295: '1539 Km', 1953289: '?', 1961990: '?', 1966823: '?', 1922461: 'Rust', 1910647: '?', 1513762: 'Shibenaya', 1513741: 'Ilkovtsy', 3788805: 'Weihai', 1500386: 'Veselovka', 1708516: 'Kentwood', 1145611: 'Krasny Yar', 1047836: 'Tesovo-4', 1160292: 'Ksenyevskaya', 1713852: 'Malibu', 1159348: 'Bychikha', 1502231: 'Suvorovo', 1052737: 'Pokrovsk', 1123182: 'Sadovy', 1120539: 'Zaozerye', 1091590: 'Baklanovskaya', 8678: 'Troitskoe', 1702184: 'Asenkritovka', 1904947: '?', 1910731: '?', 1964192: '?', 22687: 'Mazanka', 1024119: 'Volya', 1922336: '?', 1958882: '?', 1709895: '?', 1503341: 'Kamenny Brod', 1601377: 'Milevichi', 1962236: '?', 1957386: 'Uetersen', 1507674: 'Glinyany', 1904532: '?', 1705263: 'Auxerre', 1041774: 'Blagodarnoe', 4497217: 'Lwówek Śląski', 1005929: 'Pushkino', 1909564: '?', 4485608: 'Żywiec', 1136085: 'Irba', 1153962: 'Chayvo', 1008118: 'Krasny Klyuch', 1949018: '?', 1963225: '?', 1007186: 'Maginsk', 1964733: 'Masterton', 10817: '?', 1013851: 'Mitino', 1929659: 'Lahnstein', 1600782: 'Parafyanovo', 1144167: 'Polovinnoe', 1071813: 'Opukhliki-2', 22402: 'Banff', 1956787: '?', 1010350: 'Streletskoe', 1135647: 'Karapsel', 1701561: 'Burlin', 1505999: 'Korolivka', 1130612: 'Lesnoy', 1962989: '?', 1000541: 'Khozmino', 1508608: 'Velikoalexandrovka', 1963126: '?', 1948799: 'Rokiškio rajonas', 1091468: 'Malaya Dzhalga', 1083798: 'Krotkovo', 1037068: 'Butkan', 1957835: '?', 1086435: 'Tsalyk', 5094405: 'San Andreas', 1509105: 'Budei', 1907328: '?', 1034542: 'Chiplyaevo', 1091541: 'Alexandriyskaya', 1964554: '?', 1709211: 'Altoona', 1514507: 'Timchenki', 1032115: 'Gazoprovod', 1039147: 'Teterinskoe', 1939392: '?', 1002356: 'Koyda', 1113765: 'Goragorsky', 4314768: 'Boutersem', 1952237: 'Shaumyanovsk', 1025051: 'Belogorye', 1928633: 'Pokrovka', 7720: 'Etseri', 1960719: '?', 1964469: '?', 1800321: 'Gradinitsa', 1937554: 'Lysá nad Labem', 1909082: '?', 1030310: 'Mikhaylovo', 1907240: '?', 1157113: 'Ust-Elegest', 1146: 'Lappajärvi', 1067383: 'Khotiml-Kuzmenkovo', 1961492: '?', 5094385: 'Saint Helena', 5095933: 'Yountville', 5259505: 'Gröditz', 1509413: 'Borisovka', 1081767: 'Murmino', 1008869: 'Aleshkino', 1095045: 'Pokrovsky-Urustamak', 1095040: 'Nikolashkino', 1023858: 'Ostrovki', 1059717: 'Vaulovo', 1091474: 'Bashanta', 1917091: '?', 1910612: 'Schiphol', 1517914: 'Alphen aan den Rijn', 1600141: 'Nemerzha', 5266369: 'Meschede', 1152883: 'Panteleymonovka', 1067657: 'Bessonovka', 1505368: 'Bukachevtsy', 1049796: 'Eletskoe', 1111810: 'Artyushkino', 1504711: 'Mirnoe', 1504724: 'Semenovka', 5087136: 'Beacon Falls', 1602862: 'Stary Sverzhen', 1112438: 'Novopokrovka', 1700758: 'Shamalgan Stantsia', 1511314: 'Pogrebki / Korotchenkovo', 1940404: '?', 1975175: 'Penrith', 1700065: 'Oktyabrskoe', 1506242: 'Denikhovka', 1602909: 'Grebenka', 1012447: 'Kuban', 1935109: '?', 1918707: '?', 1600825: 'Bobrovo', 1024295: 'Podgornoe', 1939053: '?', 1128338: 'Atagay', 1914264: 'Ventura', 1160223: 'Maloarkhangelsk', 4396952: 'Claremorris', 1944757: '?', 12518: 'Chik', 1068395: 'Poretskoe', 1909417: 'Mount Vernon', 1136136: 'Chibizhek', 1929152: '?', 1129040: 'Ustyevoe', 1135664: 'Novopokrovka', 1129100: 'Mokhovo', 1000071: 'Elenovskoe', 1136401: 'Kucherovo', 1155076: 'Novoisetskoe', 1077870: 'Gornyatsky', 1123187: 'Tretyakovo', 1112373: 'Atamanovsky', 1511337: 'Orlovka', 1079383: 'Kamyshevka', 1094914: 'Novy Kyrlay', 1507839: 'Velikie Glebovichi', 1159755: 'Bolchary', 1018921: 'Vokhtoga (derevnya)', 1004326: 'Kirovsky', 1960002: '?', 1945811: '?', 1964993: '?', 1602621: 'Videvschina', 1123014: 'Karabinka', 1054164: 'Rogachevo', 2206317: '?', 1511061: 'Rusanovka', 1010103: 'Alexeevka', 1159955: 'Vykatnoy', 1085020: 'Kazachka', 5051664: 'Harvard', 1602245: 'Vasilishki', 1705894: 'Kamenka', 1159443: 'Ochury', 4351842: 'Melchingen', 1014509: 'Kalachevsky', 1509065: 'Kislitsa', 1603280: 'Grodzyanka', 2101241: 'Aktash (narpaysky Rayon)', 1600912: 'Babinichi', 1015542: 'Iskra', 1502220: 'Sursko-Litovskoe', 20375: 'Bokāro', 1927148: 'Los Alamitos', 1505677: 'Velikaya Alexandrovka', 3947: 'Abbots Bromley', 1113981: 'Stemasy', 1704098: 'Madison', 1942999: '?', 1962886: '?', 1708608: 'Anaga', 1010253: 'Lesnoe Ukolovo', 1016371: 'Uritskoe', 1508409: 'Krasnoe', 1006614: 'Bogdanovka', 1006204: 'Voynovka', 1913372: '?', 1145027: 'Pyatiletka', 1964950: '?', 1511526: 'Lisovtsy', 1079917: 'Khleborobnoe', 9043: 'Nizhneivkino', 1714086: '?', 1003114: 'Lugovoy', 1124527: 'Garga', 1501157: 'Ochitkov', 1501148: 'Kozhanka', 1112117: 'Karabaevka', 1903744: 'Muncie', 1150118: 'Egva', 1516558: 'Nura', 1144898: 'Elanka', 1113187: 'Verkhnyaya Sanarka', 1516076: 'Diepholz', 1715076: '?', 1946469: '?', 1514505: 'Stary Kovray', 1934665: '?', 1974244: '?', 1002588: 'Mudyuga ', 1512433: 'Peschanka', 1026068: 'Belidzhi (selo)', 1501767: 'Oblapy', 14024: 'Kuvshinskaya Salma', 5089416: 'Antioch', 1704766: 'Dobromysli', 1500788: 'Mogilevka', 1023966: 'Dyachenkovo', 1965016: '?', 1160117: 'Bilyutuy', 1915300: 'Samokov', 5266242: 'Erkelenz', 1934807: 'Hückelhoven', 1938334: 'Herzogenaurach', 1156646: 'Krasny Yar', 1937033: '?', 1125795: 'Barsovo', 1916797: '?', 1124684: 'Tataurovo', 1009884: 'Ray (poselok)', 1023851: 'Nikolaevka (selo)', 1963381: '?', 1506978: 'Baranikovka', 1016803: 'Krasavino', 1059381: 'Leontyevo', 1913412: 'Cachan', 4429513: 'La Verpillière', 9387: 'Fife', 7807: 'Polyane', 1042068: 'Novovladimirovskaya', 1948650: 'Georgia', 1510045: 'Stepnoe', 1003846: 'Ust-Pinega', 1944220: '?', 1934631: '?', 1513089: 'Vinogradovo', 1917355: 'Eranos', 1026272: 'Kraynovka', 1905582: '?', 5266577: 'Simmern/Hunsrück', 20718: '?', 1516036: '?', 1013156: 'Polniki', 1507841: 'Volkov', 1963631: '?', 1960310: '?', 5266007: 'Oy-Mittelberg', 1706905: '?', 1124522: 'Baragkhan', 1144143: 'Zubkovo', 1078544: 'Rossosh (selo)', 1089130: 'Kukuevo', 1915326: 'Novi', 1513074: 'Shirokoe', 1026210: 'Deybuk', 1961366: '?', 1136539: 'Khaydak', 14722: '?', 1113114: 'Shemakha', 1006020: 'Sabay', 1914236: 'Uusikaupunki', 1513949: 'Staroselye', 1504793: 'Novotavricheskoe', 1501964: 'Tsmini', 1081167: 'Slobodka', 1916218: 'Pfaffenhofen an der Ilm', 1057012: 'Rybkhoz', 1134089: 'Bolshoy Roy', 1156859: 'Kaftanchikovo', 1964203: '?', 5684: '?', 3374723: 'Antsirabe', 1927598: '?', 1058222: 'Elektroizolyator', 1136347: 'Preobrazhensky', 1932226: '?', 1506180: 'Shamraevka', 1154540: 'Bolshebrusyanskoe', 1155689: 'Filkino', 1509311: 'Kamenka', 10099: 'Grekovo-Stepanovka', 1803664: '?', 1096648: 'Shakhmaykino', 1516534: 'Villach', 1151928: 'Aspa', 1965135: '?', 1940999: '?', 1045751: 'Terpilitsy', 1935249: '?', 1136957: 'Solnechny ', 1936342: 'Craig', 1974187: '?', 1144971: 'Pokrovka', 1709186: 'Albemarle', 1500528: 'Dachnoe', 13905: 'Gorbatov', 1035823: 'Nilmoguba', 1085991: 'Novokrivovka', 1510952: 'Podlipnoe', 1085657: 'Staraya Porubezhka', 1508377: 'Ingulka', 1948029: '?', 1145479: 'Strokino', 1086226: 'Probuzhdenie', 1115633: 'Ivanovo (derevnya)', 1927135: 'Roquetas de Mar', 1954006: '?', 1160527: 'Ust-Kara', 1516163: 'Stayki', 1146961: 'Staromukmenevo', 1964582: '?', 1927236: '?', 5334657: '?', 1950507: '?', 1518467: 'Veresnitsa', 1901377: '?', 1949034: '?', 1059606: 'Nikolo-Kropotki', 1502708: 'Yuryevka', 1502694: 'Varvarovka', 1514371: 'Polyanetskoe', 1508837: 'Zadunaevka', 9696: 'Kingston', 1111296: 'Chufarovo', 1500249: 'Novopavlovka', 1138015: 'Kamyshnoe', 1030032: 'Kolobovo (pgt)', 1028455: 'Shileksha', 1503023: 'Rubtsy', 1059968: 'Osanovo-Dubovoe', 19533: 'Vitimsky', 1516430: '?', 1965123: '?', 1063759: 'Novoselsky', 1933487: 'Delphi', 1941099: '?', 1515060: 'Irzhavets', 1025230: 'Rossosh (selo)', 1080643: 'Lesunovo', 1035381: 'Erkin-Khalk', 1504749: 'Timoshovka', 1003362: 'Mikhalevo', 17333: 'Cuernavaca', 1943514: '?', 1086459: 'Nogir', 1041138: 'Boykoponura', 1602608: 'Lugovaya Sloboda', 1961342: '?', 5023524: 'Old Saybrook', 1005560: 'Nukatovo', 1009573: 'Staraya Nelidovka', 1086413: 'Osetinskaya', 1715708: 'Kankan', 1503093: 'Sartana', 1906759: 'Tavaxay', 1041661: 'Unarokovo', 1916853: 'Rotenburg (Wümme)', 1062621: 'Sergovo', 1003673: 'Lomonosovo', 1111980: 'Gladchikha', 4294780: 'Mayerhöfen', 1965258: '?', 2705106: 'Liudvinavas', 10223: '?', 1142199: 'Voskresenskoe', 1600254: 'Zeleny Bor', 1964178: '?', 1504688: 'Kamysh-Zarya', 4503433: 'Giebułtów', 5261834: 'Herne', 1962510: '?', 1914615: '?', 1053253: 'Stary Gorod', 13283: 'Kaskara', 1050160: 'Verkhnyaya Kolybelka', 1964490: '?', 1910913: '?', 1949422: '?', 1900899: 'Peduel', 1516290: 'New Rochelle', 2207724: '?', 1150235: 'Piter (derevnya)', 1922928: '?', 1057122: 'Kalchuga', 1713379: '?', 1710579: 'Cookeville', 1949023: '?', 1041269: 'Prototskie', 1705919: '?', 1507202: 'Lagidnoe / Komsomolsky', 1508427: 'Visunsk', 1965340: '?', 4660244: 'Trench Town', 1504370: 'Keretski', 1910916: '?', 1707280: '?', 5387558: 'Bundoran', 1800074: 'Belyavintsy', 1715598: '?', 1708663: 'Castle Rock', 1709241: 'Arkansas City', 1957192: '?', 1956283: 'Cuneo', 1965341: '?', 1122696: 'Zhuravlikha', 1144098: 'Bystrukha', 1711976: 'Galesburg', 1516079: '?', 1965359: '?', 1903609: '?', 1111779: 'Verkhnyaya Maza', 1160155: 'Atamanovka', 1700867: 'Kegen', 1950537: 'Voznesenovka', 4946176: 'Boutte', 1135350: 'Elovoe', 1938064: '?', 1959345: '?', 1152963: 'Yuzhno-Morskoy', 1503203: 'Novozaryevka', 1144075: 'Prokudskoe', 17673: 'Mitzpe Ramon', 1159240: 'Chlya', 1007899: 'Telyashevo', 5110880: 'Milwaukie', 5056251: 'West Caldwell', 1803450: 'Shizuoka', 1141521: 'Kremenki', 1141476: 'Barmino', 1091602: 'Peredovoy', 1147945: 'Donetskoe', 1052335: 'Petrovka', 1052315: 'Ardatovo', 1156142: 'Verkhovino', 1072696: 'Shukhovo', 1145175: 'Trubetskoe', 1504080: 'Karpovtsy', 1503040: 'Krinichnaya', 1963614: '?', 1500275: 'Krasnogorka', 1025522: 'Kozlovka', 1965432: '?', 1084880: 'Industrialny', 1516855: 'Yambol', 1505701: 'Chubinskoe', 1500471: 'Mirnoe', 1506155: 'Velikopolovetskoe', 1518776: 'Fátima', 4038250: 'Urqueira', 19467: 'Elantsy', 1066796: 'Pokrovskoe', 1066827: 'Fedorovka', 1002244: 'Tyva (stantsia)', 1801084: 'Pokrovka', 11531: 'Kuchugury', 1507888: 'Zimnyaya Voda', 1511455: 'Porokhova', 1514987: 'Khoroshee Ozero', 1157081: 'Chadan', 1014526: 'Chernolagutinsky', 1901658: '?', 1956464: '?', 1938477: 'Roselle Park', 1974895: 'Skrīveri', 1802474: '?', 1052144: 'Novochadovo', 1500540: 'Kurortnoe', 1514184: 'Nabutov', 1031044: 'Kostrovo', 1082142: 'Sasovsky', 5266666: 'Backnang', 21069: '?', 1021954: 'Pavlovskaya', 1965492: '?', 1501500: 'Penkovka', 1091436: 'Kazinka', 1123075: 'Anisimovo', 1501347: 'Savintsy', 1124727: 'Selenduma', 1504329: 'Poroshkovo', 1108801: 'Malyn', 1161366: 'Stepnoe', 1052771: 'Tokmovo', 1510081: 'Belyaki', 1954420: '?', 1153217: 'Bezverkhovo', 1126403: 'Muromsky', 1958934: '?', 1064322: 'Gorodische', 11544: 'Utorgosh', 1707713: '?', 1709679: 'Sisak', 1153985: 'Sabo', 1925005: '?', 1124448: 'Ivanovka', 1948857: '?', 5266855: 'Trochtelfingen', 1921387: '?', 1968288: '?', 1968289: '?', 1710215: 'Sipoteny', 1961257: '?', 1159846: 'Vonegan', 1926774: '?', 1083720: 'Barinovka', 2437: 'Voloma', 1128854: 'Kasyanovka', 1124628: 'Tugnuy', 1906833: '?', 1501129: 'Sitkovtsy', 1086422: 'Troitskoe', 1135734: 'Taloe', 1502483: 'Gavrilovka', 17842: 'Harrogate', 1930711: '?', 1075935: 'Suchischi', 1909414: 'Udzharma', 1945413: '?', 1004957: 'Bolotino', 1509514: 'Veprik', 1135625: 'Romanovka', 19666: 'Yargara', 1500214: 'Muskatnoe', 1124205: 'Malovsky', 1079692: 'Bolshinka', 22423: 'Glavani', 1509555: 'Zemlyanki', 1115199: 'Bolshie Katrasi', 1501475: 'Strateevka', 19794: 'Krasny Mayak', 1511305: 'Bogdanovka', 5265219: 'Bad Füssing', 1141373: 'Veletma', 1917825: '?', 1964190: '?', 1937963: '?', 1908446: '?', 1122565: 'Pokrovka', 1958999: '?', 1015404: 'Belyaevka', 861: 'Kandy', 1142658: 'Tatarskoe Maklakovo', 2500263: 'Rosrovut', 1082993: 'Pesochnoe', 1943598: '?', 1091510: 'Arkhipovskoe', 1963350: '?', 1518740: 'Kanto', 15463: 'Brandenburg an der Havel', 5264479: 'Friesenheim', 1123366: 'Marushka', 1517247: 'Lahr/Schwarzwald', 5259520: 'Pirna', 5266378: 'Kierspe', 1510717: 'Obarov', 1123361: 'Voevodskoe', 1500204: 'Krasnaya Polyana', 1504031: 'Yasnaya Polyana', 1085619: 'Kamenka', 1023949: 'Yudanovka', 1095414: 'Vysokaya Gora', 21979: 'Chevy Chase', 16860: 'Zelenolugsky', 1079431: 'Bogoroditskoe', 1026364: 'Kurakh', 16484: 'Melikhovskaya', 1068476: 'Bikmurzino', 1079836: 'Kerchixky', 1515153: 'Desnyanskoe / Sverdlovka', 1007865: 'Bolshaya Oka', 1511800: 'Skoriki', 4292945: 'Petzenkirchen', 1127457: 'Londoko', 1518513: 'Uzunkol', 20521: 'Radischevo', 1940067: '?', 1509009: 'Kubey / Chervonoarmeyskoe', 1961603: 'Butzbach', 1943431: '?', 1109884: 'Sep', 1002240: 'Sukhodol', 5267825: 'Friedberg (Hessen)', 1901789: 'Yaypan', 4921770: 'Aventura', 1091985: 'Orekhovka', 1701310: 'Kamyshenka', 1936833: '?', 1916017: 'Iecava', 1112084: 'Severny', 1601792: 'Nisimkovichi', 4696320: 'Morris Loobys', 1093795: 'Staroalexandrovka', 1509917: 'Khomutets', 1919607: '?', 1934539: '?', 20849: 'Danville', 1517088: 'Lake Forest', 1012835: 'Svyatsk', 4698491: 'Santa Ana', 1086341: 'Fiagdon', 1026232: 'Aknada', 1944339: 'Gallipoli', 1964941: '?', 1912529: '?', 1126507: 'Kirzhach', 1953141: '?', 3985684: 'Kokoda', 4542150: 'Pontecagnano Faiano', 1956090: '?', 1963950: '?', 1036317: 'Vedlozero', 1501999: 'Samary', 1963630: '?', 1937404: '?', 1900099: 'Nitzanei Sinai', 1024731: 'Drozdovo', 1917469: 'Acerra', 1091476: 'Kamennaya Balka', 1077699: 'Zaymo-Obryv', 1080586: 'Ekshur', 1126840: 'Rozhdestveno', 1702053: 'Arka (krasnooktyabrskoe)', 1010240: 'Gotovye', 1962319: '?', 1001341: 'Shiryaikha', 1511672: 'Budki', 1076005: 'Cherekha', 1503663: 'Berezovka', 1924572: '?', 1081984: 'Napolnoe', 4038875: 'Santa Suzana', 1949734: '?', 1966920: '?', 1954740: '?', 1920036: 'Springfield', 1960997: '?', 4487752: 'Wieruszów', 1713692: '?', 1965881: '?', 1127718: 'Moygan', 1502269: 'Druzhba', 1159844: 'Bolshoy Kamen', 1158796: 'Zakuley', 1710488: 'Columbus', 1503457: 'Bykovka', 1705007: 'Leninskoe', 1159358: 'Vyatskoe', 1129341: 'Drachenino', 1050382: 'Toshner', 1153620: 'Nyurbinsky', 1121902: 'Baevo', 1957253: 'Donghae', 1020009: 'Charozero', 1033337: 'Popelevo', 1507660: 'Soposhin', 1920510: 'Vineland', 1966613: '?', 5168087: 'Puigcerdà', 1907669: '?', 1932250: '?', 1965958: '?', 1085685: 'Privolnoe', 1504043: 'Gorodische', 1150336: 'B.brody', 10720: 'Burbank', 1965345: '?', 1155019: 'Chernovskoe', 1159333: 'Sofiysk', 4714130: 'Gonzora', 1159961: 'Kedrovy', 1024829: 'Petropavlovka', 1702072: 'Boskol', 1025688: 'Butri', 1153459: 'Tomtor', 3260706: 'Zográfos', 1500091: 'Rusakovka', 1008372: 'Otradovka', 1067447: 'Shablykino', 1512868: 'Rovnoe', 1124630: 'Kharashibir', 1146667: 'Tatarka', 1701071: 'Peschanka', 18806: 'Megrega', 8048: 'Lazarevo', 1924937: 'Doetinchem', 4234523: 'Longside', 1059685: 'Podrezkovo', 1114926: 'Chemeevo', 1700750: 'Turar', 1949646: '?', 18014: 'Lipovtsy', 1143281: 'Rozhentsevo', 1018616: 'Ezhezersky Pogost', 1012536: 'Lotaki', 1140736: 'Dubrava', 1946368: '?', 1965982: '?', 1007680: 'Bakhmut', 1505957: 'Buzova', 5054812: 'Edgewater', 1907614: '?', 2955: '?', 1946203: '?', 1965995: '?', 1973824: 'Pohlheim', 1903599: 'Plymouth', 1518738: 'Quincy', 1928585: '?', 1714179: '?', 1128304: 'Zayarsk', 1500370: 'Novoselovskoe', 4441228: 'Épernon', 1803605: 'International Falls', 1067916: 'Kamenny Brod', 1928244: '?', 14461: 'Falileevo', 1047507: 'Sisto-Palkino', 1156116: 'Smolinskoe', 1148299: 'Burdygino', 1505340: 'Delyatin', 1140793: 'Surovatikha', 1031245: 'Dubovaya Roscha', 1963227: '?', 1160432: 'Novaya Zarya', 1041907: 'Lvovskoe', 1966032: 'Subate', 21803: 'Azur', 1512881: 'Bekhteri', 16837: 'Dunaújváros', 1159809: 'Cheuskino', 1042242: 'Goytkh', 20896: 'Sosnovka', 1901664: '?', 17925: 'Recife', 9592: 'Talovka', 1926994: '?', 1703823: '?', 1518875: 'Teddington', 1601311: 'Uritskoe', 1502553: 'Slavgorod', 1148355: 'Kindelya', 4512043: 'Santurtzi', 1157970: 'Chugunaevo', 1921516: '?', 1058048: 'Donino', 1705853: '?', 1914514: '?', 1918853: '?', 5343: '?', 3960741: 'Yanji', 18790: 'Grachevka', 5124804: 'Emo', 1109878: 'Pravaya Kushya', 1500738: 'Zyatkovtsy', 1958096: '?', 10412: 'Parkano', 1708850: 'Ghazni', 1517719: 'Oak Ridge', 1511439: 'Zolotoy Potok', 21998: 'Katon Karagay', 19580: 'Pyatkovka', 1508419: 'Tronka', 4268010: 'Botkyrka', 21869: '?', 1602382: 'Pugachi', 1958445: '?', 1956266: '?', 1004880: 'Kashkino', 5053431: 'East Washington', 1942106: '?', 1941734: '?', 20109: 'Greenock', 1963541: '?', 1134613: 'Kladbische', 1956471: '?', 4629: 'Peski', 19180: 'Naumovka', 1966124: '?', 1966154: '?', 5266480: 'Dillenburg', 1514279: 'Khalaydovoe', 1713478: '?', 1516764: 'Ashburn', 1029114: 'Vanino', 1963768: '?', 1023785: 'Fedotovo', 1000165: 'Otradny', 1083467: 'Klyavlino', 1158437: 'Pyatkovo', 1079634: 'Zelenaya Gorka', 2722451: 'Shubra El-Kheima', 21872: 'Talsi', 1957770: '?', 1500600: 'Bar Vokzal', 1959623: '?', 1713267: 'Huddinge', 1150107: 'Gurina', 1033707: 'Kudinovo', 1142271: 'Kalifornia', 1500282: 'Mysovoe', 1935318: '?', 1962337: '?', 1512164: 'Khvorostovo', 1501582: 'Brany', 21874: 'Epsom', 1603297: 'Yasen', 1511618: 'Ozerna', 1966183: '?', 1034295: 'Borischevo', 1943096: 'Gagarin', 1966848: '?', 1962129: '?', 1147840: 'Priuralsky', 1134237: 'Talitsa', 1962489: '?', 1078084: 'Romanovskaya', 1113383: 'Peschanoe', 1971461: '?', 1507828: 'Chernevo', 1158512: 'Revda', 2210474: 'Mestre', 5266568: 'Weißenthurm', 1044507: 'Goncharovka', 1121717: 'Amur', 1702391: 'Fort Shevchenko', 1130347: 'Vyshka', 1518573: 'Eralievo', 1067956: 'Vladykino', 1509545: 'Bugaevka', 3257693: 'Kuklen', 1709562: 'Kavarna', 1511604: 'Zalozhtsy', 2201342: 'Nida', 1714178: '?', 1961954: '?', 1936537: '?', 5428914: 'Kalkaman', 1908332: '?', 5260765: 'Handewitt', 1500911: 'Samgorodok', 16886: 'Roslyatino', 1085265: 'Podlesnoe', 1004788: 'Azovo', 5266809: 'Oppenau', 1063139: 'Okhona', 1141608: 'Pozdnyakovo', 1081898: 'Shatskaya', 1503050: 'Berdyanskoe', 1511832: 'Burkanov', 1153837: 'Tabaga', 1923819: '?', 1155445: 'Murzinka', 5261767: 'Weilerswist', 2029: 'Kirovskoe', 1602983: 'Nikonovichi', 1602988: 'Polyaninovichi', 1965548: '?', 1510958: 'Sosnovka', 1957229: '?', 1932854: '?', 1512303: 'Borovaya', 5266446: 'Kelkheim (Taunus)', 5261891: 'Kriftel', 5093102: 'Morgan Hill', 1966225: '?', 1500123: 'Maslovo', 1154396: 'Afanasyevskoe', 1125747: 'Orgtrud', 5266210: 'Viersen', 1926470: '?', 1946984: '?', 1917999: '?', 1085837: 'Krasavka', 1503955: 'Potievka', 1957296: 'Prienai', 1144394: 'Dubrovka', 1966243: '?', 1040979: 'Ventsy', 1147468: 'Krasnoschekovo', 4044298: 'Alcochete', 1934643: 'Moita', 1502785: 'Zelenoe Pole', 1020390: 'Shonga', 5057374: 'Chappaqua', 1910049: '?', 1939049: '?', 1910268: '?', 1148160: 'Tselinny', 1935025: '?', 1945470: '?', 1600773: 'Begoml', 1147811: 'Dedurovka', 1949596: '?', 1050268: 'Novopolyanye', 1501524: 'Velikaya Kosnitsa', 1506783: 'Nikolskoe', 1513993: 'Konela', 1515830: '?', 1800619: 'Kosteshty', 1964041: '?', 1506106: 'Stovpyagi', 1058635: 'Loza', 1033115: 'Rezvan', 1601591: 'Golovchitsy', 1944166: '?', 5413490: 'Le Milan', 1700458: 'Khabalovka', 1964501: '?', 1909459: '?', 1929160: '?', 1934928: '?', 1029902: 'Ivankovo', 1500919: 'Shirokaya Greblya', 1122203: 'Voronezh (poselok)', 1902912: 'Lekbatan (karadag)', 1509074: 'Pershotravnevoe', 1500448: 'Donskoe', 1500441: 'Verkhnekurgannoe', 1937377: 'Acharkut', 5055400: 'Middlesex', 1159167: 'Oktyabrsky', 9590: 'Dębica', 1933297: 'Aralez', 1129886: '?', 1923242: '?', 1601266: 'Velikie Nemki', 1508167: 'Stary Sambor', 1514721: 'Orshovtsy', 1966309: '?', 1966385: 'Kuusankoski', 1519216: '?', 1800479: 'Ilenutsa', 1506274: 'Motovilovskaya Slobodka', 1937444: '?', 1708738: 'Gyorogly', 1501162: 'Skomoroshki', 1026639: 'Myurego', 1503647: 'Kremnoe', 1966307: '?', 1159683: 'Kolodezny', 1022089: 'Volosovo', 1960318: '?', 1500504: 'Dmitrovka', 1007096: 'Krasny Kholm', 1929063: 'Ciudad del Este', 1950735: 'Orkanger', 1041615: 'Novoplatnirovskaya', 5355: 'Spasskaya Guba', 1155233: 'Kriulino', 1929534: '?', 12498: 'Eger', 1025790: 'Khnov', 1965321: '?', 1014314: 'Medveditsa', 1934088: '?', 1144395: 'Egoryevskoe', 1921694: '?', 5353285: 'Augsburg (Schwesing)', 3830663: 'Asan', 1600020: 'Velikie Luki', 1015244: 'Raygorod', 1919532: 'Sremska Mitrovica', 1957302: '?', 1919397: 'Richlands', 1966362: 'Aygepar', 5266396: 'Lippstadt', 1056298: 'Krasnovidovo', 1056230: 'Goretovo', 1962035: '?', 1153397: 'Altantsy', 1132976: 'Khalturiny', 1514022: 'Vodyaniki', 19952: 'Taskan', 1518741: 'Novorybinka', 1963501: '?', 1157567: 'Kotochigi', 4686053: 'Acapulco de Juárez', 1159612: 'Malye Arbaty', 1159806: 'Singapay', 1706528: '?', 1971172: '?', 1057095: 'Dubki', 1502857: 'Kirillovka', 1966386: 'Maple Ridge', 1958425: 'Krempe', 1086233: 'Ternovka', 1904707: 'Ellesmere', 1937208: '?', 1916350: '?', 1802332: '?', 1954372: '?', 1156850: 'Zorkaltsevo', 1950008: '?', 1938588: '?', 1966407: '?', 1966414: '?', 1500182: 'Sinitsyno', 1130779: 'Chekashevo', 1500203: 'Kotelnikovo', 1007053: 'Yanurusovo', 1963916: '?', 1963930: '?', 1964045: '?', 1509356: 'Kulevcha', 3130208: 'Kaména Voúrla', 1505980: 'Khodosovka', 1509119: 'Slobodka', 1500244: 'Krasnoarmeyskoe', 1514532: 'Signaevka', 1922236: '?', 1803226: 'Türi ', 1902795: '?', 1093377: 'Vasilyevo', 1509748: 'Belsk', 1602584: 'Petrishki', 1154088: 'Kostromskoe', 1507920: 'Staroe Selo', 1077834: 'Elkin', 1508927: 'Zatoka', 1901080: 'Even Ehuda', 1136477: 'Svetlolobovo', 1801828: 'Helena', 1968656: '?', 5106043: 'East Helena', 1129634: 'Bolshaya Talda', 1968484: '?', 1041460: 'Urmia', 1963683: '?', 1601233: 'Bushevka', 1127913: 'Dzerzhinsk', 1113190: 'Demarino', 1038305: 'Zavrazhye', 1038287: 'Borisoglebskoe', 1966491: '?', 1007458: 'Novy Kainlyk', 1023219: 'Myaxa', 1902154: '?', 1145557: 'Panovo', 1955059: '?', 1958787: '?', 1954503: '?', 1501922: 'Yagodin', 1957540: '?', 1959425: '?', 1129714: 'Abyshevo', 1154574: 'Studenchesky', 1107544: 'Petelino', 1505282: 'Turka', 1134987: 'Barkhatovo', 4466040: 'Veľké Úľany', 2204970: '?', 1057023: 'Stromyn', 1508083: 'Karov', 1508114: 'Ugnev', 1014600: 'Pokhlebin', 1960425: '?', 1602002: 'Raytsa', 1512025: 'Pyatigorskoe', 1514496: 'Mikhaylovka', 1966577: '?', 1950098: '?', 1114818: 'Ilinka', 1501435: 'Torchin', 1135092: 'Vagino (poselok)', 1115310: 'Khachiki', 8377: '?', 1057652: 'Bykovka', 1956809: '?', 1147119: 'Derzhavino', 1026427: 'Shovkra', 1026399: 'Kumukh', 1966564: '?', 1123201: 'Eltsovka', 1000062: 'Adamy', 1112237: 'Raduzhny', 1122706: 'Logovskoe', 1060129: 'Murikovo', 1147935: 'Adamovka', 1702186: 'Beregovoe', 1146669: 'Cherlak', 1159937: 'Sytomino', 1942170: 'Berlin', 1919783: '?', 1514569: 'Chernoguzy', 4964149: 'Savannah', 1041836: 'Oktyabrsky', 1513470: 'Slobodka-Rikhtovskaya', 4640383: 'Colonia del Sacramento', 1126650: 'Malyshevo', 1707195: 'Nor Artamet', 1128762: 'Verkhnemarkovo', 1095768: 'Krasny Yar', 1004460: 'Mirny', 1007149: 'Atamanovka', 1057516: 'Sobolevo (sobolevsky S/o)', 1058856: 'Podkhozhee', 1500195: 'Zernovoe', 1042337: 'Bezlesny', 1109301: 'Sergino', 1922630: 'Anttola', 1129284: 'Yagunovo', 1506726: 'Protopopovka', 1144901: 'Kozino', 1141276: 'Zaprudnoe', 1153385: 'Uluu', 1931167: '?', 1518116: 'Ivanovka', 1109310: 'U Rechki Danilovka', 1127615: 'Kezhemsky', 1956826: '?', 1967499: '?', 1919611: '?', 1600636: 'Sarya', 14221: 'Califon', 1910351: 'Beverley', 1161020: 'Vosyakhovo', 1129729: 'Kalinkino', 1800850: 'Naslavcha', 3220043: 'Kokkola (Karleby)', 1515972: '?', 1957184: '?', 1126667: 'Novy Byt', 1956409: '?', 1159460: 'Birikchul', 1966672: '?', 5111368: 'Vernonia', 1038509: 'Volzhsky', 1907140: '?', 1513632: 'Krasnostav', 1965253: '?', 1126704: 'Aserkhovo', 1900036: 'Kedma', 1943594: '?', 1602401: 'Boroviki', 1713382: '?', 1953749: '?', 1052663: 'Pushkino', 16473: 'Manychskoe', 2585: 'Batyrevo', 1111263: 'Beketovka', 1052472: 'Lesnoy', 1933812: '?', 1959954: '?', 1963926: '?', 1519272: '?', 1955449: '?', 1109438: 'Novy', 1709208: 'Alpine', 1506937: 'Ivanovka', 1931387: '?', 1027495: 'Kamenka', 1502982: 'Grodovka', 1158467: 'Lesnoe', 1948724: '?', 4468921: 'Bošany', 1067875: 'Otorma', 15990: 'Dvubratsky', 1510850: 'Sloboda', 22236: 'Alexeevo-Druzhkovka', 1910387: '?', 1502371: 'Sholokhovo', 1513946: 'Orlovets', 1512771: 'Chernobaevka', 1936735: '?', 1035734: 'Ussuna', 4432580: 'La Garenne-Colombes', 5303514: 'Bois-Colombes', 1131194: 'Doronichi', 1113663: 'Vedeno', 1934604: '?', 1514966: 'Komarovka', 1155496: 'Baronskaya', 1967583: '?', 1109740: 'Lyuk', 1513179: 'Maydan-Alexandrovsky', 1150694: 'Filippovka', 1601756: 'Sosnovy Bor', 1500429: 'Shelkovichnoe', 1053077: 'Tatarskaya Pishlya', 1705521: 'Ware', 1092173: 'Yasny', 1004782: 'Shafranovo', 1090239: 'Loino', 1510097: 'Krivaya Ruda', 1036368: 'Matrosy', 1959367: '?', 1507680: 'Zozuli', 1964106: '?', 1508543: 'Kozubovka', 1703941: '?', 1708312: 'Varennes', 5127411: 'Mont-Saint-Hilaire', 4232305: 'Prestbury', 1509415: 'Glubokoe', 1710276: 'Maple Grove', 1500723: 'Khizhintsy', 1956385: '?', 1956378: '?', 3180652: 'Wad Madanī', 1500501: 'Almaznoe', 1938471: '?', 5460712: 'Oktyabrsky', 1502417: 'Boguslav', 1600676: 'Zadubovye', 1706133: 'Surazh', 1904688: '?', 4486966: 'Września', 1705810: 'Joure', 1141230: 'Ovechy Ovrag', 1131159: 'Paska', 1710771: 'Pearland', 1516457: '?', 1515391: 'Pavlovka', 1133959: 'Vynur', 1133988: 'Nyr', 5243313: 'Alcúdia', 1508635: 'Kuryachi Lozy', 1966763: '?', 1906364: 'Le Locle', 1704069: 'Malech', 1119695: 'Shurskol', 1966932: 'Tsakkar', 1936673: '?', 1966959: 'Bokurdak', 1515164: 'Kamka', 18664: 'Baytown', 1602545: 'Osovets', 1601910: 'Lososna', 1136359: 'Stepnoy', 1129569: 'Osinovoe Pleso', 1128235: 'Lermontovsky', 1124676: 'Mostovka', 1030394: 'Nizhnie Achaluki', 1094594: 'Yalkyn', 1966931: '?', 1948698: '?', 1044229: 'Marino', 1159245: 'Bulgin', 1035515: 'Kyzyl-Yurt', 1054415: 'Tsos Viua ', 3784570: 'Yibin', 3781889: 'Zigong', 1703517: 'Bradfield', 1146254: 'Verblyuzhye', 1114522: 'Starye Vysli', 1928435: '?', 1157175: 'Bert-Dag', 1147450: 'Zianchurino', 1501512: 'Strelniki', 1113360: 'Karsy', 1092211: 'Ozerny', 1702583: 'Lavrovka', 1703743: 'Attleboro', 22065: '?', 1928431: '?', 1157610: 'Golyshmanovo', 1111856: 'Srednyaya Tereshka', 1111422: 'Bezvodovka', 1109408: 'Gavrilovka', 1122147: 'Shatunovo', 1514435: 'Russkaya Polyana', 1702684: 'Petrovka', 1961420: '?', 1158113: 'Baykalovo', 1936056: '?', 1952070: '?', 1501716: 'Zhuravichi', 1936584: '?', 1141948: 'Madaevo', 1122880: 'Novosklyuikha', 1706219: 'Roosendaal', 1091600: 'Novoizobilny', 1508429: 'Lepetikha', 1703178: '?', 1502201: 'Voloskoe', 1018729: 'Oshta', 1129480: 'Abagur', 1906709: '?', 1083181: 'Lopatino', 1158088: 'Pokrovka', 1904315: '?', 1030462: 'Svetlovodskoe', 1921566: 'Strumitsa', 1094568: 'Mokrye Kurnali', 1515446: 'Chernotichi', 1952773: '?', 1141882: 'Medyana', 2608736: '?', 1144731: 'Uskyul', 1068884: 'Lipleyka', 1600765: 'Marchenki', 1040820: 'Kuleshovskoe', 1966651: '?', 11592: 'Gmelinka', 1935576: 'Hershey', 11211: 'Kompaneevka', 1108665: 'Chern', 1079038: 'Sulinsky', 7011: 'Shumovo', 1518591: 'Varese', 1055272: 'Taraskovo', 1518242: '?', 1967143: '?', 1919698: '?', 1965611: '?', 1965453: 'Naujoji Akmenė', 1955654: '?', 1153512: 'Promyshlenny', 1512951: 'Novokievka', 7448: 'Strizhi', 1508924: 'Vygon', 1152945: 'Prokhladnoe', 1136737: 'Irkutskoe', 5305276: 'Roche-lez-Beaupré', 1500061: 'Kholmovka', 1003095: 'Kukushka', 1949109: 'Rockenhausen', 1093234: 'Staroklenskoe', 1943070: '?', 1516401: 'Winchester', 1085962: 'Tarkhany', 1060267: 'Nikiforovo', 1935444: '?', 1514421: 'Budische', 1947539: '?', 1602042: 'Bolshie Ozerki', 5120878: 'Wailuku', 1155179: 'Kytlym', 1968905: '?', 22643: '?', 1500866: 'Pavlovka', 1967180: '?', 1959234: '?', 1516209: '?', 1005474: 'Nogushi', 1068630: 'Belyn', 1124046: 'Bamovskaya', 1118523: 'Kukoboy', 1961329: '?', 1127756: 'Khanzhinovo', 1054595: 'Popovskaya', 1083402: 'Domashka', 1501239: 'Zaluzhye', 1926641: '?', 1930320: 'Hendersonville', 1933285: 'Gorizia', 1098337: 'Kaftino', 1913108: '?', 1707544: '?', 1007742: 'Taymasovo', 1910969: '?', 2722459: 'Diyarbakır', 1152975: 'Lipovtsy', 1512873: 'Strelkovoe', 1701651: 'Zhympity', 1110295: 'Kurya', 1119570: 'Novo-Nikolskoe', 1500201: 'Kolodeznoe', 1952809: 'Vinderup', 1053479: 'Im Baumana', 1001723: 'Slobodskoy', 1131169: 'Selino', 1146191: 'Novotroitsk', 1030834: 'Guryevsk-Novy', 1602358: 'Izha', 1134891: 'Malinovka', 1952782: '?', 1909010: '?', 1955695: '?', 1910325: '?', 1927374: 'Noratus', 1502866: 'Starchenkovo', 1600414: 'Oltush', 4497595: 'Łowicz', 1022743: 'Punduga', 1928432: '?', 4442435: 'Dax', 1508012: 'Rudki', 1909786: 'Tahoe City', 17793: 'Kovalevo', 1602771: 'Zeleny Bor', 1916221: 'Évreux', 4462505: 'Hajmáskér', 1134345: 'Novaya Ukazna', 1960858: '?', 1953221: '?', 7211: 'Pyschug', 1928231: '?', 18093: '?', 1947892: '?', 1096864: 'Kugarchino', 18111: 'Ozerki', 1500459: 'Konstantinovka', 1093134: 'Dmitrievka', 1964536: '?', 1600118: 'Ogarevichi', 1121898: 'Starobelokurikha', 1074123: 'Velsk', 1933031: '?', 1910774: '?', 1121963: 'Novikovo', 1939977: '?', 1708263: '?', 1967318: '?', 1967324: '?', 1504107: 'Batyevo', 1504177: 'Korolevo', 17945: 'Gedabek', 4276409: 'Ílhavo', 1962157: '?', 1092172: 'Tsimlyansky', 1107288: 'Zibarovka', 1510521: 'Krilov', 5232066: 'Bastia', 1949799: 'Staubing', 5261808: 'Recke', 1900932: 'Barkan', 1122838: 'Guseletovo', 1962664: '?', 1922458: '?', 1913549: '?', 1906045: '?', 1500145: 'Svetloe', 1702625: 'Dauit (kuybyshevskoe)', 1145011: 'Karasevo', 1051186: 'Rim', 1961313: '?', 1902954: '?', 1111198: 'Izmaylovo', 1911019: '?', 1014177: 'Samofalovka', 1054009: 'Kamenka', 1113879: 'Serzhen-Yurt', 1600942: 'Orekhovsk', 1014753: 'Bezymyanka', 1514965: 'Kinashovka', 1144766: 'Zlatoust', 1004541: 'Selitrennoe', 3214836: 'Säviä', 1707715: 'Pielavesi', 1046196: 'Rappolovo', 21662: 'Kiuruvesi', 1005386: 'Kanash', 1708185: 'Phoenixville', 1908318: '?', 1956996: '?', 1055546: 'Chaykovskogo', 1504879: 'Preslav', 1923639: '?', 7368: 'Barsukovskaya', 1910685: '?', 1122763: 'Kotlyarovka', 4323489: 'Vogelsang', 1042827: 'Lev-Tolstovsky', 1916008: '?', 1011013: 'Shebekinsky', 1948686: '?', 1504810: 'Konskie Razdory', 1113150: 'Krutoyarsky', 1924005: '?', 1707154: 'Nowa Sól', 1714104: '?', 1702234: 'Chisty Chandak', 1963325: 'Camrose', 15368: 'Timashevka', 1600093: 'Telmy', 1715334: '?', 1900031: 'Neve Zoar', 1967470: '?', 1967475: '?', 4159: 'Bridgeport', 1967476: '?', 1602842: 'Schitkovichi', 1124440: 'Vydrino', 1153354: 'Beltsovo', 1122325: 'Tselinny', 1153034: 'Novitskoe', 5427610: 'Barashki', 1961205: '?', 1161101: 'Nizhnyaya Pesha', 1122229: 'Mirny', 1519029: 'Eišiškės', 1040869: 'Novoalexeevskoe', 1050481: 'Kuznetsovo', 1159780: 'Ushya', 1966764: '?', 1911233: '?', 1038168: 'Orekhovo', 1028132: 'Kovarchino', 1015642: 'Parizhskaya Kommuna', 1967524: 'Penfield', 1511198: 'Perekrestovka', 22445: '?', 1123819: 'Yubileynoe', 1967523: '?', 1708339: '?', 1800394: 'Drokia (sel.)', 1901130: 'Tirat Carmel', 3390495: 'Napa Beau', 1944568: 'Moroni', 1153741: 'Ust-Aldansky', 1703020: 'Karasu', 2201617: 'Madera', 1500791: 'Pochapintsy', 3828112: 'Gimhae', 1711973: 'Ikot Abasi', 1965208: '?', 1900193: 'Neot Golan', 1705140: 'Henderson', 1970821: '?', 1512268: 'Prudyanka', 1908946: '?', 5432085: 'Jüri', 1072415: 'Bologoe', 1601511: 'Kamenka', 1072440: 'Gorozhane', 1517956: '?', 12018: '?', 20563: 'Starotimoshkino', 1153312: 'Koksharovka', 1955166: '?', 1021449: 'Orlovskaya', 1500664: 'Putevaya', 1500672: 'Tyrlovka', 1710353: 'Taylak', 1711560: '?', 1902836: '?', 1122351: 'Ukrainsky', 1954438: '?', 1091550: 'Novozavedennoe', 1113213: 'Berezovy Most', 1966489: 'Terter', 1084541: 'Raduzhny', 13294: 'Izhevskoe', 1701042: 'Mamyrsu (sergiopol)', 1700671: 'Kargaly', 1700025: 'Michurino', 1927617: 'Locarno', 1967347: '?', 1955145: '?', 1501966: 'Chernizh', 1949477: '?', 1967647: '?', 1009121: 'Kara-Yakupovo', 4558446: 'Pirovac', 1092042: 'Etoka', 1153884: 'Sovetskoe', 5104389: 'Cleveland', 4986173: 'York', 1973745: '?', 1905098: '?', 1032963: 'Chubarovo', 1940106: '?', 1967654: '?', 1702304: 'Zhosaly', 8670: 'Zhemchuzhny', 1508782: 'Kobzartsy', 1509611: 'Velikaya Rudka', 1935288: '?', 5261885: 'Großkrotzenburg', 5266315: 'Versmold', 1963446: '?', 1079874: 'Karla Libknekhta', 1060867: 'Sokolovo', 16534: 'Kutukovo', 1963689: '?', 1706084: '?', 1091695: 'Balakhonovskoe', 1091134: 'Balakhonovka', 1138612: 'Khripunovo', 1144138: 'Veselovskoe', 1912213: '?', 1504652: 'Malokaterinovka', 1966877: '?', 1092924: 'Arkhangelskaya', 1965949: '?', 1501483: 'Derebchin', 1941845: '?', 2210010: 'Bad Hersfeld', 1130754: 'Kulygi', 15626: 'Manoylin', 1705058: '?', 1961078: '?', 1160874: 'Vesenny', 1040941: 'Irklievskaya', 1602855: 'Derevnaya', 1079132: 'Beglitsa', 1959894: '?', 2207316: 'Consett', 1908605: '?', 1055092: 'Pokoevo', 1957674: '?', 1706804: 'El Hadjar', 1051734: 'Kazanskoe', 21947: 'Kisumu', 1933935: '?', 1965586: '?', 1123364: 'Lozhkino', 4315286: 'Binche', 3978782: 'Busselton', 1139850: 'Im Kalinina', 1146365: 'Sosnovskoe', 1513702: 'Skovorodki', 1127613: 'Karakhun', 1038652: 'Lyubimovka', 1033679: 'Ilinskoe', 1511908: 'Petrikov', 1110981: 'Varavay', 1078384: 'Mokry Batay', 1700360: 'Karazhar', 1700315: 'Komsomolsky', 1511801: 'Staromischina', 1510497: 'Spasov', 1709897: '?', 1962903: '?', 1005021: 'Novye Karamaly', 1954404: '?', 1044169: 'Bolshegneushevo', 1965326: '?', 1961417: 'Veľké Kapušany', 1042036: 'Novoyasenskaya', 1714462: '?', 1911604: '?', 1952262: '?', 1110814: 'Uduguchin', 1121754: 'Tyungur', 1942933: '?', 1159713: 'Vanzevat', 1602006: 'Krasnoe', 1154244: 'Samotsvet', 1511906: 'Nastasov', 1068720: 'Konstantinovka', 1031970: 'Tselinny', 1051669: 'Olory', 1513700: 'Sakhnovtsy', 1513400: 'Novoe Selo', 1707281: '?', 1702083: 'Stantsionny', 1966408: '?', 1503981: 'Karabchiev', 4310910: 'Herk-de-Stad', 1967511: '?', 1000514: 'Terebino', 3532: 'Nové Zámky', 1709293: 'Gorzów Wielkopolski', 1932095: '?', 1137147: 'Almenevo', 1914008: '?', 1083996: 'Timofeevka', 2204887: '?', 1703623: 'Mukhavets', 1952260: '?', 1033364: 'Sleptsovskoe Otdelenie', 1919171: 'Radford', 239: '?', 1967862: '?', 1940341: '?', 1122799: 'Panovo', 1050232: 'Dubovoe', 1953388: '?', 1923042: '?', 1963919: '?', 1917986: '?', 5266356: 'Ennepetal', 1907269: '?', 1110401: 'Pugachevo', 4450247: 'Bordeaux', 1947530: 'Františkovy Lázně', 1054512: 'Inshino', 1967887: '?', 11663: 'Orlovsky', 1112542: 'Karataban', 1095905: 'Chuteevo', 1059470: 'Tolbino', 1514147: 'Goncharikha', 1077075: 'Dolostsy', 1514432: 'Moshny', 1013865: 'Petrovsk', 1941353: '?', 1045399: 'Mozolevo', 1503290: 'Pervomayskoe', 1003419: 'Sulonda', 4922463: 'DeBary', 1113915: 'Shatoy', 1947475: '?', 1703914: '?', 2888: '?', 6204: 'Peschanka', 18241: 'Argunovo', 1506681: 'Krasnoselye', 1506686: 'Nizhnie Vereschaki', 1950670: 'Clausthal-Zellerfeld', 1036587: 'Leppyasyurya', 1514885: 'Rashkov', 1052794: 'Krasnomaysky', 5266463: 'Bad Nauheim', 1962641: '?', 1079156: 'Dmitriadovka', 5266852: 'Münsingen', 1070009: 'Dobruchi', 1002184: 'Kozmino', 1927697: '?', 1157905: 'Bukhtal', 1157902: 'Bolshaya Zamorozovka', 1059756: 'Krasnye Orly', 1932926: '?', 1025650: 'Schuchinskie Peski', 1500046: 'Prokhladnoe', 5266928: 'Traunreut', 1515067: 'Parafievka', 22604: '?', 1910251: '?', 10749: 'Elbrus', 1913183: '?', 1966300: '?', 1706535: '?', 1963175: '?', 1095046: 'Popovka', 1944418: '?', 1931164: '?', 1968006: '?', 1707182: '?', 1706981: '?', 1517120: '?', 1962726: '?', 1940605: '?', 5118197: 'Ridgefield', 1911708: '?', 1929763: 'Denham Springs', 1004178: 'Zelenga', 1145110: 'Zyryanka', 1602161: 'Patsui', 1915195: '?', 1957025: '?', 1957950: '?', 1961606: '?', 1154784: 'Privokzalny', 1038702: 'Timoshino', 16138: 'Chernaya Kholunitsa', 1965703: '?', 1113933: 'Chervlennaya', 1501057: 'Vyssheolchedaev', 13965: 'Burashevo', 1969788: 'Hausjärvi', 1031823: 'Kevyudy', 1113662: 'V-Selmentauzen', 1030181: 'Mugreevsky', 1121713: 'Yakonur', 5266019: 'Raunheim', 1030588: 'Chernaya Rechka', 1967495: '?', 1967588: '?', 1937983: 'Blumenau', 9173: '?', 5327010: '?', 1026357: 'Gelkhen', 1515123: 'Syrai', 1124361: 'Chelutay (24 Km)', 1025557: 'Gremyachye', 1504942: 'Prostore', 1955601: '?', 5332578: '?', 1129726: 'Zhuravlevo', 1967195: '?', 18841: '?', 1054313: 'Zaborye', 1150435: 'Poturaevka', 1956214: '?', 4952516: 'Clarksburg', 1513338: 'Veliky Zhvanchik', 1513968: 'Kovalovka', 1514211: 'Zhurzhintsy', 15997: '?', 1949103: '?', 5265900: 'Wasserburg (Bodensee)', 1101107: 'Ivanovo (derevnya)', 1028914: 'Maydakovo', 1707563: 'Novosyolovka', 1968443: '?', 1945158: 'Nor Gekhi', 1955889: '?', 5330947: 'Ptitsefabrika', 1153738: 'Topolinoe', 1041182: 'Ordzhonikidze', 1505715: 'Migalki', 1032607: 'Bryn', 1121632: 'Artybash', 11351: 'Zagatuy', 1012549: 'Perelazy', 1148459: 'Novonikolaevka', 1960767: '?', 1145468: 'Kutyrly', 18422: 'Sergievskaya', 1052482: 'Novye Vyselki', 1936826: '?', 1965869: '?', 1940569: '?', 1128820: 'Alekhino', 1144393: 'Dresvyanka', 1144391: 'Verkh-Iki', 1145016: 'Maysky', 1144401: 'Mamonovo', 1097233: 'Krugloe Pole', 4567615: 'Lippetal', 1030489: 'Oktyabrskoe', 1967116: '?', 1954884: '?', 1922462: '?', 1925187: '?', 1507884: 'Davydov', 1145955: 'Novorossiyka', 1042235: 'Af-Postik', 1934712: '?', 1119813: 'Glebovo', 1702400: '?', 1160185: 'Kaylastuy', 4364947: 'Holzbunge', 1052825: 'Gumny', 1965097: '?', 1966702: '?', 1027952: 'Konokhovo', 1035601: 'Yushkozero', 1063152: 'Pogorelovo', 1025639: 'Rostoshi', 1136289: 'Rybnoe', 1153002: 'Serafimovka', 1113776: 'Alpatovo', 1157791: 'Klepikovo', 1911704: '?', 20947: 'Dudley', 1144591: 'Chingiss', 1134938: 'Elovka', 1601601: 'Gorokhovischi', 1968210: '?', 1962248: '?', 1500300: 'Zhelyabovka', 1073752: 'Vernyavino', 1506364: 'Bandurovo', 1911221: '?', 1000182: 'Gabukay', 16152: 'Ershichi', 5055129: '?', 1955977: '?', 1086384: 'Khaznidon', 1914574: '?', 1050672: 'Ismentsy', 3046: 'Verkhnie Kigi', 1506280: 'Trilesy', 1505598: 'Rudnitskoe', 1955123: 'Sotkamo', 1500087: 'Novozhilovka', 1947305: '?', 7016: '?', 1960465: '?', 1040840: 'Velikovechnoe', 1122747: 'Petropavlovskoe', 1037121: 'Ydzhyd-Yag', 1968074: '?', 1153142: 'Terney', 1111052: 'Starye Zyattsy', 1095344: 'Naberezhnye Morkvashi', 1904928: 'Davao', 1951855: '?', 1136211: 'Bystraya', 1966902: '?', 1712995: 'Goodwell', 1921254: 'Milford', 1008737: 'Mechta', 1500269: 'Zavetnoe', 1968286: '?', 1068621: 'Sura', 1953164: '?', 1919301: '?', 9252: 'Makanshy', 1145792: 'Plotbische', 1934457: '?', 1159542: 'Borodino', 1951493: '?', 1702224: 'Pervomayskoe', 1036706: 'Veslyana', 1519041: 'Bediani', 1908997: '?', 1112787: 'Dubrovka', 13946: 'Cherkekh', 1516132: 'Tierp', 1010301: 'Zasosna', 1072328: 'Stekhnovo', 1963714: '?', 1510876: 'Rossoshi', 1122062: 'Solonovka', 1956129: '?', 1077869: 'Golubinka', 1500375: 'Ruchi', 1968368: '?', 5430706: 'Abay', 1924459: '?', 1962963: 'Eisenach', 1010246: 'Kamyzino', 1968176: '?', 1137866: 'Mokrousovo', 1705730: 'Yakkabag (yakkabagsky Rayon)', 1963644: '?', 1147915: 'Revolyutsionny', 1158632: 'Ideal', 1702982: 'Temirlanovka', 1503908: 'Mirolyubovka', 1084991: 'Kanaevka', 1500603: 'Voynashovka', 1946021: '?', 1908420: '?', 1911033: '?', 1961617: 'Saddle Brook', 1514504: 'Skorodistik', 5258946: 'Hottelstedt', 1602340: 'Lyuban', 1032526: 'Lva Tolstogo', 1506442: 'Bratolyubovka', 1967713: '?', 1514913: 'Kuren', 1040246: 'Susanino', 22379: 'Arcadia', 1904329: 'Hajdúszoboszló', 1122661: 'Velizhanka', 1903777: '?', 1515862: '?', 1113854: 'Alkhan-Yurt', 1122964: 'Nikolskoe', 1014233: 'Malaya Ivanovka', 1507154: 'Seleznevka', 1921792: '?', 1947872: '?', 1078474: 'Staraya Stanitsa', 4529911: 'Tau', 1146560: 'Sazhino', 1074667: 'Bereza', 1952532: 'Agin', 1964305: '?', 1111537: 'Urzhumskoe', 1094768: 'Yamashi', 1925266: '?', 1600428: 'Ozarichi', 1517941: '?', 1917019: '?', 1943986: '?', 1974990: '?', 1507635: 'Kulikov', 1504409: 'Olkhovtsy', 21026: 'Samarskoe', 13348: 'George Town', 1601018: 'Lyntupy', 1965916: '?', 3128237: 'Loutrá Killínis', 1700073: 'Samarka', 1041543: 'Akhmetovskaya', 1082900: 'Sanskoe', 1066724: 'Droskovo', 1505859: 'Voytovo / Voykovo', 1153135: 'Edinka', 1508768: 'Chausovo', 1706667: '?', 1711524: 'Findlay', 1934181: '?', 1114328: 'Baygildino', 1160677: 'Schebenochny Zavod', 1112452: 'Pivzavod', 1043621: 'Tsukanovo-Bobrik', 1917437: '?', 1944667: '?', 1514346: 'Antonovka', 1062497: 'Gosttsy', 1096299: 'Malmyzhka', 7591: 'Sakharny Zavod', 1075672: 'Moglino', 1963503: '?', 1925836: 'Ulyanovo', 1507031: 'Uspenka', 2602740: 'Eleja', 14058: 'Vorsha', 1803646: 'Gorredijk', 17964: 'Leeuwarden', 1711482: 'Hoogeveen', 1518910: '?', 1967640: '?', 1964096: '?', 1926337: '?', 1904638: '?', 1080002: 'Sokhranovka', 1967115: '?', 1929987: '?', 1963275: '?', 1114394: 'Sugaykasy', 1963512: '?', 1052614: 'Obrochnoe', 1513667: 'Velikie Matsevichi', 1005216: 'Mustafino', 1965919: '?', 1929513: '?', 1001877: 'Derevenka', 1936535: 'Sibiu', 5266203: 'Grevenbroich', 1948150: '?', 1956244: '?', 1708833: '?', 1003255: 'Bereznik (selo)', 1012745: 'Partizanskoe', 1123984: 'Stoyba', 4242970: 'Acton Burnell', 1503152: 'Tsukurinoe', 1968642: '?', 1010844: 'Fedoseevka', 1914595: '?', 1937122: '?', 1958574: '?', 1968998: 'Mortsel', 5331095: 'Fosses-la-Ville', 1514443: 'Khudyaki', 1959091: '?', 1036578: 'Veshkelitsa', 1602541: 'Kraysk', 1962375: '?', 1949195: '?', 1504889: 'Kuznetsovka', 1113785: 'Rubezhnoe', 1968192: '?', 1959296: '?', 1146368: 'Tikhoretskoe', 1934048: '?', 16721: '?', 3033663: 'Maajiyow', 1919815: '?', 1124662: 'Elovka', 1158814: 'Tanguty', 4984139: 'Tecumseh', 1713100: 'Gunnison', 5096243: 'Crested Butte', 1712613: 'Rocklin', 5090390: 'Citrus Heights', 1921373: 'Antelope', 1913071: '?', 1517039: '?', 1129621: '?', 3317500: 'Alexandra Park', 1124509: 'Sulkhara', 1966847: '?', 1914190: 'South Wilmington', 5009772: 'Centreville', 5031852: 'Battle Ground', 1702009: 'Arshaly', 6661: 'Clinton', 1939122: '?', 1123433: 'Shelabolikha', 5428919: 'Pogranichnik', 1115623: 'Yalchiki', 1939080: '?', 1108301: 'Brusyanka', 1054932: 'Manikhino', 1925128: '?', 1960575: '?', 1965710: '?', 1506126: 'Romanovka / Ordzhonikidze', 1006851: 'Tavtimanovo', 1000139: 'Tabachny', 20885: '?', 1508984: 'Khlebodarskoe', 1942543: '?', 1500641: 'Balanovka', 1905925: 'Camberley', 1714730: '?', 1921659: '?', 1964816: '?', 1701757: 'Shashubay', 1700391: 'Grigoryevka', 1701232: 'Chekoman', 1024566: 'Nizhnedevitsk (poselok)', 1145866: 'Starinka', 1015005: 'Nikolaevsky', 1031537: 'Novo-Bobruyskoe', 1139605: 'Klin', 1030209: 'Talitsy', 1059159: 'Novaya', 1501367: 'Kirnasovka', 1500935: 'Krasnoselka', 1508866: 'Krinichki', 1079436: 'Zhukovskoe', 1514124: 'Kononcha', 1514129: 'Mezhirich', 1094782: 'Burnashevo', 1961000: '?', 1935744: '?', 1112498: 'Forshtadt', 5126517: 'La Prairie', 1954903: '?', 1515532: 'Sednev', 1948293: '?', 18145: 'Karamyshevo', 1139904: 'Sumoryevo', 4221771: 'Spjald', 1918285: '?', 1506306: 'Farbovanoe', 4546495: 'Fregona', 1503060: 'Urzuf', 1506033: 'Kozin', 1904175: '?', 1502190: 'Pershe Travnya', 1711103: '?', 1042698: 'Krupets', 1136182: 'Pervomansk', 1028711: 'Cherntsy', 1113343: 'Bobrovka', 1155719: 'Krasnoyarka', 1078065: 'Vinogradny', 1129695: 'Tomskoe', 4320222: 'Westerburg', 1514561: 'Korytnoe', 1057344: 'Poluryadinki', 1966442: '?', 1500209: 'Kremnevka', 1158321: 'Antipino', 1966963: '?', 1507654: 'Potelich', 1010430: 'Elets', 18013: 'Barano-Orenburgskoe', 1115043: 'Ykhra-Sirma', 1024455: 'Im Dzerzhinskogo', 1041129: 'Stepnoy', 1948114: '?', 1020551: 'Frolovo', 1091912: 'Novkus-Artezian', 1040931: 'Beysug', 1085650: 'Pugachevsky', 1057109: 'Zakharovo', 5421160: 'Mahé', 1134812: 'Nikolsk', 1134775: 'Apano-Klyuchi', 1049778: 'Arkhangelskie Borki', 1965323: '?', 1121515: 'Aga', 3827601: 'Geumsan', 1014182: 'Atamanovka', 1083152: 'Tavolzhanka', 1511421: 'Khudikovtsy', 1917193: '?', 1967570: '?', 1963828: '?', 1508756: 'Migia', 1965618: '?', 1904951: '?', 5430744: 'Axu', 1709645: '?', 1920429: '?', 1141639: 'Bolshoe Davydovo', 1966876: 'Zeyem', 1505475: 'Novoselitsa', 1932631: '?', 1966648: '?', 10946: 'Mezhozerny', 1925624: '?', 2084: 'Plodovoe', 1109264: 'Lyuk', 5121160: '?', 1013296: 'Rusanovo', 1504806: 'Basan', 1902820: '?', 1968916: '?', 1070081: 'Kola', 1903655: 'Donegal', 11031: 'Starichi', 5261552: 'Bad Zwischenahn', 1052323: 'Krasino', 3065: 'Podgorny', 4389004: 'Berlin', 1959278: 'Büdelsdorf', 4282470: 'Rhenen', 1513974: 'Mikhaylovka', 1036934: 'Irael', 3930: 'Khabotskoe', 1803183: 'Avinurme', 1602283: 'Pogost', 1972766: 'Stuhr', 1122316: 'Novovoznesenka', 1124422: 'Khuramsha', 3138361: 'Rūl Ḑadnā', 1513855: 'Shidlovtsy', 1506569: 'Khmelevoe', 1701572: 'Zhangala', 1511064: 'Sinevka', 1015612: 'Bolshoy Lychak', 1504989: 'Zvonyach', 1018759: 'Rebovo', 1967248: '?', 1158069: 'Vorsikha', 1911434: 'Nizhnie Eshery', 1515279: 'Kudlaevka', 1517347: 'Senftenberg', 1939854: '?', 1011496: 'Aleshnya (derevnya)', 1519179: '?', 4529056: 'Volda', 1145398: 'Solntsevka', 1902701: '?', 1091670: 'Kommayak', 1713654: 'Hersonissos', 1509147: 'Novaya Dofinovka', 1138820: 'Dudenevo', 1018154: 'Nelidovo', 1504648: 'Kushugum', 1160810: 'Kazanovo', 1932878: '?', 1966064: '?', 17077: 'Shestakovo', 1940944: 'Oktyabrskoe', 1509269: 'Baraboy', 1903303: '?', 1091972: 'Blagodatnoe', 5056558: 'Atlanta', 1504092: 'Pyatka', 1505445: 'Slivki', 1051212: 'Tsibiknur', 1503835: 'Krasilovka', 1026522: 'Tagirkent-Kazmalyar', 1966843: '?', 18339: 'Shonzha', 1017610: 'Yuchka', 1961838: 'Pößneck', 2101119: 'Karakalpakia', 1970134: '?', 1970135: '?', 1949267: '?', 1514986: 'Khovmi', 1041532: 'Srednie Chuburki', 1512477: 'Kondrashovka', 5129836: 'Stratford', 1901146: 'Tamra', 1018545: 'Andomsky Pogost', 4394202: 'Wiltz', 5302705: 'Morlaàs', 1500292: 'Chistopolye', 1507368: 'Pokrovskoe', 1963712: '?', 1509100: 'Chervony Yar', 20805: 'Crawfordsville', 1902159: 'Lafayette', 1950366: '?', 1959433: '?', 5266251: 'Wiehl', 1915776: '?', 1927547: 'Ocean Acres', 1124602: 'Irakinda', 1709068: 'Sharon', 1025070: 'Kirov', 1129703: 'Sharap', 1943141: '?', 1123448: 'Eltsovka', 1017069: 'Schekino', 1517901: 'Temir', 1114439: 'Karamyshevo', 1114771: 'Shanary', 1124403: 'Kalenovo', 5004145: 'Huffman', 1968412: '?', 1123940: 'Klimoutsy', 1961915: '?', 15508: 'Sergeevka', 1125000: 'Plekhany', 1127717: 'Moiseevka', 1517018: '?', 1067545: 'Razdolnoe', 1122195: 'Yanovo', 1517861: 'Gatlinburg', 1506194: 'Krivets', 1146836: 'Novogrigoryevka', 1958629: '?', 1109943: 'Armyaz', 1124307: 'Tuldun', 1005631: 'Karimovo', 1700272: 'Andreevka', 4352979: 'Malchow', 1041630: 'Benokovo', 22463: 'Richland', 5966: 'Veselaya Lopan', 1003338: 'Likhachevo', 9068: 'Alol', 1908302: '?', 1111332: 'Korzhevka', 1515383: 'Lyubech', 1517521: 'Lewisburg', 1130446: 'Pashino', 4697072: 'Le Gosier', 1927907: 'Argos', 1153797: 'Tekhtyur', 1902581: 'Yangi Nishan', 1135687: 'Berezovka', 1949283: '?', 1942074: '?', 8156: '?', 1937855: '?', 1047768: 'Pekhenets', 1601447: 'Schedrin', 1953636: '?', 1122424: 'Zakovryashino', 1093243: 'Khobotovo', 1020888: 'Navoloki', 1156337: '?', 1159140: 'Taezhny', 1517353: '?', 1966805: '?', 1956473: '?', 1518110: '?', 1925571: '?', 1113323: 'Tuktubaevo', 1034974: 'Bogdanovskoe', 1701656: 'Buldurta', 4905606: 'Areora', 1027537: 'Novopistsovo', 1121525: 'Kusochi', 1156796: 'Teguldet', 1938366: '?', 1710461: '?', 1513776: 'Gruzevitsa', 1136259: 'Tigritskoe', 1507259: 'Veselaya Gora', 1040774: 'Nikolaenko', 1035068: 'Oktyabrsky', 1601200: 'Nikitikha', 21563: 'Umatilla', 4187372: 'Gran Tarajal', 1706111: 'New Bloomfield', 1911590: '?', 1969354: '?', 1145449: 'Tsaritsyno', 1969348: '?', 1075739: 'Palkino', 1969372: 'Saratovka', 1965261: '?', 1517771: '?', 1969210: 'Machara', 1153678: 'Zhilinda', 1939656: 'Schifferstadt', 1024430: 'Zaprudskoe', 1024619: 'Orlovo', 1115169: '?', 1941006: 'Dadesh', 5165616: 'Puerto Rico', 1704941: 'Puerto de la Cruz', 1052312: 'Chukaly', 1923280: '?', 1134848: 'Khandalsk', 4989053: 'Brick Yard Trace', 1036876: 'Vukhtym', 1504513: 'Troitskoe / Karla Marxa', 1943546: '?', 1114396: 'Toburdanovo', 1122824: 'Rodino', 3513269: 'Awa', 1952772: '?', 1513540: 'Medzhibozh', 1041384: 'Moldavanskoe', 1966074: '?', 1921959: 'Brooks', 1502895: 'Vodyanskoe', 1031281: 'Chernyshevskoe', 1501286: 'Selische', 6208: 'Pyatnitskoe', 1091700: 'Vasilyevsky', 1026244: 'Stalskoe', 1154920: 'Berdyugina', 1508383: 'Novoalexandrovka', 4022639: "M'banza Congo", 1972674: '?', 1966194: '?', 4570085: 'Burgwedel', 1953358: '?', 1507489: 'Sukhovolya', 1093202: 'Ilovay-Dmitrievskoe', 1967505: '?', 17943: 'Elniki', 4230370: 'Street', 1501517: 'Yuliampol', 1803393: '?', 1021450: 'Perovo', 1964328: '?', 4488823: 'Teresin', 1089407: 'Krapivensky-2', 1952899: '?', 1004528: 'Ashuluk', 1081568: 'Poschupovo', 1514339: 'Potash', 4323: 'Bregenz', 1076113: 'Zabelye', 1158196: 'Poluyanova', 4351448: '?', 1006748: 'Yuldybaevo', 22279: 'Baranovka', 1502131: 'Mikhaylovka', 1902423: '?', 1045498: 'Tambovsky Shlyuz', 1053884: 'Avtopoligon', 1921015: '?', 5266966: 'Grafenwöhr', 1969503: '?', 1601739: 'Shapchitsy', 1111845: 'Karmaley', 1940707: 'Goole', 4910646: 'Loxley', 1969521: '?', 1950133: '?', 1908633: '?', 1967989: '?', 5265767: 'Sennfeld', 1702014: 'Pokrovka', 1506009: 'Nebelitsa', 2803: 'Zadono-Kagalnitskaya', 1941955: '?', 1040892: 'Shkolnoe', 1965207: '?', 1700239: 'Sabyndy', 1020862: 'Krasavino', 14357: 'Chuvashskoe Urmetyevo', 1910708: 'Gerpinnes', 1145293: 'Podolsk', 1934872: '?', 1061013: 'Kostkovo', 1516707: 'Chigwell', 1512454: 'Kozeevka', 1145669: 'Maryanovsky', 1121827: 'Shebalino', 1905730: '?', 1942864: '?', 1000442: 'Pezhma', 1700561: 'Zhylandy', 1514538: 'Topilna', 5239423: 'Le Havre', 1911255: '?', 1949319: 'Gakh', 1030622: 'Bylym', 4535591: 'Flekkefjord', 4535772: 'Feda', 1710665: '?', 13726: 'Novy Vasyugan', 1127635: 'Pribrezhny', 3129452: 'Chania', 1026773: 'Kalinovka', 1967521: '?', 1030423: 'Nesterovskaya', 1517938: 'Siazan', 3516420: 'Rājbirāj', 22659: 'Rodnikovoe', 1120228: 'Sudoverf', 1045626: 'Kursk (derevnya)', 1907717: '?', 1077751: 'Poltava 1-Ya', 4908694: 'Cullman', 1968485: '?', 1969614: '?', 1512603: 'Konstantinovka', 1938835: '?', 5266202: 'Dormagen', 1965311: '?', 1129948: 'Magistralny', 1509371: 'Svetlodolinskoe', 1019009: 'Karitsa', 1707257: 'Troutdale', 17487: '?', 1935434: 'Barekamavan', 1014803: 'Troitsky', 1507177: 'Molodezhnoe', 1967994: '?', 1149586: 'Obvinsk', 1904076: '?', 4339069: 'Recklingsen', 1969449: '?', 5262539: 'Neustadt (Wied)', 5267593: 'Altenkirchen (Westerwald)', 1966383: '?', 1907418: '?', 1012453: 'Lopandino', 1603208: 'Komsenichi', 5264629: 'Riederich', 1113764: 'Gvardeyskoe', 3768545: 'Kampar', 1707404: '?', 1908500: '?', 5819: '?', 1964419: '?', 1136121: 'Roschinsky', 1950840: '?', 1603231: 'Polykovichi', 2206975: '?', 1502299: 'Iosipovka', 1710733: 'Denison', 1968048: '?', 1153812: 'Myndagay', 1940159: '?', 1159162: 'Molodezhny', 1965909: '?', 1709189: 'Albion', 1703237: 'Walla Walla', 1122935: 'Linevskoe', 1957004: '?', 1714284: '?', 1969147: '?', 1711499: 'Farmers Branch', 1969714: '?', 1122114: 'Kamyshenka', 1966768: '?', 21974: 'Akdepe', 1151321: 'Speshkovo', 1113047: 'Arsinsky', 1152894: 'Vasilyevka', 1123375: 'Tselinnoe', 1041718: 'Gorkaya Balka', 1124371: 'Dalakhay', 1122309: 'Zelenaya Polyana', 1709959: 'Carson City', 1158279: 'Malkovo', 1031021: 'Donskoe', 5266321: 'Vlotho', 1901142: "Modi'in Illit", 1600463: 'Stavok', 3959600: 'Mandal', 1715596: '?', 1105871: 'Rovno', 1158259: 'Embaevo', 1015034: 'Zhutovo 2-E', 1014598: 'Pimeno-Cherni', 1142463: 'Pelegovo', 5349913: 'Friedensau', 1041813: 'Urupsky', 1112617: 'Novokaolinovy', 1514578: 'Gorbova', 1010798: 'Kaplino', 1009782: 'Klimenki', 1715202: '?', 1506136: 'Zhitnye Gory', 1113780: 'Mekenskaya', 1095403: 'Biryulinskogo Zverosovkhoza', 1136423: 'Pokanaevka', 1136697: 'Tinskaya', 1077820: 'Starocherkasskaya', 1157726: 'Kirovsky', 1969801: '?', 1057147: 'Likino', 1153494: 'Keptin', 1943061: '?', 1089733: 'Ponizovye', 1500549: 'Vodopoynoe', 5259692: 'Rastenberg', 1122422: 'Volchno-Burlinskoe', 1134878: 'Kamenka', 1110172: 'Kizner (voyskovaya Chast)', 6152: 'Namur', 1507167: 'Vrubovka', 3421618: 'Charikar', 1515571: 'Turya', 1134770: 'Khayryuzovo', 1507696: 'Sasov', 1938208: '?', 1601710: 'Pobolovo', 1121733: 'Kuragan', 1501552: 'Berezovichi', 389: 'Povedniki', 1083556: 'Pogruznaya', 1506376: 'Salkovo', 4567126: 'Altes Lager', 1157523: 'Ushakovo', 1962525: '?', 1135514: 'Shapkino', 1159785: 'Yumas', 1800558: 'Kishkareny', 1911564: '?', 1156759: 'Sakhalinka', 1911505: '?', 1060739: 'Konchansko-Suvorovskoe', 1962242: '?', 1091478: 'Petropavlovskoe', 3960081: 'Choyren', 1501153: 'Novozhivotov', 1047076: 'Ivanovo (derevnya)', 1509913: 'Romodan', 3761286: 'Boracay', 1602004: 'Turets', 1917272: '?', 1704536: '?', 1924575: '?', 1705683: '?', 1519018: '?', 1917572: 'Kallithea', 4547947: 'Civezzano', 1951670: '?', 3987593: 'Goroka', 1800602: 'Korbu', 3742513: 'Panabo', 1969944: 'Kintai', 1918024: '?', 1052782: 'Bulgakovo', 18317: 'Wills Point', 2694: '?', 1968253: '?', 1506043: 'Rosava', 1502733: 'Novoamvrosievskoe', 1126923: 'Vorovskogo', 1509255: 'Levadovka', 22566: 'Belenkoe', 1514465: 'Ratsevoe', 1509660: 'Verkhnyaya Lanna', 1916359: '?', 1036846: 'Lugovoy', 1002593: 'Nimenga (derevnya)', 1002595: 'Nimenga (poselok)', 1054224: 'Turist', 1159850: 'Karymkary', 1014097: 'Bykovo', 1715162: 'Neuenkirchen', 1927683: '?', 1911373: '?', 1105468: 'Avangard', 1055169: 'Barabanovo', 18957: 'Sermenevo', 1005530: 'Kagarmanovo', 1512273: 'Cherkasskaya Lozovaya', 1511044: 'Shtepovka', 1970002: '?', 1518660: '?', 1144329: 'Almenevo', 1800646: 'Krasnogorka', 1713295: '?', 1158443: 'Suerka', 1969760: '?', 1959836: '?', 1916606: '?', 1061592: 'Pavlovo', 1153664: 'Solyanka', 1706870: 'Port Elizabeth', 5256146: 'Weissach', 1970032: '?', 1917677: '?', 7993: 'Arugampuleliya', 1969616: '?', 1901517: 'Pitt Meadows', 1037308: 'Okunev Nos', 1036888: 'Kyddzyavidz', 1518593: 'Sitalchay', 1034119: 'Serpeysk', 1144980: 'Tagan', 4197974: 'Meknès', 1112389: 'Mayak', 1501616: 'Senkevichevka', 1510260: 'Velikie Tseptsevichi', 1036549: 'Shavan', 1911560: '?', 1508691: 'Novopoltavka', 1139926: 'Mulino', 1147955: 'Mamalaevka', 1939290: '?', 1504517: 'Novopetrovka', 1969904: '?', 4562228: 'Berane', 1123234: 'Gryaznovo', 1705999: '?', 1009881: 'Pokrovka', 1037257: 'Ozyag', 1079676: 'Sovetskaya', 1509429: 'Tuzly', 1135818: 'Bolshaya Urya', 5428523: 'Krasnogorskoe', 2500396: 'Madaba', 3296380: 'Choroszcz', 1968455: '?', 1926187: '?', 5266200: 'Velbert', 1600595: 'Kozyany', 12612: 'Pavelki', 1512715: 'Veseloe', 1713203: 'Jenkintown', 1036477: 'Onezhsky', 1026131: 'Guni', 1713392: '?', 1951582: '?', 1967090: '?', 1940099: '?', 1076237: 'Sergeytsevo', 1512277: 'Berdyanka', 5264379: 'Edingen-Neckarhausen', 1518539: 'Beshalma', 1001614: 'Kotelnikovo', 1069724: 'Lychevo', 1091990: 'Rogataya Balka', 1510986: 'Samotoevka', 1091661: 'Takhta', 1948900: 'Mahdia', 1122259: 'Kubanka', 1705772: '?', 1036626: '?', 1966995: '?', 1915941: '?', 1500499: 'Shirokoe', 1100713: 'Ababkovo', 1504564: 'Zaporozhye', 1109244: 'Isakovo', 20584: 'Makat', 1505824: 'Sinyak', 1970180: 'Sadzhavakho', 1516274: '?', 1024340: 'Olkhov Log', 1514565: 'Migovo', 1072200: 'Makarovo', 22609: 'Verkhnie Sirogozy', 5470364: 'Tikilisa', 1518689: '?', 1515516: 'Mnev', 1017934: 'Kipelovo (derevnya)', 1135543: 'Nizhny Suetuk', 1504682: 'Blagoveschenka', 1504575: 'Tavria', 20009: 'Veszprém', 1953952: '?', 1956215: '?', 5267909: 'Neustadt an der Donau', 5266940: 'Kelheim', 1146823: 'Karasay', 1934789: '?', 1025895: 'Kurmi', 11033: 'Kaluzhskaya Opytnaya S/kh Stantsia', 1967381: '?', 1514768: 'Toporovtsy', 1600291: 'Svischevo', 1902928: '?', 1902658: 'Khaskovo', 1965794: '?', 1705644: 'Oshkosh', 4273461: 'Roriz', 1505223: 'Vorona', 1965277: '?', 1707208: 'Kuzmin', 1703236: '?', 1960655: '?', 1153737: 'Teply Klyuch', 1502423: 'Kocheryzhki', 1966043: '?', 1936498: '?', 1135401: 'Taloe', 1160838: 'Kholbon', 1122689: 'Beryozovka', 1136714: 'Novaya Kalami', 1128228: 'Karymsk', 8552: '?', 1152305: 'Chusovskoy', 5013064: 'Manassas Park', 1160127: 'Ikabya', 5236616: 'Leucate', 1964250: '?', 1161175: 'Teysin', 1701712: 'Belogorka', 5427963: 'Pobeda', 1093452: 'Zeleny', 1084619: 'Krasnaya Kudryavka', 1017109: 'Vakhrushevo', 1085578: 'Piterka', 1516656: 'Multan', 5055798: 'Raritan', 1144713: 'Novomikhaylovka', 1042605: 'Nizhnie Apochki', 1509283: 'Prilimanskoe', 1156717: 'Staritsa', 1508170: 'Strelki', 1700014: 'Iskra', 1963690: '?', 14009: 'Babinichi', 1938252: '?', 1091976: 'Gofitskoe', 1078440: 'Krasnovka', 1078115: 'Zhukovskaya', 1148010: 'Ravninny', 1970143: '?', 1016071: 'Pavlovo', 1159655: 'Solnechnoe', 1025807: 'Tamazatyube', 1137287: 'Pichugino', 1506243: 'Dibrovka', 1960725: '?', 1036436: 'Vodla', 5098755: 'New York', 1114749: 'Oktyabrskoe', 1969733: '?', 1957682: '?', 4498002: 'Leszno', 1941767: '?', 1602837: 'Paseka', 1956081: 'San Giuseppe Vesuviano', 1130527: 'Klimkovka', 1002693: 'Novolavela', 1516343: 'Davenport', 1514033: 'Morintsy', 1072583: 'Ostrovki', 1082781: 'Starocherneevo', 1156868: 'Kopylovo', 1508111: 'Tartakov', 1109599: 'Kotlovka', 1970306: '?', 4128770: 'Ouarandji', 5266484: 'Wetzlar', 1933257: '?', 1903385: '?', 1122859: 'Veseloyarsk', 1096138: 'Rozhdestveno', 1030444: 'Psykhurey', 1110595: 'Shadrino', 1907904: 'Karlshamn', 4260566: 'Kävlinge', 1942938: '?', 1080168: 'Lipki', 19045: 'Podstepki', 1970331: '?', 1965594: 'Kurta', 1965565: '?', 1053817: 'Im Tsyurupy', 15317: 'Privolnoe', 1970334: '?', 1038678: 'Pervomayka', 1502626: 'Vysokoe / Vladimirovka', 1946355: '?', 1705705: 'Gombori', 1950851: '?', 1512474: 'Kovsharovka', 1516805: 'Akzhaik', 1958230: '?', 1705583: 'Viseu', 1160447: 'Balyaga', 1903753: '?', 1960700: '?', 1970370: '?', 1702465: 'Panfilovo', 1963062: '?', 1115436: 'Tuvany', 1708626: 'La Spezia', 1953324: '?', 1056581: 'Troitskoe', 1946874: '?', 1509101: 'Shevchenkovo', 1771: 'Suolahti (Keuruu)', 1941971: '?', 1944498: '?', 1031942: 'Sadovoe', 1968361: '?', 5267184: 'Heinsberg', 1093513: 'Vyazniki', 1112460: 'Karagaysky', 1512792: 'Davydov Brod', 1970445: '?', 5423697: 'Bubuech', 1020868: 'Lesyutino', 1505958: 'Vita-Pochtovaya', 1903424: '?', 1907530: '?', 1132327: 'Arskoe', 1113874: 'Mayrtup', 1944376: '?', 1970456: 'Zemo Bargebi', 5264503: 'Willstätt', 1155132: 'Zakharovskoe', 1128172: 'Krivaya Luka', 1511855: 'Konopkovka', 1715004: '?', 1150940: 'Atnyaguzi', 1094979: 'Bolshoy Menger', 1161162: 'Predporozhny', 13122: '?', 1032021: 'Tatal', 1031490: 'Druzhba', 1127876: '7 Km Alexandrovskogo Trakta', 1132804: 'Yubileyny', 1712917: '?', 1923564: '?', 1112412: 'Archagly-Ayat', 1004186: 'Kozlovo', 1074641: 'Utichye', 1143866: 'Chernorechensky', 1022984: 'Borok', 1138227: 'Kondinskoe', 1022982: 'Bor (derevnya)', 1048867: 'Politovo', 1501049: 'Khonkovtsy', 11419: 'Rayakoski', 1161152: 'Mezhdurechensky', 1966985: '?', 1500424: 'Trudovoe', 5422744: 'Svetlaya Roscha', 1905403: 'Platteville', 1122404: 'Maralikha', 1153898: 'Novikovo', 1509064: 'Kirnichki', 1500953: 'Verbovka', 1715045: '?', 16797: 'Chernukha', 8093: 'Ulan-Khol', 3300194: 'Labinot-Fushë', 10320: 'Dalmatovo', 1112927: 'Novoburino', 1976594: '?', 1934350: '?', 1918954: '?', 1514114: 'Yurchikha', 1940828: '?', 1155552: 'Petrokamenskoe', 1143752: 'Utyanka', 3136764: 'As Sālimīyah', 1965105: '?', 1933752: '?', 1078277: 'Rossoshinsky 1-J', 17759: 'Zhelezkovo', 1146859: 'Alexandrovka', 1146879: 'Kutuchevo', 2211249: 'Gorzów', 1954069: '?', 1158497: 'Kievo', 1926242: '?', 1905622: 'Bad Düben', 5259829: 'Delitzsch', 1942738: 'Bagratashen', 1018170: 'Novlenskoe', 1603167: 'Tupichino', 2200629: 'Odzun', 1113955: 'Ivankovo-Lenino', 1953356: '?', 1970700: '?', 1970591: '?', 1961529: '?', 1505804: 'Voropaev', 1964693: '?', 1514122: 'Keleberda', 1970760: '?', 1159810: '?', 13032: 'Selezni', 1962804: '?', 1005932: 'Rudny', 1705339: 'Butor', 1006196: 'Beloe Ozero', 1009502: 'Bessonovka', 1139895: 'Pochinki', 1516456: 'Des Plaines', 1955635: '?', 1085129: 'Pervomayskoe', 1602448: 'Krasnaya Zvezda', 1152744: 'Monomakhovo', 1514059: 'Gelmyazov', 1124099: 'Roschino', 1948163: '?', 1969746: '?', 1942159: 'Millau', 1954958: '?', 1514958: 'Velikaya Zagorovka', 1003254: 'Bereznik (derevnya)', 1975715: 'San Benedetto del Tronto', 5459182: 'Tarasovo', 1602904: 'Rovanichi', 1900093: 'Neve Itan', 1960541: '?', 1944556: 'Studio City', 1069618: 'Dubrava 1-J', 1920927: '?', 1505297: 'Gorod', 1917354: 'Motril', 1906363: 'Pompei', 1970976: '?', 1900203: 'Kfar Baruch ', 3666087: 'Hà Tây', 1091766: 'Rodyki', 1923787: 'Kurshab', 1030411: 'Yandare', 1045488: 'Somino', 1704792: 'Chilliwack', 8782: 'Yampol', 1952455: '?', 1602774: 'Drachkovo', 1962162: '?', 1518884: 'Lebach', 1002676: 'Kulosega', 5266373: 'Altena', 5266376: 'Hemer', 3123854: 'Zarqa', 1962476: '?', 1925749: 'Luumäki', 1946581: '?', 1518565: '?', 1511468: 'Vasilkovtsy', 1139440: 'Novy Mir', 1947834: '?', 1601331: 'Stary Krupets', 5061008: 'Odessa', 1802053: '?', 1923884: '?', 2722623: 'Jamestown', 1969236: '?', 1124722: 'Zurgan-Debe', 1049536: 'Sharapovka', 1143951: 'Naberezhnoe', 396: 'Bor (derevnya)', 1128294: 'Brusnichny', 1970786: '?', 1124256: 'Shibertuy', 1709939: 'Canandaigua', 1970792: '?', 1701517: 'Axuat', 19314: 'Malaya Dubna (malodubensky S/o)', 1707831: 'Constanţa', 1085621: 'Klintsovka', 3838354: 'Kanazawa', 1155790: 'Krasnoslobodskoe', 1936531: '?', 1912480: '?', 1040897: 'Bolshoy Beysug', 1515322: 'Belorechitsa', 5228224: 'Vélizy-Villacoublay', 1928898: '?', 1517084: 'Palattsy', 1711265: '?', 1097264: 'Novotroitskoe', 1084143: 'Staroe Eshtebenkino', 1084149: 'Chuvashskoe Eshtebenkino', 1084137: 'Sidelkino', 1084128: 'Novoe Eshtebenkino', 1041811: 'Udobnaya', 1702543: 'Tavolzhan', 1091169: 'Zimonino', 1027293: 'Khotoda', 6120: '?', 1142249: 'Yanovo', 1159989: 'Aksha', 1509843: 'Iskovtsy', 1513501: 'Kuzmin', 1042293: 'Yuzhny', 1008595: 'Raevka', 1112957: 'Chebarkul', 1025516: 'Dolina', 1130638: 'Sozimsky', 1070166: 'Partizanskaya', 1955151: '?', 1042307: 'Voronezhsky', 1914604: '?', 1955928: '?', 1928535: '?', 4235118: 'Linton', 1969938: '?', 1026298: 'Oguzer', 1601835: 'Podorosk', 1041166: 'Bolshie Chelbasy', 1952025: '?', 1091017: 'Cherepovische', 1514749: 'Magala', 1514765: 'Stalnovtsy', 1513689: 'Martynovka', 1514962: 'Golovenki', 1509359: 'Mikhaylovka', 5267112: 'Neu-Ulm', 21548: '?', 1970918: '?', 5259453: 'Flöha', 1517797: 'Ramat David', 1078048: 'Pozdneevka', 1002619: 'Unezhma (derevnya)', 1050359: 'Novye Paraty', 1129300: 'Borisovo', 22403: 'Tsekinovka', 1916287: '?', 1136500: 'Vershino-Rybnoe', 1801248: 'Slobozia-Dushka', 1700717: 'Pokrovka', 1110794: 'Ryabovo', 1502189: 'Novonikolaevka', 1970978: 'Lismore', 1509288: 'Tairovo', 1500800: 'Tarasovka', 1919044: 'Laon', 1050701: 'Mochalische', 1964551: '?', 1072349: 'Trakhachevo', 1910887: '?', 3297733: 'Błonie', 1143440: 'Luzhayki', 3854763: 'Zhoushan', 1944294: '?', 1964484: '?', 1512170: 'Veliky Burluk', 1517196: 'Corby', 1511480: 'Kotsyubintsy', 1504640: 'Veseloe', 1971017: '?', 1905779: '?', 4035711: 'Dolisie', 4496195: 'Mogilno', 1121549: 'Zhana-Aul', 1914664: 'Newburgh', 4689214: 'Moa', 19862: 'Murgap', 1078500: 'Vyazha', 1135396: 'Solontsy', 1158183: 'Nizhnie Aremzyany', 1146636: 'Dzhartargul', 1505356: 'Pnev', 3146336: 'Malatya', 1916467: 'Kok-Oy', 5266360: 'Schwelm', 1947369: '?', 1042123: 'Chushka', 1019620: 'Goritsy', 1151460: 'Kurashim', 1136918: 'Zlatorunovsk', 1969113: '?', 1961036: '?', 1154047: 'Zonalnoe', 1500420: 'Sizovka', 1024291: 'Novaya Kriusha', 1507899: 'Murovanoe', 1922579: '?', 1516870: 'Laxå', 1960805: '?', 1146968: 'Chkalovsky', 1701707: 'Poltavka', 1800012: 'Alexandrovka', 5266782: 'Freudenstadt', 1006395: 'Ayaz', 1122688: 'Bayunovskie Klyuchi', 1503632: 'Strizhevka', 1014633: 'Popki', 1512976: 'Razdolnoe', 1515238: 'Nezhinskoe / Grigoro-Ivanovka', 1013814: 'Gorodtsy', 1035494: 'Vazhnoe', 1094777: 'Bishevo', 5018664: 'East Salem', 1503103: 'Krasnoarmeyskoe', 1021874: 'Kamchuga', 1949355: '?', 1509382: 'Vinogradovka', 1041382: 'Mova', 1711382: 'Quinta do Conde', 1053502: 'Pavlino', 3567590: 'Adda Yusufabad', 1902952: 'Castelraimondo', 1514647: 'Kadubovtsy', 1954490: '?', 1602654: 'Zanaroch', 1957379: '?', 1955178: 'Songkhla', 1600732: 'Shunevichi', 1076548: 'Rubilovo', 1008782: 'Akhunovo', 1041625: 'Svkh Umansky', 1708079: 'Bellflower', 1123772: 'Sivaki', 1954310: 'Garkalne', 1935159: 'Slatina', 1018210: 'Ostakhovo', 1950195: '?', 1504029: 'Puliny / Chervonoarmeysk', 1504842: 'Nadezhdino', 1508361: 'Novogrigoryevka', 1095917: 'Bibeevo', 1923475: 'Solon', 4221176: 'Toftlund', 1500463: 'Krasnolesye', 1500078: 'Krymskaya Roza', 1134159: 'Russky Turek', 1053531: 'Balobanovo', 1701689: 'Dolinnoe', 1901320: 'Razgrad', 1065899: 'Buzuluk', 1509338: 'Dubinovoe', 1943569: 'Carmel', 1132477: 'Beloretsk', 1951426: '?', 1115454: 'Baldaevo', 5001299: 'Allen', 1965189: '?', 1967537: 'Yasamal (baku)', 1942390: '?', 8806: '?', 5339155: 'Rovereto', 1002542: 'Antsiferovo', 1950720: '?', 4484: '?', 1904417: '?', 22205: 'Gouda', 1501928: 'Velikaya Yablonka', 20490: 'Seredeysky', 1602484: 'Bobr', 1910928: 'Bayangol', 1022850: 'Anisimovo', 1971269: '?', 1950761: '?', 1512755: 'Muzikovka', 5047842: 'South Saint Paul', 1956339: '?', 1082533: 'Stolptsy', 1518248: 'Tatabánya', 5237930: 'Aubin', 1124596: 'Sharagol', 1517792: 'Arapoti', 1706681: 'Gig Harbor', 1104184: 'Novo-Yamskaya', 16804: '?', 4271143: 'Pyramiden', 1091832: 'Urozhaynoe', 5066568: 'Ohio City', 1963404: '?', 1152914: 'Osinovka', 1910222: '?', 1920650: 'Williamsville', 1148271: 'Novoiletsk', 1083952: 'Bakhilovo', 5261825: 'Schlangen', 1138020: 'Martynovka', 1708028: 'Moncton', 4342: '?', 1077997: 'Migulinskaya', 1027376: 'Moshkovo', 1905051: 'Richmond', 5061740: '?', 1714761: '?', 15246: 'Hechtel', 1160193: 'Soktuy-Milozan', 1702183: 'Novoilinovka', 1971319: '?', 1152630: 'Kupros', 1510871: 'Kirikovka', 1917434: 'Halberstadt', 1153585: 'Namsky', 1970865: '?', 1132528: 'Almezh', 1966388: '?', 1953842: '?', 1600787: 'Glinnoe', 1516370: 'Krulevschina', 1935927: '?', 1155098: 'Sosnovskoe', 5266865: 'Rosenfeld', 1970603: '?', 1113456: 'Khutorka', 6748: 'Korostino', 1905484: '?', 1153699: 'Kutana', 1915265: 'Loveland', 1913923: '?', 1919390: '?', 1103624: 'Berezhki', 1086433: 'Farn', 1501304: 'Verbovaya', 1153456: 'Suordakh', 1153461: 'Khayysardakh', 1513572: 'Kucha', 4058850: 'Wa', 4059491: 'Sunyani', 1601675: 'Glybov', 18611: 'Pleshanovo', 5261591: 'Handrup', 1906159: 'Pittsfield', 1974841: '?', 3959224: 'Uhiduud', 1501444: 'Berezovka', 1971414: '?', 1081776: 'Oxky', 1012897: 'Zapadenki', 1971432: '?', 1968187: '?', 1109309: 'Turetskoe', 1969749: '?', 1160481: 'Klichka', 1505168: 'Yavorov', 1143367: 'Spasskoe', 1962956: '?', 1705362: '?', 1937996: '?', 1078233: 'Donskoy', 1009486: 'Khlevische', 1947071: 'Weiden', 1929573: '?', 1506124: 'Maryanovka', 1037239: 'Kerchomya', 1150919: 'Chleny', 1912155: '?', 3166228: "Mek'elē", 5266458: 'Idstein', 1513756: 'Polyakhovo', 1511035: 'Mikhaylovka', 1156090: 'Nizhny Katarach', 1000329: 'Zakharovo', 1931832: '?', 1975404: 'Parabiago', 1020129: 'Elovino', 1094742: 'Russky Aktash', 1602710: 'Drichin', 1506013: 'Pashkovka', 4908836: 'Dog Town', 1913672: 'Cahors', 1158319: 'Yar', 1122913: 'Novovoznesenovka', 1971523: '?', 1701230: 'Ozerki', 5266445: 'Hochheim am Main', 1713443: '?', 1002530: 'Shestiozersky', 1962529: '?', 1702163: 'Sholaxay', 1144451: 'Sarapulka', 1053135: 'Meltsany', 1150591: 'Kylasovo', 1931753: 'Ełk', 1702730: 'Bolshaya Malyshka', 3829474: 'Tongyeong', 1909108: '?', 18318: 'Southend-on-Sea', 1093058: 'Temyashevo', 1051133: 'Lyulpany', 1122123: 'Chernavka', 1917490: '?', 1937840: '?', 1041301: 'Pashkovsky', 1509734: 'Prigarovka', 1602402: 'Negoreloe', 1084652: 'Trostyanka', 1710915: 'Ketchikan', 1971281: '?', 5423367: 'Vaticano', 1701678: 'Pokatilovka', 1600286: 'Rechitsa', 1015407: 'Valuevka', 1052592: 'Ichalki', 3085189: 'Iringa', 1949984: '?', 1084790: 'Demyas', 1712952: '?', 1121275: 'Pestretsovo', 1121450: 'Shebunino', 14007: 'Krasnousolsky Sanatory', 1513091: 'Kazachi Lagerya', 1955852: '?', 1122609: 'Melnikovo', 1971678: 'Ciudad Bolívar', 1091844: 'Grazhdanskoe', 1101053: 'Vladenino', 1501196: 'Babintsy', 1962973: '?', 1927628: '?', 1157446: 'Irtysh', 1967919: 'Orestiada', 1079060: 'Gruzinov', 1924732: '?', 1086464: 'Tarskoe', 5425349: 'Dzhil', 1914342: '?', 1508157: 'Novy Gorod', 1082035: 'Sysoi', 1501050: 'Yurkovtsy', 1029897: 'Dulyapino', 1041979: 'Khankov', 1083965: 'Zhiguli', 1925625: '?', 5256379: 'Kleinmachnow', 1098479: 'Vybor', 1920081: 'Saint Peters', 1111061: 'Chur', 1151513: 'Platoshino', 1973248: 'Nogent-sur-Oise', 1954855: '?', 1145513: 'Pobeditel', 1959115: '?', 1971460: '?', 1715672: '?', 1712999: 'Graham', 1913429: '?', 1964530: '?', 1510600: 'Petushkov', 1027877: 'Bogdanikha', 1500537: 'Beregovoe', 1970211: '?', 1118775: 'Ivanovskoe', 1040830: 'Tsentralny', 1514438: 'Svidivok', 1950085: '?', 5266537: 'Bad Sooden-Allendorf', 1701263: 'Gerasimovka', 5266543: 'Witzenhausen', 1513876: 'Mikhaylyuchka', 1061678: 'Vodogon', 2203823: '?', 1059611: 'Novonikolskoe', 1917845: 'Kemi', 1510113: 'Khudoleevka', 1962079: '?', 1934758: '?', 1143961: 'Sumy', 1951187: '?', 1704373: '?', 1514803: 'Gvozdovtsy', 1702669: 'Chervonnoe', 1079940: 'Markinskaya', 1507701: 'Chervonoe', 1939747: '?', 1928806: '?', 1707543: 'Cape Cod Village Mobile Home Park', 1949612: '?', 1920515: 'Visalia', 1953790: '?', 1513814: 'Sharovechka', 1160742: 'Mukhor-Konduy', 1093657: 'Vtorye Levye Lamki', 1952363: '?', 1931600: '?', 1969174: '?', 1708076: 'Joplin', 1963006: '?', 1153948: 'Shebunino', 1128046: 'Podvoloshino', 1920628: 'Wheeling', 1153094: 'Alexandrovka', 1969588: '?', 1965604: 'Martvili', 1124469: 'Posolskoe', 1137087: 'Kazantsevo', 1121773: 'Uznezya', 1113484: 'Kumlyak', 1700091: 'Krasnovodskoe', 1934531: '?', 1919143: 'Poulsbo', 1110575: 'Olenye Boloto', 8519: 'Nizhegorodka', 1700963: 'Akkuduk', 1702198: 'Nikolaevka', 5111915: 'Keystone', 5428509: 'Ashutasty', 1025587: 'Khokhol', 1086427: 'Brut', 1964251: '?', 1501481: 'Gibalovka', 1506786: 'Podorozhnoe', 1048948: 'Demshinka', 1082758: 'Olkhi', 1046272: '?', 1712192: '?', 1008538: 'Gafurovo', 1502347: 'Veseloe', 1967558: '?', 5536: 'Chindaley', 1501711: 'Derno', 1962398: '?', 1002293: 'Koynas', 3501644: 'Mayapur', 9915: 'Akhtarsky', 1926012: 'Haukivuori', 1910905: '?', 1075565: 'Krasnaya Gorka', 1971929: '?', 1143619: 'Barataevka', 1713459: '?', 1500457: 'Kolodeznoe', 1964072: '?', 5022669: 'New York', 1092163: 'Sadovy', 1907332: '?', 1504490: 'Nankovo', 1010740: 'Loznaya', 1917615: '?', 1971932: '?', 1123866: 'Panino', 1009911: 'Gora Podol', 1152046: 'Romanovo', 1008979: 'Sadovy', 1083016: 'Vilovatoe', 1967155: '?', 5430746: 'Zavodskoy', 1139: 'Skalisty', 1504952: 'Bogatyr', 1037037: 'Komsomolsk-Na-Pechore', 1114638: 'Bolshie Atmeni', 5427315: 'Solnechnoe', 1507251: 'Borovskoe', 5332185: 'Malvern', 1507444: 'Poltva', 1602143: 'Zhuprany', 1969108: '?', 1156351: 'Deryabino', 1087621: 'Vasyuki', 1517183: 'Thun', 1924113: 'Lohr am Main', 1015053: 'Shebalino', 1085577: 'Piterka', 1025413: 'Abramovka (abramovsky S/s)', 1026280: 'Malaya Areshevka', 1160724: 'Zasopka', 1136022: 'Beloyarsk', 1708410: 'Liperi', 4977252: 'Berlin', 1510696: 'Zhobrin', 1514321: 'Gordashovka', 1081890: 'Sobchakovo', 1159865: 'Sherkaly', 1911527: '?', 1159570: 'Iyus', 1006901: 'Ilishevo', 1001376: 'Volskaya', 1504774: 'Belogorye', 1602958: 'Mikhalevo', 1512419: 'Kobzovka', 1511024: 'Vorozhba', 1129231: 'Zvezdny', 1959895: '?', -2940: -2940, 1085399: 'Balashi', 1910998: '?', 1095357: 'Rudnik', 22348: 'Doylestown', 1091536: 'Tomuzlovskoe', 1949412: '?', 1951911: '?', 3128973: 'Corinth', 1055136: 'Kholscheviki', 1509327: 'Stepanovka', 1950622: 'Bragança', 1514175: 'Drabovka', 1515934: '?', 1113771: 'Nadterechnoe', 1147134: 'Koltubanka', 1145143: 'Uzhanikha', 1108436: 'Velyenikolskoe', 1000557: 'Shunema', 1514867: 'Dankovtsy', 1709250: 'Ashland', 1159294: 'Evoron', 4349233: 'Nauort', 1704574: 'Bitburg', 1904028: '?', 1112592: 'Velikopetrovka', 1024573: 'Pershino', 1039412: 'Schelykovo', 1039381: 'Pokrovskoe', 4305652: 'Pepingen', 1959121: '?', 2205943: 'Jablonec nad Nisou', 1923831: '?', 1925890: '?', 1959095: '?', 1937026: 'Bullas', 1106851: 'Kadnoe', 4176647: 'Nabeul', 4177375: 'Hammamet', 1602787: 'Usyazh', 3124085: 'Aqabah', 4376815: 'Frangenberg', 1500259: 'Filatovka', 1516579: '?', 1509225: 'Zaplazi', 6647: '?', 1518766: '?', 1134123: 'Lazarevo', 1913936: '?', 1054316: 'Zarya Podmoskovya', 1151511: 'Petushki', 1966634: '?', 1002332: 'Yuroma', 1955839: '?', 1712451: '?', 1908453: 'Midland', 1939325: '?', 1500897: 'Makhnovka / Komsomolskoe', 5266903: 'Freilassing', 1158593: 'Schetkovo', 1974874: 'Miramas', 1094697: 'Elkhovo', 1144517: 'Mochische', 1040663: 'Ekaterinovsky', 21547: 'Birlestik', 1508968: 'Ilinka', 21510: '?', 1905671: '?', 1961837: '?', 1702824: 'Yasnaya Polyana', 1083836: 'Staropokhvistnevo', 1153221: 'Zanadvorovka', 1504133: 'Svoboda', 1136895: '?', 1921160: '?', 1700127: 'Olzhabay Batyra (blagodatnoe)', 1153172: 'Novonikolsk', 1712963: 'Vardenis', 1155874: 'Verkhnyaya Sysert', 1705128: 'Arvaikheer', 1944730: '?', 1973217: '?', 1973214: '?', 1505693: 'Protsev', 1014261: 'Vyazovka', 1507773: 'Rozvadov', 1918379: 'Harrisburg', 1105925: 'Begichevo', 1800717: 'Leuntya', 1913471: '?', 1011431: 'Vasilevka', 5266433: 'Bad Soden-Salmünster', 4358616: '?', 1709256: 'Montebelluna', 4544665: 'Maser', 1071659: 'Ivanovo (derevnya)', 1082980: 'Kupino', 1911985: '?', 14493: '?', 1041725: 'Kalnibolotskaya', 21665: 'Kano', 1600235: 'Mileyki', 1931558: '?', 1510848: 'Peski', 1916804: '?', 1910145: '?', 1700693: 'Ulken', 1968908: '?', 1050136: 'Plastinka', 1972979: '?', 2722645: 'Nouméa', 1511263: 'Nizy', 1082256: 'Pavelets', 17130: 'Besovets', 1035605: '14 Km', 1966231: '?', 1900102: 'Kfar Hasidim Bet', 1043146: 'Vablya', 1968460: '?', 1504475: 'Dragovo', 5259447: 'Limbach-Oberfrohna', 1941078: '?', 2722575: 'Banjul', 4243171: 'Wohlen', 1710699: '?', 1704172: '?', 1958070: '?', 1946715: 'Akron', 21325: '?', 4184242: 'Tarifa', 1159743: 'Tegi', 1504863: 'Elizavetovka', 13963: 'Botulu', 1088865: 'Zilovo', 1518944: 'Fagersta', 1928760: '?', 1129515: 'Elan', 1121741: 'Multa', 1146928: 'Zaglyadino', 1138248: 'Samokhvalovo', 1002339: 'Dolgoschelye', 1704168: '?', 1516942: '?', 1022986: 'Botovo', 1921377: '?', 1083005: 'Troitskoe', 1147762: 'Novotroitskoe', 1159315: 'Voskresenskoe', 1504723: 'Svetlodolinskoe', 1971475: '?', 1065981: 'Anikanovo', 1058446: 'Staraya Ruza', 22631: '?', 1702179: 'Urozhaynoe', 4417909: 'Montreuil', 1933249: '?', 1910098: '?', 1954548: '?', 11945: 'Kaysatskoe', 1087063: 'Lesnoy', 1079629: 'Visly', 1140860: 'Suvorovo', 1110749: 'Karkalay', 1110140: 'Yuski', 1141254: 'Bolshoe Mokroe', 1500340: 'Kormovoe', 4274: 'Glazunovka', 1967671: 'Łuków', 1502433: 'Privolchanskoe', 1030621: 'Bedyk', 1600054: 'Revyatichi', 1957502: '?', 1156424: 'Novikovka', 1132205: 'Bezbozhnik', 16863: 'Toldzgun', 1151001: 'Sedyash', 1920813: '?', 1060248: 'Leonikha', 1513570: 'Kosikovtsy', 1702530: 'Michurino', 1030474: 'Ozrek', 1072582: 'Ostrov', 1500211: 'Maryanovka', 1111416: 'Yazykovo', 1121781: 'Elikmanar', 4831530: 'Cabo de Hornos', 1042092: 'Bely', 1042118: 'Strelka', 1937654: '?', 1041116: 'Losevo', 1514767: 'Tarasovtsy', 1006861: 'Ulu-Telyak', 1703453: 'Sharur', 1128115: 'Tolmacheva', 1508637: 'Lukanovka', 1021074: 'Ivanovo (derevnya)', 1709635: '?', 1915690: 'Jaroměř', 1500143: 'Roschino', 1159154: 'Gurskoe', 1703473: 'Lerik', 1932823: '?', 1503750: 'Radcha', 1933665: 'Jessheim', 1041408: 'Prokhladny', 7888: 'Klisheva', 1967099: '?', 1959846: '?', 1051880: 'Voznesensk', 1122921: 'Slavgorodskoe', 1601632: 'Novye Golovchitsy', 1500378: 'Slavnoe', 1012669: 'Simontovka', 1147862: 'Yuny', 5225557: 'Sélestat', 1083191: 'Petra Dubrava', 1086388: 'Darg-Kokh', 1509508: 'Bobrik', 1709187: 'Alberta', 1906012: 'Manahawkin', 17660: 'Bukachacha', 1024711: 'Solovki', 1515465: 'Berezovka', 1066643: 'Startsevo', 2002044: '?', 1901326: 'Isperikh', 1514816: 'Serbichani', 1910837: '?', 4053938: 'Korhogo', 1951821: '?', 1959169: '?', 1500895: 'Kazatin Selo', 1510115: 'Andreevka', 5053409: 'East Hampstead', 1600325: 'Zalesye', 1147638: 'Novoorsk', 1510270: 'Zabolotye', 1094411: 'Savgachevo', 14778: 'Tyvrov', 1906747: '?', 1929330: 'Dabendorf', 1514163: 'Rossokhovatka', 4927: 'Novy Svet', 1052439: 'Vysha', 1159826: 'Korliki', 13117: 'Merevo', 1056752: 'Marushkino', 1507919: 'Stavchany', 14319: 'Tulagino', 1702117: 'Ozernoe', 1972627: '?', 1028469: 'Arkhangel', 1505463: 'Dzhurov', 1030949: 'Cheremkhovo', 1507480: 'Mshana', 1503228: 'Mirnoe', 1144159: 'Nizhnecheremoshnoe', 1502447: 'Khutorskoe', 1158707: 'Polovinka', 1151499: 'Oktyabrsky', 1905531: 'Shavat', 1948058: '?', 1159555: 'Saragash', 4537148: 'Åsgard', 4966848: 'Gulfport', 5428520: 'Ushtobe ', 1701983: '?', 7691: 'Bolshie Yarki', 1508907: 'Rozkvit', 1508222: 'Nezhukhov', 5057067: '?', 1092898: 'Tomilino', 20627: 'Maysky', 1096777: 'Koschakovo', 1971868: '?', 1516204: '?', 1972705: '?', 1969084: '?', 1034877: 'Zhukovo', 1972077: '?', 1912095: '?', 4637918: 'Bernal', 1941009: '?', 1963401: '?', 1102862: 'Monchalovo', 1102767: 'Esinka', 1131758: 'Yubileyny', 13670: 'Kyshik', 16695: 'Nizhnyaya Mondoma', 1159025: 'Soloni', 1701054: 'Kanonerka', 1904324: 'Arosa', 1715702: '?', 1514706: 'Drachintsy', 1700111: 'Egindykol', 1008918: 'Pokrovka', 1925234: '?', 1052133: 'Kurtashki', 1930605: '?', 1965435: '?', 1956345: '?', 1012571: 'Bobrets', 1920237: 'Torrington', 1117956: 'Mokeikha', 1517303: 'Rozovka', 1006766: 'Baltika', 4375630: 'Gailenkirchen', 1006102: 'Kushmanakovo', 1800499: 'Kayraklia', 1015000: 'Mirny', 1926786: 'Orford', 1147958: 'Pretoria', 1706778: '?', 1600838: 'Pyshno', 1052336: 'Povodimovo', 1515009: 'Burovka', 1515040: 'Tupichev', 1970632: '?', 1130763: 'Nizhnyaya Toyma', 1121679: 'Balykcha', 1063979: 'Oryol', 1147304: 'Nizhneozernoe', 1969742: '?', 1908741: 'Rhauderfehn', 1948453: '?', 1964949: '?', 1098506: 'Ivanovo (derevnya)', 1156483: 'Stepanovka', 1121308: 'Porechye', 1700402: 'Karatausay', 1955669: '?', 1915630: '?', 1519122: 'Bogatyrskaya', 1150989: '?', 1033809: 'Spas-Zagorye', 1972145: '?', 1099768: 'Gorodnya', 1043423: 'Reutov (khutor)', 1600233: 'Lyubischitsy', 1124357: 'Ust-Bryan', 1071348: 'Lipshani', 1972815: 'Elwood', 1095113: 'Salaus-Sardygan', 1956513: '?', 1046242: 'Yanino', 1093239: 'Khobot Bogoyavlenskoe', 1125958: 'Ivanovo (selo)', 1509345: 'Osichki', 1923888: '?', 1708692: 'Arapahoe', 1938848: 'Hebron', 1512764: 'Sadovoe', 3730: '?', 8284: 'Tavatuy', 1966454: '?', 1942073: '?', 1020544: 'Turovets', 5266386: 'Lennestadt', 3138460: 'Ḩabshān', 1068925: 'Kamenka', 1919258: '?', 1123199: 'Gordeevsky', 3051222: "Ra's al Khafjī", 1966812: '?', 1713053: '?', 1122048: 'Khleborobnoe', 1908226: 'Mendota Heights', 1508925: 'Vypasnoe', 1515908: '?', 1097701: 'Serezhino', 1901599: '?', 1601706: 'Ozerany', 1700302: 'Zlatopolye', 1601854: 'Benyakoni', 1971862: '?', 1000135: 'Severo-Vostochnye Sady', 1971655: '?', 4330489: 'Sonneberg', 1510904: 'Pustogorod', 1042410: 'Krivitskie Budy', 18112: 'Luzhnikovo', 21432: 'Yagubets', 1940833: '?', 1926565: '?', 1972901: '?', 1075212: 'Yasno', 1711974: 'Gainesville', 1943685: '?', 1138653: 'Isupovo', 5392: '?', 1070731: 'Skugry', 1516851: '?', 1702756: 'Lebyazhye', 1929725: '?', 1514560: 'Kibaki', 1954679: '?', 1701682: 'Prirechnoe', 1505717: 'Mircha', 1967472: '?', 1916634: '?', 1067807: 'Srednyaya Elyuzan', 1040681: 'Sinegorsk', 1014419: 'Marinovka', 1974100: '?', 1932529: 'Belford', 1972026: '?', 1501749: 'Goloby', 1971273: '?', 1973510: '?', 1706327: 'Hickory', 1972954: '?', 1129733: 'Kolychevo', 1031896: 'Mirny', 1007019: 'Makarovo', 1122146: 'Cheremushkino', 1121945: 'Chemrovka', 1023233: 'Nova', 1084510: 'Ivanovka', 1909037: '?', 1969729: '?', 1945865: '?', 1008077: 'Uyazybashevo', 1112738: 'Kamenka', 1972976: '?', 7165: '?', 1030522: 'Novo-Poltavskoe', 1030508: 'Dalnee', 1124613: 'Galtay', 1037000: 'Sedkyrkesch', 1962532: '?', 1512815: 'Vishnevoe', 1137993: 'Raskatikha', 1053238: 'Purdoshki', 5267911: 'Saal a.d.Donau', 1095263: 'Novye Chechkaby', 1512251: 'Topoli', 1943195: '?', 1010952: 'Koshlakovo', 1011010: 'Churaevo', 1156541: 'Pavlovo', 1516561: 'Ostromechevo', 1009750: 'Shelaevo', 1129967: '?', 1042134: 'Dneprovskaya', 1031898: 'Khosheut', 1903394: '?', 1961121: '?', 1101740: 'Belaya Gora', 1079249: 'Troitskoe', 1015303: 'Peschany', 1973118: '?', 1914254: '?', 1013848: 'Lyubozhichi', 17361: 'Chuvashi', 4191284: 'Linguaglossa', 1915445: '?', 1701609: 'Shalgay (pervosovetskoe)', 1005322: 'Starotimkino', 1031988: 'Lagan', 1008821: 'Mansurovo', 1133689: 'Rogovoe', 1706456: '?', 1101849: 'Novoselki', 1501845: 'Rokini', 1057126: 'Klin (poselok)', 1803570: 'Shafirkan', 1154187: 'Katyshka', 1082587: 'Pushkino', 1136350: 'Sakhapta', 1026779: 'M. Gorkogo', 1048354: 'Monino', 1507438: 'Ozhidov', 1030596: 'Mir', 1139629: 'Novoselki', 14680: 'Ilek', 1973079: '?', 1106234: 'Verkhoupye', 1013633: 'Selechnya', 1973083: '?', 1043222: 'Yasny', 2208390: 'Łomża', 1007781: 'Vostochny', 1911128: '?', 1026947: 'Sulevkent', 1143730: 'Baklushi', 1136650: 'Uspenka', 1011911: 'Velyaminova', 1500796: 'Serbinovtsy', 1046387: 'Pervomayskoe 1-E', 1092323: 'Kurgan (derevnya)', 1504543: 'Primorskoe', 1093595: 'Chakino', 1152158: 'Primorye', 1518957: 'Beshkent', 1061532: 'Evanichi', 1157340: 'Malinovka', 1092837: 'Karpeli', 1512676: 'Lebyazhye', 1040752: 'Erik', 1000220: 'Mikhaylov', 13513: 'Kyra', 14358: 'Rozovy', 1122199: 'Baranovka', 1509069: 'Matrosskaya', 22303: 'Nieuw-Vennep', 1002263: 'Shies', 1035319: 'Prechistoe', 1136757: 'Podsopki', 1911379: '?', 1502266: 'Bykovo', 1080602: 'Ivanovo (derevnya)', 1973134: '?', 1936276: '?', 1123708: 'Bogorodskoe', 14875: 'Razdolnoe', 1086467: 'Chermen', 1510832: 'Ulyanovka', 3055642: 'Shīrāz', 1947081: '?', 1070254: 'Chernevo', 1070185: 'Polichno', 1938233: '?', 5097324: 'Garden City', 1927905: '?', 1973181: '?', 1031326: 'Krasnoyarskoe', 1105593: 'Pushkino', 1137743: 'Bolshoe Kureynoe', 1507288: 'Verkhnebogdanovka', 1711251: 'Kolbasna', 1909713: 'Wellesley', 1509528: 'Rashevka', 1901379: '?', 1908854: '?', 1715351: '?', 1028666: 'Novye Gorki', 5266836: 'Stockach', 1144745: 'Bortsovo', 4397681: 'Arklow', 1951852: '?', 1122465: 'Troitsk', 1157987: 'Krutinskaya', 4109494: 'Sulimissi', 1505172: 'Krikhovtsy', 1904193: '?', 1973127: '?', 1914702: '?', 1600775: 'Berezino', 1503799: 'Pischov', 1945553: '?', 1132488: 'Zalazna', 1132513: 'Severny', 1943181: '?', 1509544: 'Brovarki', 1971145: '?', 1030479: 'Alexandrovskaya', 1017862: 'Ermakovo', 1908409: '?', 1509670: 'Popovka', 1911830: '?', 1966302: 'Akhmedli', 1706786: 'Dendermonde', 1028087: 'Ankovo', 5944: 'Martin', 1972737: '?', 1905234: '?', 1032938: 'Tarutino', 1067754: 'Arkhangelskoe', 1967075: '?', 1970993: '?', 1972038: '?', 1071246: 'Bor', 1084701: 'Gorny', 1510266: 'Gorodets', 1709315: 'Saint George', 1923696: '?', 1073914: 'Novaya Usitva', 1914896: 'Xàbia / Jávea', 1115477: 'Zasurye', 1130426: 'Moskovskaya', 1972178: '?', 1972619: '?', 1924074: '?', 1922389: '?', 1924954: '?', 1602698: 'Blon', 1912662: '?', 1508243: 'Borinya', 1505420: 'Broshnev-Osada', 18736: 'Yangelsky', 1707115: 'Voghera', 1062375: 'Orekhovno', 1510636: 'Ploskoe', 1026907: 'Axay', 1710294: 'Iski-Naukat', 1954685: '?', 1924769: '?', 1057579: 'Efimovo', 1108805: 'Moskovskaya', 1959658: '?', 1138725: 'Shatovka', 1911715: 'Konstantinovka', 1709329: 'Brockton', 1147598: 'Novouzeli', 1600262: 'Yaglevichi', 1509372: 'Sergievka', 1508876: 'Peschanaya', 1509467: 'Novosvetovka', 1509468: 'Armashevka / Ordzhonikidze', 1507944: 'Nikolaev', 1966984: '?', 1944790: '?', 1040756: 'Kabardinskaya', 1507450: 'Storonibaby', 1149652: 'Tobolskaya', 1954401: '?', 5470222: 'Ks-5', 1142606: 'Selitba', 1602176: 'Khonevichi', 1937988: 'Sarno', 1973384: '?', 1919154: '?', 1501639: 'Kolona', 1914021: '?', 1064125: 'Morkhovo', 1701266: 'Saratovka', 17329: '?', 1602300: 'Bolshaya Ukholoda', 1047699: '?', 1944386: '?', 1091933: 'Krasnozorinsky', 1157936: 'Maslyanka', 1503944: 'Stavki / Lenino', 1161668: 'Druzhba', 21098: '?', 1911693: '?', 1504603: 'Privolnoe', 1518283: '?', 1909319: '?', 2102432: 'Pitnak', 1509088: 'Dmitrovka', 1923035: 'Torre del Greco', 1946026: '?', 1032487: 'Zhiletovo', 1973431: 'Norakert', 3803088: 'Heze', 1502047: 'Dubechno', 1708819: '?', 1600534: 'Rubel', 1508579: 'Kalinovka', 1084186: 'Saleykino', 1518644: 'Littleton', 1506042: 'Pustovity', 1710038: '?', 5332372: 'Sageston', 1939385: '?', 1930753: '?', 1973682: 'Digboi', 1512011: 'Verbovka', 1506509: 'Nazarovka', 1973517: '?', 1974019: '?', 1904990: '?', 1707219: 'Roseville', 1964193: '?', 1121633: 'Biyka', 1051060: 'Tat-Kitnya', 1705224: 'Vail', 1704667: '?', 1926980: '?', 1516486: 'Byron', 1145790: 'Okunevo', 1062059: 'Peski', 19325: 'Sukhorechka', 1130724: 'Syrda', 1961123: '?', 1502841: 'Privolnoe', 1950779: '?', 1062384: 'Pestovo', 1014057: 'Larinsky', 1512562: 'Belyaevka', 1702426: 'Ivanovka', 1941486: 'Baja California', 1037134: '?', 1008157: 'Alkino', 1083954: 'Bolshaya Ryazan', 1154315: 'Sosnovy Bor (poselok)', 1711558: '?', 1123191: 'Belovsky', 1973138: '?', 1902453: 'Baysun', 1052772: 'Troitsk', 1514191: 'Selische', 1504940: 'Obitochnoe', 1156209: 'Gorodische', 3337905: 'Upper Gong-Gong', 1502655: 'Mogilev', 1091712: 'Ivanovskoe', 1091699: 'Belomechetskaya', 1713508: 'Kalutara', 4191: 'Brig-Glis', 1158389: 'Shilovo', 1933840: '?', 1502582: 'Novopokrovka', 2000648: 'Ivanovka', 1962344: 'Nurmes', 1042110: 'Peresyp', 5039025: 'Winthrop', 11428: 'Vekovka', 1153081: 'Novostroyka', 1931716: '?', 1947451: '?', 1036246: 'Khiydenselga', 1702471: 'Tokhta', 1159326: 'Mariinskoe', 1035364: 'Apsua', 1505972: 'Mikhaylovka-Rubezhovka', 1971290: '?', 1159412: 'Topolevo', 1971863: '?', 21844: 'Kurskoe', 14504: 'Vakhovsk', 1914912: '?', 1911423: '?', 1939512: '?', 1504653: 'Maryevka', 1140954: 'Gavrilovka', 1701096: 'Ushanovo', 1081240: 'Mary', 1084648: 'Stary Khoper', 1902098: 'Killeen', 1501676: 'Kachin', 1159634: 'Zelenoe', 1512302: 'Borki', 1049032: 'Khvorostyanka', 1127191: 'Pavlovskoe', 1084298: 'Novy Port', 1071560: 'Vilno', 1507483: 'Peremozhnoe', 1030773: 'Ozerki', 5089704: 'Bermuda Dunes', 1502807: 'Shakhtarskoe', 1055149: 'Shkola Im 15 Let Oktyabrya', 1134311: 'Krasnaya Polyana', 1920221: 'Tifton', 1709458: 'Beloit', 1045530: 'Chudtsy', 1130958: 'Kosa (stantsia)', 1083758: 'Mikhaylo-Ovsyanka', 1961192: '?', 1144546: 'Yarkovo', 1095823: 'Tatarskoe Tanaevo', 1150705: 'Shadeyka', 1800608: 'Korneshty', 1030601: 'Chegem 1-J', 1120328: 'Volzhsky', 1713376: '?', 1509279: 'Novaya Dolina', 1973782: '?', 1966739: '?', 1973809: '?', 20134: '?', 1140173: 'Pustoshka', 1083644: 'Ekaterinovka', 1920712: '?', 1706361: '?', 1008969: 'Novopetrovskoe', 1110290: 'Kokman', 1022760: 'Semigorodnyaya', 1518598: 'Austin', 1154299: 'Lebedkino', 1000049: 'Maysky', 1149228: 'Plishkari', 1518341: 'Lons-le-Saunier', 1091594: 'Kamennobrodskaya', 19978: 'Kurganovo', 1154526: 'Churmanskoe', 1145534: 'Zimino', 1935777: '?', 1115008: 'Kovali', 2202648: '?', 18326: 'North Hills', 4011766: 'Sabha', 1091967: 'Novy Mayak', 1045826: 'Vyndin Ostrov', 1042152: 'Novokorsunskaya', 4387007: 'Boppard', 1114856: 'Niskasy', 1002686: 'Mamonikha', 1035597: 'Novoe Yushkozero', 1969619: '?', 1976589: '?', 2208427: '?', 1970271: '?', 1972489: '?', 1506621: 'Kapitanovka', 1014790: 'Sekachi', 1963928: '?', 1958238: '?', 1106340: 'Yalta', 1148162: 'Axenkino', 1004572: 'Abzelilovo', 1076959: 'Alexandrovo', 1153862: 'Zelenodolsk', 3423462: 'Āt Khvājeh', 12101: 'Pay', 1024915: 'Shuvalov', 1705982: 'Geraardsbergen', 1055282: 'Khvorostyanka', 1083317: 'Krasny Yar', 1078312: 'Kamyshev', 1105637: 'T/b Alexin Bor', 1160898: 'Providenia 2-E', 1505905: 'Strakholesye', 4619213: 'Lelydorp', 1707114: 'Chakvi', 1950716: '?', 1160270: 'Ustye', 1511023: 'Veliky Vistorop', 5398717: 'Swieqi', 1913202: 'Grimstad', 1514937: 'Kobizhcha', 1096962: 'Sababash', 1031283: 'Chistye Prudy', 1515244: 'Kruty', 1099990: 'Orsha', 1517619: 'Tomay', 1972726: '?', 1066302: 'Obnovlennaya Zemlya', 5421340: 'Notre Dame', 1114409: 'Shorkasy', 638: 'Orono', 1966295: 'Saco', 1709479: 'Biddeford', 1708644: 'New Paltz', 1974717: '?', 6508: 'Yutanovka', 18639: 'Doncaster', 1601056: 'Konstantovo', 1714128: '?', 1950594: '?', 1511269: 'Sad', 1967083: '?', 1013095: 'Krasny Rog', 1014025: 'Chernobabki', 1502728: 'Lisichye', 1500782: 'Lysyanka', 1099711: 'Bolshie Borki', 1509789: 'Sadki', 1967473: '?', 18592: '?', 3113850: 'Djibouti', 5267840: 'Homberg (Efze)', 1041165: 'Alexandrovskaya', 1967338: '?', 1932310: '?', 1010239: 'Gorki', 1971689: '?', 4500622: 'Kępno', 8429: 'Alnarp', 1974010: 'Alva', 1501312: 'Komargorod', 1500297: 'Vladislavovka', 1707151: '?', 1500877: 'Shepeevka', 1154115: 'Lagunnoe', 4924225: 'Palmetto', 3216609: 'Pedersören Kunta', 1971794: '?', 5130572: 'West Vancouver', 1934106: '?', 1712770: 'Getzville', 1153813: 'Myryla', 1974038: '?', 1965146: '?', 1155627: 'Ustyanka', 5061098: 'Orlando', 1068036: 'Chumaevo', 1133749: 'Shikhovo', 1066596: 'Pankovo', 1130001: 'Listvyanka', 1056069: 'Golovachevo', 1049729: 'Gagarino', 1111187: 'Golovtsevo', 1112235: 'Priuralsky', 1036516: 'Valday', 20343: 'Beihai', 1123065: 'Novorossiyka', 1001095: 'Shidrovo', 1068937: 'Narovchat', 1128368: 'Kostino', 1128316: 'Novoilimsk', 1158049: 'Rozhdestvenka', 1974074: 'East Jewett', 1900617: 'Shehania', 1152032: 'Oryol', 21362: 'Río Bravo', 1947594: '?', 1507300: 'Olkhovoe', 1501443: 'Babchintsy', 1948649: '?', 1952274: '?', 1502778: 'Bogatyr', 1933711: '?', 1951570: '?', 1913691: '?', 1945590: '?', 1152575: 'Arkhangelskoe', 1035507: 'Ali-Berdukovsky', 4230351: 'Stromness', 1511027: 'Grintsevo', 1501864: 'Vetli', 1139905: 'Torzhok', 1121501: 'Alkhanay', 1701612: 'Yanaykino', 1800245: 'Viishoara', 1701261: 'Gagarino', 1123454: 'Komarikha', 1505909: 'Fenevichi', 1505688: 'Lyubartsy', 1147829: 'Nizhnyaya Pavlovka', 1514502: 'Pridneprovskoe', 1924526: '?', 1024052: 'Karaychevka', 1500330: 'Chkalovo', 1504866: 'Inzovka', 1601373: 'Lyudenevichi', 1509416: 'Divizia', 1600159: 'Khomsk', 13768: 'Novosvetlovka', 1124465: 'Novy Enkheluk', 1039534: 'Antropovo', 5058944: 'Greenport', 1949733: 'Marinha Grande', 1044887: 'Kalinovka', 1006591: 'Tarkazy', 1121478: 'Yaroslavka', 1024370: 'Volokonovka', 1702581: 'Kutuzovka', 1512734: 'Rakovka', 1122719: 'Pervomayskoe', 1974184: '?', 1501002: 'Mikulintsy', 1055217: 'Kolmna', 1009500: 'Belomestnoe', 1969637: '?', 1077135: 'Klin', 1158742: 'Ershova', 2245: '?', 1966714: '?', 1505773: 'Ivankovichi', 1138753: 'Konevo', 1047023: 'Novaya', 1513302: 'Zyankovtsy', 4762580: 'Iquitos', 3145740: 'Muğla', 3153607: 'Göynük', 1091964: 'Zhuravskoe', 18937: 'Terenkol (kashyr)', 1959872: '?', 1962287: '?', 21714: 'Werder (Havel)', 1974389: '?', 1023827: 'Brodovoe', 1918411: '?', 1970883: '?', 1099232: 'Ivan Trud', 1049027: 'Talitsky Chamlyk', 1078412: 'Astakhov', 1940895: '?', 1033302: 'Lubny', 1961490: '?', 1152710: 'Yakunevo', 4317650: 'Wunstorf', 1083999: 'Yagodnoe', 1065860: 'Sergievskoe', 1147827: 'Nezhinka', 1945302: 'Augustów', 1920359: '?', 1004941: 'Amzya', 1936611: '?', 16871: 'Vladislavovka', 1959912: '?', 5112099: 'Onida', 1801415: 'Tyrgul Vertyuzhen', 1706147: '?', 1905951: '?', 1908668: '?', 1911006: 'Agalik', 4474794: 'Praskolesy', 2203210: '?', 1927361: 'Elze', 1512660: 'Khoroshevo', 1144134: 'Chernovka', 1955835: '?', 3917: '?', 1138493: 'Kulu', 1957062: '?', 1973583: '?', 1078364: 'Vorontsovka', 1922867: '?', 1701924: '?', 1011107: 'Yakovlevo', 1146062: 'Kalinino', 2204464: '?', 1602301: 'Zabashevichi', 1013949: 'Dubrovka', 1024594: 'Babyakovo', 1974350: '?', 1973965: '?', 1055733: 'Istra', 1500543: 'Ordzhonikidze', 1960580: '?', 1961611: 'Bembridge', 1128296: 'Dalny', 1500481: 'Pozharskoe', 1077159: 'Kuznetsovka', 1974378: '?', 1514104: 'Lebedovka', 1505902: 'Rusaki', 1709559: 'Bankya', 1973627: '?', 1060228: 'Dushonovo', 1096354: 'Su Elga', 1022497: 'Vaulino', 2749: 'Roanoke', 1508835: 'Delen', 1904637: '?', 1971716: 'Ulyanovka', 18735: 'Novomalorossiyskaya', 1105922: 'Balakhna', 1504294: 'Klyucharki', 1129740: 'Oktyabrsky', 5428285: 'Aktas', 1159969: 'Nyalinskoe', 1502457: 'Dmitrovka', 18420: 'Schapovo', 12504: 'Uspenskoe', 1901120: 'Shoham', 1967704: '?', 2206132: 'Offenbach am Main', 1509168: 'Vishnevoe', 1974408: 'Alat', 1096095: 'Astrakhanka', 1923213: '?', 1127403: 'Alexeevka', 1974414: 'Mundemba', 1025053: 'Berezovo', 1500364: 'Kotovskoe', 1970666: 'Shishtepe', 1057603: 'Rakhmanovo', 1956394: '?', 1974452: '?', 4288825: 'Wattens', 4290842: 'Schwaz', 7744: 'Demikhovo', 1094889: 'Kultes', 1036928: 'Verkhnyaya Omra', 1712602: '?', 5266697: 'Crailsheim', 1150997: 'Russky Sars', 1505766: 'Danilovka', 1963049: '?', 1970567: '?', 14611: 'Shibylgi', 1713249: 'West Milford', 1946987: '?', 1095353: 'Pechischi', 1004389: 'Krasny Yar', 1922653: 'Whistler', 1974490: 'Crewe', 11863: '?', 1972995: '?', 5470705: 'Okzhetpes', 5425832: 'Krasnaya Gorka', 1147104: 'Berezovka', 1146964: 'Troitskoe', 1800047: 'Balasineshty', 1144127: 'Reshety', 1091987: 'Prikalaussky', 1944379: 'Estonka', 1023596: 'Kotovo', 5421341: 'Cockburn Town', 1703151: 'Kholopenichi', 1974338: '?', 16031: 'Norwood', 4549252: 'Casale Monferrato', 5090854: 'Downey', 1509190: 'Staraya Kulna', 1974522: '?', 5100: 'Varsseveld', 1080871: 'Pustotino', 5259317: 'Hennigsdorf', 1932946: 'Falkensee', 1084803: 'Mirny', 1517865: '?', 1511250: 'Verkhnyaya Sirovatka', 1160579: 'Drovyanaya', 1968321: '?', 1161158: 'Otrozhny', 20463: 'Rozhnov', 1801681: '?', 1042524: 'Kobylki', 1036488: 'Pudozhgorsky', 1920191: '?', 1957493: '?', 1934648: '?', 1509294: 'Limanskoe', 1933512: '?', 1976052: '?', 1078519: 'Lysogorka', 1507550: 'Berezhnitsa', 1509788: 'Rokitnoe', 1957850: 'Kouvala', 1937275: '?', 1500265: 'Vinogradnoe', 1507632: 'Zibolki', 1059679: 'Yabdino', 1511944: 'Probezhnaya', 1975684: '?', 1601412: 'Bobovka', 1940026: '?', 5266889: 'Weingarten (Württemberg)', 1516328: 'Helmond', 1974602: '?', 1932565: '?', 4118440: 'Kara', 1516194: 'Banner Elk', 1081345: 'Voskresenka', 1955642: '?', 1917871: "Saint Mary's County", 1123292: 'Slyudyanka', 16296: '?', 18439: 'Avon', 4889902: 'Ensenada', 1121578: 'Klyuchi', 1942630: 'Louisville', 1974637: '?', 1109904: 'Fakel', 1122740: 'Zeleny Dol', 1041948: 'Zaboysky', 1152460: 'Karyer', 1973813: '?', 1134861: 'Bely Yar', 1502665: 'Tsibulkovka', 1080079: 'Azeevo', 1514185: 'Neterebka', 1937368: '?', 1136753: 'Nakhvalskoe', 1112431: 'Kulevchi', 1129636: 'Burlaki', 1918323: '?', 1513935: 'Voronovka', 3081914: 'Moshi', 1964903: '?', 1122572: 'Aschegul', 1901736: '?', 1153712: 'Khordogoy', 1515048: 'Berezhovka', 1502240: 'Zlatoustovka', 6283: 'Drabovo Baryatinskoe', 1136043: 'Salba', 5307246: 'Cesson-Sévigné', 1506927: 'Beloskelovatoe', 1715295: 'Heerbrugg', 1147801: 'Blagoslovenka', 1078629: 'Zamchalovo', 4410068: "Saint-André-Goule-d'Oie", 1507090: 'Kapitanovo', 1095082: 'Karaduvan', 16191: 'Nikolskoe', 1500069: 'Vasilyevka', 1715190: 'Oruro', 1156551: 'Kalininsk', 1800007: 'Alexanderfeld', 1963929: '?', 1923882: '?', 1958577: 'Vohburg an der Donau', 1085560: 'Mironovka', 1974720: '?', 1931851: '?', 3713: 'Shumilinskaya', 1023820: 'Artyushkino', 1069717: 'Lopatkino', 1512269: 'Russkaya Lozovaya', 1501381: 'Tarasovka', 1963254: '?', 1971563: '?', 1508764: 'Sofievka', 1146040: 'Achair', 5029392: 'Galva', 1154351: 'Malaya Tavra', 1000149: 'Tsvetochny', 1602017: 'Goldovo', 1055459: 'Nudol', 1036345: 'Kolatselga', 1708532: '?', 1923740: '?', 1974770: '?', 1046413: 'Reshetnikovo', 9423: 'Bereznyaki', 1092387: 'Vorontsovka', 1502499: 'Vinogradovka', 5266900: 'Burghausen', 1512732: 'Olgovka', 1502861: 'Malinovka', 1707825: 'Dzhebrail', 1504457: 'Srednee', 1962238: '?', 1923307: '?', 1944708: '?', 1100341: 'Vakhonino', 1124481: 'Tarakanovka', 1974058: '?', 5267640: 'Landau an der Isar', 1514214: 'Maryanovka', 1147626: 'Gorkovskoe', 1602228: 'Syrovatki', 1969155: '?', 1940479: '?', 1060280: 'Petrovskoe', 1957353: 'Fano', 1504828: 'Bogdanovka', 1084847: 'Polevodinsky', 1001892: 'Ershevskaya', 1513971: 'Levchenkovo', 1504141: 'Volosyanka', 1157256: 'Oschepkovo', 1934123: 'Zafarabad', 1143141: 'Purekh', 1937946: '?', 7808: 'Litvinovichi', 5064755: 'East Rochester', 1972661: '?', 1905734: '?', 1153498: 'Zhigansky', 1706215: 'Altynkan', 4977822: 'Medford Lakes', 1503612: 'Khotinovka', 1701779: 'G. Mustafina', 1974866: '?', 1113432: 'Krasnoselskoe', 1021144: 'Litega', 4933653: 'Detroit', 1974875: '?', 1054606: 'Ryazanovsky', 1133702: 'Semaki', 1005490: 'Yanybay', 1901922: '?', 1969532: '?', 1141616: 'Salavir', 1933781: '?', 1015025: 'Antonov', 1025102: 'Podgornoe', 5471685: 'Sumsar', 13170: 'Kulan', 18581: 'Piytsieki', 4549487: 'Carmagnola', 1085764: 'Kurgan (selo)', 5429: 'Kluczbork', 1004986: 'Kuezbashevo', 1153663: 'Sanyyakhtakh', 1096652: 'Axumla', 1503148: 'Kurakhovka', 1713720: 'Baetovo', 1138031: 'Suleymanovo', 18547: 'Dmitrievka', 5284: 'Pyatimorsk', 1144693: 'Kievka', 1052810: 'Sabaevo', 1974957: '?', 1149696: 'Belovo', 1005377: 'Ermolkino', 1970619: '?', 1513801: 'Pirogovtsy', 1113689: 'Elistanzhi', 1028125: 'Ivashevo', 1106127: 'Metrostroevsky', 1703046: 'Kyzemshek', 1911192: '?', 1926473: '?', 1120391: 'Chebakovo', 1052898: 'Alexandrovka', 1965205: '?', 1936544: '?', 4527: 'Teploe', 21461: '?', 6989: 'Shorshely', 1002602: 'Pokrovskoe', 5757: 'Urshelsky', 1939024: '?', 1946266: '?', 17639: 'IJmuiden', 1146041: 'Achairsky', 2002081: '?', 1906407: '?', 1514306: 'Samgorodok', 1914708: 'Shaumyani', 1708000: '?', 1157866: 'Ilinka', 1702150: 'Kamensk-Uralskoe', 1702147: 'Tenizovsky', 1952292: '?', 3742199: 'Panglao', 1122754: '12 Let Oktyabrya', 1052527: 'Venera', 1518594: 'Dzhulfa', 4275723: 'Mealhada', 1975037: '?', 1040234: 'Severnoe', 1944956: '?', 1975075: '?', 1975044: '?', 1954330: '?', 1042176: 'Bolshevik', 1035419: 'Kumysh', 4430797: 'La Presle', 1106037: 'Borozdenki', 1044243: 'Obesta', 11277: 'Pridneprovskoe', 1126086: 'Bavleny (poselok)', 1703135: 'Redlands', 1505191: 'Zbora', 1141094: 'Chudovo', 4187337: 'Guardamar de la Segura', 1510589: 'Malin', 4999727: 'Saratoga Springs', 5115321: 'Saratoga Springs', 1960346: 'Elmont', 2344: 'Edmond', 1512101: 'Krysino', 1603350: 'Khatskovichi', 1903411: '?', 1009717: 'Podgornoe', 1008128: 'Novokulevo', 5266778: 'Mühlacker', 3135: 'Nivshera', 1701950: 'Zharyk', 1026470: 'Orada-Chugli', 1965409: '?', 1131116: 'Burashi', 1021056: 'Zagoskino', 2201626: '?', 1004225: 'Tishkovo', 1974663: '?', 1601262: 'Sharibovka', 1051684: 'Usola', 1036560: 'Lakhdenkyulya', 1503505: 'Medvedevo', 1975158: '?', 1711579: 'Aspen', 1152398: 'Maly Bereznik', 1964571: '?', 2001493: '?', 1901691: '?', 1972386: '?', 1969282: '?', 1975174: '?', 1705604: 'La Louvière', 1155281: 'Aziatskaya', 1508926: 'Dolinovka', 1906564: '?', 4962831: 'Maryland Heights', 1910821: '?', 1508513: 'Scherbani', 18824: 'Berezinsky', 1962065: 'Uzun (bostanlyxky Rayon)', 1504931: 'Vladovka', 1097495: 'Starye Urussu', 4192354: 'Acquaviva Platani', 1006139: 'Teplyaki', 20380: 'Pazhga', 1145767: 'Kartashovo', 1145751: 'Artyn', 1970513: '?', 1157624: 'Lamensky', 1975142: '?', 1158041: 'Novoandreevka', 15124: 'Mariets', 1975208: '?', 1714570: '?', 2720495: 'Rūdiškės', 1917024: '?', 1702685: 'Amangeldy', 1011484: 'Unoshevo', 5266656: 'Kornwestheim', 1925959: '?', 1969968: '?', 1937864: '?', 1928909: '?', 2052: 'Ajaccio', 1507895: 'Lisinichi', 1964012: '?', 1905651: 'Uchkuprik (uchkuprixky Rayon)', 1109848: 'Loza', 1143722: 'Ust-Lamenka', 1975236: '?', 7885: 'Plotina', 1083600: 'Kolyvan', 20867: 'Östersund', 1037018: 'Pervomaysky', 1508796: 'Sadovoe', 1514599: 'Voloka', 14177: 'Aramashevo', 1143853: 'Sosnovka', 1151842: 'Tyulkino', 1029798: 'Morozovo', 6977: 'Strizhavka', 1112227: 'Narovchatka', 1110441: 'Gornyak', 1512493: 'Senkovo', 1112977: 'Oktyabrsky', 5126489: 'Langenburg', 1157924: 'Kinder', 7618: 'Tikhon', 1951454: '?', 2543: 'Lancaster', 21764: 'Borovskoe', 1711268: '?', 1974102: 'Nandy', 1066411: 'Yuryev', 1950640: '?', 10436: 'Podborovye', 1089842: 'Vadino', 1010509: 'Avdeevka', 1092875: 'Pervaya Annenka', 1005576: 'Tara', 1515302: 'Doslednoe', 1083369: 'Podgorny', 1704396: 'Agstafa', 1930370: '?', 1972372: 'Chimen (fergansky Rayon)', 1975401: '?', 1968007: '?', 1602559: 'Sosny', 1921282: '?', 1156284: 'Yar', 5454019: 'Chukhny', 19410: 'Vladimirovka', 1092340: 'Pavlodar', 1962742: '?', 1510918: 'Esman / Chervonoe', 1124517: 'Alla', 4240853: 'Burton upon Trent', 1701575: 'Sarykol', 1049274: 'Sokolye', 1143707: 'Pavlovo', 1142936: 'Pavlovo', 22548: 'Verblyuzhka', 1514007: 'Sabadash', 1938937: '?', 1936538: '?', 1513161: 'Khoroshev', 1904060: 'Rushan', 1041028: 'Sokolovskoe', 1701395: 'Ulken Sulutor', 1031668: 'Prokhladnoe', 1908071: '?', 1132372: 'Sokolovo', 1129745: 'Plotnikovo (poselok)', 4528338: 'Algorta', 1143508: 'Chernoe', 1032212: 'Baryatino', 1501913: 'Radekhov', 1097479: 'Bayryaka', 1946983: '?', 1146219: 'Dobrovolsk', 1711093: '?', 1966026: '?', 14616: 'Ylivieska', 1707027: '?', 1036953: 'Ust-Ukhta', 1508107: 'Spasov', 1003115: 'Luda', 1975491: '?', 1709251: 'Aston', 4384676: 'Burg bei Magdeburg', 1031866: 'Shin Mer', 1702350: 'Mangistau', 1924055: '?', 4944521: 'Princess', 1970628: '?', 4904: 'Khodzheyli', 1519102: 'Jerash', 1961527: '?', 1500849: 'Zhigalovka', 1111776: 'Adoevschina', 1509816: 'Sencha', 1902039: '?', 1975524: '?', 1157094: 'Kok-Khaak', 5563: 'Neustadt in Sachsen', 1504373: 'Ploskoe', 1044216: 'Krupets', 1008140: 'Staroisaevo', 4678113: 'Mérida', 1091617: 'Bolshevik', 1905979: '?', 1049277: 'Talitsa', 1156387: '?', 1946605: 'Hemel Hempstead', 5094900: 'Soquel', 1975557: '?', 1501531: 'Doroshovka', 1954014: '?', 3145256: '?', 1950725: '?', 1018688: 'Megra', 1160457: 'Maleta', 1958038: 'Landstuhl', 1064181: 'Tyubaevo', 5470201: 'Oktyabrsky', 1974809: 'Fléron', 1951956: '?', 1147047: 'Korovino', 5259501: 'Radebeul', 1602724: 'Talka', 1513626: 'Zhukov', 1966165: '?', 1940415: '?', 3134601: 'Deïr ez Zahrâni', 17463: 'Lepley', 1095899: 'Ulyankovo', 1962637: '?', 1714239: '?', 1968967: '?', 1122777: 'Khleborob', 1711224: 'Elizabethtown', 6394: 'Piskovichi', 3483149: 'Moratuwa', 1026344: 'Temirgoe', 1513970: 'Kononovka', 1080382: 'Krutoyarsky', 1098915: 'Pavlovo', 3503681: 'Calicut', 1061544: 'Zaytsevo', 1915449: '?', 1926974: 'Los Pedros', 1904804: 'Bad Bergzabern', 1113155: 'Mayachnoe', 1003371: 'Nagorskaya', 1064596: 'Savinsky', 1929520: '?', 1006913: 'Kipchakovo', 3833245: 'Takarazuka', 1000731: 'Osyatkino', 1000726: 'Okulovskaya', 1964537: '?', 1093093: 'Krasny Kust', 1714551: 'Einbeck', 1058749: 'Toporkovo', 3840233: 'Hachiōji', 1933576: '?', 1973871: '?', 16050: 'Staroizobilnaya', 1507111: 'Dontsovka', 1942019: '?', 1922308: '?', 1960441: '?', 1904207: '?', 4494028: 'Piekary', 4494031: 'Piekary', 2209275: 'Bourne', 1974009: '?', 1508599: 'Peresadovka', 1914405: '?', 1975687: 'Wolbrom', 1128283: 'Muskovit', 2363: 'Maidenhead', 1107196: 'Oslonovo', 1971307: '?', 1505625: 'Ozerna', 1506840: 'Dyakovo', 1602667: 'Syrmezh', 10705: 'Geel', 1955554: '?', 1970781: '?', 4553509: 'Babru', 1086294: 'Nizhny Tsey', 5330459: 'Maslovsky', 4896: 'Lomovatka', 21270: '?', 1504702: 'Voznesenka', 1958361: '?', 813: '?', 1962269: '?', 1048683: 'Volgoelektrosetstroy', 1093328: 'Peskovatka', 1153570: 'Mirninsky', 1115625: 'Yantikovo', 5428913: 'Zholkuduk', 1966716: '?', 1091737: 'Starodvortsovsky', 1159100: 'Mogilevka', 1508826: 'Shimkovo', 1508816: 'Kokhanovka', 1973613: '?', 19062: 'Orgakin', 1014457: 'Dubovka', 1712681: '?', 1502143: 'Bogdanovka', 1144431: 'Kayly', 1975819: '?', 1507302: 'Petrovka', 1115431: 'Salanchik', 1601404: 'Chervonoe', 1058491: 'D/o № 7', 1137068: 'Kholmogorskoe', 1158872: 'Bulusa', 1068710: 'Zasechnoe', 4905719: 'Karanga Village', 1160373: 'Nerchinsky Zavod', 1941236: '?', 5429885: 'Mirny', 1513397: 'Mikhnov', 1133848: 'Podnovye', 1510676: 'Khotin', 1975733: '?', 1501143: 'Balanovka', 1122180: 'Novokopylovo', 1012209: 'Novye Yurkovichi', 1900668: "Ashdot Ya'akov", 1040944: 'Novobeysugskaya', 1508048: 'Rosokhach', 1141453: 'Pichingushi', 1147994: 'Dyusmetyevo', 1122829: 'Tsentralnoe', 1062409: 'Selo', 1004812: 'Karagay', 1122082: 'Sibirsky', 1154367: 'Sazhino', 1041141: 'Grechanaya Balka', 1514373: 'Rogovaya', 1131252: 'Burmakino', 1091445: 'Kurshava', 1513592: 'Burtin', 1513354: 'Loshkovtsy', 1502859: 'Kuybyshevo', 1503102: 'Kominternovo', 1951081: '?', 1700706: 'Kaztsik', 1504197: 'Shirokoe', 1517776: '?', 1509524: 'Martynovka', 1929363: '?', 1127115: 'Ves', 1600523: 'Otverzhichi', 19971: 'Popenki', 1515415: 'Nikolaevka', 1143789: 'Tsvetniki', 1511281: 'Yastrebinoe', 1601257: 'Kommunar', 1511722: 'Vyshgorodok', 1035749: 'Voknavolok', 1053415: 'Otradnoe', 6531: 'Al Ḩasakah', 19336: 'Khuchni', 1504433: 'Velikaya Dobron', 1153622: 'Antonovka', 1036717: 'Knyazhpogost', 1091795: 'Poltavskoe', 1160120: 'Krasny Velikan', 1015144: 'Krasny Oktyabr', 3224888: 'Valea Vişeului', 1015311: 'Pronin', 1711747: '?', 1506485: 'Tsibulevoe', 1121664: 'Talon', 1601406: 'Yurkevichi', 1975937: '?', 1151583: 'Yug', 3076: 'Kotkozero', 1505840: 'Kapustintsy', 5326035: 'Les Trois-Îlets', 15072: 'Ekimchan', 1940521: 'Jaunolaine', 4605502: 'Karlshamn', 1702063: 'Taldykol', 1701987: '?', 1975277: '?', 5074452: 'Morrisville', 1504280: 'Velikie Luchki', 1041490: 'Kislyakovka', 1929317: '?', 1947957: '?', 4541979: 'Porto Potenza Picena', 1701083: 'Berezovka', 1502045: 'Galina Volya', 1502069: 'Staraya Guta', 1095737: 'Bolshie Klyuchi', 1078849: 'Ryasnoe', 1114255: 'Yangorchino', 1055656: 'Parfentyevo', 1509729: 'Novaya Galeschina', 1976063: '?', 1026435: 'Akhkent', 13061: '?', 1700885: 'Pogranichnik', 1966625: '?', 1091412: 'Kalinovskoe', 1156147: 'Dvinskaya', 1506400: 'Moldovka', 1512666: 'Velikaya Babka', 1600848: 'Susha', 4243887: 'Saillon', 1159371: 'Konstantinovka', 1501973: 'Velimchye', 1502603: 'Vakulovo / Zhovtnevoe', 1918259: '?', 1946623: 'Atascadero', 21416: 'Lincolnshire', 1966686: '?', 1517856: 'Kyzyltepa', 1074885: 'Klin', 1714123: '?', 1506031: 'Karapishi', 1000140: 'Timiryazeva', 1963682: '?', 1509296: 'Novoselskoe', 1932076: '?', 1970287: '?', 1059841: 'Chekhov-6', 1972685: '?', 1100298: 'Paskino', 1976104: '?', 1515226: 'Ushnya', 1009627: 'Nikitskoe', 1109458: 'Shalavenki', 1157055: 'Kyzyl-Dag', 1600611: 'Slobodka', 1056093: 'Krasnaya Poyma', 1976129: '?', 1702947: 'Atameken', 1036478: 'Ostrov', 1968026: '?', 1035855: 'Bor', 1091459: 'Aygursky', 5465469: 'West Kelowna', 5266886: 'Leutkirch im Allgäu', 1712160: '?', 22180: 'Eutin', 1702602: 'Kuspek', 1518264: 'Bnei Aish', 1502215: 'Partizanskoe', 1094417: 'Staraya Kiremet', 1156951: 'Turuntaevo', 1955658: '?', 1154996: 'Pionersky', 1014235: 'Peskovatka', 1124830: 'Khandagay', 1507256: 'Pavlograd', 1008453: 'Kaltyaevo', 1926322: '?', 1500283: 'Novonikolaevka', 1922556: '?', 1005431: 'Sosnovy Bor (derevnya)', 1504780: 'Komishuvakha', 1099535: 'Krasny Kholm', 1006447: 'Angasyak', 1975151: '?', 5061597: 'Putnam Valley', 1948980: '?', 5055688: 'Phillipsburg', 1510953: 'Popovka', 1976176: 'Hévíz', 1154341: 'Evalak', 1963018: '?', 1136325: 'Krasnaya Polyana', 16517: 'Yangiaryk', 1037336: 'Nizhny Domanik', 8270: 'Kongsvinger', -5332789: -5332789, 1034083: 'Moshonki', 1939443: 'Veneto', 1140037: 'Vozdvizhenskoe', 1976189: '?', 1029508: 'Kaminsky', 1964794: '?', 1105936: 'Sukhodolsky', 1923001: '?', 1127645: 'Kharanzhino', 1511226: 'Mefedovka', 1067348: 'Lgov', 1923186: 'Khulna', 1122676: 'Pavlovsky', 1016166: 'Vizma', 4957555: 'Rising Sun', 1507170: 'Kalinovo', 1505743: 'Mokrets', 1971492: 'Bergkamen', 1928835: '?', 4711: 'Ust-Kara', 1513813: 'Cherny Ostrov', 1503157: 'Bylbasovka', 20509: 'Iki-Bukhus', 1921910: 'Kosovska Mitrovica', 1714742: 'Mason', 1947338: '?', 1516525: '?', 1013647: 'Kholmechi', 1103537: 'Selische', 1044717: 'Krasavchik', 2202702: '?', 1916712: '?', 1115014: 'Musirmy', 1974374: '?', 7247: 'Muromtsevo', 1135213: 'Mikhaylovka', 18711: 'East Fayetteville', 5005371: 'Mission', 1152659: 'Piter (derevnya)', 1975512: '?', 1965499: '?', 1976306: 'El Calafate', 1918498: 'Peekskill', 1909391: 'Mount Kisco', 1911652: 'Katonah', 1007223: 'Tegermenevo', 1155935: 'Ozerki', 1148192: 'Kurskaya', 1048051: 'Pochinok', 1038552: 'Shunga', 1074261: 'Krupp', 1954306: '?', 1908335: 'Červená Voda', 1926001: 'Bagat', 1123106: 'Srednesibirsky', 1513777: 'Davydkovtsy', 1706368: 'Fort Walton Beach', 1112654: 'Grigoryevka', 1961977: 'Rochdale', 1711136: '?', 1519256: '?', 1709227: 'Ankeny', 1054600: 'Ramenki', 1976375: '?', 1506750: 'Balakhovka', 1976376: '?', 1512310: 'Zidki', 1503446: 'Ryzhany', 1517980: '?', 1709128: 'Ruzhnitsa', 3964769: 'Daqing', 1922006: '?', 5212878: 'Siecq', 1124397: 'Verkhnyaya Ivolga', 1158820: 'Tselinny', 12095: 'Chappanda', 1973421: '?', 1128649: 'Novotroitsk', 1056712: '?', 1093142: 'Kim', 1712535: '?', 1138635: 'Bolshoe Tumanovo', 1934035: '?', 1505797: 'Ustimovka', 1137328: 'Klyuchevskoe', 1906367: '?', 1045360: 'Kondratovo', 1921453: '?', 1035626: 'Rabocheostrovsk', 1511876: 'Staraya Brikulya', 3146280: 'Manavgat', 3682: 'Nikolina Balka', 1931068: '?', 1122762: 'Klepechikha', 1094903: 'Nizhnie Aty', 4466274: 'Tlmače', 1518394: '?', 1706637: 'Bray', 1153676: 'Yunkyur', 1086786: 'Kurgan (derevnya)', 1074054: 'Cherskaya', 1141382: 'Melyaevo', 1519204: 'Lakeville', 1501241: 'Kivachovka', 1909584: '?', 1122098: 'Martynovo', 1976452: '?', 1100218: 'T/b Dorozhnik', 1900976: 'Hashmonaim', 1800792: 'Mereny ', 4695533: 'Long Ground', 1144151: 'Kurinsky', 1959237: '?', 1900780: 'Tzora', 1944303: '?', 1709228: '?', 1159110: 'Sidima', 1600177: 'Khmelevo', 1053330: 'Kazhlodka', 1000103: 'Grozny (khutor)', 1946644: '?', 1966681: '?', 1025904: 'Argvani', 1151075: 'Shlyapniki', 1509570: 'Pirogi', 1969176: '?', 1513023: 'Osokorovka', 1971993: 'Alba Adriatica', 1069199: 'Klinkovo', 1026885: 'Gimry', 5307564: 'Bor-Öndör', 5327020: 'Sarigerme', 4373842: 'Göhren-Lebbin', 1701469: 'Usharal', 1500840: 'Yastrebintsy', 1024762: 'Novomoskovsky', 1507761: 'Kievets', 1079858: 'Blagodarny', 1131660: 'Osa', 1079241: 'Sinyavskoe', 1970770: '?', 1706840: 'Tisdale', 1707091: '?', 4922631: 'Ellenton', 1971843: '?', 1701087: 'Bystrukha', 1155644: 'Mariinsk', 1042729: 'Pervoavgustovsky', 1938646: '?', 1051218: 'Shoyadur', 1976542: '?', 1119768: 'Borok', 1157656: 'Uspenka', 1923324: '?', 1052394: 'Novoyamskaya Sloboda', 1500181: 'Privetnoe', 5267694: 'Bad Neustadt an der Saale', 1139994: 'Semyany', 1503643: 'Zherevtsy', 18979: '?', 1002185: 'Konets Ozerya', 1965426: '?', 1501195: 'Andrushevka', 1147146: 'Mogutovo', 2200016: 'Aragats (talinsky Rayon)', 1974915: '?', 1138482: 'Maldyak', 1510646: 'Basharovka', 1961514: 'Brive-la-Gaillarde', 1935612: '?', 1918116: 'Dusheti', 1513072: 'Ulyanovka', 4318836: 'Winsen (Luhe)', 6480: 'Stafford', 1510851: 'Snezhki', 1064434: 'Arkhangelsky', 1004560: 'Solodniki', 1094617: 'Nizhnee Alkeevo', 1506164: 'Tarasovka / Leninskoe', 1972868: '?', 1135778: 'Mokrushinskoe', 1702546: 'Konstantinovka', 1086942: 'Tumanovo', 1042064: 'Lovlinskaya', 1510543: 'Velikaya Lyubasha', 1132633: 'Zengino', 4529241: 'Verdalsøra', 1110276: 'Valamaz', 1923923: 'Bashsaka', 1056955: 'Esino', 1960189: '?', 1011226: 'Bryansk-Severny', 1121376: 'Spas-Vitaly', 1971514: 'Mendig', 1707381: '?', 1506137: 'Zaprudye', 1711728: '?', 5361533: 'Forte da Casa', 1943106: '?', 1603183: 'Bel', 1502986: 'Krasnoe', 1508457: 'Novokonstantinovka', 1035587: 'Shuezero', 1974736: '?', 1023494: 'Vaskovo', 1505324: 'Tyudov', 1921417: '?', 1146193: 'Olgino', 1967454: '?', 1929347: '?', 1601476: 'Ozarichi', 4345130: 'Oberhausen', 1925549: '?', 1908169: 'Zarkent (yangikurgansky Rayon)', 5261797: 'Senden', 1906197: '?', 1072535: 'Maevo', 1516962: '?', 1924844: '?', 1505529: 'Ugrinov', 1973596: '?', 1512178: 'Olkhovatka', 1157059: 'Shuy', 1153262: 'Novodevitsa', 1509833: 'Voynikha', 1513406: 'Sakhnovtsy', 4625191: 'Natal', 1703274: 'Avon', 1159816: 'Bolshetarkhovo', 1969907: 'Cieszyn', 1955294: '?', 1137355: 'Peschanokoledino', 1918805: 'Port Louis', 1032027: 'Yusta', 1095020: 'Alexandrovka', 1156738: 'Gorodok', 1938807: 'Skagway', 1014443: 'Baranovka', 1037829: 'Danilov', 1500103: 'Dmitrovka', 1123309: 'Krasnoyarka', 1502558: 'Shakhtarskoe', 1028749: 'Guskino', 1941810: '?', 1033142: 'Voloe', 1129103: 'Novorossiyka', 4832122: 'Maipú', 1938357: '?', 1976835: '?', 10306: 'Novoselenginsk', 1502776: 'Alexeevka', 15985: 'Podsinee', 1156327: 'Chusovoe', 1508688: 'Novodmitrovka', 1093474: 'Pervomaysky', 1701251: 'Tugyl', 1053866: 'Khorlovo', 1946194: '?', 1704656: 'Braunau', 1503372: 'Grishkovtsy', 1516008: 'Kenosha', 1086207: 'Lipovka', 1705552: 'Gatsuk', 1932921: '?', 1973212: '?', 1118108: 'Shestikhino', 1117813: 'Volga', 1088912: 'Lipetsy', 20377: 'Sotnikovo', 1975892: '?', 1157082: 'Chyraa-Bazhy', 1975393: '?', 1510783: 'Remchitsy', 1512194: 'Bely Kolodez', 1514113: 'Timoshovka', 1501576: 'Khobultova', 1705211: 'Sun Valley', 1910364: '?', 1509511: 'Velikie Budischa', 1111666: 'Alexandrovka', 1518955: 'Komarin', 1113520: 'Bishkil', 1096927: 'Bolshie Kibyachi', 1142668: 'Berezniki', 1950823: '?', 1123838: 'Petropavlovka', 1966132: '?', 4230899: 'Southbourne', 5422150: 'Bungo-ōno', 4243054: 'Aberfeldy', 4223354: 'Oksbøl', 1802036: 'Kandava', 1511284: 'Belka', 1912734: '?', 1949824: '?', 1503118: 'Shirokino', 4717141: 'Ciudad Choluteca', 1134106: 'Donaurovo', 1138035: 'Belozerka', 1907800: '?', 1502569: 'Svyatovasilevka / Elizarovo', 1053770: 'Shestakovo', 1975632: '?', 1111452: 'Pervomaysk', 1704395: 'Chok-Maydan', 1976936: '?', 1963395: '?', 1914747: 'Shawnee', 5239754: 'Le Bugue', 1126641: 'Kostenets', 2201103: '?', 1160755: 'Svetly', 1147336: 'Zelenodolsk', 1908640: '?', 1145158: 'Gauf', 1006823: 'Okhlebinino', 1007264: 'Bishaul-Ungarovo', 2001231: 'Pasvalys', 1151600: 'Berezniki', 1800597: 'Kopanka', 1052546: 'Novley', 1091532: 'Terek', 1113858: 'Goyty', 1036564: 'Ruskeala', 1121580: 'Kuzya', 1512230: 'Yurchenkovo', 1803618: 'Itta Bena', 1123961: 'Sychevka', 1503555: 'Luka', 1503871: 'Zubkovichi', 20381: 'Kirova', 1949686: 'Szentendre', 1091974: 'Vysotskoe', 2001672: '?', 1091470: 'Raguli', 1975562: '?', 21172: 'Cedar Rapids', 1976454: '?', 1114141: 'Suguty', 1154051: 'Krasnaya Tym', 1121857: 'Oktyabrsky', 1974691: '?', 1926021: 'Špindlerův Mlýn', 4469425: 'Žehrov', 2208641: '?', 1083440: 'Syreyka', 1127912: 'Granovschina', 5266692: 'Künzelsau', 1956192: '?', 1081565: 'Pionersky', 1507619: 'Gorodzhov', 2001251: '?', 1508948: 'Staraya Tsarichanka', 1142051: 'Zimenki (zimenkovskaya S/a)', 1024640: 'Khrenovoe', 1967774: '?', 1008679: 'Mudaris', 3482508: 'Negombo', 1926715: '?', 1704639: 'Ulugbek (zangiatinsky Rayon)', 1157376: 'Glubokoe', 1031379: 'Sechenovo', 1155194: 'Vorontsovka', 1158538: 'Varvara', 1904777: 'Pulheim', 1508973: 'Marinovka', 1509567: 'Oboznovka', 1504627: 'Poltavka', 1009177: '?', 15503: 'Vinogradovo', 1500141: 'Pushkino', 1114239: 'Tyumbeki', 1154137: 'Neyvo-Shaytansky', 1515186: 'Vibli', 1924693: '?', 1091921: 'Voskresenskaya', 1936004: 'Altynsay', 12172: 'Verderevschino', 1601006: 'Kamai', 1036839: 'Izyayu', 3271903: 'Edirne', 1092359: 'Seredinovka', 1092306: 'Vyazovoe', 1511116: 'Oleshnya', 16764: 'Arkhangelskoe', 1932909: 'Néa Mákri', 1504263: 'Repinnoe', 1922328: '?', 1053342: 'Maltsevo', 1053320: 'Varzhelyay', 20345: 'Voznesenskoe', 1159974: 'Sibirsky', 1938073: '?', 1975305: '?', 1600588: 'Akhremovtsy', 1509801: 'Virishalnoe', 1057293: 'B/o Zvenigorod', 1109533: 'Oktyabrsky', 1976662: '?', 1904269: 'Gudauri', 5024302: 'Blue Grass', 1008085: 'Shatmantamak', 1041650: 'Perevalka', 2001370: '?', 5479343: 'Parma', 2001376: '?', 2001379: '?', 1147339: 'Kirovsk (poselok)', 1952994: '?', 1946151: '?', 1511022: 'Vasilyevka', 2203247: '?', 1972401: '?', 1963005: '?', 5264248: 'Michelbach an der Bilz', 1092294: 'Chupovka', 1504091: 'Olshanka', 1974782: '?', 1067970: 'Kevdo-Melsitovo', 1970791: '?', 2001498: '?', 1976219: '?', 1504703: 'Vozrozhdenya', 1970817: '?', 4117080: 'Sokodé', 2056: '?', 1068183: 'Chibirley', 1131220: 'Sosheni', 1966164: '?', 1505195: 'Kropivnik', 1050433: 'Vilovatovo', 1041867: 'Novopokrovsky', 12423: 'Ryaymyalya', 1094913: 'Novy Kishit', 1014588: 'Kotelnikov', 1933513: '?', 4695531: 'Lower South Hill', 1803520: 'Batalha', 5093339: 'North Highlands', 1072333: 'Stupino', 1123272: 'Uglovskoe', 2500022: 'Baldzhuvan', 1966335: '?', 1507114: 'Kamenka', 11147: 'Esens', 1127865: '27 Km Goloustenskogo Trakta', 9541: 'Dombóvár', 1045694: 'Repolka', 1140141: 'Blizhne-Pesochnoe', 1939199: '?', 4456274: 'Zalaegerszeg', 1035417: 'Kosta Khetagurova', 1601032: 'Dvorische', 1971905: '?', 1042114: 'Svetly Put', 1501959: 'Staroselye', 1052802: 'Novotroitsk', 4618101: 'New Amsterdam', 2001497: '?', 5261722: 'Essen (Oldenburg)', 1161115: 'Kharyaginsky', 1152916: 'Pavlovka', 1962932: '?', 1974645: '?', 4696294: 'Saint Philips', 2722653: 'Cartagena de Indias', 1962333: '?', 1144628: 'Bobrovka', 1974319: '?', 1701072: 'Zenkovka', 1160146: 'Kalga', 1973933: '?', 1965495: '?', 1137479: 'Shadrinsky', 1701290: 'Karabulak', 1074160: 'Grabilovo', 1113437: 'Mikhaylovka', 1932418: '?', 1964020: '?', 4184584: 'Sant Josep de sa Talaia', 1119423: 'Vasilkovo', 1702486: 'Frumentyevka', 1151364: 'Vanyuki', 1015684: 'Morskoe', 1129901: '?', 1058645: 'Marino', 1906870: '?', 14866: 'Tyubuk', 1160361: 'Bolshoy Zerentuy', 1023849: 'Naschekino', 1157518: 'Tomskaya', 5428144: 'Dolinka', 1036325: 'Gonganalitsa', 1934504: '?', 1703016: 'Karabulak', 1114487: 'Asanovo', 1508293: 'Vizhomlya', 1145786: 'Mys', 1041425: 'Ekonomicheskoe', 1157176: 'O-Shynaa', 1969793: '?', 1160431: 'Nizhny Tsasuchey', 1940358: '?', 1004285: 'Krasa', 1043799: 'Paniki', 1953781: '?', 1507451: 'Toporov', 1000028: 'Progress', 5266934: 'Osterhofen', 1024720: 'Tsentral', 1000332: 'Zlodeevo', 1965547: '?', 1082955: 'Samovolno-Ivanovka', 1965151: '?', 5214562: 'Morteau', 1962078: '?', 1017271: 'Smetanino', 21496: 'Berkley', 1097188: 'Uryum', 1114153: 'Shygyrdan', 1129196: 'Svyatoslavka', 1097425: 'Kargali', 1504972: 'Chernozemnoe', 1504704: 'Vysokoe', 1096689: 'Mamykovo', 12089: 'Mescherskoe', 1060291: 'Solntsevo', 1975999: '?', 5266760: 'Sinsheim', 1956038: '?', 1112717: 'Tyulyuk', 1512658: 'Utkovka', 1503240: 'Telmanovo 1', 1973390: '?', 1502947: 'Sofievka / Artemovka', 1510212: 'Yareski 1', 2001657: '?', 1702545: 'Timiryazevo', 1084684: 'Tsarevschina', 1513063: 'Novonikolaevka', 1917084: '?', 1122110: 'Glubokoe', 1083834: 'Starogankino', 1129647: 'Kalachevo', 1602128: 'Budenovka', 1975058: '?', 1056350: 'Mokroe', 1124272: 'Dede-Ichetuy', 1136571: 'Omsky (poselok)', 1510149: 'Voronki', 1128564: 'Solyanaya', 14531: 'Shklo', 1702451: 'Priirtyshskoe', 1132285: 'Lipovoe', 1121150: 'Kuznechikha', 2608198: 'Slampe', 1106357: 'Berezovo', 1081743: 'Korablino', 803: 'Verkhnestepnoy', 1704548: 'Markovo', 4669590: 'Bayahibe', 1968039: '?', 4977287: 'Brighton Beach', 2207602: '?', 1713313: '?', 5266358: 'Hattingen', 1123626: 'Vinogradovka', 1903049: 'Agara', 1507558: 'Gnezdichov', 1144008: 'Pikhtovka', 1046119: 'Kolbino', 1138336: 'Medvedskoe', 1504302: 'Lokhovo', 4611516: 'Lobito', 2210265: '?', 1034967: 'Aristovo', 1920623: 'West Valley City', 1514045: 'Tarasovka', 1132087: 'Fabrichny', 1508097: 'Potoritsa', 5267838: 'Borken (Hessen)', 1944492: '?', 1040910: 'Lebyazhy Ostrov', 1140657: 'Fedurino (fedurinsky S/s)', 2201673: '?', 1049302: 'Bolkhovskoe', 1004550: 'Vyazovka', 1511306: 'Vovna', 1510881: 'Tarasovka', 1155350: 'Krasnoarmeets', 5412570: 'Créteil', 1083839: 'Sukaevka', 1502317: 'Topchinoe', 1803193: 'Mäetaguse', 1504890: 'Listvyanka', 1086194: 'Zavetnoe', 1801821: 'Hays', 4241526: 'Bolton', 16614: '?', 1511274: 'Sula', 1710744: 'Laval', 1055204: 'Zendikovo', 18185: 'Izvara', 1134990: 'Berezovsky', 1148477: 'Tyulgan', 1003311: 'Kvazenga', 1967743: '?', 20658: 'Kusino', 1515237: 'Galitsa', 5260364: 'Timmendorfer Strand', 5107795: 'Crosby', 1603289: 'Svisloch', 6315: 'Ludvika', 1975157: '?', 1512909: 'Tavriyskoe', 1960745: '?', 1510142: 'Shtompelevka', 1961993: '?', 6998: 'Oundle', 1912839: 'Ardingly', 1112085: 'Semenovka', 1949718: 'Hacienda Heights', 1715458: 'Shamlug', 1710173: 'Roy', 1708065: 'Khodzhaabad', 1007284: 'Kabakovo', 1600698: 'Malye Lettsy', 1945513: 'Friedrichsdorf', 1956705: '?', 1006336: 'Komsomolsky', 1092238: 'Bulgakovo', 1096643: 'Tatarskoe Utyashkino', 1976612: '?', 1708138: 'Launceston', 1078833: 'Novoandrianovka', 1968556: '?', 1942422: '?', 1006670: 'Seregulovo', 1060051: 'Belaya Kolp', 3099168: 'Gisenyi', 1947004: 'Assagao', 1709698: 'Tarnów', 1006781: 'Zagorsk', 1507069: 'Morozovka', 20751: 'Dover', 2845: 'Portsmouth', 1504783: 'Malaya Tokmachka', 1514156: 'Novoselitsa', 5097009: 'Silverthorne', 2001274: '?', 1059008: 'Serpukhov-13', 1503532: 'Buki', 1948126: '?', 1016889: 'Novator', 1928443: '?', 1945860: '?', 1140154: 'Druzhba', 1102206: 'Kholmets', 1915619: '?', 1063195: 'Ustyutskoe', 1144563: 'Kirza', 5217027: 'Talence', 1962048: '?', 1712738: '?', 1802138: 'Bad Bramstedt', 13962: '?', 4388138: 'Birkenfeld', 1155107: 'Cheremkhovo', 1158010: 'Tomskaya', 1501786: 'Gubin', 3136059: 'Khan Yunis', 5086263: 'Sun Prairie', 1969011: '?', 1501511: 'Sloboda-Shargorodskaya', 1078639: 'Gorny', 1112956: 'Chebakul', 3363393: 'Toamasina', 1920078: '?', 5264567: 'Mühlhausen-Ehingen', 1935580: '?', 1123430: 'Seleznevo', 1700680: 'Balgabek Kydyrbekuly', 1112178: 'Mirny', 1931244: '?', 1011459: 'Mirny', 1976789: '?', 1015535: 'Dyakonovsky', 1503570: 'Troyanov', 1949793: 'Potchefstroom', 1153635: 'Syulya', 1124394: 'Shara-Azarga', 3960132: 'Bulgan', 1517651: 'Manglisi', 1035608: 'Bab-Guba', 1054228: 'Ust-Pristan', 1508193: 'Verchani', 1157781: 'Zaozerny', 20256: 'Khoronkhoy', 1503787: 'Lebedovka', 1919272: '?', 1975743: '?', 1713754: '?', 1085215: 'Kharevka', 1026696: 'Arak', 2500291: 'Syrdarinsky', 1508236: 'Ugersko', 1101038: 'Bobrische', 1109351: 'Ivanovo-Voznesensk', 1960233: '?', 3135541: 'El Masrab', 1076875: 'Ritupe', 1702288: 'Ayteke Bi', 1955961: '?', 1904622: 'Völklingen', 1974922: '?', 4189107: 'Calp', 3159947: '?', 1084142: 'Staroe Adelyakovo', 2202918: '?', 3803587: 'Hebi', 1147269: 'Aschebutak', 2001865: '?', 1602765: 'Tanezhitsy', 1964316: 'Larissa', 1160283: 'Davenda', 1030691: 'Novoselovo', 1502493: 'Prosyanaya', 1078301: 'Gluboky', 1952281: '?', 1014297: 'Aleshniki', 1700260: 'Sandyktau', 1956125: 'Břeclav', 1970137: '?', 3505366: 'Kanpur', 1702043: 'Zabelovka', 1513929: 'Yasenovka', 1146169: 'Volnoe', 1971240: 'Mangit (amudarinsky Rayon)', 1905324: '?', 2102538: '?', 1015367: 'Kuybyshev', 10829: 'Koshurnikovo', 1153131: 'Chkalovskoe', 1502790: 'Konstantinopol', 7166: '?', 1974129: '?', 1053509: 'Rusavkino-Romanovo', 1050978: 'Elymbaevo', 1047625: 'Zhog', 1091913: 'Ozek-Suat', 1159784: 'Shugur', 1111495: 'Zagoskino', 15889: 'Varegovo (varegovsky S/s)', 4356434: 'Langenhagen', 1938213: 'Burgdorf (Region Hannover)', 4038497: 'Sobral de Monte Agraço', 4218684: 'Adel Bagrou', 1502808: 'Shevchenko', 1501846: 'Romanov', 1702804: 'Ilichevka', 1506542: 'Sofievka', 1041823: 'Veselaya', 1963766: '?', 1058703: 'Repikhovo', 1914717: 'Angoulême', 1500901: 'Makharintsy', 1936315: 'Tuusula', 1919042: '?', 1975285: '?', 1967637: '?', 1146880: 'Maysky', 1974243: '?', 1000709: 'Monchevskaya', 1976791: '?', 1122546: 'Samarka', 1948722: '?', 1800365: 'Dzhyamena', 1964013: '?', 1119512: 'Kolenovo', 1129686: 'Sevsk', 1052752: '?', 1518118: 'Badulla', 1123815: 'Taskino', 1109761: 'Pervomaysky', 1601098: 'Slavnoe', 1031335: 'Lvovskoe', 1500074: 'Zemlyanichnoe', 15675: '?', 1150840: 'Maysky', -5331: -5331, 1024148: 'Pravaya Khava', 4977492: '?', 1023950: 'Yasenki', 4741141: 'Esmeraldas', 3994761: 'Chōnan', 3296541: 'Chełm', 1042204: 'Otradnaya', 1041175: 'Krasnogvardeets', 1509266: 'Shabelniki', 1501064: 'Kotyuzhany', 5237070: 'Vienne', 1064803: 'Arkhangelskoe', 1019216: 'Rozhdestvo', 1145037: 'Shurygino', 1006361: 'Rublevka', 4056417: 'Daloa', 1075037: 'Pestovo', 1086183: 'Anisovsky', 1089483: 'Orlovka', 4190001: 'Adra', 1500147: 'Stalnoe', 1500306: 'Izobilnoe', 15987: 'Akureyri', 2204553: 'Kerpen', 1126688: 'Tuchkovo', 1976516: '?', 1702461: 'Lugovoe', 8138: 'Vershina Tei', 1501729: 'Olyka', 1702904: 'Kyzylkia', 1937335: '?', 1015411: 'Verkhnyaya Vodyanka', 1705871: '?', 1970546: 'Pakhtaabad', 1513911: 'Mikhaylovka', 1955381: '?', 1953747: '?', 1938027: '?', 1514805: 'Kobolchin', 3172607: 'Bahir Dar', 1085264: 'Pavlovka', 1050682: 'Krasny Yar', 5394: 'Tornio', 1962496: '?', 1041324: 'Novosergievskaya', 1702152: 'Kaskat', 1154035: 'Urozhaynoe', 1734: 'Urozhaynoe', 16085: 'Yakhrenga', 1132356: 'Markovo', 1968543: '?', 1501360: 'Gannopol', 1508957: 'Avgustovka', 4228317: 'Worksop', 1511608: 'Kabarovtsy', 4534836: 'Hamar', 1901363: 'Seesen', 1511164: 'Bobrik', 1500694: 'Zhabelovka', 1036054: 'Chelmuzhi', 1946739: 'Golkowice', 1924673: '?', 21002: 'Talshyk', 1010392: 'Repyakhovka', 1135978: 'Balakhton', 1042276: 'Psebe', 1128976: 'Moty', 1910732: '?', 5471017: 'Belogorsk', 1975736: '?', 1136052: 'Uyar', 1056706: 'Klin (derevnya)', 1502759: 'Luganskoe', 1601900: 'Ratichi', 17922: 'Georgievka', 1908324: 'Branchburg Park', 1700773: 'Kalpe', 18811: 'Podluzhnoe', 4923978: 'New York', 1112005: 'Soldatskaya Tashla', 1131356: 'Markovtsy', 1007618: 'Ibragimovo', 5468397: 'Malinovka', 1514726: 'Stavchany', 1510906: 'Semenovka', 1008974: 'Podolsk', 4512: 'Sikiaz', 1096823: 'Shali', 1123023: 'Novotroitsk', 5124572: 'Drumheller', 2201267: '?', 1050392: 'Chodrayal', 1500287: 'Priozernoe', 1963687: '?', 1035325: 'Rylyaki', 1600683: 'Staroe Selo', 5268103: 'Capo Vaticano', 1952275: '?', 1518117: 'Kaztalovka', 1147376: 'Ivanovka', 1514434: 'Pervomaysk', 1903591: '?', 1071747: 'Lekhovo', 2102372: 'Gurlan', 1903528: 'Jelenia Góra', 1047235: 'Mekhbaza', 1709856: 'Cetinje', 1145425: 'Kovalevo', 1132185: 'Stary Burets', 1976836: 'Ånge', 1936359: 'Oujda', 1084833: 'Bogorodskoe', 1600373: 'Tsna', 1032663: 'Pyrenka', 20235: 'Zenzeli', 1108910: 'Shakhta 21', 5259535: 'Königsbrück', 1154183: 'Kalach', 1915756: '?', 1943886: '?', 1156684: 'Tungusovo', 1706525: '?', 4565130: 'Čakovec', 1014825: 'Kruglovka', 1968170: '?', 1085814: 'Urusovo', 1915801: '?', 1926039: '?', 3133387: 'Sidon', 2201387: '?', 1030437: 'Zayukovo', 1112994: 'Tayginka', 1086517: 'Zhigalovo', 1153845: 'Viakhtu', 1159849: 'Kamennoe', 1963399: '?', 1800475: 'Izvoare', 1094735: 'Novotroitskoe', 1965339: '?', 1007568: 'Simbirsky', 1961735: '?', 20068: 'Dedinovo', 1150966: 'Ishimovo', 1159556: 'Sovetskaya Khakasia', 1013478: 'Elionka', 4650552: 'Guarulhos', 2200609: 'Lernapat', 1026218: 'Novokayakent', 1111659: 'Topornino', 1500179: 'Partizany', 1602578: 'Ozertso', 2722457: 'Kayseri', 1050751: 'Pemba', 21261: 'Gusyatin', 1919227: 'Redding', 1043107: 'Orlov', 1517606: 'Ditva', 1035615: 'Krivoy Porog', 1803606: 'Inver Grove Heights', 2201471: '?', 1703900: 'Lomé', 2100422: 'Zarbdor (zarbdarsky Rayon)', 1900615: 'Yakum', 1111860: 'Stary Atlash', 2201484: '?', 1972242: '?', 1092090: 'Solomenskoe', 1005116: 'Ishmurzino', 1112040: 'Vyshki', 1600229: 'Krai', 1952243: '?', 1954079: '?', 1047986: 'Yaroslavichi', 999999999: '?', 1704109: 'Zalău', 2001250: '?', 1026503: 'Gaptsakh', 1963290: '?', 1153368: 'Aby', 1504641: 'Veselyanka', 1511841: 'Darakhov', 1067841: 'Dolgovo', 1157503: 'Rashi', 1508281: 'Yavora', 1964692: '?', 22543: 'Hamden', 1908516: 'Newington', 1956167: '?', 17011: 'Zolotilovo', 1020564: 'Schelkovo (derevnya)', 1050137: 'Poddubrovka', 1067832: 'Vyazemka', 4495200: 'Nowy Targ', 1952421: 'Reading', 1715069: '?', 1513129: 'Khrestovka', 1054117: 'Ozeretskoe', 1114405: 'Shakulovo', 3838384: '?', 1918589: '?', 1113289: 'Mirny', 1098297: 'Bukhalovo', 1025527: 'Lipyagi', 1968133: '?', 3256487: 'Peshtera', 1046231: 'Chernaya Rechka (morozova)', 1084760: 'Voskresenskoe', 1001666: 'Novikovo', 1148131: 'Spasskoe', 1925442: 'Mount Laurel', 1967377: '?', 1702308: 'Aktobe', 1067644: 'Sharovo', 1517498: 'Ivanovka', 2101995: 'Parkent', 1927281: '?', 1509903: 'Kibintsy', 1602250: 'Rozhanka', 1501579: 'Berestechko', 1138707: 'Selema', 1963131: 'Odolena Voda', 1036585: 'Lakhkolambi', 1517028: 'Canyonville', 1502812: 'Blagodatnoe', 1039144: 'Tatarskoe', 1505350: 'Molodkov', 1511154: 'Yuryevo', 1962999: '?', 1902652: 'Lonato', 1112552: 'Novobaturino', 1940576: '?', 1157581: 'Poddubrovnoe', 1504508: 'Berdyanskoe', 1080357: 'Zakharovo', 1929007: '?', 1601397: 'Zapesochye', 5008331: 'XX Farms Colonia', 1922253: '?', 19105: 'Lokeren', 1135779: 'Momotovo', 1956664: '?', 1123901: 'Dalnevostochnoe', 1936627: 'Kruševac', 1701798: 'Orositelnoe', 1941855: '?', 1127611: 'Kaltuk', 1024532: 'Fedorovsky', 15181: 'Bentonville', 1034878: 'Zarechye', 1714175: 'Bad Oeynhausen', 1905428: '?', 1156353: 'Karaul', 1043657: 'Krivets', 1082983: 'Natalino', 1913236: '?', 5431913: 'Slobudka', 3539877: 'Mandalay', 5090153: 'Canoga Park', 1515904: 'Williamstown', 1126288: 'Levenda', 1126313: 'Panovo', 1156287: 'Vogulka', 15506: 'Ashap', 1115101: 'Medikasy', 1057029: 'Khrapunovo', 1713251: '?', 1976637: '?', 1139557: 'Altunino', 1154645: 'Poldnevoy', 1911844: '?', 1934394: '?', 1160826: 'Ononskoe', 1950976: 'Uychi', 1969046: '?', 1924797: '?', 1036721: 'Kyltovo', 1154441: 'Russky Potam', 1005379: 'Znamenka', 1509123: 'Shershentsy', 1700037: 'Lozovoe', 1935619: 'Montecatini Terme', 1939601: '?', 11302: 'Divensky', 1136076: 'Zharovsk', 4191471: 'Gerace', 1706784: '?', 1500556: 'Kirovskoe', 1091683: 'Staropavlovskaya', 1600555: 'Fedory', 1083496: 'Cherny Klyuch', 1083493: 'Usakla', 1507141: 'Bayrachki', 4618156: 'Linden', 1007374: 'Arslanovo', 1153121: 'Prokhory', 5264238: 'Mulfingen', 5259480: 'Rochlitz', 1006812: 'Nizhnie Lemezy', 1964672: '?', 1901090: 'Kiryat Ekron', 1132490: 'Kotchikha', 1123978: 'Koboldo', 1068708: 'Ermolovka', 3124515: 'Volos', 4728215: 'La Victoria', 2201373: '?', 1114793: 'Bolshoe Karachkino', 2201797: '?', 1060362: 'Mishukovo', 1137436: 'Maysky', 1916939: '?', 1913959: '?', 1602648: 'Vygolovichi', 1501142: 'Balabanovka', 1511048: 'Berestovka', 1097364: 'Ivashkino', 1948044: '?', 3423053: 'Bagrami', 1038324: 'Lubyany', 1083826: 'Savrukha', 1500281: 'Maryevka', 1505584: 'Voloshinovka', -1925340: -1925340, 1509184: 'Murovanaya', 2201812: '?', 1156564: 'Voronovo', 1516112: '?', 1945129: '?', 1142790: 'Krutoy 1-E', 1111064: 'Yakshur', 3052628: 'Abhā', 1515119: 'Progress', 1125646: 'Ulyakhino', 1153807: 'Arylakh', 1505729: 'Bogdanovka', 1916394: '?', 1062638: 'Syrkovo', 1071116: 'Nazimovo', 1962644: '?', 1159202: 'Malmyzh', 1944584: '?', 5334653: '?', 1070737: 'Stary Ostrov', 1907838: 'Kondūz', 1500022: 'Verkhorechye', 1036751: 'Chernorechinsky', 1133428: 'Urzhum', 1948361: '?', 5266317: 'Enger', 1115076: 'Vurumsyut', 1146507: 'Beloglazovo', 1089997: 'Seltso', 2201877: '?', 1932493: '?', 1702749: 'Proletarskoe', 1041346: 'Anapsky', 4384: 'Moss', 4501118: 'Kalisz', 1946613: 'Kalisz', 1063462: 'Ilemno', 1003175: 'Savinskaya', 1111671: 'Vysoky Kolok', 1005914: 'Novoblagoveschenka', 2201899: '?', 1938254: 'Dostuk', 1509149: 'Novye Belyary', 1112836: 'Petrovsky', 1600788: 'Sittsy', 1934637: '?', 1142723: 'Pakali', 1142727: 'Polyanskoe', 1910212: '?', 1010515: 'Beregovoe 2-E', 1708558: '?', 1511005: 'Spasskoe / Leninskoe', 1512103: 'Lozovaya', 1972742: '?', 1516833: '?', 3138366: "Ra's al Khaymah", 1010420: 'Velikomikhaylovka', 4184438: 'Santiago de la Ribera', 1076419: 'Ivanovo (derevnya)', 1151402: 'Zheleznodorozhny', 1129114: 'Snezhinsky', 2201759: '?', 1005955: 'Udelno-Duvaney', 1152839: 'Molodezhnoe', 1159207: 'Sinda', 22066: 'Arequipa', 4859012: '?', 1143855: 'Stary Iskitim', 1129706: 'S/o Kurortnoe', 1147581: 'Internatsionalny', 2202994: '?', 1711906: 'Carlisle', 4234053: 'Measham', 1932791: 'Tamworth', 1903406: 'Bardufoss', 1115876: 'Podolskoe (markovsky S/s)', 5267130: '?', 1046942: '?', 1512900: 'Novovladimirovka', 1601317: 'Chenki', 1601336: 'Nosovichi', 1970999: '?', 3784849: 'Yantai', 1917810: '?', 1601260: 'Chebotovichi', 1145653: 'Bogolyubovka', 1146547: 'Novy Koshkul', 1956618: '?', 1509598: 'Ovsyuki', 1602971: 'Turki', 21943: 'Avranlo', 1706114: 'Novy Dvor', 1516139: '?', 4874218: 'Torreón', 1519078: '?', 3509: 'Del Rio', 4152889: 'Sarh', 1160856: 'Ugolnye Kopi Aopp', 5058844: 'Goldens Bridge', 1502176: 'Vodyanoe', 1502258: 'Khristoforovka', 1602465: 'Poteyki', 1972225: '?', 1003790: 'Rembuevo', 2202075: 'Ryki', 4924409: 'Ponte Vedra', 1953107: '?', 1713728: 'Pickering', 1920214: 'Thomasville', 1135137: 'Angarsky', 1158922: 'Bolon', 1121533: 'Ust-Narin', 1709605: 'Bakuriani', 1969098: '?', 1707171: 'Neuquén', 1123739: 'Cheremkhovo', 1962024: '?', 1122589: 'Kamyshi', 1958415: 'Filipstad', 1948444: '?', 1711919: 'Walled Lake', 1143612: 'Shubinskoe', 1135378: 'Nikolskoe', 1133598: 'Kazan (selo)', 18291: 'Shturmovoy', 9769: '?', 1127331: 'Nebyloe', 1077795: 'Kamyshevakha', 5094527: 'San Pedro', 1975442: '?', 1504557: 'Malaya Mikhaylovka / Beloretskoe', 1901708: 'Pļaviņas', 1136685: 'Mezhovo', 1715174: 'Ganchi', 3294895: 'Dynów', 4041170: 'Loures', 1094409: 'Ponomarevka', 1053239: 'Pushta', 1970222: '?', 1129887: '?', 1160582: 'Leninsky', 1018330: 'Roslyatino', 1513610: 'Sasanovka', 1068911: 'Vesely', 1057906: 'Zhukovka', 1152770: 'Rozhdestvenka', 5347523: 'Alzenau', 1006680: 'Utyagulovo', 1007688: 'Zyak-Ishmetovo', 1969496: '?', 1506171: 'Pyschiki', 1145727: 'Obnovlenie', 1905493: '?', 1106817: 'Arkhangelskoe', 1502847: 'Khlebodarovka', 1143763: 'Verkh-Uryum', 1970843: '?', 1043364: 'Kukuevka', 1153648: 'Olekminsky', 1936169: '?', 1936402: '?', 1158000: 'Romanovka', 18939: '?', 2722581: 'Cape Coast', 5025801: 'Iowa Center', 1021808: 'Bor', 1903805: '?', 1973311: '?', 1800571: '?', 1507503: 'Voroblevichi', 1925556: '?', 1503637: 'Shakhvorostovka', 1505627: 'Ostroyki', 1945906: '?', 1958466: '?', 1973695: '?', 1041491: 'Kislyakovskaya', 1965100: '?', 4316091: 'Aubel', 4312764: 'Eynatten', 4302407: 'Verviers', 4236021: 'Keele', 1109503: 'Kachkashur', 2722526: 'Belmopan', 1058426: 'Pupki', 1513991: 'Zhitniki', 1711513: 'Feasterville', 1974432: '?', 1921716: '?', 1915184: '?', 1134794: 'Dolgy Most', 1505501: 'Zagvozdye', 1942161: '?', 5425378: 'Yukhary Nuvedi', 1123716: 'Ivanovka', 1501323: 'Yalanets', 1003052: 'Voznesenye', 1509058: 'Bogatoe', 2202328: 'Połczyn-Zdrój', 2001922: '?', 1136730: 'Borsk', 1030768: 'Kurgan', 1920154: '?', 1508045: 'Oryava', 1025677: 'Akusha', 1017756: 'Voskresenskoe (kubenskoe S/p)', 1041556: 'Zassovskaya', 2201535: '?', 1058044: 'Denezhnikovo', 1514429: 'Leski', 1913487: '?', 1159322: 'Kiselevka', 1115289: 'Sobakkasy', 3036163: 'Bocole', 1128224: 'Ignino', 1910191: '?', 1056639: 'Bryokhovo', 1705137: 'Uzmeny', 1058100: 'Kulakovo', 1976002: '?', 1515520: 'Novy Belous', 1712780: 'Gillette', 1079106: 'Vesely', 5471461: 'Kalai-Khumb', 1926906: '?', 1079112: 'Leninavan', 1800506: 'Kamenka', 1506968: 'Grushevoe', 1915152: 'Nykøbing Mors', 1136180: 'Oreshnoe', 1509785: 'Peschanoe', 19307: 'Prešov', 1110249: 'Pushin Mys', 1951534: '?', 20941: 'Fredrikstad', 1963974: 'Glenrothes', 1500639: 'Yaltushkov', 1512029: 'Novaya Gusarovka / Chervonaya Gusarovka', 1008684: 'Nikolaevka', 1512860: 'Rykovo / Partizany', 1503281: 'Krasnogorovka', 15531: 'Tim', 1130722: 'Sredneivkino', 5347921: 'Gießen', 1085044: 'Petrozavadovka', 1057177: 'Nara R/k', 1030791: 'Slavinsk', 1902516: '?', 20898: 'Warwick', 1907473: 'Le Puy-en-Velay', 1701991: 'Moskalevka', 4446181: 'Chasseneuil-sur-Bonnieure', 1511460: 'Sokolov', 1700242: 'Korgalzhyn', 17794: 'Tychy', 1044504: 'Vorobzha', 1602728: 'Motorovo', 1146910: 'Yafarovo', 1504037: 'Vidibor', 1700463: 'Koktau', 1111624: 'Kanadey', 1940801: '?', 1512368: 'Kunye', 1037309: 'Okunevo', 1974173: '?', 1923075: '?', 1514109: 'Raygorod', 1958662: '?', 2200634: 'Privolnoe', 1512635: 'Kutuzovka', 1151786: 'Zaton', 4314689: 'Brasschaat', 1601871: 'Zabolot', 1059196: 'Rzhavki', 1963362: '?', 2202498: '?', 1959921: '?', 1959917: '?', 1519238: 'Ruba', 1502827: 'Dianovka / Kirovskoe', 2202516: '?', 1704469: 'Imenin', 4207487: 'Attard', 1014793: 'Sennoy', 9994: 'Borovka', 2203517: '?', 1513768: 'Bakhmatovtsy', 1908461: '?', 1504949: 'Azovskoe', 2201211: '?', 1097175: 'Proley-Kasha', 1009869: 'Odintsov', 3269680: 'İzmit', 1942667: '?', 1973604: '?', 1160005: 'Alexandrovsky Zavod', 1122821: 'Pokrovka', 1947510: '?', 1516345: '?', 1083593: 'Dergachi', 1505647: 'Cherkas', 1702650: 'Budennoe', 1143628: 'Vitebsk', 1501141: 'Akimovka', 1600712: 'Ozertsy', 1159781: 'Chantyrya', 1158981: 'Datta', 1142175: 'Shaldezh', 1959193: '?', 1800252: 'Vishnyovka', 1041627: 'Andryuki', 1155448: 'Taraskovo', 1010494: 'Solonets-Polyana', 1513034: 'Gornostaevka', 1113553: 'Nepryakhino', 1500843: 'Glinsk', 22129: '?', 1130234: 'Verkhotulye', 1044588: 'Volobuevka', 3795815: 'Nantong', 1054841: 'Glebovo', 1147758: 'Nizhny Gumbet', 1091768: 'Shturm', 1110153: 'Bezmenshur', 1147648: 'Alexandrovka', 1159188: 'Yagodny', 1151878: 'Klyuchi', 1123101: 'Ozerki', 1514992: 'Antonovka', 1700911: 'Daulet', 1150265: 'Samkovo', 1035511: 'Zeyuko', 3295120: 'Dorohusk', 1113682: 'Tazen-Kala', 1079983: 'Mankovo-Kalitvenskoe', 21301: 'Gulf Shores', 1045324: 'Dymi', 1602348: 'Vyazyn', 3455871: 'Naogaon', 1123404: 'Sosnovka', 5266648: 'Göppingen', 4368438: 'Heide', 1506299: 'Nichiporovka', 1707292: 'Figueira da Foz', 1711030: '?', 1702728: 'Bogolyubovo', 1976785: '?', 1056762: 'Mityaevo', 1038416: 'Ivanovo (derevnya)', 1005836: 'Tan', 1079878: 'Kugulta', 1017533: 'Proletarsky', 1012959: 'Romanovka', 1124301: 'Mozhayka', 1129853: 'Temirtau', 1915286: '?', 1943999: '?', 2202254: '?', 1094794: 'Kildurazy', 4825788: 'Salta', 1600767: 'Mezha', 1131838: 'Nagoryana', 2001268: '?', 1078402: 'Zavodskoy', 1156020: 'Uval', 1007257: 'Almalyk', 5266494: 'Rauschenberg', 5129058: 'Saint-Laurent', 5266462: 'Taunusstein', 1099959: 'Nekrasovo', 1709659: 'Alakhadzy', 1037839: 'Zavetluzhye', 1501192: 'Yavorovka', 5266630: 'Hornbach', 4207348: 'Qormi', 1006665: 'Novye Chebenki', 1961348: '?', 15178: 'Devyatiny', 1023626: 'Lyubomirovo', 2101178: 'Ornek', 1514445: 'Chervonaya Sloboda', 2704117: 'Plikiai', 1127976: 'Solnechny', 1127977: '?', 1932405: '?', 1051844: 'Shaba', 4428987: 'Le Bourget', 5302347: 'Éragny', 1516179: 'Nanterre', 1803332: 'Nõo', 1504068: 'Budichany', 1038818: 'Shafranovo', 21906: '?', 1078047: 'Novy', 1601925: 'Dvorets', 1018976: 'Zhernokovo', 2203083: '?', 7684: 'Ancona', 1145660: 'Zarya Svobody', 1504488: 'Lipcha', 1045997: 'Selivanovo', 1518395: 'Drogheda', 1011627: 'Denisovka', 1112229: 'Novoburanovka', 1504034: 'Bezhev', 1700809: 'Balpyk', 1079111: 'Krym', 1933371: '?', 1913493: 'Nome', 1128749: 'Nevon', 1973284: '?', 1078142: 'Sirotsky', 2000732: 'Mamusta', 5266428: 'Friedrichsdorf', 1915466: '?', 1503137: 'Petrovka Vtoraya', 1500380: 'Stereguschee', 1501252: 'Pologi', 2209467: '?', 2209465: '?', 1504147: 'Lubnya', 4242576: 'Ashbury', 10896: 'Los Lunas', 22224: '?', 1963106: 'Adeje', 2203022: '?', 1502448: 'Chaplinka', 1155994: 'Koshuki', 1964795: 'Blackmans Point', 1908437: '?', 1060417: 'Luostari Nizhnee', 1098668: 'Chamerovo', 21322: 'Gloucester', 1053867: 'Tsibino', 1975521: '?', 1503631: 'Staroseltsy', 1707754: '?', 1965896: '?', 1046444: 'Tarasovo', 5331645: '?', 1956835: '?', 1915740: 'North Miami', 1975899: 'Ezernieki', 21156: 'Lindesberg', 1963892: '?', 1966837: '?', 1975658: '?', 1505939: 'Pereselenye', 1601937: 'Khvinevichi', 1956919: '?', 1932660: '?', 1941918: '?', 3256215: 'Veliki Preslav', 1110157: 'Verkhny Bemyzh', 1153996: 'Lermontovka', 1091635: 'Zolotarevka', 1956524: '?', 1701051: 'Semenovka', 1106602: 'Raznotopovka', 1058055: 'Eganovo', 1973998: '?', 1159337: 'Tyr', 1973997: '?', 2202878: '?', 1121498: 'Chelutay', 1700797: 'Shubar', 1108792: 'Makeevka', 1955901: '?', 1907101: 'Greenfield Mills', 1154321: 'Azigulovo', 1153482: 'Tympy', 1004558: 'Razdolny', 1107192: 'Oktyabrsky', 5243655: "Sant'Agata li Battiati", 1052992: 'Kurilovo', 1028516: 'Mytischi (selo)', 1128594: 'Algatuy', 1096385: 'Izhevka', 1135294: '?', 1122202: 'Varshava', 1018732: 'Pavlovskaya', 1512661: 'Tsirkuny', 4044416: 'A dos Cunhados', 1508024: 'Verkhnyachka', 1128357: 'Irgey', 1974483: '?', 1123917: 'Romny', 1123689: 'Ovsyanka', 4971684: 'Garner', 1705470: '?', 2002087: '?', 4176087: 'Ad-Dakhla', 1145146: 'Chuvashkino', 1974620: '?', 1024471: 'Drakino', 1111653: 'Slavkino', 1155261: 'Sarsy-Vtorye', 1509532: 'Rymarovka', 4548174: 'Ceva', 1113472: 'Glazunovka', 1153501: 'Kobyaysky', 1603042: 'Lenino', 1147871: 'Tukay', 1954614: '?', 1096968: 'Staraya Ikshurma', 1509812: 'Peski', 1975927: '?', 5114152: 'Kamas', 4695549: 'Anguilla', 1913608: 'Korsö', 1136310: 'Glyaden (poselok)', 2203176: '?', 2203177: '?', 1138432: 'Schuchye', 1941800: '?', 1914161: 'Calvi', 1002282: 'Ekaterina', 4385608: 'Bruchmühlen', 1505597: 'Podelye', 1032739: 'Murachevka', 1704133: '?', 1511230: 'Rozhkovichi', 1952570: '?', 1153071: 'Guberovo', 1043685: 'Seym', 1701596: 'Krasnoarmeyskoe', 2203187: '?', 1934781: 'Nāmakkal', 1041493: 'Komsomolsky', 1964558: '?', 1127460: 'Pashkovo', 1917765: '?', 6793: '?', 1903584: '?', 1931734: '?', 1024292: 'Novomelovatka', 1004390: 'Krivoy Buzan', 1131160: 'Pesterevo', 1135815: 'Ashkaul', 1093706: 'Podlesnoe', 1041014: 'Otrado-Olginskoe', 1160612: 'Linevo Ozero', 1940201: '?', 8236: 'Sineborsk', 1137108: 'Subbotino', 1059136: 'Lytkino', 2203244: '?', 1970796: '?', 1976595: '?', 1702590: 'Agyntay Batyra (zlatogorka)', 1096695: 'Novaya Amzya', 1068944: 'Obval', 1077474: 'Novoselye', 1602537: 'Koren', 1515987: 'Kwidzyn', 1113523: 'Borovoe', 4083773: 'Onitsha', 1926603: 'Yangikurgan (yangikurgansky Rayon)', 1111278: 'Kargino', 3138575: 'Al Fujayrah', 1160506: 'Verkhnie Kularki', 1972050: '?', 1900092: 'Mevo Modiim', 4242368: 'Bacup', 2203289: '?', 1096041: 'Oluyaz', 1115464: 'Verkhnie Achaki', 6634: 'Trollhättan', 1710275: 'Whitby', 1974256: '?', 1518978: 'Oudehaske', 1970388: '?', 5266259: 'Bornheim', 1122501: 'Novaya Taraba', 1009822: 'Alexeevka', 1700097: 'Nikolskoe', 1041077: 'Shirochanka', 1500732: 'Granov', 1042507: 'Alexeevka', 1076363: 'Volkhvo', 1056943: 'Vishnyakovo', 14888: '?', 2203386: '?', 4467838: 'Komárno', 1115675: 'Babaevo', 4923953: 'Navarre', 1006653: 'Nazarovo', 1930413: 'Brockville', 1507275: 'Sabovka', 1125948: 'Dostizhenie', 2203418: '?', 1122476: 'Krasnoznamenka', 14227: 'Minderla', 1139034: 'Kholyazino', 5268288: 'Hasliberg', 3123902: 'As Salţ', 1709955: '?', 1700993: 'Safonovka', 5064760: 'East Springfield', 1975713: '?', 1151817: 'Polovodovo', 2203097: '?', 1079866: 'Voronovo', 1801331: 'Susleny', 1963643: '?', 5396637: 'Karmøy', 1100507: 'Yuryevo-Devichye', 1600406: 'Gvoznitsa', 1146639: 'Irtysh', 5003476: 'Frisco', 1008255: 'Kundryak', 5423709: 'Durleshty', 3422: 'Zolotukhino', 1904821: 'Agropoli', 1088195: 'Astragan', 1124142: 'Novovoskresenovka', 1953062: 'Rixheim', 1517460: 'Johnson City', 1975019: 'Angra dos Reis', 1146554: 'Osha', 1097752: 'Alexeevskoe', 1155829: 'Altynay', 1506539: 'Poltavka', 1707494: '?', 1090362: 'Sinkovo', 1918006: 'Recanati', 1968241: '?', 1013644: 'Ulitsa', 1952389: 'Weston-super-Mare', 1702073: 'Novotroitskoe', 1510611: 'Uezdtsy', 1501117: 'Mukhovtsy', 1078828: 'Maryevka', 1015380: 'Rakhinka', 1012708: 'Gavan', 2300282: 'Chaek', 1135088: '?', 1503711: 'Lyubovichi', 1134156: 'Rozhdestvenskoe', 1602913: 'Zapolye', 4128592: 'Abba-Bogani', 1602657: 'Svatki', 5421396: 'West Bloomfield', 1122596: 'Polevoe', 19309: 'Singuri', 1511124: 'Chupakhovka', 1085885: 'Bagaevka', 1510554: 'Zlazne', 1506054: 'Vitachov', 2202287: '?', 1974650: '?', 1703746: '?', 11370: 'Sokoch', 1910108: '?', 1707625: '?', 1137097: 'Nizhnyaya Koya', 1090490: 'Dugino', 3808084: '?', 1026235: 'Zubutli-Miatli', 1511396: 'Ivane-Pustoe', 1014660: 'Zhukovsky', 1942845: '?', 4004025: 'Hornsby', 1963544: '?', 22278: '?', 2300151: 'Bosteri', 1907208: '?', 1502894: 'Vladimirovka', 10653: 'Rybakovka', 1513001: 'Stepnoe', 1109426: 'Kelchino', 1109425: 'Kvarsa', 1973437: '?', 1155661: 'Lipovka', 1512671: 'Zarozhnoe', 1138499: 'Transportny', 1122301: 'Tolstovsky', 1602854: 'Rubezhevichi', 1135000: 'Esaulovo', 1078471: 'Skorodumovka', 5402: 'Novochunka (poselok)', 1093135: 'Dmitrievka', 1086336: 'Kosta', 2203380: '?', 1916112: '?', 2203098: '?', 1158034: 'Mayka', 2203155: '?', 1709101: 'Santa Ana', 1957372: 'Bytów', 1940395: '?', 1909530: '?', 1931613: '?', 1712405: '?', 1039681: 'Sokolovskoe', 1129913: 'Novy Berikul', 1156806: 'Kopylovo', 1513542: 'Novokonstantinov', 1149603: 'Pestovo', 1712139: 'Palm Springs', 1932389: '?', 1501399: 'Golodki', 1914861: 'Hällefors', 1906101: '?', 4280937: 'Wateringen', 1800811: 'Mikhaylovka', 1142234: 'Pozharki', 1951868: 'Chomutov', 1024754: 'Maryevka', 1511494: 'Sidorov', 1967308: '?', 1712668: 'Chambarak', 1908287: '?', 1155503: 'Brodovo', 5266931: 'Penzberg', 2203985: 'Gubadag', 1938015: '?', 1156887: 'Mirny', 1947575: '?', 1056648: 'Veselevo', 2202172: '?', 1972523: '?', 1097288: 'Tlyanche-Tamak', 1966432: '?', 1152521: 'Mukhomorka', 1508050: 'Slavskoe', 2101755: 'Bakht', 1801009: 'Onitskany', 7633: 'Yasenskaya', 1515342: 'Malaya Devitsa', 1005807: 'Mirny', 1059256: 'Yurlovo', 1147352: 'Primorsk', 2102503: '?', 21950: 'Onufrievka', 1061921: 'Khortitsy', 1700219: 'Viktorovka', 1911611: '?', 5259452: 'Brand-Erbisdorf', 1035492: 'Urup', 1513372: 'Smotrich', 1031233: 'Babushkino', 1160744: 'Novaya', 1709715: '?', 1905612: '?', 1000769: 'Sogra', 1000581: 'Belorechensky', 1056195: 'Borisovo', 1972158: '?', 1959147: '?', 1512783: 'Rubanovka', 1078398: 'Khomutovskaya', 5121446: 'Egegik', 1506218: 'Kosyakovka', 1008425: 'Aribashevo', 1112385: 'Komsomolsky', 2207245: '?', 1128582: 'Shelekhovo', 1050538: 'Ozerki', 3371819: 'Fahankalo', 1962188: '?', 1042329: 'Trekhselskoe', 1147861: 'Yuzhny Ural', 5266391: 'Bad Laasphe', 2101697: 'Uzun (uzunsky Rayon)', 1088122: 'Vorga', 1096992: 'Alexandrovka', 1110202: 'Russky Saramak', 5471547: 'Kubadian', 5471417: 'Kabudian', 1600844: 'Staroe Lyadno', 1961003: '?', 2203843: '?', 1700762: 'Energetik', 1601639: 'Komarovichi', 1600509: 'Mogilevtsy', 2203885: '?', 1913723: '?', 1940617: '?', 1959016: '?', 1934710: '?', 2201745: 'Bolton', 1141117: 'Vavilikha', 1943423: '?', 1086354: 'Ursdon', 1967181: '?', 1041571: 'Novy Mir', 1939962: 'Tsovagyukh', 5267813: 'Gelnhausen', 1123700: 'Chalbachi', 1958605: '?', 5125657: 'Hawkesbury', 2203907: '?', 5267186: 'Königstein im Taunus', 1513369: 'Sechintsy', 1926569: '?', 2201924: '?', 1926024: '?', 1938224: '?', 2201835: '?', 1516393: '?', 1151224: 'Sukhoy Log', 1507462: 'Vishnya', 1123235: 'Zavodskoy', 1909549: 'New Port Richey', 13295: '?', 1503252: 'Shakhtnoe', 1966045: 'Tenants Harbor', 1144865: 'Krugloozernoe', 1700457: 'Kalinovka', 1601732: 'Krasnitsa', 2203994: '?', 1601310: 'Krasnoe', 5031823: 'Atlanta', 1124665: 'Zyryansk', 1159993: 'Mogoytuy', 1926975: '?', 1923942: 'Bandarban', 1975831: '?', 1702077: 'Prirechnoe', 17453: 'Romanovka', 1159342: 'Berezovka', 1901733: '?', 1154154: 'Bubchikovo', 1947175: '?', 1088402: 'Gusino', 1084193: 'Staraya Shentala', 5426228: 'Kosshy (koschi)', 1129496: 'Bezrukovo', 2000378: 'Slavyanka', 1510534: 'Ustye', 1111128: 'Cherkadtsy', 1153586: 'Appany', 1024467: 'Divnogorye', 1086428: 'Zamankul', 1960983: '?', 3054806: 'Tabrīz', 1933110: 'Jarosław', 1114310: 'Khormaly', 1501532: 'Kachkovka', 1505813: 'Kozarovichi', 1024905: 'Russkaya Buylovka', 1514789: 'Selyatin', 4693778: 'Camagüey', 1114482: 'Yangildino', 1970071: '?', 4547651: 'Colonnella', 1142287: 'Morevka', 1913556: '?', 1114850: 'Moskakasy', 5054760: 'Dunellen', 1069583: 'Gorodische', 1915331: '?', 1943890: 'Agana', 1500146: 'Solenoe Ozero', 1079826: 'Aparinsky', 1976546: '?', 1012335: 'Kuznets', 1123631: 'Malinovka', 1916025: '?', 1515210: 'Pokrovskoe / Zhovtnevoe', 1940276: '?', 1917597: '?', 1148159: 'Tobolsky', 1600652: 'Bolshie Kopti', 1932168: 'New Hampton', 1512137: 'Cherneschina', 1057038: 'Schemilovo', 1503324: 'Staraya Kotelnya', 1952986: '?', 1504404: 'Neresnitsa', 1958640: 'Navarra', 2001277: '?', 1065492: 'Gusev', 1974799: '?', 1708978: 'Triesen', 4767: '?', 1969068: '?', 1152768: 'Rakitnoe', 1909309: 'Tadzhikistan', 1510597: 'Ostrozhets', 1094348: 'Chalpy', 1513584: 'Struga', 1091681: 'Sovetskaya', 1712137: '?', 1946275: '?', 1972584: '?', 21255: 'Kovray', 1509423: 'Primorskoe', 1505596: 'Peremoga', 1052991: 'Kurgan (derevnya)', 1066327: 'Shatilovo', 1950253: 'Charleville-Mézières', 1024022: 'Makhrovka', 1124211: 'Severny', 1910046: '?', 16223: 'Borås', 4500725: 'Kąty Wrocławskie', 1157728: 'Kommunar (poselok)', 1159650: 'Raykov', 1708006: 'Ryan', 1012847: 'Khaleevichi', 1508145: 'Koblo', 1159976: 'Sogom', 1159962: 'Kirpichny', 1939035: '?', 4574470: 'Karlshöhe', 5171891: 'Salou', 1136735: 'Vysotino', 1082952: 'Patrovka', 7423: 'Chaplanovo', 1008835: 'Polyakovka', 1003401: 'Romanovskaya', 1040337: 'Klepinino', 18062: 'Kesma', 1707712: 'South Hadley', 1514425: 'Dubievka', 1153710: 'Ustye', 1161736: '?', 1158813: 'Stepnoe', 1042262: 'Moldovanovka', 1159827: 'Laryak', 1938297: '?', 1000674: 'Krasnaya', 2206106: '?', 1710975: 'Topola', 1515330: 'Dedovtsy', 1702724: 'Asanovo', 1702618: 'Akzharkyn (sovkhoznoe)', 1922035: '?', 1500064: 'Aromatnoe', 1952473: '?', 1114251: 'Shinery', 4452178: 'Beausoleil', 1120390: 'Fominskoe', 1505300: 'Kosmach', 1024281: 'Kalacheevsky', 1715647: '?', 1707410: '?', 1011403: 'Poroshino', 1967460: '?', 1513479: 'Chernokozintsy', 1505199: 'Novitsa', 1600591: 'Ikazn', 1601155: 'Bildyugi', 1124276: 'Inzagatuy', 3821217: 'Yeongam', 5279516: 'Imwŏn', 2202282: '?', 1037235: 'Zimstan', 1008203: 'Termenevo', 1014456: 'Dvoryanskoe', 1503094: 'Stary Krym', 1042104: 'Ilich', 1011086: 'Sazhnoe', 1910105: 'Imperia', 1928908: '?', 1704328: '?', 1080428: 'Novaya Derevnya', 1907506: 'Dzhany-Dzhol', 1908794: '?', 13041: 'Vinogradny', 1937262: '?', 1928093: '?', 5093276: 'Newport Terrace Mobile Home Park', 1958367: '?', 1906161: 'Manitowoc', 5032792: 'Marion', 1976140: '?', 5059909: 'Liberty', 1706241: '?', 1518090: '?', 1974294: '?', 1123706: 'Annovka', 1123801: 'Novokievsky Uval', 1503840: 'Mozhary', 1701734: 'Zhartas Sanatory', 1144827: 'Ust-Kamenka', 1144665: 'Shipunovo', 1132169: 'Plotbische', 1079928: 'Zheleznodorozhny', 1132101: 'Adzhim', 1016589: 'Ustye', 1006627: 'Idelbakovo', 4989779: 'Denver', 1705524: 'Bakay-Ata', 1014366: 'Medvedev', 1084470: 'Medvedevka', 22150: 'Smolyany', 1146060: 'Irtyshsky', 3316692: 'Zimbabwe', 1147617: 'Blyavtamak', 5278519: 'Yeosu', 5023701: '?', 5023541: 'Oxford', 4297333: 'Heiligenkreuz', 16478: 'Lipitsy', 1112912: 'Lesnoy', 1600941: 'Ustye', 1123477: 'Urlapovo', 1509830: 'Berezotocha', 1516594: 'Akdash', 1155582: 'Chernoistochinsk', 1509078: 'Utkonosovka', 1084421: 'Rostashi', 1972454: '?', 1079179: 'Lakedemonovka', 1920590: 'Waynesburg', 1111894: 'Pribrezhnoe', 1009691: 'Kukuevka', 3768321: 'Kuala Rompin', 3767384: 'Kuala Selangor', 1022943: 'Abakanovo', 3835557: 'Nishinomiya', 1513086: 'Abrikosovka', 1701761: 'Kushoky', 4454561: 'Arcueil', 1500301: 'Zhemchuzhina', 1085790: 'Pravda', 1508354: 'Voevodskoe', 1115285: 'Sinyaly', 1013368: 'Knyaginino', 2203552: '?', 1001656: 'Motma', 1602861: 'Zayamnoe', 3447883: 'Tongi', 1963207: '?', 1710735: 'Algés', 1059733: 'Dubna', 3494378: 'Udaipur', 1510077: 'Shevchenkovo', 1141228: 'Medyana', 5334672: '?', 1093310: 'Naryshkino', 1093317: 'Novoe Garitovo', 1112648: 'Bulzi', 1502657: 'Novopodkryazh', 1514622: 'Stary Volchinets', 1010614: 'Radkovka', 2204465: '?', 1929293: 'Bedford', 1146805: 'Terensay', 1064709: 'Kamenka', 1024311: 'Khreschatoe', 2202171: '?', 1910893: 'Grand Marais', 1114241: 'Khirposi', 1041039: 'Agronom', 1957492: '?', 17957: 'Vidlitsa', 1011249: 'Zhilaya Zona Khimzavoda (za Myasokombinatom)', 1159509: 'Bondarevo', 1113147: 'Karakulskoe', 1136939: 'Mikhaylovka', 1105453: 'Trud', 5244687: 'Castelluccio dei Sauri', 1002245: 'Tyva (poselok)', 1127620: 'Kuznetsovka', 1967117: '?', 1518545: '?', 3800835: '?', 1089967: 'Pavlovo', 1514586: 'Molnitsa', 1143924: 'Shilovo-Kurya', 1054984: 'Sadki', 1037286: 'Bor', 1948848: '?', 1707262: '?', 1002710: 'Pirinem', 1063138: 'Ostrov', 1014102: 'Katrichev', 5034467: 'Falmouth', 5036375: 'Yarmouth', 1052222: 'Chamzinka', 21573: 'Neubrandenburg', 2208269: '?', 2000747: 'Byadyalan', 1601539: 'Udarnoe', 1111552: 'Vishenka', 8614: 'Turichino', 1512810: 'Chkalovo', 5261674: 'Bad Laer', 1704057: 'Akhmeta', 1510043: 'Rossoshentsy', 1907036: 'Cambrils', 1974649: '?', 1128166: 'Proletarsk', 1013569: 'Proletarsk', 4923241: 'Indian Harbour Beach', 1110643: 'Novaya Monya', 1701291: 'Taskesken', 4249002: 'Tobo', 1032082: 'Ermeli', 1930688: 'Barreiro', 4430470: 'La Roche-sur-Yon', 5028380: 'Barrington', 1602181: 'Senkovschina', 1702713: 'Zhambyl', 1909429: 'Muscatine', 1500769: 'Demidovka', 1708419: 'Užice', 1927927: '?', 1099893: 'Kulitskaya', 2203797: '?', 1057778: 'Podolskleskhoz', 1954172: '?', 1911930: '?', 1053487: 'Nikolsko-Arkhangelsky', 21326: 'Ocala', 1148285: 'Tamar-Utkul', 1509154: 'Ivanovo / Sverdlovo', 1517054: 'Kushum', 1041162: 'Stepnoy', 1907661: 'Uetze', 1505986: 'Borovka', 1506210: 'Velikaya Berezyanka', 2204734: '?', 1519020: 'Sceaux', 5166684: 'Sant Adrià de Besòs', 2202521: 'North Plainfield', 4977671: 'Highland Park', 1906834: '?', 1110132: 'Cheptsa', 1004202: 'Narimanovo', 1504590: 'Semenenkovo / Kirova', 1602334: 'Zhitkovo', 1958298: '?', 1096579: 'Elantovo', 4923580: 'Lehigh Acres', 1509559: 'Kiriakovka', 5070332: 'Dayton', 21335: 'Elmira', 1085941: 'Petrovsky', 5472314: 'Bukit', 1954399: '?', 4074: '?', 1128989: 'Shamanka', 1006121: 'Sait-Kurzya', 1144995: 'Bezmenovo', 1158451: 'Chernaya', 4708556: 'Santa Rosa', 2204168: '?', 5230227: 'Savigny-sur-Orge', 1014228: 'Gorny Balykley', 1116165: 'Pestovo', 1080893: 'Shilovo', 1150239: 'Pogranichny', 1055811: 'Drozhzhino', 1009760: 'Bolshie Lipyagi', 1100184: 'Chuprianovka', 1152108: 'Sosnovo', 1971577: '?', 1063789: 'Pskovitino', 1928967: '?', 1146701: 'Slavyanskoe', 1123058: 'Zabavnoe', 1144064: 'Mirny', 1114936: 'Shomikovo', 1030125: 'Cherntsy', 1050679: 'Kokshaysk', 1085925: 'Krasny Oktyabr', 1929202: '?', 1947610: '?', 1145637: 'Tavrichanka', 1160996: 'Tolka', 1511886: 'Bavorov', 1952875: '?', 1129131: 'Gorskino', 1902272: 'Kasan', 1138285: 'Krutaya Gorka', 1700084: 'Novoalexandrovka', 1115186: 'Alatyrkasy', 17247: 'Petrovskoe', 2202444: '?', 1160444: 'Chindant 1-J', 1157758: 'Borisovka', 1928534: '?', 1910374: '?', 1084527: 'Staraya Zhukovka', 1157195: 'Khayyrakan', 1000330: 'Zeleny Bor', 1081014: 'Tsentralny', 1970573: 'Beamsville', 1030435: 'Dugulubgey', 1503067: 'Galitsinovka', 9548: 'Évora', 4041921: 'Évora', 1917199: '?', 1066492: 'Zeleny Shum', 1036109: 'Tiksha', 1513638: 'Maly Sknit', 1503268: 'Rozovka', 1905226: '?', 1800973: 'Novye Faleshty', 1126473: 'Vospushka', 4241594: 'Blidworth', 1145544: 'Kolomenka', 1125006: 'Pokrov', 1919769: '?', 8457: 'Sitskoe', 1510695: 'Dyadkovichi', 1600458: 'Lemeshevichi', 1146871: 'Kalikino', 1501562: 'Letnichye', 5479341: 'Mutny Materik', 1969544: '?', 20303: 'Vaymusha', 1026604: 'Mukhakh', 11350: 'Dover', 5332813: 'Newtownards', 10999: 'Oma', 1008600: 'Serafimovka', 1135558: 'Tanzybey', 1907031: '?', 1119116: 'Kamchatka (derevnya)', 1124947: 'Krasnoe Plamya', 1035199: 'Stayki', 1109803: 'Yuski', 1079770: 'Verkhneoblivsky', 2205030: '?', 1131789: 'Vichevschina', 1122962: 'Krasny Yar', 4109032: 'Tenkodogo', 4792: 'Fairmont', 1506651: 'Kropivnitskoe', 1975211: '?', 1019661: 'Durakovo', 1111229: 'Polivanovo', 1054829: 'Buzharovo', 1700603: 'Kosmos', 1079989: 'Nagibin', 1114135: 'Polevye Bikshiki', 1902551: 'Laval', 1957391: '?', 3931799: 'Huaihua', 1502494: 'Romanki', 1110430: 'Bolshaya Pudga', 1932380: '?', 1027972: 'Lesnoy', 2201308: '?', 21859: 'Sosnovka', 1114116: 'Kzyl-Chishma', 1137472: 'Khvoynaya', 1004417: 'Budarino', 1036110: 'Tumba', 1040427: 'Selo', 1943843: 'Woodbury', 1504808: 'Grigorovka', 1509044: 'Dzhugastrovo', 1925663: '?', 1505777: 'Krushinka', 1513138: 'Vyazovets', 1122832: 'Yaroslavtsev Log', 1153341: 'Novorossia', 1923863: '?', 1033205: 'Fominichi', 1709248: 'Ashland', 1154858: 'Puxinka', 5210496: 'Roquebrune-Cap-Martin', 5256151: 'Baienfurt', 1096566: 'Blagodatnaya', 1511645: 'Gorodische', 1066490: 'Zvyaginki', 1110396: 'Nizhnie Yuri', 1700874: 'Abay', 5166566: 'Centelles', 1702035: 'Prirechnoe', 1924181: '?', 2205565: 'Kellinghusen', 1146704: 'Talovskoe', 1972012: '?', 1513868: 'Dubievka', 1114266: 'Buinsk', 1950389: '?', 1506060: 'Zhukovtsy', 1109051: 'Santalovsky', 1059817: 'Solodovka', 1145194: 'Ingaly', 1068047: 'Golitsino', 2204966: '?', 1942943: '?', 1963592: '?', 1702833: 'Stepnoe', 1041822: 'Veselaya Zhizn', 1006868: 'Frunze', 2001482: 'Remchingen', 5115118: 'Rayann', 1600731: 'Koroby', 1074263: 'Ktogische', 2203763: '?', 2205271: '?', 1040985: 'Dukhovskoy', 1954932: '?', 1919435: '?', 1513914: 'Novoe Selo', 1513836: 'Kugaevtsy', 2205279: '?', 1969219: 'Mansa', 2205294: '?', 1509426: 'Strumok', 1930817: 'Dallas', 1128837: 'Golumet', 1149905: 'Pelym', 1972136: '?', 1153988: 'Ekhabi', 1153848: 'Korsakovka', 1135225: 'Talovka', 1135222: 'Razdolnoe', 1135765: 'Zakharovka', 1135207: 'Lugovskoe', 1094227: 'Krasny Bor', 1645: 'Petrovskoe', 1920138: 'Susanville', 1976767: '?', 1079107: 'Kalinin', 1975186: '?', 2204338: '?', 1935341: '?', 1509522: 'Lyutenka', 1709755: 'Bremerton', 1143806: 'Bystrovka', 1084768: 'Medyanikovo', 1968596: '?', 1113711: 'Starye Atagi', 15493: 'Uinskoe', 1041548: 'Vladimirskaya', 1135031: 'Bor', 22697: 'Macaé', 1503312: 'Ivnitsa', 4493934: 'Pila Ruszczyńska', 5110384: 'East Portland', 1511009: 'Mutin', 1511014: 'Bozhok / Chervony Ranok', 1962330: '?', 1160002: 'Ureysk', 1113189: 'Demarino (tsentralnaya Usadba)', 1052337: 'Purkaevo', 1513511: 'Mitintsy', 1151189: 'Kazanka', 1602674: 'Bolshaya Bykhovschina', 1929855: '?', 1040784: 'Samurskaya', 1052478: 'Navlya', 1124586: 'Ust-Kyakhta', 1933507: 'Lloydminster', 1145675: 'Orlovka', 1502122: 'Volnoe', 1093469: 'Nikolskoe', 1050211: 'Bratovka', 7825: 'Opytnoe Pole', 4640493: 'Arroyo Seco', 4639915: 'Salto', 5060702: 'New Scotland', 1000622: 'Grigoryevskaya', 1024249: 'Nizhny Karachan', 1507527: 'Popeli', 1701256: 'Molodezhnoe', 1702703: 'Arkhangelka', 1041287: 'Elizavetinskaya', 1129285: 'Yasnogorsky', 4542401: 'Pistoia', 1500447: 'Dobroe', 1146186: 'Nikopol', 1506012: 'Nezhilovichi', 1006310: 'Vpered', 1514424: 'Geronimovka', 1095342: 'Matyushino', 1948683: '?', 1910923: 'Saint Joseph', 1132685: 'Maradykovo', 1976369: '?', 1135870: 'Taezhnoe', 1502164: 'Khutoro-Chaplinoe', 1138051: 'Kostygin Log', 18357: 'Utta', 1157800: 'Larikha', 1517065: '?', 3301090: 'Zemun', 1505177: 'Berezhnitsa', 1926873: '?', 1123654: 'Zhitomirovka', 1155486: 'Poldnevaya', 1602629: 'Zaskovichi', 1704238: 'Novosady', 1506339: 'Tarasovka', 4782767: 'Los Santos', 6377: 'Arlon', 1122720: 'Povalikha', 1709207: 'Alpena', 1519240: 'Bawdsey', 1060433: 'Zasheek', 1922984: '?', 1068496: 'Staraya Andreevka', 1902435: '?', 1152110: 'Uralskoe', 1926248: '?', 1931957: '?', 1945633: '?', 5123371: 'Charlottetown', 1510706: 'Kolodenka', 1920682: 'Yucaipa', 1913988: '?', 1004774: 'Chebenli', 1131000: 'Sokolovka', 1053048: 'Levzha', 18257: 'Norrtälje', 4925148: 'Venus', 1972461: '?', 4236962: 'Harwell', 1122437: 'Ananyevka', 2205561: '?', 1128138: 'Alymovka', 1504668: 'Blagoveschenka', 1028092: 'Bobanino', 1127694: 'Babagay', 1010404: 'Belomestnoe', 1957987: 'Eshtia', 1514336: 'Onopreevka', 1939154: '?', 1700486: 'Shalkar', 1056438: 'Troparevo', 1147502: 'Priuralsk', 1924879: '?', 1052504: 'Sosnovka', 1153915: 'Burevestnik', 4140708: 'Kenema', 1945825: '?', 1054572: 'Novo-Egorye', 1500763: 'Yarmolintsy', 1908404: '?', 1968419: '?', 1963732: '?', 21297: 'Bad Neuenahr-Ahrweiler', 1103270: 'Bolshaya Kosha', 2205602: '?', 1148381: 'Yasnaya Polyana', 1011482: 'Tvorishino', 10501: 'Trenčín', 1933227: '?', 1909055: '?', 1966921: 'Bzypta', 1912083: '?', 1067687: 'Sosnovy Bor', 1155253: 'Russkaya Tavra', 4379477: 'Ellenstedt', 1702134: '?', 1141383: 'Mikhaylovka', 1502135: 'Sergievka', 2202960: '?', 1517313: 'Emden', 1515399: 'Ubozhichi', 1154364: 'Potashka', 1068078: 'Pogranichnoe', 1011020: 'Butovo', 1124698: 'Verkhnyaya Zaimka', 1133532: 'Bakuli', 18651: 'Miynala', 1506533: 'Lozovatka', 5349764: 'Schöneck/Vogtland', 1915873: 'Zacatecas', 1500315: 'Novogrigoryevka', 1517951: '?', 11941: '?', 1161176: 'Uchkhoz', 1931742: '?', 1519357: '?', 1139436: 'Krutoy Maydan', 1965772: '?', 1509784: 'Omelnik', 1976633: 'Holmenkollen', 1700523: 'Zhansugirov', 1004448: 'Buruny', 1134211: 'Levany', 1504692: 'Novoukrainka', 1709206: 'Alma', 1502404: 'Popasnoe', 1900006: 'Peleh', 1093590: 'Tambovsky', 1505856: 'Arkadyevka', 2202313: '?', 1600111: 'Budcha', 5267635: 'Vilshofen an der Donau', 1602475: 'Sloboda-Kuchinka', 1914009: '?', 1127836: 'Lesnoy', 1035770: 'Lasanen', 21705: 'Krasnopolye', 1507477: 'Koropuzh', 1055372: 'Elgozino', 1974135: '?', 2204992: '?', 5277821: 'Euiwang', 5266032: 'Husum', 21902: 'Eau Claire', 1801820: 'Hawkins', 1128426: 'Shumsky', 1053081: 'Trusklyay', 1097743: 'Shilovo', 1158606: 'Angarsky', 1709178: 'Alameda', 1708045: '?', 1141802: 'Ichalki', 21575: 'Sverdlovka', 1109447: 'Svetloe', 1601898: 'Putrishki', 1906423: '?', 1954096: '?', 2204027: '?', 1060401: '27 Km', 1702594: 'Kazanka', 1122746: 'Pautovo', 1082541: 'Khruschevo', 1512640: 'Manchenki', 1512166: 'Sharovka', 1038492: 'Zarubino', 1500625: 'Mitki', 1966618: '?', 1015046: 'Peregruznoe', 1707623: 'Strongsville', 1964409: 'Gazakh', 1137660: 'Lebyazhye', 1041897: 'Grigoryevskaya', 1959976: '?', 1127597: 'Bambuy', 1904120: '?', 1711045: 'Zwettl', 1137666: 'Obanino', 1127899: 'Butyrki', 1514446: 'Chernyavka', 1514426: 'Dumantsy', 1506186: 'Besedka', 1921346: '?', 1113722: 'Dzhalka', 1136250: 'Selivanikha', 1092001: 'Bykogorka', 1506865: 'Chervonaya Polyana', 1136710: 'Velmo', 1955316: '?', 1113011: 'Pervomaysky', 1114160: 'Azim-Sirma', 1909823: '?', 1959060: '?', 1702138: 'Krasnaya Presnya', 1122386: 'Ust-Isha', 1023973: 'Krasnodar', 1141570: 'Chernaya Maza', 4969151: 'Acorn Forest', 1904989: 'Mikhaylovka', 1127540: 'Savvateevka', 1602330: 'Gantsevichi', 1944560: '?', 1066251: 'Bobrik', 1036570: 'Khaapalampi', 1077756: 'Rogozhkino', 1041965: 'Risovy', 1504491: 'Nizhnee Selische', 1009809: 'Rossosh (khutor)', 1109783: 'Sokol', 1153855: 'Khoe', 1600768: 'Kholomerye', 1083703: 'Stary Buyan', 1500379: 'Slavyanskoe', 1160225: 'Menza', 1901806: 'Târgu Jiu', 1714733: '?', 1007829: 'Samoylovka', 2204636: '?', 1024723: 'Yarki', 1078225: 'Bolshaya Talovaya', 4302918: 'Tienen', 1510944: 'Koshary', 1115634: 'Indyrchi', 1504442: 'Kiblyary', 11321: 'Seregovo', 1039137: 'Sobakino', 1134166: 'Sobakino', 1159679: 'Efremkino', 3336232: 'Kubu A Hachwe', 1113113: 'Uraimskie Tomilki', 1099876: 'Kotelnikovo', 1514920: 'Rubanka', 1904523: 'Gabès', 1928167: '?', 1600522: 'Bolshoe Maleshevo', 1514754: 'Nesvoya', 1113573: 'Shakhmatovo', 1147625: 'Budamsha', 1124125: 'Ust-Nyukzha', 1514666: 'Babin', 1967970: '?', 1509369: 'Roylyanka', 1000497: 'Solginskaya', 4742198: 'Boca de Briceño', 1030600: 'Khushto-Syrt', 1602256: 'Skribovtsy', 1143545: 'Paletskoe', 2206109: '?', 1091579: 'Spitsevka', 4266: 'Bozeman', 1010425: 'Golubino', 1009739: 'Timonovo', 16253: 'Calau', 4539753: 'Sarsina', 1147282: 'Krasnochabansky', 1513826: 'Zhabintsy', 1511211: 'Khmelev', 1114954: 'Anastasovo', 5459301: 'Serebryanka', 5266287: 'Oer-Erkenschwick', 1922505: '?', 1094468: 'Kartovo', 1142565: 'Elizarovo', 1114497: 'Kirov', 1156554: 'Pudino', 1077827: 'Azhinov', 1096657: 'Bikulovo', 4443886: 'Corte', 1028714: 'Shilykovo', 1507294: 'Kamyshnoe', 1152810: 'Maryanovka', 1969522: '?', 1917438: '?', 2201115: '?', 2206166: '?', 1009433: 'Zhukovo', 1055224: 'Ledovo', 1505753: 'Tarasovka', 1030868: 'Liski', 1084509: 'Vyazovka', 1146631: 'Bolshoy Atmas', 1514936: 'Kazatskoe', 1913168: '?', 1030580: 'Psygansu', 1041453: 'Svetlaya Zarya', 1134410: 'Agalachenki', 2203033: '?', 1093026: 'Piterskoe', 1710892: 'Roswell', 1968898: 'Wathlingen', 5266421: 'Pfungstadt', 1038930: 'Kuzhbal', 1500219: 'Novopokrovka', 1703251: 'Fort-de-France', 1109635: 'Bibangurt', 1974166: '?', 1500822: 'Kitaygorod', 1923771: 'Pila', 22727: '?', 1014624: 'Miroshniki', 1092117: 'Kucherla', 1063101: 'Laptevo', 1502885: 'Nelipovka', 1024415: 'Taly', 1914892: 'Tongeren', 1096985: 'Yulbat', 1502729: 'Metallist', 1502490: 'Orly', 1113675: 'Makhkety', 4474703: 'Přerov', 5266798: 'Waldkirch', 1061892: 'Sychevo', 1024184: 'Muzhichye', 1024167: 'Bannoe', 1092796: 'Khobotovo', 1516015: 'Botoşani', 1112439: 'Novy Ural', 5169293: 'Cervera', 1965915: '?', 1002366: 'Moseevo', 1507393: 'Zabolottsy', 1062782: 'Novoselitsy', 1095175: 'Naratly', 1506706: 'Golovkovka', 1002791: 'Volovo', 5267803: 'Sundern (Sauerland)', 5236885: 'Vernon', 5267728: 'Dillingen an der Donau', 1938692: '?', 4948541: 'Livingston', 5117921: 'Northeast Tacoma', 1932299: '?', 5119168: 'Jackson', 1154595: 'Losiny', 1115497: 'Lesnoy', 1129395: 'Chusovitino', 7091: 'Zutkuley', 1969993: '?', 1707817: '?', 1124711: 'Yanchukan', 1929654: '?', 1156899: 'Novoarkhangelskoe', 1057653: 'Bykovo', 1037260: 'Paspom', 1012786: 'Vereschaki', 1509682: 'Drizhina Greblya', 4644722: 'Ribeirão das Neves', 1505126: 'Torgovitsa', 1052928: 'Mikhaylovka', 16855: 'Farkhor', 1044800: 'Soldatskoe', 4397366: 'Banteer', 1148366: 'Pridolinny', 5056240: 'Weehawken', 1147508: 'Sara', 1002383: 'Chetsa', 1070160: 'Ostrov', 1044330: 'Kommunar', 1708179: 'Kerimäki', 1509320: 'Novoukrainka', 1958399: '?', 1042822: 'Kopenki', 1509651: 'Stavkovo', 1508773: 'Vavilovo', 2203895: '?', 1124100: 'Sadovoe', 1064771: 'Russky Brod', 1508168: 'Staryava', 1515332: 'Dmitrovka / Zhovtnevoe', 1009638: 'Striguny', 1974812: '?', 1801041: 'Pepeny', 15452: 'Ein HaShofet', 1053268: 'Chizhikovo', 1129374: 'Podgornoe', 1501179: 'Kukuli', 1972177: 'Abergavenny', 1048696: 'Kazinka', 1013260: 'Knyaginino', 1091353: 'Pavlovo', 4048921: 'Buchanan', 1946016: 'Billesholm', 4269843: 'Åstorp', 1601039: 'Krasnopolye', 1158808: 'Nukuty', 1085569: 'Novorechensky', 1514263: 'Kopiyuvata', 1505682: 'Golovurov', 1009683: 'Koloskovo', 1708921: '?', 1514447: 'Shelepukhi', 2202299: '?', 1705080: '?', 4302050: 'Vossem', 5401656: 'Jezus-Eik', 4304533: 'Rotselaar', 4310931: 'Herent', 1908990: 'Heverlee', 1063699: 'Koloma', 1160545: 'Tupik', 1036484: 'Podporozhye (poselok)', 1121211: 'Mikhaylovsky', 22178: 'Podsoltovo', 4393062: '?', 1154669: 'Iva', 1047334: 'Yarovschina (alekhovschinskoe S/p)', 1108936: 'Arkhangelskoe', 1053326: 'Zhukovo', 8008: '?', 3801: '?', 1914188: '?', 1513530: 'Golovchintsy', 1513548: 'Trebukhovtsy', 1800194: 'Valeny', 1947919: '?', 4190609: 'San Giovanni la Punta', 1514338: 'Papuzhintsy', 1601243: 'Derbichi', 1509493: 'Matyashovka', 1057853: 'Chernetskoe', 2202924: '?', 1514883: 'Polyana', 1048134: 'Zagrivye', 1032074: 'Khar Tolga', 1145659: 'Dombay', 1507118: 'Mozhnyakovka', 1961238: '?', 1910941: 'Batavia', 1059245: 'Khorugvino', 1710536: 'Massapequa', 1975958: '?', 14043: '?', 8325: 'Kemijärvi', 1507464: 'Galichany', 1107973: 'Sorochinka', 1701769: 'Petrovka', 1708635: 'Höör', 1501754: 'Dubovoe', 1706396: 'Vievis', 1509797: 'Berbenitsy', 3125106: 'Thíra', 1151050: 'Medyanka', 1510988: 'Slavgorod', 1919344: 'Ikast', 1012545: 'Novaya Moskva', 1068249: 'Zasurskoe', 1514907: 'Grigorovka', 1916173: '?', 1943379: 'Wolvega', 1509885: 'Sakhnovschina', 1500218: 'Novozuevka', 1961944: '?', 1501223: 'Snezhnaya', 1112805: 'Dubrovka', 1510220: 'Bystrichi', 1502794: 'Novopetrikovka', 1142563: 'Davydkovo', 2601341: 'Priekuļi', 2604188: 'Staicele', 1039674: 'Poldnevitsa', 1110627: 'Kopki', 1506563: 'Onikievo', 13069: 'Yuvanovo', 1953941: '?', 2205907: '?', 1931423: 'Metsavan', 1137747: 'Grenadery', 1137777: 'Setovnoe', 1602028: 'Papernya', 1948279: '?', 1715203: '?', 2206701: '?', 1923015: '?', 1070321: 'Gorodno', 18277: 'Eletsky', 1702733: 'Rassvet', 1922920: '?', 2206724: '?', 4546728: 'Foligno', 1085164: 'Rukopol', 13981: 'Kerava', 3221558: 'Järvenpää', 1110407: 'Srednee Kechevo', 1102647: 'Kiverichi', 1930864: '?', 4696730: 'British Virgin Islands', 1037550: 'Bashmakovo', 1919047: 'Chantilly', 1509927: 'Velikie Solontsy', 1026926: 'Kurush', 3167365: 'Keren', 1024645: 'Svkh Maslovsky 1 Otdelenie', 4245019: 'Horw', 2206753: '?', 1707529: 'Mestia', 1975198: '?', 1150965: 'Ilinsk', 15313: 'Rüdersdorf bei Berlin', 1938951: '?', 1913522: '?', 2206778: '?', 1516453: '?', 1120599: 'Kotovo', 1095813: 'Safonovo', 1703142: 'Kakaydi', 1017016: 'Susolovka', 1708441: '?', 1502544: 'Novoalexandrovka', 1004342: 'Samosdelka', 1504390: 'Ganichi', 5122503: 'Barrhead', 1913385: 'Vildbjerg', 1709948: 'Carlisle', 1971668: 'Šalčininkėliai', 1600274: 'Omelenets', 4375810: 'Fürstenau', 1077889: 'Krasnodonetskaya', 2206825: '?', 1713505: '?', 1600747: 'Palminka', 4316209: 'Anzegem', 19569: 'Kamenyuki', 1948001: '?', 1927189: '?', 1916171: 'Cavtat', 1969906: '?', 1053732: 'Teryaevo', 1512265: 'Podvorki', 4271828: 'Valongo', 1509107: 'Zagnitkov', 1152910: 'Nikolaevka', 2002088: '?', 1933300: 'Brandon', 22070: '?', 1153253: 'Dalzavodskoe', 1028864: 'Borodino', 1153723: 'Kharbalakh', 3767963: 'Kertih', 1927873: '?', 1157750: 'Stanichnoe', 1145420: 'Indeyka', 1113377: 'Nizhnyaya Sanarka', 2204668: '?', 4614003: 'Swakopmund', 1001295: 'Savino', 1510909: 'Sosnovka', 4009: 'Novoukrainsky', 1083038: 'Fedorovka', 1970554: '?', 1158704: 'Olzony', 1601845: 'Izabelin', 1702709: 'Budennoe', 1152944: 'Olenevod', 1131678: 'Pokrovskoe', 1008088: 'Yashasen', 1008015: 'Karan-Kunkas', 5266676: 'Brackenheim', 4918797: 'Springdale', 1709274: 'Edinburg', 1083802: 'Maly Tolkay', 1014318: 'Mirny', 1122231: 'Novaya Chemrovka', 1900418: 'Kibutz Gat', 1043711: 'Bolshaya Vladimirovka', 1505778: 'Ksaverovka', 1501062: 'Zhvan', 1505346: 'Lanchin', 1714173: 'Strenči', 1110374: 'Ilinsk', 1503218: 'Andreevka', 2203858: '?', 1077782: 'Bolshoy Log', 1112754: 'Oktyabrsky', 1013626: 'Nerussa (derevnya)', 1513118: 'Markeev', 2206985: '?', 1122581: 'Poluyamki', 1936933: '?', 1022835: 'Shapsha', 5363865: 'Albena', 2206455: '?', 1151226: 'Tabory', 1055646: 'Novaya', 5261795: 'Nottuln', 1058194: 'Telmana', 1504772: 'Shevchenkovskoe', 1504769: 'Ternovatoe', 2201823: '?', 1600969: 'Kushliki', 1519182: 'Alsemberg', 1158265: 'Kamenka', 1513630: 'Klepachi', 1976371: 'Cuxhaven', 2206983: 'Cadenberge', 1516094: 'Bestamak', 1134079: 'Andreevsky', 2203457: '?', 1083974: 'Lunacharsky', 4245157: 'Andelfingen', 4503127: 'Gogolin', 1077750: 'Pobeda', 5355233: '?', 1046091: 'Dranishniki', 1043916: 'Ryabaya Olkha', 1094770: 'Azbaba', 1056614: 'Ateptsevo', 1006449: 'Asyanovo', 1508282: 'Yavorov', 1008551: 'Kakrybashevo', 1975618: '?', 1923246: '?', 4003740: 'Katunga', 1112145: 'Starye Algashi', 4220626: 'Vemb', 2207016: '?', 4952906: 'Darnestown', 4957232: 'Poolesville', 1156339: 'Volochanka', 1503393: 'Reya', 1505007: 'Solotvin', 2202787: '?', 1510044: 'Runovschina', 1036548: 'Cherny Porog', 1501593: 'Kvasov', 1511397: 'Ivankov', 1504246: 'Cherny Potok', 1939846: '?', 1128542: 'Nikolaevka', 16142: 'Nyurbachan', 1024158: 'Talovaya', 2203250: '?', 3288552: 'Łomianki', 1156683: 'Sulzat', 1949255: 'Vadsø', 1710262: 'Nabran', 1509613: 'Vodyanaya Balka', 6071: 'Eskilstuna', 1145087: 'Shipitsino', 1096200: 'Novoe Serezhkino', 1152962: 'Priiskovy', 1512834: 'Novopetrovka', 2204365: '?', 1514081: 'Peschanoe', 1904106: '?', 3228470: 'Sighetu Marmaţiei', 5428510: 'Vostochnoe', 1091701: 'Veseloe', 1946873: '?', 2207166: '?', 2204540: '?', 1953127: 'Waldkraiburg', 2202917: '?', 1025642: 'Sergeevka', 1974390: '?', 1507033: 'Chelyuskinets', 1506469: 'Dmitrovka', 1956230: '?', 1512068: 'Verkhnyaya Samara', 1091854: 'Kangly', 1976240: '?', 1928953: '?', 1154415: 'Zarya', 1911803: '?', 1136453: 'Anash', 16425: 'Tokarevka', 18662: 'Erin', 1151961: 'Suda', 1112679: 'Ognevskoe', 22417: 'Kelowna', 1953896: '?', 1092942: 'Glazovka', 1077842: 'Otradny', 1052828: 'Efaevo', 3058937: 'Qazvīn', 5264323: 'Durmersheim', 1004435: 'Promyslovka', 1043530: 'Checheviznya', 2202456: '?', 1112955: 'Khalitovo', 5454745: 'Sergeevka', 1710894: 'Moskovsky', 1082945: 'Letnikovo', 1912353: '?', 5091809: 'Hillsborough', 1911777: '?', 1702518: 'Zhetekshi', 1976626: 'Šventoji', 1955670: 'Provincia de Río Negro', 1024737: 'Kolesnikovo', 4291179: 'Schärding', 2001981: '?', 4523142: 'Eibar', 6954: 'Chernovskoe', 1904568: '?', 1500212: 'Mirolyubovka', 17319: '?', 1127948: 'Nikolsk', 1059011: 'Serpukhov-4', 1087100: 'Ivino', 2204906: '?', 2200523: 'Proshyan', 1601329: 'Krugovets-Kalinino', 1041149: 'Lebedi', 1114420: 'Almenevo', 1909706: '?', 1506711: 'Zvenigorodka', 1503890: 'Khochino', 1515596: '?', 1131972: 'Borovitsa', 4258458: 'Ljungby', 1501018: 'Bronnitsa', 6565: '?', 1942481: 'Tranås', 21149: '?', 1959314: '?', 1951440: '?', 5266905: 'Geretsried', 1501174: 'Gonorovka', 1501527: 'Gonorovka', 4151428: 'Boké', 1145478: 'Safonovo', 1512824: 'Arkhangelskoe', 1960077: '?', 1073828: 'Ivanovo (derevnya)', 1029803: 'Nerl', 4969991: 'Buffalo', 1908147: 'Marion', 1971239: '?', 1512807: 'Staroselye', 1159548: 'Znamenka', 1969778: '?', 1512330: 'Alexandrovka', 1136625: 'Novaya Solyanka', 1904901: 'Downers Grove', 1706083: '?', 1511929: 'Zavodskoe', 1121655: 'Ozero-Kureevo', 1957601: '?', 1501724: 'Lipnoe', 1509422: 'Nerushay', 1030426: 'Troitskaya', 1702544: 'Kovalevka', 5041642: 'Mattawan', 1958596: '?', 1080016: 'Schedrovka', 1512299: 'Cherneschina', 1512291: 'Runovschina', 3317501: 'Adylinn', 1111591: 'Tiinsk', 1960570: '?', 1929829: 'Sariasia', 1151729: 'Severny Kommunar', 4471580: 'Třemošnice', 1075365: 'Gloty', 1130168: 'Botyevo', 1920652: 'Williston', 1045157: 'Kurskaya Olkhovatka', 1510488: 'Kunin', 1101672: 'Nikolskoe', 1700535: 'Aktubek', 1930146: '?', 4722260: 'Liberia', 1706311: 'Bata', 1106729: 'Nenashevo', 1156544: 'Sredny Vasyugan', 1512132: 'Novoplatonovka', 1955665: '?', 1060908: 'Kholm', 1109909: 'Chutyr', 1967925: '?', 3147: 'Ibarra', 1053369: 'Torbeevo-1', 2207468: '?', 2722544: 'Gitega', 1514359: 'Kolodistoe', 1132153: 'Novaya Smail', 1086407: 'Malgobek', 1070748: 'Chubakovo', 1511041: 'Ryabushki', 1513385: 'Borisov', 1509152: 'Pershotravnevoe', 1042777: 'Basovo-Zarechye', 5032308: 'Fremont', 1601664: 'Borschevka', 1073967: 'Rodovoe', 1076778: 'Linovo', 1111798: 'Orekhovka', 1920065: '?', 1972308: '?', 1041659: 'Uzlovoy', 1147804: 'Bylinny', 1514028: 'Knyazhaya', 1503185: 'Zalesnoe', 5267122: 'Nördlingen', 1902091: '?', 1091902: 'Zunkar', 1052391: 'Novonikolskoe', 1052384: 'Nadezhdino', 1505844: 'Marmuleevka', 2200404: 'Ddmashen', 724: 'Potosí', 1905193: '?', 1942570: '?', 1908540: 'Owerri', 1094703: 'Kaleykino', 1123528: 'Otvazhnoe', 1505629: 'Popravka', 1515509: 'Kolychevka', 1710011: '?', 1117316: 'Zakobyakino', 1117307: 'Ermakovo', 1928890: '?', 1925896: '?', 4329466: 'Steinbach', 1506449: 'Bokovoe / Kirovo', 1025014: 'Novy Liman', 1008332: 'Karmaskaly', 1514489: 'Stepovoe / Leninskoe', 1509517: 'Kachanovo', 1965239: '?', 2207361: '?', 1911994: 'Cill Chaoi', 1502196: 'Karnaukhovka', 1002280: 'Vozhgora', 1091620: 'Vavilon', 1702196: 'Nagornoe', 1949823: '?', 1500645: 'Birlovka', 1517695: 'North Bay', 1962282: '?', 1939840: '?', 1500483: 'Razdolye', 1080100: 'Igoshino', 5425376: 'Shovu', 1043292: 'Bolshoe Shumakovo', 1024251: 'Novogolyelan', 1119155: 'Kresttsy', 1966904: 'Weinstadt', 1968659: '?', 1118033: 'Pushkino', 1705922: 'Teplye Klyuchi', 2207603: '?', 1005256: 'Starye Maty', 1509384: 'Volnoe', 1507384: 'Berlin', 1137150: 'Borozdinka', 1137176: 'Schuchanka', 1505464: 'Dolishnoe Zaluchye', 1512651: 'Rogan', 1004271: 'Bakhtemir', 1969495: '?', 2202628: '?', 1973652: '?', 2206193: '?', 1077257: 'Pustoshka', 1975842: '?', 1513989: 'Voronoe', 1507121: 'Novorossosh', 1503777: 'Kikova', 1921848: '?', 1955726: '?', 4244221: 'Ollon', 1508587: 'Luch', 2204316: '?', 4566948: 'Seebrugg', 1004430: 'Mikhaylovka', 1938766: '?', 1003947: 'Ivanovskoe', 2208881: '?', 1070158: 'Oryol (polnovskaya Volost)', 1077996: 'Mescheryakovsky', 1507942: 'Nemilov', 1966267: '?', 1929248: '?', 3304668: 'Kraljevo', 5326049: 'Matoury', 1949252: '?', 1012504: 'Verkhlichi', 1036686: 'Chernoborsk', 1029925: 'Mikhaylovskoe', 1508700: 'Shevchenkovo', 1975162: '?', 1602091: 'Petrevichi', 4977897: 'North Vineland', 3828212: 'Gapyeong', 1802077: '?', 1031864: 'Chkalovsky', 2207729: '?', 1159541: 'Bolshaya Erba', 1936415: '?', 2201375: '?', 1085042: 'Pervomayskoe', 20110: 'Volkovo', 1121839: 'Vavilon', 5262641: 'Norath', 1113549: 'Maskayka', 3305489: 'Gornji Milanovac', 1602215: 'Zalesye', 1509380: 'Borodino', 7030: '?', 1149140: 'Vizhay', 1006967: 'Yabalakovo', 1503875: 'Kopische', 1702387: 'Akshukyr', 3124005: 'Al Mafraq', 1123733: 'Srednebelaya', 1152229: 'Kurgan', 1078304: 'Donetsky', 2207449: 'Cambridge', 1972021: '?', 1084081: 'Maslennikovo', 1143751: 'Travnoe', 4276: 'Lelystad', 1947353: '?', 1032319: 'Abramovskoe', 1502540: 'Mayskoe', 1600436: 'Pinkovichi', 1110354: 'Gozhnya', 1704462: 'Orihuela', 1085111: 'Dyakovka', 1922105: 'Godolar', 1155854: 'Talitsa', 1078386: 'Novobataysk', 3295733: 'Czyżewo Sutki', 1937742: '?', 5070790: 'East Texas', 4496601: 'Międzyrzecz', 1114264: 'Bolshie Abakasy', 1709437: 'Beeville', 1038570: 'Sidorovskoe', 1150971: 'Koltaeva', 1157700: 'Stepnoy', 1091719: 'Nadzornoe', 1031242: 'Divnoe', 1709040: 'Deerfield', 2207928: '?', 4133: '?', 1505390: 'Konyushki', 4936232: 'Cloverdale', 1077764: 'Sukhodolsk', 1501895: 'Gorodnoe', 1020966: 'Biryakovo', 2207987: '?', 1948127: '?', 5028387: 'Bartlett', 1086310: 'Tib', 1115319: 'Khyrkasy', 2202905: '?', 1600583: 'Lug', 1602762: 'Lyadno', 1952662: '?', 1054425: 'Scherbinka', 1005523: 'Zigaza', 2207525: '?', 1939298: '?', 19153: 'Petrovskaya', 5266670: 'Waiblingen', 2001391: '?', 1060308: 'Yunost', 1159581: 'Novomaryasovo', 1078043: 'Malaya Zapadenka', 1909589: 'Cockeysville', 1100283: '?', 5426766: 'Borodino', 15840: 'Lykoshino', 2207551: '?', 2200187: 'Marmarashen', 1511122: 'Khukhra', 1145177: 'Tsvetnopolye', 1084579: 'Novopolevodino', 1085506: 'Nozhkino', 1517053: 'Dinant', 2208032: 'Sepetiba', 1078211: 'Fedoseevka', 2208042: '?', 1902908: '?', 10580: 'Vetyutnev', 1701613: 'Pogodaevo', 1903778: '?', 1095975: 'Bereznyak', 1026718: 'Dyubek', 1921120: 'Sittingbourne', 1505186: 'Dovpotov', 2208063: '?', 1111902: 'Shmelevka', 1709404: 'Batavia', 2208064: '?', 1160688: 'Kadala', 1512875: 'Azovskoe / Frunze', 1000125: 'Pervomaysky', 1506278: 'Skrigalovka', 1108387: 'Dubovka', 1509139: 'Korsuntsy', 5021729: 'Williamstown', 1013523: 'Luzhki', 1079727: 'Martynovka', 1510461: 'Nobel', 2208085: '?', 1503005: 'Udachnoe', 1054332: 'Kotlyakovo', 1505001: 'Porogi', 2208095: 'Shillong', 1157787: 'Kazanka', 1702689: 'Spasovka', 1121624: 'Tenga', 1106410: 'Protasovo', 5081357: 'Baltimore', 1933624: '?', 1040082: 'Raslovo', 1940782: '?', 1906651: '?', 1002570: 'Kovkula (derevnya)', 1002571: 'Kovkula (poselok)', 1112400: 'Rymnixky', 2203814: '?', 1903066: 'Hicksville', 1111763: 'Oktyabrskoe', 1065792: 'Korotysh', 1504680: 'Belotserkovka', 1918718: 'Leusden', 2204995: '?', 1032196: 'Uteshevo', 1031933: 'Kaazhikhin', 1067476: 'Kamenka', 1007747: 'Kholmogory', 1043229: 'Blagodatnoe', 1800719: 'Leusheny', 3829: 'Modesto', 1133002: '?', 4674286: 'San Juan Teotihuacán', 5009471: 'Burke', 2201320: '?', 1601482: 'Savichi', 1966469: '?', 1121715: 'Abay', 5476547: 'Nusa Penida', 1503083: 'Novoselidovka', 1708501: 'Ojai', 1024074: 'Serikovo', 1154381: 'Cherepanovo', 1083141: 'Petrovka', 1143601: 'Staroscherbakovo', 1966675: '?', 2203532: '?', 1015019: 'Khopersky', 1153520: 'Lensky', 1120039: 'Milkovo', 1963671: '?', 1114203: 'Mamalaevo', 1146579: 'Axenovo', 2100264: 'Zafarabad (gizhduvansky Rayon)', 1062467: 'Bor (derevnya)', 1514317: 'Belashki', 1123099: 'Novoperunovo', 15100: 'Kuzmino', 1096100: 'Bolshie Kabany', 1503353: 'Rogachev', 1088104: 'Shkola', 1602240: 'Orlya', 1501588: 'Zhabche', 1138299: 'Ptichye', 1096213: 'Staroe Shugurovo', 1912491: '?', 1050163: 'Voronezhskoe Malanino', 1516827: '?', 1137157: 'Kazennoe', 1961924: '?', 2208352: '?', 1015329: 'Yagodny', 9036: 'Utsunomiya', 1147115: 'Verkhnyaya Vyazovka', 2001872: '?', 1113175: 'Uysko-Chebarkulskaya', 1911278: '?', 1923597: '?', 1512236: 'Kamenka', 1514684: 'Mikhaylovka', 1968915: '?', 1508618: 'Nikolaevka', 1077712: 'Krasnaya Polyana', 1137672: 'Ptichye', 1972311: '?', 1113041: 'Khrebet', 2201747: '?', 1919311: '?', 1501313: 'Lipovka', 1913326: '?', 1974510: '?', 1015198: 'Gromki', 1513347: 'Dunaevtsy Selo', 1517105: '?', 1079728: 'Mityakinskaya', 1079213: 'Nosovo', 1067589: 'Korsaevka', 1013996: 'Pisarevka', 1058992: 'Raysemenovskoe', 1077714: 'Krugloe', 1025010: 'Krasnoselovka', 1512567: 'Grushinoe', 2208421: '?', 1132424: 'Puga', 1143594: 'Novoulyanovskoe', 1157185: 'Toora-Khem', 2722632: 'Apia', 1154189: 'Kishkinskoe', 1800794: 'Meresheny', 2205411: '?', 1506359: 'Plosko-Zabuzhskoe', 1004258: 'Nikolskoe', 4529669: 'Trysil', 1030895: 'Nizovye', 1507087: 'Grechishkino', 2100013: 'Akhunbabaev (dzhalalkuduxky Rayon)', 1000948: 'Prokopyevskaya', 1702767: 'Afonkino', 1146000: 'Leninsk', 1136576: 'Ramenskoe', 1702766: 'Ledenevo', 13029: 'Semichny', 1507419: 'Yasenov', 1147226: 'Uralsk', 1515398: 'Tarasa Shevchenko', 1968780: '?', 1097351: 'Shadki', 1025471: 'Novotroitsky', 1512871: 'Sokologornoe', 1077852: 'Yasny', 3809309: '?', 1926858: '?', 1967560: '?', 1130969: 'Maysky', 1702517: 'Olginka', 1135464: '?', 4512522: 'San Sebastián', 1142966: 'Tulaga', 1140961: 'Gorevo', 1049181: 'Timiryazevsky', 1151827: 'Sad Ptitsefabriki', 11156: 'Yulovsky', 21898: 'Valikhanovo', 1700777: 'Altynemel', 15465: '?', 1131109: 'Andryushkino', 1701040: 'Barshatas', 1944433: '?', 2206198: '?', 1917184: '?', 10658: 'Kyusyur', 6852: 'Verbovy Log', 2208554: 'Estevan', 1504515: 'Nikolaevka', 2203139: '?', 1147575: 'Gai', 1143335: 'Kostyanka', 1146056: 'Druzhino', 1007251: 'Axakovo', 1951468: 'Kocaeli İli', 1144924: 'Uguy', 1600478: 'Bakuny Pervye', 5033798: 'Athol', 1008021: 'Kozhay-Semenovka', 1514943: 'Ozeryany', 1010283: 'Bolshebykovo', 1970391: '?', 4272959: 'São Miguel', 1518589: 'Karaturyk', 1502351: 'Kapulovka', 14749: 'Goryanovo Novoe', 1108855: 'Pushkino', 1099814: 'Zavolzhsky', 1507900: 'Navaria', 1043128: 'Uspenka', 3134162: 'Jezzîne', 1059009: 'Serpukhov-14', 1504859: 'Banovka', 6904: 'Samoylovo', 1518576: 'Palvantash (markhamatsky Rayon)', 1516267: '?', 1943086: '?', 1951379: 'Whitstable', 1910750: '?', 2200961: 'Pemzashen', 1969571: '?', 5459115: 'Kopische', 1081757: 'Lgovo', 2202680: 'Mühldorf am Inn', 1045597: 'Kanarshino', 2300664: '?', 3050445: 'Fallujah', 1932816: '?', 2204964: 'Horsens', 1152900: 'Dubki', 1089321: 'Vorony', 2208645: '?', 1077796: 'Kirov', 1029297: 'Kandaurovo', 2206660: 'Biała Podlaska', 2202384: '?', 1089233: 'Strigino', 2204116: '?', 17267: 'Gryady', 1902793: 'Monza', 1970712: '?', 1510009: 'Abazovka', 1124646: 'Sayany', 4539017: 'Suzzara', 1160198: 'Yubileyny', 1005529: 'Kaga', 1122788: 'Zimino', 1137172: 'Ubalino', -1088110: -1088110, 1973472: '?', 4435848: 'Igny', 1005317: 'Seytyakovo', 1112218: 'Zheltinsky', 1063469: 'Klin (gorsky S/s)', 1080042: 'Dudarevsky', 1124597: 'Enkhe Tala', 2208755: 'Montauban', 1916299: '?', 1094758: 'Ursala', 1052210: 'Sabancheevo', 1085269: 'Raskatovo', 1152772: 'Salskoe', 1127972: 'Svetly', 1138229: 'Kyzylbay', 1106151: 'Pervomaysky', 1924934: '?', 1133747: 'Shestakovo', 1957058: 'Vamdrup', 1509207: 'Stavrovo', 1700439: 'Uil', 1146450: 'Tuy', 1115265: 'Novoe Atlashevo', 1114319: 'Alaxary', 2206114: '?', 1040913: 'Novoe Selo', 2203765: '?', 1137163: 'Mir', 1111462: 'Tomylovo', 1144310: 'Rozhdestvenka', 1509185: 'Nestoyta', 1944343: '?', 14922: 'Baltiysky', 1127495: 'Volochaevka-2', 2205067: '?', 2208227: '?', 1509463: 'Nikolaevka', 1518581: 'Bakhar', 2208171: '?', 2208669: '?', 1084718: 'Klyuchi', 1111227: 'Pavlovka', 1157927: 'Krasny Yar', 1707253: '?', 1123618: 'Chigiri', 1600041: 'Stolovichi', 1962089: '?', 2208521: '?', 1942783: '?', 1104116: 'Krutitsy', 1010323: 'Nizhnyaya Pokrovka', 1140769: 'Mukhoedovo', 1514386: 'Cherpovody', 2206523: '?', 14870: '?', 1912363: '?', 1701092: 'Tarkhanka', 1512373: 'Oskol / Chervony Oskol', 1504479: 'Iza', 1514676: 'Ivanovtsy', 1122826: 'Stepnoe', 1937692: '?', 1073079: 'Rublevka', 1159629: 'Vershino-Bidzha', 2204648: '?', 1916326: '?', 1024763: 'Novokharkovka', 1909389: '?', 1909007: '?', 1507659: 'Smerekov', 1708246: '?', 2608694: '?', 1506953: 'Ordzhonikidze', 4922318: 'Cooper City', 1705771: 'Nibe', 1514526: 'Maryanovka', 1966079: '?', 1509091: 'Mirnoe', 1966390: '?', 2201736: '?', 1903497: '?', 1049033: 'Khvorostyanka', 1038712: 'Khalaburdikha', 1714099: 'Garciems', 1702067: 'Frunze', 1136976: 'Balay', 5259835: 'Jessen (Elster)', 2208711: '?', 2208979: 'Bátaszék', 1153628: 'Kirov', 1602294: 'Leshnitsa', 1928837: 'Grobiņa', 1091895: 'Andrey-Kurgan', 1123027: 'Suzop', 1124683: 'Talovka', 1125637: 'Tasinsky Bor', 1156481: 'Sayga', 1147410: 'Toxkoe', 2205477: '?', 1710852: '?', 1091859: 'Levokumka', 1958937: '?', 1966821: '?', 1514905: 'Golinka', 1024847: 'Uryv-Pokrovka', 1040909: 'Kuban', 4912682: 'South Park Estates', 1081492: 'Aleshnya', 5056781: 'Bellmore', 1132485: 'Ezhovo', 2203307: '?', 1512602: 'Katerinovka', 1926803: '?', 1502350: 'Kamenskoe', 1935609: 'Edmonds', 2000721: 'Vel', 1502736: 'Rodniki', 1973679: '?', 1974447: '?', 1107658: 'Gremyachee', 1010751: 'Novoalexandrovka', 1902950: 'Bautzen', 1079434: 'Dalnee Pole', 1501452: 'Mazurovka', 5429692: 'Volovel', 1713276: 'Washington', 1093447: 'Verkhnespasskoe', 1117444: 'Rodniki', 1502281: 'Pokrovka', 1936878: '?', 1139533: 'Petushikha', 1913321: '?', 1923278: '?', 5062165: 'Sheldon Center', 1922240: 'Jendouba', 5103685: 'Weed', 1918190: '?', 1919967: 'Shakopee', 1971464: '?', 1943078: '?', 1039461: 'Karpovo', 1512500: 'Bunakovo', 1949748: 'Clermont', 1940585: '?', 1124232: 'Elan', 4649: 'Nacogdoches', 1939084: '?', 1710416: 'Cocoa', 5022504: 'Asbury Park', 1918264: 'Asbury Park', 1129014: 'Nikolaevka', 1153161: 'Kamenushka', 17658: 'Pinchuga', 2203735: '?', 2203302: '?', 1100463: 'Selikhovo', 1967158: '?', 5128273: 'Pointe-Claire', 1127616: 'Klyuchi-Bulak', 1139287: 'Rustay (ostankinsky S/s)', 1929852: '?', 1920140: 'Swampscott', 1137130: 'Poligus', 1709279: 'Whippany', 5056072: 'Succasunna', 1129032: 'Puschino', 1128690: 'Bolshaya Elan', 1114052: 'Russkaya Sorma', 3994328: '?', 1925223: 'Springfield', 1956566: 'Proletarsk', 1091552: 'Novoulyanovsky', 7537: 'Dover', 1917603: 'Arax (armavirsky Rayon)', 18699: 'Ulan-Gorkhon', 1137362: 'Tamakulskoe', 1137733: 'Tsentralnoe', 1915580: '?', 2209105: '?', 1512502: 'Elizavetovka', 1973064: '?', 21542: 'Bayserke', 1701635: 'Karasu', 1136090: 'Kochergino', 1702045: 'Milyutinka', 1083354: 'Kabanovka', 1924884: '?', 1501250: 'Poborka', 1156604: 'Kopylovka', 4966710: 'Gainesville', 1506096: 'Pereyaslavskoe', 1014104: 'Krasnoselets', 1042171: 'Topoli', 4125102: 'Fimbo Paliba', 1159663: 'Uybat', 1087438: 'Ivanovo (derevnya)', 1511851: 'Zolotniki', 1969371: '?', 1504853: 'Stepanovka Pervaya', 1061564: 'Kukuevo', 1971478: '?', 1137348: 'Olkhovka', 1135895: 'Kurkino', 1912387: 'Bischofshofen', 4477534: 'Mikulov', 1117089: 'Semlovo', 1104712: 'Sukromlya', 1512327: 'Chemuzhovka', 5267890: 'Garching bei München', 1161087: 'Indiga', 2628: 'Staromelovaya', 1505061: 'Zadnestryanskoe', 1105263: 'Msta', 5364483: 'Amaliada', 1506693: 'Sosnovka', 1139474: 'Bogorodskoe', 1051134: 'Malaya Rechka', 1057979: 'Tsarevo', 1079274: 'Krivov', 1512023: 'Prishib', 1045400: 'Mozolevo-1', 1118174: 'Dievo-Gorodische', 5103962: 'Mead', 1009031: 'Novokutovo', 1504522: 'Staropetrovka', 1955798: '?', 1514715: 'Luzhany', 1069892: 'Usvyaty', 1500474: 'Novoandreevka', 1041538: 'Tsukerova Balka', 1041385: 'Neberdzhaevskaya', 18698: '?', 1009515: 'Golovino', 1103745: 'Rameshki', 1514514: 'Burty', 1512910: 'Chernomorskoe', 1912586: '?', 1002496: 'Petarikha', 1969428: '?', 1968577: '?', 1502438: 'Elizavetovka', 1502441: 'Loboykovka', 1514892: 'Shilovtsy', 1111821: 'Krasny Gulyay', 1947873: 'Chaux', 1084376: 'Alexeevka', 1059769: 'Lyubuchany', 1109963: 'Sholya', 1091885: 'Sunzha', 1147870: 'Ora', 1059503: 'Yartsevo', 1505447: 'Spas', 1011155: 'Krasny Kolodets', 19236: 'Trostye', 752: 'Norderstedt', 1018890: 'Bushuikha (derevnya)', 1600957: 'Voronichi', 1502152: 'Dobrovolye', 1098635: 'Strakunovo', 1514537: 'Tovmach', 1917074: '?', 1121778: 'Cheposh', 1001082: 'Topsa', 1006961: 'Uyandykovo', 5264125: 'Neuhausen auf den Fildern', 5266759: 'Schwetzingen', 1056223: 'Gidrouzel', 1126499: 'Ivanovo (derevnya)', 1518476: 'Osterode am Harz', 1937874: 'Mickūnai', 1511530: 'Nirkov', 2300657: '?', 5261138: 'Drebber', 1603279: 'Vyazye', 1505143: 'Lolin', 1052218: 'Tetyushi', 1088443: 'Krasny', 1140796: 'Tepelevo', 1702611: 'Voskhodskoe', 1926388: '?', 1059821: 'Stolbovaya-2', 17016: 'Baga-Burul', 1080852: 'Neznanovo', 1800216: 'Varnitsa', 1704912: 'Altenholz', 1147257: 'Sablino', 1002849: 'Koryakino', 1507536: 'Snyatinka', 1010258: 'Novoukolovo', 1118229: 'Kuvakino', 4158118: 'Bongor', 1505842: 'Lobachov', 2001429: '?', 4235600: 'Kirkham', 1157441: 'Zarechny', 1965044: 'Lizums', 1502829: 'Krasnovka', 1922482: 'Edgartown', 1907492: '?', 1709123: '?', 2202165: '?', 1085274: 'Stepnoe', 1513873: 'Lenkovtsy', 1973595: 'Rukla', 1022576: 'Zarubino', 1974339: '?', 1912012: '?', 1913993: '?', 5051363: 'East Omaha', 1081381: 'Oktyabrskoe', 1708487: 'Temple', 2201261: '?', 1136849: 'Surgutikha', 1005332: 'Tutagachevo', 2204435: '?', 1041680: 'Kirova', 1964745: '?', 1079892: 'Olshanka', 1971455: '?', 1056412: 'Semenovskoe', 11672: 'Trujillo', 4750: 'Gornoe', 1601338: 'Dubetskoe', 1024830: 'Pokrovka', 1038790: 'Oktyabrsky', 1514311: 'Tashlik', 1012443: 'Kokino', 1919775: 'Rockville Centre', 1505799: 'Yatski', 1706032: '?', 3874: 'Palm Beach Gardens', 1513891: 'Khutor', 4696592: 'Turks and Caicos Islands', 3413055: 'Nābarhu', 4281511: 'Tongeren', 4691685: 'Holguín', 5470324: 'Narazeni', 2206786: '?', 1711180: 'Dobbs Ferry', 2209468: 'Pelham', 1915572: '?', 2206292: '?', 21533: 'Richmond', 1962791: '?', 2204804: '?', 2206948: '?', 1123808: 'Putyatino', 16147: 'Anga', 1094667: 'Yukhmachi', 2209497: '?', 1700169: 'Novokienka', 1049042: 'Borisovka', 4447965: 'Carcès', 1127910: 'Goryachy Klyuch', 1709651: '?', 1964820: 'صڮڬڼڪڣڵڲڝ&', 1077206: 'Motygino', 1018189: 'Ogarkovo', 1018069: 'Maysky', 1154878: 'Gorny Schit', 1138470: 'Glukhariny', 1087251: 'Schekino', 2101243: 'Andizhani', 1083837: 'Stary Amanak', 1085995: 'Rozovoe', 1602874: 'Shashki', 1967010: '?', 1025410: '2-Go Uchastka Instituta Im Dokuchaeva', 1159185: 'Shelekhovo', 1158741: 'Dunday', 1158777: 'Kharagun', 1947857: 'Hergiswil', 1145389: 'Omar', 1955266: '?', 1509199: 'Dovzhanka', 1155186: 'Karpushikha', 1602882: 'Deschenka', 1157595: 'Churtan', 1157557: 'Dostovalovo', 1961355: 'Pureņi', 19516: 'Otradnoe', 5267214: 'Berchtesgaden', 1700631: 'Saymasay', 1500371: 'Ogni', 1964835: '?', 1967269: '?', 1009489: 'Cherepov', 5422696: 'Ilino-Zaborskoe', 2203610: '?', 2209343: '?', 1065001: 'Stolbische', 1097089: 'Kuralovo', 1112490: 'Spassky', 1015689: 'Pristenovsky', 1507207: 'Mostki', 1135736: 'Tumakovo', 1504565: 'Zeleny Gai', 1504560: 'Gogolevka', 21948: 'Pato Branco', 1964933: '?', 2204423: '?', 21935: 'Lillestrøm', 1102649: 'Kushalino', 1078496: 'Verkhnemakeevka', 1041787: 'Malotenginskaya', 1041825: 'Krasnopartizanskoe', 1123495: 'Bon', 5261644: 'Wietmarschen', 1503577: 'Vaskovichi', 1953177: '?', 13193: '?', 1602893: 'Ozero', 3344894: 'Kathu', 1085057: 'Chikhachevka', 1507191: 'Mikhaylovka', 1153373: 'Syagannakh', 3562: 'Prigorskoe', 1918248: 'Tenby', 2204645: '?', 1516668: '?', 1945103: '?', 1069711: 'Lipets', 1936081: '?', 1502157: 'Manvelovka', 1975020: '?', 1501652: 'Sosnina', 1948657: '?', 1128392: 'Solontsy', 5267695: 'Bischofsheim an der Rhön', 1942997: '?', 1036891: 'Lovlya', 4327: 'Dartford', 1942488: '?', 1161062: 'Salemal', 2200640: 'Sarchapet', 1930350: '?', 2209658: '?', 2209659: '?', 1034315: 'Gremyachevo', 1509366: 'Plakhteevka', 9965: 'Dharamsal', 1702055: 'Livanovka', 1943406: 'Arakich', 1714664: '?', 1601661: 'Beloe Boloto', 1501779: 'Starye Koshary', 1913717: 'Kelmis', 1976080: '?', 1135490: 'Podgornoe', 1147837: 'Podgorodnyaya Pokrovka', 1513334: 'Balin', 1056897: 'Sharapovo', 1056802: 'Pervomayskoe', 1056848: 'Svitino', 1948530: '?', 1920850: '?', 1149030: 'Sepych', 4611584: 'Kuito', 1010303: 'Kalinovo', 1090850: 'Pustoshka', 1936022: '?', 1509955: 'Sukhaya Mayachka', 2209726: '?', 1913222: '?', 2001572: '?', 1068494: 'Plan', 1140389: 'Ivanovo (timiryazevsky S/s)', 1912437: '?', 1963245: '?', 5090921: 'East Irvine', 1041664: 'Shedok', 1138567: 'Kotovka', 1147771: 'Uranbash', 1042958: 'Matveevka', 1109725: 'Kamennoe', 1002367: 'Nizha', 1052450: 'Zubovo-Polyanskoe Lesn-Vo', 2206174: '?', 2000742: 'Shyuryuk', 1700236: 'Zhanteke', 1960276: '?', 1009986: 'Kalinin', 1900619: 'Hagoshrim', 1095922: 'Bolshie Karmaly', 1109784: 'Sredny Postol', 1105417: 'Novonikolsk', 1601242: 'Potapovka', 1025583: 'Semidesyatnoe', 1094095: 'Moiseevo-Alabushka', 1015867: 'Novoe Lukino', 1156480: 'Rybinsk (poselok)', 22571: 'San Marcos', 1059035: 'Sharapova Okhota', 1710587: 'Council Bluffs', 5330637: 'Slyuda', 20454: 'Nizhny Burluk', 1083979: 'Nizhnee Sancheleevo', 1503180: 'Cherkasskoe', 1010702: 'Rakityansky', 4062924: 'Koforidua', 1126624: 'Dubrovo', 1505328: 'Shepot', 1098760: 'Gornyak', 1500009: 'Maly Mayak', 4355561: 'Leinach', 1503658: 'Stepanovka', 1068307: 'Malaya Serdoba', 1146179: 'Krasnogorka', 1714940: '?', 1012967: 'Sochilovo', 2207836: '?', 2608896: 'Adams', 1129037: 'Ichinsky', 1601289: 'Bolshevik', 9259: 'Palevitsy', 1803374: 'Antsla', 2203494: '?', 1500251: 'Perekop', 7072: 'Urukhskaya', 1921782: 'Portofino', 1504525: 'Chervonoe Pole', 1920548: 'Warren', 1078330: 'Mokry Gashun', 1714442: 'Ebeltoft', 1507589: 'Otinevichi', 1972929: '?', 4670341: 'Philipsburg', 1512393: 'Novaya Parafievka', 3964719: 'Datong', 1923356: '?', 1503728: 'Bazar', 1949436: 'Saloglu', 1703587: 'Alès', 1160275: 'Amazar', 1040955: 'Aderbievka', 1969590: 'Fuengirola', 1901036: 'Shelomi', 1921316: '?', 1124056: 'Ignashino', 3823121: 'Daecheon', 1138: 'Lewiston', 1002223: 'Rechka', 1515973: 'Ognevka', 1706437: 'Yakovlevichi', 1122356: 'Bystryanka', 1129656: 'Kotino', 1706795: 'San Clemente', 1702070: 'Beloglinka', 1145436: 'Osokino', 15197: 'Bernovo', 1079201: 'Nikolaevka', 1919876: '?', 1508762: 'Romanova Balka', 1067946: 'Andreevka', 5423688: 'Konstantinovka', 2205962: '?', 3294128: 'Gołdap', 1135518: 'Yuzhakovo', 1146416: 'Martyushevo', 1134903: 'Preobrazhenka', 1157629: 'Medvedevo', 1045725: 'Selo', 1701131: 'Nikolsk', 2204732: '?', 1154309: 'Nezevay', 1506723: 'Popelnastoe', 1109711: 'Golyany', 1512367: 'Kramarovka', 1147530: 'Andreevka', 1970850: '?', 1090802: 'Kolchugino', 1702227: 'Kostryakovka', 1054576: 'Novy', 1906130: '?', 1123496: 'Borzya', 1510714: 'Novaya Lyubomirka', 1512372: 'Studenok', 2208752: '?', 1024383: 'Kasyanovka', 1507960: 'Tetevchitsy', 1506731: 'Sharovka', 1917479: '?', 1707258: 'Antofagasta', 1505296: 'Verbovets', 1921412: '?', 1714455: '?', 1512966: 'Kamenka', 2200883: 'Ashotsk', 1713824: 'Grand Canyon', 1600966: 'Zakharnichi', 4230030: 'Tetford', 1121762: 'Askat', 1081977: 'Mordovo', 22387: 'Angermünde', 1504571: 'Novoivanovka', 1507027: 'Orekhovka', 1077211: 'Nischa', 1503211: 'Razdolnoe', 1025549: 'Tyumenevka', 1100952: 'Lykoshino', 1602906: 'Rudnya', 1092215: 'Pervomaysky', 1934861: '?', 1034116: 'Sennaya', 1513040: 'Mayachka', 2210149: '?', 1976847: '?', 1031611: 'Lyublino', 1011411: 'Sosnovka', 1033903: 'Kochubeevka', 2203546: '?', 1042406: 'Kommunar (poselok)', 1918507: 'Ardeen', 1114265: 'Buguyan', 10560: 'Erzovka', 1513659: 'Tsvetokha', 1086329: 'Tsrau', 1141728: 'Yasentsy', 1146867: 'Zhdanovka', 1005821: 'Prishib', 1973236: '?', 1041457: 'Stepnoy', 1148223: 'Sekretarka', 1504613: 'Verkhnyaya Tersa', 1010958: 'Kupino', 1975690: '?', 2210191: '?', 1091977: 'Donskaya Balka', 1036816: 'Podelsk', 1504591: 'Kuprianovka', 1919801: 'Saint Benedict', 14566: 'Lyubimovka', 1512187: 'Khatnoe', 1137381: 'Krugloe', 1144815: 'Razlivy', 1084832: 'Berezovaya Luka', 1934280: '?', 1030830: 'Gorlovka', 1505588: 'Lekhnovka', 1976828: '?', 1966167: '?', 17190: 'Cooma', 1083179: 'Kurumoch', 1005657: 'Novomikhaylovsky', 2100267: 'Kavalyamakhmud', 1601096: 'Slaveni', 1907124: '?', 2205349: '?', 1112350: 'Ilek', 1044280: 'Fonov', 1054187: 'Sinkovo', 1004596: 'Zelenaya Polyana', 1958769: '?', 1500862: 'Lyulintsy', 1500872: 'Uladovskoe', 1014004: 'Robchik', 1700533: 'Akzhar', 1506923: 'Novotoshkovskoe', 1145541: 'Kiterma', 1111489: 'Vyry', 1153615: 'Nizhnekolymsky', 5008982: 'Berryville', 1511785: 'Krivoe', 1975036: '?', 3857434: 'Suzhou', 1956248: '?', 1025513: 'Bratki', 5264789: 'Stetten am kalten Markt', 2211322: '?', 1714410: 'Spiez', 4243374: 'Uzwil', 1045009: 'Znamenka-1', 1960253: '?', 5266392: 'Netphen', 4367614: 'Herdorf', 5261844: 'Neunkirchen (Siegerland)', 1974642: '?', 5328088: 'Gołdap', 1919955: '?', 1080561: 'Vikulovo', 1939605: '?', 1113875: 'Mesker-Yurt', 2210326: '?', 1973542: '?', 4232353: 'Portsmouth', 5260637: 'Westerrönfeld', 1924124: '?', 1519040: 'Nivelles', 1601707: 'Bolshie Strelki', 1922761: 'Amherst', 1092139: 'Vyazniki', 1510629: 'Milyatin', 2210348: '?', 1025315: 'Staraya Kalitva', 1026138: 'Khubar', 1076049: 'Alol', 1022689: 'Nizhne-Kubensky', 1500347: 'Ostrovskoe', 1506148: 'Teleshovka', 1117953: 'Mirnaya', 1054085: 'Mukhanki', 2001238: '?', 1027009: 'Amuschi Bolshoe', 2001205: '?', 1962884: '?', 2207667: '?', 1967000: '?', 1112226: 'Navarinka', 1148617: 'Tyundyuk', 1034205: 'Dolgoe', 1600427: 'Bobrik', 1060354: 'Kitsa', 1059288: 'Batayki', 1123869: 'Pokrovka', 1802202: '?', 1094662: 'Chuvashsky Brod', 1153537: 'Yaroslavsky', 2210446: '?', 1510772: 'Klesov', 1700397: 'Poltavka', 1122768: 'Nikolaevka', 1099389: 'Kholm', 1500005: 'Zaprudnoe', 1100255: 'Unitsy', 1053146: 'Novoe Akshino', 1012802: 'Zamishevo', 1702850: 'Telzhan (tolbukhinskoe)', 1004426: 'Karavannoe', 1123891: 'Shiroky', 1513588: 'Shebutintsy', 1128890: 'Sayanskoe', 2102511: '?', 1936428: '?', 1091581: 'Tuguluk', 1091706: 'Georgievskaya', 1501210: 'Novofastov', 1929250: '?', 1124511: 'Ust-Orot', 4227292: 'Bækmarksbro', 1143595: 'Novochanovskoe', 1513954: 'Bezborodki', 2208860: '?', 1503488: 'Berezovka', 1081043: 'Goldino', 1602403: 'Borovoe', 1514467: 'Subbotov', 5266973: 'Neutraubling', 1061072: 'Priozerny', 1093372: 'Baylovka 2-Ya', 2203359: '?', 3890345: 'Zhangjiajie', 1511174: 'Glinsk', 1110247: 'Pervomaysky', 1109966: 'Arzamastsevo', 1110570: 'Nechkino', 1513059: 'Krasnoe', 1801268: 'Sofia', 1004828: 'Maxim Gorky', 1971355: '?', 1097372: 'Lagerka', 1112004: 'Skugareevka', 1953239: '?', 1008928: 'Tenyaevo', 1502648: 'Babaykovka', 1010149: 'Koshmanovka', 1940791: '?', 2546: '?', 1970041: '?', 1939663: '?', 1111634: 'Kurmaevka', 1111628: 'Klyuchiki', 2002077: '?', 1919649: '?', 5470321: 'Chkaduashi', 5256186: 'Wegberg', 1160115: 'Abagaytuy', 1122412: 'Ust-Kozlukha', 1514347: 'Apolyanka', 1049833: 'Podgornoe', 1049814: 'Lenino', 1000378: 'Lodeynoe', 1084130: 'Ozerki', 1905084: '?', 2210578: '?', 1942496: '?', 2209128: '?', 1122242: 'Shubenka', 1158473: 'Novy Tap', 1701800: 'Taldybulak', 1962241: '?', 9688: '?', 1972649: '?', 1113677: 'N-Kurchali', 1515964: 'Cosenza', 1515192: 'Kladkovka', 1012405: 'Arkino (stantsia)', 2210616: '?', 1039730: 'Pritykino', 1144763: 'Zavyalovo', 1017623: 'Abramovo', 5039352: 'Bay City', 1939156: '?', 1974240: '?', 1150508: 'Vypolzovo', 1969877: '?', 1511866: 'Ostrovets', 1012767: 'Sinezerki', 1509067: 'Larzhanka', 1511318: 'Obrazheevka', 1512949: 'Mirnoe', 1129389: 'Kharkov Log', 1078279: 'Svetlorechnoe', 2206511: '?', 1702054: 'Altynsarino', 1065055: 'Kudinovo', 2205868: 'Kitee', 2204651: '?', 1033843: 'Yubileyny', 1158545: 'Dubrovnoe', 2100917: 'Iskovut (papsky Rayon)', 1024559: 'Kuchugury', 10854: 'Oshminskoe', 1136610: 'Irsha', 3262583: 'Drama', 1969400: '?', 1046306: 'Zverevo', 1072728: 'Balakhi', 1007041: 'Timashevka', 5313222: 'Huwei', 1506708: 'Alexandriyskoe / Dimitrovo', 1054201: 'Stupino', 2001264: '?', 1702050: 'Yrsay', 2206176: '?', 1062112: 'Borok', 1929564: '?', 1962950: '?', 1602776: 'Dinarovka', 1602778: 'Zhazhelka', 1948804: 'Tomaszów Lubelski', 1140052: 'Zadvorka', 2204880: '?', 1502440: 'Kurilovka', 1920321: 'Troy', 1700994: 'Enbekshi', 1031963: 'Mogata', 1919541: '?', 1800978: 'Novy Korten', 1054185: 'Semenovskoe', 4496916: 'Margonin', 1077880: 'Ilinka', 2210162: '?', 1112109: 'Verkhnie Timersyany', 1701931: 'Akzhal', 1961033: '?', 1511422: 'Tsigany', 1941228: '?', 1024223: 'Vasilyevka', 1081206: 'Borisovka', 1083410: 'Krasnosamarskoe', 1086465: 'Tmenikau', 1513614: 'Berezdov', 1513641: 'Mirutin', 1965130: '?', 1508126: 'Bukovaya', 1974615: '?', 1160682: 'Vostochny', 1054721: 'Kozlovka', 1960558: '?', 5070090: 'Corry', 1006582: 'Spartak', 1974504: '?', 1917790: '?', 5421257: 'Ile-Ife', 1054182: 'Selivanovo', 2202275: '?', 1975189: '?', 1084947: 'Mokhovoe', 1079313: 'Zaplavskaya', 2210866: '?', 1902080: 'Keene', 3133434: 'Rayak', 1153603: 'Kharyyalakh', 1141440: 'Neverovo', 1503914: 'Pochuyki', 1504734: 'Burchak', 1503965: 'Belilovka', 1703059: 'Birinshi Mamyr (pervomaevka)', 1138875: 'Oxky', 5101570: 'Nazareth', 1504186: 'Podvinogradov', 1502015: 'Dorosini', 1092482: 'Krasivka', 1706910: 'Marysville', 1149121: 'Seyva', 1908908: '?', 1911280: 'Abeliani', 1502274: 'Kudashevka', 1515460: 'Savintsy', 2206911: '?', 1094904: 'Nizhnie Meteski', 1094861: 'Verkhnie Meteski', 1512704: 'Semenovka', 1040762: 'Kubanskaya', 1951550: '?', 1094166: 'Olkhovka', 1066489: 'Zarya', 1969846: '?', 1155102: 'Travyanskoe', 1040855: 'Komsomolsky', 1501976: 'Gorniki', 1129108: 'Permyaki', 1942008: 'Walbay', 1051657: 'Kuyankovo', 11614: 'Giri', 1600761: 'Kabische', 1007280: 'Ibragimovo', 1158827: 'Bilchir', 1128834: 'Verkhnyaya Iret', 1700964: 'Karaton', 1014150: 'Vertyachy', 2608758: 'Verdun', 2201586: '?', 1961154: '?', 5448310: 'Boltiniki', 1048268: 'Bor', 2204686: '?', 1095876: 'Malye Memi', 1904677: '?', 1152394: 'Levy Bizyar', 1014729: 'Kolobovka', 1602572: 'Novoselye', 1912284: '?', 1030031: 'Kolobovo (derevnya)', 3839428: 'Ibaraki', 1078174: 'Obedinenny', 1114261: 'Andreevka', 1030433: 'Baxanenok', 1975167: '?', 1935251: 'Rokytnice nad Jizerou', 1057712: 'Kresty', 1715314: 'Shipka', 2207754: '?', 1084395: 'Kistendey', 4235701: 'Kingswear', 1094941: 'Stary Kyrlay', 1517319: 'Skanderborg', 2211080: '?', 1159970: 'Pyryakh', 1135438: 'Vysokogorsky', 1138747: 'Gumnischi', 1011116: 'Brasovo', 1707896: 'Somerville', 1926332: '?', 1902872: '?', 5432260: 'Loo', 5368729: '?', 1035384: 'Ersakon', 4980234: 'Monterey', 1938827: '?', 1702659: 'Starobelka', 1970223: '?', 1048687: 'Dvurechki', 1156317: 'Roscha', 1513173: 'Zenkov', 1925636: '?', 1506739: 'Kutsevolovka', 1926402: '?', 1903529: '?', 1058896: 'Buturlino', 1070618: 'Bykovo', 2210225: '?', 1113178: 'Chudinovo', 1159429: 'Altay', 5625: '?', 2206177: '?', 1085570: 'Novotulka', 1130618: 'Ozhmegovo', 1906569: 'Sidmouth', 1037340: 'Tobys', 1082352: 'Lakash', 20874: 'Seaside', 1505668: 'Savarka', 1083622: 'Chapaevsky', 1969774: '?', 18648: '?', 1601651: 'Chelyuschevichi', 1513594: 'Velikaya Berezna', 1710954: 'Prievidza', 1512219: 'Reznikovo', 1024285: 'Leskovo', 1512408: 'Shelestovo', 1158102: 'Sumkino', 2400049: 'Zundaga', 1518128: '?', 1078550: 'Sychevka', 14624: 'Mordino', 1064639: 'Fatnevo', 1601129: 'Antopolye', 1501477: 'Popova Greblya / Chervonaya Greblya', 2211264: '?', 1964307: '?', 1144164: 'Orekhov Log', 14985: 'Woodbridge', 1969511: '?', 18634: 'Pobedim', 2201537: '?', 2211311: 'Chatham', 2211312: 'Blenheim', 1113184: 'Borisovka', 1505904: 'Starye Sokoly', 1907038: 'Murphy', 2209116: '?', 5103436: 'Minnesota', 2211325: 'Hudson Bay', 1129123: 'Schebzavod', 1966599: '?', 1130578: 'Badya', 1006096: 'Kashkalevo', 2209709: '?', 1041426: 'Yuzhny', 5060317: 'Medina', 1601867: 'Dotishki', 1159111: 'Sita', 1709774: 'Mill Creek', 1876: '?', 2211359: '?', 1074193: 'Zadrebye', 1930476: '?', 1031873: 'Krasinskoe', 18704: '?', 1139371: 'Valgusy', 1974003: '?', 1152169: 'Shabury', 1080054: 'Kruzhilinsky', 1025012: 'Novobogoroditskoe', 1072197: 'Lyubavets', 2202520: '?', 1967660: '?', 1973466: '?', 1151417: 'Zapolye', 1601135: 'Grinki', 1503709: 'Ksaverov', 1027726: 'Vozdvizhenye', 1033329: 'Plyuskovo', 1124508: 'Orot', 1917733: 'Penzance', 1708164: 'Arbroath', 1041087: 'Morevka', 5266220: 'Baesweiler', 5261799: 'Hopsten', 1504720: 'Polyanovka', 3079088: 'Rizokarpaso', 5062502: 'Spring Valley', 1932278: 'Tönisvorst', 4860: 'Donguz', 1149424: 'Sykulyata', 1518829: '?', 1035461: 'Oktyabrsky', 1514442: 'Khatski', 1153866: 'Mitsulevka', 1963654: '?', 1139545: 'Severny', 1912186: '?', 1507229: 'Biryukovo', 1702637: 'Chagly', 1602022: 'Minoyty', 2207837: '?', 1700010: 'Gusarka', 5259314: 'Strausberg', 5266752: 'Ladenburg', 1083657: 'Kommunarsky', 1147183: 'Troitskoe', 1097432: 'Kutlushkino', 1156030: 'Basmanovskoe', 1136216: '?', 1503817: 'Chizhovka', 1509047: 'Konoplyanoe', 4041456: 'Grândola', 1157906: 'Velizhany', 1035862: 'Velikaya Guba (selo)', 19774: 'Andreevka', 5328008: 'Tököl', 1948123: '?', 1936670: '?', 1709986: 'Chalmette', 14729: 'Emtsa', 2202060: '?', 1946787: 'Garbagnate Milanese', 4068368: 'Tom', 1702194: 'Naberezhnoe', 2211525: '?', 1143396: 'Bolshoe Shirokoe', 1025356: 'Kazinka', 1157814: 'Nikolsky', 1145230: 'Chebakly', 1502766: 'Pereeznoe', 1130544: 'Prokopye', 2208809: '?', 2210153: '?', 1930240: '?', 1501488: 'Ivashkovtsy', 1000732: 'Pavlovskaya', 1513927: 'Sharovka', 1149145: 'Kusye-Alexandrovsky', 1149614: 'Proletarsky', 1149170: 'Shirokovsky', 1141396: 'Shiloksha', 1160885: 'Vostochny Priisk', 1924527: 'Piņķi', 1507501: 'Vinniki', 1972671: '?', 1603058: 'Kamenka', 1903760: '?', 1086321: 'Khudisan', 1138236: 'Mogileva', 1148795: 'Klenovka', 1086430: 'Novy Batakoyurt', 1025874: 'Nizhnee Kazanische', 1905887: 'Cuzco', 2209628: '?', 1130410: 'Lytka', 1138670: 'Lomovka', 1152639: 'Melyukhino', 1502840: 'Petrovka / Petrovskoe', 1905201: '?', 1123299: 'Belovo', 1955462: '?', 1010500: 'Kholki', 1010906: 'Kholki', 1093565: 'Pervomaysky', 2211207: '?', 1508394: 'Privolnoe', -1032: -1032, 1049558: 'Gudalovka', 1504598: 'Mikhaylovka', 1500392: 'Geroyskoe', 1937337: '?', 1974635: '?', 1512047: 'Ivanovka Selo', 2211369: '?', 1962969: '?', 1518306: 'Neuilly-sur-Seine', 2207711: 'Metzingen', 5266744: 'Buchen (Odenwald)', 1509215: 'Chernaya', 1509271: 'Dalnik', 2300873: '?', 1936335: '?', 1021719: 'Prokopyevskaya', 1916392: '?', 1934112: '?', 1967400: '?', 1155900: 'Sedelnikovo', 1159631: 'Domozhakov', 1968868: '?', 2102456: 'Khanka', 1700198: 'Kostychevo', 1701341: 'Asa', 1013855: 'Monastyrische', 1700022: 'Alexandrovka', 1515417: 'Pogoreltsy', 1082421: 'Troitsa', 1122898: 'Bursol', 1127207: 'Seltso', 1122055: 'Malyshev Log', 2602560: 'Rite', 2211822: '?', 1128718: 'Razdolye', 5259279: 'Bexbach', 1505299: 'Kobaki', 1700116: 'Kazgorodok', 1125732: 'Mirny', 1516019: 'Kagoshima', 1135144: '?', 1154440: 'Russkie Karshi', 1960873: '?', 1942728: '?', 1160796: 'Shelopugino', 1015080: 'Rybinka', 1036032: 'Tikhvin Bor', 1014887: 'Solodushino', 1913598: 'Agtaklya', 5266326: 'Höxter', 1503993: 'Rostavitsa', 1503390: 'Romanovka / Radyanskoe', 1092680: 'Zh/d Vodokachka', 1126645: 'Krasnaya Ushna', 1125266: 'Saryevo', 1500930: 'Zhabokrich', 1940853: 'Kozani', 1157743: 'Rassvet', 1603101: 'Barsuki', 1158582: 'Sorokino', 1974526: '?', 1951626: '?', 1084476: 'Ozernoe', 2207717: '?', 1507513: 'Ivana-Franka', 1154543: 'Gagarsky', 2206343: 'Dilbeek', 18385: 'Assen', 2209175: '?', 1916065: 'Sirmione', 1091441: 'Krasnoyarskoe', 5222590: 'Grande-Synthe', 1119123: 'Klin', 1056231: 'Gorki', 1113490: 'Maslovo', 1009924: 'Ivanovskaya Lisitsa', 1701897: 'Ozernoe', 1144520: 'Novolugovoe', 1700755: 'Kaynar', 5266488: 'Weilburg', 1944731: 'Delaware City', 1142173: 'Chudovo', 1062858: 'Chudovo', 1146028: 'Krutaya Gorka', 1506068: 'Peregonovka', 1918633: 'Artsevi', 14308: 'Kentik', 1152301: 'Chepets', 1040679: 'Svetlogorskoe', 1503483: 'Yasnogorod', 1502639: 'Nastasovka', 1024874: 'Gavrilsk', 21723: 'Gif-sur-Yvette', 2889: 'Jouy-en-Josas', 1108757: 'Krapivna', 1153267: 'Sivakovka', 1044463: 'Orlyanka', 2300648: '?', 1135231: 'Yuxeevo', 1159244: 'Aeroport', 1929823: '?', 1973186: '?', 1505352: 'Nazavizov', 1046884: 'Pavlovo', 1507851: 'Kostenov', 1514863: 'Vladichnaya', 1514660: 'Khreschatik', 4914: 'Terechnoe', 2208354: '?', 1703286: 'Saitama-ken', 3840324: 'Ginowan', 1706415: 'Southbury', 1137894: 'Bolshoe Kamennoe', 1122156: 'Verkh-Kamyshenka', 1928683: '?', 1973162: '?', 1126708: 'Babaevo', 1960213: '?', 2209172: '?', 3836093: 'Naha', 1041878: 'Stepnaya', 3829852: 'Cheongju', 1512020: 'Morozovka', 1908406: 'Sassari', 1098476: 'Volosovo', 1508584: 'Kotlyarevo', 1125234: 'Oktyabrskaya', 1972016: '?', 1022031: 'Frolovo', 1041552: 'Gofitskoe', 1154557: 'Kosulino', 1704366: '?', 1124275: 'Zarubino', 1514714: 'Lashkovka', 1065697: 'Otrada', 1971735: '?', 1920600: 'Oakland', 4637902: 'Boulogne Sur Mer', 1971083: 'Middelfart', 1501434: 'Tomashpol', 2100799: 'Zarafshan (khatyrchinsky Rayon)', 5428145: 'Aktau', 2207726: '?', 1601004: 'Dunilovichi', 1139834: 'Uryupino', 2101012: 'Khudoyberdiev', 1135899: 'Motorskoe', 1123405: 'Tulata', 1041058: 'Pervorechenskoe', 1096440: 'Kuzembetyevo', 2211916: 'West New York', 5266277: 'Coesfeld', 2203100: '?', 1700039: 'Novoe', 1961783: '?', 1704005: '?', 1135403: 'Taskino', 1517293: 'Poltavka', 1036350: 'Kroshnozero', 1509375: 'Faraonovka', 1057669: 'Davydovo', 1502455: 'Vasilkovskoe', 1515049: 'Budy', 1709407: 'Batesville', 1023538: 'Driblevo', 1032405: 'Piskovo', 1951936: '?', 2211693: '?', 2211347: '?', 1946034: '?', 1074171: 'Drislivik', 1909440: '?', 1509292: 'Dolinskoe', 1155878: 'Kadnikovo', 1511596: 'Gai-Rostotsky', 1013201: 'Tatischevo', 1708965: '?', 1904959: 'Hofgeismar', 5110792: 'London', 1501530: 'Dovzhok', 1918230: '?', 1058599: 'Iudino', 1515490: 'Alexandrovka', 1143813: 'Dzerzhinsky', 2202059: '?', 4494965: 'Oleśnica', 1049338: 'Kamenka', 1067103: 'Pokhvistnevo', 1023059: 'Domozerovo', 5267707: 'Zeil am Main', 1003058: 'Golova', 1507621: 'Derevnya', 1962391: 'Grodzisk Mazowiecki', 1513561: 'Glebov', 1702831: 'Moskvoretskoe', 2300663: '?', 1902075: 'Delafield', 3185844: 'Bor', 1941292: '?', 1013535: 'Melensk', 1940637: '?', 1704516: 'Chipping Norton', 2201378: '?', 21159: 'Worthing', 1704800: 'Pasco', 2209951: 'Edgewater', 1924470: 'Reisterstown', 2202166: '?', 1509832: 'Vovchik', 1963460: '?', 1093268: 'Volchki', 1151275: 'Kuliki', 1109496: 'Zolotarevo', 1972313: '?', 1148400: 'Kovylyaevka', 14446: 'Belozerny', 1964919: '?', 2300152: 'Bulan-Sogottuu', 1025352: 'Zemlyansk', 1501554: 'Verba', 1501572: 'Stenzharichi', 1135451: 'Kamensk', 1713610: 'Bushey', 3488582: 'Hikkaduwa', 1701300: 'Yuzhnoe', 1001191: 'Kiselevskaya', 5061021: 'Old Brookville', 1950738: '?', 1707812: 'Dassel', 1922037: '?', 1030410: 'Ekazhevo', 1056977: 'Kudinovo', 1004231: 'Tsvetnoe', 1025880: 'Khalimbekaul', 1084090: 'Romanovka', 20633: 'Kryzhino', 1108626: 'Stantsia Skuratovo', 1902524: 'Herentals', 2204991: '?', 1143548: 'Podolsk', 1095648: 'Verkhnie Shipki', 1009300: 'Asavdybash', 1054654: 'Shuvoe', 1914369: '?', 1963393: '?', 1701890: 'Tsentralnoe', 1146128: 'Chernoluchye', 1971837: 'South Pasadena', 1510822: 'Novye Virki', 1052408: 'Starodevichye', 1122593: 'Nikolaevka', 1904827: '?', 2001596: '?', 1122402: 'Kuybyshevo', 2208689: '?', 1714207: 'Chesterfield', 1086353: 'Nikolaevskaya', 2203349: '?', 2211739: 'Oyten', 1967081: '?', 1966761: '?', 1933826: 'Loano', 2300842: '?', 1035512: 'Inzhich-Chukun', 1156747: 'Kuyanovo', 1510001: 'Sasinovka', 1068666: 'Titovo', 1143878: 'Blagodatnoe', 2201000: '?', 1944771: '?', 1924620: 'Clevedon', 1153998: 'Malinovka', 1060172: 'Stepankovo', 1032713: 'Zikeevo (stantsia)', 1046373: 'Ogonki', 1134398: 'Chernovskoe', 1920112: 'Sterling', 1508356: 'Ivanovka', 1803285: 'Sindi (sindi)', 1938278: 'Bridlington', 1937846: 'Altenberge', 1108823: 'Novoogarevsky', 18577: 'Nizhny Burgaltay', 1127362: 'Sima', 1973789: '?', 1507933: 'Byshev', 4255913: 'Nybro', 1903182: '?', 1083396: 'Bugry', 1032415: 'Satinskaya Shkola Pchelovodov', 1958527: '?', 1050684: 'Kuzhmara', 1135113: 'Kritovo', 8676: 'Meschura', 1060410: 'Borisoglebsky', 1514155: 'Mokraya Kaligorka', 5064031: 'Boardman', 5063944: 'Berlin Center', 4559580: 'Mišići', 1001484: 'Temnaya', 1503141: 'Starovarvarovka', 1089043: 'Belik', 4474667: 'Příbram', 1510691: 'Gorodok', 1958949: '?', 1110563: 'Mazunino', 1962854: '?', 1800373: 'Dobrodzhya Veke', 1510987: 'Sennoe', 1130769: 'Sludka', 1109376: 'Nyurdor-Kotya', 1902980: '?', 1067467: 'Druzhny', 1067462: 'Vysokoe', 1131384: 'Pasegovo', 1515008: 'Andreevka', 1138492: 'Im Matrosova', 1157977: 'Vagay', 2205408: '?', 1906131: '?', 1702210: 'Mirolyubovka', 1049787: 'Verbilovo', 2614: 'Dachnoe', 1975099: '?', 1510172: 'Gryakovo', 2207247: '?', 1505089: 'Khokhonov', 1504191: 'Khizha', 1158244: 'Andreevsky', 1024086: 'Donskoy', 1014403: 'Donskoy', 1111686: 'Sredny Santimir', 2209992: '?', 1113320: 'Tominsky', 1121866: 'Tolstaya Dubrova', 1036784: 'Bolshelug', 1966276: '?', 1951940: '?', 5266687: 'Weinsberg', 1008615: 'Tuktagulovo', 2206652: '?', 1713236: '?', 1151205: 'Okulovka', 17951: 'Tomkovichi', 1007002: 'Kalu-Ayry', 1702174: 'Zlatous', 1800471: 'Ivancha', 7267: 'Karaga', 1603075: 'Mikheevka', 1508420: 'Tuzly', 5121420: 'Deadhorse', 1053506: 'Poltevo', 1123285: 'Novoburanovo', 1602550: 'Zagalye', 1161099: 'Nelmin Nos', 1951051: 'Healdsburg', 5459292: 'Dekshnyany', 2209066: '?', 1518966: 'Hartlepool', 1147860: 'Experimentalny', 2202505: '?', 1009495: 'Scherbakovo', 1082601: 'Yasenok', 1006261: 'Sait-Baba', 5420369: '?', 1506118: 'Dibrova', 1700553: 'Ekpendi', 5266881: 'Überlingen', 1512564: 'Troitskoe / Bolshevik', 1704498: 'Yuma County', 4307932: 'Lommel', 1709894: 'Brooklyn Center', 4911681: 'Pennsylvania', 1040277: 'Blagachevo', 4912752: 'Springfield', 2211490: '?', 2609013: '?', 1152718: 'Grazhdanka', 2605201: 'Dzelzava', 1158406: 'Ingalinskoe', 1920631: '?', 1153786: 'Isit', 5225262: 'Vernet-les-Bains', 1063959: 'Migoloschi', 1515558: 'Nizkovka', 5430680: 'Maytobe ', 19899: 'Kiprino', 1111687: 'Srednyaya Yakushka', 1154942: 'Gorki', 1113357: 'Karabanovo', 1121518: 'Borzhigantay', 1124789: 'Tory', 1091509: 'Arkhangelskoe', 15084: 'Sherman Oaks', 2500275: 'Sangtuda', 1147359: 'Urtazym', 1502510: 'Likhovka', 1513515: 'Radostnoe', 1969836: '?', 1057890: 'Bratovschina', 4456125: 'Andreas', 1083988: 'Primorsky', 2608674: '?', 1104269: 'Stepurino', 1513257: 'Ivankovtsy', 2608677: '?', 2001607: '?', 1077825: 'Yantarny', 1942300: '?', 1095: 'Mullingar', 1158866: 'Baytog', 1079848: 'Razdorskaya', 1704410: 'Tsikhisdziri', 1505636: 'Tarasovka', 1067122: 'Trosna', 1514478: 'Velikie Kanevtsy', 1059066: 'Brekhovo', 1802292: 'Dunaföldvár', 1159510: 'Budenovka', 1508026: 'Volosyanka', 2210999: '?', 1905765: '?', 1953948: '?', 1160257: 'Lyubov', 1051369: 'Shinsha', 1051345: 'Sebeusad', 2300594: '?', 1052217: 'Tarasovo', 1958456: '?', 1962294: '?', 1114113: 'Dolgy Ostrov', 1601170: 'Stolitsa', 2202717: 'Jacarilla', 4533931: 'Jevnaker', 1135902: 'Nizhnie Kuryaty', 1965644: '?', 1078789: 'Anastasievka', 1501326: 'Alexandrovka', 1603215: 'Makhovo', 1156211: 'Davydovo', 1601162: 'Luzhki', 1512127: 'Izyumskoe', 1516861: 'Kenesary', 1056651: 'Volchenki', 2205557: '?', 1703924: 'Bloomfield', 2201693: '?', 1702001: 'Timofeevka', 1129735: 'Krasninskoe', 1117589: 'Ivanovo (derevnya)', 12652: 'Chkalovsky', 1146442: 'Souskanovo', 1130027: 'Chulym', 1976015: '?', 1512588: 'Novy Burluk', 1930495: '?', 1508840: 'Nadezhdovka', 1036034: 'Tolvuya', 1603224: 'Veyno', 1092115: 'Krasny Manych', 1925482: 'Wrightsville Beach', 1124123: 'Tutaul', 1123263: 'Naumovka', 1123260: 'Laptev Log', 1935563: 'Wintergreen', 1160908: 'Bystry', 1004471: 'Raznochinovka', 1132174: 'Preobrazhenka', 1088441: 'Krasnaya Gorka', 1508234: 'Strigantsy', 1501386: 'Shpikov', 1919788: 'Roseville', 2206888: '?', 1130284: 'Sorvizhi', 1032818: 'Voskhod', 1709184: 'Albany', 5111414: 'West Salem', 1135465: 'Mayskoe', 1042150: 'Nezaymanovsky', 1123112: 'Shipitsino', 4490990: 'Skoki', 1920395: 'Vermillion', 5339605: 'Milano San Felice', 1505716: 'Mikulichi', 1968356: '?', 1919157: 'Pulaski', 1907186: '?', 1058779: 'Shemetovo', 2211440: '?', 1144087: 'Tselinnoe', 1509783: 'Nedogarki', 13206: 'Boulogne-sur-Mer', 1954133: '?', 2102114: 'Bagdad', 1107686: 'Mirny', 1703767: 'Faenza', 3259477: 'Dolni Chiflik', 1706105: '?', 1967635: '?', 1967703: '?', 1975711: '?', 1052063: 'Zhabino', 1121052: 'Zhabino', 1924752: '?', 1155686: 'Trety Severny', 1973830: '?', 1140812: 'Gorbatovka', 1088598: 'Gorodok', 2201808: '?', 1601963: 'Bakshty', 1123136: 'Kirovsky', 1041518: 'Pervomaysky (poselok)', 10100: 'Zolotinka', 1027159: 'Nakhada', 1153557: 'Tabaga', 1508051: 'Smozhe', 1713470: 'Geelong', 1057846: 'Fabriki Im 1 Maya', 1124097: 'Razdolnoe', 3284988: 'Pińczów', 1502341: 'Slavyanka', 1124321: 'Gorkhon', 1712523: 'Charkhin', 1924203: '?', 1159442: 'Novorossiyskoe', 1725: 'Shiroky Yar', 1020459: 'Krapivino', 1060258: 'Mizinovo', 18189: 'Verkhnyaya Uftyuga', 1912804: '?', 1123450: 'Zerkaly', 1112777: 'Zheleznodorozhny', 1047295: 'Tervenichi', 1516200: 'Signakhi', 1029708: 'Stupino', 1068144: 'Elyuzan', 2202084: '?', 1500304: 'Zorkino', 1024486: 'Liskinskoe', 1039335: 'Kozmodemyan', 1110672: 'Akilovo', 1927423: 'Kotor', 1701832: 'Egendybulak', 3823001: '?', 1508920: 'Belenkoe', 4527935: 'Aranda de Duero', 1152333: 'Bogorodsk', 2207129: '?', 4547209: 'Desenzano', 2608616: '?', 5261173: 'Brüggen', 1129410: 'Kalininsky', 1137366: 'Shirokovskoe', 1067620: 'Pushanino', 1506048: 'Shandra', 1032680: 'Chernysheno', 1079852: 'Ust-Bystryanskaya', 1600719: 'Zalesye', 4921281: 'Seaford', 1101833: 'Mozhayka', 1147694: 'Platovka', 1707183: 'Askersund', 1135794: 'Talazhanka', 4368047: 'Heitersheim', 1068282: 'Staraya Stepanovka', 1969613: 'Talin', 1056996: 'Novye Doma', 1041717: 'Vpered', 1943155: '?', 1014275: 'Nabat', 2718648: 'Butrimonys', 1048636: 'Naberezhanskie Vyselki', 1958483: '?', 1010330: 'Palatovo', 1156404: 'Bolshedorokhovo', 1601061: 'Moshkany', 1501450: 'Gontovka', 1156301: 'Kolpakovka', 1157399: 'Uktuz', 1518176: 'Schlotheim', 1129068: 'Rudnichny', 1129372: 'Panfilovo', 1908396: '?', 1143852: 'Sovetsky', 1505936: 'Novoselki', 1136635: '?', 1505240: 'Knyazhdvor', 2500002: '50 Let Tadzhikistana', 1920280: 'Viterbo', 1031945: 'Umantsevo', 1503615: 'Beloshitsy / Schorsovka', 1134319: 'Kungur', 1091516: 'Iskra', 1501413: 'Lipyatin', 7115: 'Kazanskaya Archada', 1022914: 'Pokrovskoe', 1955430: 'Pinckney', 1934739: 'Daun', 1909404: 'Mount Pleasant', 1157357: 'Rusakovo', 1013189: 'Setolovo', 2000191: 'Bakikhanov (sabunchi)', 1156460: 'Porotnikovo', 1135179: 'Khrebtovy', 1937204: '?', 1600244: 'Dobromysl', 1513527: 'Verbka', 1602492: 'Dubrovka', 1005993: 'Kapey-Kybau', 1925972: '?', 1092272: 'Osino-Gai', 2001954: '?', 4492934: 'Przeźmierowo', 1971916: '?', 1709793: 'Kamnik', 1037298: 'Korovy Ruchey', 1136834: 'Komsa', 1145758: 'Durnovo', 1047792: 'Pushkino', 1515064: 'Martynovka', 4017724: 'Garoua', 1083677: '?', 1501687: 'Pnevno', 1124531: 'Maysky', 1046192: 'Proba', 1503164: 'Malinovka', 1947319: '?', 1024168: 'Berezovka', 4543858: 'Montesilvano', 1091999: 'Bekeshevskaya', 2210610: '?', 1960351: 'Otrokovice', 5442895: 'Rodnoe', 1702748: 'Zolotaya Niva', 4528092: 'Andoain', 1031028: 'Zaostrovye', 5422067: 'Kaga', 2210917: '?', 1914149: '?', 4735503: 'Barcelona', 1137913: 'Oktyabrskoe', 1063037: 'Vyatka', 1513399: 'Myakoti', 1025518: 'Esipovo', 1083959: 'Verkhnie Belozerki', 1701304: 'Volchanka', 1715289: '?', 2208540: '?', 1963024: '?', 1511499: 'Uvisla', 1803298: 'Kohila', 1142617: 'Yakovskoe', 1975070: 'An Daingean', 1023990: 'Radchenskoe', 1503648: 'Lipniki', 1914502: '?', 1516592: '?', 1510235: 'Malinsk', 2210448: '?', 5266972: 'Hemau', 4378250: 'Eslarn', 15712: 'Novoe Mashezero', 2202997: '?', 4356803: 'Lahr', 1922613: 'Roseland', 1974891: '?', 1502136: 'Tokovskoe', 1909076: '?', 1125363: 'Gorlovka', 1006422: 'Nizhny Absalyam', 5098534: 'Llano Santa Barbara Tract', 1511831: 'Budanov', 1020202: 'Laptyug', 1500882: 'Brodetskoe', 1941717: 'Seydi', 1146837: 'Novomaryevka', 1946370: '?', 1008959: 'Makan', 1000305: 'Dmitrievo', 2206794: 'Novi Pazar', 1506836: 'Bokovo-Platovo', 4911951: 'Preston', 1153685: 'Nalimsk', 4120: 'Ferndale', 1008996: 'Ablay', 1091401: 'Schekino', 1044167: 'Boblovo', 1151522: 'Rozhdestvenskoe', 1112430: 'Krasny Oktyabr', 1104571: 'Mirny', 1127259: 'Berezniki', 3959204: 'Ulan-Tsereg', 1506518: 'Sozonovka', 1701187: 'Preobrazhenka', 1145290: 'Oktyabrskoe', 1514181: 'Komarovka', 1701376: 'Aukatty', 1507230: 'Volodarsk', 5267613: 'Eisenberg (Pfalz)', 1143857: 'Talmenka', 1800301: 'Gidirim', 1048350: 'Melegezhskaya Gorka', 1507953: 'Seredpoltsy', 3178322: 'Būr Safājah', 1969552: '?', 1600117: 'Gantsevichi - Selo', 1047316: 'Shamoksha', 2001585: '?', 1027623: 'Gorodischi', 1158630: 'Ivanicheskoe', 2209074: 'Harbin City', 1509086: 'Desantnoe', 1966135: '?', 5358049: 'Halle (Westfalen)', 1973081: '?', 1124314: 'Tselinny', 1084385: 'Benderovka', 2204701: '?', 1500749: 'Ladyzhinskie Khutory', 1036788: 'Vizyabozh', 1500254: 'Pyatikhatka', 5266633: 'Holzgerlingen', 4977419: 'Cranberry Hill', 1961613: 'Ansonia', 1937924: 'Manaus', 1031879: 'Zurgan', 1105507: 'Dulevo', 1141481: 'Berendeevka', 1140210: 'Kakino', 5125572: 'Hamilton', 1006190: 'Antonovka', 1110679: 'Vaskino', 1500905: 'Ovsyaniki', 1126977: 'Krasny Bogatyr', 1091909: 'Makhmud-Mekteb', 1040823: 'Novolokinskaya', 1505621: 'Malaya Olshanka', 1079807: 'Novorossoshansky', 2722630: 'Neves', 1015057: 'Gurovo', 2207252: '?', 1130060: 'Usmanka', 1944410: '?', 1158864: 'Aluzhina', 1135146: 'Govorkovo', 1015374: 'Nevidimka', 1006718: 'Kananikolskoe', 1138628: 'Balakhonikha', 2300209: 'Taldy-Suu', 5081878: 'Manchester', 1502751: 'Zvanovka', 1501693: 'Rakov Les', 1013749: 'Novy Drokov', 1030934: 'Sokolovka', 1937486: 'Praia da Rocha', 1900987: 'Kfar Tavor', 1907489: '?', 1966765: '?', 1952887: '?', 1040688: 'Erivanskaya', 1035477: 'Beskess', 1035479: 'Damkhurts', 1000076: 'Novosevastopolskoe', 1514048: 'Chizhovka', 2203021: '?', 1072607: 'Rabotino', 1036815: 'Podtybok', 1947791: '?', 3840496: '?', 1051018: 'Mari-Kupta', 1127025: 'Pavlovskaya', 1024542: 'Bor (selo)', 5266525: 'Schwalmstadt', 1024530: 'Troitskoe', 1503602: 'Polesskoe', 2101105: 'Zhaslyk', 1038477: '1 Maya', 1093701: 'Pervye Levye Lamki', 1132478: 'Belorechensk', 1965376: '?', 1930455: '?', 5264550: 'Wehingen', 1942991: '?', 1030390: 'Voznesenskaya', 1976274: '?', 1950644: '?', 1902532: '?', 1902101: 'Kings Point', 1920693: 'Springfield', 1100157: 'Turginovo', 1935517: '?', 5266755: 'Neckargemünd', 1503857: 'Khluplyany', 1503848: 'Pokalov', 5267839: 'Fritzlar', 4189987: 'Aguadulce', 1706895: 'Belleville', 1937696: '?', 15351: 'Khebda', 1512717: 'Zmeevka', 1095209: 'Adav-Tulumbaevo', 1512942: 'Alexandrovka', 1702449: 'Novokuzminka', 1917486: '?', 2300118: 'Toktogul', 1009791: 'Malakeevo', 2209023: '?', 1048722: 'Pribytkovo', 1969195: '?', 1602791: 'Yuryevo', 1155718: 'Krasnoglinny', 1600051: 'Pervomayskaya', 4509436: 'Vigo', 1948721: '?', 1111436: 'Kivat', 2206792: '?', 1035622: 'Panozero', 1600696: 'Mazolovo', 4743405: 'Manaus', 1079251: 'Fedorovka', 1160947: 'Kutopyugan', 1976897: '?', 1512248: 'Tavolzhanka', 1509627: 'Batki', 1970988: '?', 1508341: 'Chernilyavaya', 5421329: 'Nouméa', 1052886: 'Starye Goryashi', 1516748: 'Bergen op Zoom', 1973037: '?', 1137566: 'Listvennaya', 1094808: 'Murzino', 1292: 'Lorient', 5221754: 'Vannes', 1965335: '?', 1076729: 'Zili', 3052: '?', 1920671: 'North Woburn', 1922226: 'Juankoski', 1711304: '?', 2500328: 'Khidzhborak', 1904879: 'Lilongwe', 5327889: 'Paks', 1158870: 'Bozoy', 1023139: 'Kotovo', 1509197: 'Gavinosi', 1503927: 'Velikaya Racha', 1704522: 'Tashlyk', 17203: 'Solnechnoe', 1078889: 'Degtevo', 1714489: '?', 1501307: 'Gnatkov', 1094427: 'Suncheleevo', 1511793: 'Ostapye', 1902304: 'Lisle', 1704480: 'Greeley', 1054455: 'Bobkovo', 1005602: 'Bazlyk', 1147491: 'Novosimbirka', 1124731: 'Tashir', 18705: 'Riverside', 1704986: 'Dordrecht', 1153580: 'Tas-Yuryakh', 1506091: 'Kovalin', 1959262: '?', 1137236: 'Rychkovo', 1024429: 'Dankovo', 1515211: 'Kiselevka', 1124255: 'Shanaga', 1019413: 'Koptelovo', 1007739: 'Staraya Otrada', 1152433: 'Taush', 1052629: 'Smolny', 1959201: '?', 1126228: 'Adino', 1147235: 'Budennovka', 9966: 'Bayangol', 1151344: 'Bereznik', 1703685: '?', 1963710: '?', 2211918: '?', 1078137: 'Prisalsky', 1501491: 'Klekotina', 1508220: 'Mirtyuki', 1148034: 'Zhilgorodok', 2101795: 'Navoi (bayautsky Rayon)', 1964117: '?', 1112893: 'Druzhny', 1976171: 'Svencionys', 1932555: '?', 1036857: 'Rybnitsa', 1505052: 'Viktorov', 1922660: '?', 1901452: '?', 1903602: 'Karlovo', 1905981: '?', 1016684: 'Kuzino', 1128233: 'Kunduy', 1062538: 'Lesnaya', 1919856: 'Bellingham', 1128260: 'Tulyushka', 1129968: 'Treschevsky', 1083304: 'Soxky', 1037253: 'Nizhny Voch', 1514490: 'Likholety', 1137750: 'Zolotoe', 5052817: 'Syracuse', 5460769: 'Budagovo', 1503316: 'Lyubimovka', 1973841: '?', 1921228: '?', 1083824: 'Rysaykino', 1711048: '?', 2206791: '?', 1954675: '?', 1145292: 'Pavlodarovka', 4429720: 'Laval', 4422527: 'Loix', 5257090: 'Severin', 1080185: 'Plakhino', 1940507: '?', 5056037: 'Springfield', 1008534: 'Verkhnetroitskoe', 1073923: 'Olenino', 1974660: '?', 1122320: 'Petukhi', 1124419: 'Ulan-Ivolginsky', 1048491: 'Zhorzhino', 4145579: 'Bakau', 1908612: 'Assonet', 1091802: 'Roschino', 2200715: 'Egvard', 1041043: 'Vorontsovskaya', 1507614: 'Volitsa', 1514326: 'Kobrinovo', 1031931: 'Dogzmakin', 1024036: 'Chigorak', 5430152: 'Beybitshilik', 1507774: 'Rozdol', 1013961: 'Korzhovka', 1704453: '?', 1600047: 'Yamichno', 1600011: 'Milovidy', 1507070: 'Musievka', 1519303: 'Mol', 1714516: 'Heemstede', 4285668: 'Grootebroek', 4283220: 'Noord-Scharwoude', 4282278: 'Santpoort-Noord', 4286331: 'Driehuis', 22680: 'Bolshie Zhukhovichi', 1940399: '?', 4922784: 'Fort Florida', 1036132: 'Interposelok', 1017951: '?', 5267863: 'Rheinfelden (Baden)', 1041631: 'Besleneevskaya', 1510739: 'Dubno', 1921283: 'Annonay', 4984461: 'Yukon', 1508082: 'Ilkovichi', 5470204: 'Pugachevsky 1-J', 1510740: 'Elnoe', 1602274: 'Bogushevichi', 1917588: '?', 1138131: 'Iltyakovo', 1507736: 'Stary Dobrotvor', 1513739: 'Gavrilovka', 1025365: 'Livenka', 1702588: 'Gusakovka', 1935593: '?', 1916340: '?', 1904239: '?', 1969163: '?', 15926: 'Sredny Ikorets', 1918760: '?', 1905326: '?', 14911: 'Derechin', 1926557: '?', 1927618: '?', 1081880: 'Morozovy-Borki', 1043386: 'Mokva 1-Ya', 1931203: 'Gujranwala', 1514355: 'Dmitrushki', 1507439: 'Olesko', 3792366: '?', 4503277: 'Głogów', 1006605: 'Baishevo', 1128099: 'Manzurka', 1503811: 'Tupaltsy', 1008312: 'Burikazgan', 13936: 'Bekherden (bakharly)', 1152738: 'Trudovoe', 1159091: 'Durmin', 1936719: '?', 1601418: 'Dobrogoscha', 1134151: 'Pilyandysh', 1129587: 'Sosnovka', 2206903: '?', 1131704: 'Sodom', 1901605: '?', 1909780: 'Arnstadt', 1931067: 'Kauai County', 1709171: 'Adelphia', 5259351: 'Wittenberge', 1513100: 'Radensk', 1149224: 'Nizhnyaya Barda', 1059451: 'Semenovskoe', 5166710: 'Sant Just Desvern', 5166706: 'Sant Joan Despí', 1602248: 'Rakovichi', 1702834: 'Druzhba', 1085371: 'Osnovnoy', 5266799: 'Achern', 1109192: 'Andreyshur', 1156855: 'Kaltay', 4696402: 'Vieux Fort', 1146495: 'Taychi', 1515405: 'Zhadovo', 1517772: '?', 4002392: 'Mullumbimby', 1900284: 'Gevaram', 1703604: 'Krasnenkoe', 1078173: 'Novorogovskaya', 1097892: 'Knyazhevo', 1156883: 'Malinovka', 5421261: 'Freeport', 1158834: 'Irkhidey', 1146241: 'Tsvetochnoe', 1105932: 'Zhdankovsky', 1711605: '?', 1057434: 'Zaputnoe (krasnovsky S/o)', 1945432: '?', 1136078: 'Zhuravlevo', 5479328: 'Khalmer-Yu', 1900948: 'Kfar Haroe', 1703583: 'Tsakhkaovit', 2203311: '?', 1124079: 'Zharikovo', 2204064: '?', 1086406: 'Lukovskaya', 11313: '?', 1602705: 'Pravdinsky', 1152322: 'Bolshoy Esaul', 1091454: 'Sultan', 1114415: 'Yanglichi', 1002568: 'Kaska', 15130: "Saint George's", 1007023: 'Nizhnearmetovo', 1053858: 'Stepanschino', 1121853: 'Mamontovsky', 5259590: '?', 5050386: 'Portland', 1507159: 'Chervony Prapor', 1068912: 'Vishnevoe', 1504392: 'Grushevo', 1921350: 'East Haddam', 3760065: 'Butuan', 1504189: 'Tekovo', 1928981: '?', 1506994: 'Novaya Astrakhan', 1084836: 'Volzhsky', 1038540: 'Sukhonogovo (poselok)', 1907976: 'Langdon', 4661647: 'Drummand Orange Grove', 1091425: 'Severnoe', 1941454: '?', 1036996: 'Verkhnyaya Maxakovka', 1123925: '18 Svobodny', 4568515: 'Lichtenstein', 1007985: 'Yanagushevo', 1146750: 'Nikolkino', 1801831: 'Henderson', 4409443: 'Saint-Cloud', 1113378: 'Novy Mir', 1068785: 'Kurakino', 1509898: 'Erki', 1134124: 'Lopyal', 1967520: 'Sparks', 1514840: 'Mikhalcha', 1049388: 'Repets', 1944939: '?', 8097: 'Gorno-Chuysky', 2722597: 'Kitwe', 1059781: 'Molodi', 1974549: 'Kanata', 1503135: 'Novoalexandrovka', 1709245: 'Arnold', 1514605: 'Kamenka', 5421954: 'Sakai', 1159197: 'Dzhonka', 17504: 'Kudeevsky', 1702008: 'Krymskoe', 1093949: 'Troitsky Roslyay', 1082271: 'Rozhdestveno', 1082178: 'Voslebovo', 1122311: 'Kaip', 1142258: 'Boltinka', 2102085: 'Yukari-Chirchik', 1122871: 'Kuybyshevo', 1153583: 'Momsky Natsionalny', 5422755: 'Sobolookh', 1149535: 'Kozmodemyansk', 1008958: 'Komsomolsk', 3684729: 'Rayong', 1122414: 'Ust-Chagyrka', 1918928: '?', 1504576: 'Chkalovo', 1504165: 'Velikie Komyaty', 1147842: 'Pugachevsky', 4549445: 'Carpineto Romano', 1602875: 'Novy Sverzhen', 1120313: 'Artemyevo', 1004663: 'Adamovka', 20551: 'Elmshorn', 1514331: 'Legedzinoe', 1128977: 'Ogonki', 1153868: 'Ogonki', 1948346: '?', 1600404: 'Velikorita', 1507402: 'Nakvasha', 1700296: 'Dorofeevka', 2211699: '?', 1703034: '?', 1160339: 'Kotelnikovo', 1972653: '?', 1501110: 'Krikovtsy', 2602783: 'Dobeļi', 1131895: 'Elizarovo', 1944001: '?', 1704824: 'Qiqihar City', 1509023: 'Novoborisovka', 1023050: 'Demyanka', 5001049: 'Windy City', 19762: 'Yanishpole', 1138033: 'Yalanskoe', 1510057: 'Zhovtnevoe', 1156293: 'Gora', 1151229: 'Usolye', 1146106: 'Pushkino', 1160970: 'Katravozh', 1505185: 'Dobrovlyany', 1113965: 'Mezhdurechye', 1511493: 'Samoluskovtsy', 2210955: '?', 1459: '?', 1911252: '?', 1007626: 'Karacha-Elga', 1091613: 'Filimonovskaya', 1149438: 'Filatovo', 4245954: 'Bière', 2202879: 'Morges', 1034053: 'Kudrinskaya', 4183725: 'Vila-Real', 875: 'Imo State', 4985211: 'Huston', 1041253: 'Kryzhanovsky', 1005094: 'Bekeshevo', 1967490: 'Apsley', 1501299: 'Antonovka', 5002664: 'Crossroads', 1004776: 'Chekhovo', 1800386: 'Dondyushany (sel.)', 2608894: '?', 1514313: 'Ternovka', 1905161: 'Centre de Flacq', 1151811: 'Nsklad', 3997652: 'Vilakalaka', 1036243: 'Uchebnoe Khozyaystvo Shkoly-Internat', 1510391: 'Semiduby', 1901387: '?', 1144238: 'Nagornoe', 1130158: 'Ulanovka', 1502465: 'Petrovka', 1701541: 'Burli', 5261573: 'Lastrup', 1708374: 'Arab', 1503224: 'Kamenka', 1506805: 'Olkhovoe', 1505938: 'Pevtsy', 1924331: '?', 1014362: 'Krasnodonsky', 1084934: 'Krasny Boets', 2608136: 'Jaunpils', 1024179: 'Kvashino', 1503451: 'Toporische', 1917548: '?', 1115367: 'Bolshoe Buyanovo', 5267642: 'Auerbach in der Oberpfalz', 1951499: '?', 1953953: '?', 1051082: 'Azanovo', 1006887: 'Bishkuraevo', 1006902: 'Ilyakshide', 1042336: 'Alexandrovsky', 1030926: 'Rybnoe', 15244: 'Tessenderlo', 1939498: 'Kroměříž', 5267035: 'Feuchtwangen', 1514875: 'Kruglik', 1511158: 'Andreevka', 1152175: 'Ambor', 1064245: 'Krug', 1120288: 'Shashkovo', 1505167: 'Shevchenkovo', 1010079: 'Novenkoe', 1507769: 'Novoselki-Oparskie', 4242204: 'Bangor', 2209622: '?', 1914224: '?', 1906149: 'Madison', 1927429: 'Hendersonville', 1025285: 'Lizinovka', 5038290: 'Readfield', 1943060: '?', 2203074: '?', 1901845: '?', 1020198: 'Kurilovo (kurilovskoe S/p)', 1502471: 'Khoroshee', 1156728: 'Almyakovo', 4321504: 'Weida', 4242322: 'Baldock', 1953182: 'Page', 2205663: '?', 1147401: 'Preobrazhenka', 1144985: 'Tebisskoe', 1514357: 'Dubovaya', 2205928: '?', 1120565: 'Ilinskoe (ilinskoe S/p)', 1131621: 'Leninskaya Iskra', 1154897: 'Mezenskoe', 1913702: 'Szerencs', 11062: 'Holderness', 1015158: 'Novostroyka', 5214165: 'Périgueux', 1958114: '?', 1502041: 'Schurin', 5266268: 'Ahaus', 2206409: '?', 1004687: 'Gayniamak', 1023855: 'Novonadezhdinsky', 1902170: 'Lakewood', 1502863: 'Novokrasnovka', 1801569: 'Chadyr', 1915402: 'Český Brod', 1600245: 'Rechki', 1023238: 'Novinka', 1904834: '?', 5104896: 'Little Rock', 13640: 'Richardson', 1711479: 'Euless', 1506370: 'Dolinovka', 5054780: 'East Newark', 1975516: '?', 1511931: 'Zvinyach', 5267070: 'Hammelburg', 1910125: '?', 1953752: 'Linden', 1500153: 'Tselinnoe', 1700050: 'Zelenoe', 1153709: 'Tyubyay', 1059041: 'D/o Avangard', 1134923: 'Yastrebovo', 1083931: 'Svetlodolsk', 1154276: 'Yasashnaya', 2500082: 'Dzhirgatal', 1159061: 'Kotikovo', 19766: 'Starye Kuty', 1125561: 'Kurlovo (derevnya)', 1601951: 'Karolin', 1040404: 'Povalikhino', 1506650: 'Komishevatoe', 7779: 'Gzhatsk', 11263: 'Starodzherelievskaya', 21444: 'Rosa', 1042290: 'Shaumyan', 1151484: 'Mulyanka', 3226167: 'Traniş', 1031269: 'Pushkino', 1119931: 'Kozhevnikovo', 1961614: 'Gjirokastër', 13655: 'Gilroy', 1153288: 'Orekhovo', 1040807: 'Neftekachka', 1713484: '?', 1714797: '?', 1511682: 'Katerinovka', 1958351: '?', 1964771: '?', 1974562: '?', 1947450: '?', 1036104: 'Rugozero', 1958211: '?', 1910082: '?', 1906730: 'New London', 1134964: 'Primorsk', 1955838: '?', 1600383: 'Darevo', 2300495: 'Zhayyl', 2861: 'Mokshino', 1975182: 'Srebrenica', 1068103: 'Varypaevo', 2002105: '?', 1803221: 'Koeru ', 1507583: 'Monastyrets', 1963742: 'Nynäshamn', 1925623: 'Giengen an der Brenz', 4745953: 'Santa Fe', 10978: 'Zhuravkino', 1937234: '?', 12757: 'Pinneberg', 3993517: 'Shisui', 1508994: 'Vinogradnoe', 1707934: 'Merzig', 1144015: 'Skala', 1144058: 'Lesnaya Polyana', 1148529: 'Akzharskoe', 1153334: 'Anisimovka', 1915252: 'Lisburn', 1057286: 'Yudino', 1068731: 'Leonidovka', 1514988: 'Shapovalovka', 1158747: 'Kazachye', 1101367: 'Kistutovo', 1964071: '?', 1502311: 'Polivanovka', 1713500: '?', 1905437: 'Pully', 1157763: 'Butusovo', 1600884: 'Perebrodye', 1935495: '?', 2101739: 'Yangiabad (denovsky Rayon)', 1701055: 'Sosnovka', 1902468: '?', 1077991: 'Kukuevsky', 2722452: '?', 5330661: 'Aguilar de la Frontera', 1936872: '?', 1914666: 'Zlín', 1079521: 'Vesely', 1919914: 'Fermo', 1120384: 'Stolbischi', 4244122: 'Porrentruy', 1801893: '?', 1706911: 'Nevada City', 1928698: 'Gagliano Castelferrato', 1079446: 'Rassypnoe', 1502120: 'Velikaya Kostromka', 14782: 'Maloe Vasilevo', 2210827: '?', 1974628: '?', 1946848: '?', 1148517: 'Ratchino', 1121793: 'Paspaul', 1005076: '1-E Itkulovo', 2203902: '?', 1946789: '?', 1024579: 'Semenov', 1800589: 'Kongazchik', 20932: 'Georgetown', 1975791: 'Liberty', 1056773: 'Naro-Fominsk-11', 1158772: 'Ukyr', 2300085: 'Kerben', 1085520: 'Sinenkie', 1711738: '?', 2608779: '?', 2211776: '?', 1800148: 'Bukuria', 1109498: 'Ivanovo (derevnya)', 20084: 'Maseru', 1124772: 'Zun-Murino', 1922132: '?', 1095079: 'Gondyrevo', 5388856: 'Lacey Green', 4548718: 'Castelletto sopra Ticino', 4539429: 'Sesto Calende', 1060116: 'Kurkino', 1050059: 'Novosilskoe', 1113206: 'Alexeevka', 1145126: 'Novoitkulskoe', 1028512: 'Markovo', 1600360: 'Dyatlovichi', 1714478: 'Blackrock', 1702107: 'Lenino', 1801843: 'Vinh', 1502235: 'Volnoe', 1942138: '?', 1912581: 'Springfield', 1112397: 'Oktyabrsky', 1705621: '?', 1936917: '?', 1956630: '?', 1512735: 'Stepnoe', 1091653: 'Oktyabrskoe', 1800825: 'Moleshty', 1041789: 'Nadezhnaya', 1803598: '?', 1507673: 'Voronyaki', 1042371: 'Yuzhny', 1937274: '?', 1906028: '?', 1954394: 'Freckleben', 1011225: 'Bryansk-Severny Kech', 1157390: 'Okunevo', 1919219: 'Randolphville', 4186217: 'Llíria', 4189396: 'Benaguasil', 1127928: 'Karluk', 1956019: '?', 1602045: 'Gudevichi', 1078044: 'Manych-Balabinka', 1910476: '?', 1041955: 'Maevsky', 1513383: 'Belogorodka', 1502566: 'Voyskovoe', 1059181: 'Podolino', 1006640: 'Kuzhanak', 3212197: 'Bureå', 5117518: 'Lancaster', 1904683: '?', 1920799: '?', 2754: 'Kyrchany', 1160494: 'Ulan', 1143596: 'Novoyarkovo', 1160428: 'Kulusutay', 1143928: 'Alabuga', 1140197: 'Bolshaya Arat', 1145491: 'Borki', 1008647: 'Dmitrievka', 2210031: '?', 1500994: 'Ivcha', 1071424: 'Satanino', 1965890: 'Iron Mountain', 1915888: 'Owatonna', 2211161: '?', 15553: 'Orem', 5113416: 'Eagle Mountain', 1513749: 'Lyutarovka', 1513755: 'Ordyntsy', 1159526: 'Sabinka', 1154434: 'Nizhny Ary', 1014739: 'Pokrovka', 2207157: '?', 1108469: 'Zavodskoy', 1117555: 'Glinino', 1058743: 'Syrnevo', 1702741: 'Oktyabrskoe', 1939482: 'Pilani', 1129010: 'Lesnoy', 20152: '?', 1503171: 'Privolye', 2201057: '?', 1943725: '?', 1505635: 'Sukholesy', 3130593: 'Ierapetra', 3638096: 'Bor-Üdzüür', 1159043: 'Avan', 1013532: 'Maritsa', 1919335: '?', 1004850: 'Ubalary', 1079631: 'Zhukov', 1903430: '?', 1144579: 'Rogalevo', 1602471: 'Sadovichi', 2207133: '?', 2400852: '?', 1510727: 'Alexandrovka', 1126342: 'Usad', 1009229: 'Mescherevo', 1015668: 'Vorobyev', 1514752: 'Marshintsy', 1161022: 'Vyzymgort', 1025955: 'Kudali', 1157564: 'Kargaly', 1504881: 'Radolovka', 4539019: 'Suvereto', 1006181: 'Sargaya', 1703204: '?', 1921321: '?', 1509214: 'Tsekhanovka', 9355: 'Krivskoe', 1057566: 'Bykovo', 1700556: 'Terekty', 1124770: 'Zhemchug', 1051034: 'Pabaynur', 1506761: 'Luganka', 2101076: 'Beruni', 21093: 'Pagėgiai', 1085703: 'Bobylevka', 1948586: 'Kent', 1502714: 'Beloyarovka', 1711574: '?', 1501647: 'Pavlovka', 1091578: 'Sergievskoe', 1715751: '?', 1601761: 'Ostashkovichi', 1601749: 'Davydovka', 5349878: 'Ilsenburg (Harz)', 670: '?', 1137753: 'Klyukvennoe', 1007481: 'Yanaul', 2202461: '?', 3138316: 'Umm al Qaywayn', 1140394: 'Ilinsky (ilinsky S/s)', 1934975: 'Vimpeli', 3976: '?', 1025774: 'Gdym', 1060480: 'Volnaya Gorka', 1715224: '?', 1507905: 'Pidbereztsy', 1078213: 'Frunze', 1122641: 'Rogozikha', 1041040: 'Vasyurinskaya (stantsia)', 1602789: 'Chernitsky', 1713637: '?', 1926612: '?', 1969995: '?', 1947694: '?', 1919166: 'Coron', 1703992: 'Westminster', 1145504: 'Mikhaylovka', 1158304: 'Sozonovo', 1122699: 'Kazachy', 16850: 'Shulma', 1914084: '?', 1909755: '?', 1957293: '?', 1007229: 'Urgush', 4587771: 'Dannstadt-Schauernheim', 1125542: 'Ivanischi', 1031828: 'Manych', 1511033: 'Maly Vistorop', 1136768: 'Shila', 5469475: 'Torit', 1703982: 'Chechevichi', 1009918: 'Dorogosch', 1603082: 'Pavlovichi', 1963885: 'Hollywood Beach', 1049029: 'Tikhvinka', 1048995: 'Pavlovka', 5127797: 'North Red Deer', 1005597: 'Aitovo', 1922121: '?', 1083072: 'Frunzensky', 4003416: 'Lakes Entrance', 1902391: '?', 1143591: 'Novonikolaevka', 1009346: 'Nikolsk', 2207595: '?', 1096288: 'Krasnaya Gorka', 1007633: 'Mavlyutovo', 1125267: 'Sedelnikovo', 1601767: 'Borisovschina', 1054160: 'Ramensky', 1078602: 'Suvorov', 3243598: 'Bran', 3175942: 'Mersa Matruh', 1510477: 'Buscha', 1001560: 'Grigorovo', 1500409: 'Mikhaylovka', 17396: 'Pereleshinsky', 1600195: 'Potapovichi', 5094943: 'South Park', 1148347: 'Zhirnov', 1516596: 'Póvoa de Varzim', 1511099: 'Vyazovo', 1925085: 'Carrollton', 1510354: 'Khrenniki', 1709076: 'Troitskoe', 1010764: 'Kharkovskoe', 1900915: 'Yagur', 1912789: 'Eaton Rapids', 1926271: 'Ostrowiec Świętokrzyski', 1007343: 'Sikhonkino', 1135531: '?', 1801479: 'Fyrleden', 1027950: 'Kolyanovo', 1029945: 'Reutovo', 2204731: '?', 1040890: 'Chernigovskaya', 2609031: '?', 1031222: 'Pushkino', 1702022: 'Frunzenskoe', 1150739: 'Kyn (selo)', 1803190: 'Lohusuu', 1152357: 'Demenevo', 1503285: 'Novoselovka', 1803480: '?', 1509760: 'Miloradovo', 1147244: 'Klyuchi', 1122598: 'Redkaya Dubrava', 1081067: 'Zmeinka', 1080440: 'Pogost', 1158029: 'Kataysk', 1032041: 'Manychsky', 5266527: 'Bad Arolsen', 1111430: 'Edelevo', 20182: 'Michurinsky', 14723: 'Ermolaevo', 1507361: 'Lantratovka', 1505024: 'Verkhny Yasenov', 1503560: 'Ozeryanka', 1503551: 'Kodnya', 1100340: 'Varaxino', 1959684: '?', 1519198: 'El Paso', 1107573: 'Rozhdestvensky', 1510249: 'Khotin', 1515021: 'Drozdovitsa', 1060202: 'Almazovo', 2206374: 'Benito', 5334649: '?', 1510396: 'Studyanka', 1601679: 'Zhmurovka', 3793824: 'Quanzhou', 1714502: 'Fuerteventura', 4184565: 'Sanlúcar de Barrameda', 1116000: 'Berezniki (andreevskaya S/a)', 1025431: 'Vysoky', 1085242: 'Zvonarevka', 1059049: 'Alabushevo', 1052051: 'Yurkino', 1068667: 'Titovo', 1602596: 'Krupitsa', 1517738: '?', 1800654: 'Kriva', 1800391: 'Drepkautsy', 1051732: 'Joshkar Ushem', 1042099: 'Garkusha', 1155072: 'Maminskoe', 1514300: 'Nosachov', 1155000: 'Rechkalova', 1501737: 'Trostyanets', 1943486: '?', 1093628: 'Panovy Kusty', 1505182: 'Golin', 1014866: 'Komsomolets', 1709709: '?', 1045766: 'Khudanki', 1514642: 'Dobrinovtsy', 1042407: 'Kondratovka', 1916661: 'Highlands', 6652: 'Prishnya', 1932506: 'Romanija', 1514979: 'Prachi', 1109198: 'Balezino', 1145963: 'Cherlaxkoe', 1053336: 'Krasnoarmeysky', 1511238: 'Chernatskoe', 1061429: 'Pestovo', 1973010: '?', 1094000: 'Kochetovka', 1025319: 'Ternovka', 1081709: 'Dashki-2', 1114423: 'Baygulovo', 1156477: 'Nibega', 1131629: 'Makarye', 1103019: 'Chachkino', 1082765: 'Polnoe Yaltunovo', 1510159: 'Mokievka', 2203764: '?', 1507590: 'Poddnestryany', 1513995: 'Konelskie Khutora', 1513994: 'Konelskaya Popovka', 1052811: 'Svobodny', 1506191: 'Zhuravlikha', 1508722: 'Troitskoe', 1086050: 'Sadovy', 1022485: 'Bor', 1908374: 'Ochkhamuri', 1924160: '?', 4310444: 'Hoogstraten', 1714054: 'Aubagne', 1122155: 'Borovlyanka', 1517287: 'Ypsilanti', 1903038: '?', 1125685: 'Vtorovo', 1512584: 'Artemovka', 1084462: 'Kochetovka', 1919551: '?', 1715584: '?', 1058074: 'Igumnovo', 1703232: '?', 1108204: 'Odintsovo', 1504496: 'Steblovka', 1955690: '?', 1025109: 'Saprino (khutor)', 1014480: 'Semenovka', 1111270: '?', 1916996: '?', 1009362: 'Rabak', 1031920: 'Peschany', 1091467: 'Kievka', 1105422: 'Ostrov', 1147569: 'Afrika', 1123971: 'D/o Buzuli', 1042530: 'Kulbaki', 1042528: 'Korovyakovka', 1706617: 'Surrey', 5129932: 'Surrey', 1964710: 'Phoenix', 1046534: '?', 2209835: '?', 1972504: '?', 1507337: 'Polovinkino', 1942208: '?', 5430872: 'Vulka-Telekhanskaya', 2208316: '?', 8927: '?', 1711191: 'Dublin', 21385: 'Niagara-on-the-Lake', 1510204: 'Prishib', 5262265: 'Abentheuer', 4492573: 'Radom', 1909875: '?', 1962486: '?', 1970483: 'Pomona', 1700898: 'Koylyk', 1514980: 'Prokhory', 1156655: 'Petrovka', 14283: 'Nizhny Atlyan', 2500001: '?', 1093055: 'Starotomnikovo', 1122417: 'Chineta', 1033235: 'Volkonskoe (derevnya)', 5238997: 'La Planche', 16873: 'Verkhny Balykley', 1123546: 'Vasilyevka', 1037269: 'Smolyanka', 1506010: 'Novoselki', 1508321: 'Nagachov', 1514869: 'Zarozhany', 1970967: '?', 1702094: 'Novoselovka', 1078601: 'Stychnovsky', 1515097: 'Kopti', 1135822: 'Brazhnoe', 1067308: 'Bogoroditskoe', 4771589: 'Tortue', 1085956: 'Sergievsky', 1155136: 'Kvashninskoe', 1154847: 'Novy Vagil', 1142967: 'Tulazhka', 1146904: 'Cheboxarovo', 1714950: '?', 1514097: 'Grushkovka', 1508621: 'Novodanilovka', 1509872: 'Andreevka', 1110815: 'Uzey-Tuklya', 4302816: 'Tournai', 1601641: 'Konkovichi', 1701591: 'Rubezhinskoe', 1920564: 'Washington', 1058894: 'Bolshoe Gryzlovo', 1024887: 'Livenka', 1085767: 'Makarovo', 1800079: 'Berlintsy', 1066429: 'Biofabrika', 1947191: '?', 1518831: 'Kitab', 1120112: 'Pesochnoe', 1975548: 'Vöcklabruck', 3744: '?', 2210192: '?', 1106889: 'Prekrasny', 1503351: 'Polyanka', 1025016: 'Peski', 1053018: 'Urishka', 15293: '?', 5120055: 'Kīhei', 1708575: '?', 1065621: 'Vozhovo', 1514014: 'Khizhnya', 1130319: 'Biserovo', 1009499: 'Belovskoe', 1010723: 'Aydar', 1071821: 'Ostrov', 1516113: 'Cashel', 1100216: 'Yarkovo', 1144456: 'Stantsionno-Oyashinsky', 1031919: 'Pervomaysky', 1008786: 'Buyda', 1057513: 'Smolevo (sobolevsky S/o)', 1026537: 'Leninkent', 4349274: '?', 1933284: 'Gorelovka', 1023279: 'Povarovo', 1601295: 'Grabovka', 1503638: 'Scheglovka', 1918696: 'Hermannsburg', 1081542: 'Kostino', 1503633: 'Studenitsa', 1136412: 'Novoalexandrovka', 1092589: 'Kompressornaya', 1944426: '?', 3835967: 'Nakano', 1709982: 'Centralia', 4540805: 'San Daniele del Friuli', 1024460: 'Bodeevka', 1902235: 'Bulle', 1011621: 'Berezino', 1122076: 'Pervomayskoe', 4190752: 'Realmonte', 1143556: 'Terengul', 1936744: '?', 1105935: 'Krasnitsky', 1913129: 'Colombes', 5228197: "Saint-Cyr-l'École", 5004168: 'Hurst', 1500065: 'Balki', 1941146: '?', 1959439: '?', 1052516: 'Umet', 1955616: 'Gramsh', 4176077: 'Ejbei Uad el Aabd', 1141467: 'Ulyanovo', 17308: 'Volga', 1111861: 'Stary Mostyak', 1052182: 'Dyurki', 1057483: 'Novoe-2 (novinsky S/o)', 1083636: 'Vulkan', 1032912: 'Ostrov (selo)', 1600392: 'Svoyatichi', 1602433: 'Domotkanovichi', 1602683: 'Gritskevichi', 1506996: 'Novokrasnyanka', 1508846: 'Pavlovka', 1070222: 'Spitsino', 1600859: 'Velikoe Selo', 4994825: 'Charlotte', 1507192: 'Nagolno-Tarasovka', 1702652: 'Vozvyshenka', 1132312: 'Sinegorye', 1083678: 'Mirny', 1503046: 'Yasinovka', 1098418: 'Tokarevo', 1000207: 'Dzherokay', 4433034: 'La Défense', 5227050: 'Saint-Jean-de-Maurienne', 1974938: '?', 1707367: 'Rushville', 1906737: '?', 2203692: '?', 1106349: 'Shakhtersky', 1511919: 'Belaya', 5113140: 'Colorado', 1500674: 'Florino', 1037327: 'Borovoy', 1102095: 'Mostovaya', 1058457: 'Sytkovo', 1041763: 'Raevskaya', 1941770: 'Wilton', 1091588: 'R. Lyuxemburg', 4935787: 'Alaska', 1135957: 'Panovo', 4944133: 'Nicholasville', 1518143: 'West Windsor', 1041250: 'Krikuna', 1094963: 'Sheka', 5328222: 'Jelcz-Laskowice', 5091271: 'Fontana', 1038577: 'Sholokhovo', 1503029: 'Schurovo', 1079096: 'Chekalov', 1938616: '?', 1058199: 'Troshkovo', 1513433: 'Dovzhok', 4477448: 'Milovice', 1146564: 'Starosoldatskoe', 1951571: '?', 2203123: '?', 1512886: 'Gladkovka', 1504042: 'Gorbulyov', 1141775: 'Satis', 5261773: 'Morsbach', 5266250: 'Waldbröl', 5261778: 'Eitorf', 5266254: 'Burscheid', 1601957: 'Kremyanitsa', 1958000: '?', 1160920: 'Neshkan', 1501632: 'Gryady', 1506705: 'Voynovka', 1138872: 'Novinki', 5266404: 'Schwerte', 1058247: 'Babaevo', 1701211: 'Terekty', 5088838: 'Snowflake', 1703531: 'Sandford', 1026542: 'Shamkhal', 1122270: 'Shilovo', 4177687: 'Tipasa', 1963467: '?', 18242: 'Westchester', 1500415: 'Okhotnichye', 1160758: 'Sokhondo', 21651: 'Abay', 2209675: '?', 1155684: 'Pokrovsk-Uralsky', 1156443: 'Bolshaya Galka', 1057737: 'Mis', 4988984: 'Booker Washington Heights', 14853: 'Voybokalo (derevnya)', 1971715: 'Loches', 1110008: 'B.kez', 1500991: 'Dyakovtsy', 1942992: '?', 17461: 'Sanboli', 1061265: 'Bereznik', 3288794: 'Limanowa', 3277229: 'Zamość', 1158363: 'Krasny Yar', 1915157: '?', 16528: '?', 1925422: '?', 1160440: 'Ust Borzya', 1920430: '?', 1710342: 'La Plata', 1141272: 'Druzhny', 1108280: 'Yasnaya Polyana', 1700281: 'Raevka', 1150335: 'Aryazh', 5326777: '?', 1112756: 'Polotskoe', 1502287: 'Ulyanovka', 1077695: 'Elizavetovka', 2202882: '?', 1075242: 'Astratovo', 1102527: 'Kvashnino', 1010327: 'Novokhutornoe', 1008840: 'Safarovo', 1512161: 'Snezhkov', 4696355: 'Emanuel', 1972284: '?', 1902074: '?', 1101625: 'Kamenka', 4660819: 'Ocho Rios', 1145746: 'Elita', 1500277: 'Leninskoe', 1801472: 'Fuzovka', 1160924: 'Billings', 13709: 'Lipovets', 1513905: 'Zhilintsy', 1121814: 'Ilinka', 1073409: 'Kryuki1', 1500243: 'Ishun', 1910455: '?', 1508990: 'Alexandrovka', 1030434: 'Verkhny Kurkuzhin', 13898: 'Peniki', 1036763: 'Kazhim', 1155298: 'Ayat', 1132812: 'Belyanka', 2206964: '?', 1511706: 'Stary Alexinets', 1703896: '?', 1010658: 'Vengerovka', 1508985: 'Kholodnaya Balka', 1709819: '?', 2205554: '?', 1803265: 'Põlva (pylva)', 1095615: 'Pospelovo', 1157154: 'Sug-Axy', 1093468: 'Nizhnespasskoe', 1974126: '?', 1131212: 'Poroshino', 4883230: 'Morelia', 1086454: 'Mayskoe', 1124070: 'Takhtamygda', 1014659: 'Ermakovsky', 1602539: 'Kosino', 1161180: 'Elginsky', 1152761: 'Malinovo', 1138019: 'Mansurovo', 1800552: 'Kirkaeshty', 4170195: 'Mopti', 2205599: 'Ajax', 1512921: 'Olgino', 1113364: 'Kosobrodka', 2400682: 'Abano', 1112194: 'Stary Bely Yar', 1511481: 'Krasnoe', 1019433: 'Maza', 1042680: 'Zhirnovsky', 1511464: 'Tribukhovtsy', 1113111: 'Unkurda', 1111145: 'Dolzhnikovo', 1961860: '?', 2101705: 'Khalkabad (muzrabadsky Rayon)', 1141868: 'Kamenka', 1037927: 'Ray (derevnya)', 1515056: 'Doroginka', 1066550: 'Malaya Kulikovka', 1142559: 'Vitkulovo', 1157664: 'Borovinka', 1112425: 'Katenino', 1026093: 'Padar', 1153509: 'Kobyay', 1152811: 'Mezhgorye', 1916674: 'Springfield', 1974719: '?', 1519269: '?', 1041117: 'Maxima Gorkogo', 1010891: 'Olshanka', 1122611: 'Novichikha', 5002826: 'Detroit', 1098016: 'Priseki', 22672: 'Wenzhou', 1094757: 'Ulakly-Chishma', 1500660: 'Mikhaylovka', 1084655: 'Khoperskoe', 13164: 'Pichaevo', 1159469: 'Kamyshta', 1702052: 'Adaevka', 1139674: 'Yakovtsevo', 5432240: 'Harkujärve', 1150533: 'Zhilino', 1049958: 'Palenka', 1135949: 'Nedokura', 1921443: 'Jičín', 1958634: 'Heerenveen', 1031309: 'Zhuchkovo', 1110916: 'Eshmakovo', 2205329: '?', 1054293: 'Velyaminovo', 1119655: 'Sulost', 1119668: 'Ugodichi', 2204318: '?', 1517745: 'Pombal', 1123530: 'Rachi', 1005557: 'Novoabzakovo', 5470333: 'Sadzeli', 1516556: 'Viernheim', 1504312: 'Rakoshino', 1920405: '?', 1926712: '?', 1956136: '?', 1094491: 'Poisevo', 1012929: 'Mikhnovka', 1972342: '?', 1506869: 'Baranikovka', 1038559: 'Graviyny Karyer', 1130543: 'Polom', 1507948: 'Piratin', 1703455: '?', 1915419: '?', 1516183: '?', 4242412: 'Aviemore', 1083262: 'Zolnoe', 2609027: '?', 1924719: '?', 1084254: 'Taydakovo', 5426884: 'Kuchino', 1140814: 'Zhelnino', 1501471: 'Lugi', 1501464: 'Brytovka', 5470329: 'Kolkhida (psakhara)', 1012292: 'Groza', 1056928: 'Balobanovo', 4853661: 'La Perla', 1710331: 'Yazvan', 3135390: 'Qlaïaât', 1507556: 'Vladimirtsy', 4011409: 'Hawera', 1508368: 'Sadovoe', 1016302: 'Ostrov Sladky', 1601214: 'Novaya Iolcha', 1915346: 'Nordhausen', 1518797: '?', 1514700: 'Brusnitsa', 1707692: 'North Potomac', 2500016: 'Aral', 1113877: 'Novye-Atagi', 1710117: 'Lakewood', 1108345: 'Lyutorichi', 1122094: 'Eltsovka', 1943659: 'Dún Laoghaire', 1711485: 'Ewing', 20652: 'Nizhny Sayantuy', 1112445: 'Tolsty', 1600930: 'Krapivno', 1127686: 'Tutura', 1026654: 'Ashaga-Stal', 1037175: 'Kokvitsy', 15484: 'Klyukva', 1161156: 'Novomikhaylovsky-2', 1122313: 'Krasny Yar', 3737530: 'San Pablo', 1920110: 'Stephenville', 1077561: 'Antropovo', 1149195: 'Peremskoe', 1005253: 'Starokuruchevo', 1502686: 'Blagodatnoe / Chapaevka', 1036534: 'Oleny', 4293020: 'Perg', 1927027: '?', 1902121: 'La Grande', 1057954: 'Zavety Ilicha', 1711354: 'Vantaa', 1147835: 'Pervomaysky', 1936823: '?', 15938: 'Vozdvizhenskoe', 1600309: 'Verkholesye', 1510985: 'Ryasnoe', 1056398: 'Pushkino', 1903093: '?', 1099168: 'Bentsy', 1956985: '?', 1078683: 'Chicherino', 1962207: 'Jeonnam', 1918160: '?', 1108241: 'Uspenskoe', 1115583: 'Arancheevo', 1030835: 'Dvorki', 3191: '?', 1159435: 'Kaybaly', 1509481: 'Balakleya', 1004243: 'Volzhsky', 1006983: 'Bixyanovo', 1009888: 'Staroivanovka', 1959138: 'Springfield', 1946518: '?', 1517684: '?', 1031215: 'Malomozhayskoe', 1048323: 'Krasava', 1965176: '?', 1108055: 'Krainka', 1084747: 'Cherkasskoe', 1013723: 'Lebedin', 1508845: 'Ostrovnoe', 1129839: 'Spassk', 1136444: 'Tiny', 1504709: 'Lazurnoe', 1701392: 'Karasay Batyr', 4655535: 'Bagé', 4760009: 'Talara', 1954868: '?', 1956152: '?', 1508605: 'Shevchenkovo', 1513605: 'Onatskovtsy', 2202319: 'Nagano', 2001446: '?', 5327174: 'Agia Marina', 5102683: 'Arizona City', 1920743: '?', 1160308: 'Temnaya', 1141372: 'Blagoveschenka', 1156758: 'Rozhdestvenka', 1951210: '?', 2202321: '?', 1139197: 'Linda-27 (lindovsky S/s)', 1061367: 'Lavrovo', 1901999: 'Ingelheim am Rhein', 1927885: '?', 4044167: 'Almada', 1946832: '?', 1960734: '?', 1094706: 'Kama-Ismagilovo', 1502211: 'Nikolaevka', 12348: '?', 1106536: 'Lobanovo', 1150348: 'Bolshie Kusty', 1704608: 'Rashkovo', 1086720: 'Dorokhovo', 1516258: '?', 1958580: '?', 5468687: 'Mechta', 1041618: 'Pervomaysky', 1161103: 'Oxino', 1500084: 'Michurinskoe', 1602606: 'Loshany', 15286: 'Holmdel', 1031953: 'Verkhny Yashkul', 1603209: 'Filatovo', 1000092: 'Podgorny', 1922745: 'Montrose', 1511581: 'Sinyava', 1955814: 'Muri', 1934349: '?', 1513374: 'Staraya Guta', 1060393: 'Krasnoschelye', 4229802: 'Tiverton', 1130967: 'Luza', 5074312: 'Milwaukee', 1147496: 'Onoprienovka', 1513291: 'Bozhikovtsy', 1602976: 'Borkolabovo', 1602989: 'Glukhi', 1109861: 'Menil (derevnya)', 1114117: 'Kozlovka', 1506935: 'Davydo-Nikolskoe', 1120818: 'Troitskoe', 1700185: 'Prigorodnoe', 1500509: 'Lokhovka', 1144779: 'Koltyrak', 1514630: 'Cherepkovtsy', 1517493: '?', 5267357: 'Feucht', 5266260: 'Königswinter', 1902335: 'Long Beach', 1048019: 'Krasnoe', 1129214: 'Baranovka', 1088749: 'Sobolevo', 1093431: 'Utekha', 5123934: 'Dawson Creek', 1111566: 'Lesnaya Khmelevka', 1114402: 'Chagasi', 1505744: 'Ploskoe', 1099661: 'Schekoldino', 1058498: 'P/l Druzhba', 1147494: 'Novouralsk', 4386476: 'Brandenburg', 1972973: '?', 1513942: 'Ksaverovo', 1037035: 'Znamenka', 1129443: 'Suslovo', 1127987: 'Urik', 1707643: 'Landeck', 1071841: 'Pogrebische', 8167: 'Dezhnevo', 1505179: 'Verkhnyaya', 1943559: '?', 1709100: '?', 1709327: 'Bridgewater', 1137613: 'Keramzitovy', 2206359: '?', 1123471: 'Rodino', 1123041: 'Nizhnyaya Suetka', 1012538: 'Makarichi', 1517107: 'Galkino', 1033666: 'Erdenevo', 1066481: 'Zhilina', 1112198: 'Urazgildino', 2205321: '?', 1068092: 'Treskino', 1925553: '?', 17051: 'Sharnut', 1012411: 'Bobrik', 1147845: 'Sergievka', 1971766: '?', 2204213: '?', 1110513: 'Starye Kaxi', 1519007: 'Avellino', 5267792: 'Brake (Unterweser)', 1510718: 'Orzhev', 1149040: 'Sokolovo', 1938574: '?', 4962061: 'Hollister', 4239906: 'Collingbourne Kingston', 1014527: 'Chistopol', 5470283: 'Tinchlik', 1511275: 'Tereshkovka', 1041898: 'Derbentskaya', 1901622: '?', 1051429: 'Joshkar-Pamash', 1600557: 'Khoromsk', 1964445: '?', 1947022: '?', 1079938: 'Loznoy', 1159363: 'Druzhba', 1508118: 'Khlevchany', 1058671: 'Novozheltikovo', 1057254: 'Tatarki', 1971356: '?', 4523456: 'Cuenca', 1134081: 'Arkhangelskoe', 1513617: 'Veliky Sknit', 1041616: 'Obraztsovy', 1503683: 'Motovilovka', 1500368: 'Kumovo', 1107994: 'Ageevo', 1502261: 'Shirokoe', 1007993: 'Anyas', 4284907: 'Horn', 20284: 'Irsha', 1702966: 'Satpaevo', 1923887: 'Bassum', 1161726: 'Novaya Chortoria', 1709240: 'Arkadelphia', 1138958: 'Malinovka', 1085916: 'Kleschevka', 1503838: 'Listvin', 5166650: 'Palau-solità i Plegamans', 1516222: 'Cliffside Park', 1035520: 'Elburgan', 1953397: '?', 1041257: 'Moldovansky', 1903674: 'Halle', 1601206: 'Krivcha', 1711238: 'Key Largo', 1972648: '?', 5308423: 'Oyster Pond', 1087153: 'Nikolskoe', 4540869: 'San Bonifacio', 1130687: 'Klyuchi', 1502303: 'Lychkovo', 1102892: 'Orekhovo', 1147730: 'Belozerka', 1976196: 'Heddesheim', 1098733: 'Veli', 1093065: 'Khlystovo', 1704027: 'Leland', 1704106: '?', 1504770: 'Tersyanka', 1014415: 'Logovsky', 1113856: 'Gekhi-Chu', 1011092: 'Streletskoe', 1077801: 'Lenina', 1097224: 'Kalmash', 1903970: 'South Padre Island', 2500281: 'Sebistan', 1113298: 'Polevoy', 1138022: 'Nadezhdinka', 1041671: 'Voskhod', 1964931: 'Bare', 1506195: 'Ostraya Mogila', 1517903: 'North East', 1072941: 'Laptevo', 4905247: 'Alele', 1700713: 'Kuygan', 1114645: 'Ispukhany', 1037297: 'Karpushovka', 1946846: 'American Falls', 1067947: 'Anuchino', 5056415: 'Allegany Reservation', 2608690: 'Bayamón', 5259497: 'Coswig', 1016417: 'Bonga', 5256562: 'Tutow', 4016187: 'Maroua', 3906455: 'Paju', 1923361: '?', 1956026: 'Lidzbark Warmiński', 1020148: 'Zakharovo', 4919746: '?', 1707426: 'Vallejo', 1129226: 'Elykaevo', 1957276: 'Kanab', 1160472: 'Khokhotuy', 1902263: 'Lenexa', 5105226: 'Sandpoint', 5086750: '?', 1035836: 'Tedino', 1919868: '?', 2362: '?', 2608859: '?', 1136573: 'Pirovsky', 1976867: 'Appomattox', 1158860: 'Khokta', 1601893: 'Grandichi', 1036638: 'Ust-Soplesk', 1147927: 'Uralsky', 1144453: 'Smolensky', 1501404: 'Kachanovka', 1087640: 'Dnestrovsky', 3296203: 'Ciechanowiec', 4499401: 'Koszewko', 1714565: '?', 1516268: 'Paskautsy', 1707297: 'Boz', 1096180: 'Zay-Karatay', 1155127: 'Galkinskoe', 1145621: 'Novoarkhangelka', 1517843: 'Fish Creek', 1023987: 'Podkolodnovka', 1063960: 'Mintsy', 5267120: 'Donauwörth', 1114198: 'Kyustyumery', 1513464: 'Rikhta', 3051774: 'Buraydah', 1510291: 'Svaryni', 4644219: 'Salvador', 1012878: 'Gorodische', 1012887: 'Dareevsk', 1113630: 'Redutovo', 1519289: 'Kozenki', 1707479: '?', 1092105: 'Sukhoy Log', 1138066: 'Peski', 1702148: 'Dolbushka', 2201549: '?', 1077338: 'Chernaya Gryaz', 1505992: 'Zabuyanye', 1121055: 'Zabornoe', 1514960: 'Vysokoe', 1920556: '?', 1919995: 'Slippery Rock', 1505481: 'Rudniki', 1937896: '?', 1933040: '?', 1926984: 'Alice Springs', 1097035: 'Saklov-Bash', 1930987: 'Saint-Malo', 1952562: '?', 1515508: 'Kovpita', 1147803: 'Brodetskoe', 1600067: 'Strigin', 1082439: 'Alabino', 1091587: 'Kapelnitsa', 1136701: 'Uner', 1602634: 'Selevtsy', 1600068: 'Zditovo', 1124444: 'Elan', 1504243: 'Seltso', 1112523: 'Borisovka', 2602092: 'Špoģi', 1702085: 'Toguzak', 2206101: '?', 1712683: '?', 1008054: 'Rodnikovka', 1502125: 'Zaporozhskoe', 1005333: 'Tuchubaevo', 1935224: 'Sombor', 1030561: 'Planovskoe', 1082799: 'Fedosovo', 1952217: '?', 1008322: 'Dergachevka', 1000166: 'Panakhes', 5266187: 'Geldern', 1514951: 'Stary Bikov', 5368811: 'Dehesa de Campoamor', 1712061: 'Port Angeles', 1704938: 'Imola', 1507651: 'Novaya Skvaryava', 1084956: 'Orlov-Gai', 1960301: '?', 1114163: 'Almenevo', 1068238: 'Bolotnikovo', 1513866: 'Gorodnyavka', 1041906: 'Krepostnaya', 1713204: 'Odder', 1709224: 'Angwin', 1024091: 'Mamonovka', 1324: '?', 1906189: 'Allentown', 5735: 'Otradnoe', 4531460: 'Røros', 4537373: 'Ålen', 1713718: '?', 4507212: 'Biały Bór', 1920002: 'Sorrento', 1902827: 'Quarteira', 1907103: 'Hell', 8794: 'Skvortsovo', 1016866: 'Moskvin Pochinok', 1512950: 'Novoalexandrovka', 1920217: '?', 1143368: 'Staroe Ivantsevo', 1143644: 'Kornilovo', 1145488: 'Alexeevka', 1110487: 'Novotroitsk', 1081048: 'Gryaznoe', 1970117: '?', 1048608: 'Gatische', 1083070: 'Tambovka', 1948059: '?', 1153486: 'Chineke', 1041009: 'Novomikhaylovskoe', 1959042: 'Sokółka', 1910327: '?', 1514251: 'Chernaya Kamenka', 4068962: 'Mongomo', 1108784: 'Lomintsevsky', 1122640: 'Prutskoy', 1142105: 'Novodmitrievka', 1906306: 'Dorval', 1702871: 'Sukhorabovka', 1503997: 'Chernorudka', 1915766: 'Nyack', 1096780: 'Kulaevo', 1095347: 'Nizhny Uslon', 1057939: 'Nagornoe', 1508023: 'Verkhnee Sinevidnoe', 1502050: 'Lyubokhini', 1800476: 'Izvoare', 1501733: 'Prilutskoe', 1517021: '?', 1008762: 'Shemyak', 1508055: 'Tukhlya', 1110507: 'Russky Pychas', 1083731: 'Kuleshovka', 1086415: 'Priterechny', 5431136: 'Zhayrem', 1800376: 'Dobrusha', 1019387: 'Zhukov Pochinok', 1705060: '?', 1905920: 'Bellinzona', 1068691: 'Bolshaya Elan', 1119000: 'Bobarino', 1511925: 'Dzhurin', 1511934: 'Kosov', 1502421: 'Karabinovka', 3963178: 'Liaoyang', 1708381: '?', 1507205: 'Mankovka', 1123714: 'Dmitrievka', 1096577: 'Gorodische', 5267021: 'Stadtsteinach', 1502357: 'Mironovka', 3150517: 'Karabük', 1800831: 'Moshana', 1079326: 'Kireevka', 1512470: 'Glushkovka', 1963796: 'Patras', 1506503: 'Kalinovka', 1505261: 'Nizhny Verbizh', 1506582: 'Novonikolaevka', 1869: 'Khuzhir', 1145970: 'Bunyakovka', 1148138: 'Turkestan', 1956525: '?', 16705: '?', 2210622: '?', 1109423: 'Kamskoe', 1714515: 'Bitterfeld-Wolfen', 1124733: 'Tokhoy', 1507683: 'Kurovichi', 1130293: 'Chernushka', 5266339: 'Schieder-Schwalenberg', 1501563: 'Ludin', 3248407: 'Nagykálló', 1801702: 'Seward', 5330578: 'Kaka', 4244612: 'Manno', 1002200: 'Lysimo', 1935991: '?', 1709025: '?', 1159010: 'Alanap', 1054608: 'Savvino', 2210631: '?', 1136808: 'Fanachet', 1053380: 'Apraxino', 1122731: 'Sosnovka', 1156175: 'Oshkukovo', 5266935: 'Plattling', 1054124: 'Orudyevo', 8058: 'Kuleshovka (poselok)', 1113442: 'Peschanoe', 1077816: 'Rekonstruktor', 1505708: 'Zagaltsy', 1602553: 'Rechen', 1157886: 'Chelyuskintsev', 1966879: '?', 2211054: '?', 4381097: 'Düren', 1024888: 'Losevo', 1122891: 'Tishinka', 1701911: 'Karsakpay', 1023945: 'Shestakovo', 1053514: 'Chernoe', 2207904: '?', 1146136: 'Duvanovka', 1026228: 'Bavtugay', 1504183: 'Onok', 1515572: 'Khotunichi', 1108992: 'Kamenka', 2207132: '?', 1091932: 'Krasnodarsky', 1050842: 'Yuxary', 6252: 'Cheb', 1048855: 'Petrovsky', 1009438: 'Ilovka', 21345: 'Trekhizbenka', 1024603: 'Gorenskie Vyselki', 1938232: 'Vona', 5266979: 'Oberviechtach', 1002866: 'Letneozersky', 4533171: 'Leirvik', 1922531: '?', 1512390: 'Lozovaya', 1100122: 'Bobachevo', 1093294: 'Krutoe', 1095508: 'Chepchugi', 17399: 'Misheronsky', 1603265: 'Ryazantsy', 2200665: 'Agarak (selo)', 1901143: 'Sakhnin', 1048113: 'Glazova Gora', 5266486: 'Hadamar', 1956622: '?', 1705157: 'Charlottetown', 1152844: 'Pokrovka', 1513315: 'Nizhnee', 10323: 'Sanaga', 21395: 'Clarksville', 1153564: 'Khaptagay', 1111567: 'Lesnoy', 1148630: 'Shermeyka', 1113635: 'Uglitsky', 1139253: 'Okhlobystino (kantaurovsky S/s)', 1147659: 'Gerasimovka', 1127791: 'Novoletniki', 1127784: 'Maslyanogorsk', 1032843: 'Zhukovo', 1135322: 'Shelomki', 5066370: 'New Hampshire', 1962250: '?', 1708154: '?', 2208277: '?', 1517690: 'Yangadzha', 1153847: 'Due', 1111744: 'Alexeevka', 1509008: 'Tabaki', 1130050: 'Novoivanovsky', 1011834: 'Khodilovichi', 2205507: '?', 1513066: 'Primorskoe', 13134: 'Georgievskaya', 1157020: 'Gyngazovo', 1514732: 'Shishkovtsy', 1504745: 'Radostnoe', 1148534: 'Elenovka', 1503999: 'Yagnyatin', 1057538: 'Khoteichi (sobolevsky S/o)', 1121960: 'Malougrenevo', 1701529: 'Budarino', 1705969: '?', 1512200: 'Volchanskie Khutora', 1159040: 'Etyrken', 1713151: 'North Vancouver', 1513026: 'Khreschenovka', 1517194: 'Mendrisio', 1153324: 'Samarka', 1943884: '?', 1045230: 'Terebuzh', 1704517: 'Changwon', 1120004: 'Lyskovo', 1514746: 'Kostichany', 2202830: 'Thonon-les-Bains', 4441322: 'Ennery', 1147990: 'Grachevka', 1940393: '?', 1508976: 'Naberezhnoe', 1502695: 'Verbovatovka', 1504719: 'Orlovo', 5329538: 'Maarianhamina (Mariehamn)', 1124389: 'Kholtoson', 5243540: 'Tossa de Mar', 1900834: 'Midreshet Ben Gurion', 1500454: 'Kashtanovoe', 1092638: 'Sosnovka', 1158880: 'Zakhal', 5267958: 'Boizenburg/Elbe', 5266383: 'Werdohl', 1501612: 'Pustomyty', 4543515: 'Nola', 1000951: 'Pysye', 5130030: 'Terrebonne', 1700170: 'Zaporozhye', 1502700: 'Novoivanovskoe', 1713761: '?', 1505861: 'Zhukovka', 1505019: 'Tisov', 3358859: 'Vila Junqueiro', 21231: 'York Run Junction', 1517092: '?', 1501177: 'Dmitrashkovka', 1095570: 'Ubey', 1500806: 'Babin', 1923157: '?', 1052748: 'Rybkino', 1710454: 'Columbia', 20990: '?', 3648395: '?', 1155313: 'Nizhnie Tavolgi', 21021: 'Strasburg', 2201131: '?', 4045: '?', 1132439: 'Tataurovo', 22331: '?', 1517027: 'Shrewsbury', 1114294: 'Oryol', 4874479: 'Texas', 1910712: '?', 1506121: 'Krasyatichi', 1080237: 'Kotelino', 1975141: '?', 1122051: 'Bor-Forpost', 1067999: 'Skvorechnoe', 1160730: 'Kakavo', 1000847: 'Viled', 1925652: '?', 1074185: 'Zababye', 1151620: 'Vyatchana', 4374401: 'Gießen', 1133037: 'Izh', 1707088: 'Aylmer', 1077758: 'Semibalki', 1600849: 'Chereyschina', 2209289: 'Garches', 12297: 'Krasny', 1511666: 'Tsenov', 1027161: 'Retlob', 1047994: 'Borisovo', 2208098: '?', 1150052: 'Beloevo', 1155086: 'Pokrovskoe', 1500156: 'Yarkoe Pole', 1602731: 'Shatsk', 1510579: 'Borbin', 1914282: 'Aalsmeer', 1161280: 'Ivanov', 4188024: 'El Grao', 4188672: 'Castelló de la Plana', 1921991: 'Alhambra', 1501167: 'Chagov', 16656: 'Nezhitino', 1508628: 'Berezki', 1514231: 'Pominik / Viktorovka', 1931233: '?', 1136137: 'Shalabolino', 1508728: 'Kamenka', 1154177: 'Zadanie', 1505431: 'Krekhovichi', 1079338: 'Markin', 1065655: 'Konotop', 1507193: 'Novodaryevka', 5110959: 'North Portland', 1153548: 'Matta', 1516119: 'Hajnówka', 1159383: 'Mirnoe', 4964791: 'Vineland', 1970405: '?', 1704679: '?', 1006819: 'Oktyabrsky', 1078633: 'Kiselevo', 1701367: 'Shakpakata', 4238704: 'East Grinstead', 1702214: 'Presnogorkovka', 1109145: 'Nizhnee Asanovo', 1030443: 'Nizhny Kurkuzhin', 1507630: 'Zashkov', 1090128: 'Gnezdovo', 4703051: 'San Antonio Huista', 4352766: 'Marbach an der Lauter', 1003050: 'Verkhnyaya Zolotitsa', 1082310: 'Brykin Bor', 1090305: 'Pechersk', 1709429: 'Beaumont', 1502487: 'Malomikhaylovka', 1081606: 'Alexeevka', 5421621: 'Manzini', 1154330: 'Baraba', 1504139: 'Veliky Berezny', 1083380: 'Semenovka', 1118416: 'Berezniki', 1085409: 'Sinegorsky', 1509653: 'Udovichenki', 1900964: 'Givat Ela', 1503874: 'Pokrovskoe / Komsomolskoe', 1027285: 'Urada', 2204106: '?', 1122872: 'Mamontovo', 5261666: 'Hatten', 1505202: 'Podmikhaylye', 1705689: 'Holzminden', 4695550: 'Zion Hill', 1091442: 'Krymgireevskoe', 1507771: 'Pesochnaya', 5331990: 'Sveti Vlas', 1153568: 'Khocho', 1024923: 'Aloe Pole', 1931111: '?', 1092674: 'Gololobovka', 1907340: 'Pepperell', 1920685: 'Zeeland', 1971711: '?', 6060: '?', 2001714: '?', 1911601: '?', 1144714: 'Novopervomayskoe', 1154163: 'Garaninka', 1908068: '?', 1146145: 'Loginovka', 1938614: '?', 1703608: 'Polesye', 1709757: 'Brentwood', 1926900: '?', 1109602: 'Loloshur Vozzhi', 1600566: 'Ostrovno', 1113589: 'Miassky', 1042349: 'Krasny', 1156195: 'Yar', 1705905: 'Cegléd', 4558828: 'Osijek', 1941308: '?', 3078983: 'Ypsonas', 2210263: '?', 1143015: 'Varlashevo', 5350: 'Liptovský Mikuláš', 4468671: 'Demänová (Okres Liptovský Mikuláš)', 1115183: 'Avdan-Sirmy', 1964051: '?', 1601805: 'Merkulovichi', 1016210: 'Zubovo (gulinsky S/s)', 1136502: 'Zapasnoy Imbezh', 1155932: 'Novoselovo', 1913557: 'Sighişoara', 1515503: 'Ivanovka', 2719584: 'Adutiškis', 1501447: 'Bukatinka', 1501305: 'Vila', 1123148: 'Parfenovo', 1052554: 'Sialeevskaya Pyatina', 1078071: 'Kalinin', 1803197: 'Sonda', 1950740: '?', 1051108: 'Znamensky', 1157967: 'Tyunevo', 1083947: 'Chernovka', 1507699: 'Snovichi', 1707143: 'Hopwood', 1013686: 'Dedovsk', 1602016: 'Vangi', 1141339: 'Selektsionnoy Stantsii', 1923847: '?', 1041628: 'Bagovskaya', 1123868: 'Peschanoozerka', 1803479: 'Glasgow', 1509510: 'Brovarki', 1603024: 'Kletnoe', 1507466: 'Gradovka', 4507553: 'Bąków', 1910252: 'Albersdorf', 1708228: 'Tonbridge', 1506037: 'Maslovka', 1502083: 'Mokrets', 4244852: 'Lachen', 1506041: 'Potok', 1082281: 'Zarechny', 1929947: 'Barrhead', 2208223: '?', 5389195: 'Sandhurst', 1961173: '?', 5266303: 'Ennigerloh', 2722633: 'Kigali', 1513267: 'Mudrigolovy', 1967431: '?', 1962550: '?', 1946669: '?', 1502821: 'Egorovka', 1706776: '?', 1704137: 'Piteå', 1517376: 'Kirkcaldy', 2416: '?', 1032565: 'Pyatovskaya', 1968041: '?', 1159395: 'Rakitnoe', 1707399: '?', 1083968: 'Karmaly', 1517155: 'Pobeda', 1053103: 'Yalga', 5118357: 'Shelton', 5003691: 'Grapevine', 1803615: 'Irving', 1155814: 'Timofeevo', 1005398: 'Metevbashevo', 1936914: '?', 11886: 'Aktaban', 1507916: 'Sokolniki', 1700670: 'Aydarly', 1149191: 'Nizhny Lukh', 1940433: 'Prijedor', 5265458: 'Heinersreuth', 1514727: 'Streletsky Kut', 1509749: 'Velikaya Rublevka', 3154337: '?', 4925245: 'Wellington', 4723289: 'Alajuela', 3366176: 'Sainte-Marie', 1042835: 'Mikhaylovka', 1003292: 'Zaostrovye', 9294: 'Bukovo', 1034685: 'Strelna', 1700770: 'Eskeldy', 18510: 'Novoavramovka', 1130279: 'Roi', 1113966: 'Mirenki', 1900614: 'Beit Zvi', 2204350: '?', 1125486: 'Anopino', 1507169: 'Zolotarevka', 4132438: 'Tamba', 1095572: 'Khornovar-Shigali', 1083086: 'Irgizsky', 1957565: '?', 1049687: 'Pavelka', 5125052: 'Fort Nelson', 1701788: 'Tsentralnoe', 1912397: '?', 1025991: 'Chokh', 2204352: '?', 3149959: 'Karaman', 2500010: 'Almosi', 1700673: 'Kasymbek', 1703947: 'Ozerichino', 1965801: '?', 1036838: 'Zelenoborsk', 1602074: 'Valevka', 1129947: 'Lukoshkino', 5330638: 'Ruchi', 1506630: 'Panchevo', 1501497: 'Murafa', 1079910: 'Sredny Egorlyk', 1708301: 'Ringwood', 1500756: 'Nosovtsy', 1067884: 'Saltykovo', 1511657: 'Kupchintsy', 1506952: 'Ogulchansk', 8206: 'Parkhomenko', 1155857: 'Filatovskoe', 1707021: 'Glassboro', 1158844: 'Novo-Lenino', 21034: 'Guilderland', 1515498: 'Dneprovskoe', 1713740: 'Poway', 1500416: 'Pribrezhnoe', 1500335: 'Voykovo', 1140785: 'Sechuga', 1155014: 'Fomina', 1068848: 'Ozerki', 2204118: '?', 1117704: 'Savelovo', 1094466: 'Kazkeevo', 1943735: '?', 2204498: '?', 1702478: 'Oktyabrskoe', 1501939: 'Komarovo', 3351310: 'Quelimane', 1137491: 'Borovskoe', 1008059: 'Satyevo', 1017994: 'Kotelnikovo (spasskoe S/p)', 1505689: 'Martusovka', 1502162: 'Pismennoe', 1711325: 'Bad Aussee', 1109968: 'Byrgynda', 5092139: 'Kings Beach', 1091457: 'Yankul', 3186757: 'Khartoum North', 1144627: 'Bitki', 19796: 'Byurakan', 1801040: 'Pelinia', 1114775: 'Elbarusovo', 1098339: 'Kemtsy', 1943037: '?', 1092422: 'Syava', 1974716: 'Tooele', 1917918: '?', 5266420: 'Ober-Ramstadt', 7359: 'Delfzijl', 1918269: 'Sneek', 1931963: 'Etten-Leur', 1517656: '?', 1121996: 'Nizhny Kuchuk', 1025395: 'Staraya Veduga', 1500992: 'Zhuravnoe', 1943045: 'Kokhb', 1968806: '?', 1968771: '?', 1920583: 'Wausau', 2722615: 'Najaf', 22378: 'Maryville', 1048402: 'Svir', 1005154: 'Temyasovo', 1156905: 'Oktyabrskoe', 1512328: 'Sheludkovka', 2206744: '?', 5103449: 'Mount Shasta', 1507693: 'Pomoryany', 1095741: 'Bolshie Yaki', 1502500: 'Vishnevoe', 1518795: 'Santa Maria', 1025883: 'Chirkey', 3790419: 'Taiyuan', 1706730: 'Doboj', 1015239: 'Nariman', 1040828: 'Turkinsky', 1912230: 'Pleasantville', 5058473: 'Fishkill', 2204132: 'Heckfield', 1914699: '?', 1505600: 'Sezenkov', 1148640: 'Asovo', 1711530: 'East Florence', 1102724: 'Glebovo', 1903663: 'Barnsley', 1153326: 'Sokolovka', 2300189: 'Kyzyl-Suu', 3960194: 'Bayan Ulaan Suma', 1078468: 'Samburov', 1602020: 'Maloe Mozheykovo', 1601959: 'Krivichi', 1037104: 'Patrakovo', 1518265: '?', 1054319: 'Ilinskoe', 1048928: 'Bereznegovatka', 1011689: 'Zhiryatino', 1044920: 'Nadeyka', 1012777: 'Chichkovo', 5045812: 'Jordan', 1511845: 'Dolina', 1041191: 'Sladky Liman', 1159568: 'Gaydarovsk', 1128601: 'Afanasyeva', 1128597: 'Anguy', 1128667: 'Ust-Kulsk', 1085125: 'Lebedevka', 1904258: '?', 1084571: 'Natalino', 1073565: 'Rubilovo', 1138965: 'Novaya Sloboda', 1003106: 'Lakhta', 1129959: 'Rassvet', 1159356: 'Vostochnoe', 5055122: 'Hopewell', 1964649: 'Industry', 1936289: 'Amadora', 1907504: 'York Beach', 1505664: 'Moskalenki', 1506549: 'Velikaya Viska', 1123081: 'Zagaynovo', 1138913: 'Khabarskoe', 1503514: 'Ryasnoe', 1500773: 'Kamenogorka', 1149184: 'Krasnoe', 2209869: 'Silchar', 1950122: 'Puerto Jiménez', 1156682: 'Suyga', 1503524: 'Usolusi', 1062950: '?', 1500943: 'Knyazhaya Krinitsa / Radyanskoe', 1702130: 'Maykol', 1083404: 'Kazakhsky', 1150916: 'Chaykovskaya', 1088420: 'Zibriki', 1154760: 'Krasnogorskoe', 1801005: 'Olishkany', 1701490: 'Abay', 1700708: 'Karaoy', 1503740: 'Latashi', 1702038: 'Zhaltyrkol', 1031936: 'Kirovsky', 1053307: 'Staraya Kacheevka', 1062630: 'Sosnovka', 1024676: 'Kamenka-Sadovka', 1507018: 'Kamenka', 1079222: 'Petrushino', 1141332: 'Prokoshevo', 5062491: 'Springfield', 1917560: 'Honningsvåg', 1973354: '?', 1050940: 'Shoy-Shudumar', 1972090: '?', 1703158: 'Løgumkloster', 1085946: 'Raskovo', 1038993: 'Babaevo', 1049085: 'Ratchino', 1004322: 'Karalat', 1913752: 'Gurbansoltan-Edzhe', 1110097: 'Polomskoe', 1500945: 'Sokolovka', 1512092: 'Vinnitskie Ivany', 1144747: 'Bugotak', 3447947: 'Mymensingh', 1073174: 'Shelkovo', 1930941: '?', 5121082: 'Hawaiian Beaches', 1042113: 'Progress', 1042129: 'Bednyagina', 1710850: '?', 1002503: 'Polokha', 4239794: 'Corby', 5259971: 'Weißwasser/Oberlausitz', 1114869: 'Orinino', 1080191: 'Smena', 1969621: '?', 1086290: 'Mayramadag', 1137052: 'Novoaltatka', 1093636: 'Satinka', 1600372: 'Lugi', 1507612: 'Velikie Gribovichi', 1514761: 'Redkovtsy', 1936399: 'Babylon', 1915500: 'Clifton', 1707751: '?', 2101821: 'Farkhad (khavastsky Rayon)', 2210817: 'Barreda', 1513249: 'Velikaya Yaromirka', 1905577: 'Pakruojis', 2206947: '?', 1908290: '?', 1153325: 'Saratovka', 1920373: 'Petrich', 1505593: 'Nedra', 2735: '?', 1153464: 'Yunkyur', 1153640: 'Chukar', 12675: 'Letnik', 3487249: 'Kalutara North', 5069269: 'Bryn Mawr', 1086053: 'Sokur', 16562: 'Maly Shpakov', 5081601: 'East Georgia', 1908083: 'Sequoia', 1705812: 'Winscombe', 2300114: 'Suzak', 1518211: 'Mechanicsville', 1137701: 'Eloshnoe', 1128262: 'Ukhovsky', 1007601: 'Mayachny', 1122804: 'Rozhnev Log', 1952023: '?', 1155164: 'Pyshminskaya', 1000160: 'Novaya Adygeya', 1041697: 'Prikubansky', 1962543: '?', 5033471: 'Topeka', 1934092: 'Redondo Beach', 1711175: 'Diamond Bar', 1948791: 'Léon', 1501418: 'Maryanovka', 1506482: 'Ploskoe', 1938803: '?', 1907099: '?', 1512961: 'Volynskoe', 2500206: 'Nefteabad', 1705856: 'Bristol', 1945351: '?', 1905080: '?', 4078: '?', 1503325: 'Stepok', 1124375: 'Ekhe-Tsakir', 1702477: 'Beregovoe', 1505294: 'Vazhny Berezov', 1095900: 'Fedorovskoe', 1704525: 'Bracebridge', 1083300: 'Samsonovka', 1083294: 'Novoe Yakushkino', 1005387: 'Kirillovka', 1033264: 'Zarechye (derevnya)', 1976174: '?', 1943617: '?', 20111: 'Rozengardovka ', 1095291: 'Cherki-Kildurazy', 1503640: 'Bovsuny', 1027755: 'Zarechny', 1922793: 'Nummela', 1517463: 'Karkkila', 1956447: '?', 5101: 'Nenoxa', 2500191: 'Murgab', 1032029: 'Baga-Tugtun', 1940686: '?', 1801824: 'Hazelton Mills', 1803422: 'Twin Falls', 1144418: 'Balta', 1511407: 'Ozeryany', 1035459: 'Nikolaevskoe', 1113940: 'Altyshevo', 1708638: '?', 1128419: 'Chekhovo', 1128416: 'Khudoelanskoe', 1705098: 'Anambra', 1906494: 'Trebich', 1091609: 'Sporny', 1911145: '?', 1946686: '?', 1060218: 'Vore-Bogorodskoe Lesn-Vo', 1111257: 'Im. V. I. Lenina', 2608822: '?', 1097107: 'Tatarskaya Takhtala', 1935480: 'Putlitz', 1938606: '?', 1004923: 'Urmiazy', 1951848: 'Leppävirta', 1077737: 'Obukhovka', 5243507: 'Sant Feliu de Guíxols', 1040396: 'Ostashovo', 2608597: '?', 2204580: 'Terni', 1712934: '?', 1963910: '?', 1931516: '?', 1903858: 'Frascati', 1501981: 'Zabrody', 1903649: '?', 1955562: '?', 1503294: 'Yakovlevka', 1105284: 'Pavlovo', 1708035: 'Sparta', 1016338: 'Rybnitsa', 1042320: 'Michurinsky', 1149172: 'Bobki', 1936502: '?', 1513359: 'Minkovtsy', 1014447: 'Verkhnyaya Dobrinka', 1514454: 'Galaganovka', 1053227: 'Pievka', 1947945: 'Cathair Dónall', 1702719: 'Kazanka', 1113698: 'Dolinsky', 1942459: '?', 5428893: 'Shiderty', 1956614: '?', 4153884: 'Mongo', 1004932: 'Yanaul', 1147555: 'Romashkino', 1600066: 'Vysokoe', 1002196: 'Litvino', 1901107: 'Gadera', 1707895: 'Akhtala (gorod)', 1030969: 'Kubanovka', 2602104: 'Višķi', 1503912: 'Paripsi', 6648: 'Haverhill', 12026: 'Samoded', 5121086: 'Hawaiian Ocean View Estates', 1967899: 'Harrington', 5264205: 'Urbach', 1703218: '?', 2202145: 'Châteauguay', 2300541: 'Rot-Front', 1927095: 'Limerick', 1078068: 'Dubentsovskaya', 1512388: 'Krasnoe', 1509534: 'Svatki', 1923744: '?', 2206667: 'Santurce', 1715146: 'Aarschot', 2202189: '?', 5037197: 'Fryeburg', 2204180: '?', 1503931: 'Vishevichi', 17847: 'Chagorta', 1709852: 'Pljevlja', 4941490: 'Benton', 1014910: 'Budennovsky', 1517786: 'Jeju', 1136067: 'Bragino', 1110063: 'Kuliga', 1920436: '?', 1602878: 'Valeryany', 1904077: '?', 1500517: 'Pushkino', 5266667: 'Fellbach', 1078676: 'Uglerodovsky', 3508500: 'Ernakulam', 4258129: 'Lund', 1706960: '?', 1914489: 'Čerčany', 1930502: '?', 1115283: 'Sinyal-Pokrovskoe', 1518122: 'Santos', 1130208: 'Talovka', 1157238: 'Kamyshinka', 1144421: 'Beloyarka', 1944661: 'Hat Yai', 1051216: 'Shoybulak', 5267065: 'Gunzenhausen', 1959979: '?', 1099754: 'Vyazma', 1913196: 'Cleveland Heights', 4691756: 'Habana', 1136320: 'Kanash', 1078732: 'Denisov', 1014142: 'Metallurg', 1513565: 'Zamikhov', 1710605: 'Crystal Lake', 2500322: 'Khaydar Usmanov', 3493981: 'Vallabh Vidyanagar', 1111411: 'Tenkovka', 1041304: 'Rossiysky 1-J', 1500609: 'Ivanovtsy', 1509016: 'Grebeniki', 1004751: 'Slak', 5166501: 'Eivissa', 1029462: 'Berezniki', 1046699: 'Torfyanoe', 1048582: 'Yam-Izhora', 2500136: 'Kistakuz', 1135416: 'Shuvaevo', 4554: 'Rubezhnoe', 1008036: 'Miakibashevo', 1143658: 'Oyash', 1512109: 'Polkovaya Nikitovka', 1943920: '?', 1144121: 'Novotselinnoe', 1006070: 'Bakaly', 21553: 'Bidaik', 1916576: 'Blanes', 1512399: 'Slobozhanskoe / Chapaevo', 1147627: 'Granitny', 1514933: 'Voronki', 2101904: 'Durman (kibraysky Rayon)', 1948370: '?', 1508585: 'Limany', 1096215: 'Stary Kuvak', 1705860: 'La Crosse', 1963272: 'Wittmund', 1097246: 'Melekes', 1601543: 'Byvalki', 1149914: 'Serva', 1014768: 'Karagichevsky', 1016045: 'Krasota', 1714999: '?', 1507957: 'Stoyanov', 20815: '?', 1937620: 'Lacombe', 5266822: 'Donaueschingen', 1112598: 'Eleninka', 1502425: 'Mezherich', 1702837: 'Khmelnitskoe', 1092626: 'Ramza', 1908270: 'Meridian', 1068671: 'Sheyno', 1113853: 'Alkhazurovo', 1512517: 'Peremoga', 1051067: 'Khlebnikovo', 1143796: 'Agroles', 20008: '?', 1036708: 'Vozhael', 1005511: 'Buganak', 1921962: '?', 1111859: 'Staroe Zelenoe', 1714637: 'Owings Mills', 1133914: 'Kurchum', 1122038: 'Akutikha', 1500369: 'Niva', 1142934: 'Obkhod', 1908631: 'Moudania', 1511977: 'Kuty', 5266753: 'Leimen', 1053448: 'Kryukovo', 1515521: 'Olishevka', 9522: 'Rodomanovo', 1500118: 'Lobanovo', 1030545: 'Arik', 1102207: 'Kholmina', 1505082: 'Perlovtsy', 1514719: 'Nizhnie Stanovtsy', 1507628: 'Zamochok', 1513722: 'Paplintsy', 1159864: 'Chemashi', 22154: 'Nurlykent (burnooktyabrskoe)', 1900643: 'Shamir', 1973094: '?', 1017500: 'Pavlovskaya (vozhegodsky S/s)', 1041454: 'Svobody', 1005593: 'Shigaevo', 1145148: 'Chulym-3', 1016139: 'Bely Ruchey', 1018733: 'Pavshozero', 20589: 'Mishkovichi', 2100495: 'Usmat', 1514973: 'Olenevka', 4427850: 'Le Hohwald', 1938603: 'Bagnols-sur-Cèze', 1517016: 'Hofors', 1508894: 'Demidovo', 1044261: 'Svoboda', 5266677: 'Eppingen', 1014816: 'Dinamo', 1921658: '?', 1092413: 'Pokrovo-Marfino', 1518437: 'Ellensburg', 5110636: 'Hood River', 1513048: 'Podovoe', 1936916: 'Ascoli Piceno', 6674: 'Buchholz in der Nordheide', 1146854: 'Shkunovka', 21815: '?', 1079503: 'Privolny', 1508339: 'Stradch', 5423695: 'Bachoy', 1602970: 'Tugolitsa', 1031343: 'Moshenskoe', 1502027: 'Naviz', 1121487: 'Amitkhasha', 1505535: 'Yamnitsa', 1068729: 'Lenino', 1925356: '?', 1150742: 'Lomovka', 1712869: 'North Myrtle Beach', 5422706: 'Kargalinskaya', 1035978: 'Padany', 1159585: 'Priiskovoe', 1146980: 'Burtinsky', 1932135: 'Snina', 1032013: 'Barun', 4983150: 'Lone Grove', 1153754: 'Syrdakh', 1968338: '?', 1160872: 'Anyuysk', 1903413: 'Deerfield Beach', 1511147: 'Revyakino', 1513112: 'Dolinskoe', 1519300: 'Carmen', 1508211: 'Iosipovichi', 1922206: 'Litomyšl', 21092: 'Emeryville', 1113458: 'Aminevo', 1129223: 'Gorodok', 1000861: 'Gorodok', 1509711: 'Radyanskoe', 1037065: 'Bolshaya Pyssa', 1514262: 'Knyazhiki', 1124271: 'Dyrestuy', 5266951: 'Geiselhöring', 1002741: 'Shardonem', 1510690: 'Gorodische', 1040474: 'Yaksha', 2200727: 'Kornidzor', 1502382: 'Golubovka', 1964241: '?', 4350489: 'Moordorf', 1089487: 'Ostrov', 1132584: 'Berezovka', 1036663: 'Vertep', 1500898: 'Kordishovka', 1008276: 'Raevka', 1123825: 'Dim', 1514242: 'Molodetskoe', 1068652: 'Pachelma (selo)', 4566216: 'Bečići', 1511961: 'Yagelnitsa', 1025485: 'Sinyavka', 1942660: 'Niles', 1922457: '?', 1916426: 'Bad Gandersheim', 1976739: 'Aosta', 5007346: 'Spring', 1032060: 'Molodezhny', 1096718: 'Selengushi', 1010207: 'Sorokovka', 4951913: 'Brunswick', 1518874: "'s-Hertogenbosch", 1026979: 'Kushtil', 1518251: 'Suhl', 1049613: 'Rozhdestvo', 1505462: 'Gorishnoe Zaluchye', 1505471: 'Knyazhee', 1068511: 'Verkhny Lomov', 1035474: 'Chapaevskoe', 1086549: 'Logovo', 5013845: 'North Springfield', 1505363: 'Chernik', 1500946: 'Ternovka', 2101433: 'Payshamba', 5121560: 'Kenai', 1946548: 'San Benedetto', 5225700: 'Landser', 5264458: 'Stegen', 1957476: 'Svanvik', 1923756: 'Lia', 1085289: 'Beloyarsky', 1601256: 'Uza', 1504861: 'Vyacheslavka', 12857: '?', 2210389: '?', 1904312: 'Tirrenia', 1154677: 'Nikitino', 1141984: 'Uzhovka', 4240728: 'Cambridge', 1503052: 'Zakharovka', 2001514: '?', 4188106: 'Elx – Elche', 1036339: 'Kinelakhta', 1902199: 'Lame Deer', 2300196: 'Orgochor', 1128700: 'Zheleznodorozhny', 1903155: '?', 7479: 'Bayonne', 1082298: 'Shelemishevskie Khutora', 1842: '?', 20667: 'Nocera Inferiore', 1710395: 'Cleveland', 1512225: 'Khotomlya', 1025307: 'Poddubnoe', 1702084: 'Nadezhdinka', 1089573: 'Frolovo', 1943801: '?', 1149105: 'Kebraty', 1971168: '?', 1902092: 'Kettering', 1078976: 'Sulin', 1710378: 'Claremore', 1005121: 'Karyshkino', 1922669: '?', 1955509: '?', 1033149: 'Debri', 1155230: 'Krasnaya Polyana', 1006038: 'Ural', 4499026: 'Krosno Odrzańskie', 1011267: 'Maloe Polpino', 1126232: 'Arkhangel', 4661353: 'Half Way Tree', 1124051: 'Bolshoy Never', 1701507: 'Dalakaynar', 1603147: 'Belynkovichi', 5440114: 'Novoe Selo', 1031910: 'Dotseng', 1115028: 'Starye Urmary', 1508960: 'Vasilyevka', 1008249: 'Kabakushevo', 1107717: 'Sokolniki 2', 1055068: 'Pavlo-Slobodsky', 1082821: 'Borki', 1147790: 'Rostoshi', 1504928: 'Bogdanovka', 1504932: 'Dolgoe', 1515724: 'Bargteheide', 1910715: '?', 1107403: 'Berniki', 1506263: 'Velikaya Snitinka', 1005456: 'Emashi', 4409597: 'Saint-Chamond', 1971728: 'Legnano', 1971430: 'Rena', 1062507: 'Ermolino', 1709611: '?', 1108974: 'Denisovo', 1113149: 'Kocherdyk', 5261903: 'Altenstadt', 1915714: 'Niceville', 1705809: 'Portsmouth', 1052715: 'Mamolaevo', 1142103: 'Nikitino (ogibnovsky S/s)', 10545: 'Tyresö', 1036628: '?', 1923694: 'Årslev', 1140590: 'Serkovo (kumokhinsky S/s)', 1934303: 'Bad Ischl', 1709521: 'Trutnov', 1504995: 'Manyava', 1112487: 'Smelovskaya', 1152565: 'Yum', 1936212: '?', 1117701: 'Romanovka', 1505129: 'Chertovets', 5055077: 'Highland Lakes', 1701079: 'Belokamenka', 1972802: '?', 1085610: 'Davydovka', 1601350: 'Korma', 4134525: 'Kongo Boumba', 1122257: 'Kalistratikha', 1122253: 'Buranovo', 1967022: '?', 1710748: 'Gravesend', 1703920: 'Kozlovichi', 1030921: 'Razino', 3996958: 'Abashiri', 1500388: 'Vitino', 1800015: 'Alexeevka', 1124335: 'Naryn-Atsagat', 1919734: 'Rangpur', 1502813: 'Blizhnee', 1705991: 'Farap', 1507375: 'Topoli', 1905550: 'Lázně Bohdaneč', 1500654: 'Krasnoselka', 4190260: 'Taormina', 1710584: '?', 1948508: '?', 1137028: 'Berezovskoe', 1511783: 'Kolodeevka', 1026751: 'Khalag', 1510254: 'Antonovka', 1154032: 'Penzenskoe', 1093158: 'Nikolskoe', 1086243: 'Im Karla Marxa', 1511285: 'Boromlya', 1095377: 'Shelanga', 2206982: '?', 1087160: 'Pavlovo', 1152778: 'Filino', 3123927: 'Ar Ramthā', 1058256: 'Bogorodskoe', 5081617: 'East Orange', 1709943: 'Canton', 1505128: 'Chernyatin', 1062521: 'Ilmen', 1709213: 'Alva', 1157157: 'Balgazyn', 18246: 'Santa Maria', 1124264: 'Botsy', 1083099: 'Polyakov', 5259437: 'Annaberg-Buchholz', 21953: 'Les Baux-de-Provence', 4232378: 'Portishead', 1024093: 'Nizhny Mamon (nizhnemamonsky 2-J S/s)', 1702794: 'Donetskoe', 1601326: 'Vasilyevka', 1503276: 'Verkhnetoretskoe', 1078214: 'Shebalin', 4525682: 'Calafell', 1504353: 'Lug', 4696290: 'Sea View Farm', 1092012: 'Zheleznovodsky', 1971519: 'Pontpoint', 1902252: 'Leadville', 1146003: 'Mayak', 1507478: 'Mavkovichi', 1024181: 'Leschanoe', 1012193: 'Lakomaya Buda', 1150975: 'Leun', 1068968: 'Buturlinka', 1506032: 'Kipyachka', 1951316: '?', 1101785: 'Zemtsy', 1145376: 'Lesnoy', 5259305: 'Friesack', 1946978: '?', 1085161: 'Rimsko-Korsakovka', 1053946: 'Goveynovo', 13846: 'Aberystwyth', 1967379: 'Aytos', 1707254: 'Sonora', 1111174: 'Akshuat', 3215451: 'Ristijärvi', 4485801: 'Złotów', 9741: 'Marfino', 1714053: 'Orange', 1901554: 'Agde', 14004: 'Vyvenka', 4229162: 'Watford', 1072274: 'Pustoshka', 1146682: 'Ekaterinoslavka', 1082936: 'Gavrilovka', 1959053: '?', 1931187: '?', 13581: '?', 1511291: 'Kamenetskoe', 1973142: '?', 1960128: '?', 1125957: 'Ivakino', 1010056: 'Chuevo', 1508546: 'Marinovka', 1516115: 'Płock', 1080635: 'Kultuki', 18333: 'Voznesenovka', 1700323: 'Sulukol', 1079492: 'Valuevka', 4319807: '?', 1946753: 'Massy', 1705405: 'Caldwell', 1091997: 'Shvedino', 1128666: 'Umygan', 1514223: 'Chaplinka', 4924846: 'South Jacksonville', 8464: 'Narbonne', 1110111: 'Stengurt', 1920024: 'Chłapowo', 1147433: 'Blyava', 1702817: 'Krasnaya Polyana', 1056998: 'Noginsk-4', 22072: 'Middletown', 2100874: 'Yangirabad', 1101338: 'Dymtsevo', 1602030: 'Pervomaysky', 1602639: 'Khozhovo', 1511075: 'Ivanitsa', 1503664: 'Bichevaya', 4531151: 'Sandvika', 1501302: '?', 1602694: 'Soltanovschina', 1508744: 'Dolgaya Pristan', 3259088: 'Etropole', 1086231: 'Stepnoe', 1946508: 'Wiązów', 1924166: 'Wieliczka', 3565: 'Marion', 1159963: 'Krasnoleninsky', 1714659: 'Toms River', 1702757: 'Uzunkol', 1012983: 'Yurkovo', 1914796: '?', 1508993: 'Vasilyevka', 1940891: '?', 1041101: 'Yasenskaya Pereprava', 1103086: 'Gryadki', 1967283: '?', 1704367: 'Cerritos', 3832057: '?', 1128954: 'Targiz', 2500088: 'Zeravshan', 1111497: 'Ignatovka', 1974547: '?', 2206875: 'Nevada', 1113049: 'Astafyevsky', 1502137: 'Ukrainka', 1509473: 'Starye Mayaki', 1504397: 'Kaliny', 1000457: 'Pokrovskaya', 1502021: 'Kremenets', 1137931: 'Batyrevo', 1120974: 'Bukhalovo', 1053985: 'Ermolino Opkh', 1600391: 'Konki', 21997: 'Novonikolaevka', 1041596: 'Bichevoy', 1130179: 'Kolmogorovo', 4374739: '?', 1515825: 'Tanbalytas (gornyy)', 4307802: 'Lummen', 1122528: 'Gilevo', 1513792: 'Matskovtsy', 2722619: '?', 1015632: 'Lychak', 1085906: 'Dubki', 22142: '?', 1118723: 'Voskresenskoe', 1092143: 'Dubovka', 2200536: 'Agarak', 1086066: 'Yagodnaya Polyana', 1902259: 'Leesburg', 1103847: 'Kozlovo', 1007295: 'Konstantinovka', 1506684: 'Mikhaylovka', 1076652: 'Borousy', 2207301: 'Mondragone', 1921517: '?', 1144688: 'Kazatkul', 4545823: 'Il Prato', 1115548: 'Sovetskoe', 2207736: '?', 1504380: 'Stroynoe', 1155212: 'Bolshoy Turysh', 1128197: 'Khabarova', 1501099: 'Golovenki', 1504624: 'Mirnoe', 1031795: 'Amur-Sanan', 4184500: 'Santa Cruz de la Palma', 1973636: 'Kehl', 1917265: 'Vardenik', 16845: 'Shapki', 4530346: 'Steinkjer', 1064452: 'Borilovo', 1155509: 'Visim', 1509342: 'Kontseba', 1506379: 'Tauzhnoe', 21775: 'Sturzovka', 1508136: 'Gorodovichi', 2045: 'Velingrad', 1919153: '?', 1706728: '?', 1123246: 'Uryvka', 1503608: 'Syngai', 1156976: 'Grishkino', 1003470: 'Belogorsky', 1005574: 'Subkhangulovo', 12530: 'Ayon', 1135819: '?', 1024084: 'Gorokhovka', 1031884: 'Tundutovo', 2200595: 'Katnarat', 1091908: 'Makhach', 1501215: 'Pliskov', 1909280: 'Rožnov pod Radhoštěm', 4346129: 'Norddeich', 2205576: 'Ahrensburg', 1092579: 'Inokovka-1', 1706645: 'Feldkirch', 1048827: 'Malinki', 1058367: 'Mars', 1512716: 'Vysokoe', 15906: 'Malabo', 1049056: 'Zamartynye', 1915416: 'Amelia', 1159906: 'Snezhny', 1959412: 'Grieskirchen', 1136772: 'B/o Buzim', 1500070: 'Vishennoe', 5054352: 'Wolfeboro', 1909382: 'Mount Berry', 1513495: 'Zasluchnoe', 4339071: 'Recklinghausen Ost', 1500661: 'Myakokhod', 2202121: "Province d'Essaouira", 1915268: 'Corona', 1087949: 'Vava', 1502635: 'Kislichovatoe', 1052654: 'Latyshovka', 1045460: 'Radogosch', 1160452: 'Katangar', 1516611: 'La Jolla', 1041280: 'Elitny', 1004407: 'Cheremukha', 1160321: 'Berezovo', 1111136: 'Yarsky Lnozavod', 1115190: 'Anatkas-Margi', 2209532: 'Sodankylä', 1907445: 'Friesoythe', 1149951: 'Visherogorsk', 1702071: 'Nauchnoe', 1934472: '?', 1029593: 'Filisovo', 1050279: 'Roschinsky', 2300569: 'Shamshy', 1114622: 'Yamaykasy', 1026363: 'Kumukh', 1122191: 'Tyagun', 1127759: 'Khor-Tagna', 1124124: 'Urkan', 1115426: 'Put Lenina', 1515289: 'Popovka', 22189: 'Shevchenko', 1504561: 'Dalekoe', 1124302: 'Ozerny', 17529: 'Uktur', 1920518: 'Giannitsá', 5035924: 'Stoughton', 1094629: 'Novye Salmany', 1078051: 'Progress', 4318604: '?', 1119376: 'Yudino', 1082077: 'Demushkino', 1067615: 'Pichevka', 1702855: 'Kishkenekol', 1919976: 'Shepherdstown', 1130004: 'Novovostochny', 1041395: 'Novomikhaylovsky', 1137857: 'Kurtan', 1511705: 'Sapanov', 2202765: '?', 1507979: 'Voyutichi', 2206996: 'Kentwood', 3307095: '?', 1512357: 'Bugaevka', 1513719: 'Novaya Sinyavka', 1078785: 'Avilo-Uspenka', 1141724: 'Schelkovo', 1087450: 'Klin', 1145302: 'Sukhoe', 8990: '?', 5090051: '?', 1135445: 'Epishino', 1602057: 'Lunna', 1030438: 'Islamey', 3233403: 'Muntele Rece', 3233259: 'Năsăud', 1124178: 'Suvo', 1912105: 'Greeley', 1505949: 'Chernyakhov', 1506408: 'Rozdol', 1505582: 'Bzov', 1079278: 'Nesterkin', 1042252: 'Indyuk', 1137785: 'Chebaki', 1511900: 'Iosipovka', 1511471: 'Gorodnitsa', 1096937: 'Zavod-Nyrty', 4420009: 'Mende', 1134664: 'Noski', 1514056: 'Brovarki', 3257905: 'Kostenets', 1518155: 'Castro', 1514177: 'Zarechye', 1702600: 'Konstantinovka', 1032517: 'Kurovskoe', 1506667: 'Shishkino', 1500125: 'Mirnovka', 1077688: 'Golovatovka', 5032896: 'Monticello', 5032876: 'Monon', 1089280: 'Astapkovichi', 1935297: 'Toulon', 1965284: 'Bad Oldesloe', 1012580: 'Velzhichi', 5043305: 'West Branch', 1040966: 'Praskoveevka', 1107386: 'Aleshnya', 1602627: 'Dubrovo', 1104805: 'Buy', 1114271: 'Klimovo', 1023892: 'Bobrovsky 1-J', 1101418: 'Malyshevo', 1514192: 'Sidorovka', 1053972: 'Dmitrov-5', 1501799: 'Mankov', 1068669: 'Cherkasskoe', 1916895: 'Pembroke', 1800823: 'Moldovyanka', 1108058: 'Kuleshovo', 2202549: 'Kupiškis', 1084646: 'Sotszemledelsky', 1152954: 'Timofeevka', 1140341: 'Gorodetsky (moshkovsky S/s)', 1709278: 'Stevens Point', 4973590: 'Minneapolis', 1021012: 'Vypolzovo', 15655: 'Outokumpu', 1061074: 'Roschino', 1145062: 'Novokrasnoe', 1705020: 'Voorhees', 1919145: 'Powell', 2206822: 'Elmwood Park', 4922282: 'Coconut Creek', 1129338: 'Voskhodyaschy', 1123699: 'Khvoyny', 5090763: 'Denverton', 1045678: 'Pikalevo', 4290590: 'Sommerein', 20531: 'Westgate-on-Sea', 1110668: 'Yugdon', 1122889: 'Samarka', 1041362: 'Evseevsky', 5266751: 'Hockenheim', 1802143: 'Lima', 1956729: '?', 1036558: 'Zaozerny', 1923605: '?', 1914967: '?', 1123544: 'Amurskoe', 1700211: 'Kuropatkino', 1096112: 'Kaipy', 20711: 'Bebelevo', 1093580: 'Semenovka', 1121574: 'Karasuk', 3184307: 'Juba', 1002252: 'Ustyug', 1501678: 'Krymnoe', 1160846: 'Vaegi', 1514667: 'Bernovo', 1024749: 'Kulishovka', 1133316: 'Vypolzovo', 2000886: 'Zazaly', 1126413: 'Panfilovo', 1514207: 'Votilovka', 1709920: 'Jangar', 17136: 'Latonovo', 1026221: 'Rbb', 1148432: 'Totskoe 4-E', 1507543: 'Ulichnoe', 1512872: 'Stokopany', 1013590: 'Tarasovka', 1502997: 'Novotroitskoe', 1159691: 'Solenoozernoe', 21955: '?', 1908144: 'Albion', 1514280: 'Tsibulov', 1706718: '?', 1514872: 'Kerstentsy', 1601400: 'Khilchitsy', 1026547: 'Duchi', 1505200: 'Perevozets', 20850: '?', 1077784: 'Verkhnepodpolny', 1091385: 'Suetovo', 1105636: 'P/l Zapolyarye', 1159255: 'Novoe Ustye', 1070375: 'Zuevka', 1602588: 'Zamostochye', 5018205: 'Charles Town', 1009921: 'Zamostye', 1914023: 'Benicarló', 1121212: 'Mikhaylovskoe', 4304859: 'Retie', 1714861: '?', 1501980: 'Zabolotye', 1139732: 'Ivanovo (derevnya)', 1040857: 'Kubansky', 5470168: 'Uspenka', 1506202: 'Stanislavchik', 4326879: 'Theley', 1703873: 'Ekaterinovka', 21338: 'Heppenheim (Bergstraße)', 1008596: 'Raymanovo', 1087538: 'Rudnya', 1127704: 'Goryachy Klyuch', 19661: '?', 1706393: '?', 19211: '?', 1084860: 'Bakury', 1926338: 'Gorna Oryakhovitsa', 1517427: 'Gateshead', 14023: 'Skien', 1113033: 'Smorodinka', 4666663: 'La Caleta', 19868: 'Ogibalovo', 1055087: 'Petushki', 1041303: 'Pobeditel', 1152620: 'Kama', 1134604: 'Ivanovo (derevnya)', 5426641: 'Mayskoe', 1157101: 'Ust-Buren', 2206154: 'Selbyville', 1045769: 'Chirkovitsy', 1045579: 'Zhilgorodok', 1507524: 'Opaka', 1511490: 'Peremilov', 1514441: 'Tuboltsy', 1503581: 'Groznoe', 1515849: 'Aguascalientes', 1506941: 'Krasnodon Selo', 1005085: 'Aminevo', 1510203: 'Mikhayliki', 1138395: 'Krasny Uralets', 1709174: 'Aguadilla', 1701944: 'Verkhnie Kayrakty', 8228: 'Bolshaya Tura', 1014868: 'Krasny Meliorator', 1085302: 'Karabulak', 1077977: 'Verkhnyakovsky', 1932320: 'Bognor Regis', 5332771: 'Yangelsky', 1160483: 'Margutsek', 1153418: 'Taymylyr', 1503916: 'Savertsy', 1145094: 'Alexandrovsky', 1157392: 'Peganovo', 2102376: 'Dustlik (gurlensky Rayon)', 1907895: 'Asti', 1064770: 'Rtischevo', 1507724: 'Neznanov', 1503130: 'Mirnaya Dolina', 1005394: 'Malinovka', 5261985: 'Willingen (Upland)', 1102563: 'Moshary', 1703773: 'Nyborg', 1055825: 'Kalinovka', 1961450: 'Gols', 1701877: 'Esil', 1504443: 'Kontsovo', 1149199: 'Chelva', 1511790: 'Novoe Selo', 1919391: 'Albires', 4191282: 'Lipari', 1973786: 'Kadaň', 1600146: 'Gutovo', 1114508: 'Novochelny-Syurbeevo', 1511947: 'Rosokhach', 1126476: 'Glubokovo', 1926759: 'Zafar', 4500128: 'Koło', 1513817: 'Belaya', 1102592: 'Pochinok', 2206391: '?', 1514814: 'Romankovtsy', 1800257: 'Voynesku', 1129403: 'Bolshoy Antibes', 1602678: 'Vysokaya Lipa', 1093167: 'Pervomaysky', 1114263: 'Berezovka', 1709249: 'Ashland', 5426273: 'Nauchny', 1098087: 'Tebleshi', 1123262: 'Mirny', 1158075: 'Znamenschikovo', 1157223: 'Bannikovo', 1069482: 'Shilovo', 1708240: 'Virginia', 2211465: '?', 5430750: 'Erkin', 4907063: 'Bellevue', 1124315: 'Shiringa', 10522: 'Newport', 1508591: 'Nikolaev Zhovtnevy', 4500537: 'Kietrz', 1908214: '?', 1514971: 'Novye Melnitsy', 1701508: 'Dinmukhamed Konaev', 1151751: 'Cherepanovo', 1097088: 'Kuznechikha', 1025037: 'Mazurka', 1131647: 'Mukha', 1024849: 'Uchkhoz Zoovettekhnikuma', 1082019: 'Puschino', 1035607: 'Avneporog', 1023999: 'Filonovo', 1961982: 'Port Royal', 1059846: 'Sharapovo', 1140234: 'Pokrov', 1081540: 'Konstantinovo', 1948216: 'Springe', 1517569: 'West Haven', 1083735: 'Pokrovka', 1155338: 'Vaskino', 1113459: 'Belovo', 14477: 'Hemet', 1703062: 'Kaskasu', 1143856: 'Stepnoy', 1146122: 'Ust-Zaostrovka', 1148430: 'Suvorovsky', 1071493: 'Aluntyevo', 1023974: 'Krinitsa', 1147515: 'Ural', 1155397: 'Labazka', 1508887: 'Anatolyevka', 1115063: 'Verkhnie Anatrialy', 5470325: 'Kakhati', 1127366: 'Sosnovy Bor', 1160369: 'Zolotonosha', 1082037: 'Telyatniki', 5104163: 'Amsterdam', 1711598: 'Huachuca City', 1122878: 'Novonikolaevka', 1009161: 'Sayran', 1941998: 'Gardiner', 1147006: 'Axakovo', 1098543: 'Lyubegoschi', 1503922: 'Kharleevka', 1086240: 'Shumeyka', 2722523: 'Holetown', 1063832: 'Susolovo', 1012864: 'Bobrik', 1513004: 'Korsunka', 1509205: 'Novosamarka', 1010314: 'Livenka', 1079955: 'Anno-Rebrikovskaya', 3684514: 'Udon Thani', 1053720: 'Sudnikovo', 1129799: 'Za-Mrassu', 1510531: 'Stovpin', 1091528: 'Preobrazhenskoe', 1017361: 'Gorodische', 1020587: 'Borok', 1503553: 'Levkov', 1703377: '?', 1065502: 'Korsakovo', 1025040: 'Oktyabrskoe', 1123967: 'Chernovka', 2100008: 'Altynkul (altynkulsky Rayon)', 5471754: 'Huidong County', 1157895: 'Antropovo', 1158520: 'Yuzhnaya', 1702087: 'Aydarlinskoe', 1914167: 'Menton', 1916121: 'Ustka', 1513104: 'Tarasovka', 1153764: 'Ust-Maysky', 1702720: 'Troitskoe', 1121843: 'Zavety Ilicha', 1141062: 'Skorobogatovo', 2500157: 'Kuruxay', 1076872: 'Redkino', 1081933: 'Zhelobovo', 1702830: 'Dmitrievka', 4494910: 'Olsztyn', 1015416: 'Kano', 1141385: 'Murzitsy', 1945019: 'Alma', 1153927: 'Gornoe', 1509391: 'Lesnoe', 1926580: 'Cerdanyola del Vallès', 1047678: 'Konezerye', 1513020: 'Novoalexandrovka', 1082687: 'Borki', 1708305: 'Bremervörde', 1084045: 'Pecherskoe', 4478985: 'Lanškroun', 1099194: 'Glazomichi', 1971839: 'Arcadia', 1123171: 'Korbolikha', 1504401: 'Krichovo', 1093896: 'Malinovka', 1046239: 'Yukki', 1063351: 'Rovno', 1714726: 'Bunbury', 1153761: 'Cheriktey', 16256: 'Balyktakh', 1039672: 'Panino (poselok)', 4553564: 'Zvornik', 1125505: 'Velikodvorsky', 2207601: 'Akron', 5011049: 'Fishersville', 1920626: 'Weyers Cave', 1708568: 'Caux', 1079840: 'Krymsky', 1112838: 'Pionersky', 1602890: 'Losha', 1513676: 'Gubcha', 1970831: '?', 1048013: 'Ivanovo', 1512455: 'Kolontaev', 1511797: 'Polupanovka', 5267210: 'Bad Tölz', 1065472: 'Alexandrovka', 1601977: 'Zhemyslavl', 2204279: 'Greencastle', 1713107: 'Hagerstown', 5428521: 'Furmanovo', 1700608: 'Almaly', 22574: 'Thousand Oaks', 12329: 'Beloit', 1709398: 'Barnesville', 1143966: 'Forpost-Kargat', 5057686: 'Copiague', 1700590: 'Avangard', 1111737: 'Troitsky Sungur', 1080402: 'Lyubovnikovo', 1005851: 'Sharlyk', 1148015: 'Fadeevsky', 1601493: 'Kozlovichi', 1079941: 'Novotsimlyanskaya', 1157255: 'Nazarovo', 1146467: 'Bely Yar', 2203678: 'Qingdao City', 1134445: 'Zagarye', 1142627: 'Vysoky Oselok', 1515111: 'Olbin', 1501641: 'Lukovichi', 1028894: 'Kletino', 3138426: 'Khawr Fakkān', 1052023: 'Kozikovo', 1052035: 'Marino', 4968801: 'Tupelo', 3820652: 'Kâmpóng Thum', 1145370: 'Kromy', 1509218: 'Alexandrovka', 1047355: 'Vilpovitsy', 8144: 'Naruto', 1141887: 'Novomochaley', 1914734: 'Marathon', 1518465: 'Dülmen', 1095923: 'Bolshie Klyari', 1097349: 'Uzyak', 1097335: 'Saush', 5267903: 'Wasserburg am Inn', 4000877: 'Surfers Paradise', 1135616: 'Nikolskoe', 1047101: 'Nazia (derevnya)', 1031384: 'Suvorovka', 1901009: 'Fasuta', 2207771: 'Rose Hall', 1092954: 'Zeleny Bor', 1078970: 'Rogalik', 1083549: 'Novaya Karmala', 1503245: 'Rassypnoe', 4544200: 'Monsummano Terme', 1114909: 'Toygildino', 1026017: 'Zubanchi', 1031331: 'Kutuzovo', 1000199: 'Tlyustenkhabl', 1152127: 'Erzovka', 1000751: 'Puchuzhskaya', 4283860: 'Maaskantje', 5448: 'Saratoga', 1067033: 'Tsvelenevo', 1080364: '?', 17953: 'Glukhovo', 1505044: 'Yablonitsa', 1111273: 'Ermolovka', 1031708: 'Zagorskoe', 3257897: 'Kostinbrod', 2201166: '?', 1947140: 'Aguada de Cima', 1008548: 'Ismailovo', 1711467: 'Englewood', 1964133: '?', 1098994: 'Ukhab', 2000567: 'Khaldan', 1702389: 'Bautino', 1500399: 'Ivanovka', 1122786: 'Georgievka', 1049631: 'Yablonovo', 1601703: 'Belitsk', 1932298: 'Sines', 4038871: 'Santiago do Cacém', 1962362: '?', 3855: 'Rosva', 1128560: 'Serafimovka', 1026032: 'Morskoe', 1803593: 'Ina', 1702762: 'Nadezhka', 1133923: 'Nestino', 6073: 'Güby', 1702027: 'Krasnoarmeyskoe', 5427921: 'Bolshoy Chagan', 1049772: 'Sselki', 1158388: 'Demyanskoe', 1953550: 'São João da Madeira', 1152965: 'Vladimirovka', 1919572: '?', 1069546: 'Bulynino', 1514508: 'Frankovka', 4392437: '?', 1506312: 'Alexeevka', 1603077: 'Barsuki', 1601607: 'Lomovichi', 5446717: 'New Taipei', 1505101: 'Kopachintsy', 1067304: 'Bashmakovo', 1715328: 'Greenhithe', 4290617: 'Sitzenberg', 1009260: 'Sakty', 1096934: 'Dva Polya Artash', 1136279: 'Ordzhonikidze', 1057265: 'Usovo', 4374807: 'Georgsmarienhütte', 3979239: 'Kolonia', 1505491: 'Ustye', 1054985: 'Selivanikha', 1514204: 'Budische', 4231379: 'Sculthorpe', 4567814: 'Rosenheim', 1702191: 'Smaylovka', 1924171: 'San Pawl il-Baħar', 3792581: 'Shantou', 1146653: 'Nikolaevka', 1509264: 'Stryukovo', 1137385: 'Proryvnoe', 1128877: 'Onot', 1115010: 'Kudesnery', 1139559: 'Arefino', 1511736: 'Snigirevka', 1158857: 'Ust-Altan', 2205591: 'Rouffach', 1109759: 'Oktyabrsky', 1137417: 'Zhuravlevo', 1129228: 'Zhuravlevo', 4667388: 'Galeón', 4369: 'Oyo', 1954067: 'Lernagog', 1159577: 'Kopyevo', 1516280: 'Baymyrza (pokornoe)', 1100500: 'Shosha', 1700086: 'Novomarinovka', 1122785: 'Voronikha', 1140687: 'Sharypovo (yagodno-Lesnovsky S/s)', 1078747: 'Krutoberezhny', 1510536: 'Chernitsa', 1112209: 'Burannaya', 1504597: 'Mikhaylo-Lukashevo', 1059007: 'Serpukhov-12', 1514808: 'Lomachintsy', 1067010: 'Novoselki', 4235175: 'Leyland', 1507249: 'Shakhterskoe', 1936283: 'Goiânia', 2300566: 'Chat-Kyol', 5055767: 'Princeton Colonial Park', 1022147: 'Kanskoe', 1705358: 'Stratford', 4207394: 'Kalkara', 9678: 'Novoe Domozerovo', 1515011: 'Vaganichi', 1907754: 'Blue Mountains', 1600331: 'Kiselevtsy', 6655: 'Asenovgrad', 5470323: 'Chkhoria', 1504533: 'Zlatopol', 1014862: 'Berezhnovka', 1098263: 'Frolovo', 4480218: 'Kaznějov', 1053571: 'Gryady', 1072037: 'Borovichi', 1086477: 'Belousovo', 1944236: 'Nanuet', 1153775: 'Ust-Yansky', 1518719: 'Melilia', 1106552: 'Mirny', 1706844: 'Sandy Spring', 1068037: 'Shishovka', 1066560: 'Mezensky', 1706907: 'Painesville', 1035443: 'Tereze', 1502673: 'Zaporozhye', 1141237: 'Semenovka', 1110525: 'Udmurt Syugail', 3669573: 'Cẩm Phả', 1007175: 'Kaltasy', 20903: 'Ivanovka', 5370885: 'Caleta de Famara', 7031: 'Karnobat', 1519037: 'Næstved', 4221343: 'Tappernøje', 1054622: 'Staroe', 1803273: 'Are', 1933419: 'Naypyidaw', 1602779: 'Oreshniki', 4226198: 'Gadstrup', 1123395: 'Maralikha', 1920307: 'Londonderry', 2607601: 'Baloži', 1919206: 'Heiligenhaus', 10346: 'Ulakhan-Kyuel', 13955: 'Axvall', 1037275: 'Ust-Nem', 1600164: 'Bolshie Yakovchitsy', 1157634: 'Nikolsk', 1111521: 'Repyevka Kolkhoznaya', 1937551: 'Cles', 1976831: 'Mamou', 1966719: 'Harlingen', 1031170: 'Sadovoe', 3509095: 'Dharmsala', 1113257: 'Arkhangelskoe', 1138134: 'Kanashi', 2607517: 'Verēmi', 5388429: 'Newcastle-under-Lyme', 1966339: '?', 1041963: 'Prikubansky (prikubanskoe S/p)', 1057191: 'Novokubinsky Gorodok', 1602050: 'Peski', 1090123: 'Gedeonovka', 1004752: 'Sosnovka', 1143557: 'Troitskoe', 1513450: 'Kulchievtsy', 1081558: 'Novoe Baturino', 1056454: 'Tsvetkovsky', 5267110: 'Thannhausen', 5263197: 'Scheitenkorb', 5267106: 'Burgau', 4391906: 'Aretsried', 1114536: 'Churachiki', 1114659: 'Loba', 1706057: 'Lamezia Terme', 4642401: 'Sete Lagoas', 1975507: 'Vichy', 1037119: 'Chuprovo', 1506674: 'Vysshie Vereschaki', 1125159: 'Zarechny', 1086168: 'Severny', 1601709: 'Vysokoe', 1077490: 'Pleskovo', 1509361: 'Nadezhda', 1704255: 'Linz am Rhein', 1009525: 'Kazatskoe', 1501983: 'Zalukhov', 1052112: 'Chukaly', 1137154: 'Ivankovo', 1129935: 'Glubokoe', 1084089: 'Progress', 1016864: 'Morozovitsa', 1045196: 'Okhochevka', 1114977: 'Nikulino', 1030609: 'Aushiger', 3162110: 'Aliağa', 1153956: 'Katangli', 1129707: 'S/o Podshipnikovets', 1500957: 'Ivanki', 1960956: 'Reseda', 4566930: 'Bergheim', 1119722: 'Arefino', 1506017: 'Sosnovka', 1515765: 'Buada District', 1503287: 'Opytnoe', 1112696: 'Shaburovo', 1057670: 'Devyatskoe', 1158572: 'Novoselovo', 1059845: 'Chudinovo', 5221042: 'Jarny', 1067865: 'Morsovo', 2500043: 'Vose', 2722598: 'Kabwe', 1503272: 'Stepanovka', 1090732: 'Arkhangelsky', 1068008: 'Fedorovka', 1956054: 'Āstārā', 3853411: '?', 1042445: 'Bolshoe Soldatskoe', 1510879: 'Soldatskoe', 1506874: 'Danilovka', 1155159: 'Oktyabrsky', 20136: '?', 1041397: 'Novotroitsky', 1933387: '?', 1517586: 'Petworth', 1512978: 'Sergievka', 3299080: 'Båtsfjord', 1084651: 'Ternovka', 1138491: 'Gastello', 1511504: 'Chabarovka', 5430761: 'Shengeldy', 5421665: 'Svoboda', 1153207: 'Platono-Alexandrovskoe', 1148323: 'Rodinsky', 5371296: 'San Cristóbal de la Laguna', 1705942: 'Old Windsor', 1509399: 'Petrovka', 1026955: 'Khamavyurt', 1704044: 'Vilvoorde', 1510825: 'Rechki', 1931843: 'Princeton', 4320147: 'Wester-Jork', 1022036: 'Tsareva', 1155279: 'Yuva', 11225: 'Isinga', 1602759: 'Lenino', 1136503: 'Ivanovka', 1136506: 'Ivashikha', 1016292: 'Nikanovskaya', 4223402: 'Nykøbing Falster', 1518274: 'Sèvres', 1704673: 'Lehrte', 1712552: 'Bradford', 1906434: 'Southbourne', 1135449: '?', 1507666: 'Bely Kamen', 9004: 'Bitimka', 1129240: 'Mazurovo', 1048091: '?', 1976492: 'Waremme', 1801408: 'Troitsa', 1093951: 'Tulinovka', 1010369: 'Grafovka', 1515524: 'Peski', 1077893: 'Lenina', 4985263: 'Kemblesville', 4937948: 'Straughn', 1002532: 'Shozhma', 1143521: 'Andreevka', 1513364: 'Nesterovtsy', 1108535: 'Maysky', 5266941: 'Mainburg', 1075991: 'Khomutovo', 1947374: 'Monheim am Rhein', 1075910: 'Spasovschina', 1957383: 'Buffalo', 1916961: '?', 1159427: 'Podsinee', 2722549: 'Cruz Bay', 2722548: 'Christiansted', 1504261: 'Novoselitsa', 1078295: 'Verkhneserebryakovka', 1518496: 'Kesaria', 1507970: 'Beskovichi', 1975698: 'Traben-Trarbach', 1704834: 'Enugu', 1063607: 'Borisovo', 4243193: 'Wildhaus', 1015645: 'Pisarevka', 1959874: 'Chiavari', 1803713: 'Jamestown', 1159515: 'Kirba', 1159525: 'Novotroitskoe', 1513519: 'Chepelovka', 4635905: 'Seltjarnarnes', 1122854: 'Bezrukavka', 1516765: 'Ptich', 5266922: 'Schrobenhausen', 1116949: 'Melenki', 1945749: 'Lanchkhuti', 1085004: 'Schigry', 19806: 'Polevaya', 1144889: 'Cherny Mys', 1153747: 'Dygdal', 1153801: 'Ulakh-An', 1015414: 'Ilovatka', 1134746: 'Apuka', 1031125: 'Belkino', 1147547: 'Labazy', 1112749: 'Novoershovsky', 1960501: 'Leżajsk', 1143860: 'Ulybino', 1006768: 'Beloretsk', 1030836: 'Dobrino', 1514008: 'Skibin', 1906648: '?', 1920072: 'Saint Martin', 1513885: 'Seredintsy', 1104104: 'Korenicheno', 1035841: 'Engozero', 1512320: 'Paseki', 1059088: 'Dubinino', 1055270: 'Starodub', 1507336: 'Podgorovka', 1058539: 'Vasilyevskoe', 1507186: 'Blagovka', 1025045: 'Rozhdestvenskoe', 1046233: 'Shampoladieva Dacha', 1511428: 'Beremyany', 16967: 'Tovarkovo', 1096143: 'Smoldeyarovo', 1976027: 'Bedworth', 1500692: 'Desna', 1008899: 'Klyuchevka', 1601353: 'Krasny Pilschik', 5368822: 'Playa Flamenca', 1513341: 'Gannovka', 1128173: 'Krivoshapkino', 1800993: 'Oknitsa ', 5009671: 'Castle Rock', 1142604: 'Rozhok', 1142580: 'Lesunovo', 1712116: 'Voronkovo', 1513624: 'Dovzhki', 4977204: 'Barnegat', 6236: 'Kriushi', 1507615: 'Volya-Vysotskaya', 1079140: 'Varenovka', 1700340: 'Bogoslovka', 1145784: 'Mokhovoy Prival', 1941416: 'Williams Lake', 1500995: 'Kozhukhov', 5082222: 'South Royalton', 1906109: '?', 1958650: '?', 1147779: 'Gorodische', 1061124: 'Shuya', 1002916: 'Pivka', 1501011: 'Selische', 4539748: 'Sarzana', 1962640: 'Sarzana', 1085507: 'Ozerki', 1071393: 'Pavlovo', 1800040: 'Baymaklia', 1013248: 'Dubrovka', 5002186: 'Carrollton', 1002629: 'Shasta', 3264484: 'Tokat', 1030578: 'Nizhny Cherek', 1083434: 'Privet', 4624852: 'Olinda', 1502611: 'Maryevka', 1711221: '?', 1602485: 'Obchuga', 1700609: 'Kusain Bizhanov', 1033698: 'Kollontay (derevnya)', 6916: 'Zeven', 22601: '?', 1018146: 'Nadeevo', 5267878: 'Neufahrn bei Freising', 1709695: 'Dąbrowa Górnicza', 1035406: 'Ordzhonikidzevsky', 1091704: 'Vrevskoe', 1113713: 'Chechen-Aul', 1704564: 'Hadsten', 1150245: 'Ponosova', 1501368: 'Kleban', 1011391: 'Ormenka', 4362915: 'Ittersbach', 1060339: 'Ena', 1510471: 'Serniki', 4989918: 'East Spartanburg', 1159347: 'Blagodatnoe', 1129927: '?', 1067573: 'Gorodok', 1513084: 'Stepanovka', 1514120: 'Grischintsy', 1153968: 'Kolendo', 1501465: 'Verbka', 1153767: 'Kyuptsy', 1011798: 'Nikolskaya Sloboda', 1032001: 'Rybachy', 1038619: 'Doroginya', 1972959: 'Berrie', 1049204: 'Voronets', 3963662: 'Hulunbuir', 8917: 'Beloozersk', 1089263: 'Shmakovo', 1513920: 'Skarzhintsy', 1121952: 'Verkh-Katunskoe', 1922827: 'Ordino', 1083987: 'Podstepki', 1153819: 'Kharbala 1-Ya', 5094767: 'Shingle Springs', 1511159: 'Andriashevka', 1083605: 'Leninsky', 4458451: 'Rezi', 1022617: 'Kraskovo', 1052503: 'Svezhenkaya', 1055176: 'Bogatischevo', 1144928: 'Scherbaki', 10442: 'Ocheretinoe', 1153231: 'Narva', 1917933: 'Aspindza', 1144198: 'Burundukovo', 1135721: 'Novotroitsk', 1908289: 'Pirdop', 1116023: 'Vysokovo (vysokovskaya S/a)', 1510120: 'Vishnyaki', 5345948: 'Marina di Pulsano', 1902627: '?', 1602387: 'Sakovschina', 1513494: 'Zapadintsy', 1151163: 'Andreevka', 1509155: 'Serbka', 1049988: 'Travinka', 1124306: 'Tuzhinka', 1509950: 'Sokolova Balka', 1921540: 'Velten', 19751: 'Jacksonville', 5266285: 'Herten', 5266286: 'Marl', 1086976: 'Uspenskoe', 1142296: 'Ratovo', 1511360: 'Nadrechnoe', 1128908: 'Tyumen (derevnya)', 2722622: 'Hagåtña Heights', 1714748: 'Redruth', 4539759: 'Sarnano', 1043939: 'Adoeva', 4904949: 'Vaitape', 6684: 'Akademichesky', 1509726: 'Lutovinovka', 1148308: 'Matveevka', 1155065: 'Kremlevka', 5267497: 'Altmannstein', 1079460: 'Kovrino', 1054342: 'Kutuzovo', 1050102: 'Verkhnyaya Mosolovka', 5267345: 'Weidenbach', 1122116: 'Malinovsky', 1516667: 'Walsall', 1062864: 'Shuya', 1964102: '?', 1701139: 'Pervorossiyskoe', 1148331: 'Tolkaevka', 1146950: 'Novosultangulovo', 1078111: 'Dalny', 1035544: 'Zolotets', 1007698: 'Krivle-Ilyushkino', 1029910: 'Kargashino', 4369706: '?', 1502715: 'Blagodatnoe', 1506109: 'Ulyanovka', 1112882: 'Amineva', 1056034: 'Ushakovo', 1944854: 'Fort Bragg', 5211892: '?', 1012276: 'Buyan', 1073940: 'Pestovo', 1113729: 'Nizhny Noybera', 1513382: 'Beleevo', 4511102: 'Tarazona', 1114964: 'Kozlovka', 1013632: 'Polevye Novoselki', 1072803: 'Glubokoe', 1129252: 'Novostroyka', 1502358: 'Naberezhnoe', 1503208: 'Petrovskoe', 1035811: 'Karelsky', 4242560: 'Ashford', 3838: '?', 1109443: 'Pikhtovka', 1907357: 'Noordwijkerhout', 1113782: 'Nikolaevskaya', 1955826: 'Lexington', 1084981: 'Bartenevka', 1516088: 'La Coruña (Canarias)', 1705252: 'Krosno', 3136124: 'Tulkarm', 3782051: 'Shangqiu', 4102329: 'Benin-City', 4972844: 'Kitty Hawk Beach', 1515075: 'Khaenki', 2100113: 'Markhamat (markhamatsky Rayon)', 5116919: 'East Wenatchee', 1603056: 'Dobraya', 1077247: 'Pripeshi', 1044939: 'Pravaya Lipa', 5112290: 'Spokane', 1703065: 'Tasaryk', 5430636: 'Mayatas', 1146391: 'Zalivino', 1146882: 'Marxovsky', 1093040: 'Rybnoe', 1093562: 'Pavlodar', 1060653: 'Volgino', 5263515: '?', 5266529: 'Battenberg (Eder)', 2300147: 'Boz-Uchuk', 1145928: 'Khomutinka', 5326788: 'Tholos (Rhodos)', 2300243: 'Debelyuu', 1035293: 'Mokroe', 1122692: 'Borovikha', 4997789: 'Loretto', 1106955: 'Zavodskoy', 1505403: 'Pukov', 1148247: 'Grigoryevka', 4008269: 'Russell', 5227897: 'Montévrain', 1969756: '?', 1037302: 'Medvezhka', 1083905: 'Krasnoselskoe', 1001861: 'Gorodischenskaya', 4488902: 'Tarnów', 1510105: 'Panivanovka', 1122127: 'Borisovo', 4695501: 'Hog Bay', 2200611: 'Lorut', 1007929: 'Kameevo', 1701605: 'Chirovo', 1503606: 'Stremigorod', 1702773: 'Dubrovnoe', 1901778: 'Laurel', 4177292: 'Al Metlaoui', 4648660: 'Limeira', 1002746: 'Shirokoe', 1517785: 'Moline', 1709477: 'Bettendorf', 1511237: 'Uralovo', 1504906: 'Lagidnoe / Kirovo', 3498621: 'Puducherry', 1157459: 'Komsomolsky', 1600050: 'Narutovichi', 1507112: 'Zaaydarovka', 1510656: 'Kozin', 1161117: 'Khorey-Ver', 1121959: 'Maloeniseyskoe', 1801455: 'Floresht', 1602746: 'Podlesye', 5029609: 'Harwood Heights', 1044514: 'Zamostye', 15435: 'Skive', 1068683: 'Alferyevka', 3722544: '?', 1803271: 'Värska', 1005227: 'Novokataevo', 3038950: 'Radā`', 2722531: 'Sucre', 1707284: 'Cochabamba', 4705590: 'Escuintla', 1508212: 'Kavskoe', 1151865: 'Brekhovo', 1047827: 'Stavotino', 1009531: 'Krasny Oktyabr', 4230543: 'Stirling', 1511912: 'Romanovka', 1139968: 'Krasnaya Gorka', 1009046: 'Rapat', 18087: 'Olonki', 3146369: '?', 1058420: 'Polushkino', 4323617: '?', 1042288: 'Tsypka', 3125832: 'Saloníki', 1514450: 'Borovitsa', 1132545: 'Zarya', 1518814: 'Kranj', 1028208: 'Schastlivka', 1059869: 'Baksheevo', 1094823: 'Starye Yumraly', 1055060: 'Onufrievo', 3741757: 'Pasay', 5266208: 'Kempen', 1030847: 'Zaozerye', 1096731: 'Stepnoe Ozero', 1128909: 'Uzky Lug', 5430015: 'Akanbarak', 5064310: 'Centerburg', 1157310: 'Orlovo', 1028651: 'Kukarino', 20530: 'Vereya', 1037261: 'Pozheg', 1510197: 'Gogolevo', 1147983: 'Alyabyevo', 1505523: 'Starye Krivotuli', 5266291: 'Greven', 1509518: 'Knishovka', 1920398: '?', 5259825: '?', 1500701: 'Lisogorka', 1702012: 'Pereleski', 1078764: 'Novosadkovsky', 1156411: 'Itatka', 5118146: 'Puyallup', 1136138: '?', 4378207: '?', 1702558: 'Khmelnitskoe', 1915037: 'Schüttorf', 1084071: 'Abashevo', 1095390: 'Alan-Bexer', 4549268: 'Casalecchio di Reno', 4549991: 'Calderara di Reno', 1061760: 'Komarovo', 1601743: 'Boroviki', 1500643: 'Berezovka', 5094445: 'San Francisco', 1129984: 'Alexeevka', 1032497: 'Kartsovo', 1091654: 'Pervomayskoe', 1058360: 'Lyskovo', 1923717: 'Mineola', 1514722: 'Oshikhleby', 1701861: 'Ivanovka', 1091344: 'Mikheykovo', 1091479: 'Rodnikovskoe', 1105736: 'Tsentralny', 1078321: 'Kuteynikovo', 1111920: 'Bolshoy Kuvay', 4484567: 'Březůvky', 22521: 'Bačka Palanka', 1700253: 'Vasilyevka', 1083370: 'Poludni', 1516439: 'Châlons-en-Champagne', 4389962: '?', 1701410: 'Zhambyl', 1014749: 'Tsarev', 2300680: 'Bad Leonfelden', 20596: 'Mezhevoy', 1136442: '?', 1144155: 'Lotoshnoe', 1156739: 'Ezhi', 2792: 'Andenes', 1079083: 'Prishib', 1023947: 'Shishovka', 1041526: 'Razdolnoe', 3172748: 'Hawassa', 5259842: '?', 1025808: 'Tatayurt', 1600946: 'Azino', 5366731: '?', 1506957: 'Samsonovka', 1094749: 'Staraya Mikhaylovka', 5129760: "St. John's", 4541074: 'Rubiera', 1049799: 'Ivovo', 1110817: 'Chekan', 20045: 'Serebryanka', 1122802: 'Podstepnoe', 3141516: 'Tire', 1509878: 'Kustolovo-Sukhodolka', 1007219: 'Tayga', 1600310: 'Minyanka', 1085957: 'Sinenkie', 12625: 'Tesovo-Netylsky', 1013186: 'Semtsy', 1114138: 'Staroe Akhperdino', 4249143: 'Tibro', 1054993: 'Lobanovo', 5237682: '?', 11777: 'Margate', 3279410: 'Warka', 1154311: 'Pisanets', 5058197: 'East Syracuse', 1033273: 'Kamenka', 1908702: 'Coquitlam', 1057781: 'Podsobnoe Kh-Vo Minzag', 1008068: 'Timyashevo', 1511693: 'Losyatin', 1004563: 'Ushakovka', 1711246: 'Santa Rosa Beach', 8112: 'Marinskaya', 1068409: 'Uspenskoe', 1507983: 'Dublyany', 1032369: 'Kabitsino', 5126934: 'Mahone Bay', 4956959: 'Pasadena Manor', 5032324: 'Gas City', 1036290: 'Rybreka', 1004288: 'Mumra', 1057582: 'Kazanskoe', 1148142: 'Cherkassy', 5330430: 'Echichens', 1707647: 'Renens', 4244189: 'Pampigny', 1100841: 'Sokolniki', 1515505: 'Kienka', 4337999: '?', 4567876: 'Gründau', 1059263: 'D/o Morozovka', 1146250: 'Bazhenovo', 1600734: 'Shunevtsy', 1500761: 'Chechelovka', 1024510: 'Pochepskoe', 1028538: 'Rozhdestvenno', 3317181: 'Kalane', 1005477: 'Sokolki', 1158552: 'Karbany', 1514981: 'Sivolozh', 1106334: 'Turdey (mo Turdeyskoe)', 1049722: 'Svkh Agronom', 1144016: 'Sokolovo', 1501006: 'Penkovka', 5055012: 'Hamilton Square', 1060445: 'Varzuga', 16046: 'Stary Kalmash', 1510659: 'Krupets', 1135797: 'Chelnoki', 1115414: 'Malye Tuvany', 1095620: 'Stary Kuklyuk', 1129084: 'Dunay-Klyuch', 1111563: 'Lebyazhye', 3830704: 'Anyang', 4494515: 'Oświęcim', 1143846: 'Preobrazhenka', 1506129: 'Radinka', 11111: '?', 2206725: 'Diourbel', 5470318: 'Konchkati', 1022073: 'Bogorodskoe', 1091783: 'Kanovo', -295: -295, 1935303: 'Ellicott City', 1014007: 'Ryukhov', 4377014: 'Flomborn', 1500677: 'Chernyatka', 1602715: 'Sedcha', 1105927: 'Begichevsky', 4349346: 'Nassau', 1155868: 'Asbest (poselok)', 1151832: 'Sim', 1030497: 'Kenzhe', 1509943: 'Nekhvoroscha', 2000720: 'Boladi', 1053784: 'Yaropolets', 1011629: 'Druzhba', 1502360: 'Novoivanovka', 4452268: 'Beaumont-le-Roger', 1012315: 'Kirov', 5090930: 'East Pleasanton', 2001260: 'Holtsville', 1509767: 'Beletskovka', 1509792: 'Chechelevo', 1095429: 'Kazaklar', 1969765: 'Skierniewice', 1505451: 'Yasen', 1706940: 'Saint Peter', 1150400: 'M.rechka', 1056627: 'Bekasovo-1', 1106178: 'Sosenki', 3257156: 'Mezdra', 1094397: 'Novoe Ibraykino', 1123311: 'Nizhnyaya Gusikha', 5031336: 'Tennessee', 1910062: 'Marion', 1944575: 'Saas-Fee', 1512256: 'Dvurechny Kut', 1158672: 'Shakhovskaya', 1098343: 'Korykhnovo', 1001753: 'Faustovo', 1068923: 'Kalinovka', 5238234: '?', 1042396: 'Goptarovka', 1505478: 'Popelniki', 1129753: 'Pushkino', 1512518: 'Ukrainskoe / Petrovskoe', 1501476: 'Tartak', 1063676: 'Zaluchye', 4533637: 'Knappstad', 1947137: 'Mittersill', 1137264: 'Vasilki', 1800801: 'Mindzhir', 1004125: 'Bolkhuny', 1025545: 'Sergeevka', 1123130: 'Volodarka', 1503222: 'Grekovo-Alexandrovka', 1519297: 'Vero Beach', 1700748: 'Terekty', 1154312: 'Pokrovskoe', 1149162: 'Yubileyny', 4497559: 'Lubawa', 1500475: 'Novoselovka', 4229379: 'Uttoxeter', 3961896: 'Siping', 1946967: 'Belluno', 1602430: 'Moroch', 1085748: 'Ekaterinovka', 1084435: 'Alexeevka', 5330606: 'Ilinskoe', 1086033: 'Kurdyum', 1962176: 'Shulaveri', 5073599: 'Long Pond', 1511434: 'Zhiznomir', 1709527: 'Prostějov', 1510524: 'Nevirkov', 1012921: 'Lobki', 1510483: 'Zdovbitsa', 4550673: 'Besana in Brianza', 1938313: 'Desio', 1702722: 'Ukrainskoe', 15834: 'Savostino', 20527: 'Bakbakty', 1511135: 'Zinovo', 1513230: 'Solomnaya', 1047643: 'Zaperedolye', 3218539: 'Lohja (Lojo)', 1500607: 'Zhuravlevka'}

# %%
# Создаем соединение с нашей базой данных
# В нашем примере у нас это просто файл базы
conn = sqlite3.connect(dbase_city)

# Создаем курсор - это специальный объект который делает запросы и получает их результаты
cursor = conn.cursor()

cursor = conn.execute("SELECT id_city, name_city from CITIES")

results = cursor.fetchall()
    
print ("Operation done successfully")


# Не забываем закрыть соединение с базой данных
conn.close()
# Out:
# Operation done successfully

# %%
print(results[0:5])
print(len(results))
# Out:
# [('2', 'Saint Petersburg'), ('458', 'Berlin'), ('16', 'Torino'), ('314', 'Kyiv'), ('1713650', 'Heraklion')]
# 170592

# %%
#fill from base cities
city_id_dict={}
city_erorr={}

for ii in range(0,len(results)):
    if str(results[ii][0]) in city_id_dict:
        city_erorr[str(results[ii][0])]=str(results[ii][1])
    else:
        city_id_dict[str(results[ii][0])]=str(results[ii][1])
    
    
    
print(len(city_id_dict))
print(len(city_erorr))
# Out:
# 103963
# 66629

# %%
city_id_dict_base={}

for ii in range(0,len(results)):
    city_id_dict_base[str(results[ii][0])]=str(results[ii][1])
    
    
print(len(city_id_dict_base))
# Out:
# 103963

# %%
print(city_id_dict['2'])
# Out:
# Saint Petersburg

# %%
token = '74cc2fc574cc2fc574cc2fc51674bd0ddd774cc74cc2fc52a52f6d01cd4498f9b895e70'

# %%
def city_id (city_id):
    if city_id in city_id_dict.keys():
        return city_id_dict[city_id]
    else:
        try:
            url = 'https://api.vk.com/method/database.getCitiesById' 
        # start = timer()

            params = {'city_ids':city_id,'v': 5.103,'access_token': token}  

            response_city=requests.get(url, params=params) 
            response_city=response_city.json()['response']#['title']
            if len(response_city)>0:
                X= response_city[0]['title']
                if X =='':
                    X='?'
            else: 
                X=city_id

            #add new city to the dict
            city_id_dict[city_id]=X
        except:
            timer.sleep(5)
            return city_id (city_id)
        
   # end = timer()
   # print('city_id_func___',(end - start)*10000000)
        
    return X


# создание функции country_id 

url = 'https://api.vk.com/method/database.getCountries' 

params = {'need_all': 1,'v': 5.103,'access_token': token, 'count':1000}  

response_county=requests.get(url, params=params) 
response_county=response_county.json()['response']#['title']
pprint(response_county['items'][0])

country_dict={}
for i in range(0,234):
    country_dict[response_county['items'][i]['id']]=response_county['items'][i]['title']

def country_id (country_id):
    if country_id in country_dict.keys():
        return country_dict[country_id]
    else:
        return country_id

country_id (0)
# Out:
# {'id': 30, 'title': 'Afghanistan'}
# 0

# %%
def user_get(multi,k,token):

    url = 'https://api.vk.com/method/users.get' 
    #token = '74cc2fc574cc2fc574cc2fc51674bd0ddd774cc74cc2fc52a52f6d01cd4498f9b895e70'
    f='id, skype, facebook, twitter, livejournal, Instagram, contacts, mobile_phone, home_phone, site, first_name, last_name, about, activities, bdate, city, country, books, career, domain, education, followers_count, games, home_town, interests, last_seen, maiden_name, movies, music, nickname, occupation, personal, photo_100, photo_max_orig, quotes, relatives, relation, schools, screen_name, sex, status, tv, universities, university, university_name, faculty, faculty_name, chair_name, graduation, education_form, education_status'    

    ids = ",".join(map(str, range(multi*k, (multi*(k+1))))) #

    params = {'user_ids': ids, 'v': 5.103, 'fields': f, 'access_token': token, 'lang': 'ru'}  

    response_vk=requests.get(url, params=params) 
    
    return response_vk

# %%
from gtts import gTTS
import playsound

def speak(text):
    tts = gTTS(text=text, lang='en')
    filename = '/Users/romanpodoynitsyn/voice.mp3'
    tts.save(filename)
    
    playsound.playsound(filename)

# %%
415440198/200
# Out:
# 2077200.99

# %%
import time
import requests
from tqdm import tqdm,trange

miss_list=('deactivated', 'is_closed', 'can_access_closed','blacklisted,counters','photo_50,photo_200_orig', 'photo_200', 'photo_400_orig', 'photo_max', 'timezone', 'trendin', 'verified', 'wall_default')


multi=200 #размер запроса

response_bucket=list()

for k in trange(2077201,22500000): #количество запросов = порядковый номер юзера
         #309401
        
        try:
            response_vk=user_get(multi,k,token)
            #print(response_vk.status_code)
            #print('ids__',ids)
        except:
            time.sleep(60)
            print('error')
            speak('skvidvart andrey')
            response_vk=user_get(multi,k,token)
        
        try:
            
            if 'response' in response_vk.json():
                response_v=response_vk.json()['response']
                response_bucket=response_bucket+response_v
                #print('attempt')
        except:
            print('error_response')
            speak('skvidvart andrey')
            break

        if k%50 ==0:

            #print(response_vk.status_code)
            #start = timer()

            LLL1=list()

            LLL0=robot_1(response_bucket)
                #LLL0=replace_(LLL0)
            LLL1=turn_to_list(LLL0)

            #print('len_bucket______',len(response_bucket))
            #print('len_LLL1_____',len(LLL1))
            response_bucket=list()

            end = timer()
            #print('replace+robot___',(end - start))

            #print('check_2')
            if len(LLL1) == 0:
                print('check_continue')
                continue
            else:

                #start = timer()
                try:
                    
                    write_to(LLL1)
                    #print('id_last_to_base',print(LLL1[len(LLL1)-1][0]))
                except:
                    time.sleep(60)
                    print('error_datbase')
                    write_to(LLL1)
                #end = timer()
                #print('write_to_base___',(end - start)) 
    #except:
        #print('k___',k)
        
       # 61896984
# Out:
# ...
#   0%|          | 891/20422799 [1:06:31<18698:06:37,  3.30s/it]

# %%
print(response_vk.text)

# %%
print(LLL1[148])

# %%
print(LLL1[len(LLL1)-1][0])

# %%
149998197/200

# %%
response_bucket=list()

# %%
print(len(city_id_dict))

# %%
dbase='workbase_9.db'

conn = sqlite3.connect(dbase)
print ("Opened database successfully")

conn.execute('''CREATE TABLE CITIES
         (
         id_city, name_city
         );''')
print ("Table created successfully")


conn.close()

# %%
city_tuple=list()
for k in city_id_dict.keys():
    temp=list()
    temp.append(k)
    temp.append(city_id_dict[k])
    city_tuple.append(temp)

# %%
print(city_tuple[0])

# %%
def write_to_city (LLL):
    conn = sqlite3.connect(dbase_city)
    print ("Opened database successfully")
    cursor = conn.cursor()

    #cursor.executemany("REPLACE INTO CITIES VALUES (?,?)", LLL)
    cursor.executemany("INSERT OR IGNORE INTO CITIES VALUES (?,?)", LLL)

    conn.commit()
    print ("Records created successfully")
    conn.close()

# %%
def uniq ():
    conn = sqlite3.connect(dbase_city)
    #print ("Opened database successfully")
    cursor = conn.cursor()

    cursor.execute("CREATE UNIQUE INDEX idx_city ON CITIES (id_city)")

    conn.commit()
    #print ("Records created successfully")
    conn.close()

# %%
uniq()

# %%
write_to_city(city_tuple)

# %%
100420200/200

# %%
multi=10

for k in range(0,10):
    #try:
        print(multi*k, '____',multi*(k+1))

# %%
print(response_vk[0])

# %%
def count_max_user (dbase):
    conn = sqlite3.connect(dbase)
    print ("Opened database successfully")
    cursor = conn.cursor()

    cursor.execute("SELECT MIN(id) FROM F" )
    print(cursor.fetchall())

    #conn.commit()
    #print ("Records created successfully")
    conn.close()

# %%
#find max user
count_max_user ('workbase_friends_2.db')

# %%
print(cursor.fetchall())

# %%
response_vk[6]

# %%
multi=400 #размер запроса

for k in range(2738,2800): #ко
    print(multi*k, (multi*(k+1)))

# %%
#print(city_id_dict)

# %%
import requests
        
url = 'https://api.vk.com/method/users.get' 
token = '74cc2fc574cc2fc574cc2fc51674bd0ddd774cc74cc2fc52a52f6d01cd4498f9b895e70'
f='id, skype, facebook, twitter, livejournal, Instagram, contacts, mobile_phone, home_phone, site, first_name, last_name, about, activities, bdate, city, country, books, career, domain, education, followers_count, games, home_town, interests, last_seen, maiden_name, movies, music, nickname, occupation, personal, photo_100, photo_max_orig, quotes, relatives, relation, schools, screen_name, sex, status, tv, universities, university, university_name, faculty, faculty_name, chair_name, graduation, education_form, education_status'    
        
#ids = 43007198
ids = ",".join(map(str, range(149998197, 149998198)))

params = {'user_id': 149998197, 'v': 5.103, 'fields': f, 'access_token': token, 'lang': 'ru'}  

response_vk=requests.get(url, params=params) 
print(response_vk.status_code)
print(response_vk.text)
        
if 'response' in response_vk.json():
    print(response_vk.json()['response'])

# %%
print(ids)

# %%
for i in range(1,10):
    try:
        print(i/0)
    except:
        print('erorr')
        if i%5==0:
            print('i__',i)
            break
    print('lets go')

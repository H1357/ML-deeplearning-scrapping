# %%
import sqlite3

conn = sqlite3.connect(dbase)
print ("Opened database successfully")

conn.execute('''CREATE TABLE USERS
         (
         idvk, first_name, last_name, deactivated, is_closed, can_access_closed, about, activities, bdate, blacklisted, books, career, city, skype, facebook, twitter, livejournal, Instagram, contacts, mobile_phone, home_phone, counters, country, domain, education, followers_count, games, home_town, interests, last_seen, maiden_name, military, movies, music, nickname, occupation, personal, photo_50, photo_100, photo_200_orig, photo_200, photo_400_orig, photo_max, photo_max_orig, quotes, relatives, relation, schools, screen_name, sex, site, status, timezone, trendin, tv, universities, verified, university, university_name, faculty, faculty_name, chair_name, graduation, education_form, education_status, political, langs, religion, inspired_by, people_main, life_main, smoking, alcohol, city_name, country_name, university_name_, faculty_name_, graduation_, platform, last_time, relation_name,  occupation_type, occupation_place   TEXT    
         
         );''')
print ("Table created successfully")

#school_1_country, school_1_city, school_1_name, school_1_year_from, school_1_year_to, school_1_year_graduated, school_1_class, school_1_speciality, school_1_type_str, school_2_country, school_2_city, school_2_name, school_2_year_from, school_2_year_to, school_2_year_graduated, school_2_class, school_2_speciality, school_2_type_str,


conn.close()

# %%
from pprint import pprint  
import requests  
import sqlite3

# %%
def write_to (LLL):
    conn = sqlite3.connect(dbase)
    print ("Opened database successfully")
    cursor = conn.cursor()

    cursor.executemany("INSERT INTO USERS VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)", LLL)

    conn.commit()
    print ("Records created successfully",'____', LLL[0][0])
    conn.close()

# %%
def robot(response_):

    LLx=list()
    LLL=tuple()
    
    for ii in range(0, len(response_)):
        LL=list()
       # print(ii)
        user = response_[ii]
        if 'deactivated' in user:
            continue
       # user =list(response[ii])
        for X in L:
            if X in user:
                LL.append(str(user[X]))
               # print('yes')
            else:
                LL.append('NULL')
                #print('no')


        #print(ii, school_funk (user)[0],school_funk (user)[1])

        LL=LL+personal_result_funk (user)
        LL.append(city_funk(user))
        LL.append(country_funk(user))
        LL=LL+education_funk(user)
        LL=LL+last_seen_funk(user)
        LL.append(relation_funk(user))


       # LL=LL+school_funk (user)[0]
        #LL=LL+school_funk (user)[1]
        LL=LL+occupation_funk(user)

        LLx.append(LL)
        #print('check lll')
        LLL=tuple(LLx)
        
    #if len(LLL)==0:
        #LLL=tuple(LLx)
    return LLL

# %%
def city_id (city_id):
    url = 'https://api.vk.com/method/database.getCitiesById' 
    

    params = {'city_ids':city_id,'v': 5.103,'access_token': token}  

    response_city=requests.get(url, params=params) 
    response_city=response_city.json()['response']#['title']
    X= response_city[0]['title']
    if X =='':
        X='NULL'
    print('citi_id')
    return X

'''
    url = 'https://api.vk.com/method/database.getCountriesById' 
    
    params = {'city_ids':country_id,'v': 5.103,'access_token': token}  

    response_country=requests.get(url, params=params) 
    response_country=response_country.json()#['response']#['title']
    X= response_country
    #if X =='':
    #    X='NULL'
    return X
'''
# создание функции country_id 

url = 'https://api.vk.com/method/database.getCountries' 

params = {'need_all': 1,'v': 5.103,'access_token': token, 'count':1000}  

response_county=requests.get(url, params=params) 
response_county=response_county.json()['response']#['title']
pprint(response_county['items'][0])

country_dict={}
for i in range(0,234):
    country_dict[response_county['items'][i]['id']]=response_county['items'][i]['title']

def country_id (country_id):
    return country_dict[country_id]

country_id (30)

# %%
education_=['university_name', 'faculty_name', 'graduation']
education_NULL=['NULL','NULL','NULL']

personal_ = ['political','langs','religion','inspired_by','people_main','life_main','smoking','alcohol']
personal_NULL=['NULL','NULL','NULL','NULL','NULL','NULL','NULL','NULL']

occupation_=['type','name']
occupation_NULL=['NULL','NULL']

school_=['country','city','name','year_from','year_to','year_graduated','class','speciality','type_str']
school_NULL=['NULL','NULL','NULL','NULL','NULL','NULL','NULL','NULL','NULL']

political_dict={'0' : 'NULL',
    '1' : 'коммунистические',
'2' : 'социалистические',
'3' : 'умеренные',
'4' : 'либеральные',
'5' : 'консервативные',
'6' : 'монархические',
'7' : 'ультраконсервативные',
'8' : 'индифферентные',
'9' : 'либертарианские'}

people_main_dict={'0' : 'NULL',
                  '1' : 'ум и креативность',
'2' : 'доброта и честность',
'3' : 'красота и здоровье',
'4' : 'власть и богатство',
'5' : 'смелость и упорство',
'6' : 'юмор и жизнелюбие'
}

life_main_dict={'0' : 'NULL',
                '1':'семья и дети',
'2':'карьера и деньги',
'3':'развлечения и отдых',
'4':'наука и исследования',
'5':'совершенствование мира',
'6':'саморазвитие',
'7':'красота и искусство',
'8':'слава и влияние'}

smoking_dict={'0' : 'NULL',
'1' :'резко негативное',
'2' : 'негативное',
'3' : 'компромиссное',
'4' : 'нейтральное',
'5' : 'положительное'}
alcohol_dict={'0' : 'NULL',
'1' :'резко негативное',
'2' : 'негативное',
'3' : 'компромиссное',
'4' : 'нейтральное',
'5' : 'положительное'}

platform_dict={
'1':  'мобильная версия',
'2':  'приложение для iPhone',
'3':  'приложение для iPad',
'4':  'приложение для Android',
'5':  'приложение для Windows Phone',
'6':  'приложение для Windows 10',
'7':  'полная версия сайта',
}


relation_dict={ 
'1' : 'не женат/не замужем',
'2' : 'есть друг/есть подруга',
'3' : 'помолвлен/помолвлена',
'4' : 'женат/замужем',
'5' : 'всё сложно',
'6' : 'в активном поиске',
'7' : 'влюблён/влюблена',
'8' : 'в гражданском браке',
'0' : 'NULL'}


def personal_result_funk (user):

    personal_result=list()

    if 'personal' in user:
        personallist=user['personal']

        for X in personal_:
            if X in personallist:
                if (X=='political' and personallist[X] in political_dict.keys()):
                    personal_result.append(political_dict[str(personallist[X])])
                    continue
                if (X=='people_main' and personallist[X] in people_main_dict.keys()):
                    personal_result.append(people_main_dict[str(personallist[X])])
                    continue
                if (X=='life_main' and personallist[X] in life_main_dict.keys()):
                    personal_result.append(life_main_dict[str(personallist[X])])
                    continue
                if (X=='smoking' and personallist[X] in smoking_dict.keys()):              
                    personal_result.append(smoking_dict[str(personallist[X])])
                    continue
                if (X=='alcohol' and personallist[X] in alcohol_dict.keys()):
                    personal_result.append(alcohol_dict[str(personallist[X])])
                    continue
                else:
                    personal_result.append(str(personallist[X]))
               # print('yes')
            else:
                personal_result.append('NULL')
                
                
    else: 
        personal_result=personal_result+personal_NULL
    return personal_result


def education_funk (user):

    _result=list()

    if 'education' in user:
        educationlist=user['education']

        for X in education_:
            if X in educationlist:
                _result.append(str(educationlist[X]))
                         
            else:
                _result.append('NULL')
                
                
    else: 
        _result=_result+education_NULL
    return _result

def occupation_funk (user):

    _result=list()

    if 'occupation' in user:
        occupationlist=user['occupation']

        for X in occupation_:
            if X in occupationlist:
                _result.append(str(occupationlist[X]))
                         
            else:
                _result.append('NULL')
                
                
    else: 
        _result=_result+occupation_NULL
    return _result

def city_funk (user):
    if 'city' in user:
        city_result=user['city']['title']
        
    else:
        city_result='NULL'
    return str(city_result)

def country_funk (user):
    if 'country' in user:
        result=user['country']['title']
        
    else:
        result='NULL'
    return str(result)


import datetime

def last_seen_funk (user):
    time_result=list()
    if 'last_seen' in user:    
        if 'platform' in user['last_seen']:
            time_result.append(platform_dict[str(user['last_seen']['platform'])])
        else:
            time_result.append('NULL')
        if 'time' in user['last_seen']:
        
            time_seen=datetime.datetime.fromtimestamp(user['last_seen']['time'])
            time_result.append(time_seen.strftime('%Y-%m-%d %H:%M:%S'))
        else:
            time_result.append('NULL')
    else:
        time_result.append('NULL')
        time_result.append('NULL')
    return time_result

def relation_funk (user):
   
    if ('relation' in user and user['relation'] in relation_dict.keys()) :    
      
        _result=relation_dict[str(user['relation'])]
      
    else:
        _result=relation_dict['0']
       
    return _result



def school_funk (user):

    _result_1=list()
   

    if 'schools' in user:
        school_that=user['schools']
        
        if len(school_that)>1:
            for i in range(0,len(school_that)):

                school_that_that=school_that[i]
                _result_2=list()

                for X in school_:
                    if X in school_that_that:
                        if X=='city':
                            _result_2.append(city_id(str(school_that_that[X])))
                            #print(1, X,'___',city_id(str(school_that_that[X])))
                        if X=='country':
                            _result_2.append(country_id(school_that_that[X]))
                            #print(2, X,'___',country_id(school_that_that[X]))
                        if ((X!= 'country') and (X!='city')):
                            _result_2.append(str(school_that_that[X]))
                            #print(3, X,'___',school_that_that[X])

                    else:
                        _result_2.append('NULL')
                        #print(4, X,'___','NULL')
                _result_1.append(_result_2)
        
        if len(school_that)==1:
            school_that_that=school_that[0]
            _result_2=list()

            for X in school_:
                if X in school_that_that:
                    _result_2.append(str(school_that_that[X]))
                    #print(5, X,'___',school_that_that[X])
                else:
                    _result_2.append('NULL')
                    #print(6, X,'___','NULL')
            _result_1.append(_result_2)
            _result_1.append(school_NULL)
        if len(school_that)==0:
            _result_1.append(school_NULL)
            _result_1.append(school_NULL)
        
    else: 
        _result_1.append(school_NULL)
        _result_1.append(school_NULL)
    return _result_1

#не работает!
def replace_city_country (user):
    if len(user)==1:
        if 'country_id' in user:
            user['country_id']=country_id(user['country_id'])
        if 'city_id' in user:
            user['city_id']=city_id(user['city_id'])
        return user
    
    if len(user)>1:
        
        if ('country_id' or 'city_id') in user:
            if 'country_id' in user:
                user['country_id']=country_id(user['country_id'])
            if 'city_id' in user:
                user['city_id']=city_id(user['city_id'])
            return user
        else:
            for i in range(0,len(user)):    
                replace_city_country (user[i])
            
    if len(user)==0:
        return 'NULL'

# %%
dbase='workbase_2.db'

# %%
import time



multi=100 #размер запроса

for k in range(10700,100000): #количество запросов = порядковый номер юзера
    #try:
        #print(multi*k)
       # print(multi*(k+1))
        
        url = 'https://api.vk.com/method/users.get' 
        token = '74cc2fc574cc2fc574cc2fc51674bd0ddd774cc74cc2fc52a52f6d01cd4498f9b895e70'
        f='id, first_name, last_name, deactivated, is_closed, can_access_closed, about, activities, bdate, blacklisted, books, career, city, skype, facebook, twitter, livejournal, Instagram, contacts, mobile_phone, home_phone, counters, country, domain, education, followers_count, games, home_town, interests, last_seen, maiden_name, military, movies, music, nickname, occupation, personal, photo_50, photo_100, photo_200_orig, photo_200, photo_400_orig, photo_max, photo_max_orig, quotes, relatives, relation, schools, screen_name, sex, site, status, timezone, trendin, tv, universities, verified, university, university_name, faculty, faculty_name, chair_name, graduation, education_form, education_status'

        L=f.split(', ')
        
        
        ids = ",".join(map(str, range(multi*k, (multi*(k+1))))) #

        params = {'user_ids': ids, 'v': 5.103, 'fields': f, 'access_token': token, 'lang': 'ru'}  

        response_vk=requests.get(url, params=params) 
        print(response_vk.status_code)
        #print(response_vk.text)
        response_vk=response_vk.json()['response']
        #print('check_1')
        #print(response_vk)
        LLL1=list()
        
        
       
        LLL1=robot(response_vk)
        
        #print('check_2')
        if len(LLL1) == 0:
            time.sleep(0.05)
            continue
        else:
            write_to(LLL1)
        
    #except:
        print('k___',k)
# Out:
# 200
# Opened database successfully
# Records created successfully ____ 1070009
# k___ 10700
# 200
# Opened database successfully
# Records created successfully ____ 1070106
# k___ 10701
# 200
# Opened database successfully
# Records created successfully ____ 1070202
# k___ 10702
# 200
# Opened database successfully
# Records created successfully ____ 1070344
# k___ 10703
# 200
# 200
# 200
# Opened database successfully
# Records created successfully ____ 1070623
# k___ 10706
# 200
# Opened database successfully
# Records created successfully ____ 1070715
# k___ 10707
# 200
# Opened database successfully
# Records created successfully ____ 1070853
# k___ 10708
# 200
# Opened database successfully
# Records created successfully ____ 1070900
# k___ 10709
# 200
# Opened database successfully
# Records created successfully ____ 1071000
# k___ 10710
# 200
# Opened database successfully
# Records created successfully ____ 1071102
# k___ 10711
# 200
# Opened database successfully
# Records created successfully ____ 1071200
# k___ 10712
# 200
# Opened database successfully
# Records created successfully ____ 1071300
# k___ 10713
# 200
# Opened database successfully
# Records created successfully ____ 1071401
# k___ 10714
# 200
# Opened database successfully
# Records created successfully ____ 1071501
# k___ 10715
# 200
# Opened database successfully
# Records created successfully ____ 1071600
# k___ 10716
# 200
# Opened database successfully
# Records created successfully ____ 1071700
# k___ 10717
# 200
# Opened database successfully
# Records created successfully ____ 1071801
# k___ 10718
# 200
# Opened database successfully
# Records created successfully ____ 1071900
# k___ 10719
# 200
# Opened database successfully
# Records created successfully ____ 1072000
# k___ 10720
# 200
# Opened database successfully
# Records created successfully ____ 1072101
# k___ 10721
# 200
# Opened database successfully
# Records created successfully ____ 1072200
# k___ 10722
# 200
# Opened database successfully
# Records created successfully ____ 1072300
# k___ 10723
# 200
# Opened database successfully
# Records created successfully ____ 1072400
# k___ 10724
# 200
# Opened database successfully
# Records created successfully ____ 1072500
# k___ 10725
# 200
# Opened database successfully
# Records created successfully ____ 1072600
# k___ 10726
# 200
# Opened database successfully
# Records created successfully ____ 1072700
# k___ 10727
# 200
# Opened database successfully
# Records created successfully ____ 1072800
# k___ 10728
# 200
# Opened database successfully
# Records created successfully ____ 1072900
# k___ 10729
# 200
# Opened database successfully
# Records created successfully ____ 1073000
# k___ 10730
# 200
# Opened database successfully
# Records created successfully ____ 1073100
# k___ 10731
# 200
# Opened database successfully
# Records created successfully ____ 1073201
# k___ 10732
# 200
# Opened database successfully
# Records created successfully ____ 1073300
# k___ 10733
# 200
# Opened database successfully
# Records created successfully ____ 1073400
# k___ 10734
# 200
# Opened database successfully
# Records created successfully ____ 1073500
# k___ 10735
# 200
# Opened database successfully
# Records created successfully ____ 1073601
# k___ 10736
# 200
# Opened database successfully
# Records created successfully ____ 1073700
# k___ 10737
# 200
# Opened database successfully
# Records created successfully ____ 1073801
# k___ 10738
# 200
# Opened database successfully
# Records created successfully ____ 1073900
# k___ 10739
# 200
# Opened database successfully
# Records created successfully ____ 1074000
# k___ 10740
# 200
# Opened database successfully
# Records created successfully ____ 1074101
# k___ 10741
# 200
# Opened database successfully
# Records created successfully ____ 1074200
# k___ 10742
# 200
# Opened database successfully
# Records created successfully ____ 1074300
# k___ 10743
# 200
# Opened database successfully
# Records created successfully ____ 1074400
# k___ 10744
# 200
# Opened database successfully
# Records created successfully ____ 1074500
# k___ 10745
# 200
# Opened database successfully
# Records created successfully ____ 1074600
# k___ 10746
# 200
# Opened database successfully
# Records created successfully ____ 1074700
# k___ 10747
# 200
# Opened database successfully
# Records created successfully ____ 1074801
# k___ 10748
# 200
# Opened database successfully
# Records created successfully ____ 1074900
# k___ 10749
# 200
# Opened database successfully
# Records created successfully ____ 1075000
# k___ 10750
# 200
# Opened database successfully
# Records created successfully ____ 1075100
# k___ 10751
# 200
# Opened database successfully
# Records created successfully ____ 1075200
# k___ 10752
# 200
# Opened database successfully
# Records created successfully ____ 1075300
# k___ 10753
# 200
# Opened database successfully
# Records created successfully ____ 1075401
# k___ 10754
# 200
# Opened database successfully
# Records created successfully ____ 1075500
# k___ 10755
# 200
# Opened database successfully
# Records created successfully ____ 1075601
# k___ 10756
# 200
# Opened database successfully
# Records created successfully ____ 1075701
# k___ 10757
# 200
# Opened database successfully
# Records created successfully ____ 1075800
# k___ 10758
# 200
# Opened database successfully
# Records created successfully ____ 1075900
# k___ 10759
# 200
# Opened database successfully
# Records created successfully ____ 1076000
# k___ 10760
# 200
# Opened database successfully
# Records created successfully ____ 1076100
# k___ 10761
# 200
# Opened database successfully
# Records created successfully ____ 1076200
# k___ 10762
# 200
# Opened database successfully
# Records created successfully ____ 1076300
# k___ 10763
# 200
# Opened database successfully
# Records created successfully ____ 1076403
# k___ 10764
# 200
# Opened database successfully
# Records created successfully ____ 1076500
# k___ 10765
# 200
# Opened database successfully
# Records created successfully ____ 1076600
# k___ 10766
# 200
# Opened database successfully
# Records created successfully ____ 1076701
# k___ 10767
# 200
# Opened database successfully
# Records created successfully ____ 1076800
# k___ 10768
# 200
# Opened database successfully
# Records created successfully ____ 1076900
# k___ 10769
# 200
# Opened database successfully
# Records created successfully ____ 1077000
# k___ 10770
# 200
# Opened database successfully
# Records created successfully ____ 1077101
# k___ 10771
# 200
# Opened database successfully
# Records created successfully ____ 1077206
# k___ 10772
# 200
# Opened database successfully
# Records created successfully ____ 1077300
# k___ 10773
# 200
# Opened database successfully
# Records created successfully ____ 1077400
# k___ 10774
# 200
# Opened database successfully
# Records created successfully ____ 1077501
# k___ 10775
# 200
# Opened database successfully
# Records created successfully ____ 1077601
# k___ 10776
# 200
# Opened database successfully
# Records created successfully ____ 1077700
# k___ 10777
# 200
# Opened database successfully
# Records created successfully ____ 1077800
# k___ 10778
# 200
# Opened database successfully
# Records created successfully ____ 1077900
# k___ 10779
# 200
# Opened database successfully
# Records created successfully ____ 1078000
# k___ 10780
# 200
# Opened database successfully
# Records created successfully ____ 1078100
# k___ 10781
# 200
# Opened database successfully
# Records created successfully ____ 1078200
# k___ 10782
# 200
# Opened database successfully
# Records created successfully ____ 1078301
# k___ 10783
# 200
# Opened database successfully
# Records created successfully ____ 1078402
# k___ 10784
# 200
# Opened database successfully
# Records created successfully ____ 1078501
# k___ 10785
# 200
# Opened database successfully
# Records created successfully ____ 1078600
# k___ 10786
# 200
# Opened database successfully
# Records created successfully ____ 1078701
# k___ 10787
# 200
# Opened database successfully
# Records created successfully ____ 1078801
# k___ 10788
# 200
# Opened database successfully
# Records created successfully ____ 1078900
# k___ 10789
# 200
# Opened database successfully
# Records created successfully ____ 1079000
# k___ 10790
# 200
# Opened database successfully
# Records created successfully ____ 1079100
# k___ 10791
# 200
# Opened database successfully
# Records created successfully ____ 1079200
# k___ 10792
# 200
# Opened database successfully
# Records created successfully ____ 1079300
# k___ 10793
# 200
# Opened database successfully
# Records created successfully ____ 1079400
# k___ 10794
# 200
# Opened database successfully
# Records created successfully ____ 1079500
# k___ 10795
# 200
# Opened database successfully
# Records created successfully ____ 1079600
# k___ 10796
# 200
# Opened database successfully
# Records created successfully ____ 1079700
# k___ 10797
# 200
# Opened database successfully
# Records created successfully ____ 1079800
# k___ 10798
# 200
# Opened database successfully
# Records created successfully ____ 1079901
# k___ 10799
# 200
# Opened database successfully
# Records created successfully ____ 1080001
# k___ 10800
# 200
# Opened database successfully
# Records created successfully ____ 1080100
# k___ 10801
# 200
# Opened database successfully
# Records created successfully ____ 1080200
# k___ 10802
# 200
# Opened database successfully
# Records created successfully ____ 1080300
# k___ 10803
# 200
# Opened database successfully
# Records created successfully ____ 1080400
# k___ 10804
# 200
# Opened database successfully
# Records created successfully ____ 1080501
# k___ 10805
# 200
# Opened database successfully
# Records created successfully ____ 1080601
# k___ 10806
# 200
# Opened database successfully
# Records created successfully ____ 1080700
# k___ 10807
# 200
# Opened database successfully
# Records created successfully ____ 1080800
# k___ 10808
# 200
# Opened database successfully
# Records created successfully ____ 1080902
# k___ 10809
# 200
# Opened database successfully
# Records created successfully ____ 1081000
# k___ 10810
# 200
# Opened database successfully
# Records created successfully ____ 1081100
# k___ 10811
# 200
# Opened database successfully
# Records created successfully ____ 1081201
# k___ 10812
# 200
# Opened database successfully
# Records created successfully ____ 1081301
# k___ 10813
# 200
# Opened database successfully
# Records created successfully ____ 1081400
# k___ 10814
# 200
# Opened database successfully
# Records created successfully ____ 1081502
# k___ 10815
# 200
# Opened database successfully
# Records created successfully ____ 1081601
# k___ 10816
# 200
# Opened database successfully
# Records created successfully ____ 1081700
# k___ 10817
# 200
# Opened database successfully
# Records created successfully ____ 1081800
# k___ 10818
# 200
# Opened database successfully
# Records created successfully ____ 1081901
# k___ 10819
# 200
# Opened database successfully
# Records created successfully ____ 1082002
# k___ 10820
# 200
# Opened database successfully
# Records created successfully ____ 1082100
# k___ 10821
# 200
# Opened database successfully
# Records created successfully ____ 1082200
# k___ 10822
# 200
# Opened database successfully
# Records created successfully ____ 1082300
# k___ 10823
# 200
# Opened database successfully
# Records created successfully ____ 1082401
# k___ 10824
# 200
# Opened database successfully
# Records created successfully ____ 1082501
# k___ 10825
# 200
# Opened database successfully
# Records created successfully ____ 1082600
# k___ 10826
# 200
# Opened database successfully
# Records created successfully ____ 1082700
# k___ 10827
# 200
# Opened database successfully
# Records created successfully ____ 1082800
# k___ 10828
# 200
# Opened database successfully
# Records created successfully ____ 1082900
# k___ 10829
# 200
# Opened database successfully
# Records created successfully ____ 1083001
# k___ 10830
# 200
# Opened database successfully
# Records created successfully ____ 1083101
# k___ 10831
# 200
# Opened database successfully
# Records created successfully ____ 1083200
# k___ 10832
# 200
# Opened database successfully
# Records created successfully ____ 1083300
# k___ 10833
# 200
# Opened database successfully
# Records created successfully ____ 1083400
# k___ 10834
# 200
# Opened database successfully
# Records created successfully ____ 1083500
# k___ 10835
# 200
# Opened database successfully
# Records created successfully ____ 1083600
# k___ 10836
# 200
# Opened database successfully
# Records created successfully ____ 1083701
# k___ 10837
# 200
# Opened database successfully
# Records created successfully ____ 1083801
# k___ 10838
# 200
# Opened database successfully
# Records created successfully ____ 1083901
# k___ 10839
# 200
# Opened database successfully
# Records created successfully ____ 1084001
# k___ 10840
# 200
# Opened database successfully
# Records created successfully ____ 1084101
# k___ 10841
# 200
# Opened database successfully
# Records created successfully ____ 1084200
# k___ 10842
# 200
# Opened database successfully
# Records created successfully ____ 1084303
# k___ 10843
# 200
# Opened database successfully
# Records created successfully ____ 1084400
# k___ 10844
# 200
# Opened database successfully
# Records created successfully ____ 1084500
# k___ 10845
# 200
# Opened database successfully
# Records created successfully ____ 1084600
# k___ 10846
# 200
# Opened database successfully
# Records created successfully ____ 1084700
# k___ 10847
# 200
# Opened database successfully
# Records created successfully ____ 1084800
# k___ 10848
# 200
# Opened database successfully
# Records created successfully ____ 1084900
# k___ 10849
# 200
# Opened database successfully
# Records created successfully ____ 1085003
# k___ 10850
# 200
# Opened database successfully
# Records created successfully ____ 1085102
# k___ 10851
# 200
# Opened database successfully
# Records created successfully ____ 1085200
# k___ 10852
# 200
# Opened database successfully
# Records created successfully ____ 1085300
# k___ 10853
# 200
# Opened database successfully
# Records created successfully ____ 1085400
# k___ 10854
# 200
# Opened database successfully
# Records created successfully ____ 1085501
# k___ 10855
# 200
# Opened database successfully
# Records created successfully ____ 1085600
# k___ 10856
# 200
# Opened database successfully
# Records created successfully ____ 1085700
# k___ 10857
# 200
# Opened database successfully
# Records created successfully ____ 1085801
# k___ 10858
# 200
# Opened database successfully
# Records created successfully ____ 1085902
# k___ 10859
# 200
# Opened database successfully
# Records created successfully ____ 1086000
# k___ 10860
# 200
# Opened database successfully
# Records created successfully ____ 1086100
# k___ 10861
# 200
# Opened database successfully
# Records created successfully ____ 1086201
# k___ 10862
# 200
# Opened database successfully
# Records created successfully ____ 1086300
# k___ 10863
# 200
# Opened database successfully
# Records created successfully ____ 1086400
# k___ 10864
# 200
# Opened database successfully
# Records created successfully ____ 1086500
# k___ 10865
# 200
# Opened database successfully
# Records created successfully ____ 1086600
# k___ 10866
# 200
# Opened database successfully
# Records created successfully ____ 1086700
# k___ 10867
# 200
# Opened database successfully
# Records created successfully ____ 1086800
# k___ 10868
# 200
# Opened database successfully
# Records created successfully ____ 1086900
# k___ 10869
# 200
# Opened database successfully
# Records created successfully ____ 1087001
# k___ 10870
# 200
# Opened database successfully
# Records created successfully ____ 1087101
# k___ 10871
# 200
# Opened database successfully
# Records created successfully ____ 1087200
# k___ 10872
# 200
# Opened database successfully
# Records created successfully ____ 1087300
# k___ 10873
# 200
# Opened database successfully
# Records created successfully ____ 1087400
# k___ 10874
# 200
# Opened database successfully
# Records created successfully ____ 1087500
# k___ 10875
# 200
# Opened database successfully
# Records created successfully ____ 1087600
# k___ 10876
# 200
# Opened database successfully
# Records created successfully ____ 1087700
# k___ 10877
# 200
# Opened database successfully
# Records created successfully ____ 1087801
# k___ 10878
# 200
# Opened database successfully
# Records created successfully ____ 1087900
# k___ 10879
# 200
# Opened database successfully
# Records created successfully ____ 1088001
# k___ 10880
# 200
# Opened database successfully
# Records created successfully ____ 1088100
# k___ 10881
# 200
# Opened database successfully
# Records created successfully ____ 1088202
# k___ 10882
# 200
# Opened database successfully
# Records created successfully ____ 1088300
# k___ 10883
# 200
# Opened database successfully
# Records created successfully ____ 1088401
# k___ 10884
# 200
# Opened database successfully
# Records created successfully ____ 1088500
# k___ 10885
# 200
# Opened database successfully
# Records created successfully ____ 1088600
# k___ 10886
# 200
# Opened database successfully
# Records created successfully ____ 1088700
# k___ 10887
# 200
# Opened database successfully
# Records created successfully ____ 1088800
# k___ 10888
# 200
# Opened database successfully
# Records created successfully ____ 1088900
# k___ 10889
# 200
# Opened database successfully
# Records created successfully ____ 1089000
# k___ 10890
# 200
# Opened database successfully
# Records created successfully ____ 1089100
# k___ 10891
# 200
# Opened database successfully
# Records created successfully ____ 1089200
# k___ 10892
# 200
# Opened database successfully
# Records created successfully ____ 1089300
# k___ 10893
# 200
# Opened database successfully
# Records created successfully ____ 1089400
# k___ 10894
# 200
# Opened database successfully
# Records created successfully ____ 1089500
# k___ 10895
# 200
# Opened database successfully
# Records created successfully ____ 1089600
# k___ 10896
# 200
# Opened database successfully
# Records created successfully ____ 1089700
# k___ 10897
# 200
# Opened database successfully
# Records created successfully ____ 1089801
# k___ 10898
# 200
# Opened database successfully
# Records created successfully ____ 1089900
# k___ 10899
# 200
# Opened database successfully
# Records created successfully ____ 1090000
# k___ 10900
# 200
# Opened database successfully
# Records created successfully ____ 1090101
# k___ 10901
# 200
# Opened database successfully
# Records created successfully ____ 1090201
# k___ 10902
# 200
# Opened database successfully
# Records created successfully ____ 1090300
# k___ 10903
# 200
# Opened database successfully
# Records created successfully ____ 1090400
# k___ 10904
# 200
# Opened database successfully
# Records created successfully ____ 1090500
# k___ 10905
# 200
# Opened database successfully
# Records created successfully ____ 1090600
# k___ 10906
# 200
# Opened database successfully
# Records created successfully ____ 1090700
# k___ 10907
# 200
# Opened database successfully
# Records created successfully ____ 1090800
# k___ 10908
# 200
# Opened database successfully
# Records created successfully ____ 1090901
# k___ 10909
# 200
# Opened database successfully
# Records created successfully ____ 1091000
# k___ 10910
# 200
# Opened database successfully
# Records created successfully ____ 1091100
# k___ 10911
# 200
# Opened database successfully
# Records created successfully ____ 1091200
# k___ 10912
# 200
# Opened database successfully
# Records created successfully ____ 1091300
# k___ 10913
# 200
# Opened database successfully
# Records created successfully ____ 1091400
# k___ 10914
# 200
# Opened database successfully
# Records created successfully ____ 1091501
# k___ 10915
# 200
# Opened database successfully
# Records created successfully ____ 1091601
# k___ 10916
# 200
# Opened database successfully
# Records created successfully ____ 1091700
# k___ 10917
# 200
# Opened database successfully
# Records created successfully ____ 1091801
# k___ 10918
# 200
# Opened database successfully
# Records created successfully ____ 1091900
# k___ 10919
# 200
# Opened database successfully
# Records created successfully ____ 1092000
# k___ 10920
# 200
# Opened database successfully
# Records created successfully ____ 1092100
# k___ 10921
# 200
# Opened database successfully
# Records created successfully ____ 1092202
# k___ 10922
# 200
# Opened database successfully
# Records created successfully ____ 1092300
# k___ 10923
# 200
# Opened database successfully
# Records created successfully ____ 1092400
# k___ 10924
# 200
# Opened database successfully
# Records created successfully ____ 1092500
# k___ 10925
# 200
# Opened database successfully
# Records created successfully ____ 1092600
# k___ 10926
# 200
# Opened database successfully
# Records created successfully ____ 1092700
# k___ 10927
# 200
# Opened database successfully
# Records created successfully ____ 1092800
# k___ 10928
# 200
# Opened database successfully
# Records created successfully ____ 1092900
# k___ 10929
# 200
# Opened database successfully
# Records created successfully ____ 1093001
# k___ 10930
# 200
# Opened database successfully
# Records created successfully ____ 1093100
# k___ 10931
# 200
# Opened database successfully
# Records created successfully ____ 1093200
# k___ 10932
# 200
# Opened database successfully
# Records created successfully ____ 1093300
# k___ 10933
# 200
# Opened database successfully
# Records created successfully ____ 1093400
# k___ 10934
# 200
# Opened database successfully
# Records created successfully ____ 1093501
# k___ 10935
# 200
# Opened database successfully
# Records created successfully ____ 1093600
# k___ 10936
# 200
# Opened database successfully
# Records created successfully ____ 1093701
# k___ 10937
# 200
# Opened database successfully
# Records created successfully ____ 1093801
# k___ 10938
# 200
# Opened database successfully
# Records created successfully ____ 1093900
# k___ 10939
# 200
# Opened database successfully
# Records created successfully ____ 1094000
# k___ 10940
# 200
# Opened database successfully
# Records created successfully ____ 1094100
# k___ 10941
# 200
# Opened database successfully
# Records created successfully ____ 1094201
# k___ 10942
# 200
# Opened database successfully
# Records created successfully ____ 1094300
# k___ 10943
# 200
# Opened database successfully
# Records created successfully ____ 1094400
# k___ 10944
# 200
# Opened database successfully
# Records created successfully ____ 1094500
# k___ 10945
# 200
# Opened database successfully
# Records created successfully ____ 1094600
# k___ 10946
# 200
# Opened database successfully
# Records created successfully ____ 1094700
# k___ 10947
# 200
# Opened database successfully
# Records created successfully ____ 1094800
# k___ 10948
# 200
# Opened database successfully
# Records created successfully ____ 1094900
# k___ 10949
# 200
# Opened database successfully
# Records created successfully ____ 1095001
# k___ 10950
# 200
# Opened database successfully
# Records created successfully ____ 1095100
# k___ 10951
# 200
# Opened database successfully
# Records created successfully ____ 1095200
# k___ 10952
# 200
# Opened database successfully
# Records created successfully ____ 1095300
# k___ 10953
# 200
# Opened database successfully
# Records created successfully ____ 1095400
# k___ 10954
# 200
# Opened database successfully
# Records created successfully ____ 1095502
# k___ 10955
# 200
# Opened database successfully
# Records created successfully ____ 1095600
# k___ 10956
# 200
# Opened database successfully
# Records created successfully ____ 1095701
# k___ 10957
# 200
# Opened database successfully
# Records created successfully ____ 1095801
# k___ 10958
# 200
# Opened database successfully
# Records created successfully ____ 1095900
# k___ 10959
# 200
# Opened database successfully
# Records created successfully ____ 1096001
# k___ 10960
# 200
# Opened database successfully
# Records created successfully ____ 1096101
# k___ 10961
# 200
# Opened database successfully
# Records created successfully ____ 1096200
# k___ 10962
# 200
# Opened database successfully
# Records created successfully ____ 1096300
# k___ 10963
# 200
# Opened database successfully
# Records created successfully ____ 1096400
# k___ 10964
# 200
# Opened database successfully
# Records created successfully ____ 1096501
# k___ 10965
# 200
# Opened database successfully
# Records created successfully ____ 1096600
# k___ 10966
# 200
# Opened database successfully
# Records created successfully ____ 1096700
# k___ 10967
# 200
# Opened database successfully
# Records created successfully ____ 1096800
# k___ 10968
# 200
# Opened database successfully
# Records created successfully ____ 1096900
# k___ 10969
# 200
# Opened database successfully
# Records created successfully ____ 1097000
# k___ 10970
# 200
# Opened database successfully
# Records created successfully ____ 1097100
# k___ 10971
# 200
# Opened database successfully
# Records created successfully ____ 1097201
# k___ 10972
# 200
# Opened database successfully
# Records created successfully ____ 1097300
# k___ 10973
# 200
# Opened database successfully
# Records created successfully ____ 1097400
# k___ 10974
# 200
# Opened database successfully
# Records created successfully ____ 1097500
# k___ 10975
# 200
# Opened database successfully
# Records created successfully ____ 1097601
# k___ 10976
# 200
# Opened database successfully
# Records created successfully ____ 1097701
# k___ 10977
# 200
# Opened database successfully
# Records created successfully ____ 1097800
# k___ 10978
# 200
# Opened database successfully
# Records created successfully ____ 1097901
# k___ 10979
# 200
# Opened database successfully
# Records created successfully ____ 1098000
# k___ 10980
# 200
# Opened database successfully
# Records created successfully ____ 1098101
# k___ 10981
# 200
# Opened database successfully
# Records created successfully ____ 1098200
# k___ 10982
# 200
# Opened database successfully
# Records created successfully ____ 1098300
# k___ 10983
# 200
# Opened database successfully
# Records created successfully ____ 1098400
# k___ 10984
# 200
# Opened database successfully
# Records created successfully ____ 1098500
# k___ 10985
# 200
# Opened database successfully
# Records created successfully ____ 1098601
# k___ 10986
# 200
# Opened database successfully
# Records created successfully ____ 1098700
# k___ 10987
# 200
# Opened database successfully
# Records created successfully ____ 1098800
# k___ 10988
# 200
# Opened database successfully
# Records created successfully ____ 1098900
# k___ 10989
# 200
# Opened database successfully
# Records created successfully ____ 1099000
# k___ 10990
# 200
# Opened database successfully
# Records created successfully ____ 1099100
# k___ 10991
# 200
# Opened database successfully
# Records created successfully ____ 1099200
# k___ 10992
# 200
# Opened database successfully
# Records created successfully ____ 1099300
# k___ 10993
# 200
# Opened database successfully
# Records created successfully ____ 1099400
# k___ 10994
# 200
# Opened database successfully
# Records created successfully ____ 1099500
# k___ 10995
# 200
# Opened database successfully
# Records created successfully ____ 1099600
# k___ 10996
# 200
# Opened database successfully
# Records created successfully ____ 1099700
# k___ 10997
# 200
# Opened database successfully
# Records created successfully ____ 1099800
# k___ 10998
# 200
# Opened database successfully
# Records created successfully ____ 1099900
# k___ 10999
# 200
# Opened database successfully
# Records created successfully ____ 1100001
# k___ 11000
# 200
# Opened database successfully
# Records created successfully ____ 1100100
# k___ 11001
# 200
# Opened database successfully
# Records created successfully ____ 1100201
# k___ 11002
# 200
# Opened database successfully
# Records created successfully ____ 1100300
# k___ 11003
# 200
# Opened database successfully
# Records created successfully ____ 1100400
# k___ 11004
# 200
# Opened database successfully
# Records created successfully ____ 1100500
# k___ 11005
# 200
# Opened database successfully
# Records created successfully ____ 1100600
# k___ 11006
# 200
# Opened database successfully
# Records created successfully ____ 1100700
# k___ 11007
# 200
# Opened database successfully
# Records created successfully ____ 1100800
# k___ 11008
# 200
# Opened database successfully
# Records created successfully ____ 1100900
# k___ 11009
# 200
# Opened database successfully
# Records created successfully ____ 1101000
# k___ 11010
# 200
# Opened database successfully
# Records created successfully ____ 1101100
# k___ 11011
# 200
# Opened database successfully
# Records created successfully ____ 1101200
# k___ 11012
# 200
# Opened database successfully
# Records created successfully ____ 1101300
# k___ 11013
# 200
# Opened database successfully
# Records created successfully ____ 1101400
# k___ 11014
# 200
# Opened database successfully
# Records created successfully ____ 1101500
# k___ 11015
# 200
# Opened database successfully
# Records created successfully ____ 1101600
# k___ 11016
# 200
# Opened database successfully
# Records created successfully ____ 1101700
# k___ 11017
# 200
# Opened database successfully
# Records created successfully ____ 1101801
# k___ 11018
# 200
# Opened database successfully
# Records created successfully ____ 1101901
# k___ 11019
# 200
# Opened database successfully
# Records created successfully ____ 1102000
# k___ 11020
# 200
# Opened database successfully
# Records created successfully ____ 1102100
# k___ 11021
# 200
# Opened database successfully
# Records created successfully ____ 1102201
# k___ 11022
# 200
# Opened database successfully
# Records created successfully ____ 1102300
# k___ 11023
# 200
# Opened database successfully
# Records created successfully ____ 1102400
# k___ 11024
# 200
# Opened database successfully
# Records created successfully ____ 1102500
# k___ 11025
# 200
# Opened database successfully
# Records created successfully ____ 1102600
# k___ 11026
# 200
# Opened database successfully
# Records created successfully ____ 1102700
# k___ 11027
# 200
# Opened database successfully
# Records created successfully ____ 1102800
# k___ 11028
# 200
# Opened database successfully
# Records created successfully ____ 1102900
# k___ 11029
# 200
# Opened database successfully
# Records created successfully ____ 1103000
# k___ 11030
# 200
# Opened database successfully
# Records created successfully ____ 1103100
# k___ 11031
# 200
# Opened database successfully
# Records created successfully ____ 1103200
# k___ 11032
# 200
# Opened database successfully
# Records created successfully ____ 1103300
# k___ 11033
# 200
# Opened database successfully
# Records created successfully ____ 1103400
# k___ 11034
# 200
# Opened database successfully
# Records created successfully ____ 1103500
# k___ 11035
# 200
# Opened database successfully
# Records created successfully ____ 1103601
# k___ 11036
# 200
# Opened database successfully
# Records created successfully ____ 1103701
# k___ 11037
# 200
# Opened database successfully
# Records created successfully ____ 1103802
# k___ 11038
# 200
# Opened database successfully
# Records created successfully ____ 1103900
# k___ 11039
# 200
# Opened database successfully
# Records created successfully ____ 1104000
# k___ 11040
# 200
# Opened database successfully
# Records created successfully ____ 1104100
# k___ 11041
# 200
# Opened database successfully
# Records created successfully ____ 1104202
# k___ 11042
# 200
# Opened database successfully
# Records created successfully ____ 1104300
# k___ 11043
# 200
# Opened database successfully
# Records created successfully ____ 1104400
# k___ 11044
# 200
# Opened database successfully
# Records created successfully ____ 1104500
# k___ 11045
# 200
# Opened database successfully
# Records created successfully ____ 1104601
# k___ 11046
# 200
# Opened database successfully
# Records created successfully ____ 1104700
# k___ 11047
# 200
# Opened database successfully
# Records created successfully ____ 1104800
# k___ 11048
# 200
# Opened database successfully
# Records created successfully ____ 1104900
# k___ 11049
# 200
# Opened database successfully
# Records created successfully ____ 1105000
# k___ 11050
# 200
# Opened database successfully
# Records created successfully ____ 1105100
# k___ 11051
# 200
# Opened database successfully
# Records created successfully ____ 1105200
# k___ 11052
# 200
# Opened database successfully
# Records created successfully ____ 1105300
# k___ 11053
# 200
# Opened database successfully
# Records created successfully ____ 1105400
# k___ 11054
# 200
# Opened database successfully
# Records created successfully ____ 1105500
# k___ 11055
# 200
# Opened database successfully
# Records created successfully ____ 1105600
# k___ 11056
# 200
# Opened database successfully
# Records created successfully ____ 1105700
# k___ 11057
# 200
# Opened database successfully
# Records created successfully ____ 1105800
# k___ 11058
# 200
# Opened database successfully
# Records created successfully ____ 1105900
# k___ 11059
# 200
# Opened database successfully
# Records created successfully ____ 1106001
# k___ 11060
# 200
# Opened database successfully
# Records created successfully ____ 1106100
# k___ 11061
# 200
# Opened database successfully
# Records created successfully ____ 1106200
# k___ 11062
# 200
# Opened database successfully
# Records created successfully ____ 1106302
# k___ 11063
# 200
# Opened database successfully
# Records created successfully ____ 1106400
# k___ 11064
# 200
# Opened database successfully
# Records created successfully ____ 1106501
# k___ 11065
# 200
# Opened database successfully
# Records created successfully ____ 1106602
# k___ 11066
# 200
# Opened database successfully
# Records created successfully ____ 1106701
# k___ 11067
# 200
# Opened database successfully
# Records created successfully ____ 1106800
# k___ 11068
# 200
# Opened database successfully
# Records created successfully ____ 1106900
# k___ 11069
# 200
# Opened database successfully
# Records created successfully ____ 1107000
# k___ 11070
# 200
# Opened database successfully
# Records created successfully ____ 1107100
# k___ 11071
# 200
# Opened database successfully
# Records created successfully ____ 1107201
# k___ 11072
# 200
# Opened database successfully
# Records created successfully ____ 1107301
# k___ 11073
# 200
# Opened database successfully
# Records created successfully ____ 1107400
# k___ 11074
# 200
# Opened database successfully
# Records created successfully ____ 1107500
# k___ 11075
# 200
# Opened database successfully
# Records created successfully ____ 1107600
# k___ 11076
# 200
# Opened database successfully
# Records created successfully ____ 1107700
# k___ 11077
# 200
# Opened database successfully
# Records created successfully ____ 1107800
# k___ 11078
# 200
# Opened database successfully
# Records created successfully ____ 1107900
# k___ 11079
# 200
# Opened database successfully
# Records created successfully ____ 1108000
# k___ 11080
# 200
# Opened database successfully
# Records created successfully ____ 1108100
# k___ 11081
# 200
# Opened database successfully
# Records created successfully ____ 1108201
# k___ 11082
# 200
# Opened database successfully
# Records created successfully ____ 1108300
# k___ 11083
# 200
# Opened database successfully
# Records created successfully ____ 1108401
# k___ 11084
# 200
# Opened database successfully
# Records created successfully ____ 1108500
# k___ 11085
# 200
# Opened database successfully
# Records created successfully ____ 1108601
# k___ 11086
# 200
# Opened database successfully
# Records created successfully ____ 1108700
# k___ 11087
# 200
# Opened database successfully
# Records created successfully ____ 1108800
# k___ 11088
# 200
# Opened database successfully
# Records created successfully ____ 1108902
# k___ 11089
# 200
# Opened database successfully
# Records created successfully ____ 1109000
# k___ 11090
# 200
# Opened database successfully
# Records created successfully ____ 1109101
# k___ 11091
# 200
# Opened database successfully
# Records created successfully ____ 1109200
# k___ 11092
# 200
# Opened database successfully
# Records created successfully ____ 1109300
# k___ 11093
# 200
# Opened database successfully
# Records created successfully ____ 1109400
# k___ 11094
# 200
# Opened database successfully
# Records created successfully ____ 1109500
# k___ 11095
# 200
# Opened database successfully
# Records created successfully ____ 1109600
# k___ 11096
# 200
# Opened database successfully
# Records created successfully ____ 1109700
# k___ 11097
# 200
# Opened database successfully
# Records created successfully ____ 1109801
# k___ 11098
# 200
# Opened database successfully
# Records created successfully ____ 1109901
# k___ 11099
# 200
# Opened database successfully
# Records created successfully ____ 1110001
# k___ 11100
# 200
# Opened database successfully
# Records created successfully ____ 1110100
# k___ 11101
# 200
# Opened database successfully
# Records created successfully ____ 1110200
# k___ 11102
# 200
# Opened database successfully
# Records created successfully ____ 1110300
# k___ 11103
# 200
# Opened database successfully
# Records created successfully ____ 1110400
# k___ 11104
# 200
# Opened database successfully
# Records created successfully ____ 1110501
# k___ 11105
# 200
# Opened database successfully
# Records created successfully ____ 1110601
# k___ 11106
# 200
# Opened database successfully
# Records created successfully ____ 1110700
# k___ 11107
# 200
# Opened database successfully
# Records created successfully ____ 1110800
# k___ 11108
# 200
# Opened database successfully
# Records created successfully ____ 1110900
# k___ 11109
# 200
# Opened database successfully
# Records created successfully ____ 1111001
# k___ 11110
# 200
# Opened database successfully
# Records created successfully ____ 1111101
# k___ 11111
# 200
# Opened database successfully
# Records created successfully ____ 1111200
# k___ 11112
# 200
# Opened database successfully
# Records created successfully ____ 1111301
# k___ 11113
# 200
# Opened database successfully
# Records created successfully ____ 1111400
# k___ 11114
# 200
# Opened database successfully
# Records created successfully ____ 1111501
# k___ 11115
# 200
# Opened database successfully
# Records created successfully ____ 1111604
# k___ 11116
# 200
# Opened database successfully
# Records created successfully ____ 1111701
# k___ 11117
# 200
# Opened database successfully
# Records created successfully ____ 1111801
# k___ 11118
# 200
# Opened database successfully
# Records created successfully ____ 1111900
# k___ 11119
# 200
# Opened database successfully
# Records created successfully ____ 1112000
# k___ 11120
# 200
# Opened database successfully
# Records created successfully ____ 1112100
# k___ 11121
# 200
# Opened database successfully
# Records created successfully ____ 1112200
# k___ 11122
# 200
# Opened database successfully
# Records created successfully ____ 1112300
# k___ 11123
# 200
# Opened database successfully
# Records created successfully ____ 1112400
# k___ 11124
# 200
# Opened database successfully
# Records created successfully ____ 1112500
# k___ 11125
# 200
# Opened database successfully
# Records created successfully ____ 1112600
# k___ 11126
# 200
# Opened database successfully
# Records created successfully ____ 1112700
# k___ 11127
# 200
# Opened database successfully
# Records created successfully ____ 1112800
# k___ 11128
# 200
# Opened database successfully
# Records created successfully ____ 1112900
# k___ 11129
# 200
# Opened database successfully
# Records created successfully ____ 1113000
# k___ 11130
# 200
# Opened database successfully
# Records created successfully ____ 1113100
# k___ 11131
# 200
# Opened database successfully
# Records created successfully ____ 1113200
# k___ 11132
# 200
# Opened database successfully
# Records created successfully ____ 1113300
# k___ 11133
# 200
# Opened database successfully
# Records created successfully ____ 1113401
# k___ 11134
# 200
# Opened database successfully
# Records created successfully ____ 1113500
# k___ 11135
# 200
# Opened database successfully
# Records created successfully ____ 1113600
# k___ 11136
# 200
# Opened database successfully
# Records created successfully ____ 1113700
# k___ 11137
# 200
# Opened database successfully
# Records created successfully ____ 1113800
# k___ 11138
# 200
# Opened database successfully
# Records created successfully ____ 1113901
# k___ 11139
# 200
# Opened database successfully
# Records created successfully ____ 1114000
# k___ 11140
# 200
# Opened database successfully
# Records created successfully ____ 1114100
# k___ 11141
# 200
# Opened database successfully
# Records created successfully ____ 1114200
# k___ 11142
# 200
# Opened database successfully
# Records created successfully ____ 1114300
# k___ 11143
# 200
# Opened database successfully
# Records created successfully ____ 1114402
# k___ 11144
# 200
# Opened database successfully
# Records created successfully ____ 1114500
# k___ 11145
# 200
# Opened database successfully
# Records created successfully ____ 1114600
# k___ 11146
# 200
# Opened database successfully
# Records created successfully ____ 1114700
# k___ 11147
# 200
# Opened database successfully
# Records created successfully ____ 1114802
# k___ 11148
# 200
# Opened database successfully
# Records created successfully ____ 1114901
# k___ 11149
# 200
# Opened database successfully
# Records created successfully ____ 1115000
# k___ 11150
# 200
# Opened database successfully
# Records created successfully ____ 1115100
# k___ 11151
# 200
# Opened database successfully
# Records created successfully ____ 1115201
# k___ 11152
# 200
# Opened database successfully
# Records created successfully ____ 1115300
# k___ 11153
# 200
# Opened database successfully
# Records created successfully ____ 1115400
# k___ 11154
# 200
# Opened database successfully
# Records created successfully ____ 1115500
# k___ 11155
# 200
# Opened database successfully
# Records created successfully ____ 1115601
# k___ 11156
# 200
# Opened database successfully
# Records created successfully ____ 1115700
# k___ 11157
# 200
# Opened database successfully
# Records created successfully ____ 1115800
# k___ 11158
# 200
# Opened database successfully
# Records created successfully ____ 1115901
# k___ 11159
# 200
# Opened database successfully
# Records created successfully ____ 1116002
# k___ 11160
# 200
# Opened database successfully
# Records created successfully ____ 1116100
# k___ 11161
# 200
# Opened database successfully
# Records created successfully ____ 1116201
# k___ 11162
# 200
# Opened database successfully
# Records created successfully ____ 1116302
# k___ 11163
# 200
# Opened database successfully
# Records created successfully ____ 1116400
# k___ 11164
# 200
# Opened database successfully
# Records created successfully ____ 1116500
# k___ 11165
# 200
# Opened database successfully
# Records created successfully ____ 1116600
# k___ 11166
# 200
# Opened database successfully
# Records created successfully ____ 1116701
# k___ 11167
# 200
# Opened database successfully
# Records created successfully ____ 1116800
# k___ 11168
# 200
# Opened database successfully
# Records created successfully ____ 1116901
# k___ 11169
# 200
# Opened database successfully
# Records created successfully ____ 1117001
# k___ 11170
# 200
# Opened database successfully
# Records created successfully ____ 1117103
# k___ 11171
# 200
# Opened database successfully
# Records created successfully ____ 1117201
# k___ 11172
# 200
# Opened database successfully
# Records created successfully ____ 1117300
# k___ 11173
# 200
# Opened database successfully
# Records created successfully ____ 1117400
# k___ 11174
# 200
# Opened database successfully
# Records created successfully ____ 1117500
# k___ 11175
# 200
# Opened database successfully
# Records created successfully ____ 1117600
# k___ 11176
# 200
# Opened database successfully
# Records created successfully ____ 1117700
# k___ 11177
# 200
# Opened database successfully
# Records created successfully ____ 1117802
# k___ 11178
# 200
# Opened database successfully
# Records created successfully ____ 1117900
# k___ 11179
# 200
# Opened database successfully
# Records created successfully ____ 1118000
# k___ 11180
# 200
# Opened database successfully
# Records created successfully ____ 1118102
# k___ 11181
# 200
# Opened database successfully
# Records created successfully ____ 1118200
# k___ 11182
# 200
# Opened database successfully
# Records created successfully ____ 1118301
# k___ 11183
# 200
# Opened database successfully
# Records created successfully ____ 1118401
# k___ 11184
# 200
# Opened database successfully
# Records created successfully ____ 1118500
# k___ 11185
# 200
# Opened database successfully
# Records created successfully ____ 1118600
# k___ 11186
# 200
# Opened database successfully
# Records created successfully ____ 1118700
# k___ 11187
# 200
# Opened database successfully
# Records created successfully ____ 1118800
# k___ 11188
# 200
# Opened database successfully
# Records created successfully ____ 1118900
# k___ 11189
# 200
# Opened database successfully
# Records created successfully ____ 1119000
# k___ 11190
# 200
# Opened database successfully
# Records created successfully ____ 1119100
# k___ 11191
# 200
# Opened database successfully
# Records created successfully ____ 1119200
# k___ 11192
# 200
# Opened database successfully
# Records created successfully ____ 1119300
# k___ 11193
# 200
# Opened database successfully
# Records created successfully ____ 1119400
# k___ 11194
# 200
# Opened database successfully
# Records created successfully ____ 1119500
# k___ 11195
# 200
# Opened database successfully
# Records created successfully ____ 1119600
# k___ 11196
# 200
# Opened database successfully
# Records created successfully ____ 1119700
# k___ 11197
# 200
# Opened database successfully
# Records created successfully ____ 1119802
# k___ 11198
# 200
# Opened database successfully
# Records created successfully ____ 1119900
# k___ 11199
# 200
# Opened database successfully
# Records created successfully ____ 1120000
# k___ 11200
# 200
# Opened database successfully
# Records created successfully ____ 1120100
# k___ 11201
# 200
# Opened database successfully
# Records created successfully ____ 1120200
# k___ 11202
# 200
# Opened database successfully
# Records created successfully ____ 1120300
# k___ 11203
# 200
# Opened database successfully
# Records created successfully ____ 1120401
# k___ 11204
# 200
# Opened database successfully
# Records created successfully ____ 1120500
# k___ 11205
# 200
# Opened database successfully
# Records created successfully ____ 1120600
# k___ 11206
# 200
# Opened database successfully
# Records created successfully ____ 1120703
# k___ 11207
# 200
# Opened database successfully
# Records created successfully ____ 1120800
# k___ 11208
# 200
# Opened database successfully
# Records created successfully ____ 1120900
# k___ 11209
# 200
# Opened database successfully
# Records created successfully ____ 1121000
# k___ 11210
# 200
# Opened database successfully
# Records created successfully ____ 1121100
# k___ 11211
# 200
# Opened database successfully
# Records created successfully ____ 1121200
# k___ 11212
# 200
# Opened database successfully
# Records created successfully ____ 1121300
# k___ 11213
# 200
# Opened database successfully
# Records created successfully ____ 1121400
# k___ 11214
# 200
# Opened database successfully
# Records created successfully ____ 1121501
# k___ 11215
# 200
# Opened database successfully
# Records created successfully ____ 1121602
# k___ 11216
# 200
# Opened database successfully
# Records created successfully ____ 1121700
# k___ 11217
# 200
# Opened database successfully
# Records created successfully ____ 1121800
# k___ 11218
# 200
# Opened database successfully
# Records created successfully ____ 1121901
# k___ 11219
# 200
# Opened database successfully
# Records created successfully ____ 1122000
# k___ 11220
# 200
# Opened database successfully
# Records created successfully ____ 1122100
# k___ 11221
# 200
# Opened database successfully
# Records created successfully ____ 1122201
# k___ 11222
# 200
# Opened database successfully
# Records created successfully ____ 1122300
# k___ 11223
# 200
# Opened database successfully
# Records created successfully ____ 1122400
# k___ 11224
# 200
# Opened database successfully
# Records created successfully ____ 1122500
# k___ 11225
# 200
# Opened database successfully
# Records created successfully ____ 1122600
# k___ 11226
# 200
# Opened database successfully
# Records created successfully ____ 1122700
# k___ 11227
# 200
# Opened database successfully
# Records created successfully ____ 1122801
# k___ 11228
# 200
# Opened database successfully
# Records created successfully ____ 1122901
# k___ 11229
# 200
# Opened database successfully
# Records created successfully ____ 1123001
# k___ 11230
# 200
# Opened database successfully
# Records created successfully ____ 1123102
# k___ 11231
# 200
# Opened database successfully
# Records created successfully ____ 1123200
# k___ 11232
# 200
# Opened database successfully
# Records created successfully ____ 1123300
# k___ 11233
# 200
# Opened database successfully
# Records created successfully ____ 1123400
# k___ 11234
# 200
# Opened database successfully
# Records created successfully ____ 1123501
# k___ 11235
# 200
# Opened database successfully
# Records created successfully ____ 1123600
# k___ 11236
# 200
# Opened database successfully
# Records created successfully ____ 1123701
# k___ 11237
# 200
# Opened database successfully
# Records created successfully ____ 1123801
# k___ 11238
# 200
# Opened database successfully
# Records created successfully ____ 1123901
# k___ 11239
# 200
# Opened database successfully
# Records created successfully ____ 1124001
# k___ 11240
# 200
# Opened database successfully
# Records created successfully ____ 1124100
# k___ 11241
# 200
# Opened database successfully
# Records created successfully ____ 1124201
# k___ 11242
# 200
# Opened database successfully
# Records created successfully ____ 1124302
# k___ 11243
# 200
# Opened database successfully
# Records created successfully ____ 1124400
# k___ 11244
# 200
# Opened database successfully
# Records created successfully ____ 1124500
# k___ 11245
# 200
# Opened database successfully
# Records created successfully ____ 1124601
# k___ 11246
# 200
# Opened database successfully
# Records created successfully ____ 1124700
# k___ 11247
# 200
# Opened database successfully
# Records created successfully ____ 1124800
# k___ 11248
# 200
# Opened database successfully
# Records created successfully ____ 1124901
# k___ 11249
# 200
# Opened database successfully
# Records created successfully ____ 1125000
# k___ 11250
# 200
# Opened database successfully
# Records created successfully ____ 1125100
# k___ 11251
# 200
# Opened database successfully
# Records created successfully ____ 1125201
# k___ 11252
# 200
# Opened database successfully
# Records created successfully ____ 1125300
# k___ 11253
# 200
# Opened database successfully
# Records created successfully ____ 1125400
# k___ 11254
# 200
# Opened database successfully
# Records created successfully ____ 1125500
# k___ 11255
# 200
# Opened database successfully
# Records created successfully ____ 1125601
# k___ 11256
# 200
# Opened database successfully
# Records created successfully ____ 1125700
# k___ 11257
# 200
# Opened database successfully
# Records created successfully ____ 1125800
# k___ 11258
# 200
# Opened database successfully
# Records created successfully ____ 1125900
# k___ 11259
# 200
# ...
# 200
# Opened database successfully
# Records created successfully ____ 1695200
# k___ 16952
# 200
# Opened database successfully
# Records created successfully ____ 1695300
# k___ 16953
# 200
# Opened database successfully
# Records created successfully ____ 1695400
# k___ 16954
# 200
# Opened database successfully
# Records created successfully ____ 1695500
# k___ 16955
# 200
# Opened database successfully
# Records created successfully ____ 1695600
# k___ 16956
# 200
# Opened database successfully
# Records created successfully ____ 1695700
# k___ 16957
# 200
# Opened database successfully
# Records created successfully ____ 1695800
# k___ 16958
# 200
# Opened database successfully
# Records created successfully ____ 1695900
# k___ 16959
# 200
# Opened database successfully
# Records created successfully ____ 1696000
# k___ 16960
# 200
# Opened database successfully
# Records created successfully ____ 1696100
# k___ 16961
# 200
# Opened database successfully
# Records created successfully ____ 1696200
# k___ 16962
# 200
# Opened database successfully
# Records created successfully ____ 1696300
# k___ 16963
# 200
# Opened database successfully
# Records created successfully ____ 1696400
# k___ 16964
# 200
# Opened database successfully
# Records created successfully ____ 1696500
# k___ 16965
# 200
# Opened database successfully
# Records created successfully ____ 1696600
# k___ 16966
# 200
# Opened database successfully
# Records created successfully ____ 1696700
# k___ 16967
# 200
# Opened database successfully
# Records created successfully ____ 1696800
# k___ 16968
# 200
# Opened database successfully
# Records created successfully ____ 1696900
# k___ 16969
# 200
# Opened database successfully
# Records created successfully ____ 1697003
# k___ 16970
# 200
# Opened database successfully
# Records created successfully ____ 1697100
# k___ 16971
# 200
# Opened database successfully
# Records created successfully ____ 1697200
# k___ 16972
# 200
# Opened database successfully
# Records created successfully ____ 1697301
# k___ 16973
# 200
# Opened database successfully
# Records created successfully ____ 1697400
# k___ 16974
# 200
# Opened database successfully
# Records created successfully ____ 1697500
# k___ 16975
# 200
# Opened database successfully
# Records created successfully ____ 1697601
# k___ 16976
# 200
# Opened database successfully
# Records created successfully ____ 1697700
# k___ 16977
# 200
# Opened database successfully
# Records created successfully ____ 1697801
# k___ 16978
# 200
# Opened database successfully
# Records created successfully ____ 1697900
# k___ 16979
# 200
# Opened database successfully
# Records created successfully ____ 1698000
# k___ 16980
# 200
# Opened database successfully
# Records created successfully ____ 1698104
# k___ 16981
# 200
# Opened database successfully
# Records created successfully ____ 1698201
# k___ 16982
# 200
# Opened database successfully
# Records created successfully ____ 1698300
# k___ 16983
# 200
# Opened database successfully
# Records created successfully ____ 1698400
# k___ 16984
# 200
# Opened database successfully
# Records created successfully ____ 1698500
# k___ 16985
# 200
# Opened database successfully
# Records created successfully ____ 1698602
# k___ 16986
# 200
# Opened database successfully
# Records created successfully ____ 1698701
# k___ 16987
# 200
# Opened database successfully
# Records created successfully ____ 1698800
# k___ 16988
# 200
# Opened database successfully
# Records created successfully ____ 1698900
# k___ 16989
# 200
# Opened database successfully
# Records created successfully ____ 1699001
# k___ 16990
# 200
# Opened database successfully
# Records created successfully ____ 1699100
# k___ 16991
# 200
# Opened database successfully
# Records created successfully ____ 1699200
# k___ 16992
# 200
# Opened database successfully
# Records created successfully ____ 1699300
# k___ 16993
# 200
# Opened database successfully
# Records created successfully ____ 1699402
# k___ 16994
# 200
# Opened database successfully
# Records created successfully ____ 1699500
# k___ 16995
# 200
# Opened database successfully
# Records created successfully ____ 1699602
# k___ 16996
# 200
# Opened database successfully
# Records created successfully ____ 1699700
# k___ 16997
# 200
# Opened database successfully
# Records created successfully ____ 1699802
# k___ 16998
# 200
# Opened database successfully
# Records created successfully ____ 1699902
# k___ 16999
# 200
# Opened database successfully
# Records created successfully ____ 1700000
# k___ 17000
# 200
# Opened database successfully
# Records created successfully ____ 1700100
# k___ 17001
# 200
# Opened database successfully
# Records created successfully ____ 1700200
# k___ 17002
# 200
# Opened database successfully
# Records created successfully ____ 1700300
# k___ 17003
# 200
# Opened database successfully
# Records created successfully ____ 1700400
# k___ 17004
# 200
# Opened database successfully
# Records created successfully ____ 1700500
# k___ 17005
# 200
# Opened database successfully
# Records created successfully ____ 1700600
# k___ 17006
# 200
# Opened database successfully
# Records created successfully ____ 1700701
# k___ 17007
# 200
# Opened database successfully
# Records created successfully ____ 1700801
# k___ 17008
# 200
# Opened database successfully
# Records created successfully ____ 1700900
# k___ 17009
# 200
# Opened database successfully
# Records created successfully ____ 1701000
# k___ 17010
# 200
# Opened database successfully
# Records created successfully ____ 1701101
# k___ 17011
# 200
# Opened database successfully
# Records created successfully ____ 1701200
# k___ 17012
# 200
# Opened database successfully
# Records created successfully ____ 1701300
# k___ 17013
# 200
# Opened database successfully
# Records created successfully ____ 1701400
# k___ 17014
# 200
# Opened database successfully
# Records created successfully ____ 1701500
# k___ 17015
# 200
# Opened database successfully
# Records created successfully ____ 1701601
# k___ 17016
# 200
# Opened database successfully
# Records created successfully ____ 1701700
# k___ 17017
# 200
# Opened database successfully
# Records created successfully ____ 1701800
# k___ 17018
# 200
# Opened database successfully
# Records created successfully ____ 1701902
# k___ 17019
# 200
# Opened database successfully
# Records created successfully ____ 1702001
# k___ 17020
# 200
# Opened database successfully
# Records created successfully ____ 1702101
# k___ 17021
# 200
# Opened database successfully
# Records created successfully ____ 1702200
# k___ 17022
# 200
# Opened database successfully
# Records created successfully ____ 1702301
# k___ 17023
# 200
# Opened database successfully
# Records created successfully ____ 1702400
# k___ 17024
# 200
# Opened database successfully
# Records created successfully ____ 1702501
# k___ 17025
# 200
# Opened database successfully
# Records created successfully ____ 1702600
# k___ 17026
# 200
# Opened database successfully
# Records created successfully ____ 1702702
# k___ 17027
# 200
# Opened database successfully
# Records created successfully ____ 1702800
# k___ 17028
# 200
# Opened database successfully
# Records created successfully ____ 1702901
# k___ 17029
# 200
# Opened database successfully
# Records created successfully ____ 1703000
# k___ 17030
# 200
# Opened database successfully
# Records created successfully ____ 1703100
# k___ 17031
# 200
# Opened database successfully
# Records created successfully ____ 1703200
# k___ 17032
# 200
# Opened database successfully
# Records created successfully ____ 1703300
# k___ 17033
# 200
# Opened database successfully
# Records created successfully ____ 1703400
# k___ 17034
# 200
# Opened database successfully
# Records created successfully ____ 1703500
# k___ 17035
# 200
# Opened database successfully
# Records created successfully ____ 1703600
# k___ 17036
# 200
# Opened database successfully
# Records created successfully ____ 1703700
# k___ 17037
# 200
# Opened database successfully
# Records created successfully ____ 1703801
# k___ 17038
# 200
# Opened database successfully
# Records created successfully ____ 1703902
# k___ 17039
# 200
# Opened database successfully
# Records created successfully ____ 1704000
# k___ 17040
# 200
# Opened database successfully
# Records created successfully ____ 1704102
# k___ 17041
# 200
# Opened database successfully
# Records created successfully ____ 1704200
# k___ 17042
# 200
# Opened database successfully
# Records created successfully ____ 1704300
# k___ 17043
# 200
# Opened database successfully
# Records created successfully ____ 1704401
# k___ 17044
# 200
# Opened database successfully
# Records created successfully ____ 1704500
# k___ 17045
# 200
# Opened database successfully
# Records created successfully ____ 1704600
# k___ 17046
# 200
# Opened database successfully
# Records created successfully ____ 1704700
# k___ 17047
# 200
# Opened database successfully
# Records created successfully ____ 1704800
# k___ 17048
# 200
# Opened database successfully
# Records created successfully ____ 1704904
# k___ 17049
# 200
# Opened database successfully
# Records created successfully ____ 1705004
# k___ 17050
# 200
# Opened database successfully
# Records created successfully ____ 1705101
# k___ 17051
# 200
# Opened database successfully
# Records created successfully ____ 1705201
# k___ 17052
# 200
# Opened database successfully
# Records created successfully ____ 1705302
# k___ 17053
# 200
# Opened database successfully
# Records created successfully ____ 1705400
# k___ 17054
# 200
# Opened database successfully
# Records created successfully ____ 1705500
# k___ 17055
# 200
# Opened database successfully
# Records created successfully ____ 1705600
# k___ 17056
# 200
# Opened database successfully
# Records created successfully ____ 1705700
# k___ 17057
# 200
# Opened database successfully
# Records created successfully ____ 1705800
# k___ 17058
# 200
# Opened database successfully
# Records created successfully ____ 1705900
# k___ 17059
# 200
# Opened database successfully
# Records created successfully ____ 1706000
# k___ 17060
# 200
# Opened database successfully
# Records created successfully ____ 1706100
# k___ 17061
# 200
# Opened database successfully
# Records created successfully ____ 1706201
# k___ 17062
# 200
# Opened database successfully
# Records created successfully ____ 1706300
# k___ 17063
# 200
# Opened database successfully
# Records created successfully ____ 1706402
# k___ 17064
# 200
# Opened database successfully
# Records created successfully ____ 1706500
# k___ 17065
# 200
# Opened database successfully
# Records created successfully ____ 1706603
# k___ 17066
# 200
# Opened database successfully
# Records created successfully ____ 1706700
# k___ 17067
# 200
# Opened database successfully
# Records created successfully ____ 1706800
# k___ 17068
# 200
# Opened database successfully
# Records created successfully ____ 1706901
# k___ 17069
# 200
# Opened database successfully
# Records created successfully ____ 1707001
# k___ 17070
# 200
# Opened database successfully
# Records created successfully ____ 1707100
# k___ 17071
# 200
# Opened database successfully
# Records created successfully ____ 1707200
# k___ 17072
# 200
# Opened database successfully
# Records created successfully ____ 1707300
# k___ 17073
# 200
# Opened database successfully
# Records created successfully ____ 1707402
# k___ 17074
# 200
# Opened database successfully
# Records created successfully ____ 1707500
# k___ 17075
# 200
# Opened database successfully
# Records created successfully ____ 1707600
# k___ 17076
# 200
# Opened database successfully
# Records created successfully ____ 1707700
# k___ 17077
# 200
# Opened database successfully
# Records created successfully ____ 1707801
# k___ 17078
# 200
# Opened database successfully
# Records created successfully ____ 1707900
# k___ 17079
# 200
# Opened database successfully
# Records created successfully ____ 1708000
# k___ 17080
# 200
# Opened database successfully
# Records created successfully ____ 1708100
# k___ 17081
# 200
# Opened database successfully
# Records created successfully ____ 1708200
# k___ 17082
# 200
# Opened database successfully
# Records created successfully ____ 1708300
# k___ 17083
# 200
# Opened database successfully
# Records created successfully ____ 1708400
# k___ 17084
# 200
# Opened database successfully
# Records created successfully ____ 1708502
# k___ 17085
# 200
# Opened database successfully
# Records created successfully ____ 1708600
# k___ 17086
# 200
# Opened database successfully
# Records created successfully ____ 1708700
# k___ 17087
# 200
# Opened database successfully
# Records created successfully ____ 1708800
# k___ 17088
# 200
# Opened database successfully
# Records created successfully ____ 1708900
# k___ 17089
# 200
# Opened database successfully
# Records created successfully ____ 1709000
# k___ 17090
# 200
# Opened database successfully
# Records created successfully ____ 1709100
# k___ 17091
# 200
# Opened database successfully
# Records created successfully ____ 1709201
# k___ 17092
# 200
# Opened database successfully
# Records created successfully ____ 1709300
# k___ 17093
# 200
# Opened database successfully
# Records created successfully ____ 1709400
# k___ 17094
# 200
# Opened database successfully
# Records created successfully ____ 1709500
# k___ 17095
# 200
# Opened database successfully
# Records created successfully ____ 1709601
# k___ 17096
# 200
# Opened database successfully
# Records created successfully ____ 1709700
# k___ 17097
# 200
# Opened database successfully
# Records created successfully ____ 1709800
# k___ 17098
# 200
# Opened database successfully
# Records created successfully ____ 1709900
# k___ 17099
# 200
# Opened database successfully
# Records created successfully ____ 1710003
# k___ 17100
# 200
# Opened database successfully
# Records created successfully ____ 1710100
# k___ 17101
# 200
# Opened database successfully
# Records created successfully ____ 1710201
# k___ 17102
# 200
# Opened database successfully
# Records created successfully ____ 1710300
# k___ 17103
# 200
# Opened database successfully
# Records created successfully ____ 1710400
# k___ 17104
# 200
# Opened database successfully
# Records created successfully ____ 1710500
# k___ 17105
# 200
# Opened database successfully
# Records created successfully ____ 1710600
# k___ 17106
# 200
# Opened database successfully
# Records created successfully ____ 1710700
# k___ 17107
# 200
# Opened database successfully
# Records created successfully ____ 1710802
# k___ 17108
# 200
# Opened database successfully
# Records created successfully ____ 1710901
# k___ 17109
# 200
# Opened database successfully
# Records created successfully ____ 1711000
# k___ 17110
# 200
# Opened database successfully
# Records created successfully ____ 1711100
# k___ 17111
# 200
# Opened database successfully
# Records created successfully ____ 1711200
# k___ 17112
# 200
# Opened database successfully
# Records created successfully ____ 1711300
# k___ 17113
# 200
# Opened database successfully
# Records created successfully ____ 1711400
# k___ 17114
# 200
# Opened database successfully
# Records created successfully ____ 1711500
# k___ 17115
# 200
# Opened database successfully
# Records created successfully ____ 1711600
# k___ 17116
# 200
# Opened database successfully
# Records created successfully ____ 1711700
# k___ 17117
# 200
# Opened database successfully
# Records created successfully ____ 1711800
# k___ 17118
# 200
# Opened database successfully
# Records created successfully ____ 1711900
# k___ 17119
# 200
# Opened database successfully
# Records created successfully ____ 1712000
# k___ 17120
# 200
# Opened database successfully
# Records created successfully ____ 1712101
# k___ 17121
# 200
# Opened database successfully
# Records created successfully ____ 1712200
# k___ 17122
# 200
# Opened database successfully
# Records created successfully ____ 1712300
# k___ 17123
# 200
# Opened database successfully
# Records created successfully ____ 1712400
# k___ 17124
# 200
# Opened database successfully
# Records created successfully ____ 1712500
# k___ 17125
# 200
# Opened database successfully
# Records created successfully ____ 1712601
# k___ 17126
# 200
# Opened database successfully
# Records created successfully ____ 1712701
# k___ 17127
# 200
# Opened database successfully
# Records created successfully ____ 1712800
# k___ 17128
# 200
# Opened database successfully
# Records created successfully ____ 1712901
# k___ 17129
# 200
# Opened database successfully
# Records created successfully ____ 1713001
# k___ 17130
# 200
# Opened database successfully
# Records created successfully ____ 1713101
# k___ 17131
# 200
# Opened database successfully
# Records created successfully ____ 1713201
# k___ 17132
# 200
# Opened database successfully
# Records created successfully ____ 1713300
# k___ 17133
# 200
# Opened database successfully
# Records created successfully ____ 1713400
# k___ 17134
# 200
# Opened database successfully
# Records created successfully ____ 1713500
# k___ 17135
# 200
# Opened database successfully
# Records created successfully ____ 1713601
# k___ 17136
# 200
# Opened database successfully
# Records created successfully ____ 1713700
# k___ 17137

# %%
multi=10

for k in range(0,10):
    #try:
        print(multi*k, '____',multi*(k+1))

# %%
print(response_vk[28])

# %%
print(LLL1)

# %%
ids = ",".join(map(str, range(10,15)))
print(ids)

# %%
len(ids)

# %%
1069901-1070000

# %%
multi=100 #размер запроса

for k in range(10700,11000): #ко
    print(multi*k, (multi*(k+1)))
